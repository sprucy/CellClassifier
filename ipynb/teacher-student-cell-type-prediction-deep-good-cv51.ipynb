# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Deep'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Deep
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (83, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries,
non-null     object
# dtypes: float64(36), object(1)
# memory usage: 24.1+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 83
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      17 non-null     float64
#  1   sag                   17 non-null     float64
#  2   VmatSag               17 non-null     float64
#  3   vmbaseM               17 non-null     float64
#  4   tau                   17 non-null     float64
#  5   FAP_rheobase          17 non-null     float64
#  6   FAP_num_APs           17 non-null     float64
#  7   TS1_rheobase          17 non-null     float64
#  8   TS1_num_APs           17 non-null     float64
#  9   TS2_rheobase          17 non-null     float64
#  10  TS2_num_APs           17 non-null     float64
#  11  TS1_adp_index         17 non-null     float64
#  12  TS2_adp_index         17 non-null     float64
#  13  FAP_threshold         17 non-null     float64
#  14  FAP_peak              17 non-null     float64
#  15  FAP_maxupstroke       17 non-null     float64
#  16  FAP_maxdownstroke     17 non-null     float64
#  17  FAP_halfwidth         17 non-null     float64
#  18  FAP_avg_upstroke      17 non-null     float64
#  19  FAP_avg_downstroke    17 non-null     float64
#  20  FAP_up_down_ratio     17 non-null     float64
#  21  TS1_threshold         17 non-null     float64
#  22  TS1_maxupstroke       17 non-null     float64
#  23  TS1_maxdownstroke     17 non-null     float64
#  24  TS1_halfwidth         17 non-null     float64
#  25  TS1_avg_upstroke      17 non-null     float64
#  26  TS1_avg_downstroke    17 non-null     float64
#  27  TS1_up_down_ratio     17 non-null     float64
#  28  TS2_threshold         17 non-null     float64
#  29  TS2_peak              17 non-null     float64
#  30  TS2_maxupstroke       17 non-null     float64
#  31  TS2_maxdownstroke     17 non-null     float64
#  32  TS2_avg_upstroke      17 non-null     float64
#  33  TS2_avg_downstroke    17 non-null     float64
#  34  TS2_up_down_ratio     17 non-null     float64
#  35  L23_depth_normalized  17 non-null     float64
#  36  label                 17 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 5.0+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='good_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=True
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
num_bag_sets=1
dynamic_stacking = True
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       5.95 GB / 15.92 GB (37.4%)
# Disk Space Avail:   306.79 GB / 931.51 GB (32.9%)
# ===================================================
# Presets specified: ['good_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Starting (repeated-)cross-validation-based sub-fits for dynamic stacking. Context path: "models\Teacher\good_quality-20241101-172756\ds_sub_fit"Run at most 5 sub-fits based on 1-repeated 5-fold cross-validation.
# 	Starting sub-fit 1. Time limit for the sub-fit of this split is: 180.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 17:28:02,890	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8268
# 		Context path: "models\Teacher\good_quality-20241101-172756\ds_sub_fit\sub_fit_0"
# (_dystack pid=85416) Running DyStack sub-fit ...
# (_dystack pid=85416) Beginning AutoGluon training ... Time limit = 890s
# (_dystack pid=85416) AutoGluon will save models to "models\Teacher\good_quality-20241101-172756\ds_sub_fit\sub_fit_0"
# (_dystack pid=85416) Train Data Rows:    69
# (_dystack pid=85416) Train Data Columns: 36
# (_dystack pid=85416) Label Column:       label
# (_dystack pid=85416) Problem Type:       multiclass
# (_dystack pid=85416) Preprocessing data ...
# (_dystack pid=85416) Train Data Class Count: 3
# (_dystack pid=85416) Using Feature Generators to preprocess the data ...
# (_dystack pid=85416) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=85416) 	Available Memory:                    5523.25 MB
# (_dystack pid=85416) 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=85416) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=85416) 	Stage 1 Generators:
# (_dystack pid=85416) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=85416) 	Stage 2 Generators:
# (_dystack pid=85416) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=85416) 	Stage 3 Generators:
# (_dystack pid=85416) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=85416) 	Stage 4 Generators:
# (_dystack pid=85416) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=85416) 	Stage 5 Generators:
# (_dystack pid=85416) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=85416) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=85416) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=85416) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=85416) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=85416) 	0.1s = Fit runtime
# (_dystack pid=85416) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=85416) 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=85416) Data preprocessing and feature engineering runtime = 0.1s ...
# (_dystack pid=85416) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=85416) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=85416) User-specified model hyperparameters to be fit:
# (_dystack pid=85416) {
# (_dystack pid=85416) 	'NN_TORCH': {},
# (_dystack pid=85416) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=85416) 	'CAT': {},
# (_dystack pid=85416) 	'XGB': {},
# (_dystack pid=85416) 	'FASTAI': {},
# (_dystack pid=85416) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=85416) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=85416) }
# (_dystack pid=85416) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=85416) Fitting 11 L1 models ...
# (_dystack pid=85416) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 592.96s of the 889.65s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=85416) 	0.942	 = Validation score   (accuracy)
# (_dystack pid=85416) 	11.05s	 = Training   runtime
# (_dystack pid=85416) 	0.11s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 574.05s of the 870.74s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=85416) 	0.8841	 = Validation score   (accuracy)
# (_dystack pid=85416) 	3.91s	 = Training   runtime
# (_dystack pid=85416) 	0.01s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBM_BAG_L1 ... Training model for up to 563.7s of the 860.39s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=85416) 	0.8841	 = Validation score   (accuracy)
# (_dystack pid=85416) 	3.69s	 = Training   runtime
# (_dystack pid=85416) 	0.02s	 = Validation runtime
# (_dystack pid=85416) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 554.07s of the 850.76s of remaining time.
# (_dystack pid=85416) 	0.8696	 = Validation score   (accuracy)
# (_dystack pid=85416) 	1.21s	 = Training   runtime
# (_dystack pid=85416) 	0.08s	 = Validation runtime
# (_dystack pid=85416) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 552.68s of the 849.37s of remaining time.
# (_dystack pid=85416) 	0.8696	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.86s	 = Training   runtime
# (_dystack pid=85416) 	0.09s	 = Validation runtime
# (_dystack pid=85416) Fitting model: CatBoost_BAG_L1 ... Training model for up to 551.7s of the 848.39s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=85416) 	0.913	 = Validation score   (accuracy)
# (_dystack pid=85416) 	9.27s	 = Training   runtime
# (_dystack pid=85416) 	0.01s	 = Validation runtime
# (_dystack pid=85416) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 537.32s of the 834.01s of remaining time.
# (_dystack pid=85416) 	0.8551	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.87s	 = Training   runtime
# (_dystack pid=85416) 	0.09s	 = Validation runtime
# (_dystack pid=85416) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 536.35s of the 833.04s of remaining time.
# (_dystack pid=85416) 	0.8406	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.83s	 = Training   runtime
# (_dystack pid=85416) 	0.13s	 = Validation runtime
# (_dystack pid=85416) Fitting model: XGBoost_BAG_L1 ... Training model for up to 535.35s of the 832.04s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=85416) 	0.8696	 = Validation score   (accuracy)
# (_dystack pid=85416) 	4.18s	 = Training   runtime
# (_dystack pid=85416) 	0.03s	 = Validation runtime
# (_dystack pid=85416) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 525.44s of the 822.13s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=87680) Stack (most recent call first):
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=87680)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=87680)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=85416) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=85416) 	23.65s	 = Training   runtime
# (_dystack pid=85416) 	0.12s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 495.84s of the 792.53s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# (_ray_fit pid=86216) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=86216)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=86216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=85416) 	0.8551	 = Validation score   (accuracy)
# (_dystack pid=85416) 	3.91s	 = Training   runtime
# (_dystack pid=85416) 	0.01s	 = Validation runtime
# (_dystack pid=85416) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 782.48s of remaining time.
# (_dystack pid=85416) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# (_dystack pid=85416) 	0.942	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.19s	 = Training   runtime
# (_dystack pid=85416) 	0.0s	 = Validation runtime
# (_dystack pid=85416) Fitting 11 L2 models ...
# (_dystack pid=85416) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 782.28s of the 782.27s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=85416) 	0.9275	 = Validation score   (accuracy)
# (_dystack pid=85416) 	11.21s	 = Training   runtime
# (_dystack pid=85416) 	0.08s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 765.24s of the 765.23s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=85416) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=85416) 	3.26s	 = Training   runtime
# (_dystack pid=85416) 	0.04s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBM_BAG_L2 ... Training model for up to 755.61s of the 755.59s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=85416) 	0.8986	 = Validation score   (accuracy)
# (_dystack pid=85416) 	4.0s	 = Training   runtime
# (_dystack pid=85416) 	0.01s	 = Validation runtime
# (_dystack pid=85416) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 745.81s of the 745.8s of remaining time.
# (_dystack pid=85416) 	0.8696	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.9s	 = Training   runtime
# (_dystack pid=85416) 	0.1s	 = Validation runtime
# (_dystack pid=85416) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 744.77s of the 744.76s of remaining time.
# (_dystack pid=85416) 	0.8551	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.8s	 = Training   runtime
# (_dystack pid=85416) 	0.15s	 = Validation runtime
# (_dystack pid=85416) Fitting model: CatBoost_BAG_L2 ... Training model for up to 743.79s of the 743.76s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# (_dystack pid=85416) 	0.9275	 = Validation score   (accuracy)
# (_dystack pid=85416) 	14.31s	 = Training   runtime
# (_dystack pid=85416) 	0.04s	 = Validation runtime
# (_dystack pid=85416) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 723.54s of the 723.51s of remaining time.
# (_dystack pid=85416) 	0.8841	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.81s	 = Training   runtime
# (_dystack pid=85416) 	0.1s	 = Validation runtime
# (_dystack pid=85416) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 722.58s of the 722.56s of remaining time.
# (_dystack pid=85416) 	0.8841	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.77s	 = Training   runtime
# (_dystack pid=85416) 	0.1s	 = Validation runtime
# (_dystack pid=85416) Fitting model: XGBoost_BAG_L2 ... Training model for up to 721.67s of the 721.66s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# (_dystack pid=85416) 	0.8551	 = Validation score   (accuracy)
# (_dystack pid=85416) 	4.56s	 = Training   runtime
# (_dystack pid=85416) 	0.04s	 = Validation runtime
# (_dystack pid=85416) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 711.77s of the 711.75s of remaining time.
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=81768) Stack (most recent call first):
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=81768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=81768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=85416) 	0.913	 = Validation score   (accuracy)
# (_dystack pid=85416) 	19.87s	 = Training   runtime
# (_dystack pid=85416) 	0.25s	 = Validation runtime
# (_dystack pid=85416) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 686.08s of the 686.06s of remaining time.
# (_ray_fit pid=85828) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=85828)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=85828)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=85416) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.01%)
# (_dystack pid=85416) 	0.8551	 = Validation score   (accuracy)
# (_dystack pid=85416) 	4.13s	 = Training   runtime
# (_dystack pid=85416) 	0.02s	 = Validation runtime
# (_dystack pid=85416) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 676.12s of remaining time.
# (_dystack pid=85416) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# (_dystack pid=85416) 	0.942	 = Validation score   (accuracy)
# (_dystack pid=85416) 	0.3s	 = Training   runtime
# (_dystack pid=85416) 	0.0s	 = Validation runtime
# (_dystack pid=85416) AutoGluon training complete, total runtime = 213.94s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 85.6 rows/s (9 batch size)
# (_dystack pid=85416) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=85416) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=85416) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=85416) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=85416) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=85416) 	Stopping at the best epoch learned earlier - 8.
# (_dystack pid=85416) 	0.42s	 = Training   runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=85416) 	0.18s	 = Training   runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=85416) 	0.12s	 = Training   runtime
# (_dystack pid=85416) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=85416) 	1.21s	 = Training   runtime
# (_dystack pid=85416) 	0.08s	 = Validation runtime
# (_dystack pid=85416) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=85416) 	0.86s	 = Training   runtime
# (_dystack pid=85416) 	0.09s	 = Validation runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=85416) 	0.82s	 = Training   runtime
# (_dystack pid=85416) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=85416) 	0.87s	 = Training   runtime
# (_dystack pid=85416) 	0.09s	 = Validation runtime
# (_dystack pid=85416) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=85416) 	0.83s	 = Training   runtime
# (_dystack pid=85416) 	0.13s	 = Validation runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=85416) 	0.01s	 = Training   runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=85416) Stack (most recent call first):
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=85416)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=85416)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 496 in _fit_single
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 263 in _fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 165 in _fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1844 in _train_single
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1904 in _train_and_save
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2269 in _train_single_full
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2496 in _train_multi_fold
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2378 in _train_multi_initial
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2539 in _train_multi
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 730 in stack_new_level_core
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1366 in refit_single_full
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1449 in refit_ensemble_full
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py", line 450 in refit_ensemble_full
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py", line 3270 in refit_full
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py", line 1513 in _post_fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py", line 1175 in _fit
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py", line 5175 in _dystack
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_dystack pid=85416)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=85416) 	22.14s	 = Training   runtime
# (_dystack pid=85416) Fitting 1 L1 models ...
# (_dystack pid=85416) Fitting model: LightGBMLarge_BAG_L1_FULL ...
# (_dystack pid=85416) 	0.24s	 = Training   runtime
# (_dystack pid=85416) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# ...
# 8    NeuralNetFastAI_BAG_L2_FULL       0.833333   0.898551    accuracy        0.383178            NaN  5.715027                 0.011387                     NaN           0.362551            2       True         12
# 9           LightGBM_BAG_L2_FULL       0.833333   0.956522    accuracy        0.388039            NaN  5.494594                 0.016248                     NaN           0.142118            2       True         14
# 10        LightGBMXT_BAG_L1_FULL       0.777778   0.869565    accuracy        0.001529            NaN  0.208430                 0.001529                     NaN           0.208430            1       True          2
# 11  RandomForestGini_BAG_L1_FULL       0.777778   0.840580    accuracy        0.069304       0.112481  0.992788                 0.069304                0.112481           0.992788            1       True          4
# 12  RandomForestEntr_BAG_L1_FULL       0.777778   0.840580    accuracy        0.141129       0.096792  0.816608                 0.141129                0.096792           0.816608            1       True          5
# 13  RandomForestEntr_BAG_L2_FULL       0.777778   0.913043    accuracy        0.463320            NaN  6.273841                 0.091529                0.129823           0.921365            2       True         16
# 14  RandomForestGini_BAG_L2_FULL       0.777778   0.884058    accuracy        0.490676            NaN  6.365871                 0.118885                0.111028           1.013396            2       True         15
# 15          LightGBM_BAG_L1_FULL       0.722222   0.884058    accuracy        0.000000            NaN  0.134459                 0.000000                     NaN           0.134459            1       True          3
# 16           XGBoost_BAG_L1_FULL       0.722222   0.913043    accuracy        0.004032            NaN  0.035315                 0.004032                     NaN           0.035315            1       True          9
# 	Stop cross-validation during dynamic stacking early as no more time left. Consider specifying a larger time_limit.
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	914s	 = DyStack   runtime |	2686s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2686s
# AutoGluon will save models to "models\Teacher\good_quality-20241101-172756"
# Train Data Rows:    87
# Train Data Columns: 36
# Label Column:       label
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5048.49 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.2s = Fit runtime
# 	36 features in original data used to generate 36 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.2s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1789.93s of the 2685.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.954	 = Validation score   (accuracy)
# 	12.35s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1768.06s of the 2663.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.8966	 = Validation score   (accuracy)
# 	4.74s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1757.27s of the 2652.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.8966	 = Validation score   (accuracy)
# 	4.57s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1746.54s of the 2642.17s of remaining time.
# 	0.8851	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1745.51s of the 2641.14s of remaining time.
# 	0.8851	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1744.34s of the 2639.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8851	 = Validation score   (accuracy)
# 	10.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1727.82s of the 2623.45s of remaining time.
# 	0.8736	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1726.67s of the 2622.3s of remaining time.
# 	0.8736	 = Validation score   (accuracy)
# 	0.8s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1725.72s of the 2621.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8966	 = Validation score   (accuracy)
# 	4.2s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1715.23s of the 2610.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.931	 = Validation score   (accuracy)
# 	20.21s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1689.06s of the 2584.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.8851	 = Validation score   (accuracy)
# 	4.73s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2573.81s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.954	 = Validation score   (accuracy)
# 	0.19s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2573.58s of the 2573.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.954	 = Validation score   (accuracy)
# 	12.36s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2555.3s of the 2555.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.931	 = Validation score   (accuracy)
# 	3.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2545.3s of the 2545.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	0.9425	 = Validation score   (accuracy)
# 	3.99s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 2535.45s of the 2535.42s of remaining time.
# 	0.9195	 = Validation score   (accuracy)
# 	0.93s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 2534.32s of the 2534.3s of remaining time.
# 	0.9195	 = Validation score   (accuracy)
# 	0.75s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2533.41s of the 2533.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.9425	 = Validation score   (accuracy)
# 	17.71s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 2509.94s of the 2509.92s of remaining time.
# 	0.908	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 2508.93s of the 2508.91s of remaining time.
# 	0.9195	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2507.88s of the 2507.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.954	 = Validation score   (accuracy)
# 	4.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2497.4s of the 2497.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.9195	 = Validation score   (accuracy)
# 	22.83s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2468.61s of the 2468.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.04%)
# 	0.9425	 = Validation score   (accuracy)
# 	5.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 2457.54s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.954	 = Validation score   (accuracy)
# 	0.4s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 228.67s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 110.6 rows/s (11 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.89s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.96s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	0.33s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.96s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.8s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.03s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	10.85s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.27s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.19s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	0.36s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.24s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.93s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.75s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	0.07s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.86s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.86s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	1.37s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	0.21s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.4s	 = Training   runtime
# Updated best model to "NeuralNetFastAI_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "NeuralNetFastAI_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 15.95s ... Best model: "NeuralNetFastAI_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\good_quality-20241101-172756")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\medium_quality-20241008-171554"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: NeuralNetFastAI_BAG_L1_FULL
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L3   0.954023    accuracy       0.098592  12.746136                0.000000           0.395980            3      False         24
# 1         NeuralNetFastAI_BAG_L1   0.954023    accuracy       0.098592  12.350156                0.098592          12.350156            1      False          1
# 2            WeightedEnsemble_L2   0.954023    accuracy       0.105193  12.544300                0.006601           0.194145            2      False         12
# 3                 XGBoost_BAG_L2   0.954023    accuracy       0.871060  69.264678                0.035500           4.515158            2      False         21
# 4         NeuralNetFastAI_BAG_L2   0.954023    accuracy       0.948511  77.114282                0.112951          12.364762            2      False         13
# 5           LightGBMLarge_BAG_L2   0.942529    accuracy       0.836567  69.803056                0.001007           5.053536            2      False         23
# 6                LightGBM_BAG_L2   0.942529    accuracy       0.842951  68.735782                0.007391           3.986262            2      False         15
# 7                CatBoost_BAG_L2   0.942529    accuracy       0.870207  82.461098                0.034647          17.711578            2      False         18
# 8          NeuralNetTorch_BAG_L1   0.931034    accuracy       0.158993  20.205369                0.158993          20.205369            1      False         10
# 9              LightGBMXT_BAG_L2   0.931034    accuracy       0.843571  68.466783                0.008011           3.717262            2      False         14
# 10       RandomForestEntr_BAG_L2   0.919540    accuracy       0.930968  65.500555                0.095407           0.751034            2      False         17
# 11       RandomForestGini_BAG_L2   0.919540    accuracy       0.945119  65.683730                0.109559           0.934210            2      False         16
# 12         ExtraTreesEntr_BAG_L2   0.919540    accuracy       0.961092  65.608928                0.125531           0.859408            2      False         20
# 13         NeuralNetTorch_BAG_L2   0.919540    accuracy       1.061703  87.579686                0.226143          22.830166            2      False         22
# 14         ExtraTreesGini_BAG_L2   0.908046    accuracy       0.932472  65.613701                0.096911           0.864181            2      False         19
# 15             LightGBMXT_BAG_L1   0.896552    accuracy       0.023217   4.738702                0.023217           4.738702            1      False          2
# 16                XGBoost_BAG_L1   0.896552    accuracy       0.030474   4.203879                0.030474           4.203879            1      False          9
# 17               LightGBM_BAG_L1   0.896552    accuracy       0.038447   4.573402                0.038447           4.573402            1      False          3
# 18               CatBoost_BAG_L1   0.885057    accuracy       0.012634  10.336131                0.012634          10.336131            1      False          6
# 19          LightGBMLarge_BAG_L1   0.885057    accuracy       0.018631   4.726743                0.018631           4.726743            1      False         11
# 20       RandomForestGini_BAG_L1   0.885057    accuracy       0.086764   0.894839                0.086764           0.894839            1       True          4
# 21       RandomForestEntr_BAG_L1   0.885057    accuracy       0.123066   0.961340                0.123066           0.961340            1       True          5
# 22         ExtraTreesEntr_BAG_L1   0.873563    accuracy       0.090368   0.798167                0.090368           0.798167            1       True          8
# 23         ExtraTreesGini_BAG_L1   0.873563    accuracy       0.154375   0.960792                0.154375           0.960792            1       True          7
# 24  RandomForestGini_BAG_L1_FULL        NaN    accuracy       0.086764   0.894839                0.086764           0.894839            1       True         28
# 25    ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       0.090368   0.798167                0.090368           0.798167            1       True         32
# 26  RandomForestEntr_BAG_L1_FULL        NaN    accuracy       0.123066   0.961340                0.123066           0.961340            1       True         29
# 27    ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       0.154375   0.960792                0.154375           0.960792            1       True         31
# 28           XGBoost_BAG_L2_FULL        NaN    accuracy            NaN  16.018267                     NaN           0.045212            2       True         45
# 29           XGBoost_BAG_L1_FULL        NaN    accuracy            NaN   0.030879                     NaN           0.030879            1       True         33
# 30      WeightedEnsemble_L3_FULL        NaN    accuracy            NaN   0.835062                     NaN           0.395980            3       True         48
# 31      WeightedEnsemble_L2_FULL        NaN    accuracy            NaN   0.633226                     NaN           0.194145            2       True         36
# 32  RandomForestGini_BAG_L2_FULL        NaN    accuracy            NaN  16.907265                0.109559           0.934210            2       True         40
# 33  RandomForestEntr_BAG_L2_FULL        NaN    accuracy            NaN  16.724090                0.095407           0.751034            2       True         41
# 34    NeuralNetTorch_BAG_L2_FULL        NaN    accuracy            NaN  17.339445                     NaN           1.366389            2       True         46
# 35    NeuralNetTorch_BAG_L1_FULL        NaN    accuracy            NaN  10.845537                     NaN          10.845537            1       True         34
# 36   NeuralNetFastAI_BAG_L2_FULL        NaN    accuracy            NaN  16.334389                     NaN           0.361334            2       True         37
# 37   NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN   0.439081                     NaN           0.439081            1       True         25
# 38          LightGBM_BAG_L2_FULL        NaN    accuracy            NaN  16.210244                     NaN           0.237188            2       True         39
# 39          LightGBM_BAG_L1_FULL        NaN    accuracy            NaN   0.176055                     NaN           0.176055            1       True         27
# 40        LightGBMXT_BAG_L2_FULL        NaN    accuracy            NaN  16.183776                     NaN           0.210720            2       True         38
# 41        LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN   0.263623                     NaN           0.263623            1       True         26
# 42     LightGBMLarge_BAG_L2_FULL        NaN    accuracy            NaN  16.186590                     NaN           0.213534            2       True         47
# 43     LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN   0.273415                     NaN           0.273415            1       True         35
# 44    ExtraTreesGini_BAG_L2_FULL        NaN    accuracy            NaN  16.837236                0.096911           0.864181            2       True         43
# 45    ExtraTreesEntr_BAG_L2_FULL        NaN    accuracy            NaN  16.832463                0.125531           0.859408            2       True         44
# 46          CatBoost_BAG_L2_FULL        NaN    accuracy            NaN  16.046033                     NaN           0.072978            2       True         42
# 47          CatBoost_BAG_L1_FULL        NaN    accuracy            NaN   0.329326                     NaN           0.329326            1       True         30
# Number of models trained: 48
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# NeuralNetFastAI_BAG_L1_FULL
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.75      0.60      0.67         5
#         Exc L3-4 RORB CARM1P1       0.67      0.50      0.57         4
#         Exc L3-5 RORB COL22A1       0.80      1.00      0.89         8
#
#                      accuracy                           0.76        17
#                     macro avg       0.74      0.70      0.71        17
#                  weighted avg       0.75      0.76      0.75        17

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[3 1 1]
#  [1 2 1]
#  [0 0 8]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                        0.518870               0.188508
# 1                        0.687522               0.198668
# 2                        0.005936               0.006250
# 3                        0.036614               0.018794
# 4                        0.195047               0.144075
# 5                        0.086638               0.861340
# 6                        0.289342               0.420630
# 7                        0.002815               0.001198
# 8                        0.999127               0.000132
# 9                        0.000580               0.000071
# 10                       0.077310               0.884291
# 11                       0.357182               0.004971
# 12                       0.204848               0.161849
# 13                       0.851888               0.114954
# 14                       0.024621               0.055171
# 15                       0.000389               0.000075
# 16                       0.004662               0.000483
#
#     Exc L3-5 RORB COL22A1
# 0                0.292621
# 1                0.113810
# 2                0.987814
# 3                0.944592
# 4                0.660878
# 5                0.052022
# 6                0.290028
# 7                0.995987
# 8                0.000742
# 9                0.999348
# 10               0.038399
# 11               0.637847
# 12               0.633303
# 13               0.033157
# 14               0.920207
# 15               0.999536
# 16               0.994855

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 17 rows with 5 shuffle sets...
# 	5.65s	= Expected runtime (1.13s per shuffle set)
# 	0.87s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                         importance    stddev   p_value  n  p99_high   p99_low
# TS1_rheobase          7.058824e-02  0.064438  0.035242  5  0.203267 -0.062090
# L23_depth_normalized  5.882353e-02  0.072044  0.070964  5  0.207163 -0.089516
# TS2_rheobase          4.705882e-02  0.049215  0.049650  5  0.148394 -0.054276
# TS2_avg_upstroke      4.705882e-02  0.026307  0.008065  5  0.101225 -0.007107
# TS2_maxupstroke       4.705882e-02  0.026307  0.008065  5  0.101225 -0.007107
# TS2_up_down_ratio     3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# TS1_avg_upstroke      3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# TS1_halfwidth         3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# FAP_maxupstroke       3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# input_resistance      3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# FAP_avg_upstroke      2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# FAP_num_APs           2.352941e-02  0.067069  0.238310  5  0.161626 -0.114567
# FAP_halfwidth         2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# sag                   2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# VmatSag               1.176471e-02  0.026307  0.186950  5  0.065931 -0.042401
# FAP_rheobase          1.176471e-02  0.026307  0.186950  5  0.065931 -0.042401
# TS2_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# vmbaseM               0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# tau                   0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_peak              0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_up_down_ratio     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_num_APs           0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxupstroke       0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_peak              0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_adp_index         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_adp_index        -2.220446e-17  0.041595  0.500000  5  0.085644 -0.085644
# FAP_up_down_ratio    -3.529412e-02  0.032219  0.964758  5  0.031045 -0.101633
# TS1_num_APs          -4.705882e-02  0.026307  0.991935  5  0.007107 -0.101225

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# NeuralNetFastAI_BAG_L1_FULL
# {'accuracy': 0.7647058823529411,
#  'balanced_accuracy': 0.7000000000000001,
#  'mcc': 0.6274738949672117,
#  'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
#  Exc L2-3 LINC00507 FREM3 deep                              3
#  Exc L3-4 RORB CARM1P1                                      1
#  Exc L3-5 RORB COL22A1                                      0
#
#                                 Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
#  Exc L2-3 LINC00507 FREM3 deep                      1                      1
#  Exc L3-4 RORB CARM1P1                              2                      1
#  Exc L3-5 RORB COL22A1                              0                      8  ,
#  'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.75,
#    'recall': 0.6,
#    'f1-score': 0.6666666666666666,
#    'support': 5.0},
#   'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666,
#    'recall': 0.5,
#    'f1-score': 0.5714285714285714,
#    'support': 4.0},
#   'Exc L3-5 RORB COL22A1': {'precision': 0.8,
#    'recall': 1.0,
#    'f1-score': 0.8888888888888888,
#    'support': 8.0},
#   'accuracy': 0.7647058823529411,
#   'macro avg': {'precision': 0.7388888888888889,
#    'recall': 0.7000000000000001,
#    'f1-score': 0.708994708994709,
#    'support': 17.0},
#   'weighted avg': {'precision': 0.753921568627451,
#    'recall': 0.7647058823529411,
#    'f1-score': 0.7488328664799253,
#    'support': 17.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
#leaderboard.to_csv('leaderboard_medium.csv')
# Out:
#                            model  score_test  score_val eval_metric  \
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN    accuracy
# 1          ExtraTreesGini_BAG_L1    0.823529   0.873563    accuracy
# 2     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN    accuracy
# 3      LightGBMLarge_BAG_L2_FULL    0.823529        NaN    accuracy
# 4           LightGBM_BAG_L2_FULL    0.823529        NaN    accuracy
# 5    NeuralNetFastAI_BAG_L2_FULL    0.823529        NaN    accuracy
# 6     NeuralNetTorch_BAG_L2_FULL    0.823529        NaN    accuracy
# 7     ExtraTreesEntr_BAG_L2_FULL    0.823529        NaN    accuracy
# 8    NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN    accuracy
# 9         LightGBMXT_BAG_L1_FULL    0.764706        NaN    accuracy
# 10      WeightedEnsemble_L3_FULL    0.764706        NaN    accuracy
# 11    NeuralNetTorch_BAG_L1_FULL    0.764706        NaN    accuracy
# 12          LightGBM_BAG_L1_FULL    0.764706        NaN    accuracy
# 13      WeightedEnsemble_L2_FULL    0.764706        NaN    accuracy
# 14         ExtraTreesEntr_BAG_L1    0.764706   0.873563    accuracy
# 15    ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN    accuracy
# 16  RandomForestEntr_BAG_L1_FULL    0.764706        NaN    accuracy
# 17  RandomForestGini_BAG_L1_FULL    0.764706        NaN    accuracy
# 18       RandomForestEntr_BAG_L1    0.764706   0.885057    accuracy
# 19       RandomForestGini_BAG_L1    0.764706   0.885057    accuracy
# 20           XGBoost_BAG_L2_FULL    0.764706        NaN    accuracy
# 21        LightGBMXT_BAG_L2_FULL    0.764706        NaN    accuracy
# 22          CatBoost_BAG_L2_FULL    0.764706        NaN    accuracy
# 23  RandomForestGini_BAG_L2_FULL    0.764706        NaN    accuracy
# 24  RandomForestEntr_BAG_L2_FULL    0.764706        NaN    accuracy
# 25    ExtraTreesGini_BAG_L2_FULL    0.764706        NaN    accuracy
# 26          CatBoost_BAG_L1_FULL    0.705882        NaN    accuracy
# 27           XGBoost_BAG_L1_FULL    0.647059        NaN    accuracy
# 28           WeightedEnsemble_L3         NaN   0.954023    accuracy
# 29        NeuralNetFastAI_BAG_L1         NaN   0.954023    accuracy
# 30           WeightedEnsemble_L2         NaN   0.954023    accuracy
# 31                XGBoost_BAG_L2         NaN   0.954023    accuracy
# 32        NeuralNetFastAI_BAG_L2         NaN   0.954023    accuracy
# 33          LightGBMLarge_BAG_L2         NaN   0.942529    accuracy
# 34               LightGBM_BAG_L2         NaN   0.942529    accuracy
# 35               CatBoost_BAG_L2         NaN   0.942529    accuracy
# 36         NeuralNetTorch_BAG_L1         NaN   0.931034    accuracy
# 37             LightGBMXT_BAG_L2         NaN   0.931034    accuracy
# 38       RandomForestEntr_BAG_L2         NaN   0.919540    accuracy
# 39       RandomForestGini_BAG_L2         NaN   0.919540    accuracy
# 40         ExtraTreesEntr_BAG_L2         NaN   0.919540    accuracy
# 41         NeuralNetTorch_BAG_L2         NaN   0.919540    accuracy
# 42         ExtraTreesGini_BAG_L2         NaN   0.908046    accuracy
# 43             LightGBMXT_BAG_L1         NaN   0.896552    accuracy
# 44                XGBoost_BAG_L1         NaN   0.896552    accuracy
# 45               LightGBM_BAG_L1         NaN   0.896552    accuracy
# 46               CatBoost_BAG_L1         NaN   0.885057    accuracy
# 47          LightGBMLarge_BAG_L1         NaN   0.885057    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.000000            NaN   0.273415                 0.000000
# 1         0.074463       0.154375   0.960792                 0.074463
# 2         0.076657       0.154375   0.960792                 0.076657
# 3         0.298589            NaN  16.186590                 0.000000
# 4         0.308597            NaN  16.210244                 0.010007
# 5         0.308627            NaN  16.334389                 0.010038
# 6         0.324636            NaN  17.339445                 0.026046
# 7         0.361722            NaN  16.832463                 0.063133
# 8         0.000000            NaN   0.439081                 0.000000
# 9         0.000000            NaN   0.263623                 0.000000
# 10        0.007202            NaN   0.835062                 0.007202
# 11        0.010007            NaN  10.845537                 0.010007
# 12        0.015640            NaN   0.176055                 0.015640
# 13        0.015752            NaN   0.633226                 0.015752
# 14        0.048447       0.090368   0.798167                 0.048447
# 15        0.056524       0.090368   0.798167                 0.056524
# 16        0.064012       0.123066   0.961340                 0.064012
# 17        0.075749       0.086764   0.894839                 0.075749
# 18        0.080185       0.123066   0.961340                 0.080185
# 19        0.081235       0.086764   0.894839                 0.081235
# 20        0.298589            NaN  16.018267                 0.000000
# 21        0.298589            NaN  16.183776                 0.000000
# 22        0.301170            NaN  16.046033                 0.002580
# 23        0.373592            NaN  16.907265                 0.075003
# 24        0.418166            NaN  16.724090                 0.119577
# 25        0.430222            NaN  16.837236                 0.131632
# 26        0.000000            NaN   0.329326                 0.000000
# 27        0.000000            NaN   0.030879                 0.000000
# 28             NaN       0.098592  12.746136                      NaN
# 29             NaN       0.098592  12.350156                      NaN
# 30             NaN       0.105193  12.544300                      NaN
# 31             NaN       0.871060  69.264678                      NaN
# 32             NaN       0.948511  77.114282                      NaN
# 33             NaN       0.836567  69.803056                      NaN
# 34             NaN       0.842951  68.735782                      NaN
# 35             NaN       0.870207  82.461098                      NaN
# 36             NaN       0.158993  20.205369                      NaN
# 37             NaN       0.843571  68.466783                      NaN
# 38             NaN       0.930968  65.500555                      NaN
# 39             NaN       0.945119  65.683730                      NaN
# 40             NaN       0.961092  65.608928                      NaN
# 41             NaN       1.061703  87.579686                      NaN
# 42             NaN       0.932472  65.613701                      NaN
# 43             NaN       0.023217   4.738702                      NaN
# 44             NaN       0.030474   4.203879                      NaN
# 45             NaN       0.038447   4.573402                      NaN
# 46             NaN       0.012634  10.336131                      NaN
# 47             NaN       0.018631   4.726743                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           0.273415            1       True
# 1                 0.154375           0.960792            1       True
# 2                 0.154375           0.960792            1       True
# 3                      NaN           0.213534            2       True
# 4                      NaN           0.237188            2       True
# 5                      NaN           0.361334            2       True
# 6                      NaN           1.366389            2       True
# 7                 0.125531           0.859408            2       True
# 8                      NaN           0.439081            1       True
# 9                      NaN           0.263623            1       True
# 10                     NaN           0.395980            3       True
# 11                     NaN          10.845537            1       True
# 12                     NaN           0.176055            1       True
# 13                     NaN           0.194145            2       True
# 14                0.090368           0.798167            1       True
# 15                0.090368           0.798167            1       True
# 16                0.123066           0.961340            1       True
# 17                0.086764           0.894839            1       True
# 18                0.123066           0.961340            1       True
# 19                0.086764           0.894839            1       True
# 20                     NaN           0.045212            2       True
# 21                     NaN           0.210720            2       True
# 22                     NaN           0.072978            2       True
# 23                0.109559           0.934210            2       True
# 24                0.095407           0.751034            2       True
# 25                0.096911           0.864181            2       True
# 26                     NaN           0.329326            1       True
# 27                     NaN           0.030879            1       True
# 28                0.000000           0.395980            3      False
# 29                0.098592          12.350156            1      False
# 30                0.006601           0.194145            2      False
# 31                0.035500           4.515158            2      False
# 32                0.112951          12.364762            2      False
# 33                0.001007           5.053536            2      False
# 34                0.007391           3.986262            2      False
# 35                0.034647          17.711578            2      False
# 36                0.158993          20.205369            1      False
# 37                0.008011           3.717262            2      False
# 38                0.095407           0.751034            2      False
# 39                0.109559           0.934210            2      False
# 40                0.125531           0.859408            2      False
# 41                0.226143          22.830166            2      False
# 42                0.096911           0.864181            2      False
# 43                0.023217           4.738702            1      False
# 44                0.030474           4.203879            1      False
# 45                0.038447           4.573402            1      False
# 46                0.012634          10.336131            1      False
# 47                0.018631           4.726743            1      False
#
#     fit_order
# 0          35
# 1           7
# 2          31
# 3          47
# 4          39
# 5          37
# 6          46
# 7          44
# 8          25
# 9          26
# 10         48
# 11         34
# 12         27
# 13         36
# 14          8
# 15         32
# 16         29
# 17         28
# 18          5
# 19          4
# 20         45
# 21         38
# 22         42
# 23         40
# 24         41
# 25         43
# 26         30
# 27         33
# 28         24
# 29          1
# 30         12
# 31         21
# 32         13
# 33         23
# 34         15
# 35         18
# 36         10
# 37         14
# 38         17
# 39         16
# 40         20
# 41         22
# 42         19
# 43          2
# 44          9
# 45          3
# 46          6
# 47         11

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_84040\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                         0.999912           7.631130e-08
# 1                         0.994909           5.112098e-05
# 2                         0.943839           1.221919e-02
# 3                         0.967286           1.950986e-03
# 4                         0.989655           1.979370e-05
# ..                             ...                    ...
# 204                       0.575833           1.796598e-02
# 205                       0.962750           2.350251e-04
# 206                       0.998642           9.398353e-09
# 207                       0.986761           2.216522e-05
# 208                       0.845030           2.025876e-03
#
#      Exc L3-5 RORB COL22A1
# 0                 0.000088
# 1                 0.005040
# 2                 0.043942
# 3                 0.030763
# 4                 0.010325
# ..                     ...
# 204               0.406201
# 205               0.037015
# 206               0.001358
# 207               0.013217
# 208               0.152944
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]=='Exc L3-4 RORB CARM1P1']])

new_unlabeled_data.shape
# Out:
# (158, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='NeuralNetFastAI_BAG_L1_FULL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.317417
# [100]	valid_set's soft_log_loss: -0.172152
# [150]	valid_set's soft_log_loss: -0.109582
# [200]	valid_set's soft_log_loss: -0.0887806
# [250]	valid_set's soft_log_loss: -0.0761815
# [300]	valid_set's soft_log_loss: -0.0685872
# [350]	valid_set's soft_log_loss: -0.0680186
# [400]	valid_set's soft_log_loss: -0.0670148
# [450]	valid_set's soft_log_loss: -0.0651742
# [500]	valid_set's soft_log_loss: -0.0632391
# [550]	valid_set's soft_log_loss: -0.0618184
# [600]	valid_set's soft_log_loss: -0.0625101
# [650]	valid_set's soft_log_loss: -0.0623678
# [700]	valid_set's soft_log_loss: -0.061822
# [750]	valid_set's soft_log_loss: -0.0624323
# [800]	valid_set's soft_log_loss: -0.0632999
# [850]	valid_set's soft_log_loss: -0.0655144
# [900]	valid_set's soft_log_loss: -0.0653691
# 	Note: model has different eval_metric than default.
# 	-0.0613	 = Validation score   (-soft_log_loss)
# 	3.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.2437	 = Validation score   (-soft_log_loss)
# 	0.87s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0650218	test: -1.0603389	best: -1.0603389 (0)	total: 931ms	remaining: 2h 35m 5s
# 20:	learn: -0.7182127	test: -0.7363172	best: -0.7363172 (20)	total: 1.19s	remaining: 9m 23s
# 40:	learn: -0.5768801	test: -0.5706442	best: -0.5706442 (40)	total: 1.44s	remaining: 5m 49s
# 60:	learn: -0.4979769	test: -0.4589666	best: -0.4589666 (60)	total: 1.71s	remaining: 4m 38s
# 80:	learn: -0.4501738	test: -0.3844755	best: -0.3844755 (80)	total: 1.98s	remaining: 4m 3s
# 100:	learn: -0.4184880	test: -0.3321278	best: -0.3321278 (100)	total: 2.25s	remaining: 3m 40s
# 120:	learn: -0.3955171	test: -0.2942883	best: -0.2942883 (120)	total: 2.49s	remaining: 3m 23s
# 140:	learn: -0.3780868	test: -0.2639217	best: -0.2639217 (140)	total: 2.75s	remaining: 3m 12s
# 160:	learn: -0.3644761	test: -0.2343121	best: -0.2343121 (160)	total: 3.02s	remaining: 3m 4s
# 180:	learn: -0.3536126	test: -0.2167205	best: -0.2167205 (180)	total: 3.29s	remaining: 2m 58s
# 200:	learn: -0.3455849	test: -0.2005147	best: -0.2005147 (200)	total: 3.53s	remaining: 2m 52s
# 220:	learn: -0.3389732	test: -0.1868454	best: -0.1868454 (220)	total: 3.8s	remaining: 2m 48s
# 240:	learn: -0.3337525	test: -0.1753876	best: -0.1753876 (240)	total: 4.05s	remaining: 2m 43s
# 260:	learn: -0.3295873	test: -0.1668054	best: -0.1668054 (260)	total: 4.32s	remaining: 2m 41s
# 280:	learn: -0.3259209	test: -0.1607575	best: -0.1607575 (280)	total: 4.55s	remaining: 2m 37s
# 300:	learn: -0.3229344	test: -0.1546207	best: -0.1546207 (300)	total: 4.83s	remaining: 2m 35s
# 320:	learn: -0.3203690	test: -0.1465701	best: -0.1465701 (320)	total: 5.1s	remaining: 2m 33s
# 340:	learn: -0.3180214	test: -0.1418346	best: -0.1418346 (340)	total: 5.38s	remaining: 2m 32s
# 360:	learn: -0.3159526	test: -0.1370232	best: -0.1370026 (359)	total: 5.65s	remaining: 2m 30s
# 380:	learn: -0.3142803	test: -0.1336565	best: -0.1336565 (380)	total: 5.91s	remaining: 2m 29s
# 400:	learn: -0.3124780	test: -0.1291630	best: -0.1291630 (400)	total: 6.16s	remaining: 2m 27s
# 420:	learn: -0.3112990	test: -0.1251435	best: -0.1251355 (419)	total: 6.42s	remaining: 2m 26s
# 440:	learn: -0.3101931	test: -0.1213220	best: -0.1213220 (440)	total: 6.69s	remaining: 2m 25s
# 460:	learn: -0.3089405	test: -0.1184905	best: -0.1184905 (460)	total: 6.96s	remaining: 2m 24s
# 480:	learn: -0.3081579	test: -0.1167527	best: -0.1167527 (480)	total: 7.23s	remaining: 2m 23s
# 500:	learn: -0.3072867	test: -0.1146436	best: -0.1146436 (500)	total: 7.52s	remaining: 2m 22s
# 520:	learn: -0.3065688	test: -0.1131490	best: -0.1131490 (520)	total: 7.78s	remaining: 2m 21s
# 540:	learn: -0.3057104	test: -0.1112511	best: -0.1112511 (540)	total: 8.04s	remaining: 2m 20s
# 560:	learn: -0.3050252	test: -0.1092491	best: -0.1092190 (558)	total: 8.3s	remaining: 2m 19s
# 580:	learn: -0.3044086	test: -0.1079181	best: -0.1078955 (579)	total: 8.62s	remaining: 2m 19s
# 600:	learn: -0.3038444	test: -0.1059029	best: -0.1059029 (600)	total: 8.88s	remaining: 2m 18s
# 620:	learn: -0.3031758	test: -0.1041546	best: -0.1041546 (620)	total: 9.14s	remaining: 2m 18s
# 640:	learn: -0.3026226	test: -0.1031357	best: -0.1031287 (639)	total: 9.39s	remaining: 2m 17s
# 660:	learn: -0.3021624	test: -0.1019397	best: -0.1019397 (660)	total: 9.64s	remaining: 2m 16s
# 680:	learn: -0.3016521	test: -0.1000606	best: -0.1000606 (680)	total: 9.87s	remaining: 2m 15s
# 700:	learn: -0.3012038	test: -0.0992272	best: -0.0992272 (700)	total: 10.1s	remaining: 2m 14s
# 720:	learn: -0.3008011	test: -0.0974735	best: -0.0974735 (720)	total: 10.4s	remaining: 2m 13s
# 740:	learn: -0.3004405	test: -0.0961182	best: -0.0961182 (740)	total: 10.7s	remaining: 2m 13s
# 760:	learn: -0.3000977	test: -0.0953404	best: -0.0953404 (760)	total: 11s	remaining: 2m 13s
# 780:	learn: -0.2997388	test: -0.0939385	best: -0.0939385 (780)	total: 11.3s	remaining: 2m 13s
# 800:	learn: -0.2993921	test: -0.0934871	best: -0.0934871 (800)	total: 11.5s	remaining: 2m 12s
# 820:	learn: -0.2990920	test: -0.0930619	best: -0.0930619 (820)	total: 11.8s	remaining: 2m 11s
# 840:	learn: -0.2988598	test: -0.0924691	best: -0.0924691 (840)	total: 12.1s	remaining: 2m 11s
# 860:	learn: -0.2986132	test: -0.0915377	best: -0.0915377 (860)	total: 12.3s	remaining: 2m 10s
# 880:	learn: -0.2983567	test: -0.0906464	best: -0.0906464 (880)	total: 12.5s	remaining: 2m 9s
# 4600:	learn: -0.2895903	test: -0.0576263	best: -0.0576234 (4520)	total: 1m 1s	remaining: 1m 12s
# 4620:	learn: -0.2895824	test: -0.0576130	best: -0.0576031 (4612)	total: 1m 2s	remaining: 1m 12s
# 4640:	learn: -0.2895738	test: -0.0575909	best: -0.0575711 (4624)	total: 1m 2s	remaining: 1m 12s
# 4660:	learn: -0.2895642	test: -0.0575551	best: -0.0575551 (4660)	total: 1m 2s	remaining: 1m 11s
# 4680:	learn: -0.2895544	test: -0.0575253	best: -0.0574900 (4672)	total: 1m 3s	remaining: 1m 11s
# 4700:	learn: -0.2895459	test: -0.0574571	best: -0.0574313 (4697)	total: 1m 3s	remaining: 1m 11s
# 4720:	learn: -0.2895371	test: -0.0574086	best: -0.0574086 (4720)	total: 1m 3s	remaining: 1m 11s
# 4740:	learn: -0.2895291	test: -0.0573281	best: -0.0573242 (4728)	total: 1m 3s	remaining: 1m 10s
# 4760:	learn: -0.2895211	test: -0.0573624	best: -0.0573242 (4728)	total: 1m 4s	remaining: 1m 10s
# 4780:	learn: -0.2895137	test: -0.0573558	best: -0.0573242 (4728)	total: 1m 4s	remaining: 1m 10s
# 4800:	learn: -0.2895048	test: -0.0573242	best: -0.0573114 (4798)	total: 1m 4s	remaining: 1m 9s
# 4820:	learn: -0.2894960	test: -0.0572492	best: -0.0572372 (4811)	total: 1m 4s	remaining: 1m 9s
# 4840:	learn: -0.2894872	test: -0.0572992	best: -0.0572222 (4822)	total: 1m 5s	remaining: 1m 9s
# 4860:	learn: -0.2894801	test: -0.0572252	best: -0.0572187 (4859)	total: 1m 5s	remaining: 1m 9s
# 4880:	learn: -0.2894724	test: -0.0571977	best: -0.0571909 (4879)	total: 1m 5s	remaining: 1m 8s
# 4900:	learn: -0.2894652	test: -0.0571511	best: -0.0571330 (4898)	total: 1m 5s	remaining: 1m 8s
# 4920:	learn: -0.2894576	test: -0.0571423	best: -0.0571315 (4908)	total: 1m 6s	remaining: 1m 8s
# 4940:	learn: -0.2894506	test: -0.0570069	best: -0.0570069 (4940)	total: 1m 6s	remaining: 1m 8s
# 4960:	learn: -0.2894426	test: -0.0570279	best: -0.0570025 (4941)	total: 1m 6s	remaining: 1m 7s
# 4980:	learn: -0.2894358	test: -0.0570987	best: -0.0570025 (4941)	total: 1m 7s	remaining: 1m 7s
# 5000:	learn: -0.2894289	test: -0.0571427	best: -0.0570025 (4941)	total: 1m 7s	remaining: 1m 7s
# 5020:	learn: -0.2894213	test: -0.0570956	best: -0.0570025 (4941)	total: 1m 7s	remaining: 1m 6s
# 5040:	learn: -0.2894150	test: -0.0570084	best: -0.0569911 (5039)	total: 1m 7s	remaining: 1m 6s
# 5060:	learn: -0.2894075	test: -0.0569757	best: -0.0569540 (5059)	total: 1m 8s	remaining: 1m 6s
# 5080:	learn: -0.2894021	test: -0.0569138	best: -0.0569106 (5079)	total: 1m 8s	remaining: 1m 6s
# 5100:	learn: -0.2893951	test: -0.0568901	best: -0.0568852 (5098)	total: 1m 8s	remaining: 1m 5s
# 5120:	learn: -0.2893885	test: -0.0568531	best: -0.0568517 (5112)	total: 1m 8s	remaining: 1m 5s
# 5140:	learn: -0.2893814	test: -0.0568424	best: -0.0568374 (5139)	total: 1m 9s	remaining: 1m 5s
# 5160:	learn: -0.2893745	test: -0.0567844	best: -0.0567844 (5160)	total: 1m 9s	remaining: 1m 5s
# 5180:	learn: -0.2893671	test: -0.0567779	best: -0.0567779 (5180)	total: 1m 9s	remaining: 1m 4s
# 5200:	learn: -0.2893591	test: -0.0567961	best: -0.0567533 (5188)	total: 1m 9s	remaining: 1m 4s
# 5220:	learn: -0.2893518	test: -0.0568175	best: -0.0567533 (5188)	total: 1m 10s	remaining: 1m 4s
# 5240:	learn: -0.2893450	test: -0.0567592	best: -0.0567528 (5237)	total: 1m 10s	remaining: 1m 4s
# 5260:	learn: -0.2893376	test: -0.0567947	best: -0.0567528 (5237)	total: 1m 10s	remaining: 1m 3s
# 5280:	learn: -0.2893296	test: -0.0568176	best: -0.0567528 (5237)	total: 1m 11s	remaining: 1m 3s
# 5300:	learn: -0.2893234	test: -0.0568041	best: -0.0567528 (5237)	total: 1m 11s	remaining: 1m 3s
# 5320:	learn: -0.2893174	test: -0.0568066	best: -0.0567528 (5237)	total: 1m 11s	remaining: 1m 2s
# 5340:	learn: -0.2893102	test: -0.0568215	best: -0.0567528 (5237)	total: 1m 11s	remaining: 1m 2s
# 5360:	learn: -0.2893033	test: -0.0567237	best: -0.0567237 (5360)	total: 1m 12s	remaining: 1m 2s
# 5380:	learn: -0.2892976	test: -0.0567462	best: -0.0567076 (5371)	total: 1m 12s	remaining: 1m 2s
# 5400:	learn: -0.2892906	test: -0.0567283	best: -0.0567068 (5395)	total: 1m 12s	remaining: 1m 1s
# 5420:	learn: -0.2892841	test: -0.0567392	best: -0.0567068 (5395)	total: 1m 12s	remaining: 1m 1s
# 5440:	learn: -0.2892785	test: -0.0566805	best: -0.0566578 (5435)	total: 1m 13s	remaining: 1m 1s
# 5460:	learn: -0.2892710	test: -0.0566856	best: -0.0566578 (5435)	total: 1m 13s	remaining: 1m 1s
# 5480:	learn: -0.2892642	test: -0.0566439	best: -0.0566351 (5479)	total: 1m 13s	remaining: 1m
# 5500:	learn: -0.2892583	test: -0.0566422	best: -0.0566279 (5498)	total: 1m 14s	remaining: 1m
# 5520:	learn: -0.2892524	test: -0.0565970	best: -0.0565970 (5520)	total: 1m 14s	remaining: 1m
# 5540:	learn: -0.2892464	test: -0.0565537	best: -0.0565430 (5537)	total: 1m 14s	remaining: 60s
# 5560:	learn: -0.2892412	test: -0.0565472	best: -0.0565296 (5552)	total: 1m 14s	remaining: 59.7s
# 5580:	learn: -0.2892350	test: -0.0565034	best: -0.0564972 (5578)	total: 1m 15s	remaining: 59.5s
# 5600:	learn: -0.2892300	test: -0.0564472	best: -0.0564472 (5600)	total: 1m 15s	remaining: 59.2s
# 5620:	learn: -0.2892241	test: -0.0564049	best: -0.0563877 (5612)	total: 1m 15s	remaining: 58.9s
# 9860:	learn: -0.2885431	test: -0.0534957	best: -0.0534671 (9851)	total: 2m 12s	remaining: 1.87s
# 9880:	learn: -0.2885412	test: -0.0534865	best: -0.0534671 (9851)	total: 2m 13s	remaining: 1.6s
# 9900:	learn: -0.2885395	test: -0.0534948	best: -0.0534671 (9851)	total: 2m 13s	remaining: 1.33s
# 9920:	learn: -0.2885379	test: -0.0534878	best: -0.0534671 (9851)	total: 2m 13s	remaining: 1.06s
# 9940:	learn: -0.2885361	test: -0.0534975	best: -0.0534671 (9851)	total: 2m 14s	remaining: 796ms
# 9960:	learn: -0.2885344	test: -0.0534886	best: -0.0534671 (9851)	total: 2m 14s	remaining: 526ms
# 9980:	learn: -0.2885327	test: -0.0535176	best: -0.0534671 (9851)	total: 2m 14s	remaining: 256ms
# 9999:	learn: -0.2885312	test: -0.0534948	best: -0.0534671 (9851)	total: 2m 14s	remaining: 0us
#
# bestTest = -0.05346706845
# bestIteration = 9851
#
# Shrink model to first 9852 iterations.
# 	Note: model has different eval_metric than default.
# 	-0.0535	 = Validation score   (-soft_log_loss)
# 	250.59s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.006	 = Validation score   (-soft_log_loss)
# 	11.46s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.006	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL   1.000000  soft_log_loss       0.000000    3.261302                0.000000           3.261302            1       True         49
# 1             CatBoost_DSTL   1.000000  soft_log_loss       0.000000  250.594729                0.000000         250.594729            1       True         51
# 2  WeightedEnsemble_L2_DSTL   1.000000  soft_log_loss       0.016547   11.491515                0.000000           0.036310            2       True         53
# 3       NeuralNetTorch_DSTL   1.000000  soft_log_loss       0.016547   11.455205                0.016547          11.455205            1       True         52
# 4      RandomForestMSE_DSTL   0.944444  soft_log_loss       0.056472    0.871956                0.056472           0.871956            1       True         50
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 1                  LightGBM_DSTL    0.823529   1.000000  soft_log_loss
# 2                  CatBoost_DSTL    0.823529   1.000000  soft_log_loss
# 17      WeightedEnsemble_L2_DSTL    0.764706   1.000000  soft_log_loss
# 18           NeuralNetTorch_DSTL    0.764706   1.000000  soft_log_loss
# 33           WeightedEnsemble_L3         NaN   0.954023       accuracy
# 34        NeuralNetFastAI_BAG_L1         NaN   0.954023       accuracy
# 35           WeightedEnsemble_L2         NaN   0.954023       accuracy
# 36                XGBoost_BAG_L2         NaN   0.954023       accuracy
# 37        NeuralNetFastAI_BAG_L2         NaN   0.954023       accuracy
# 5           RandomForestMSE_DSTL    0.823529   0.944444  soft_log_loss
# 38          LightGBMLarge_BAG_L2         NaN   0.942529       accuracy
# 39               LightGBM_BAG_L2         NaN   0.942529       accuracy
# 40               CatBoost_BAG_L2         NaN   0.942529       accuracy
# 41         NeuralNetTorch_BAG_L1         NaN   0.931034       accuracy
# 42             LightGBMXT_BAG_L2         NaN   0.931034       accuracy
# 43       RandomForestEntr_BAG_L2         NaN   0.919540       accuracy
# 44       RandomForestGini_BAG_L2         NaN   0.919540       accuracy
# 45         ExtraTreesEntr_BAG_L2         NaN   0.919540       accuracy
# 46         NeuralNetTorch_BAG_L2         NaN   0.919540       accuracy
# 47         ExtraTreesGini_BAG_L2         NaN   0.908046       accuracy
# 48             LightGBMXT_BAG_L1         NaN   0.896552       accuracy
# 49                XGBoost_BAG_L1         NaN   0.896552       accuracy
# 50               LightGBM_BAG_L1         NaN   0.896552       accuracy
# 21       RandomForestEntr_BAG_L1    0.764706   0.885057       accuracy
# 22       RandomForestGini_BAG_L1    0.764706   0.885057       accuracy
# 51               CatBoost_BAG_L1         NaN   0.885057       accuracy
# 52          LightGBMLarge_BAG_L1         NaN   0.885057       accuracy
# 4          ExtraTreesGini_BAG_L1    0.823529   0.873563       accuracy
# 23         ExtraTreesEntr_BAG_L1    0.764706   0.873563       accuracy
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN       accuracy
# 3     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN       accuracy
# 6           LightGBM_BAG_L2_FULL    0.823529        NaN       accuracy
# 7      LightGBMLarge_BAG_L2_FULL    0.823529        NaN       accuracy
# 8    NeuralNetFastAI_BAG_L2_FULL    0.823529        NaN       accuracy
# 9     NeuralNetTorch_BAG_L2_FULL    0.823529        NaN       accuracy
# 10    ExtraTreesEntr_BAG_L2_FULL    0.823529        NaN       accuracy
# 11      WeightedEnsemble_L3_FULL    0.764706        NaN       accuracy
# 12   NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN       accuracy
# 13          LightGBM_BAG_L1_FULL    0.764706        NaN       accuracy
# 14      WeightedEnsemble_L2_FULL    0.764706        NaN       accuracy
# 15        LightGBMXT_BAG_L1_FULL    0.764706        NaN       accuracy
# 16    NeuralNetTorch_BAG_L1_FULL    0.764706        NaN       accuracy
# 19    ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 20  RandomForestEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 24  RandomForestGini_BAG_L1_FULL    0.764706        NaN       accuracy
# 25           XGBoost_BAG_L2_FULL    0.764706        NaN       accuracy
# 26        LightGBMXT_BAG_L2_FULL    0.764706        NaN       accuracy
# 27          CatBoost_BAG_L2_FULL    0.764706        NaN       accuracy
# 28  RandomForestEntr_BAG_L2_FULL    0.764706        NaN       accuracy
# 29  RandomForestGini_BAG_L2_FULL    0.764706        NaN       accuracy
# 30    ExtraTreesGini_BAG_L2_FULL    0.764706        NaN       accuracy
# 31          CatBoost_BAG_L1_FULL    0.705882        NaN       accuracy
# 32           XGBoost_BAG_L1_FULL    0.647059        NaN       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 1         0.029960       0.000000    3.261302                 0.029960
# 2         0.053378       0.000000  250.594729                 0.053378
# 17        0.026250       0.016547   11.491515                 0.000000
# 18        0.026250       0.016547   11.455205                 0.026250
# 33             NaN       0.098592   12.746136                      NaN
# 34             NaN       0.098592   12.350156                      NaN
# 35             NaN       0.105193   12.544300                      NaN
# 36             NaN       0.871060   69.264678                      NaN
# 37             NaN       0.948511   77.114282                      NaN
# 5         0.100263       0.056472    0.871956                 0.100263
# 38             NaN       0.836567   69.803056                      NaN
# 39             NaN       0.842951   68.735782                      NaN
# 40             NaN       0.870207   82.461098                      NaN
# 41             NaN       0.158993   20.205369                      NaN
# 42             NaN       0.843571   68.466783                      NaN
# 43             NaN       0.930968   65.500555                      NaN
# 44             NaN       0.945119   65.683730                      NaN
# 45             NaN       0.961092   65.608928                      NaN
# 46             NaN       1.061703   87.579686                      NaN
# 47             NaN       0.932472   65.613701                      NaN
# 48             NaN       0.023217    4.738702                      NaN
# 49             NaN       0.030474    4.203879                      NaN
# 50             NaN       0.038447    4.573402                      NaN
# 21        0.093861       0.123066    0.961340                 0.093861
# 22        0.105805       0.086764    0.894839                 0.105805
# 51             NaN       0.012634   10.336131                      NaN
# 52             NaN       0.018631    4.726743                      NaN
# 4         0.077429       0.154375    0.960792                 0.077429
# 23        0.125677       0.090368    0.798167                 0.125677
# 0         0.000000            NaN    0.273415                 0.000000
# 3         0.058107       0.154375    0.960792                 0.058107
# 6         0.375672            NaN   16.210244                 0.000000
# 7         0.383699            NaN   16.186590                 0.008027
# 8         0.391355            NaN   16.334389                 0.015683
# 9         0.395915            NaN   17.339445                 0.020243
# 10        0.431251            NaN   16.832463                 0.055579
# 11        0.000000            NaN    0.835062                 0.000000
# 12        0.000000            NaN    0.439081                 0.000000
# 13        0.002036            NaN    0.176055                 0.002036
# 14        0.010007            NaN    0.633226                 0.010007
# 15        0.015637            NaN    0.263623                 0.015637
# 16        0.020379            NaN   10.845537                 0.020379
# 19        0.051352       0.090368    0.798167                 0.051352
# 20        0.067611       0.123066    0.961340                 0.067611
# 24        0.160549       0.086764    0.894839                 0.160549
# 25        0.375672            NaN   16.018267                 0.000000
# 26        0.375672            NaN   16.183776                 0.000000
# 27        0.375672            NaN   16.046033                 0.000000
# 28        0.457217            NaN   16.724090                 0.081546
# 29        0.473998            NaN   16.907265                 0.098327
# 30        0.532382            NaN   16.837236                 0.156711
# 31        0.000000            NaN    0.329326                 0.000000
# 32        0.000000            NaN    0.030879                 0.000000
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                 0.000000           3.261302            1       True
# 2                 0.000000         250.594729            1       True
# 17                0.000000           0.036310            2       True
# 18                0.016547          11.455205            1       True
# 33                0.000000           0.395980            3      False
# 34                0.098592          12.350156            1      False
# 35                0.006601           0.194145            2      False
# 36                0.035500           4.515158            2      False
# 37                0.112951          12.364762            2      False
# 5                 0.056472           0.871956            1       True
# 38                0.001007           5.053536            2      False
# 39                0.007391           3.986262            2      False
# 40                0.034647          17.711578            2      False
# 41                0.158993          20.205369            1      False
# 42                0.008011           3.717262            2      False
# 43                0.095407           0.751034            2      False
# 44                0.109559           0.934210            2      False
# 45                0.125531           0.859408            2      False
# 46                0.226143          22.830166            2      False
# 47                0.096911           0.864181            2      False
# 48                0.023217           4.738702            1      False
# 49                0.030474           4.203879            1      False
# 50                0.038447           4.573402            1      False
# 21                0.123066           0.961340            1       True
# 22                0.086764           0.894839            1       True
# 51                0.012634          10.336131            1      False
# 52                0.018631           4.726743            1      False
# 4                 0.154375           0.960792            1       True
# 23                0.090368           0.798167            1       True
# 0                      NaN           0.273415            1       True
# 3                 0.154375           0.960792            1       True
# 6                      NaN           0.237188            2       True
# 7                      NaN           0.213534            2       True
# 8                      NaN           0.361334            2       True
# 9                      NaN           1.366389            2       True
# 10                0.125531           0.859408            2       True
# 11                     NaN           0.395980            3       True
# 12                     NaN           0.439081            1       True
# 13                     NaN           0.176055            1       True
# 14                     NaN           0.194145            2       True
# 15                     NaN           0.263623            1       True
# 16                     NaN          10.845537            1       True
# 19                0.090368           0.798167            1       True
# 20                0.123066           0.961340            1       True
# 24                0.086764           0.894839            1       True
# 25                     NaN           0.045212            2       True
# 26                     NaN           0.210720            2       True
# 27                     NaN           0.072978            2       True
# 28                0.095407           0.751034            2       True
# 29                0.109559           0.934210            2       True
# 30                0.096911           0.864181            2       True
# 31                     NaN           0.329326            1       True
# 32                     NaN           0.030879            1       True
#
#     fit_order
# 1          49
# 2          51
# 17         53
# 18         52
# 33         24
# 34          1
# 35         12
# 36         21
# 37         13
# 5          50
# 38         23
# 39         15
# 40         18
# 41         10
# 42         14
# 43         17
# 44         16
# 45         20
# 46         22
# 47         19
# 48          2
# 49          9
# 50          3
# 21          5
# 22          4
# 51          6
# 52         11
# 4           7
# 23          8
# 0          35
# 3          31
# 6          39
# 7          47
# 8          37
# 9          46
# 10         44
# 11         48
# 12         25
# 13         27
# 14         36
# 15         26
# 16         34
# 19         32
# 20         29
# 24         28
# 25         45
# 26         38
# 27         42
# 28         41
# 29         40
# 30         43
# 31         30
# 32         33
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.8235294117647058
# Evaluations on test data:
# {
#     "accuracy": 0.8235294117647058,
#     "balanced_accuracy": 0.7833333333333333,
#     "mcc": 0.7224006147708789
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.75,
#         "recall": 0.6,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.75,
#         "recall": 0.75,
#         "f1-score": 0.75,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.8235294117647058,
#     "macro avg": {
#         "precision": 0.7962962962962963,
#         "recall": 0.7833333333333333,
#         "f1-score": 0.7859477124183005,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.815359477124183,
#         "recall": 0.8235294117647058,
#         "f1-score": 0.8154555940023068,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.8235294117647058, 'balanced_accuracy': 0.7833333333333333, 'mcc': 0.7224006147708789, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      1
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              3                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.75, 'recall': 0.6, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.8235294117647058, 'macro avg': {'precision': 0.7962962962962963, 'recall': 0.7833333333333333, 'f1-score': 0.7859477124183005, 'support': 17.0}, 'weighted avg': {'precision': 0.815359477124183, 'recall': 0.8235294117647058, 'f1-score': 0.8154555940023068, 'support': 17.0}}}

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7647058823529411
# Evaluations on test data:
# {
#     "accuracy": 0.7647058823529411,
#     "balanced_accuracy": 0.7000000000000001,
#     "mcc": 0.6380450213545767
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 1.0,
#         "recall": 0.6,
#         "f1-score": 0.75,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5,
#         "f1-score": 0.5714285714285714,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.7272727272727273,
#         "recall": 1.0,
#         "f1-score": 0.8421052631578947,
#         "support": 8.0
#     },
#     "accuracy": 0.7647058823529411,
#     "macro avg": {
#         "precision": 0.7979797979797979,
#         "recall": 0.7000000000000001,
#         "f1-score": 0.7211779448621553,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.7932263814616756,
#         "recall": 0.7647058823529411,
#         "f1-score": 0.7513268465280848,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.7647058823529411, 'balanced_accuracy': 0.7000000000000001, 'mcc': 0.6380450213545767, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      0
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              2                      2
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 1.0, 'recall': 0.6, 'f1-score': 0.75, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666, 'recall': 0.5, 'f1-score': 0.5714285714285714, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.7272727272727273, 'recall': 1.0, 'f1-score': 0.8421052631578947, 'support': 8.0}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.7979797979797979, 'recall': 0.7000000000000001, 'f1-score': 0.7211779448621553, 'support': 17.0}, 'weighted avg': {'precision': 0.7932263814616756, 'recall': 0.7647058823529411, 'f1-score': 0.7513268465280848, 'support': 17.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.75      0.60      0.67         5
#         Exc L3-4 RORB CARM1P1       0.75      0.75      0.75         4
#         Exc L3-5 RORB COL22A1       0.89      1.00      0.94         8
#
#                      accuracy                           0.82        17
#                     macro avg       0.80      0.78      0.79        17
#                  weighted avg       0.82      0.82      0.82        17

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.32774
# [100]	valid_set's soft_log_loss: -0.211488
# [150]	valid_set's soft_log_loss: -0.168852
# [200]	valid_set's soft_log_loss: -0.150844
# [250]	valid_set's soft_log_loss: -0.141267
# [300]	valid_set's soft_log_loss: -0.141085
# [350]	valid_set's soft_log_loss: -0.145928
# [400]	valid_set's soft_log_loss: -0.149992
# [450]	valid_set's soft_log_loss: -0.142965
# [500]	valid_set's soft_log_loss: -0.144872
# [550]	valid_set's soft_log_loss: -0.148289
# 	Note: model has different eval_metric than default.
# 	-0.1397	 = Validation score   (-soft_log_loss)
# 	2.02s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.2565	 = Validation score   (-soft_log_loss)
# 	0.81s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0657121	test: -1.0754330	best: -1.0754330 (0)	total: 695ms	remaining: 1h 55m 49s
# 20:	learn: -0.6671849	test: -0.7413500	best: -0.7413500 (20)	total: 913ms	remaining: 7m 13s
# 40:	learn: -0.4938681	test: -0.5315641	best: -0.5315641 (40)	total: 1.18s	remaining: 4m 46s
# 60:	learn: -0.4117771	test: -0.4414918	best: -0.4414918 (60)	total: 1.4s	remaining: 3m 47s
# 80:	learn: -0.3613793	test: -0.3743650	best: -0.3743650 (80)	total: 1.63s	remaining: 3m 19s
# 100:	learn: -0.3281700	test: -0.3206622	best: -0.3206622 (100)	total: 1.84s	remaining: 3m
# 120:	learn: -0.3026797	test: -0.2815125	best: -0.2815125 (120)	total: 2.05s	remaining: 2m 47s
# 140:	learn: -0.2837590	test: -0.2520674	best: -0.2520674 (140)	total: 2.27s	remaining: 2m 38s
# 160:	learn: -0.2689184	test: -0.2271937	best: -0.2271937 (160)	total: 2.5s	remaining: 2m 33s
# 180:	learn: -0.2579782	test: -0.2078641	best: -0.2078641 (180)	total: 2.73s	remaining: 2m 27s
# 200:	learn: -0.2489300	test: -0.1909244	best: -0.1909244 (200)	total: 2.98s	remaining: 2m 25s
# 220:	learn: -0.2417068	test: -0.1790156	best: -0.1790156 (220)	total: 3.21s	remaining: 2m 21s
# 240:	learn: -0.2371454	test: -0.1706140	best: -0.1706140 (240)	total: 3.44s	remaining: 2m 19s
# 260:	learn: -0.2323520	test: -0.1614706	best: -0.1614706 (260)	total: 3.65s	remaining: 2m 16s
# 280:	learn: -0.2290688	test: -0.1552347	best: -0.1552347 (280)	total: 3.88s	remaining: 2m 14s
# 300:	learn: -0.2254857	test: -0.1482036	best: -0.1482036 (300)	total: 4.11s	remaining: 2m 12s
# 320:	learn: -0.2228367	test: -0.1434759	best: -0.1434759 (320)	total: 4.33s	remaining: 2m 10s
# 340:	learn: -0.2206349	test: -0.1396476	best: -0.1396476 (340)	total: 4.59s	remaining: 2m 9s
# 360:	learn: -0.2180519	test: -0.1363994	best: -0.1363994 (360)	total: 4.83s	remaining: 2m 8s
# 380:	learn: -0.2159336	test: -0.1329873	best: -0.1329873 (380)	total: 5.1s	remaining: 2m 8s
# 400:	learn: -0.2140491	test: -0.1293703	best: -0.1293703 (400)	total: 5.31s	remaining: 2m 7s
# 420:	learn: -0.2125587	test: -0.1257352	best: -0.1257352 (420)	total: 5.56s	remaining: 2m 6s
# 440:	learn: -0.2111792	test: -0.1230514	best: -0.1230514 (440)	total: 5.79s	remaining: 2m 5s
# 460:	learn: -0.2096913	test: -0.1200038	best: -0.1200038 (460)	total: 6.02s	remaining: 2m 4s
# 480:	learn: -0.2086089	test: -0.1180128	best: -0.1180128 (480)	total: 6.25s	remaining: 2m 3s
# 500:	learn: -0.2074024	test: -0.1157960	best: -0.1157937 (496)	total: 6.52s	remaining: 2m 3s
# 520:	learn: -0.2065883	test: -0.1138999	best: -0.1138999 (520)	total: 6.75s	remaining: 2m 2s
# 540:	learn: -0.2058022	test: -0.1127069	best: -0.1127069 (540)	total: 6.95s	remaining: 2m 1s
# 560:	learn: -0.2050865	test: -0.1106881	best: -0.1106844 (558)	total: 7.18s	remaining: 2m
# 580:	learn: -0.2044261	test: -0.1093996	best: -0.1093715 (579)	total: 7.4s	remaining: 1m 59s
# 600:	learn: -0.2036496	test: -0.1073903	best: -0.1072699 (597)	total: 7.62s	remaining: 1m 59s
# 620:	learn: -0.2030623	test: -0.1046857	best: -0.1046857 (620)	total: 7.87s	remaining: 1m 58s
# 640:	learn: -0.2025174	test: -0.1042046	best: -0.1042040 (632)	total: 8.13s	remaining: 1m 58s
# 660:	learn: -0.2019238	test: -0.1017301	best: -0.1017301 (660)	total: 8.36s	remaining: 1m 58s
# 680:	learn: -0.2014350	test: -0.1004782	best: -0.1004782 (680)	total: 8.61s	remaining: 1m 57s
# 700:	learn: -0.2009921	test: -0.0997139	best: -0.0996685 (699)	total: 8.82s	remaining: 1m 56s
# 720:	learn: -0.2005840	test: -0.0990098	best: -0.0990098 (720)	total: 9.03s	remaining: 1m 56s
# 740:	learn: -0.2001610	test: -0.0977402	best: -0.0977402 (740)	total: 9.24s	remaining: 1m 55s
# 760:	learn: -0.1997512	test: -0.0972305	best: -0.0972305 (760)	total: 9.47s	remaining: 1m 54s
# 780:	learn: -0.1993426	test: -0.0963706	best: -0.0963706 (780)	total: 9.7s	remaining: 1m 54s
# 800:	learn: -0.1990094	test: -0.0953964	best: -0.0953820 (799)	total: 9.91s	remaining: 1m 53s
# 820:	learn: -0.1987610	test: -0.0945792	best: -0.0945792 (820)	total: 10.2s	remaining: 1m 53s
# 840:	learn: -0.1984661	test: -0.0939954	best: -0.0939468 (834)	total: 10.4s	remaining: 1m 53s
# 860:	learn: -0.1981866	test: -0.0928579	best: -0.0928579 (860)	total: 10.7s	remaining: 1m 53s
# 880:	learn: -0.1979038	test: -0.0919570	best: -0.0919507 (876)	total: 10.9s	remaining: 1m 52s
# 900:	learn: -0.1976307	test: -0.0908527	best: -0.0908527 (900)	total: 11.1s	remaining: 1m 52s
# 920:	learn: -0.1973654	test: -0.0904096	best: -0.0903731 (919)	total: 11.4s	remaining: 1m 51s
# 940:	learn: -0.1971282	test: -0.0895597	best: -0.0895597 (940)	total: 11.6s	remaining: 1m 51s
# 5200:	learn: -0.1893200	test: -0.0583904	best: -0.0583591 (5162)	total: 1m 1s	remaining: 57s
# 5220:	learn: -0.1893137	test: -0.0583681	best: -0.0583591 (5162)	total: 1m 2s	remaining: 56.8s
# 5240:	learn: -0.1893090	test: -0.0582678	best: -0.0582653 (5234)	total: 1m 2s	remaining: 56.5s
# 5260:	learn: -0.1893032	test: -0.0582267	best: -0.0582267 (5260)	total: 1m 2s	remaining: 56.3s
# 5280:	learn: -0.1892982	test: -0.0581940	best: -0.0581885 (5279)	total: 1m 2s	remaining: 56s
# 5300:	learn: -0.1892921	test: -0.0582236	best: -0.0581882 (5292)	total: 1m 2s	remaining: 55.8s
# 5320:	learn: -0.1892859	test: -0.0581935	best: -0.0581836 (5314)	total: 1m 3s	remaining: 55.5s
# 5340:	learn: -0.1892804	test: -0.0581276	best: -0.0581264 (5338)	total: 1m 3s	remaining: 55.3s
# 5360:	learn: -0.1892751	test: -0.0580593	best: -0.0580593 (5360)	total: 1m 3s	remaining: 55s
# 5380:	learn: -0.1892692	test: -0.0581390	best: -0.0580593 (5360)	total: 1m 3s	remaining: 54.7s
# 5400:	learn: -0.1892636	test: -0.0580851	best: -0.0580593 (5360)	total: 1m 4s	remaining: 54.5s
# 5420:	learn: -0.1892580	test: -0.0580826	best: -0.0580593 (5360)	total: 1m 4s	remaining: 54.3s
# 5440:	learn: -0.1892527	test: -0.0580195	best: -0.0580195 (5440)	total: 1m 4s	remaining: 54s
# 5460:	learn: -0.1892472	test: -0.0579937	best: -0.0579937 (5460)	total: 1m 4s	remaining: 53.8s
# 5480:	learn: -0.1892416	test: -0.0578762	best: -0.0578762 (5480)	total: 1m 4s	remaining: 53.6s
# 5500:	learn: -0.1892368	test: -0.0578282	best: -0.0578170 (5492)	total: 1m 5s	remaining: 53.3s
# 5520:	learn: -0.1892323	test: -0.0577932	best: -0.0577876 (5519)	total: 1m 5s	remaining: 53.1s
# 5540:	learn: -0.1892278	test: -0.0578252	best: -0.0577876 (5519)	total: 1m 5s	remaining: 52.8s
# 5560:	learn: -0.1892228	test: -0.0578079	best: -0.0577876 (5519)	total: 1m 5s	remaining: 52.6s
# 5580:	learn: -0.1892171	test: -0.0577679	best: -0.0577679 (5580)	total: 1m 6s	remaining: 52.4s
# 5600:	learn: -0.1892128	test: -0.0576962	best: -0.0576962 (5600)	total: 1m 6s	remaining: 52.1s
# 5620:	learn: -0.1892077	test: -0.0575982	best: -0.0575896 (5619)	total: 1m 6s	remaining: 51.9s
# 5640:	learn: -0.1892033	test: -0.0575532	best: -0.0575518 (5638)	total: 1m 6s	remaining: 51.6s
# 5660:	learn: -0.1891985	test: -0.0575178	best: -0.0575040 (5647)	total: 1m 7s	remaining: 51.4s
# 5680:	learn: -0.1891937	test: -0.0574632	best: -0.0574616 (5679)	total: 1m 7s	remaining: 51.1s
# 5700:	learn: -0.1891886	test: -0.0574141	best: -0.0574004 (5691)	total: 1m 7s	remaining: 50.9s
# 5720:	learn: -0.1891839	test: -0.0573879	best: -0.0573826 (5715)	total: 1m 7s	remaining: 50.6s
# 5740:	learn: -0.1891793	test: -0.0573948	best: -0.0573744 (5728)	total: 1m 7s	remaining: 50.4s
# 5760:	learn: -0.1891744	test: -0.0573675	best: -0.0573675 (5760)	total: 1m 8s	remaining: 50.2s
# 5780:	learn: -0.1891697	test: -0.0573684	best: -0.0573671 (5766)	total: 1m 8s	remaining: 49.9s
# 5800:	learn: -0.1891649	test: -0.0573185	best: -0.0573185 (5800)	total: 1m 8s	remaining: 49.7s
# 5820:	learn: -0.1891610	test: -0.0572514	best: -0.0572360 (5818)	total: 1m 8s	remaining: 49.4s
# 5840:	learn: -0.1891565	test: -0.0571676	best: -0.0571566 (5839)	total: 1m 9s	remaining: 49.2s
# 5860:	learn: -0.1891518	test: -0.0571972	best: -0.0571566 (5839)	total: 1m 9s	remaining: 49s
# 5880:	learn: -0.1891478	test: -0.0572033	best: -0.0571566 (5839)	total: 1m 9s	remaining: 48.7s
# 5900:	learn: -0.1891435	test: -0.0571555	best: -0.0571555 (5900)	total: 1m 9s	remaining: 48.5s
# 5920:	learn: -0.1891390	test: -0.0570919	best: -0.0570919 (5920)	total: 1m 9s	remaining: 48.2s
# 5940:	learn: -0.1891345	test: -0.0570710	best: -0.0570697 (5936)	total: 1m 10s	remaining: 48s
# 5960:	learn: -0.1891305	test: -0.0570970	best: -0.0570586 (5950)	total: 1m 10s	remaining: 47.7s
# 5980:	learn: -0.1891257	test: -0.0570886	best: -0.0570586 (5950)	total: 1m 10s	remaining: 47.5s
# 6000:	learn: -0.1891221	test: -0.0570884	best: -0.0570586 (5950)	total: 1m 10s	remaining: 47.3s
# 6020:	learn: -0.1891178	test: -0.0570538	best: -0.0570501 (6018)	total: 1m 11s	remaining: 47s
# 6040:	learn: -0.1891136	test: -0.0570685	best: -0.0570200 (6036)	total: 1m 11s	remaining: 46.8s
# 6060:	learn: -0.1891093	test: -0.0570583	best: -0.0570200 (6036)	total: 1m 11s	remaining: 46.6s
# 6080:	learn: -0.1891046	test: -0.0570272	best: -0.0570200 (6036)	total: 1m 11s	remaining: 46.3s
# 6100:	learn: -0.1891002	test: -0.0570220	best: -0.0569783 (6090)	total: 1m 12s	remaining: 46.1s
# 6120:	learn: -0.1890956	test: -0.0569939	best: -0.0569783 (6090)	total: 1m 12s	remaining: 45.8s
# 6140:	learn: -0.1890916	test: -0.0569211	best: -0.0568967 (6132)	total: 1m 12s	remaining: 45.6s
# 6160:	learn: -0.1890868	test: -0.0568580	best: -0.0568568 (6155)	total: 1m 12s	remaining: 45.4s
# 6180:	learn: -0.1890824	test: -0.0568289	best: -0.0567885 (6169)	total: 1m 13s	remaining: 45.2s
# 6200:	learn: -0.1890782	test: -0.0567790	best: -0.0567790 (6200)	total: 1m 13s	remaining: 44.9s
# 6220:	learn: -0.1890745	test: -0.0567751	best: -0.0567606 (6209)	total: 1m 13s	remaining: 44.7s
# 6240:	learn: -0.1890699	test: -0.0567735	best: -0.0567606 (6209)	total: 1m 13s	remaining: 44.4s
# 9960:	learn: -0.1886107	test: -0.0525826	best: -0.0525779 (9952)	total: 1m 56s	remaining: 458ms
# 9980:	learn: -0.1886092	test: -0.0525571	best: -0.0525457 (9972)	total: 1m 57s	remaining: 223ms
# 9999:	learn: -0.1886077	test: -0.0525282	best: -0.0525282 (9999)	total: 1m 57s	remaining: 0us
#
# bestTest = -0.05252822141
# bestIteration = 9999
# 	Note: model has different eval_metric than default.
# 	-0.0525	 = Validation score   (-soft_log_loss)
# 	232.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.1071	 = Validation score   (-soft_log_loss)
# 	3.93s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.0525	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_2_L2_DSTL   1.000000  soft_log_loss       0.000000  232.039850                0.000000           0.036566            2       True         58
# 1             CatBoost_2_DSTL   1.000000  soft_log_loss       0.000000  232.003284                0.000000         232.003284            1       True         56
# 2             LightGBM_2_DSTL   0.944444  soft_log_loss       0.015639    2.016387                0.015639           2.016387            1       True         54
# 3       NeuralNetTorch_2_DSTL   0.944444  soft_log_loss       0.020185    3.933484                0.020185           3.933484            1       True         57
# 4      RandomForestMSE_2_DSTL   0.888889  soft_log_loss       0.064045    0.809390                0.064045           0.809390            1       True         55
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 2                  LightGBM_DSTL    0.823529   1.000000  soft_log_loss
# 3                  CatBoost_DSTL    0.823529   1.000000  soft_log_loss
# 1                LightGBM_2_DSTL    0.823529   0.944444  soft_log_loss
# 5           RandomForestMSE_DSTL    0.823529   0.944444  soft_log_loss
# 6          ExtraTreesGini_BAG_L1    0.823529   0.873563       accuracy
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN       accuracy
# 4     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN       accuracy
# 7           LightGBM_BAG_L2_FULL    0.823529        NaN       accuracy
# 8      LightGBMLarge_BAG_L2_FULL    0.823529        NaN       accuracy
# 9    NeuralNetFastAI_BAG_L2_FULL    0.823529        NaN       accuracy
# 10    NeuralNetTorch_BAG_L2_FULL    0.823529        NaN       accuracy
# 11    ExtraTreesEntr_BAG_L2_FULL    0.823529        NaN       accuracy
# 18      WeightedEnsemble_L2_DSTL    0.764706   1.000000  soft_log_loss
# 19           NeuralNetTorch_DSTL    0.764706   1.000000  soft_log_loss
# 21               CatBoost_2_DSTL    0.764706   1.000000  soft_log_loss
# 23    WeightedEnsemble_2_L2_DSTL    0.764706   1.000000  soft_log_loss
# 20         NeuralNetTorch_2_DSTL    0.764706   0.944444  soft_log_loss
# 25       RandomForestEntr_BAG_L1    0.764706   0.885057       accuracy
# 28       RandomForestGini_BAG_L1    0.764706   0.885057       accuracy
# 24         ExtraTreesEntr_BAG_L1    0.764706   0.873563       accuracy
# 12          LightGBM_BAG_L1_FULL    0.764706        NaN       accuracy
# 13        LightGBMXT_BAG_L1_FULL    0.764706        NaN       accuracy
# 14    NeuralNetTorch_BAG_L1_FULL    0.764706        NaN       accuracy
# 15      WeightedEnsemble_L3_FULL    0.764706        NaN       accuracy
# 16      WeightedEnsemble_L2_FULL    0.764706        NaN       accuracy
# 17   NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN       accuracy
# 22    ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 26  RandomForestEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 27  RandomForestGini_BAG_L1_FULL    0.764706        NaN       accuracy
# 29           XGBoost_BAG_L2_FULL    0.764706        NaN       accuracy
# 30          CatBoost_BAG_L2_FULL    0.764706        NaN       accuracy
# 31        LightGBMXT_BAG_L2_FULL    0.764706        NaN       accuracy
# 32  RandomForestEntr_BAG_L2_FULL    0.764706        NaN       accuracy
# 33    ExtraTreesGini_BAG_L2_FULL    0.764706        NaN       accuracy
# 34  RandomForestGini_BAG_L2_FULL    0.764706        NaN       accuracy
# 36        RandomForestMSE_2_DSTL    0.705882   0.888889  soft_log_loss
# 35          CatBoost_BAG_L1_FULL    0.705882        NaN       accuracy
# 37           XGBoost_BAG_L1_FULL    0.647059        NaN       accuracy
# 38           WeightedEnsemble_L3         NaN   0.954023       accuracy
# 39        NeuralNetFastAI_BAG_L1         NaN   0.954023       accuracy
# 40           WeightedEnsemble_L2         NaN   0.954023       accuracy
# 41                XGBoost_BAG_L2         NaN   0.954023       accuracy
# 42        NeuralNetFastAI_BAG_L2         NaN   0.954023       accuracy
# 43          LightGBMLarge_BAG_L2         NaN   0.942529       accuracy
# 44               LightGBM_BAG_L2         NaN   0.942529       accuracy
# 45               CatBoost_BAG_L2         NaN   0.942529       accuracy
# 46         NeuralNetTorch_BAG_L1         NaN   0.931034       accuracy
# 47             LightGBMXT_BAG_L2         NaN   0.931034       accuracy
# 48       RandomForestEntr_BAG_L2         NaN   0.919540       accuracy
# 49       RandomForestGini_BAG_L2         NaN   0.919540       accuracy
# 50         ExtraTreesEntr_BAG_L2         NaN   0.919540       accuracy
# 51         NeuralNetTorch_BAG_L2         NaN   0.919540       accuracy
# 52         ExtraTreesGini_BAG_L2         NaN   0.908046       accuracy
# 53             LightGBMXT_BAG_L1         NaN   0.896552       accuracy
# 54                XGBoost_BAG_L1         NaN   0.896552       accuracy
# 55               LightGBM_BAG_L1         NaN   0.896552       accuracy
# 56               CatBoost_BAG_L1         NaN   0.885057       accuracy
# 57          LightGBMLarge_BAG_L1         NaN   0.885057       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 2         0.041120       0.000000    3.261302                 0.041120
# 3         0.066972       0.000000  250.594729                 0.066972
# 1         0.010388       0.015639    2.016387                 0.010388
# 5         0.093386       0.056472    0.871956                 0.093386
# 6         0.105675       0.154375    0.960792                 0.105675
# 0         0.000000            NaN    0.273415                 0.000000
# 4         0.086985       0.154375    0.960792                 0.086985
# 7         0.301806            NaN   16.210244                 0.000000
# 8         0.301806            NaN   16.186590                 0.000000
# 9         0.310813            NaN   16.334389                 0.009008
# 10        0.330735            NaN   17.339445                 0.028929
# 11        0.370042            NaN   16.832463                 0.068236
# 18        0.020588       0.016547   11.491515                 0.000000
# 19        0.020588       0.016547   11.455205                 0.020588
# 21        0.048913       0.000000  232.003284                 0.048913
# 23        0.057065       0.000000  232.039850                 0.008152
# 20        0.028045       0.020185    3.933484                 0.028045
# 25        0.065304       0.123066    0.961340                 0.065304
# 28        0.085240       0.086764    0.894839                 0.085240
# 24        0.063682       0.090368    0.798167                 0.063682
# 12        0.000000            NaN    0.176055                 0.000000
# 13        0.003063            NaN    0.263623                 0.003063
# 14        0.010131            NaN   10.845537                 0.010131
# 15        0.010234            NaN    0.835062                 0.000000
# 16        0.010234            NaN    0.633226                 0.000000
# 17        0.010234            NaN    0.439081                 0.010234
# 22        0.054972       0.090368    0.798167                 0.054972
# 26        0.066025       0.123066    0.961340                 0.066025
# 27        0.067289       0.086764    0.894839                 0.067289
# 29        0.301806            NaN   16.018267                 0.000000
# 30        0.309906            NaN   16.046033                 0.008100
# 31        0.317759            NaN   16.183776                 0.015953
# 32        0.369374            NaN   16.724090                 0.067568
# 33        0.385931            NaN   16.837236                 0.084125
# 34        0.388056            NaN   16.907265                 0.086251
# 36        0.078915       0.064045    0.809390                 0.078915
# 35        0.000000            NaN    0.329326                 0.000000
# 37        0.003107            NaN    0.030879                 0.003107
# 38             NaN       0.098592   12.746136                      NaN
# 39             NaN       0.098592   12.350156                      NaN
# 40             NaN       0.105193   12.544300                      NaN
# 41             NaN       0.871060   69.264678                      NaN
# 42             NaN       0.948511   77.114282                      NaN
# 43             NaN       0.836567   69.803056                      NaN
# 44             NaN       0.842951   68.735782                      NaN
# 45             NaN       0.870207   82.461098                      NaN
# 46             NaN       0.158993   20.205369                      NaN
# 47             NaN       0.843571   68.466783                      NaN
# 48             NaN       0.930968   65.500555                      NaN
# 49             NaN       0.945119   65.683730                      NaN
# 50             NaN       0.961092   65.608928                      NaN
# 51             NaN       1.061703   87.579686                      NaN
# 52             NaN       0.932472   65.613701                      NaN
# 53             NaN       0.023217    4.738702                      NaN
# 54             NaN       0.030474    4.203879                      NaN
# 55             NaN       0.038447    4.573402                      NaN
# 56             NaN       0.012634   10.336131                      NaN
# 57             NaN       0.018631    4.726743                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 2                 0.000000           3.261302            1       True
# 3                 0.000000         250.594729            1       True
# 1                 0.015639           2.016387            1       True
# 5                 0.056472           0.871956            1       True
# 6                 0.154375           0.960792            1       True
# 0                      NaN           0.273415            1       True
# 4                 0.154375           0.960792            1       True
# 7                      NaN           0.237188            2       True
# 8                      NaN           0.213534            2       True
# 9                      NaN           0.361334            2       True
# 10                     NaN           1.366389            2       True
# 11                0.125531           0.859408            2       True
# 18                0.000000           0.036310            2       True
# 19                0.016547          11.455205            1       True
# 21                0.000000         232.003284            1       True
# 23                0.000000           0.036566            2       True
# 20                0.020185           3.933484            1       True
# 25                0.123066           0.961340            1       True
# 28                0.086764           0.894839            1       True
# 24                0.090368           0.798167            1       True
# 12                     NaN           0.176055            1       True
# 13                     NaN           0.263623            1       True
# 14                     NaN          10.845537            1       True
# 15                     NaN           0.395980            3       True
# 16                     NaN           0.194145            2       True
# 17                     NaN           0.439081            1       True
# 22                0.090368           0.798167            1       True
# 26                0.123066           0.961340            1       True
# 27                0.086764           0.894839            1       True
# 29                     NaN           0.045212            2       True
# 30                     NaN           0.072978            2       True
# 31                     NaN           0.210720            2       True
# 32                0.095407           0.751034            2       True
# 33                0.096911           0.864181            2       True
# 34                0.109559           0.934210            2       True
# 36                0.064045           0.809390            1       True
# 35                     NaN           0.329326            1       True
# 37                     NaN           0.030879            1       True
# 38                0.000000           0.395980            3      False
# 39                0.098592          12.350156            1      False
# 40                0.006601           0.194145            2      False
# 41                0.035500           4.515158            2      False
# 42                0.112951          12.364762            2      False
# 43                0.001007           5.053536            2      False
# 44                0.007391           3.986262            2      False
# 45                0.034647          17.711578            2      False
# 46                0.158993          20.205369            1      False
# 47                0.008011           3.717262            2      False
# 48                0.095407           0.751034            2      False
# 49                0.109559           0.934210            2      False
# 50                0.125531           0.859408            2      False
# 51                0.226143          22.830166            2      False
# 52                0.096911           0.864181            2      False
# 53                0.023217           4.738702            1      False
# 54                0.030474           4.203879            1      False
# 55                0.038447           4.573402            1      False
# 56                0.012634          10.336131            1      False
# 57                0.018631           4.726743            1      False
#
#     fit_order
# 2          49
# 3          51
# 1          54
# 5          50
# 6           7
# 0          35
# 4          31
# 7          39
# 8          47
# 9          37
# 10         46
# 11         44
# 18         53
# 19         52
# 21         56
# 23         58
# 20         57
# 25          5
# 28          4
# 24          8
# 12         27
# 13         26
# 14         34
# 15         48
# 16         36
# 17         25
# 22         32
# 26         29
# 27         28
# 29         45
# 30         42
# 31         38
# 32         41
# 33         43
# 34         40
# 36         55
# 35         30
# 37         33
# 38         24
# 39          1
# 40         12
# 41         21
# 42         13
# 43         23
# 44         15
# 45         18
# 46         10
# 47         14
# 48         17
# 49         16
# 50         20
# 51         22
# 52         19
# 53          2
# 54          9
# 55          3
# 56          6
# 57         11
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_2_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7647058823529411
# Evaluations on test data:
# {
#     "accuracy": 0.7647058823529411,
#     "balanced_accuracy": 0.7000000000000001,
#     "mcc": 0.6259425676138543
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.6,
#         "recall": 0.6,
#         "f1-score": 0.6,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5,
#         "f1-score": 0.5714285714285714,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.7647058823529411,
#     "macro avg": {
#         "precision": 0.7185185185185184,
#         "recall": 0.7000000000000001,
#         "f1-score": 0.7042016806722687,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.7516339869281046,
#         "recall": 0.7647058823529411,
#         "f1-score": 0.7538309441423628,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.7647058823529411, 'balanced_accuracy': 0.7000000000000001, 'mcc': 0.6259425676138543, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      2
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              2                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666, 'recall': 0.5, 'f1-score': 0.5714285714285714, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.7185185185185184, 'recall': 0.7000000000000001, 'f1-score': 0.7042016806722687, 'support': 17.0}, 'weighted avg': {'precision': 0.7516339869281046, 'recall': 0.7647058823529411, 'f1-score': 0.7538309441423628, 'support': 17.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'WeightedEnsemble_L3', 'NeuralNetFastAI_BAG_L1_FULL', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'RandomForestGini_BAG_L1_FULL', 'RandomForestEntr_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'ExtraTreesGini_BAG_L1_FULL', 'ExtraTreesEntr_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'NeuralNetTorch_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'WeightedEnsemble_L2_FULL', 'NeuralNetFastAI_BAG_L2_FULL', 'LightGBMXT_BAG_L2_FULL', 'LightGBM_BAG_L2_FULL', 'RandomForestGini_BAG_L2_FULL', 'RandomForestEntr_BAG_L2_FULL', 'CatBoost_BAG_L2_FULL', 'ExtraTreesGini_BAG_L2_FULL', 'ExtraTreesEntr_BAG_L2_FULL', 'XGBoost_BAG_L2_FULL', 'NeuralNetTorch_BAG_L2_FULL', 'LightGBMLarge_BAG_L2_FULL', 'WeightedEnsemble_L3_FULL', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 4
#       2 i = 0  # index of model to use
#       3 model_to_use = all_models[i]
# ----> 4 model_pred = predictor.predict(test_data, model=model_to_use)
#       5 print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py:2117, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    2115 if decision_threshold is None:
#    2116     decision_threshold = self.decision_threshold
# -> 2117 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:189, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     187     if transform_features:
#     188         X = self.transform_features(X)
# --> 189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#     193 return y_pred_proba
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:837, in AbstractTrainer.predict_proba(self, X, model)
#     835     model = self._get_best()
#     836 cascade = isinstance(model, list)
# --> 837 return self._predict_proba_model(X, model, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:2611, in AbstractTrainer._predict_proba_model(self, X, model, model_pred_proba_dict, cascade)
#    2610 def _predict_proba_model(self, X, model, model_pred_proba_dict=None, cascade=False):
# -> 2611     return self.get_pred_proba_from_model(model=model, X=X, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:851, in AbstractTrainer.get_pred_proba_from_model(self, model, X, model_pred_proba_dict, cascade)
#     849 else:
#     850     models = [model]
# --> 851 model_pred_proba_dict = self.get_model_pred_proba_dict(X=X, models=models, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#     852 if not isinstance(model, str):
#     853     model = model.name
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1100, in AbstractTrainer.get_model_pred_proba_dict(self, X, models, model_pred_proba_dict, model_pred_time_dict, record_pred_time, use_val_cache, cascade, cascade_threshold)
#    1098     else:
#    1099         preprocess_kwargs = dict(infer=False, model_pred_proba_dict=model_pred_proba_dict)
# -> 1100     model_pred_proba_dict[model_name] = model.predict_proba(X, **preprocess_kwargs)
#    1101 else:
#    1102     model_pred_proba_dict[model_name] = model.predict_proba(X)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py:456, in BaggedEnsembleModel._predict_proba_internal(self, X, normalize, **kwargs)
#     454 model = self.load_child(self.models[0])
#     455 X = self.preprocess(X, model=model, **kwargs)
# --> 456 y_pred_proba = model.predict_proba(X=X, preprocess_nonadaptive=False, normalize=normalize)
#     457 for model in self.models[1:]:
#     458     model = self.load_child(model)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:982, in AbstractModel._predict_proba_internal(self, X, normalize, **kwargs)
#     980 if normalize is None:
#     981     normalize = self.normalize_pred_probas
# --> 982 y_pred_proba = self._predict_proba(X=X, **kwargs)
#     983 if normalize:
#     984     y_pred_proba = normalize_pred_probas(y_pred_proba, self.problem_type)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:483, in NNFastAiTabularModel._predict_proba(self, X, **kwargs)
#     479     X = pd.concat([X, X]).reset_index(drop=True)
#     480 # Copy cat_columns and cont_columns because TabularList is mutating the list
#     481 # TODO: This call has very high fixed cost with many features (0.7s for a single row with 3k features)
#     482 #  Primarily due to normalization performed on the inputs
# --> 483 test_dl = self.model.dls.test_dl(X, inplace=True)
#     484 with self.model.no_bar():
#     485     with self.model.no_logging():
#
# AttributeError: 'NoneType' object has no attribute 'dls'

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
