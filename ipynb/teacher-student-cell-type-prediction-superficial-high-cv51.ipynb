# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='high_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=True
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
num_bag_sets=1
dynamic_stacking = True
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       9.99 GB / 15.92 GB (62.8%)
# Disk Space Avail:   312.07 GB / 931.51 GB (33.5%)
# ===================================================
# Presets specified: ['high_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Starting (repeated-)cross-validation-based sub-fits for dynamic stacking. Context path: "models\Teacher\high_quality-20241101-075040\ds_sub_fit"Run at most 5 sub-fits based on 1-repeated 5-fold cross-validation.
# 	Starting sub-fit 1. Time limit for the sub-fit of this split is: 180.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 07:51:12,514	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "models\Teacher\high_quality-20241101-075040\ds_sub_fit\sub_fit_0"
# (_dystack pid=1516) Running DyStack sub-fit ...
# (_dystack pid=1516) Beginning AutoGluon training ... Time limit = 864s
# (_dystack pid=1516) AutoGluon will save models to "models\Teacher\high_quality-20241101-075040\ds_sub_fit\sub_fit_0"
# (_dystack pid=1516) Train Data Rows:    247
# (_dystack pid=1516) Train Data Columns: 36
# (_dystack pid=1516) Label Column:       label
# (_dystack pid=1516) Problem Type:       multiclass
# (_dystack pid=1516) Preprocessing data ...
# (_dystack pid=1516) Train Data Class Count: 3
# (_dystack pid=1516) Using Feature Generators to preprocess the data ...
# (_dystack pid=1516) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=1516) 	Available Memory:                    9375.67 MB
# (_dystack pid=1516) 	Train Data (Original)  Memory Usage: 0.07 MB (0.0% of available memory)
# (_dystack pid=1516) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=1516) 	Stage 1 Generators:
# (_dystack pid=1516) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=1516) 	Stage 2 Generators:
# (_dystack pid=1516) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=1516) 	Stage 3 Generators:
# (_dystack pid=1516) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=1516) 	Stage 4 Generators:
# (_dystack pid=1516) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=1516) 	Stage 5 Generators:
# (_dystack pid=1516) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=1516) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=1516) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=1516) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=1516) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=1516) 	0.1s = Fit runtime
# (_dystack pid=1516) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=1516) 	Train Data (Processed) Memory Usage: 0.07 MB (0.0% of available memory)
# (_dystack pid=1516) Data preprocessing and feature engineering runtime = 0.14s ...
# (_dystack pid=1516) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=1516) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=1516) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=1516) User-specified model hyperparameters to be fit:
# (_dystack pid=1516) {
# (_dystack pid=1516) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=1516) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=1516) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=1516) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=1516) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=1516) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=1516) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=1516) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=1516) }
# (_dystack pid=1516) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=1516) Fitting 110 L1 models ...
# (_dystack pid=1516) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 576.08s of the 864.32s of remaining time.
# (_dystack pid=1516) 	0.6356	 = Validation score   (accuracy)
# (_dystack pid=1516) 	0.01s	 = Training   runtime
# (_dystack pid=1516) 	0.62s	 = Validation runtime
# (_dystack pid=1516) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 549.6s of the 837.84s of remaining time.
# (_dystack pid=1516) 	0.749	 = Validation score   (accuracy)
# (_dystack pid=1516) 	0.0s	 = Training   runtime
# (_dystack pid=1516) 	0.0s	 = Validation runtime
# (_dystack pid=1516) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 549.57s of the 837.81s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=1516) 	0.8988	 = Validation score   (accuracy)
# (_dystack pid=1516) 	12.3s	 = Training   runtime
# (_dystack pid=1516) 	0.15s	 = Validation runtime
# (_dystack pid=1516) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 532.22s of the 820.46s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=1516) 	0.8623	 = Validation score   (accuracy)
# (_dystack pid=1516) 	2.09s	 = Training   runtime
# (_dystack pid=1516) 	0.01s	 = Validation runtime
# (_dystack pid=1516) Fitting model: LightGBM_BAG_L1 ... Training model for up to 525.13s of the 813.38s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_dystack pid=1516) 	0.8866	 = Validation score   (accuracy)
# (_dystack pid=1516) 	1.8s	 = Training   runtime
# (_dystack pid=1516) 	0.02s	 = Validation runtime
# (_dystack pid=1516) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 518.31s of the 806.55s of remaining time.
# (_dystack pid=1516) 	0.8502	 = Validation score   (accuracy)
# (_dystack pid=1516) 	1.18s	 = Training   runtime
# (_dystack pid=1516) 	0.12s	 = Validation runtime
# (_dystack pid=1516) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 516.97s of the 805.21s of remaining time.
# (_dystack pid=1516) 	0.83	 = Validation score   (accuracy)
# (_dystack pid=1516) 	0.91s	 = Training   runtime
# (_dystack pid=1516) 	0.08s	 = Validation runtime
# (_dystack pid=1516) Fitting model: CatBoost_BAG_L1 ... Training model for up to 515.92s of the 804.17s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.14%)
# (_dystack pid=1516) 	0.8462	 = Validation score   (accuracy)
# (_dystack pid=1516) 	14.96s	 = Training   runtime
# (_dystack pid=1516) 	0.12s	 = Validation runtime
# (_dystack pid=1516) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 496.57s of the 784.81s of remaining time.
# (_dystack pid=1516) 	0.8462	 = Validation score   (accuracy)
# (_dystack pid=1516) 	0.85s	 = Training   runtime
# (_dystack pid=1516) 	0.08s	 = Validation runtime
# (_dystack pid=1516) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 495.6s of the 783.84s of remaining time.
# (_dystack pid=1516) 	0.8421	 = Validation score   (accuracy)
# (_dystack pid=1516) 	0.87s	 = Training   runtime
# (_dystack pid=1516) 	0.08s	 = Validation runtime
# (_dystack pid=1516) Fitting model: XGBoost_BAG_L1 ... Training model for up to 494.61s of the 782.85s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=1516) 	0.8866	 = Validation score   (accuracy)
# (_dystack pid=1516) 	2.48s	 = Training   runtime
# (_dystack pid=1516) 	0.02s	 = Validation runtime
# (_dystack pid=1516) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 487.64s of the 775.88s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=14312) Stack (most recent call first):
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=14312)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=14312)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=1516) 	0.8704	 = Validation score   (accuracy)
# (_dystack pid=1516) 	69.33s	 = Training   runtime
# (_dystack pid=1516) 	0.12s	 = Validation runtime
# (_dystack pid=1516) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 413.13s of the 701.38s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_ray_fit pid=1628) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=1628)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=1628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=1516) 	0.8704	 = Validation score   (accuracy)
# (_dystack pid=1516) 	3.16s	 = Training   runtime
# (_dystack pid=1516) 	0.01s	 = Validation runtime
# (_dystack pid=1516) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 405.3s of the 693.54s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=1516) 	0.8664	 = Validation score   (accuracy)
# (_dystack pid=1516) 	16.95s	 = Training   runtime
# (_dystack pid=1516) 	0.01s	 = Validation runtime
# (_dystack pid=1516) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 383.44s of the 671.69s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=3532) Stack (most recent call first):
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=3532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=3532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>", line 940 in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line 690
# (_ray_fit pid=6128)  in _load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 1176 in
# (_ray_fit pid=6128) _find_and_load
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py"
# (_ray_fit pid=6128) , line 36 in <module>
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>", line 241 in
# (_ray_fit pid=6128) _call_with_frames_removed
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>"
# (_ray_fit pid=6128) , line 940 in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 1176 in _find_and_load
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py"
# (_ray_fit pid=6128) , line 59
# (_ray_fit pid=6128)  in <module>
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 241 in _call_with_frames_removed
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap_external>", line 940 in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 690 in _load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 1176
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) _find_and_load
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 1126
# (_ray_fit pid=6128)  in _find_and_load_unlocked
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 1176
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) _find_and_load
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line
# (_ray_fit pid=6128) 13 in <module>
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 241 in
# (_ray_fit pid=6128) _call_with_frames_removed
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>", line 940 in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 690 in
# (_ray_fit pid=6128) _load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line 1176 in
# (_ray_fit pid=6128) _find_and_load
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34
# (_ray_fit pid=6128)  in <module>
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 241 in _call_with_frames_removed
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>", line 940
# (_ray_fit pid=6128)  in exec_module
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 1176
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) _find_and_load
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 241
# (_ray_fit pid=6128)  in _call_with_frames_removed
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line 940
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=6128) 690 in _load_unlocked
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 1176
# (_ray_fit pid=6128)  in _find_and_load
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) ", line
# (_ray_fit pid=6128) 241 in
# (_ray_fit pid=6128) _call_with_frames_removed
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap_external>
# (_ray_fit pid=6128) ", line 940 in exec_module
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line 1176
# (_ray_fit pid=6128)  in _find_and_load
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=6128) ", line
# (_ray_fit pid=6128) 241 in
# (_ray_fit pid=6128) _call_with_frames_removed
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>"
# (_ray_fit pid=6128) , line 1232
# (_ray_fit pid=6128)  in _handle_fromlist
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap_external>"
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 940
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) exec_module
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "<frozen importlib._bootstrap>", line 690 in
# (_ray_fit pid=6128) _load_unlocked
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) <frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line
# (_ray_fit pid=6128) 284 in __init__
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line 45 in
# (_ray_fit pid=6128) __init__
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py"
# (_ray_fit pid=6128) , line
# (_ray_fit pid=6128) 561
# (_ray_fit pid=6128)  in
# (_ray_fit pid=6128) _init_optimizer
# (_ray_fit pid=6128)
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196
# (_ray_fit pid=6128)  in _fit
# (_ray_fit pid=6128)   File "
# (_ray_fit pid=6128) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py
# (_ray_fit pid=6128) ", line 856 in fit
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py
# (_ray_fit pid=6128) "
# (_ray_fit pid=6128) , line 402
# (_ray_fit pid=6128)  in _ray_fit
# (_ray_fit pid=6128)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py"
# (_ray_fit pid=6128) , line 282 in
# (_ray_fit pid=6128) <module>
# (_ray_fit pid=6128)
# (_dystack pid=1516) 	0.8947	 = Validation score   (accuracy)
# (_dystack pid=1516) 	20.07s	 = Training   runtime
# (_dystack pid=1516) 	0.15s	 = Validation runtime
# (_dystack pid=1516) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 358.84s of the 647.09s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=12708) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 77x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 58x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 62x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 57x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 48x across cluster]
# (_ray_fit pid=12708)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 13x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 12x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 6x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 6x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 6x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 6x across cluster]
# (_ray_fit pid=12708)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=1516) 	0.8664	 = Validation score   (accuracy)
# (_dystack pid=1516) 	2.39s	 = Training   runtime
# (_dystack pid=1516) 	0.0s	 = Validation runtime
# (_dystack pid=1516) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 351.77s of the 640.02s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=1516) 	0.8785	 = Validation score   (accuracy)
# (_dystack pid=1516) 	14.04s	 = Training   runtime
# (_dystack pid=1516) 	0.09s	 = Validation runtime
# (_dystack pid=1516) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 332.84s of the 621.09s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.63%)
# (_dystack pid=1516) 	0.8381	 = Validation score   (accuracy)
# (_dystack pid=1516) 	41.14s	 = Training   runtime
# (_dystack pid=1516) 	0.04s	 = Validation runtime
# (_dystack pid=1516) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 286.77s of the 575.01s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=1516) 	0.7773	 = Validation score   (accuracy)
# (_dystack pid=1516) 	1.5s	 = Training   runtime
# (_dystack pid=1516) 	0.02s	 = Validation runtime
# (_dystack pid=1516) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 280.93s of the 569.17s of remaining time.
# (_dystack pid=1516) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=9824) Stack (most recent call first):
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=9824)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=9824)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=9824)   File "
# ...
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.55s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.23s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.93s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.79s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	2.38s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.75s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.87s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	8.32s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.58s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	1.37s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	2.64s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# No improvement since epoch 1: early stopping
# 	0.66s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	3.45s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	0.17s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	2.03s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	0.11s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.88s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	0.69s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	1.88s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	6.21s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.06s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r145_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	3.52s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	2.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r11_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	0.69s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	0.13s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.89s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	1.12s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r103_BAG_L1_FULL ...
# No improvement since epoch 0: early stopping
# 	0.48s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	0.89s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	0.37s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r143_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	2.11s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	1.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r156_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 20.
# 	1.78s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r196_BAG_L1_FULL ...
# 	0.27s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.0s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r167_BAG_L1_FULL ...
# 	3.58s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r95_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.56s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r41_BAG_L1_FULL ...
# 	1.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r98_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r15_BAG_L1_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	3.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	4.05s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r37_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	1.63s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r197_BAG_L1_FULL ...
# 	0.69s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r49_BAG_L1_FULL ...
# 	0.71s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.93s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r143_BAG_L1_FULL ...
# 	0.28s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.08s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r134_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 22.
# 	2.81s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r94_BAG_L1_FULL ...
# 	0.25s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r143_BAG_L1_FULL ...
# 	4.2s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r128_BAG_L1_FULL ...
# 	2.25s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r111_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	1.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r31_BAG_L1_FULL ...
# 	1.4s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.85s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r65_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 23.
# 	2.03s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r88_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	1.01s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r30_BAG_L1_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r49_BAG_L1_FULL ...
# 	0.05s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r5_BAG_L1_FULL ...
# 	0.91s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r87_BAG_L1_FULL ...
# 	1.2s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r71_BAG_L1_FULL ...
# 	0.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r143_BAG_L1_FULL ...
# 	1.51s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.98s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.29s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r31_BAG_L1_FULL ...
# 	0.09s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r185_BAG_L1_FULL ...
# 	1.62s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r160_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.46s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r60_BAG_L1_FULL ...
# 	1.37s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.05s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r135_BAG_L1_FULL ...
# 	0.24s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r22_BAG_L1_FULL ...
# 	0.06s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r69_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.45s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r6_BAG_L1_FULL ...
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r138_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r121_BAG_L1_FULL ...
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r172_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	1.38s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r180_BAG_L1_FULL ...
# 	2.5s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r76_BAG_L1_FULL ...
# 	0.85s	 = Training   runtime
# Fitting model: ExtraTrees_r197_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.07s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r121_BAG_L1_FULL ...
# 	2.13s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r127_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	1.37s	 = Training   runtime
# Fitting model: RandomForest_r16_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.64s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r194_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	0.38s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r12_BAG_L1_FULL ...
# 	4.21s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r135_BAG_L1_FULL ...
# 	2.43s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r4_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 17.
# 	0.37s	 = Training   runtime
# Fitting model: ExtraTrees_r126_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.4s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r36_BAG_L1_FULL ...
# 	1.2s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r100_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 17.
# 	2.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r163_BAG_L1_FULL ...
# 	0.74s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r198_BAG_L1_FULL ...
# 	1.98s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r187_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 22.
# 	2.34s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r19_BAG_L1_FULL ...
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r95_BAG_L1_FULL ...
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r34_BAG_L1_FULL ...
# 	0.16s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r42_BAG_L1_FULL ...
# 	0.25s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L1': 0.25, 'NeuralNetTorch_r86_BAG_L1': 0.25, 'LightGBM_r15_BAG_L1': 0.25, 'NeuralNetTorch_r121_BAG_L1': 0.25}
# 	0.44s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.29s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.89s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.79s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	1.02s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.86s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.9s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.95s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	1.77s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	2.31s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	0.9s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	1.52s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.4s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	2.03s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	0.2s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_r33_BAG_L2_FULL ...
# 	0.37s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	0.26s	 = Training   runtime
# Updated best model to "LightGBM_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "LightGBM_BAG_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 135.73s ... Best model: "LightGBM_BAG_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\high_quality-20241101-075040")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\medium_quality-20241008-171554"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: LightGBM_BAG_L2_FULL
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                     LightGBM_BAG_L2   0.941748    accuracy       9.456595  1324.130895                0.028830           7.703694            2      False        112
# 1                 WeightedEnsemble_L3   0.941748    accuracy       9.457593  1324.386525                0.000998           0.255630            3      False        128
# 2                LightGBMLarge_BAG_L2   0.941748    accuracy       9.471454  1348.143882                0.043688          31.716681            2      False        120
# 3                LightGBM_r131_BAG_L2   0.938511    accuracy       9.457379  1326.770023                0.029613          10.342822            2      False        123
# 4                   LightGBMXT_BAG_L2   0.935275    accuracy       9.461252  1321.034631                0.033487           4.607430            2      False        111
# 5           NeuralNetTorch_r79_BAG_L2   0.935275    accuracy       9.908495  1344.359099                0.480730          27.931898            2      False        122
# 6                 LightGBM_r96_BAG_L2   0.932039    accuracy       9.455281  1318.767251                0.027516           2.340050            2      False        126
# 7                  XGBoost_r33_BAG_L2   0.932039    accuracy       9.458693  1331.247500                0.030927          14.820299            2      False        127
# 8                      XGBoost_BAG_L2   0.932039    accuracy       9.498045  1328.591077                0.070280          12.163876            2      False        118
# 9                 WeightedEnsemble_L2   0.928803    accuracy       0.419380    54.077676                0.001000           0.441070            2      False        109
# 10            RandomForestEntr_BAG_L2   0.928803    accuracy       9.526917  1317.216325                0.099151           0.789124            2      False        114
# 11        NeuralNetFastAI_r191_BAG_L2   0.928803    accuracy       9.558687  1327.141493                0.130922          10.714292            2      False        124
# 12             NeuralNetFastAI_BAG_L2   0.925566    accuracy       9.522558  1327.009111                0.094793          10.581910            2      False        110
# 13              NeuralNetTorch_BAG_L2   0.925566    accuracy       9.973392  1335.218597                0.545627          18.791396            2      False        119
# 14                    CatBoost_BAG_L2   0.922330    accuracy       9.502550  1504.773277                0.074784         188.346076            2      False        115
# 15              ExtraTreesGini_BAG_L2   0.922330    accuracy       9.524086  1317.291982                0.096320           0.864781            2      False        116
# 16               CatBoost_r177_BAG_L2   0.922330    accuracy       9.524561  1505.085488                0.096795         188.658287            2      False        121
# 17            RandomForestGini_BAG_L2   0.922330    accuracy       9.537946  1317.321536                0.110180           0.894334            2      False        113
# 18                 CatBoost_r9_BAG_L2   0.919094    accuracy       9.516328  1555.136982                0.088562         238.709781            2      False        125
# 19              ExtraTreesEntr_BAG_L2   0.919094    accuracy       9.569266  1317.332001                0.141500           0.904800            2      False        117
# 20         NeuralNetTorch_r121_BAG_L1   0.915858    accuracy       0.152392    23.502568                0.152392          23.502568            1      False         92
# 21        NeuralNetFastAI_r191_BAG_L1   0.912621    accuracy       0.094924    10.763831                0.094924          10.763831            1      False         17
# 22          NeuralNetTorch_r86_BAG_L1   0.912621    accuracy       0.155632    27.103465                0.155632          27.103465            1      False         32
# 23          NeuralNetTorch_r79_BAG_L1   0.912621    accuracy       0.158957    22.795484                0.158957          22.795484            1      False         15
# 24        NeuralNetFastAI_r134_BAG_L1   0.912621    accuracy       0.185107    17.029548                0.185107          17.029548            1      False         59
# 25          NeuralNetTorch_r76_BAG_L1   0.909385    accuracy       0.173985    16.864635                0.173985          16.864635            1      False         90
# 26         NeuralNetTorch_r135_BAG_L1   0.906149    accuracy       0.176894    21.429495                0.176894          21.429495            1      False         97
# 27               LightGBM_r130_BAG_L1   0.902913    accuracy       0.019997     1.859465                0.019997           1.859465            1      False         31
# 28               LightGBM_r121_BAG_L1   0.902913    accuracy       0.023848     3.294063                0.023848           3.294063            1      False         87
# 29                 XGBoost_r98_BAG_L1   0.902913    accuracy       0.067891     5.683582                0.067891           5.683582            1      False         49
# 30             NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.098578     9.314915                0.098578           9.314915            1      False          3
# 31         NeuralNetFastAI_r95_BAG_L1   0.902913    accuracy       0.103258     9.249706                0.103258           9.249706            1      False         47
# 32        NeuralNetFastAI_r145_BAG_L1   0.902913    accuracy       0.104500     9.251714                0.104500           9.251714            1      False         28
# 33        NeuralNetFastAI_r156_BAG_L1   0.902913    accuracy       0.118980    12.502903                0.118980          12.502903            1      False         43
# 34                LightGBM_r15_BAG_L1   0.899676    accuracy       0.015913     2.277660                0.015913           2.277660            1      False         50
# 35               LightGBMLarge_BAG_L1   0.899676    accuracy       0.024141     4.357730                0.024141           4.357730            1      False         13
# 36          NeuralNetTorch_r19_BAG_L1   0.899676    accuracy       0.179232    16.796366                0.179232          16.796366            1      False        105
# 37                    LightGBM_BAG_L1   0.896440    accuracy       0.020027     2.390576                0.020027           2.390576            1      False          5
# 38                 XGBoost_r89_BAG_L1   0.896440    accuracy       0.038835     2.953639                0.038835           2.953639            1      False         29
# 39                 XGBoost_r49_BAG_L1   0.896440    accuracy       0.041863     3.832678                0.041863           3.832678            1      False         70
# 40                LightGBM_r42_BAG_L1   0.896440    accuracy       0.042334     2.115366                0.042334           2.115366            1      False        108
# 41                XGBoost_r194_BAG_L1   0.896440    accuracy       0.062597     3.132954                0.062597           3.132954            1      False         35
# 42              ExtraTreesEntr_BAG_L1   0.896440    accuracy       0.091988     0.868361                0.091988           0.868361            1       True         10
# 43          NeuralNetTorch_r71_BAG_L1   0.896440    accuracy       0.154395    23.539770                0.154395          23.539770            1      False         73
# 44        NeuralNetFastAI_r100_BAG_L1   0.896440    accuracy       0.158623    15.522455                0.158623          15.522455            1      False        101
# 45         NeuralNetTorch_r185_BAG_L1   0.896440    accuracy       0.194354    18.049533                0.194354          18.049533            1      False         78
# 46               LightGBM_r188_BAG_L1   0.893204    accuracy       0.015001     2.320786                0.015001           2.320786            1      False         27
# 47                  LightGBMXT_BAG_L1   0.893204    accuracy       0.022278     3.326730                0.022278           3.326730            1      False          4
# 48        NeuralNetFastAI_r172_BAG_L1   0.893204    accuracy       0.097391    11.358941                0.097391          11.358941            1      False         88
# 49        NeuralNetFastAI_r138_BAG_L1   0.893204    accuracy       0.145478    10.782672                0.145478          10.782672            1      False         86
# 50          NeuralNetTorch_r41_BAG_L1   0.893204    accuracy       0.171532    17.152228                0.171532          17.152228            1      False         48
# 51          NeuralNetTorch_r31_BAG_L1   0.893204    accuracy       0.220161    15.218050                0.220161          15.218050            1      False         65
# 52               LightGBM_r131_BAG_L1   0.889968    accuracy       0.018126     2.962676                0.018126           2.962676            1      False         16
# 53               CatBoost_r177_BAG_L1   0.889968    accuracy       0.019599    22.120475                0.019599          22.120475            1      False         14
# 54                 XGBoost_r34_BAG_L1   0.889968    accuracy       0.034482     3.889856                0.034482           3.889856            1      False        107
# 55              ExtraTrees_r49_BAG_L1   0.889968    accuracy       0.092549     0.927928                0.092549           0.927928            1       True         56
# 56              ExtraTreesGini_BAG_L1   0.889968    accuracy       0.094444     0.752913                0.094444           0.752913            1       True          9
# 57        NeuralNetFastAI_r127_BAG_L1   0.889968    accuracy       0.128456    10.999300                0.128456          10.999300            1      False         93
# 58                 CatBoost_r9_BAG_L1   0.886731    accuracy       0.015930    51.061750                0.015930          51.061750            1      False         18
# 59               LightGBM_r161_BAG_L1   0.886731    accuracy       0.025533     2.421566                0.025533           2.421566            1      False         40
# 60                 XGBoost_r95_BAG_L1   0.886731    accuracy       0.026004     3.868099                0.026004           3.868099            1      False        106
# 61                 XGBoost_r22_BAG_L1   0.886731    accuracy       0.028296     2.824805                0.028296           2.824805            1      False         83
# 62                 XGBoost_r33_BAG_L1   0.886731    accuracy       0.035119     4.998569                0.035119           4.998569            1      False         21
# 63         NeuralNetFastAI_r69_BAG_L1   0.886731    accuracy       0.112883     8.668978                0.112883           8.668978            1      False         84
# 64        NeuralNetFastAI_r102_BAG_L1   0.886731    accuracy       0.119307    11.242360                0.119307          11.242360            1      False         24
# 65        NeuralNetFastAI_r194_BAG_L1   0.886731    accuracy       0.122083     8.960870                0.122083           8.960870            1      False         95
# 66                 XGBoost_r31_BAG_L1   0.883495    accuracy       0.013020     4.050597                0.013020           4.050597            1      False         77
# 67                CatBoost_r70_BAG_L1   0.883495    accuracy       0.015579    20.662557                0.015579          20.662557            1      False         42
# 68                 CatBoost_r5_BAG_L1   0.883495    accuracy       0.017961    10.762468                0.017961          10.762468            1      False         71
# 69                     XGBoost_BAG_L1   0.883495    accuracy       0.027003     2.963220                0.027003           2.963220            1      False         11
# 70        NeuralNetFastAI_r103_BAG_L1   0.883495    accuracy       0.131720     9.229335                0.131720           9.229335            1      False         38
# 71        NeuralNetFastAI_r187_BAG_L1   0.883495    accuracy       0.134388    12.769310                0.134388          12.769310            1      False        104
# 72          NeuralNetTorch_r14_BAG_L1   0.883495    accuracy       0.167017    13.847338                0.167017          13.847338            1      False         39
# 73              NeuralNetTorch_BAG_L1   0.883495    accuracy       0.172265    20.261994                0.172265          20.261994            1      False         12
# 74         NeuralNetTorch_r143_BAG_L1   0.883495    accuracy       0.210328    20.805662                0.210328          20.805662            1      False         62
# 75                CatBoost_r86_BAG_L1   0.880259    accuracy       0.009897    63.486430                0.009897          63.486430            1      False         52
# 76               CatBoost_r128_BAG_L1   0.880259    accuracy       0.016095    44.166414                0.016095          44.166414            1      False         63
# 77               CatBoost_r167_BAG_L1   0.880259    accuracy       0.019041    43.415419                0.019041          43.415419            1      False         46
# 78               LightGBM_r196_BAG_L1   0.880259    accuracy       0.021530     2.769495                0.021530           2.769495            1      False         44
# 79         NeuralNetFastAI_r11_BAG_L1   0.880259    accuracy       0.115501    10.095912                0.115501          10.095912            1      False         34
# 80         NeuralNetTorch_r158_BAG_L1   0.880259    accuracy       0.196728    18.812831                0.196728          18.812831            1      False         51
# 81                CatBoost_r60_BAG_L1   0.877023    accuracy       0.019667    14.554982                0.019667          14.554982            1      False         80
# 82                CatBoost_r49_BAG_L1   0.877023    accuracy       0.019984     9.142879                0.019984           9.142879            1      False         55
# 83               LightGBM_r135_BAG_L1   0.877023    accuracy       0.021246     1.707080                0.021246           1.707080            1      False         82
# 84               LightGBM_r143_BAG_L1   0.877023    accuracy       0.026647     2.584281                0.026647           2.584281            1      False         57
# 85          NeuralNetTorch_r30_BAG_L1   0.877023    accuracy       0.164858    20.840538                0.164858          20.840538            1      False         30
# 86         NeuralNetTorch_r197_BAG_L1   0.877023    accuracy       0.165031    17.478120                0.165031          17.478120            1      False         54
# 87          NeuralNetTorch_r36_BAG_L1   0.877023    accuracy       0.177896    30.918267                0.177896          30.918267            1      False        100
# 88               CatBoost_r143_BAG_L1   0.873786    accuracy       0.013645    32.784670                0.013645          32.784670            1      False         74
# 89               CatBoost_r163_BAG_L1   0.873786    accuracy       0.015794    11.649385                0.015794          11.649385            1      False        102
# 90                    CatBoost_BAG_L1   0.873786    accuracy       0.016990    23.323966                0.016990          23.323966            1      False          8
# 91                CatBoost_r50_BAG_L1   0.873786    accuracy       0.019992     8.864509                0.019992           8.864509            1      False         33
# 92               CatBoost_r180_BAG_L1   0.873786    accuracy       0.020113    34.043415                0.020113          34.043415            1      False         89
# 93             ExtraTrees_r126_BAG_L1   0.873786    accuracy       0.091269     1.398372                0.091269           1.398372            1       True         99
# 94          NeuralNetFastAI_r4_BAG_L1   0.873786    accuracy       0.111802     9.193975                0.111802           9.193975            1      False         98
# 95                CatBoost_r69_BAG_L1   0.870550    accuracy       0.016614    12.450064                0.016614          12.450064            1      False         37
# 96               CatBoost_r198_BAG_L1   0.870550    accuracy       0.017943    25.253000                0.017943          25.253000            1      False        103
# 97                 CatBoost_r6_BAG_L1   0.870550    accuracy       0.019269     9.616084                0.019269           9.616084            1      False         85
# 98                CatBoost_r12_BAG_L1   0.867314    accuracy       0.015000    52.200069                0.015000          52.200069            1      False         96
# 99               CatBoost_r137_BAG_L1   0.867314    accuracy       0.018454     9.237008                0.018454           9.237008            1      False         23
# 100               LightGBM_r94_BAG_L1   0.867314    accuracy       0.025509     2.045273                0.025509           2.045273            1      False         61
# 101          RandomForest_r166_BAG_L1   0.867314    accuracy       0.104508     1.290366                0.104508           1.290366            1       True         76
# 102         NeuralNetTorch_r22_BAG_L1   0.867314    accuracy       0.168928    17.875455                0.168928          17.875455            1      False         20
# 103         NeuralNetTorch_r87_BAG_L1   0.867314    accuracy       0.179067    18.412598                0.179067          18.412598            1      False         72
# 104           RandomForestEntr_BAG_L1   0.864078    accuracy       0.097988     0.793408                0.097988           0.793408            1       True          7
# 105           RandomForestGini_BAG_L1   0.864078    accuracy       0.123791     0.929276                0.123791           0.929276            1       True          6
# 106               LightGBM_r30_BAG_L1   0.860841    accuracy       0.053900     2.119878                0.053900           2.119878            1      False         69
# 107           RandomForest_r16_BAG_L1   0.860841    accuracy       0.089296     1.641133                0.089296           1.641133            1       True         94
# 108          RandomForest_r195_BAG_L1   0.860841    accuracy       0.092071     1.059180                0.092071           1.059180            1       True         26
# 109             ExtraTrees_r42_BAG_L1   0.860841    accuracy       0.111981     0.881181                0.111981           0.881181            1       True         22
# 110            ExtraTrees_r197_BAG_L1   0.860841    accuracy       0.125427     1.071203                0.125427           1.071203            1       True         91
# 111               CatBoost_r13_BAG_L1   0.854369    accuracy       0.019372    81.395025                0.019372          81.395025            1      False         25
# 112        NeuralNetFastAI_r37_BAG_L1   0.851133    accuracy       0.164012    13.357765                0.164012          13.357765            1      False         53
# 113        NeuralNetFastAI_r88_BAG_L1   0.847896    accuracy       0.113031    12.411124                0.113031          12.411124            1      False         68
# 114            ExtraTrees_r172_BAG_L1   0.844660    accuracy       0.089851     0.890306                0.089851           0.890306            1       True         36
# 115        NeuralNetFastAI_r65_BAG_L1   0.844660    accuracy       0.107795    12.202846                0.107795          12.202846            1      False         67
# 116       NeuralNetFastAI_r160_BAG_L1   0.841424    accuracy       0.098507     9.792036                0.098507           9.792036            1      False         79
# 117           RandomForest_r39_BAG_L1   0.841424    accuracy       0.108248     0.996619                0.108248           0.996619            1       True         45
# 118       NeuralNetFastAI_r111_BAG_L1   0.838188    accuracy       0.119952    10.702485                0.119952          10.702485            1      False         64
# 119            ExtraTrees_r178_BAG_L1   0.834951    accuracy       0.107904     0.976138                0.107904           0.976138            1       True         75
# 120          RandomForest_r127_BAG_L1   0.828479    accuracy       0.130433     1.080183                0.130433           1.080183            1       True         58
# 121           RandomForest_r15_BAG_L1   0.822006    accuracy       0.114082     1.053841                0.114082           1.053841            1       True         81
# 122       NeuralNetFastAI_r143_BAG_L1   0.812298    accuracy       0.117862    12.548135                0.117862          12.548135            1      False         41
# 123             KNeighborsDist_BAG_L1   0.799353    accuracy       0.007997     0.009001                0.007997           0.009001            1       True          2
# 124               LightGBM_r96_BAG_L1   0.796117    accuracy       0.011997     1.320595                0.011997           1.320595            1      False         19
# 125              ExtraTrees_r4_BAG_L1   0.718447    accuracy       0.146651     0.854699                0.146651           0.854699            1       True         66
# 126           RandomForest_r34_BAG_L1   0.705502    accuracy       0.080302     1.029795                0.080302           1.029795            1       True         60
# 127             KNeighborsUnif_BAG_L1   0.686084    accuracy       0.273122     0.006001                0.273122           0.006001            1       True          1
# 128        KNeighborsDist_BAG_L1_FULL        NaN    accuracy       0.007997     0.009001                0.007997           0.009001            1       True        130
# 129      RandomForest_r34_BAG_L1_FULL        NaN    accuracy       0.080302     1.029795                0.080302           1.029795            1       True        188
# 130      RandomForest_r16_BAG_L1_FULL        NaN    accuracy       0.089296     1.641133                0.089296           1.641133            1       True        222
# 131       ExtraTrees_r172_BAG_L1_FULL        NaN    accuracy       0.089851     0.890306                0.089851           0.890306            1       True        164
# 132       ExtraTrees_r126_BAG_L1_FULL        NaN    accuracy       0.091269     1.398372                0.091269           1.398372            1       True        227
# 133        ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       0.091988     0.868361                0.091988           0.868361            1       True        138
# 134     RandomForest_r195_BAG_L1_FULL        NaN    accuracy       0.092071     1.059180                0.092071           1.059180            1       True        154
# 135        ExtraTrees_r49_BAG_L1_FULL        NaN    accuracy       0.092549     0.927928                0.092549           0.927928            1       True        184
# 136        ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       0.094444     0.752913                0.094444           0.752913            1       True        137
# 137      RandomForestEntr_BAG_L1_FULL        NaN    accuracy       0.097988     0.793408                0.097988           0.793408            1       True        135
# 138     RandomForest_r166_BAG_L1_FULL        NaN    accuracy       0.104508     1.290366                0.104508           1.290366            1       True        204
# 139       ExtraTrees_r178_BAG_L1_FULL        NaN    accuracy       0.107904     0.976138                0.107904           0.976138            1       True        203
# 140      RandomForest_r39_BAG_L1_FULL        NaN    accuracy       0.108248     0.996619                0.108248           0.996619            1       True        173
# 141        ExtraTrees_r42_BAG_L1_FULL        NaN    accuracy       0.111981     0.881181                0.111981           0.881181            1       True        150
# 142      RandomForest_r15_BAG_L1_FULL        NaN    accuracy       0.114082     1.053841                0.114082           1.053841            1       True        209
# 143      RandomForestGini_BAG_L1_FULL        NaN    accuracy       0.123791     0.929276                0.123791           0.929276            1       True        134
# 144       ExtraTrees_r197_BAG_L1_FULL        NaN    accuracy       0.125427     1.071203                0.125427           1.071203            1       True        219
# 145     RandomForest_r127_BAG_L1_FULL        NaN    accuracy       0.130433     1.080183                0.130433           1.080183            1       True        186
# 146         ExtraTrees_r4_BAG_L1_FULL        NaN    accuracy       0.146651     0.854699                0.146651           0.854699            1       True        194
# 147        KNeighborsUnif_BAG_L1_FULL        NaN    accuracy       0.273122     0.006001                0.273122           0.006001            1       True        129
# 148           XGBoost_r98_BAG_L1_FULL        NaN    accuracy            NaN     0.150004                     NaN           0.150004            1       True        177
# 149           XGBoost_r95_BAG_L1_FULL        NaN    accuracy            NaN     0.266270                     NaN           0.266270            1       True        234
# 150           XGBoost_r89_BAG_L1_FULL        NaN    accuracy            NaN     0.150713                     NaN           0.150713            1       True        157
# 151           XGBoost_r49_BAG_L1_FULL        NaN    accuracy            NaN     0.052576                     NaN           0.052576            1       True        198
# 152           XGBoost_r34_BAG_L1_FULL        NaN    accuracy            NaN     0.159920                     NaN           0.159920            1       True        235
# 153           XGBoost_r33_BAG_L2_FULL        NaN    accuracy            NaN   135.060863                     NaN           0.368021            2       True        255
# 154           XGBoost_r33_BAG_L1_FULL        NaN    accuracy            NaN     0.109457                     NaN           0.109457            1       True        149
# 155           XGBoost_r31_BAG_L1_FULL        NaN    accuracy            NaN     0.090207                     NaN           0.090207            1       True        205
# 156           XGBoost_r22_BAG_L1_FULL        NaN    accuracy            NaN     0.061729                     NaN           0.061729            1       True        211
# 157          XGBoost_r194_BAG_L1_FULL        NaN    accuracy            NaN     0.134795                     NaN           0.134795            1       True        163
# 158               XGBoost_BAG_L2_FULL        NaN    accuracy            NaN   135.643083                     NaN           0.950241            2       True        246
# 159               XGBoost_BAG_L1_FULL        NaN    accuracy            NaN     0.111541                     NaN           0.111541            1       True        139
# 160          WeightedEnsemble_L3_FULL        NaN    accuracy            NaN   135.233480                     NaN           0.255630            3       True        256
# 161          WeightedEnsemble_L2_FULL        NaN    accuracy            NaN     5.826992                     NaN           0.441070            2       True        237
# 162      RandomForestGini_BAG_L2_FULL        NaN    accuracy            NaN   135.587177                0.110180           0.894334            2       True        241
# 163      RandomForestEntr_BAG_L2_FULL        NaN    accuracy            NaN   135.481966                0.099151           0.789124            2       True        242
# 164    NeuralNetTorch_r87_BAG_L1_FULL        NaN    accuracy            NaN     1.204119                     NaN           1.204119            1       True        200
# 165    NeuralNetTorch_r86_BAG_L1_FULL        NaN    accuracy            NaN     2.266884                     NaN           2.266884            1       True        160
# 166    NeuralNetTorch_r79_BAG_L2_FULL        NaN    accuracy            NaN   136.209159                     NaN           1.516316            2       True        250
# 167    NeuralNetTorch_r79_BAG_L1_FULL        NaN    accuracy            NaN     2.640136                     NaN           2.640136            1       True        143
# 168    NeuralNetTorch_r76_BAG_L1_FULL        NaN    accuracy            NaN     0.850072                     NaN           0.850072            1       True        218
# 169    NeuralNetTorch_r71_BAG_L1_FULL        NaN    accuracy            NaN     0.530556                     NaN           0.530556            1       True        201
# 170    NeuralNetTorch_r41_BAG_L1_FULL        NaN    accuracy            NaN     1.272016                     NaN           1.272016            1       True        176
# 171    NeuralNetTorch_r36_BAG_L1_FULL        NaN    accuracy            NaN     1.201473                     NaN           1.201473            1       True        228
# 172    NeuralNetTorch_r31_BAG_L1_FULL        NaN    accuracy            NaN     1.397951                     NaN           1.397951            1       True        193
# 173    NeuralNetTorch_r30_BAG_L1_FULL        NaN    accuracy            NaN     3.516393                     NaN           3.516393            1       True        158
# 174    NeuralNetTorch_r22_BAG_L1_FULL        NaN    accuracy            NaN     2.027862                     NaN           2.027862            1       True        148
# 175    NeuralNetTorch_r19_BAG_L1_FULL        NaN    accuracy            NaN     0.723167                     NaN           0.723167            1       True        233
# 176   NeuralNetTorch_r197_BAG_L1_FULL        NaN    accuracy            NaN     0.692954                     NaN           0.692954            1       True        182
# 177   NeuralNetTorch_r185_BAG_L1_FULL        NaN    accuracy            NaN     1.623149                     NaN           1.623149            1       True        206
# 178   NeuralNetTorch_r158_BAG_L1_FULL        NaN    accuracy            NaN     3.268129                     NaN           3.268129            1       True        179
# 179    NeuralNetTorch_r14_BAG_L1_FULL        NaN    accuracy            NaN     0.893440                     NaN           0.893440            1       True        167
# 180   NeuralNetTorch_r143_BAG_L1_FULL        NaN    accuracy            NaN     4.197430                     NaN           4.197430            1       True        190
# 181   NeuralNetTorch_r135_BAG_L1_FULL        NaN    accuracy            NaN     2.427917                     NaN           2.427917            1       True        225
# 182   NeuralNetTorch_r121_BAG_L1_FULL        NaN    accuracy            NaN     2.127547                     NaN           2.127547            1       True        220
# 183        NeuralNetTorch_BAG_L2_FULL        NaN    accuracy            NaN   136.464015                     NaN           1.771173            2       True        247
# 184        NeuralNetTorch_BAG_L1_FULL        NaN    accuracy            NaN     8.322222                     NaN           8.322222            1       True        140
# 185   NeuralNetFastAI_r95_BAG_L1_FULL        NaN    accuracy            NaN     0.556964                     NaN           0.556964            1       True        175
# 186   NeuralNetFastAI_r88_BAG_L1_FULL        NaN    accuracy            NaN     1.011675                     NaN           1.011675            1       True        196
# 187   NeuralNetFastAI_r69_BAG_L1_FULL        NaN    accuracy            NaN     0.452157                     NaN           0.452157            1       True        212
# 188   NeuralNetFastAI_r65_BAG_L1_FULL        NaN    accuracy            NaN     2.029235                     NaN           2.029235            1       True        195
# 189    NeuralNetFastAI_r4_BAG_L1_FULL        NaN    accuracy            NaN     0.370038                     NaN           0.370038            1       True        226
# 190   NeuralNetFastAI_r37_BAG_L1_FULL        NaN    accuracy            NaN     1.631754                     NaN           1.631754            1       True        181
# 191  NeuralNetFastAI_r194_BAG_L1_FULL        NaN    accuracy            NaN     0.376821                     NaN           0.376821            1       True        223
# 192  NeuralNetFastAI_r191_BAG_L2_FULL        NaN    accuracy            NaN   135.089262                     NaN           0.396419            2       True        252
# 193  NeuralNetFastAI_r191_BAG_L1_FULL        NaN    accuracy            NaN     0.660884                     NaN           0.660884            1       True        145
# 194  NeuralNetFastAI_r187_BAG_L1_FULL        NaN    accuracy            NaN     2.336237                     NaN           2.336237            1       True        232
# 195  NeuralNetFastAI_r172_BAG_L1_FULL        NaN    accuracy            NaN     1.378400                     NaN           1.378400            1       True        216
# 196  NeuralNetFastAI_r160_BAG_L1_FULL        NaN    accuracy            NaN     0.463435                     NaN           0.463435            1       True        207
# 197  NeuralNetFastAI_r156_BAG_L1_FULL        NaN    accuracy            NaN     1.781229                     NaN           1.781229            1       True        171
# 198  NeuralNetFastAI_r145_BAG_L1_FULL        NaN    accuracy            NaN     0.530789                     NaN           0.530789            1       True        156
# 199  NeuralNetFastAI_r143_BAG_L1_FULL        NaN    accuracy            NaN     2.113657                     NaN           2.113657            1       True        169
# 200  NeuralNetFastAI_r138_BAG_L1_FULL        NaN    accuracy            NaN     0.633491                     NaN           0.633491            1       True        214
# 201  NeuralNetFastAI_r134_BAG_L1_FULL        NaN    accuracy            NaN     2.805324                     NaN           2.805324            1       True        187
# 202  NeuralNetFastAI_r127_BAG_L1_FULL        NaN    accuracy            NaN     1.367372                     NaN           1.367372            1       True        221
# 203   NeuralNetFastAI_r11_BAG_L1_FULL        NaN    accuracy            NaN     0.685511                     NaN           0.685511            1       True        162
# 204  NeuralNetFastAI_r111_BAG_L1_FULL        NaN    accuracy            NaN     1.535478                     NaN           1.535478            1       True        192
# 205  NeuralNetFastAI_r103_BAG_L1_FULL        NaN    accuracy            NaN     0.475762                     NaN           0.475762            1       True        166
# 206  NeuralNetFastAI_r102_BAG_L1_FULL        NaN    accuracy            NaN     1.883408                     NaN           1.883408            1       True        152
# 207  NeuralNetFastAI_r100_BAG_L1_FULL        NaN    accuracy            NaN     2.270581                     NaN           2.270581            1       True        229
# 208       NeuralNetFastAI_BAG_L2_FULL        NaN    accuracy            NaN   135.031251                     NaN           0.338409            2       True        238
# 209       NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN     0.553046                     NaN           0.553046            1       True        131
# 210          LightGBM_r96_BAG_L2_FULL        NaN    accuracy            NaN   134.892302                     NaN           0.199460            2       True        254
# 211          LightGBM_r96_BAG_L1_FULL        NaN    accuracy            NaN     0.170387                     NaN           0.170387            1       True        147
# 212          LightGBM_r94_BAG_L1_FULL        NaN    accuracy            NaN     0.250534                     NaN           0.250534            1       True        189
# 213          LightGBM_r42_BAG_L1_FULL        NaN    accuracy            NaN     0.245793                     NaN           0.245793            1       True        236
# 214          LightGBM_r30_BAG_L1_FULL        NaN    accuracy            NaN     0.339627                     NaN           0.339627            1       True        197
# 215         LightGBM_r196_BAG_L1_FULL        NaN    accuracy            NaN     0.273940                     NaN           0.273940            1       True        172
# 216         LightGBM_r188_BAG_L1_FULL        NaN    accuracy            NaN     0.211234                     NaN           0.211234            1       True        155
# 217         LightGBM_r161_BAG_L1_FULL        NaN    accuracy            NaN     0.374811                     NaN           0.374811            1       True        168
# 218          LightGBM_r15_BAG_L1_FULL        NaN    accuracy            NaN     0.238578                     NaN           0.238578            1       True        178
# 219         LightGBM_r143_BAG_L1_FULL        NaN    accuracy            NaN     0.284951                     NaN           0.284951            1       True        185
# 220         LightGBM_r135_BAG_L1_FULL        NaN    accuracy            NaN     0.236071                     NaN           0.236071            1       True        210
# 221         LightGBM_r131_BAG_L2_FULL        NaN    accuracy            NaN   135.032098                     NaN           0.339255            2       True        251
# 222         LightGBM_r131_BAG_L1_FULL        NaN    accuracy            NaN     0.255024                     NaN           0.255024            1       True        144
# 223         LightGBM_r130_BAG_L1_FULL        NaN    accuracy            NaN     0.256606                     NaN           0.256606            1       True        159
# 224         LightGBM_r121_BAG_L1_FULL        NaN    accuracy            NaN     0.442788                     NaN           0.442788            1       True        215
# 225              LightGBM_BAG_L2_FULL        NaN    accuracy            NaN   134.977850                     NaN           0.285007            2       True        240
# 226              LightGBM_BAG_L1_FULL        NaN    accuracy            NaN     0.230474                     NaN           0.230474            1       True        133
# 227            LightGBMXT_BAG_L2_FULL        NaN    accuracy            NaN   134.908114                     NaN           0.215272            2       True        239
# 228            LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN     0.315647                     NaN           0.315647            1       True        132
# 229         LightGBMLarge_BAG_L2_FULL        NaN    accuracy            NaN   137.002494                     NaN           2.309651            2       True        248
# 230         LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN     0.577363                     NaN           0.577363            1       True        141
# 231        ExtraTreesGini_BAG_L2_FULL        NaN    accuracy            NaN   135.557623                0.096320           0.864781            2       True        244
# 232        ExtraTreesEntr_BAG_L2_FULL        NaN    accuracy            NaN   135.597642                0.141500           0.904800            2       True        245
# 233           CatBoost_r9_BAG_L2_FULL        NaN    accuracy            NaN   136.720813                     NaN           2.027970            2       True        253
# 234           CatBoost_r9_BAG_L1_FULL        NaN    accuracy            NaN     3.449926                     NaN           3.449926            1       True        146
# 235          CatBoost_r86_BAG_L1_FULL        NaN    accuracy            NaN     4.045059                     NaN           4.045059            1       True        180
# 236          CatBoost_r70_BAG_L1_FULL        NaN    accuracy            NaN     1.092469                     NaN           1.092469            1       True        170
# 237           CatBoost_r6_BAG_L1_FULL        NaN    accuracy            NaN     0.444209                     NaN           0.444209            1       True        213
# 238          CatBoost_r69_BAG_L1_FULL        NaN    accuracy            NaN     1.115503                     NaN           1.115503            1       True        165
# 239          CatBoost_r60_BAG_L1_FULL        NaN    accuracy            NaN     1.367292                     NaN           1.367292            1       True        208
# 240           CatBoost_r5_BAG_L1_FULL        NaN    accuracy            NaN     0.908599                     NaN           0.908599            1       True        199
# 241          CatBoost_r50_BAG_L1_FULL        NaN    accuracy            NaN     0.542881                     NaN           0.542881            1       True        161
# 242          CatBoost_r49_BAG_L1_FULL        NaN    accuracy            NaN     0.706340                     NaN           0.706340            1       True        183
# 243         CatBoost_r198_BAG_L1_FULL        NaN    accuracy            NaN     1.981085                     NaN           1.981085            1       True        231
# 244         CatBoost_r180_BAG_L1_FULL        NaN    accuracy            NaN     2.497076                     NaN           2.497076            1       True        217
# 245         CatBoost_r177_BAG_L2_FULL        NaN    accuracy            NaN   135.594569                     NaN           0.901726            2       True        249
# 246         CatBoost_r177_BAG_L1_FULL        NaN    accuracy            NaN     1.373999                     NaN           1.373999            1       True        142
# 247         CatBoost_r167_BAG_L1_FULL        NaN    accuracy            NaN     3.576395                     NaN           3.576395            1       True        174
# 248         CatBoost_r163_BAG_L1_FULL        NaN    accuracy            NaN     0.741415                     NaN           0.741415            1       True        230
# 249         CatBoost_r143_BAG_L1_FULL        NaN    accuracy            NaN     1.514340                     NaN           1.514340            1       True        202
# 250          CatBoost_r13_BAG_L1_FULL        NaN    accuracy            NaN     6.214239                     NaN           6.214239            1       True        153
# 251         CatBoost_r137_BAG_L1_FULL        NaN    accuracy            NaN     0.686034                     NaN           0.686034            1       True        151
# 252          CatBoost_r12_BAG_L1_FULL        NaN    accuracy            NaN     4.211051                     NaN           4.211051            1       True        224
# 253         CatBoost_r128_BAG_L1_FULL        NaN    accuracy            NaN     2.252322                     NaN           2.252322            1       True        191
# 254              CatBoost_BAG_L2_FULL        NaN    accuracy            NaN   135.710526                     NaN           1.017684            2       True        243
# 255              CatBoost_BAG_L1_FULL        NaN    accuracy            NaN     2.384999                     NaN           2.384999            1       True        136
# Number of models trained: 256
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_KNN'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# LightGBM_BAG_L2_FULL
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.60      0.40      0.48        15
# Exc L2-3 LINC00507 FREM3 superficial       0.64      0.88      0.74        26
#             Exc L2-4 LINC00507 GLP2R       0.00      0.00      0.00         5
#
#                             accuracy                           0.63        46
#                            macro avg       0.41      0.43      0.41        46
#                         weighted avg       0.56      0.63      0.58        46
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 6  9  0]
#  [ 3 23  0]
#  [ 1  4  0]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.339407                              0.464418
# 1           0.207652                              0.619546
# 2           0.240375                              0.535233
# 3           0.267309                              0.515105
# 4           0.215946                              0.621756
# 5           0.167669                              0.679573
# 6           0.300176                              0.543016
# 7           0.211383                              0.629714
# 8           0.215254                              0.580632
# 9           0.555338                              0.291752
# 10          0.571139                              0.301073
# 11          0.310191                              0.496484
# 12          0.516465                              0.359552
# 13          0.304800                              0.517235
# 14          0.217335                              0.577896
# 15          0.283838                              0.486018
# 16          0.259975                              0.583163
# 17          0.165483                              0.688254
# 18          0.252990                              0.565453
# 19          0.567421                              0.303603
# 20          0.304874                              0.394199
# 21          0.480729                              0.338395
# 22          0.197995                              0.637720
# 23          0.191283                              0.643502
# 24          0.524345                              0.292376
# 25          0.338856                              0.485020
# 26          0.612399                              0.199788
# 27          0.302322                              0.460359
# 28          0.222002                              0.602296
# 29          0.449854                              0.386515
# 30          0.595828                              0.221616
# 31          0.204841                              0.630969
# 32          0.216358                              0.621044
# 33          0.180308                              0.655625
# 34          0.255039                              0.583899
# 35          0.251811                              0.590730
# 36          0.430974                              0.398598
# 37          0.180336                              0.658281
# 38          0.174152                              0.672568
# 39          0.190918                              0.644237
# 40          0.286805                              0.434697
# 41          0.225068                              0.595791
# 42          0.208803                              0.630814
# 43          0.229166                              0.561422
# 44          0.200116                              0.627238
# 45          0.172204                              0.657238
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.196175
# 1                   0.172802
# 2                   0.224392
# 3                   0.217586
# 4                   0.162298
# 5                   0.152759
# 6                   0.156808
# 7                   0.158903
# 8                   0.204114
# 9                   0.152910
# 10                  0.127787
# 11                  0.193324
# 12                  0.123983
# 13                  0.177965
# 14                  0.204769
# 15                  0.230144
# 16                  0.156862
# 17                  0.146263
# 18                  0.181556
# 19                  0.128975
# 20                  0.300927
# 21                  0.180875
# 22                  0.164285
# 23                  0.165215
# 24                  0.183279
# 25                  0.176124
# 26                  0.187812
# 27                  0.237319
# 28                  0.175702
# 29                  0.163630
# 30                  0.182555
# 31                  0.164190
# 32                  0.162599
# 33                  0.164067
# 34                  0.161062
# 35                  0.157459
# 36                  0.170428
# 37                  0.161384
# 38                  0.153280
# 39                  0.164845
# 40                  0.278498
# 41                  0.179141
# 42                  0.160383
# 43                  0.209412
# 44                  0.172647
# 45                  0.170558

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	455.7s	= Expected runtime (91.14s per shuffle set)
# 	31.17s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# TS1_maxupstroke         0.026087  0.009722  0.001941  5  0.046105  0.006069
# TS2_peak                0.017391  0.018188  0.049650  5  0.054841 -0.020059
# TS1_avg_downstroke      0.017391  0.023814  0.088904  5  0.066425 -0.031642
# TS1_adp_index           0.013043  0.011907  0.035242  5  0.037560 -0.011473
# tau                     0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS2_avg_downstroke      0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS2_adp_index           0.004348  0.023814  0.352000  5  0.053381 -0.044686
# FAP_rheobase            0.004348  0.009722  0.186950  5  0.024366 -0.015670
# FAP_halfwidth           0.004348  0.018188  0.310654  5  0.041798 -0.033102
# FAP_maxdownstroke       0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS1_threshold           0.000000  0.015372  0.500000  5  0.031651 -0.031651
# FAP_num_APs             0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS2_threshold           0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS2_avg_upstroke        0.000000  0.026625  0.500000  5  0.054821 -0.054821
# FAP_maxupstroke         0.000000  0.026625  0.500000  5  0.054821 -0.054821
# FAP_avg_downstroke     -0.004348  0.018188  0.689346  5  0.033102 -0.041798
# TS1_maxdownstroke      -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# FAP_peak               -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# TS1_halfwidth          -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# TS1_rheobase           -0.004348  0.018188  0.689346  5  0.033102 -0.041798
# TS1_num_APs            -0.008696  0.019444  0.813050  5  0.031340 -0.048731
# vmbaseM                -0.008696  0.011907  0.911096  5  0.015821 -0.033212
# TS2_up_down_ratio      -0.008696  0.019444  0.813050  5  0.031340 -0.048731
# input_resistance       -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# TS2_maxupstroke        -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# TS1_up_down_ratio      -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# L23_depth_normalized   -0.013043  0.019444  0.896000  5  0.026992 -0.053079
# TS1_avg_upstroke       -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_up_down_ratio      -0.013043  0.019444  0.896000  5  0.026992 -0.053079
# TS2_maxdownstroke      -0.021739  0.000000  0.500000  5 -0.021739 -0.021739
# TS2_rheobase           -0.021739  0.034373  0.884900  5  0.049034 -0.092513
# VmatSag                -0.021739  0.015372  0.982945  5  0.009912 -0.053390
# sag                    -0.026087  0.028344  0.945650  5  0.032274 -0.084448
# FAP_threshold          -0.030435  0.029166  0.960020  5  0.029619 -0.090488
# TS2_num_APs            -0.034783  0.019444  0.991935  5  0.005253 -0.074818
# FAP_avg_upstroke       -0.047826  0.018188  0.997909  5 -0.010376 -0.085276

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# LightGBM_BAG_L2_FULL
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'accuracy': 0.6304347826086957,
#  'balanced_accuracy': 0.42820512820512824,
#  'mcc': 0.2679242057348946,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     6
#  Exc L2-3 LINC00507 FREM3 superficial                 3
#  Exc L2-4 LINC00507 GLP2R                             1
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                         9
#  Exc L2-3 LINC00507 FREM3 superficial                                    23
#  Exc L2-4 LINC00507 GLP2R                                                 4
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     0  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6,
#    'recall': 0.4,
#    'f1-score': 0.48,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.6388888888888888,
#    'recall': 0.8846153846153846,
#    'f1-score': 0.7419354838709677,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 0.0,
#    'recall': 0.0,
#    'f1-score': 0.0,
#    'support': 5.0},
#   'accuracy': 0.6304347826086957,
#   'macro avg': {'precision': 0.412962962962963,
#    'recall': 0.4282051282051282,
#    'f1-score': 0.4073118279569892,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.5567632850241546,
#    'recall': 0.6304347826086957,
#    'f1-score': 0.5758765778401121,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
#leaderboard.to_csv('leaderboard_medium.csv')
# Out:
#                                 model  score_test  score_val eval_metric  \
# 0    NeuralNetFastAI_r172_BAG_L1_FULL    0.760870        NaN    accuracy
# 1    NeuralNetFastAI_r194_BAG_L1_FULL    0.739130        NaN    accuracy
# 2    NeuralNetFastAI_r191_BAG_L2_FULL    0.739130        NaN    accuracy
# 3             CatBoost_r5_BAG_L1_FULL    0.717391        NaN    accuracy
# 4           LightGBM_r196_BAG_L1_FULL    0.717391        NaN    accuracy
# ..                                ...         ...        ...         ...
# 251        NeuralNetFastAI_r65_BAG_L1         NaN   0.844660    accuracy
# 252       NeuralNetFastAI_r160_BAG_L1         NaN   0.841424    accuracy
# 253       NeuralNetFastAI_r111_BAG_L1         NaN   0.838188    accuracy
# 254       NeuralNetFastAI_r143_BAG_L1         NaN   0.812298    accuracy
# 255               LightGBM_r96_BAG_L1         NaN   0.796117    accuracy
#
#      pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0          0.015213            NaN    1.378400                 0.015213
# 1          0.013590            NaN    0.376821                 0.013590
# 2          2.747278            NaN  135.089262                 0.016736
# 3          0.005623            NaN    0.908599                 0.005623
# 4          0.008718            NaN    0.273940                 0.008718
# ..              ...            ...         ...                      ...
# 251             NaN       0.107795   12.202846                      NaN
# 252             NaN       0.098507    9.792036                      NaN
# 253             NaN       0.119952   10.702485                      NaN
# 254             NaN       0.117862   12.548135                      NaN
# 255             NaN       0.011997    1.320595                      NaN
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                       NaN           1.378400            1       True
# 1                       NaN           0.376821            1       True
# 2                       NaN           0.396419            2       True
# 3                       NaN           0.908599            1       True
# 4                       NaN           0.273940            1       True
# ..                      ...                ...          ...        ...
# 251                0.107795          12.202846            1      False
# 252                0.098507           9.792036            1      False
# 253                0.119952          10.702485            1      False
# 254                0.117862          12.548135            1      False
# 255                0.011997           1.320595            1      False
#
#      fit_order
# 0          216
# 1          223
# 2          252
# 3          199
# 4          172
# ..         ...
# 251         67
# 252         79
# 253         64
# 254         41
# 255         19
#
# [256 rows x 13 columns]

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_13848\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.215953                              0.621776
# 1            0.212822                              0.624187
# 2            0.198933                              0.643389
# 3            0.189562                              0.646721
# 4            0.267574                              0.585454
# ..                ...                                   ...
# 204          0.277082                              0.474728
# 205          0.232687                              0.589155
# 206          0.200341                              0.640896
# 207          0.268510                              0.515822
# 208          0.184207                              0.661423
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.162271
# 1                    0.162991
# 2                    0.157678
# 3                    0.163717
# 4                    0.146972
# ..                        ...
# 204                  0.248189
# 205                  0.178158
# 206                  0.158763
# 207                  0.215668
# 208                  0.154370
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (157, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_BAG_L2_FULL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.550082
# [100]	valid_set's soft_log_loss: -0.470366
# [150]	valid_set's soft_log_loss: -0.47289
# [200]	valid_set's soft_log_loss: -0.481894
# [250]	valid_set's soft_log_loss: -0.512309
# [300]	valid_set's soft_log_loss: -0.55728
# 	Note: model has different eval_metric than default.
# 	-0.4672	 = Validation score   (-soft_log_loss)
# 	0.89s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# [350]	valid_set's soft_log_loss: -0.592166
# [400]	valid_set's soft_log_loss: -0.621022
# 	Note: model has different eval_metric than default.
# 	-0.4459	 = Validation score   (-soft_log_loss)
# 	0.93s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0791191	test: -1.0811044	best: -1.0811044 (0)	total: 3.1s	remaining: 8h 36m 54s
# 20:	learn: -0.8415166	test: -0.8264982	best: -0.8264982 (20)	total: 3.46s	remaining: 27m 26s
# 40:	learn: -0.7465806	test: -0.7049759	best: -0.7049759 (40)	total: 3.81s	remaining: 15m 25s
# 60:	learn: -0.6886775	test: -0.6296617	best: -0.6296617 (60)	total: 4.15s	remaining: 11m 16s
# 80:	learn: -0.6570857	test: -0.5987729	best: -0.5987729 (80)	total: 4.53s	remaining: 9m 15s
# 100:	learn: -0.6281817	test: -0.5705781	best: -0.5699022 (98)	total: 4.89s	remaining: 7m 59s
# 120:	learn: -0.6017815	test: -0.5475601	best: -0.5475601 (120)	total: 5.22s	remaining: 7m 6s
# 140:	learn: -0.5832096	test: -0.5331487	best: -0.5331487 (140)	total: 5.54s	remaining: 6m 27s
# 160:	learn: -0.5667034	test: -0.5191755	best: -0.5191755 (160)	total: 5.9s	remaining: 6m
# 180:	learn: -0.5548632	test: -0.5060828	best: -0.5060828 (180)	total: 6.25s	remaining: 5m 39s
# 200:	learn: -0.5437464	test: -0.4973751	best: -0.4973751 (200)	total: 6.58s	remaining: 5m 21s
# 220:	learn: -0.5338459	test: -0.4906801	best: -0.4901667 (219)	total: 6.95s	remaining: 5m 7s
# 240:	learn: -0.5252895	test: -0.4795342	best: -0.4795342 (240)	total: 7.34s	remaining: 4m 57s
# 260:	learn: -0.5175020	test: -0.4716407	best: -0.4716407 (260)	total: 7.7s	remaining: 4m 47s
# 280:	learn: -0.5116959	test: -0.4655734	best: -0.4655734 (280)	total: 8.04s	remaining: 4m 37s
# 300:	learn: -0.5061389	test: -0.4628193	best: -0.4628193 (300)	total: 8.43s	remaining: 4m 31s
# 320:	learn: -0.5009619	test: -0.4595722	best: -0.4592967 (319)	total: 8.76s	remaining: 4m 24s
# 340:	learn: -0.4964726	test: -0.4562361	best: -0.4561628 (339)	total: 9.07s	remaining: 4m 16s
# 360:	learn: -0.4932627	test: -0.4526974	best: -0.4525070 (359)	total: 9.44s	remaining: 4m 12s
# 380:	learn: -0.4899534	test: -0.4511620	best: -0.4502144 (371)	total: 9.85s	remaining: 4m 8s
# 400:	learn: -0.4867758	test: -0.4489581	best: -0.4487898 (394)	total: 10.2s	remaining: 4m 3s
# 420:	learn: -0.4841756	test: -0.4451424	best: -0.4450266 (418)	total: 10.5s	remaining: 3m 58s
# 440:	learn: -0.4817061	test: -0.4440956	best: -0.4440956 (440)	total: 10.9s	remaining: 3m 55s
# 460:	learn: -0.4790105	test: -0.4422337	best: -0.4422337 (460)	total: 11.2s	remaining: 3m 51s
# 480:	learn: -0.4767686	test: -0.4414530	best: -0.4412811 (478)	total: 11.5s	remaining: 3m 48s
# 500:	learn: -0.4744075	test: -0.4433854	best: -0.4412811 (478)	total: 11.9s	remaining: 3m 45s
# 520:	learn: -0.4725699	test: -0.4427312	best: -0.4412811 (478)	total: 12.2s	remaining: 3m 42s
# 540:	learn: -0.4707760	test: -0.4429876	best: -0.4412811 (478)	total: 12.6s	remaining: 3m 39s
# 560:	learn: -0.4691664	test: -0.4432781	best: -0.4412811 (478)	total: 12.9s	remaining: 3m 36s
# 580:	learn: -0.4676327	test: -0.4418581	best: -0.4412811 (478)	total: 13.2s	remaining: 3m 34s
# 600:	learn: -0.4661372	test: -0.4411610	best: -0.4409014 (598)	total: 13.6s	remaining: 3m 32s
# 620:	learn: -0.4648204	test: -0.4396669	best: -0.4396669 (620)	total: 13.9s	remaining: 3m 30s
# 640:	learn: -0.4637174	test: -0.4410110	best: -0.4396669 (620)	total: 14.3s	remaining: 3m 28s
# 660:	learn: -0.4625743	test: -0.4420611	best: -0.4396669 (620)	total: 14.7s	remaining: 3m 27s
# 680:	learn: -0.4613175	test: -0.4416311	best: -0.4396669 (620)	total: 15s	remaining: 3m 24s
# 700:	learn: -0.4602264	test: -0.4424516	best: -0.4396669 (620)	total: 15.3s	remaining: 3m 23s
# 720:	learn: -0.4590533	test: -0.4433386	best: -0.4396669 (620)	total: 15.7s	remaining: 3m 21s
# 740:	learn: -0.4579798	test: -0.4447664	best: -0.4396669 (620)	total: 16s	remaining: 3m 19s
# 760:	learn: -0.4570292	test: -0.4447089	best: -0.4396669 (620)	total: 16.4s	remaining: 3m 18s
# 780:	learn: -0.4562339	test: -0.4460996	best: -0.4396669 (620)	total: 16.8s	remaining: 3m 17s
# 800:	learn: -0.4554368	test: -0.4466072	best: -0.4396669 (620)	total: 17.1s	remaining: 3m 16s
# 820:	learn: -0.4546372	test: -0.4480964	best: -0.4396669 (620)	total: 17.4s	remaining: 3m 14s
# 840:	learn: -0.4538893	test: -0.4482217	best: -0.4396669 (620)	total: 17.8s	remaining: 3m 13s
# 860:	learn: -0.4531645	test: -0.4479293	best: -0.4396669 (620)	total: 18.1s	remaining: 3m 12s
# 880:	learn: -0.4524455	test: -0.4480163	best: -0.4396669 (620)	total: 18.5s	remaining: 3m 11s
# 900:	learn: -0.4517735	test: -0.4478715	best: -0.4396669 (620)	total: 18.8s	remaining: 3m 10s
# 	Note: model has different eval_metric than default.
# 	-0.4397	 = Validation score   (-soft_log_loss)
# 	25.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# 920:	learn: -0.4512327	test: -0.4495647	best: -0.4396669 (620)	total: 19.2s	remaining: 3m 9s
#
# bestTest = -0.4396668567
# bestIteration = 620
#
# Shrink model to first 621 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5583	 = Validation score   (-soft_log_loss)
# 	3.2s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.571, 'RandomForestMSE_DSTL': 0.333, 'LightGBM_DSTL': 0.095}
# 	Note: model has different eval_metric than default.
# 	-0.43	 = Validation score   (-soft_log_loss)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL   0.838710  soft_log_loss       0.001000   0.892298                0.001000           0.892298            1       True        257
# 1             CatBoost_DSTL   0.822581  soft_log_loss       0.002001  25.464130                0.002001          25.464130            1       True        259
# 2  WeightedEnsemble_L2_DSTL   0.822581  soft_log_loss       0.063238  27.305897                0.000000           0.023508            2       True        261
# 3      RandomForestMSE_DSTL   0.806452  soft_log_loss       0.060237   0.925961                0.060237           0.925961            1       True        258
# 4       NeuralNetTorch_DSTL   0.758065  soft_log_loss       0.017658   3.202752                0.017658           3.202752            1       True        260
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                                model  score_test  score_val eval_metric  \
# 153                  LightGBM_BAG_L2         NaN   0.941748    accuracy
# 154              WeightedEnsemble_L3         NaN   0.941748    accuracy
# 155             LightGBMLarge_BAG_L2         NaN   0.941748    accuracy
# 156             LightGBM_r131_BAG_L2         NaN   0.938511    accuracy
# 157                LightGBMXT_BAG_L2         NaN   0.935275    accuracy
# ..                               ...         ...        ...         ...
# 146   NeuralNetTorch_r31_BAG_L1_FULL    0.478261        NaN    accuracy
# 147  NeuralNetTorch_r158_BAG_L1_FULL    0.478261        NaN    accuracy
# 148   NeuralNetTorch_r79_BAG_L1_FULL    0.434783        NaN    accuracy
# 149       KNeighborsUnif_BAG_L1_FULL    0.391304        NaN    accuracy
# 150       KNeighborsDist_BAG_L1_FULL    0.391304        NaN    accuracy
#
#      pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 153             NaN       9.456595  1324.130895                      NaN
# 154             NaN       9.457593  1324.386525                      NaN
# 155             NaN       9.471454  1348.143882                      NaN
# 156             NaN       9.457379  1326.770023                      NaN
# 157             NaN       9.461252  1321.034631                      NaN
# ..              ...            ...          ...                      ...
# 146        0.017530            NaN     1.397951                 0.017530
# 147        0.022998            NaN     3.268129                 0.022998
# 148        0.021550            NaN     2.640136                 0.021550
# 149        0.002999       0.273122     0.006001                 0.002999
# 150        0.004003       0.007997     0.009001                 0.004003
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 153                0.028830           7.703694            2      False
# 154                0.000998           0.255630            3      False
# 155                0.043688          31.716681            2      False
# 156                0.029613          10.342822            2      False
# 157                0.033487           4.607430            2      False
# ..                      ...                ...          ...        ...
# 146                     NaN           1.397951            1       True
# 147                     NaN           3.268129            1       True
# 148                     NaN           2.640136            1       True
# 149                0.273122           0.006001            1       True
# 150                0.007997           0.009001            1       True
#
#      fit_order
# 153        112
# 154        128
# 155        120
# 156        123
# 157        111
# ..         ...
# 146        193
# 147        179
# 148        143
# 149        129
# 150        130
#
# [261 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7391304347826086
# Evaluations on test data:
# {
#     "accuracy": 0.7391304347826086,
#     "balanced_accuracy": 0.7264957264957266,
#     "mcc": 0.5493380164557105
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.7272727272727273,
#         "recall": 0.5333333333333333,
#         "f1-score": 0.6153846153846154,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8148148148148148,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8301886792452831,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.8,
#         "f1-score": 0.6153846153846154,
#         "support": 5.0
#     },
#     "accuracy": 0.7391304347826086,
#     "macro avg": {
#         "precision": 0.680695847362514,
#         "recall": 0.7264957264957266,
#         "f1-score": 0.6869859700048379,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7520494803103499,
#         "recall": 0.7391304347826086,
#         "f1-score": 0.7367956080015147,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7391304347826086, 'balanced_accuracy': 0.7264957264957266, 'mcc': 0.5493380164557105, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     8
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             2
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.7272727272727273, 'recall': 0.5333333333333333, 'f1-score': 0.6153846153846154, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8148148148148148, 'recall': 0.8461538461538461, 'f1-score': 0.8301886792452831, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.8, 'f1-score': 0.6153846153846154, 'support': 5.0}, 'accuracy': 0.7391304347826086, 'macro avg': {'precision': 0.680695847362514, 'recall': 0.7264957264957266, 'f1-score': 0.6869859700048379, 'support': 46.0}, 'weighted avg': {'precision': 0.7520494803103499, 'recall': 0.7391304347826086, 'f1-score': 0.7367956080015147, 'support': 46.0}}}

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7391304347826086
# Evaluations on test data:
# {
#     "accuracy": 0.7391304347826086,
#     "balanced_accuracy": 0.7170940170940172,
#     "mcc": 0.5327844981851296
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.7,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.56,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7666666666666667,
#         "recall": 0.8846153846153846,
#         "f1-score": 0.8214285714285714,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.6666666666666666,
#         "recall": 0.8,
#         "f1-score": 0.7272727272727273,
#         "support": 5.0
#     },
#     "accuracy": 0.7391304347826086,
#     "macro avg": {
#         "precision": 0.7111111111111111,
#         "recall": 0.7170940170940172,
#         "f1-score": 0.7029004329004329,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7340579710144928,
#         "recall": 0.7391304347826086,
#         "f1-score": 0.7259457933370976,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7391304347826086, 'balanced_accuracy': 0.7170940170940172, 'mcc': 0.5327844981851296, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         7
# Exc L2-3 LINC00507 FREM3 superficial                                    23
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             1
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.7, 'recall': 0.4666666666666667, 'f1-score': 0.56, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7666666666666667, 'recall': 0.8846153846153846, 'f1-score': 0.8214285714285714, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.6666666666666666, 'recall': 0.8, 'f1-score': 0.7272727272727273, 'support': 5.0}, 'accuracy': 0.7391304347826086, 'macro avg': {'precision': 0.7111111111111111, 'recall': 0.7170940170940172, 'f1-score': 0.7029004329004329, 'support': 46.0}, 'weighted avg': {'precision': 0.7340579710144928, 'recall': 0.7391304347826086, 'f1-score': 0.7259457933370976, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.73      0.53      0.62        15
# Exc L2-3 LINC00507 FREM3 superficial       0.81      0.85      0.83        26
#             Exc L2-4 LINC00507 GLP2R       0.50      0.80      0.62         5
#
#                             accuracy                           0.74        46
#                            macro avg       0.68      0.73      0.69        46
#                         weighted avg       0.75      0.74      0.74        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.519267
# [100]	valid_set's soft_log_loss: -0.450362
# [150]	valid_set's soft_log_loss: -0.453484
# [200]	valid_set's soft_log_loss: -0.479439
# [250]	valid_set's soft_log_loss: -0.529019
# [300]	valid_set's soft_log_loss: -0.561235
# 	Note: model has different eval_metric than default.
# 	-0.4482	 = Validation score   (-soft_log_loss)
# 	0.93s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# [350]	valid_set's soft_log_loss: -0.581434
# 	Note: model has different eval_metric than default.
# 	-0.4458	 = Validation score   (-soft_log_loss)
# 	0.79s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0753668	test: -1.0720177	best: -1.0720177 (0)	total: 546ms	remaining: 1h 31m
# 20:	learn: -0.8260677	test: -0.8227342	best: -0.8227342 (20)	total: 904ms	remaining: 7m 9s
# 40:	learn: -0.7131627	test: -0.7063503	best: -0.7063503 (40)	total: 1.25s	remaining: 5m 3s
# 60:	learn: -0.6506102	test: -0.6297019	best: -0.6297019 (60)	total: 1.58s	remaining: 4m 17s
# 80:	learn: -0.6101633	test: -0.5900936	best: -0.5900936 (80)	total: 1.9s	remaining: 3m 52s
# 100:	learn: -0.5748183	test: -0.5575660	best: -0.5575660 (100)	total: 2.23s	remaining: 3m 38s
# 120:	learn: -0.5468639	test: -0.5289625	best: -0.5289625 (120)	total: 2.54s	remaining: 3m 27s
# 140:	learn: -0.5271820	test: -0.5114980	best: -0.5114980 (140)	total: 2.85s	remaining: 3m 19s
# 160:	learn: -0.5095699	test: -0.4954203	best: -0.4954203 (160)	total: 3.16s	remaining: 3m 13s
# 180:	learn: -0.4936779	test: -0.4845388	best: -0.4845388 (180)	total: 3.51s	remaining: 3m 10s
# 200:	learn: -0.4795520	test: -0.4790849	best: -0.4790849 (200)	total: 3.86s	remaining: 3m 8s
# 220:	learn: -0.4681593	test: -0.4693921	best: -0.4693921 (220)	total: 4.23s	remaining: 3m 7s
# 240:	learn: -0.4592506	test: -0.4694009	best: -0.4683221 (231)	total: 4.57s	remaining: 3m 4s
# 260:	learn: -0.4521039	test: -0.4591597	best: -0.4591597 (260)	total: 4.86s	remaining: 3m 1s
# 280:	learn: -0.4454756	test: -0.4560408	best: -0.4559743 (279)	total: 5.18s	remaining: 2m 59s
# 300:	learn: -0.4387992	test: -0.4557913	best: -0.4543328 (293)	total: 5.5s	remaining: 2m 57s
# 320:	learn: -0.4333087	test: -0.4512437	best: -0.4508285 (318)	total: 5.84s	remaining: 2m 56s
# 340:	learn: -0.4288921	test: -0.4483249	best: -0.4483249 (340)	total: 6.2s	remaining: 2m 55s
# 360:	learn: -0.4244621	test: -0.4446048	best: -0.4445278 (357)	total: 6.57s	remaining: 2m 55s
# 380:	learn: -0.4211341	test: -0.4402197	best: -0.4402197 (380)	total: 6.91s	remaining: 2m 54s
# 400:	learn: -0.4176165	test: -0.4365050	best: -0.4365050 (400)	total: 7.21s	remaining: 2m 52s
# 420:	learn: -0.4143272	test: -0.4375679	best: -0.4363530 (405)	total: 7.52s	remaining: 2m 51s
# 440:	learn: -0.4112304	test: -0.4323315	best: -0.4318813 (436)	total: 7.83s	remaining: 2m 49s
# 460:	learn: -0.4083611	test: -0.4315090	best: -0.4315090 (460)	total: 8.16s	remaining: 2m 48s
# 480:	learn: -0.4058960	test: -0.4315323	best: -0.4304416 (467)	total: 8.52s	remaining: 2m 48s
# 500:	learn: -0.4032122	test: -0.4296640	best: -0.4296640 (500)	total: 8.85s	remaining: 2m 47s
# 520:	learn: -0.4008109	test: -0.4298990	best: -0.4294956 (514)	total: 9.19s	remaining: 2m 47s
# 540:	learn: -0.3989091	test: -0.4304186	best: -0.4294044 (526)	total: 9.52s	remaining: 2m 46s
# 560:	learn: -0.3969447	test: -0.4305557	best: -0.4294044 (526)	total: 9.81s	remaining: 2m 45s
# 580:	learn: -0.3953938	test: -0.4322786	best: -0.4294044 (526)	total: 10.1s	remaining: 2m 44s
# 600:	learn: -0.3938523	test: -0.4332217	best: -0.4294044 (526)	total: 10.5s	remaining: 2m 43s
# 620:	learn: -0.3923395	test: -0.4318323	best: -0.4294044 (526)	total: 10.8s	remaining: 2m 43s
# 640:	learn: -0.3909291	test: -0.4322090	best: -0.4294044 (526)	total: 11.2s	remaining: 2m 43s
# 660:	learn: -0.3895417	test: -0.4334360	best: -0.4294044 (526)	total: 11.5s	remaining: 2m 42s
# 680:	learn: -0.3882803	test: -0.4349459	best: -0.4294044 (526)	total: 11.8s	remaining: 2m 41s
# 700:	learn: -0.3871612	test: -0.4357805	best: -0.4294044 (526)	total: 12.2s	remaining: 2m 41s
# 720:	learn: -0.3860594	test: -0.4353599	best: -0.4294044 (526)	total: 12.5s	remaining: 2m 41s
# 740:	learn: -0.3850810	test: -0.4361131	best: -0.4294044 (526)	total: 12.9s	remaining: 2m 41s
# 760:	learn: -0.3842291	test: -0.4356763	best: -0.4294044 (526)	total: 13.2s	remaining: 2m 40s
# 780:	learn: -0.3832985	test: -0.4373921	best: -0.4294044 (526)	total: 13.6s	remaining: 2m 40s
# 800:	learn: -0.3825211	test: -0.4381647	best: -0.4294044 (526)	total: 13.9s	remaining: 2m 40s
# 	Note: model has different eval_metric than default.
# 	-0.4294	 = Validation score   (-soft_log_loss)
# 	15.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# 820:	learn: -0.3817020	test: -0.4399559	best: -0.4294044 (526)	total: 14.2s	remaining: 2m 39s
#
# bestTest = -0.4294043707
# bestIteration = 526
#
# Shrink model to first 527 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5443	 = Validation score   (-soft_log_loss)
# 	2.81s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.652, 'RandomForestMSE_2_DSTL': 0.348}
# 	Note: model has different eval_metric than default.
# 	-0.4212	 = Validation score   (-soft_log_loss)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   0.854839  soft_log_loss       0.000843  15.095343                0.000843          15.095343            1       True        264
# 1             LightGBM_2_DSTL   0.854839  soft_log_loss       0.001002   0.934631                0.001002           0.934631            1       True        262
# 2  WeightedEnsemble_2_L2_DSTL   0.838710  soft_log_loss       0.052179  15.908442                0.000000           0.023408            2       True        266
# 3       NeuralNetTorch_2_DSTL   0.806452  soft_log_loss       0.018616   2.814386                0.018616           2.814386            1       True        265
# 4      RandomForestMSE_2_DSTL   0.806452  soft_log_loss       0.051336   0.789690                0.051336           0.789690            1       True        263
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                                 model  score_test  score_val    eval_metric  \
# 0    NeuralNetFastAI_r172_BAG_L1_FULL     0.76087        NaN       accuracy
# 1                       LightGBM_DSTL     0.73913   0.838710  soft_log_loss
# 4            WeightedEnsemble_L2_DSTL     0.73913   0.822581  soft_log_loss
# 3                RandomForestMSE_DSTL     0.73913   0.806452  soft_log_loss
# 2    NeuralNetFastAI_r194_BAG_L1_FULL     0.73913        NaN       accuracy
# ..                                ...         ...        ...            ...
# 261        NeuralNetFastAI_r65_BAG_L1         NaN   0.844660       accuracy
# 262       NeuralNetFastAI_r160_BAG_L1         NaN   0.841424       accuracy
# 263       NeuralNetFastAI_r111_BAG_L1         NaN   0.838188       accuracy
# 264       NeuralNetFastAI_r143_BAG_L1         NaN   0.812298       accuracy
# 265               LightGBM_r96_BAG_L1         NaN   0.796117       accuracy
#
#      pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0          0.014999            NaN   1.378400                 0.014999
# 1          0.007624       0.001000   0.892298                 0.007624
# 4          0.141210       0.063238  27.305897                 0.003001
# 3          0.122025       0.060237   0.925961                 0.122025
# 2          0.014328            NaN   0.376821                 0.014328
# ..              ...            ...        ...                      ...
# 261             NaN       0.107795  12.202846                      NaN
# 262             NaN       0.098507   9.792036                      NaN
# 263             NaN       0.119952  10.702485                      NaN
# 264             NaN       0.117862  12.548135                      NaN
# 265             NaN       0.011997   1.320595                      NaN
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                       NaN           1.378400            1       True
# 1                  0.001000           0.892298            1       True
# 4                  0.000000           0.023508            2       True
# 3                  0.060237           0.925961            1       True
# 2                       NaN           0.376821            1       True
# ..                      ...                ...          ...        ...
# 261                0.107795          12.202846            1      False
# 262                0.098507           9.792036            1      False
# 263                0.119952          10.702485            1      False
# 264                0.117862          12.548135            1      False
# 265                0.011997           1.320595            1      False
#
#      fit_order
# 0          216
# 1          257
# 4          261
# 3          258
# 2          223
# ..         ...
# 261         67
# 262         79
# 263         64
# 264         41
# 265         19
#
# [266 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_2_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7042735042735043,
#     "mcc": 0.5108759939945801
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6363636363636364,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5384615384615384,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8148148148148148,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8301886792452831,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.8,
#         "f1-score": 0.6153846153846154,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6503928170594837,
#         "recall": 0.7042735042735043,
#         "f1-score": 0.6613449443638123,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7224052115356463,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7117119959613807,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7042735042735043, 'mcc': 0.5108759939945801, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             3
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6363636363636364, 'recall': 0.4666666666666667, 'f1-score': 0.5384615384615384, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8148148148148148, 'recall': 0.8461538461538461, 'f1-score': 0.8301886792452831, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.8, 'f1-score': 0.6153846153846154, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6503928170594837, 'recall': 0.7042735042735043, 'f1-score': 0.6613449443638123, 'support': 46.0}, 'weighted avg': {'precision': 0.7224052115356463, 'recall': 0.717391304347826, 'f1-score': 0.7117119959613807, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'CatBoost_r177_BAG_L1', 'NeuralNetTorch_r79_BAG_L1', 'LightGBM_r131_BAG_L1', 'NeuralNetFastAI_r191_BAG_L1', 'CatBoost_r9_BAG_L1', 'LightGBM_r96_BAG_L1', 'NeuralNetTorch_r22_BAG_L1', 'XGBoost_r33_BAG_L1', 'ExtraTrees_r42_BAG_L1', 'CatBoost_r137_BAG_L1', 'NeuralNetFastAI_r102_BAG_L1', 'CatBoost_r13_BAG_L1', 'RandomForest_r195_BAG_L1', 'LightGBM_r188_BAG_L1', 'NeuralNetFastAI_r145_BAG_L1', 'XGBoost_r89_BAG_L1', 'NeuralNetTorch_r30_BAG_L1', 'LightGBM_r130_BAG_L1', 'NeuralNetTorch_r86_BAG_L1', 'CatBoost_r50_BAG_L1', 'NeuralNetFastAI_r11_BAG_L1', 'XGBoost_r194_BAG_L1', 'ExtraTrees_r172_BAG_L1', 'CatBoost_r69_BAG_L1', 'NeuralNetFastAI_r103_BAG_L1', 'NeuralNetTorch_r14_BAG_L1', 'LightGBM_r161_BAG_L1', 'NeuralNetFastAI_r143_BAG_L1', 'CatBoost_r70_BAG_L1', 'NeuralNetFastAI_r156_BAG_L1', 'LightGBM_r196_BAG_L1', 'RandomForest_r39_BAG_L1', 'CatBoost_r167_BAG_L1', 'NeuralNetFastAI_r95_BAG_L1', 'NeuralNetTorch_r41_BAG_L1', 'XGBoost_r98_BAG_L1', 'LightGBM_r15_BAG_L1', 'NeuralNetTorch_r158_BAG_L1', 'CatBoost_r86_BAG_L1', 'NeuralNetFastAI_r37_BAG_L1', 'NeuralNetTorch_r197_BAG_L1', 'CatBoost_r49_BAG_L1', 'ExtraTrees_r49_BAG_L1', 'LightGBM_r143_BAG_L1', 'RandomForest_r127_BAG_L1', 'NeuralNetFastAI_r134_BAG_L1', 'RandomForest_r34_BAG_L1', 'LightGBM_r94_BAG_L1', 'NeuralNetTorch_r143_BAG_L1', 'CatBoost_r128_BAG_L1', 'NeuralNetFastAI_r111_BAG_L1', 'NeuralNetTorch_r31_BAG_L1', 'ExtraTrees_r4_BAG_L1', 'NeuralNetFastAI_r65_BAG_L1', 'NeuralNetFastAI_r88_BAG_L1', 'LightGBM_r30_BAG_L1', 'XGBoost_r49_BAG_L1', 'CatBoost_r5_BAG_L1', 'NeuralNetTorch_r87_BAG_L1', 'NeuralNetTorch_r71_BAG_L1', 'CatBoost_r143_BAG_L1', 'ExtraTrees_r178_BAG_L1', 'RandomForest_r166_BAG_L1', 'XGBoost_r31_BAG_L1', 'NeuralNetTorch_r185_BAG_L1', 'NeuralNetFastAI_r160_BAG_L1', 'CatBoost_r60_BAG_L1', 'RandomForest_r15_BAG_L1', 'LightGBM_r135_BAG_L1', 'XGBoost_r22_BAG_L1', 'NeuralNetFastAI_r69_BAG_L1', 'CatBoost_r6_BAG_L1', 'NeuralNetFastAI_r138_BAG_L1', 'LightGBM_r121_BAG_L1', 'NeuralNetFastAI_r172_BAG_L1', 'CatBoost_r180_BAG_L1', 'NeuralNetTorch_r76_BAG_L1', 'ExtraTrees_r197_BAG_L1', 'NeuralNetTorch_r121_BAG_L1', 'NeuralNetFastAI_r127_BAG_L1', 'RandomForest_r16_BAG_L1', 'NeuralNetFastAI_r194_BAG_L1', 'CatBoost_r12_BAG_L1', 'NeuralNetTorch_r135_BAG_L1', 'NeuralNetFastAI_r4_BAG_L1', 'ExtraTrees_r126_BAG_L1', 'NeuralNetTorch_r36_BAG_L1', 'NeuralNetFastAI_r100_BAG_L1', 'CatBoost_r163_BAG_L1', 'CatBoost_r198_BAG_L1', 'NeuralNetFastAI_r187_BAG_L1', 'NeuralNetTorch_r19_BAG_L1', 'XGBoost_r95_BAG_L1', 'XGBoost_r34_BAG_L1', 'LightGBM_r42_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'CatBoost_r177_BAG_L2', 'NeuralNetTorch_r79_BAG_L2', 'LightGBM_r131_BAG_L2', 'NeuralNetFastAI_r191_BAG_L2', 'CatBoost_r9_BAG_L2', 'LightGBM_r96_BAG_L2', 'XGBoost_r33_BAG_L2', 'WeightedEnsemble_L3', 'KNeighborsUnif_BAG_L1_FULL', 'KNeighborsDist_BAG_L1_FULL', 'NeuralNetFastAI_BAG_L1_FULL', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'RandomForestGini_BAG_L1_FULL', 'RandomForestEntr_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'ExtraTreesGini_BAG_L1_FULL', 'ExtraTreesEntr_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'NeuralNetTorch_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'CatBoost_r177_BAG_L1_FULL', 'NeuralNetTorch_r79_BAG_L1_FULL', 'LightGBM_r131_BAG_L1_FULL', 'NeuralNetFastAI_r191_BAG_L1_FULL', 'CatBoost_r9_BAG_L1_FULL', 'LightGBM_r96_BAG_L1_FULL', 'NeuralNetTorch_r22_BAG_L1_FULL', 'XGBoost_r33_BAG_L1_FULL', 'ExtraTrees_r42_BAG_L1_FULL', 'CatBoost_r137_BAG_L1_FULL', 'NeuralNetFastAI_r102_ ...

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
