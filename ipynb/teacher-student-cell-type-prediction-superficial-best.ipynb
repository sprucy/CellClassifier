# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='best_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=5
# stacking的级别
num_stack_levels=2
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 3,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       9.77 GB / 15.92 GB (61.4%)
# Disk Space Avail:   311.81 GB / 931.51 GB (33.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 09:30:41,344	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "models\Teacher\best_quality-20241101-093036\ds_sub_fit\sub_fit_ho"
# (_dystack pid=19788) Running DyStack sub-fit ...
# (_dystack pid=19788) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=19788) AutoGluon will save models to "models\Teacher\best_quality-20241101-093036\ds_sub_fit\sub_fit_ho"
# (_dystack pid=19788) Train Data Rows:    274
# (_dystack pid=19788) Train Data Columns: 36
# (_dystack pid=19788) Label Column:       label
# (_dystack pid=19788) Problem Type:       multiclass
# (_dystack pid=19788) Preprocessing data ...
# (_dystack pid=19788) Train Data Class Count: 3
# (_dystack pid=19788) Using Feature Generators to preprocess the data ...
# (_dystack pid=19788) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=19788) 	Available Memory:                    9473.93 MB
# (_dystack pid=19788) 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=19788) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=19788) 	Stage 1 Generators:
# (_dystack pid=19788) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=19788) 	Stage 2 Generators:
# (_dystack pid=19788) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=19788) 	Stage 3 Generators:
# (_dystack pid=19788) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=19788) 	Stage 4 Generators:
# (_dystack pid=19788) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=19788) 	Stage 5 Generators:
# (_dystack pid=19788) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=19788) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=19788) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=19788) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=19788) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=19788) 	0.0s = Fit runtime
# (_dystack pid=19788) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=19788) 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=19788) Data preprocessing and feature engineering runtime = 0.07s ...
# (_dystack pid=19788) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=19788) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=19788) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=19788) User-specified model hyperparameters to be fit:
# (_dystack pid=19788) {
# (_dystack pid=19788) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=19788) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=19788) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=19788) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=19788) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=19788) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=19788) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=19788) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=19788) }
# (_dystack pid=19788) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=19788) Fitting 110 L1 models ...
# (_dystack pid=19788) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.53s of the 892.02s of remaining time.
# (_dystack pid=19788) 	0.6861	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.0s	 = Training   runtime
# (_dystack pid=19788) 	0.1s	 = Validation runtime
# (_dystack pid=19788) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 592.19s of the 889.67s of remaining time.
# (_dystack pid=19788) 	0.8029	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.01s	 = Training   runtime
# (_dystack pid=19788) 	0.0s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 592.17s of the 889.65s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=19788) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=19788) 	10.0s	 = Training   runtime
# (_dystack pid=19788) 	0.12s	 = Validation runtime
# (_dystack pid=19788) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 577.74s of the 875.22s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_dystack pid=19788) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=19788) 	2.23s	 = Training   runtime
# (_dystack pid=19788) 	0.03s	 = Validation runtime
# (_dystack pid=19788) Fitting model: LightGBM_BAG_L1 ... Training model for up to 570.59s of the 868.07s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_dystack pid=19788) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=19788) 	2.21s	 = Training   runtime
# (_dystack pid=19788) 	0.01s	 = Validation runtime
# (_dystack pid=19788) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 563.6s of the 861.08s of remaining time.
# (_dystack pid=19788) 	0.8504	 = Validation score   (accuracy)
# (_dystack pid=19788) 	1.02s	 = Training   runtime
# (_dystack pid=19788) 	0.08s	 = Validation runtime
# (_dystack pid=19788) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 562.47s of the 859.95s of remaining time.
# (_dystack pid=19788) 	0.8394	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.78s	 = Training   runtime
# (_dystack pid=19788) 	0.09s	 = Validation runtime
# (_dystack pid=19788) Fitting model: CatBoost_BAG_L1 ... Training model for up to 561.57s of the 859.05s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=19788) 	0.854	 = Validation score   (accuracy)
# (_dystack pid=19788) 	15.58s	 = Training   runtime
# (_dystack pid=19788) 	0.02s	 = Validation runtime
# (_dystack pid=19788) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 541.53s of the 839.01s of remaining time.
# (_dystack pid=19788) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.78s	 = Training   runtime
# (_dystack pid=19788) 	0.1s	 = Validation runtime
# (_dystack pid=19788) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 540.63s of the 838.11s of remaining time.
# (_dystack pid=19788) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.89s	 = Training   runtime
# (_dystack pid=19788) 	0.09s	 = Validation runtime
# (_dystack pid=19788) Fitting model: XGBoost_BAG_L1 ... Training model for up to 539.62s of the 837.1s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=19788) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=19788) 	2.99s	 = Training   runtime
# (_dystack pid=19788) 	0.04s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 532.32s of the 829.8s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=8168) Stack (most recent call first):
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=8168)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=8168)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=19788) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=19788) 	18.36s	 = Training   runtime
# (_dystack pid=19788) 	0.15s	 = Validation runtime
# (_dystack pid=19788) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 509.24s of the 806.72s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# (_ray_fit pid=17732) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=17732)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=17732)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=19788) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=19788) 	3.67s	 = Training   runtime
# (_dystack pid=19788) 	0.04s	 = Validation runtime
# (_dystack pid=19788) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 500.62s of the 798.1s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=19788) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=19788) 	17.99s	 = Training   runtime
# (_dystack pid=19788) 	0.02s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 477.26s of the 774.74s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=22840) Stack (most recent call first):
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=22840)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=22840)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=19072)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py
# (_ray_fit pid=19072) "
# (_ray_fit pid=19072) , line 196
# (_ray_fit pid=19072)  in
# (_ray_fit pid=19072) _fit
# (_ray_fit pid=19072)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856
# (_ray_fit pid=19072)  in fit
# (_ray_fit pid=19072)
# (_ray_fit pid=19072)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py"
# (_ray_fit pid=19072) , line 402 in
# (_ray_fit pid=19072) _ray_fit
# (_ray_fit pid=19072)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py"
# (_ray_fit pid=19072) , line 879 in main_loop
# (_ray_fit pid=19072)
# (_ray_fit pid=19072)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py
# (_ray_fit pid=19072) "
# (_ray_fit pid=19072) , line 282 in <module>
# (_dystack pid=19788) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=19788) 	20.67s	 = Training   runtime
# (_dystack pid=19788) 	0.14s	 = Validation runtime
# (_dystack pid=19788) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 452.24s of the 749.72s of remaining time.
# (_ray_fit pid=17876) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 62x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=17876)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 6x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 6x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 6x across cluster]
# (_ray_fit pid=17876)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 6x across cluster]
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=19788) 	0.8577	 = Validation score   (accuracy)
# (_dystack pid=19788) 	2.09s	 = Training   runtime
# (_dystack pid=19788) 	0.02s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 445.6s of the 743.08s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=19788) 	0.8796	 = Validation score   (accuracy)
# (_dystack pid=19788) 	14.97s	 = Training   runtime
# (_dystack pid=19788) 	0.17s	 = Validation runtime
# (_dystack pid=19788) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 425.59s of the 723.07s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# (_dystack pid=19788) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=19788) 	51.43s	 = Training   runtime
# (_dystack pid=19788) 	0.02s	 = Validation runtime
# (_dystack pid=19788) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 369.07s of the 666.55s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_ray_fit pid=25184) [1000]	valid_set's multi_error: 0.0588235
# (_dystack pid=19788) 	0.8248	 = Validation score   (accuracy)
# (_dystack pid=19788) 	2.31s	 = Training   runtime
# (_dystack pid=19788) 	0.0s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 362.18s of the 659.66s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=24500) Stack (most recent call first):
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=24500)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=24500)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=19788) 	0.8796	 = Validation score   (accuracy)
# (_dystack pid=19788) 	18.22s	 = Training   runtime
# (_dystack pid=19788) 	0.18s	 = Validation runtime
# (_dystack pid=19788) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 339.46s of the 636.94s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.24%)
# (_ray_fit pid=21032) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=21032)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=21032)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=19788) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=19788) 	4.57s	 = Training   runtime
# (_dystack pid=19788) 	0.02s	 = Validation runtime
# (_dystack pid=19788) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 329.94s of the 627.43s of remaining time.
# (_dystack pid=19788) 	0.854	 = Validation score   (accuracy)
# (_dystack pid=19788) 	0.8s	 = Training   runtime
# (_dystack pid=19788) 	0.09s	 = Validation runtime
# (_dystack pid=19788) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 329.03s of the 626.51s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=19788) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=19788) 	10.65s	 = Training   runtime
# (_dystack pid=19788) 	0.01s	 = Validation runtime
# (_dystack pid=19788) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 313.74s of the 611.22s of remaining time.
# (_dystack pid=19788) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=19788) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=19788) 	10.56s	 = Training   runtime
# (_dystack pid=19788) 	0.11s	 = Validation runtime
# (_dystack pid=19788) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 298.75s of the 596.23s of remaining time.
# ...
# 	22.65s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 484.55s of the 1380.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8414	 = Validation score   (accuracy)
# 	12.04s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 466.91s of the 1362.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.877	 = Validation score   (accuracy)
# 	15.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 442.38s of the 1338.33s of remaining time.
# 	0.822	 = Validation score   (accuracy)
# 	1.2s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 441.05s of the 1336.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.877	 = Validation score   (accuracy)
# 	2.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 433.14s of the 1329.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.8867	 = Validation score   (accuracy)
# 	3.64s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 424.18s of the 1320.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8867	 = Validation score   (accuracy)
# 	9.66s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 408.98s of the 1304.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.8706	 = Validation score   (accuracy)
# 	10.79s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 392.37s of the 1288.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8932	 = Validation score   (accuracy)
# 	12.2s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 374.91s of the 1270.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.9029	 = Validation score   (accuracy)
# 	4.4s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 364.84s of the 1260.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8932	 = Validation score   (accuracy)
# 	12.25s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 347.25s of the 1243.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8738	 = Validation score   (accuracy)
# 	36.13s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 305.3s of the 1201.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9094	 = Validation score   (accuracy)
# 	14.54s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 285.47s of the 1181.41s of remaining time.
# 	0.8608	 = Validation score   (accuracy)
# 	1.33s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 283.96s of the 1179.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9159	 = Validation score   (accuracy)
# 	22.13s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 256.21s of the 1152.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.89	 = Validation score   (accuracy)
# 	11.48s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 239.97s of the 1135.92s of remaining time.
# 	0.8608	 = Validation score   (accuracy)
# 	1.54s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 238.27s of the 1134.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8867	 = Validation score   (accuracy)
# 	8.99s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 224.56s of the 1120.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8673	 = Validation score   (accuracy)
# 	52.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 166.06s of the 1062.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9061	 = Validation score   (accuracy)
# 	20.87s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 140.55s of the 1036.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8738	 = Validation score   (accuracy)
# 	9.2s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTrees_r126_BAG_L1 ... Training model for up to 126.53s of the 1022.47s of remaining time.
# 	0.8738	 = Validation score   (accuracy)
# 	1.49s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 124.9s of the 1020.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.877	 = Validation score   (accuracy)
# 	19.07s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 101.0s of the 996.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8964	 = Validation score   (accuracy)
# 	17.23s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r163_BAG_L1 ... Training model for up to 78.7s of the 974.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	0.8738	 = Validation score   (accuracy)
# 	12.03s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r198_BAG_L1 ... Training model for up to 61.64s of the 957.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.8706	 = Validation score   (accuracy)
# 	26.45s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 30.33s of the 926.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8835	 = Validation score   (accuracy)
# 	13.88s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 11.76s of the 907.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r19_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 889.63s of remaining time.
# 	Ensemble Weights: {'XGBoost_r49_BAG_L1': 0.444, 'ExtraTreesGini_BAG_L1': 0.111, 'NeuralNetTorch_r86_BAG_L1': 0.111, 'NeuralNetFastAI_r156_BAG_L1': 0.111, 'LightGBM_r15_BAG_L1': 0.111, 'NeuralNetTorch_r121_BAG_L1': 0.111}
# 	0.932	 = Validation score   (accuracy)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 889.21s of the 888.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 2024-11-01 10:16:00,468	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9256	 = Validation score   (accuracy)
# 	11.12s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 872.22s of the 871.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	0.9385	 = Validation score   (accuracy)
# 	4.14s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 862.68s of the 862.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	0.9417	 = Validation score   (accuracy)
# 	7.55s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 850.1s of the 849.55s of remaining time.
# 	0.9223	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 848.83s of the 848.27s of remaining time.
# 	0.9223	 = Validation score   (accuracy)
# 	0.9s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 847.6s of the 847.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.42%)
# 	0.9353	 = Validation score   (accuracy)
# 	188.47s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 654.33s of the 653.84s of remaining time.
# 	0.9223	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 653.3s of the 652.81s of remaining time.
# 	0.932	 = Validation score   (accuracy)
# 	0.88s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 652.18s of the 651.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.44%)
# 	0.932	 = Validation score   (accuracy)
# 	11.86s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 635.57s of the 635.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9256	 = Validation score   (accuracy)
# 	18.82s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 611.64s of the 611.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.98%)
# 	0.9385	 = Validation score   (accuracy)
# 	31.98s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 574.13s of the 573.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.44%)
# 2024-11-01 10:22:46,692	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-01 10:22:50,487	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9288	 = Validation score   (accuracy)
# 	277.43s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 291.53s of the 291.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9353	 = Validation score   (accuracy)
# 	19.51s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 266.84s of the 266.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.43%)
# 	0.9353	 = Validation score   (accuracy)
# 	10.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 251.64s of the 251.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.9417	 = Validation score   (accuracy)
# 	11.43s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 235.08s of the 234.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=6.59%)
# 	0.9288	 = Validation score   (accuracy)
# 	187.33s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 42.43s of the 41.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.9288	 = Validation score   (accuracy)
# 	2.76s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 34.5s of the 33.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	0.9353	 = Validation score   (accuracy)
# 	20.0s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 4.06s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.909, 'CatBoost_r9_BAG_L2': 0.091}
# 	0.945	 = Validation score   (accuracy)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2682.91s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 5.3 rows/s (39 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\best_quality-20241101-093036")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L3
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L3   0.944984    accuracy       9.109573  1536.955566                0.000000           0.271479            3       True        124
# 1                LightGBM_BAG_L2   0.941748    accuracy       9.016738  1349.358618                0.031922           7.553515            2       True        108
# 2    NeuralNetFastAI_r191_BAG_L2   0.941748    accuracy       9.150366  1353.233233                0.165551          11.428130            2       True        120
# 3           LightGBMLarge_BAG_L2   0.938511    accuracy       9.016665  1373.786523                0.031849          31.981420            2       True        116
# 4              LightGBMXT_BAG_L2   0.938511    accuracy       9.016781  1345.949046                0.031965           4.143943            2       True        107
# 5           LightGBM_r131_BAG_L2   0.935275    accuracy       9.003982  1351.832759                0.019166          10.027656            2       True        119
# 6                CatBoost_BAG_L2   0.935275    accuracy       9.055280  1530.271254                0.070465         188.466151            2       True        111
# 7      NeuralNetTorch_r22_BAG_L2   0.935275    accuracy       9.472110  1361.801877                0.487294          19.996773            2       True        123
# 8      NeuralNetTorch_r79_BAG_L2   0.935275    accuracy       9.496561  1361.314658                0.511745          19.509555            2       True        118
# 9            WeightedEnsemble_L2   0.932039    accuracy       0.772978    64.382461                0.000000           0.374262            2       True        105
# 10                XGBoost_BAG_L2   0.932039    accuracy       9.044537  1353.668105                0.059721          11.863002            2       True        114
# 11         ExtraTreesEntr_BAG_L2   0.932039    accuracy       9.098720  1342.683741                0.113904           0.878638            2       True        113
# 12           LightGBM_r96_BAG_L2   0.928803    accuracy       9.026097  1344.569269                0.041281           2.764166            2       True        122
# 13          CatBoost_r177_BAG_L2   0.928803    accuracy       9.077570  1619.237309                0.092754         277.432206            2       True        117
# 14            CatBoost_r9_BAG_L2   0.928803    accuracy       9.077651  1529.130572                0.092836         187.325469            2       True        121
# 15        NeuralNetFastAI_BAG_L2   0.925566    accuracy       9.087455  1352.928159                0.102639          11.123055            2       True        106
# 16         NeuralNetTorch_BAG_L2   0.925566    accuracy       9.528827  1360.625535                0.544011          18.820432            2       True        115
# 17         ExtraTreesGini_BAG_L2   0.922330    accuracy       9.080715  1342.619686                0.095900           0.814583            2       True        112
# 18       RandomForestEntr_BAG_L2   0.922330    accuracy       9.110445  1342.708887                0.125629           0.903784            2       True        110
# 19       RandomForestGini_BAG_L2   0.922330    accuracy       9.130127  1342.740487                0.145311           0.935384            2       True        109
# 20    NeuralNetTorch_r121_BAG_L1   0.915858    accuracy       0.344257    22.129718                0.344257          22.129718            1       True         92
# 21   NeuralNetFastAI_r191_BAG_L1   0.912621    accuracy       0.086342    10.548377                0.086342          10.548377            1       True         17
# 22     NeuralNetTorch_r86_BAG_L1   0.912621    accuracy       0.132888    22.038933                0.132888          22.038933            1       True         32
# 23     NeuralNetTorch_r79_BAG_L1   0.912621    accuracy       0.158542    32.617796                0.158542          32.617796            1       True         15
# 24   NeuralNetFastAI_r134_BAG_L1   0.912621    accuracy       0.161420    17.726037                0.161420          17.726037            1       True         59
# 25     NeuralNetTorch_r76_BAG_L1   0.909385    accuracy       0.185506    14.543380                0.185506          14.543380            1       True         90
# 26    NeuralNetTorch_r135_BAG_L1   0.906149    accuracy       0.179563    20.871046                0.179563          20.871046            1       True         97
# 27          LightGBM_r130_BAG_L1   0.902913    accuracy       0.007034     2.147074                0.007034           2.147074            1       True         31
# 28          LightGBM_r121_BAG_L1   0.902913    accuracy       0.050375     4.399371                0.050375           4.399371            1       True         87
# 29            XGBoost_r98_BAG_L1   0.902913    accuracy       0.069701     5.931285                0.069701           5.931285            1       True         49
# 30        NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.084943     8.357386                0.084943           8.357386            1       True          3
# 31    NeuralNetFastAI_r95_BAG_L1   0.902913    accuracy       0.103496     9.828471                0.103496           9.828471            1       True         47
# 32   NeuralNetFastAI_r145_BAG_L1   0.902913    accuracy       0.105032     9.206260                0.105032           9.206260            1       True         28
# 33   NeuralNetFastAI_r156_BAG_L1   0.902913    accuracy       0.123321    11.720742                0.123321          11.720742            1       True         43
# 34          LightGBMLarge_BAG_L1   0.899676    accuracy       0.018744     4.461579                0.018744           4.461579            1       True         13
# 35           LightGBM_r15_BAG_L1   0.899676    accuracy       0.020549     3.136807                0.020549           3.136807            1       True         50
# 36               LightGBM_BAG_L1   0.896440    accuracy       0.019236     2.243650                0.019236           2.243650            1       True          5
# 37            XGBoost_r89_BAG_L1   0.896440    accuracy       0.032388     3.485958                0.032388           3.485958            1       True         29
# 38            XGBoost_r49_BAG_L1   0.896440    accuracy       0.042937     4.164434                0.042937           4.164434            1       True         70
# 39           XGBoost_r194_BAG_L1   0.896440    accuracy       0.074417     3.437561                0.074417           3.437561            1       True         35
# 40         ExtraTreesEntr_BAG_L1   0.896440    accuracy       0.087457     0.806971                0.087457           0.806971            1       True         10
# 41   NeuralNetFastAI_r100_BAG_L1   0.896440    accuracy       0.143084    17.227116                0.143084          17.227116            1       True        101
# 42     NeuralNetTorch_r71_BAG_L1   0.896440    accuracy       0.168801    22.225348                0.168801          22.225348            1       True         73
# 43    NeuralNetTorch_r185_BAG_L1   0.896440    accuracy       0.175997    22.654721                0.175997          22.654721            1       True         78
# 44             LightGBMXT_BAG_L1   0.893204    accuracy       0.026096     2.202256                0.026096           2.202256            1       True          4
# 45          LightGBM_r188_BAG_L1   0.893204    accuracy       0.041521     2.240056                0.041521           2.240056            1       True         27
# 46   NeuralNetFastAI_r172_BAG_L1   0.893204    accuracy       0.105692    12.245936                0.105692          12.245936            1       True         88
# 47     NeuralNetTorch_r41_BAG_L1   0.893204    accuracy       0.140205    18.846457                0.140205          18.846457            1       True         48
# 48   NeuralNetFastAI_r138_BAG_L1   0.893204    accuracy       0.147478    12.200135                0.147478          12.200135            1       True         86
# 49     NeuralNetTorch_r31_BAG_L1   0.893204    accuracy       0.207836    18.547816                0.207836          18.547816            1       True         65
# 50          CatBoost_r177_BAG_L1   0.889968    accuracy       0.022203    23.554746                0.022203          23.554746            1       True         14
# 51          LightGBM_r131_BAG_L1   0.889968    accuracy       0.033400     3.441135                0.033400           3.441135            1       True         16
# 52         ExtraTrees_r49_BAG_L1   0.889968    accuracy       0.088469     0.992811                0.088469           0.992811            1       True         56
# 53         ExtraTreesGini_BAG_L1   0.889968    accuracy       0.109027     0.817564                0.109027           0.817564            1       True          9
# 54   NeuralNetFastAI_r127_BAG_L1   0.889968    accuracy       0.124281    11.483905                0.124281          11.483905            1       True         93
# 55            XGBoost_r22_BAG_L1   0.886731    accuracy       0.007020     3.639289                0.007020           3.639289            1       True         83
# 56          LightGBM_r161_BAG_L1   0.886731    accuracy       0.009922     2.724545                0.009922           2.724545            1       True         40
# 57            XGBoost_r33_BAG_L1   0.886731    accuracy       0.018149     5.283609                0.018149           5.283609            1       True         21
# 58            CatBoost_r9_BAG_L1   0.886731    accuracy       0.019582    49.757252                0.019582          49.757252            1       True         18
# 59   NeuralNetFastAI_r194_BAG_L1   0.886731    accuracy       0.081013     8.993372                0.081013           8.993372            1       True         95
# 60   NeuralNetFastAI_r102_BAG_L1   0.886731    accuracy       0.146576    11.343436                0.146576          11.343436            1       True         24
# 61    NeuralNetFastAI_r69_BAG_L1   0.886731    accuracy       0.156348     9.659760                0.156348           9.659760            1       True         84
# 62           CatBoost_r70_BAG_L1   0.883495    accuracy       0.015519    21.916470                0.015519          21.916470            1       True         42
# 63            CatBoost_r5_BAG_L1   0.883495    accuracy       0.028404    10.142470                0.028404          10.142470            1       True         71
# 64                XGBoost_BAG_L1   0.883495    accuracy       0.048693     3.136985                0.048693           3.136985            1       True         11
# 65            XGBoost_r31_BAG_L1   0.883495    accuracy       0.063059     4.499590                0.063059           4.499590            1       True         77
# 66   NeuralNetFastAI_r187_BAG_L1   0.883495    accuracy       0.091962    13.879507                0.091962          13.879507            1       True        104
# 67   NeuralNetFastAI_r103_BAG_L1   0.883495    accuracy       0.112042     9.293385                0.112042           9.293385            1       True         38
# 68         NeuralNetTorch_BAG_L1   0.883495    accuracy       0.135732    20.354029                0.135732          20.354029            1       True         12
# 69     NeuralNetTorch_r14_BAG_L1   0.883495    accuracy       0.186891    18.921007                0.186891          18.921007            1       True         39
# 70    NeuralNetTorch_r143_BAG_L1   0.883495    accuracy       0.232260    21.355265                0.232260          21.355265            1       True         62
# 71           CatBoost_r86_BAG_L1   0.880259    accuracy       0.006450    64.519895                0.006450          64.519895            1       True         52
# 72          LightGBM_r196_BAG_L1   0.880259    accuracy       0.008811     3.113380                0.008811           3.113380            1       True         44
# 73          CatBoost_r167_BAG_L1   0.880259    accuracy       0.019918    43.031043                0.019918          43.031043            1       True         46
# 74          CatBoost_r128_BAG_L1   0.880259    accuracy       0.022618    44.633611                0.022618          44.633611            1       True         63
# 75    NeuralNetFastAI_r11_BAG_L1   0.880259    accuracy       0.138500    10.862058                0.138500          10.862058            1       True         34
# 76    NeuralNetTorch_r158_BAG_L1   0.880259    accuracy       0.188798    15.719774                0.188798          15.719774            1       True         51
# 77           CatBoost_r60_BAG_L1   0.877023    accuracy       0.003755    15.569301                0.003755          15.569301            1       True         80
# 78          LightGBM_r135_BAG_L1   0.877023    accuracy       0.007877     2.472863                0.007877           2.472863            1       True         82
# 79           CatBoost_r49_BAG_L1   0.877023    accuracy       0.015304     9.301587                0.015304           9.301587            1       True         55
# 80          LightGBM_r143_BAG_L1   0.877023    accuracy       0.016556     3.297730                0.016556           3.297730            1       True         57
# 81     NeuralNetTorch_r30_BAG_L1   0.877023    accuracy       0.138115    20.294370                0.138115          20.294370            1       True         30
# 82     NeuralNetTorch_r36_BAG_L1   0.877023    accuracy       0.141412    19.068487                0.141412          19.068487            1       True        100
# 83    NeuralNetTorch_r197_BAG_L1   0.877023    accuracy       0.149129    23.773614                0.149129          23.773614            1       True         54
# 84          CatBoost_r143_BAG_L1   0.873786    accuracy       0.003278    33.893711                0.003278          33.893711            1       True         74
# 85          CatBoost_r180_BAG_L1   0.873786    accuracy       0.020180    36.134574                0.020180          36.134574            1       True         89
# 86               CatBoost_BAG_L1   0.873786    accuracy       0.022807    23.528556                0.022807          23.528556            1       True          8
# 87          CatBoost_r163_BAG_L1   0.873786    accuracy       0.025943    12.034237                0.025943          12.034237            1       True        102
# 88           CatBoost_r50_BAG_L1   0.873786    accuracy       0.034736     9.670118                0.034736           9.670118            1       True         33
# 89     NeuralNetFastAI_r4_BAG_L1   0.873786    accuracy       0.081084     9.197587                0.081084           9.197587            1       True         98
# 90        ExtraTrees_r126_BAG_L1   0.873786    accuracy       0.085454     1.485461                0.085454           1.485461            1       True         99
# 91            CatBoost_r6_BAG_L1   0.870550    accuracy       0.016207    10.794800                0.016207          10.794800            1       True         85
# 92           CatBoost_r69_BAG_L1   0.870550    accuracy       0.024795    13.118403                0.024795          13.118403            1       True         37
# 93          CatBoost_r198_BAG_L1   0.870550    accuracy       0.025994    26.445776                0.025994          26.445776            1       True        103
# 94           CatBoost_r12_BAG_L1   0.867314    accuracy       0.002000    52.737933                0.002000          52.737933            1       True         96
# 95           LightGBM_r94_BAG_L1   0.867314    accuracy       0.018206     2.587414                0.018206           2.587414            1       True         61
# 96          CatBoost_r137_BAG_L1   0.867314    accuracy       0.027843     9.154614                0.027843           9.154614            1       True         23
# 97      RandomForest_r166_BAG_L1   0.867314    accuracy       0.095390     1.150767                0.095390           1.150767            1       True         76
# 98     NeuralNetTorch_r22_BAG_L1   0.867314    accuracy       0.167617    30.875452                0.167617          30.875452            1       True         20
# 99     NeuralNetTorch_r87_BAG_L1   0.867314    accuracy       0.203909    19.955283                0.203909          19.955283            1       True         72
# 100      RandomForestEntr_BAG_L1   0.864078    accuracy       0.090434     0.823168                0.090434           0.823168            1       True          7
# 101      RandomForestGini_BAG_L1   0.864078    accuracy       0.093477     0.905832                0.093477           0.905832            1       True          6
# 102          LightGBM_r30_BAG_L1   0.860841    accuracy       0.054472     2.707248                0.054472           2.707248            1       True         69
# 103      RandomForest_r16_BAG_L1   0.860841    accuracy       0.082893     1.535224                0.082893           1.535224            1       True         94
# 104        ExtraTrees_r42_BAG_L1   0.860841    accuracy       0.088532     0.787438                0.088532           0.787438            1       True         22
# 105     RandomForest_r195_BAG_L1   0.860841    accuracy       0.096200     1.095444                0.096200           1.095444            1       True         26
# 106       ExtraTrees_r197_BAG_L1   0.860841    accuracy       0.104602     1.330925                0.104602           1.330925            1       True         91
# 107          CatBoost_r13_BAG_L1   0.854369    accuracy       0.013056    84.696503                0.013056          84.696503            1       True         25
# 108   NeuralNetFastAI_r37_BAG_L1   0.851133    accuracy       0.136934    13.168471                0.136934          13.168471            1       True         53
# 109   NeuralNetFastAI_r88_BAG_L1   0.847896    accuracy       0.084550    12.554882                0.084550          12.554882            1       True         68
# 110       ExtraTrees_r172_BAG_L1   0.844660    accuracy       0.099310     0.837493                0.099310           0.837493            1       True         36
# 111   NeuralNetFastAI_r65_BAG_L1   0.844660    accuracy       0.148985    12.113369                0.148985          12.113369            1       True         67
# 112      RandomForest_r39_BAG_L1   0.841424    accuracy       0.083031     0.954605                0.083031           0.954605            1       True         45
# 113  NeuralNetFastAI_r160_BAG_L1   0.841424    accuracy       0.100008    12.041016                0.100008          12.041016            1       True         79
# 114  NeuralNetFastAI_r111_BAG_L1   0.838188    accuracy       0.149154    10.552546                0.149154          10.552546            1       True         64
# 115       ExtraTrees_r178_BAG_L1   0.834951    accuracy       0.093780     1.040931                0.093780           1.040931            1       True         75
# 116     RandomForest_r127_BAG_L1   0.828479    accuracy       0.093861     1.160529                0.093861           1.160529            1       True         58
# 117      RandomForest_r15_BAG_L1   0.822006    accuracy       0.091290     1.202707                0.091290           1.202707            1       True         81
# 118  NeuralNetFastAI_r143_BAG_L1   0.812298    accuracy       0.098408    12.718001                0.098408          12.718001            1       True         41
# 119        KNeighborsDist_BAG_L1   0.799353    accuracy       0.008002     0.007654                0.008002           0.007654            1       True          2
# 120          LightGBM_r96_BAG_L1   0.796117    accuracy       0.024791     1.756119                0.024791           1.756119            1       True         19
# 121         ExtraTrees_r4_BAG_L1   0.718447    accuracy       0.090938     0.875047                0.090938           0.875047            1       True         66
# 122      RandomForest_r34_BAG_L1   0.705502    accuracy       0.087880     1.128744                0.087880           1.128744            1       True         60
# 123        KNeighborsUnif_BAG_L1   0.686084    accuracy       0.282129     0.005998                0.282129           0.005998            1       True          1
# Number of models trained: 124
# Types of models trained:
# {'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_TabularNeuralNetTorch'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L3
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.62      0.33      0.43        15
# Exc L2-3 LINC00507 FREM3 superficial       0.63      0.92      0.75        26
#             Exc L2-4 LINC00507 GLP2R       0.00      0.00      0.00         5
#
#                             accuracy                           0.63        46
#                            macro avg       0.42      0.42      0.39        46
#                         weighted avg       0.56      0.63      0.57        46
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[ 5 10  0]
#  [ 2 24  0]
#  [ 1  4  0]]
# ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']
# ([<matplotlib.axis.YTick at 0x23bae069210>,
#   <matplotlib.axis.YTick at 0x23bad962a90>,
#   <matplotlib.axis.YTick at 0x23bae093a90>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 5 10  0]
#  [ 2 24  0]
#  [ 1  4  0]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.292954                              0.455534
# 1           0.256369                              0.508560
# 2           0.319798                              0.427600
# 3           0.273658                              0.471950
# 4           0.251503                              0.511354
# 5           0.243786                              0.517854
# 6           0.266609                              0.497196
# 7           0.250335                              0.512754
# 8           0.267955                              0.481544
# 9           0.449245                              0.304059
# 10          0.450280                              0.308887
# 11          0.280983                              0.452204
# 12          0.466557                              0.296056
# 13          0.259075                              0.504084
# 14          0.241092                              0.519312
# 15          0.264233                              0.475715
# 16          0.255376                              0.500934
# 17          0.239005                              0.522421
# 18          0.239613                              0.522047
# 19          0.413047                              0.347570
# 20          0.280391                              0.433733
# 21          0.312963                              0.442318
# 22          0.244773                              0.515468
# 23          0.246119                              0.515377
# 24          0.461442                              0.300165
# 25          0.307844                              0.445711
# 26          0.495474                              0.259467
# 27          0.269801                              0.485715
# 28          0.242350                              0.516101
# 29          0.432215                              0.318593
# 30          0.464821                              0.286237
# 31          0.244126                              0.517438
# 32          0.242076                              0.519250
# 33          0.246863                              0.515461
# 34          0.239769                              0.522195
# 35          0.287143                              0.461866
# 36          0.281344                              0.460970
# 37          0.239974                              0.520787
# 38          0.239775                              0.522586
# 39          0.239320                              0.522067
# 40          0.346153                              0.359471
# 41          0.252511                              0.512524
# 42          0.259525                              0.504108
# 43          0.310553                              0.441357
# 44          0.245738                              0.518399
# 45          0.244240                              0.512779
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.251512
# 1                   0.235071
# 2                   0.252601
# 3                   0.254392
# 4                   0.237143
# 5                   0.238360
# 6                   0.236196
# 7                   0.236911
# 8                   0.250501
# 9                   0.246696
# 10                  0.240833
# 11                  0.266813
# 12                  0.237386
# 13                  0.236840
# 14                  0.239596
# 15                  0.260052
# 16                  0.243691
# 17                  0.238574
# 18                  0.238340
# 19                  0.239383
# 20                  0.285875
# 21                  0.244719
# 22                  0.239760
# 23                  0.238503
# 24                  0.238393
# 25                  0.246445
# 26                  0.245059
# 27                  0.244484
# 28                  0.241549
# 29                  0.249191
# 30                  0.248941
# 31                  0.238436
# 32                  0.238674
# 33                  0.237676
# 34                  0.238036
# 35                  0.250991
# 36                  0.257687
# 37                  0.239239
# 38                  0.237639
# 39                  0.238612
# 40                  0.294376
# 41                  0.234965
# 42                  0.236368
# 43                  0.248090
# 44                  0.235862
# 45                  0.242981

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	2029.77s	= Expected runtime (405.95s per shuffle set)
# 	174.93s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# FAP_rheobase            0.039130  0.018188  0.004290  5  0.076580  0.001681
# sag                     0.021739  0.021739  0.044505  5  0.066500 -0.023022
# TS2_adp_index           0.017391  0.028344  0.120991  5  0.075753 -0.040970
# input_resistance        0.017391  0.009722  0.008065  5  0.037409 -0.002626
# FAP_num_APs             0.017391  0.009722  0.008065  5  0.037409 -0.002626
# TS1_rheobase            0.017391  0.009722  0.008065  5  0.037409 -0.002626
# TS2_threshold           0.017391  0.009722  0.008065  5  0.037409 -0.002626
# TS2_up_down_ratio       0.013043  0.019444  0.104000  5  0.053079 -0.026992
# tau                     0.008696  0.011907  0.088904  5  0.033212 -0.015821
# FAP_halfwidth           0.008696  0.019444  0.186950  5  0.048731 -0.031340
# TS1_up_down_ratio       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxdownstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_halfwidth           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_avg_downstroke      0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS2_maxupstroke         0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_peak                0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_threshold           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_avg_upstroke        0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_avg_downstroke      0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxupstroke         0.000000  0.015372  0.500000  5  0.031651 -0.031651
# L23_depth_normalized    0.000000  0.034373  0.500000  5  0.070774 -0.070774
# FAP_maxdownstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_peak                0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_threshold           0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS1_adp_index           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_num_APs             0.000000  0.000000  0.500000  5  0.000000  0.000000
# VmatSag                 0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_avg_downstroke     -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# TS1_avg_upstroke       -0.008696  0.011907  0.911096  5  0.015821 -0.033212
# TS2_num_APs            -0.008696  0.011907  0.911096  5  0.015821 -0.033212
# TS2_rheobase           -0.008696  0.019444  0.813050  5  0.031340 -0.048731
# FAP_maxupstroke        -0.013043  0.024786  0.847721  5  0.037992 -0.064079
# vmbaseM                -0.021739  0.000000  0.500000  5 -0.021739 -0.021739
# FAP_avg_upstroke       -0.026087  0.009722  0.998059  5 -0.006069 -0.046105
# FAP_up_down_ratio      -0.034783  0.011907  0.998581  5 -0.010266 -0.059299

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L3
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'accuracy': 0.6304347826086957,
#  'balanced_accuracy': 0.41880341880341887,
#  'mcc': 0.2656948697685335,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     5
#  Exc L2-3 LINC00507 FREM3 superficial                 2
#  Exc L2-4 LINC00507 GLP2R                             1
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                        10
#  Exc L2-3 LINC00507 FREM3 superficial                                    24
#  Exc L2-4 LINC00507 GLP2R                                                 4
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     0  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.625,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.43478260869565216,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.631578947368421,
#    'recall': 0.9230769230769231,
#    'f1-score': 0.75,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 0.0,
#    'recall': 0.0,
#    'f1-score': 0.0,
#    'support': 5.0},
#   'accuracy': 0.6304347826086957,
#   'macro avg': {'precision': 0.418859649122807,
#    'recall': 0.4188034188034188,
#    'f1-score': 0.39492753623188404,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.5607837528604118,
#    'recall': 0.6304347826086957,
#    'f1-score': 0.5656899810964083,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                           model  score_test  score_val eval_metric  \
# 0        NeuralNetFastAI_BAG_L1    0.739130   0.902913    accuracy
# 1           WeightedEnsemble_L2    0.739130   0.932039    accuracy
# 2           LightGBM_r96_BAG_L1    0.717391   0.796117    accuracy
# 3          LightGBM_r196_BAG_L1    0.717391   0.880259    accuracy
# 4        ExtraTrees_r172_BAG_L1    0.717391   0.844660    accuracy
# ..                          ...         ...        ...         ...
# 119     RandomForest_r34_BAG_L1    0.543478   0.705502    accuracy
# 120  NeuralNetTorch_r185_BAG_L1    0.543478   0.896440    accuracy
# 121  NeuralNetTorch_r158_BAG_L1    0.543478   0.880259    accuracy
# 122       KNeighborsUnif_BAG_L1    0.391304   0.686084    accuracy
# 123       KNeighborsDist_BAG_L1    0.391304   0.799353    accuracy
#
#      pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0          0.093501       0.084943   8.357386                 0.093501
# 1          0.754200       0.772978  64.382461                 0.006416
# 2          0.050563       0.024791   1.756119                 0.050563
# 3          0.066317       0.008811   3.113380                 0.066317
# 4          0.087010       0.099310   0.837493                 0.087010
# ..              ...            ...        ...                      ...
# 119        0.074330       0.087880   1.128744                 0.074330
# 120        0.158560       0.175997  22.654721                 0.158560
# 121        0.199020       0.188798  15.719774                 0.199020
# 122        0.006004       0.282129   0.005998                 0.006004
# 123        0.006998       0.008002   0.007654                 0.006998
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                  0.084943           8.357386            1       True
# 1                  0.000000           0.374262            2       True
# 2                  0.024791           1.756119            1       True
# 3                  0.008811           3.113380            1       True
# 4                  0.099310           0.837493            1       True
# ..                      ...                ...          ...        ...
# 119                0.087880           1.128744            1       True
# 120                0.175997          22.654721            1       True
# 121                0.188798          15.719774            1       True
# 122                0.282129           0.005998            1       True
# 123                0.008002           0.007654            1       True
#
#      fit_order
# 0            3
# 1          105
# 2           19
# 3           44
# 4           36
# ..         ...
# 119         60
# 120         78
# 121         51
# 122          1
# 123          2
#
# [124 rows x 13 columns]

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_4872\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.249587                              0.514795
# 1            0.249871                              0.513280
# 2            0.242502                              0.520325
# 3            0.238629                              0.523371
# 4            0.272654                              0.492053
# ..                ...                                   ...
# 204          0.329824                              0.414813
# 205          0.245392                              0.517927
# 206          0.251167                              0.504708
# 207          0.287535                              0.464754
# 208          0.245089                              0.517072
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.235617
# 1                    0.236849
# 2                    0.237173
# 3                    0.238000
# 4                    0.235292
# ..                        ...
# 204                  0.255363
# 205                  0.236681
# 206                  0.244125
# 207                  0.247711
# 208                  0.237840
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (157, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L3', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.572846
# [100]	valid_set's soft_log_loss: -0.495296
# [150]	valid_set's soft_log_loss: -0.487355
# [200]	valid_set's soft_log_loss: -0.511583
# [250]	valid_set's soft_log_loss: -0.55364
# [300]	valid_set's soft_log_loss: -0.594283
# [350]	valid_set's soft_log_loss: -0.613025
# [400]	valid_set's soft_log_loss: -0.6254
# 	Note: model has different eval_metric than default.
# 	-0.4773	 = Validation score   (-soft_log_loss)
# 	1.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4436	 = Validation score   (-soft_log_loss)
# 	0.86s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0821163	test: -1.0743438	best: -1.0743438 (0)	total: 925ms	remaining: 2h 34m 12s
# 20:	learn: -0.8822837	test: -0.8369785	best: -0.8369785 (20)	total: 1.27s	remaining: 10m 5s
# 40:	learn: -0.7908002	test: -0.7162533	best: -0.7162533 (40)	total: 1.63s	remaining: 6m 36s
# 60:	learn: -0.7371161	test: -0.6429073	best: -0.6429073 (60)	total: 1.98s	remaining: 5m 23s
# 80:	learn: -0.7056533	test: -0.6071336	best: -0.6071336 (80)	total: 2.35s	remaining: 4m 48s
# 100:	learn: -0.6746184	test: -0.5733978	best: -0.5733978 (100)	total: 2.72s	remaining: 4m 26s
# 120:	learn: -0.6483075	test: -0.5492176	best: -0.5492176 (120)	total: 3.07s	remaining: 4m 10s
# 140:	learn: -0.6312391	test: -0.5344936	best: -0.5344936 (140)	total: 3.45s	remaining: 4m 1s
# 160:	learn: -0.6158995	test: -0.5190854	best: -0.5190854 (160)	total: 3.77s	remaining: 3m 50s
# 180:	learn: -0.6034212	test: -0.5041032	best: -0.5041032 (180)	total: 4.12s	remaining: 3m 43s
# 200:	learn: -0.5902600	test: -0.4943278	best: -0.4943278 (200)	total: 4.46s	remaining: 3m 37s
# 220:	learn: -0.5810375	test: -0.4880343	best: -0.4880343 (220)	total: 4.82s	remaining: 3m 33s
# 240:	learn: -0.5735122	test: -0.4826156	best: -0.4818774 (238)	total: 5.18s	remaining: 3m 30s
# 260:	learn: -0.5665167	test: -0.4739620	best: -0.4739620 (260)	total: 5.58s	remaining: 3m 28s
# 280:	learn: -0.5608824	test: -0.4687164	best: -0.4687164 (280)	total: 5.94s	remaining: 3m 25s
# 300:	learn: -0.5549784	test: -0.4667068	best: -0.4665949 (299)	total: 6.26s	remaining: 3m 21s
# 320:	learn: -0.5498182	test: -0.4623258	best: -0.4623258 (320)	total: 6.6s	remaining: 3m 19s
# 340:	learn: -0.5452620	test: -0.4566592	best: -0.4563181 (337)	total: 6.93s	remaining: 3m 16s
# 360:	learn: -0.5420144	test: -0.4537643	best: -0.4537643 (360)	total: 7.26s	remaining: 3m 13s
# 380:	learn: -0.5385756	test: -0.4500426	best: -0.4500426 (380)	total: 7.61s	remaining: 3m 12s
# 400:	learn: -0.5348900	test: -0.4473164	best: -0.4473164 (400)	total: 7.95s	remaining: 3m 10s
# 420:	learn: -0.5316677	test: -0.4419974	best: -0.4419974 (420)	total: 8.31s	remaining: 3m 9s
# 440:	learn: -0.5287128	test: -0.4387885	best: -0.4387031 (437)	total: 8.63s	remaining: 3m 7s
# 460:	learn: -0.5260984	test: -0.4369308	best: -0.4366311 (455)	total: 8.97s	remaining: 3m 5s
# 480:	learn: -0.5234666	test: -0.4355483	best: -0.4348639 (468)	total: 9.29s	remaining: 3m 3s
# 500:	learn: -0.5209773	test: -0.4361741	best: -0.4343656 (490)	total: 9.64s	remaining: 3m 2s
# 520:	learn: -0.5189281	test: -0.4363190	best: -0.4343656 (490)	total: 9.99s	remaining: 3m 1s
# 540:	learn: -0.5171210	test: -0.4356964	best: -0.4343656 (490)	total: 10.4s	remaining: 3m 1s
# 560:	learn: -0.5153396	test: -0.4362731	best: -0.4343656 (490)	total: 10.7s	remaining: 3m
# 580:	learn: -0.5136492	test: -0.4351492	best: -0.4343656 (490)	total: 11.1s	remaining: 2m 59s
# 600:	learn: -0.5123656	test: -0.4352581	best: -0.4343656 (490)	total: 11.5s	remaining: 2m 59s
# 620:	learn: -0.5108682	test: -0.4326846	best: -0.4326846 (620)	total: 11.8s	remaining: 2m 58s
# 640:	learn: -0.5092541	test: -0.4313607	best: -0.4313607 (640)	total: 12.2s	remaining: 2m 57s
# 660:	learn: -0.5078901	test: -0.4326201	best: -0.4310993 (654)	total: 12.5s	remaining: 2m 56s
# 680:	learn: -0.5066875	test: -0.4330924	best: -0.4310993 (654)	total: 12.8s	remaining: 2m 55s
# 700:	learn: -0.5054826	test: -0.4343760	best: -0.4310993 (654)	total: 13.2s	remaining: 2m 55s
# 720:	learn: -0.5042311	test: -0.4328743	best: -0.4310993 (654)	total: 13.6s	remaining: 2m 54s
# 740:	learn: -0.5030943	test: -0.4329265	best: -0.4310993 (654)	total: 14s	remaining: 2m 54s
# 760:	learn: -0.5020584	test: -0.4329844	best: -0.4310993 (654)	total: 14.4s	remaining: 2m 54s
# 780:	learn: -0.5012708	test: -0.4332615	best: -0.4310993 (654)	total: 14.8s	remaining: 2m 54s
# 800:	learn: -0.5004682	test: -0.4331272	best: -0.4310993 (654)	total: 15.1s	remaining: 2m 53s
# 820:	learn: -0.4997435	test: -0.4328853	best: -0.4310993 (654)	total: 15.5s	remaining: 2m 52s
# 840:	learn: -0.4990247	test: -0.4331097	best: -0.4310993 (654)	total: 15.8s	remaining: 2m 51s
# 860:	learn: -0.4983435	test: -0.4324847	best: -0.4310993 (654)	total: 16.1s	remaining: 2m 51s
# 880:	learn: -0.4976392	test: -0.4325345	best: -0.4310993 (654)	total: 16.5s	remaining: 2m 50s
# 900:	learn: -0.4969362	test: -0.4329728	best: -0.4310993 (654)	total: 16.8s	remaining: 2m 49s
# 920:	learn: -0.4963566	test: -0.4321889	best: -0.4310993 (654)	total: 17.2s	remaining: 2m 49s
# 940:	learn: -0.4957593	test: -0.4322663	best: -0.4310993 (654)	total: 17.5s	remaining: 2m 48s
# 	Note: model has different eval_metric than default.
# 	-0.4311	 = Validation score   (-soft_log_loss)
# 	19.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# bestTest = -0.4310993377
# bestIteration = 654
#
# Shrink model to first 655 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5725	 = Validation score   (-soft_log_loss)
# 	10.28s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.588, 'RandomForestMSE_DSTL': 0.353, 'LightGBM_DSTL': 0.059}
# 	Note: model has different eval_metric than default.
# 	-0.4174	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL   0.822581  soft_log_loss       0.000000   1.201365                0.000000           1.201365            1       True        125
# 1             CatBoost_DSTL   0.822581  soft_log_loss       0.000000  19.030374                0.000000          19.030374            1       True        127
# 2  WeightedEnsemble_L2_DSTL   0.822581  soft_log_loss       0.066729  21.136465                0.000000           0.040861            2       True        129
# 3      RandomForestMSE_DSTL   0.822581  soft_log_loss       0.066729   0.863866                0.066729           0.863866            1       True        126
# 4       NeuralNetTorch_DSTL   0.790323  soft_log_loss       0.018623  10.275874                0.018623          10.275874            1       True        128
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 117          WeightedEnsemble_L3    0.630435   0.944984       accuracy
# 97   NeuralNetFastAI_r191_BAG_L2    0.652174   0.941748       accuracy
# 113              LightGBM_BAG_L2    0.630435   0.941748       accuracy
# 73             LightGBMXT_BAG_L2    0.673913   0.938511       accuracy
# 96          LightGBMLarge_BAG_L2    0.652174   0.938511       accuracy
# ..                           ...         ...        ...            ...
# 5            LightGBM_r96_BAG_L1    0.717391   0.796117       accuracy
# 118          NeuralNetTorch_DSTL    0.608696   0.790323  soft_log_loss
# 105         ExtraTrees_r4_BAG_L1    0.630435   0.718447       accuracy
# 124      RandomForest_r34_BAG_L1    0.543478   0.705502       accuracy
# 128        KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#      pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 117       10.873056       9.109573  1536.955566                 0.000000
# 97        10.870219       9.150366  1353.233233                 0.130622
# 113       10.773016       9.016738  1349.358618                 0.033419
# 73        10.779461       9.016781  1345.949046                 0.039864
# 96        10.853888       9.016665  1373.786523                 0.114291
# ..              ...            ...          ...                      ...
# 5          0.030195       0.024791     1.756119                 0.030195
# 118        0.019653       0.018623    10.275874                 0.019653
# 105        0.121943       0.090938     0.875047                 0.121943
# 124        0.070409       0.087880     1.128744                 0.070409
# 128        0.012761       0.282129     0.005998                 0.012761
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 117                0.000000           0.271479            3       True
# 97                 0.165551          11.428130            2       True
# 113                0.031922           7.553515            2       True
# 73                 0.031965           4.143943            2       True
# 96                 0.031849          31.981420            2       True
# ..                      ...                ...          ...        ...
# 5                  0.024791           1.756119            1       True
# 118                0.018623          10.275874            1       True
# 105                0.090938           0.875047            1       True
# 124                0.087880           1.128744            1       True
# 128                0.282129           0.005998            1       True
#
#      fit_order
# 117        124
# 97         120
# 113        108
# 73         107
# 96         116
# ..         ...
# 5           19
# 118        128
# 105         66
# 124         60
# 128          1
#
# [129 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7608695652173914
# Evaluations on test data:
# {
#     "accuracy": 0.7608695652173914,
#     "balanced_accuracy": 0.7487179487179487,
#     "mcc": 0.5799730721104378
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.8181818181818182,
#         "recall": 0.6,
#         "f1-score": 0.6923076923076923,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7857142857142857,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8148148148148148,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "accuracy": 0.7608695652173914,
#     "macro avg": {
#         "precision": 0.725108225108225,
#         "recall": 0.7487179487179487,
#         "f1-score": 0.7245963912630579,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7730095990965554,
#         "recall": 0.7608695652173914,
#         "f1-score": 0.758763780502911,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7608695652173914, 'balanced_accuracy': 0.7487179487179487, 'mcc': 0.5799730721104378, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     9
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             0
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 1
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             1
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.8181818181818182, 'recall': 0.6, 'f1-score': 0.6923076923076923, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7857142857142857, 'recall': 0.8461538461538461, 'f1-score': 0.8148148148148148, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5714285714285714, 'recall': 0.8, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'accuracy': 0.7608695652173914, 'macro avg': {'precision': 0.725108225108225, 'recall': 0.7487179487179487, 'f1-score': 0.7245963912630579, 'support': 46.0}, 'weighted avg': {'precision': 0.7730095990965554, 'recall': 0.7608695652173914, 'f1-score': 0.758763780502911, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.82      0.60      0.69        15
# Exc L2-3 LINC00507 FREM3 superficial       0.79      0.85      0.81        26
#             Exc L2-4 LINC00507 GLP2R       0.57      0.80      0.67         5
#
#                             accuracy                           0.76        46
#                            macro avg       0.73      0.75      0.72        46
#                         weighted avg       0.77      0.76      0.76        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.547621
# [100]	valid_set's soft_log_loss: -0.46773
# [150]	valid_set's soft_log_loss: -0.45116
# [200]	valid_set's soft_log_loss: -0.460303
# [250]	valid_set's soft_log_loss: -0.497239
# [300]	valid_set's soft_log_loss: -0.513683
# [350]	valid_set's soft_log_loss: -0.547675
# [400]	valid_set's soft_log_loss: -0.570909
# 	Note: model has different eval_metric than default.
# 	-0.4494	 = Validation score   (-soft_log_loss)
# 	1.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4371	 = Validation score   (-soft_log_loss)
# 	0.82s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0809008	test: -1.0777094	best: -1.0777094 (0)	total: 579ms	remaining: 1h 36m 26s
# 20:	learn: -0.8553596	test: -0.8213331	best: -0.8213331 (20)	total: 923ms	remaining: 7m 18s
# 40:	learn: -0.7478258	test: -0.7073894	best: -0.7073894 (40)	total: 1.23s	remaining: 4m 58s
# 60:	learn: -0.6900885	test: -0.6383971	best: -0.6383971 (60)	total: 1.56s	remaining: 4m 14s
# 80:	learn: -0.6490523	test: -0.5948720	best: -0.5948720 (80)	total: 1.89s	remaining: 3m 51s
# 100:	learn: -0.6163392	test: -0.5610796	best: -0.5609976 (99)	total: 2.21s	remaining: 3m 37s
# 120:	learn: -0.5905024	test: -0.5348523	best: -0.5348523 (120)	total: 2.54s	remaining: 3m 26s
# 140:	learn: -0.5704051	test: -0.5147483	best: -0.5147483 (140)	total: 2.86s	remaining: 3m 19s
# 160:	learn: -0.5532950	test: -0.4978996	best: -0.4978206 (159)	total: 3.19s	remaining: 3m 14s
# 180:	learn: -0.5387929	test: -0.4814969	best: -0.4814603 (179)	total: 3.49s	remaining: 3m 9s
# 200:	learn: -0.5257363	test: -0.4734000	best: -0.4734000 (200)	total: 3.79s	remaining: 3m 4s
# 220:	learn: -0.5145703	test: -0.4649193	best: -0.4649193 (220)	total: 4.11s	remaining: 3m 1s
# 240:	learn: -0.5064816	test: -0.4625782	best: -0.4622087 (239)	total: 4.48s	remaining: 3m 1s
# 260:	learn: -0.4995441	test: -0.4582743	best: -0.4582428 (259)	total: 4.81s	remaining: 2m 59s
# 280:	learn: -0.4917912	test: -0.4535024	best: -0.4532837 (277)	total: 5.15s	remaining: 2m 58s
# 300:	learn: -0.4861176	test: -0.4521666	best: -0.4521666 (300)	total: 5.49s	remaining: 2m 57s
# 320:	learn: -0.4808318	test: -0.4482467	best: -0.4482467 (320)	total: 5.87s	remaining: 2m 57s
# 340:	learn: -0.4759356	test: -0.4460567	best: -0.4460567 (340)	total: 6.17s	remaining: 2m 54s
# 360:	learn: -0.4711661	test: -0.4444179	best: -0.4434658 (354)	total: 6.53s	remaining: 2m 54s
# 380:	learn: -0.4668988	test: -0.4405997	best: -0.4405997 (380)	total: 6.86s	remaining: 2m 53s
# 400:	learn: -0.4629612	test: -0.4387027	best: -0.4387027 (400)	total: 7.2s	remaining: 2m 52s
# 420:	learn: -0.4597154	test: -0.4393405	best: -0.4378310 (413)	total: 7.56s	remaining: 2m 52s
# 440:	learn: -0.4563925	test: -0.4384486	best: -0.4375260 (436)	total: 7.91s	remaining: 2m 51s
# 460:	learn: -0.4533644	test: -0.4358783	best: -0.4357224 (459)	total: 8.24s	remaining: 2m 50s
# 480:	learn: -0.4504463	test: -0.4351828	best: -0.4345151 (466)	total: 8.55s	remaining: 2m 49s
# 500:	learn: -0.4482451	test: -0.4348654	best: -0.4345151 (466)	total: 8.87s	remaining: 2m 48s
# 520:	learn: -0.4459534	test: -0.4343397	best: -0.4338552 (510)	total: 9.19s	remaining: 2m 47s
# 540:	learn: -0.4438213	test: -0.4355068	best: -0.4338552 (510)	total: 9.5s	remaining: 2m 46s
# 560:	learn: -0.4423091	test: -0.4346600	best: -0.4338552 (510)	total: 9.83s	remaining: 2m 45s
# 580:	learn: -0.4407930	test: -0.4353936	best: -0.4338552 (510)	total: 10.2s	remaining: 2m 44s
# 600:	learn: -0.4392513	test: -0.4349611	best: -0.4338552 (510)	total: 10.5s	remaining: 2m 44s
# 620:	learn: -0.4375981	test: -0.4339811	best: -0.4332890 (617)	total: 10.8s	remaining: 2m 43s
# 640:	learn: -0.4359548	test: -0.4354786	best: -0.4332890 (617)	total: 11.1s	remaining: 2m 42s
# 660:	learn: -0.4344959	test: -0.4346773	best: -0.4332890 (617)	total: 11.5s	remaining: 2m 41s
# 680:	learn: -0.4332068	test: -0.4344672	best: -0.4332890 (617)	total: 11.8s	remaining: 2m 41s
# 700:	learn: -0.4319480	test: -0.4352998	best: -0.4332890 (617)	total: 12.1s	remaining: 2m 40s
# 720:	learn: -0.4308636	test: -0.4348588	best: -0.4332890 (617)	total: 12.4s	remaining: 2m 40s
# 740:	learn: -0.4296606	test: -0.4363561	best: -0.4332890 (617)	total: 12.8s	remaining: 2m 39s
# 760:	learn: -0.4286724	test: -0.4357111	best: -0.4332890 (617)	total: 13.1s	remaining: 2m 38s
# 780:	learn: -0.4277664	test: -0.4367048	best: -0.4332890 (617)	total: 13.4s	remaining: 2m 37s
# 800:	learn: -0.4268940	test: -0.4376983	best: -0.4332890 (617)	total: 13.7s	remaining: 2m 37s
# 820:	learn: -0.4260036	test: -0.4396489	best: -0.4332890 (617)	total: 14s	remaining: 2m 36s
# 840:	learn: -0.4252967	test: -0.4411040	best: -0.4332890 (617)	total: 14.3s	remaining: 2m 36s
# 860:	learn: -0.4244740	test: -0.4406236	best: -0.4332890 (617)	total: 14.7s	remaining: 2m 35s
# 880:	learn: -0.4236060	test: -0.4412581	best: -0.4332890 (617)	total: 15s	remaining: 2m 35s
# 900:	learn: -0.4228789	test: -0.4413801	best: -0.4332890 (617)	total: 15.3s	remaining: 2m 34s
# 	Note: model has different eval_metric than default.
# 	-0.4333	 = Validation score   (-soft_log_loss)
# 	16.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# bestTest = -0.4332889577
# bestIteration = 617
#
# Shrink model to first 618 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.609	 = Validation score   (-soft_log_loss)
# 	3.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'RandomForestMSE_2_DSTL': 0.421, 'CatBoost_2_DSTL': 0.421, 'LightGBM_2_DSTL': 0.158}
# 	Note: model has different eval_metric than default.
# 	-0.4122	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_2_DSTL   0.838710  soft_log_loss       0.000000   1.087418                0.000000           1.087418            1       True        130
# 1             CatBoost_2_DSTL   0.838710  soft_log_loss       0.010046  16.541821                0.010046          16.541821            1       True        132
# 2  WeightedEnsemble_2_L2_DSTL   0.838710  soft_log_loss       0.064695  18.484773                0.000000           0.030873            2       True        134
# 3      RandomForestMSE_2_DSTL   0.806452  soft_log_loss       0.054649   0.824661                0.054649           0.824661            1       True        131
# 4       NeuralNetTorch_2_DSTL   0.790323  soft_log_loss       0.018429   3.012341                0.018429           3.012341            1       True        133
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                           model  score_test  score_val    eval_metric  \
# 0                 LightGBM_DSTL    0.760870   0.822581  soft_log_loss
# 3           WeightedEnsemble_L2    0.739130   0.932039       accuracy
# 1        NeuralNetFastAI_BAG_L1    0.739130   0.902913       accuracy
# 2      WeightedEnsemble_L2_DSTL    0.739130   0.822581  soft_log_loss
# 17              CatBoost_BAG_L2    0.717391   0.935275       accuracy
# ..                          ...         ...        ...            ...
# 130  NeuralNetTorch_r185_BAG_L1    0.543478   0.896440       accuracy
# 131  NeuralNetTorch_r158_BAG_L1    0.543478   0.880259       accuracy
# 129     RandomForest_r34_BAG_L1    0.543478   0.705502       accuracy
# 133       KNeighborsDist_BAG_L1    0.391304   0.799353       accuracy
# 132       KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#      pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0          0.014517       0.000000     1.201365                 0.014517
# 3          0.739594       0.772978    64.382461                 0.003050
# 1          0.126066       0.084943     8.357386                 0.126066
# 2          0.133662       0.066729    21.136465                 0.002567
# 17        11.150709       9.055280  1530.271254                 0.079827
# ..              ...            ...          ...                      ...
# 130        0.146531       0.175997    22.654721                 0.146531
# 131        0.177282       0.188798    15.719774                 0.177282
# 129        0.103271       0.087880     1.128744                 0.103271
# 133        0.005999       0.008002     0.007654                 0.005999
# 132        0.004000       0.282129     0.005998                 0.004000
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                  0.000000           1.201365            1       True
# 3                  0.000000           0.374262            2       True
# 1                  0.084943           8.357386            1       True
# 2                  0.000000           0.040861            2       True
# 17                 0.070465         188.466151            2       True
# ..                      ...                ...          ...        ...
# 130                0.175997          22.654721            1       True
# 131                0.188798          15.719774            1       True
# 129                0.087880           1.128744            1       True
# 133                0.008002           0.007654            1       True
# 132                0.282129           0.005998            1       True
#
#      fit_order
# 0          125
# 3          105
# 1            3
# 2          129
# 17         111
# ..         ...
# 130         78
# 131         51
# 129         60
# 133          2
# 132          1
#
# [134 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7608695652173914
# Evaluations on test data:
# {
#     "accuracy": 0.7608695652173914,
#     "balanced_accuracy": 0.7487179487179487,
#     "mcc": 0.5799730721104378
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.8181818181818182,
#         "recall": 0.6,
#         "f1-score": 0.6923076923076923,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7857142857142857,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8148148148148148,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "accuracy": 0.7608695652173914,
#     "macro avg": {
#         "precision": 0.725108225108225,
#         "recall": 0.7487179487179487,
#         "f1-score": 0.7245963912630579,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7730095990965554,
#         "recall": 0.7608695652173914,
#         "f1-score": 0.758763780502911,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7608695652173914, 'balanced_accuracy': 0.7487179487179487, 'mcc': 0.5799730721104378, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     9
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             0
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 1
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             1
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.8181818181818182, 'recall': 0.6, 'f1-score': 0.6923076923076923, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7857142857142857, 'recall': 0.8461538461538461, 'f1-score': 0.8148148148148148, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5714285714285714, 'recall': 0.8, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'accuracy': 0.7608695652173914, 'macro avg': {'precision': 0.725108225108225, 'recall': 0.7487179487179487, 'f1-score': 0.7245963912630579, 'support': 46.0}, 'weighted avg': {'precision': 0.7730095990965554, 'recall': 0.7608695652173914, 'f1-score': 0.758763780502911, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x23bc17a8950>,
#   <matplotlib.axis.YTick at 0x23bc159a110>,
#   <matplotlib.axis.YTick at 0x23bc159bed0>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'CatBoost_r177_BAG_L1', 'NeuralNetTorch_r79_BAG_L1', 'LightGBM_r131_BAG_L1', 'NeuralNetFastAI_r191_BAG_L1', 'CatBoost_r9_BAG_L1', 'LightGBM_r96_BAG_L1', 'NeuralNetTorch_r22_BAG_L1', 'XGBoost_r33_BAG_L1', 'ExtraTrees_r42_BAG_L1', 'CatBoost_r137_BAG_L1', 'NeuralNetFastAI_r102_BAG_L1', 'CatBoost_r13_BAG_L1', 'RandomForest_r195_BAG_L1', 'LightGBM_r188_BAG_L1', 'NeuralNetFastAI_r145_BAG_L1', 'XGBoost_r89_BAG_L1', 'NeuralNetTorch_r30_BAG_L1', 'LightGBM_r130_BAG_L1', 'NeuralNetTorch_r86_BAG_L1', 'CatBoost_r50_BAG_L1', 'NeuralNetFastAI_r11_BAG_L1', 'XGBoost_r194_BAG_L1', 'ExtraTrees_r172_BAG_L1', 'CatBoost_r69_BAG_L1', 'NeuralNetFastAI_r103_BAG_L1', 'NeuralNetTorch_r14_BAG_L1', 'LightGBM_r161_BAG_L1', 'NeuralNetFastAI_r143_BAG_L1', 'CatBoost_r70_BAG_L1', 'NeuralNetFastAI_r156_BAG_L1', 'LightGBM_r196_BAG_L1', 'RandomForest_r39_BAG_L1', 'CatBoost_r167_BAG_L1', 'NeuralNetFastAI_r95_BAG_L1', 'NeuralNetTorch_r41_BAG_L1', 'XGBoost_r98_BAG_L1', 'LightGBM_r15_BAG_L1', 'NeuralNetTorch_r158_BAG_L1', 'CatBoost_r86_BAG_L1', 'NeuralNetFastAI_r37_BAG_L1', 'NeuralNetTorch_r197_BAG_L1', 'CatBoost_r49_BAG_L1', 'ExtraTrees_r49_BAG_L1', 'LightGBM_r143_BAG_L1', 'RandomForest_r127_BAG_L1', 'NeuralNetFastAI_r134_BAG_L1', 'RandomForest_r34_BAG_L1', 'LightGBM_r94_BAG_L1', 'NeuralNetTorch_r143_BAG_L1', 'CatBoost_r128_BAG_L1', 'NeuralNetFastAI_r111_BAG_L1', 'NeuralNetTorch_r31_BAG_L1', 'ExtraTrees_r4_BAG_L1', 'NeuralNetFastAI_r65_BAG_L1', 'NeuralNetFastAI_r88_BAG_L1', 'LightGBM_r30_BAG_L1', 'XGBoost_r49_BAG_L1', 'CatBoost_r5_BAG_L1', 'NeuralNetTorch_r87_BAG_L1', 'NeuralNetTorch_r71_BAG_L1', 'CatBoost_r143_BAG_L1', 'ExtraTrees_r178_BAG_L1', 'RandomForest_r166_BAG_L1', 'XGBoost_r31_BAG_L1', 'NeuralNetTorch_r185_BAG_L1', 'NeuralNetFastAI_r160_BAG_L1', 'CatBoost_r60_BAG_L1', 'RandomForest_r15_BAG_L1', 'LightGBM_r135_BAG_L1', 'XGBoost_r22_BAG_L1', 'NeuralNetFastAI_r69_BAG_L1', 'CatBoost_r6_BAG_L1', 'NeuralNetFastAI_r138_BAG_L1', 'LightGBM_r121_BAG_L1', 'NeuralNetFastAI_r172_BAG_L1', 'CatBoost_r180_BAG_L1', 'NeuralNetTorch_r76_BAG_L1', 'ExtraTrees_r197_BAG_L1', 'NeuralNetTorch_r121_BAG_L1', 'NeuralNetFastAI_r127_BAG_L1', 'RandomForest_r16_BAG_L1', 'NeuralNetFastAI_r194_BAG_L1', 'CatBoost_r12_BAG_L1', 'NeuralNetTorch_r135_BAG_L1', 'NeuralNetFastAI_r4_BAG_L1', 'ExtraTrees_r126_BAG_L1', 'NeuralNetTorch_r36_BAG_L1', 'NeuralNetFastAI_r100_BAG_L1', 'CatBoost_r163_BAG_L1', 'CatBoost_r198_BAG_L1', 'NeuralNetFastAI_r187_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'CatBoost_r177_BAG_L2', 'NeuralNetTorch_r79_BAG_L2', 'LightGBM_r131_BAG_L2', 'NeuralNetFastAI_r191_BAG_L2', 'CatBoost_r9_BAG_L2', 'LightGBM_r96_BAG_L2', 'NeuralNetTorch_r22_BAG_L2', 'WeightedEnsemble_L3', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
