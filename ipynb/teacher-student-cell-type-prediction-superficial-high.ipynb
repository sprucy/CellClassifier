# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='high_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=5
# stacking的级别
num_stack_levels=2
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 3,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       6.65 GB / 15.92 GB (41.8%)
# Disk Space Avail:   312.38 GB / 931.51 GB (33.5%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-10-31 22:08:09,973	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8267
# 		Context path: "models\Teacher\high_quality-20241031-220804\ds_sub_fit\sub_fit_ho"
# (_dystack pid=34980) Running DyStack sub-fit ...
# (_dystack pid=34980) Beginning AutoGluon training ... Time limit = 891s
# (_dystack pid=34980) AutoGluon will save models to "models\Teacher\high_quality-20241031-220804\ds_sub_fit\sub_fit_ho"
# (_dystack pid=34980) Train Data Rows:    274
# (_dystack pid=34980) Train Data Columns: 36
# (_dystack pid=34980) Label Column:       label
# (_dystack pid=34980) Problem Type:       multiclass
# (_dystack pid=34980) Preprocessing data ...
# (_dystack pid=34980) Train Data Class Count: 3
# (_dystack pid=34980) Using Feature Generators to preprocess the data ...
# (_dystack pid=34980) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=34980) 	Available Memory:                    6351.71 MB
# (_dystack pid=34980) 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=34980) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=34980) 	Stage 1 Generators:
# (_dystack pid=34980) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=34980) 	Stage 2 Generators:
# (_dystack pid=34980) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=34980) 	Stage 3 Generators:
# (_dystack pid=34980) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=34980) 	Stage 4 Generators:
# (_dystack pid=34980) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=34980) 	Stage 5 Generators:
# (_dystack pid=34980) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=34980) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=34980) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=34980) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=34980) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=34980) 	0.1s = Fit runtime
# (_dystack pid=34980) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=34980) 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=34980) Data preprocessing and feature engineering runtime = 0.09s ...
# (_dystack pid=34980) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=34980) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=34980) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=34980) User-specified model hyperparameters to be fit:
# (_dystack pid=34980) {
# (_dystack pid=34980) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=34980) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=34980) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=34980) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=34980) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=34980) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=34980) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=34980) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=34980) }
# (_dystack pid=34980) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=34980) Fitting 110 L1 models ...
# (_dystack pid=34980) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.08s of the 891.34s of remaining time.
# (_dystack pid=34980) 	0.6861	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.0s	 = Training   runtime
# (_dystack pid=34980) 	0.1s	 = Validation runtime
# (_dystack pid=34980) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 591.63s of the 888.89s of remaining time.
# (_dystack pid=34980) 	0.8029	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.01s	 = Training   runtime
# (_dystack pid=34980) 	0.0s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 591.61s of the 888.87s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=34980) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=34980) 	11.39s	 = Training   runtime
# (_dystack pid=34980) 	0.12s	 = Validation runtime
# (_dystack pid=34980) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 575.43s of the 872.69s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=34980) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=34980) 	2.76s	 = Training   runtime
# (_dystack pid=34980) 	0.03s	 = Validation runtime
# (_dystack pid=34980) Fitting model: LightGBM_BAG_L1 ... Training model for up to 567.14s of the 864.4s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=34980) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=34980) 	2.79s	 = Training   runtime
# (_dystack pid=34980) 	0.01s	 = Validation runtime
# (_dystack pid=34980) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 559.03s of the 856.29s of remaining time.
# (_dystack pid=34980) 	0.8504	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.96s	 = Training   runtime
# (_dystack pid=34980) 	0.1s	 = Validation runtime
# (_dystack pid=34980) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 557.94s of the 855.2s of remaining time.
# (_dystack pid=34980) 	0.8394	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.79s	 = Training   runtime
# (_dystack pid=34980) 	0.09s	 = Validation runtime
# (_dystack pid=34980) Fitting model: CatBoost_BAG_L1 ... Training model for up to 557.04s of the 854.29s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=34980) 	0.854	 = Validation score   (accuracy)
# (_dystack pid=34980) 	17.0s	 = Training   runtime
# (_dystack pid=34980) 	0.0s	 = Validation runtime
# (_dystack pid=34980) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 534.9s of the 832.16s of remaining time.
# (_dystack pid=34980) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.79s	 = Training   runtime
# (_dystack pid=34980) 	0.11s	 = Validation runtime
# (_dystack pid=34980) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 533.98s of the 831.24s of remaining time.
# (_dystack pid=34980) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.85s	 = Training   runtime
# (_dystack pid=34980) 	0.1s	 = Validation runtime
# (_dystack pid=34980) Fitting model: XGBoost_BAG_L1 ... Training model for up to 533.01s of the 830.26s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=34980) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=34980) 	3.43s	 = Training   runtime
# (_dystack pid=34980) 	0.01s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 524.72s of the 821.98s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=42272) Stack (most recent call first):
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=42272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=41608)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py
# (_ray_fit pid=41608) "
# (_ray_fit pid=41608) , line
# (_ray_fit pid=41608) 282
# (_ray_fit pid=41608)  in
# (_ray_fit pid=41608) <module>
# (_ray_fit pid=41608)
# (_dystack pid=34980) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=34980) 	51.59s	 = Training   runtime
# (_dystack pid=34980) 	0.15s	 = Validation runtime
# (_dystack pid=34980) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 467.55s of the 764.8s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# (_ray_fit pid=32628) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 62x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=32628)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=32628)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=34980) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=34980) 	4.02s	 = Training   runtime
# (_dystack pid=34980) 	0.03s	 = Validation runtime
# (_dystack pid=34980) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 458.4s of the 755.66s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=34980) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=34980) 	19.39s	 = Training   runtime
# (_dystack pid=34980) 	0.02s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 433.33s of the 730.58s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=40572) Stack (most recent call first):
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40572)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=40572)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=34980) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=34980) 	15.42s	 = Training   runtime
# (_dystack pid=34980) 	0.22s	 = Validation runtime
# (_dystack pid=34980) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 412.74s of the 709.99s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_ray_fit pid=34432) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=34432)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=34432)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=34980) 	0.8577	 = Validation score   (accuracy)
# (_dystack pid=34980) 	2.54s	 = Training   runtime
# (_dystack pid=34980) 	0.02s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 404.48s of the 701.73s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=34980) 	0.8796	 = Validation score   (accuracy)
# (_dystack pid=34980) 	16.77s	 = Training   runtime
# (_dystack pid=34980) 	0.17s	 = Validation runtime
# (_dystack pid=34980) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 382.27s of the 679.53s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.15%)
# (_dystack pid=34980) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=34980) 	56.68s	 = Training   runtime
# (_dystack pid=34980) 	0.03s	 = Validation runtime
# (_dystack pid=34980) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 319.39s of the 616.64s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_ray_fit pid=27180) [1000]	valid_set's multi_error: 0.0588235
# (_dystack pid=34980) 	0.8248	 = Validation score   (accuracy)
# (_dystack pid=34980) 	2.82s	 = Training   runtime
# (_dystack pid=34980) 	0.0s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 311.6s of the 608.86s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=42456) Stack (most recent call first):
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=42456)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=42456)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=34980) 	0.8796	 = Validation score   (accuracy)
# (_dystack pid=34980) 	24.5s	 = Training   runtime
# (_dystack pid=34980) 	0.25s	 = Validation runtime
# (_dystack pid=34980) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 281.84s of the 579.09s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.69%)
# (_ray_fit pid=35476) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=35476)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=35476)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=34980) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=34980) 	5.27s	 = Training   runtime
# (_dystack pid=34980) 	0.02s	 = Validation runtime
# (_dystack pid=34980) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 271.26s of the 568.51s of remaining time.
# (_dystack pid=34980) 	0.854	 = Validation score   (accuracy)
# (_dystack pid=34980) 	0.99s	 = Training   runtime
# (_dystack pid=34980) 	0.1s	 = Validation runtime
# (_dystack pid=34980) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 270.14s of the 567.39s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_dystack pid=34980) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=34980) 	11.76s	 = Training   runtime
# (_dystack pid=34980) 	0.04s	 = Validation runtime
# (_dystack pid=34980) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 252.8s of the 550.05s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=34980) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=34980) 	11.98s	 = Training   runtime
# (_dystack pid=34980) 	0.14s	 = Validation runtime
# (_dystack pid=34980) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 235.72s of the 532.98s of remaining time.
# (_dystack pid=34980) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.95%)
# (_dystack pid=34980) 	0.8613	 = Validation score   (accuracy)
# (_dystack pid=34980) 	81.8s	 = Training   runtime
# (_dystack pid=34980) 	0.03s	 = Validation runtime
# (_dystack pid=34980) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 148.2s of the 445.45s of remaining time.
# (_dystack pid=34980) 	0.8394	 = Validation score   (accuracy)
# ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.9385	 = Validation score   (accuracy)
# 	14.59s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 228.36s of the 227.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.9223	 = Validation score   (accuracy)
# 	14.42s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 207.62s of the 207.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=7.02%)
# 	0.932	 = Validation score   (accuracy)
# 	165.56s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 34.94s of the 34.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.9385	 = Validation score   (accuracy)
# 	3.29s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 25.48s of the 25.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.03%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r22_BAG_L2.
# 2024-10-31 23:08:09,889	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -9.89s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	0.9417	 = Validation score   (accuracy)
# 	0.32s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2663.15s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 5.4 rows/s (39 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	5.5s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.29s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.95s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.96s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	2.53s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.83s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.81s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 2024-10-31 23:08:38,070	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	16.66s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.65s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	1.5s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r79_BAG_L1_FULL ...
# 	3.71s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# No improvement since epoch 1: early stopping
# 	1.12s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	3.85s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	0.19s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r22_BAG_L1_FULL ...
# 	2.87s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	0.18s	 = Training   runtime
# Fitting model: ExtraTrees_r42_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.97s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r137_BAG_L1_FULL ...
# 	0.99s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r102_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	2.51s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r13_BAG_L1_FULL ...
# 	7.29s	 = Training   runtime
# Fitting model: RandomForest_r195_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.28s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r188_BAG_L1_FULL ...
# 	0.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r145_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.65s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r89_BAG_L1_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r30_BAG_L1_FULL ...
# 	4.8s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r130_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r86_BAG_L1_FULL ...
# 	2.99s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r50_BAG_L1_FULL ...
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r11_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 16.
# 	1.07s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r194_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting model: ExtraTrees_r172_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.02s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r69_BAG_L1_FULL ...
# 	1.27s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r103_BAG_L1_FULL ...
# No improvement since epoch 0: early stopping
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r14_BAG_L1_FULL ...
# 	1.17s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r161_BAG_L1_FULL ...
# 	0.45s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r143_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 19.
# 	2.66s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r70_BAG_L1_FULL ...
# 	1.28s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r156_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 20.
# 	2.22s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r196_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting model: RandomForest_r39_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.16s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r167_BAG_L1_FULL ...
# 	3.76s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r95_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.75s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r41_BAG_L1_FULL ...
# 	1.62s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r98_BAG_L1_FULL ...
# 	0.14s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r15_BAG_L1_FULL ...
# 	0.33s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r158_BAG_L1_FULL ...
# 	4.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r86_BAG_L1_FULL ...
# 	4.81s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r37_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	2.35s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r197_BAG_L1_FULL ...
# 	0.83s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r49_BAG_L1_FULL ...
# 	0.92s	 = Training   runtime
# Fitting model: ExtraTrees_r49_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.11s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r143_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting model: RandomForest_r127_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.3s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r134_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 22.
# 	3.61s	 = Training   runtime
# Fitting model: RandomForest_r34_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.44s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r94_BAG_L1_FULL ...
# 	0.35s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r143_BAG_L1_FULL ...
# 	5.71s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r128_BAG_L1_FULL ...
# 	2.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r111_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	2.06s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r31_BAG_L1_FULL ...
# 	2.01s	 = Training   runtime
# Fitting model: ExtraTrees_r4_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.93s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r65_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 23.
# 	2.55s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r88_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	1.36s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r30_BAG_L1_FULL ...
# 	0.4s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r49_BAG_L1_FULL ...
# 	0.15s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r5_BAG_L1_FULL ...
# 	0.92s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r87_BAG_L1_FULL ...
# 	1.82s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r71_BAG_L1_FULL ...
# 	0.68s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r143_BAG_L1_FULL ...
# 	1.67s	 = Training   runtime
# Fitting model: ExtraTrees_r178_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.12s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.31s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r31_BAG_L1_FULL ...
# 	0.12s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_r185_BAG_L1_FULL ...
# 	2.32s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r160_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	0.6s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r60_BAG_L1_FULL ...
# 	1.45s	 = Training   runtime
# Fitting model: RandomForest_r15_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.34s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r135_BAG_L1_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_r22_BAG_L1_FULL ...
# 	0.06s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r69_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	0.63s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r6_BAG_L1_FULL ...
# 	0.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r138_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	0.79s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_r121_BAG_L1_FULL ...
# 	0.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_r172_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	1.77s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_r180_BAG_L1_FULL ...
# 	0.83s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetTorch_r79_BAG_L1': 1.0}
# 	0.49s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	0.44s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.34s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.9s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.04s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	0.86s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.99s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.86s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.71s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	1.7s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	1.17s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_r177_BAG_L2_FULL ...
# 	3.55s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_r79_BAG_L2_FULL ...
# 	1.69s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_r131_BAG_L2_FULL ...
# 	0.52s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_r191_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	0.42s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_r9_BAG_L2_FULL ...
# 	2.61s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_r96_BAG_L2_FULL ...
# 	0.23s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_BAG_L2': 1.0}
# 	0.32s	 = Training   runtime
# Updated best model to "LightGBM_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "LightGBM_BAG_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 148.92s ... Best model: "LightGBM_BAG_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\high_quality-20241031-220804")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: LightGBM_BAG_L2_FULL
# *** Summary of fit() ***
# Estimated performance of each model:
#                                 model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                 WeightedEnsemble_L3   0.941748    accuracy       9.238577  1325.587987                0.000000           0.323750            3      False        108
# 1                     LightGBM_BAG_L2   0.941748    accuracy       9.238577  1325.264238                0.072382           9.451713            2      False         93
# 2                 LightGBM_r96_BAG_L2   0.938511    accuracy       9.189218  1319.103193                0.023023           3.290668            2      False        107
# 3                LightGBMLarge_BAG_L2   0.938511    accuracy       9.207267  1352.599453                0.041072          36.786929            2      False        101
# 4                LightGBM_r131_BAG_L2   0.938511    accuracy       9.208974  1330.399279                0.042779          14.586755            2      False        104
# 5                CatBoost_r177_BAG_L2   0.938511    accuracy       9.247814  1553.128452                0.081619         237.315927            2      False        102
# 6                      XGBoost_BAG_L2   0.935275    accuracy       9.213806  1328.869558                0.047611          13.057033            2      False         99
# 7                   LightGBMXT_BAG_L2   0.932039    accuracy       9.235145  1320.741989                0.068950           4.929465            2      False         92
# 8                  CatBoost_r9_BAG_L2   0.932039    accuracy       9.272120  1481.373993                0.105925         165.561469            2      False        106
# 9               NeuralNetTorch_BAG_L2   0.932039    accuracy       9.805214  1340.012535                0.639019          24.200010            2      False        100
# 10                    CatBoost_BAG_L2   0.928803    accuracy       9.257826  1520.672144                0.091631         204.859619            2      False         96
# 11          NeuralNetTorch_r79_BAG_L2   0.925566    accuracy       9.847317  1339.203262                0.681122          23.390737            2      False        103
# 12              ExtraTreesEntr_BAG_L2   0.922330    accuracy       9.296001  1316.672357                0.129806           0.859833            2      False         98
# 13        NeuralNetFastAI_r191_BAG_L2   0.922330    accuracy       9.326704  1330.233637                0.160509          14.421113            2      False        105
# 14             NeuralNetFastAI_BAG_L2   0.922330    accuracy       9.345961  1327.575590                0.179766          11.763065            2      False         91
# 15            RandomForestEntr_BAG_L2   0.919094    accuracy       9.281939  1316.850404                0.115744           1.037879            2      False         95
# 16              ExtraTreesGini_BAG_L2   0.915858    accuracy       9.290613  1316.799422                0.124418           0.986898            2      False         97
# 17        NeuralNetFastAI_r191_BAG_L1   0.912621    accuracy       0.145426    13.838237                0.145426          13.838237            1      False         17
# 18        NeuralNetFastAI_r134_BAG_L1   0.912621    accuracy       0.180724    22.558109                0.180724          22.558109            1      False         59
# 19          NeuralNetTorch_r86_BAG_L1   0.912621    accuracy       0.207247    29.674718                0.207247          29.674718            1      False         32
# 20                WeightedEnsemble_L2   0.912621    accuracy       0.262504    24.945261                0.000000           0.494858            2      False         90
# 21          NeuralNetTorch_r79_BAG_L1   0.912621    accuracy       0.262504    24.450403                0.262504          24.450403            1      False         15
# 22            RandomForestGini_BAG_L2   0.912621    accuracy       9.305703  1316.713580                0.139508           0.901055            2      False         94
# 23               LightGBM_r130_BAG_L1   0.902913    accuracy       0.019365     3.915576                0.019365           3.915576            1      False         31
# 24               LightGBM_r121_BAG_L1   0.902913    accuracy       0.048018     5.439896                0.048018           5.439896            1      False         87
# 25                 XGBoost_r98_BAG_L1   0.902913    accuracy       0.074031     8.873812                0.074031           8.873812            1      False         49
# 26        NeuralNetFastAI_r145_BAG_L1   0.902913    accuracy       0.119103    12.021044                0.119103          12.021044            1      False         28
# 27         NeuralNetFastAI_r95_BAG_L1   0.902913    accuracy       0.129171    12.897579                0.129171          12.897579            1      False         47
# 28             NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.156043    10.490409                0.156043          10.490409            1      False          3
# 29        NeuralNetFastAI_r156_BAG_L1   0.902913    accuracy       0.164258    14.710381                0.164258          14.710381            1      False         43
# 30               LightGBMLarge_BAG_L1   0.899676    accuracy       0.014136     5.476315                0.014136           5.476315            1      False         13
# 31                LightGBM_r15_BAG_L1   0.899676    accuracy       0.018661     4.080727                0.018661           4.080727            1      False         50
# 32                 XGBoost_r89_BAG_L1   0.896440    accuracy       0.023372     4.447477                0.023372           4.447477            1      False         29
# 33                    LightGBM_BAG_L1   0.896440    accuracy       0.030689     3.416725                0.030689           3.416725            1      False          5
# 34                 XGBoost_r49_BAG_L1   0.896440    accuracy       0.030905     5.297535                0.030905           5.297535            1      False         70
# 35                XGBoost_r194_BAG_L1   0.896440    accuracy       0.094761     3.937306                0.094761           3.937306            1      False         35
# 36              ExtraTreesEntr_BAG_L1   0.896440    accuracy       0.129886     0.811369                0.129886           0.811369            1       True         10
# 37          NeuralNetTorch_r71_BAG_L1   0.896440    accuracy       0.197031    16.373440                0.197031          16.373440            1      False         73
# 38         NeuralNetTorch_r185_BAG_L1   0.896440    accuracy       0.247307    35.377483                0.247307          35.377483            1      False         78
# 39               LightGBM_r188_BAG_L1   0.893204    accuracy       0.010604     3.369099                0.010604           3.369099            1      False         27
# 40                  LightGBMXT_BAG_L1   0.893204    accuracy       0.026269     3.259429                0.026269           3.259429            1      False          4
# 41        NeuralNetFastAI_r138_BAG_L1   0.893204    accuracy       0.109656    14.579254                0.109656          14.579254            1      False         86
# 42        NeuralNetFastAI_r172_BAG_L1   0.893204    accuracy       0.152065    15.720455                0.152065          15.720455            1      False         88
# 43          NeuralNetTorch_r41_BAG_L1   0.893204    accuracy       0.217750    21.657255                0.217750          21.657255            1      False         48
# 44          NeuralNetTorch_r31_BAG_L1   0.893204    accuracy       0.218222    20.976703                0.218222          20.976703            1      False         65
# 45               CatBoost_r177_BAG_L1   0.889968    accuracy       0.013243    26.454760                0.013243          26.454760            1      False         14
# 46               LightGBM_r131_BAG_L1   0.889968    accuracy       0.017226     4.494274                0.017226           4.494274            1      False         16
# 47              ExtraTreesGini_BAG_L1   0.889968    accuracy       0.097150     0.829063                0.097150           0.829063            1       True          9
# 48              ExtraTrees_r49_BAG_L1   0.889968    accuracy       0.123156     1.111301                0.123156           1.111301            1       True         56
# 49               LightGBM_r161_BAG_L1   0.886731    accuracy       0.020187     3.925645                0.020187           3.925645            1      False         40
# 50                 CatBoost_r9_BAG_L1   0.886731    accuracy       0.020823    61.823872                0.020823          61.823872            1      False         18
# 51                 XGBoost_r33_BAG_L1   0.886731    accuracy       0.036920     6.785562                0.036920           6.785562            1      False         21
# 52                 XGBoost_r22_BAG_L1   0.886731    accuracy       0.038192     4.101746                0.038192           4.101746            1      False         83
# 53         NeuralNetFastAI_r69_BAG_L1   0.886731    accuracy       0.087563    11.610723                0.087563          11.610723            1      False         84
# 54        NeuralNetFastAI_r102_BAG_L1   0.886731    accuracy       0.194425    15.170401                0.194425          15.170401            1      False         24
# 55                CatBoost_r70_BAG_L1   0.883495    accuracy       0.007505    25.289023                0.007505          25.289023            1      False         42
# 56                 CatBoost_r5_BAG_L1   0.883495    accuracy       0.024045    13.938421                0.024045          13.938421            1      False         71
# 57                 XGBoost_r31_BAG_L1   0.883495    accuracy       0.039673     6.273433                0.039673           6.273433            1      False         77
# 58                     XGBoost_BAG_L1   0.883495    accuracy       0.041289     4.524839                0.041289           4.524839            1      False         11
# 59        NeuralNetFastAI_r103_BAG_L1   0.883495    accuracy       0.097534    11.074467                0.097534          11.074467            1      False         38
# 60              NeuralNetTorch_BAG_L1   0.883495    accuracy       0.211968    24.934419                0.211968          24.934419            1      False         12
# 61         NeuralNetTorch_r143_BAG_L1   0.883495    accuracy       0.218053    28.029281                0.218053          28.029281            1      False         62
# 62          NeuralNetTorch_r14_BAG_L1   0.883495    accuracy       0.237164    20.393398                0.237164          20.393398            1      False         39
# 63               CatBoost_r167_BAG_L1   0.880259    accuracy       0.018022    51.730369                0.018022          51.730369            1      False         46
# 64                CatBoost_r86_BAG_L1   0.880259    accuracy       0.019470    81.498010                0.019470          81.498010            1      False         52
# 65               CatBoost_r128_BAG_L1   0.880259    accuracy       0.031644    54.802028                0.031644          54.802028            1      False         63
# 66               LightGBM_r196_BAG_L1   0.880259    accuracy       0.033649     4.137869                0.033649           4.137869            1      False         44
# 67         NeuralNetFastAI_r11_BAG_L1   0.880259    accuracy       0.145850    13.040032                0.145850          13.040032            1      False         34
# 68         NeuralNetTorch_r158_BAG_L1   0.880259    accuracy       0.202504    36.496201                0.202504          36.496201            1      False         51
# 69                CatBoost_r60_BAG_L1   0.877023    accuracy       0.021491    20.644237                0.021491          20.644237            1      False         80
# 70               LightGBM_r135_BAG_L1   0.877023    accuracy       0.026074     2.921264                0.026074           2.921264            1      False         82
# 71               LightGBM_r143_BAG_L1   0.877023    accuracy       0.026210     4.310190                0.026210           4.310190            1      False         57
# 72                CatBoost_r49_BAG_L1   0.877023    accuracy       0.027748    13.343378                0.027748          13.343378            1      False         55
# 73          NeuralNetTorch_r30_BAG_L1   0.877023    accuracy       0.249457    28.592045                0.249457          28.592045            1      False         30
# 74         NeuralNetTorch_r197_BAG_L1   0.877023    accuracy       0.257487    20.189412                0.257487          20.189412            1      False         54
# 75                CatBoost_r50_BAG_L1   0.873786    accuracy       0.014852    11.290451                0.014852          11.290451            1      False         33
# 76                    CatBoost_BAG_L1   0.873786    accuracy       0.019545    28.290824                0.019545          28.290824            1      False          8
# 77               CatBoost_r143_BAG_L1   0.873786    accuracy       0.029247    41.681209                0.029247          41.681209            1      False         74
# 78                CatBoost_r69_BAG_L1   0.870550    accuracy       0.020417    14.646969                0.020417          14.646969            1      False         37
# 79                 CatBoost_r6_BAG_L1   0.870550    accuracy       0.021796    12.186646                0.021796          12.186646            1      False         85
# 80               CatBoost_r137_BAG_L1   0.867314    accuracy       0.015469    10.668142                0.015469          10.668142            1      False         23
# 81                LightGBM_r94_BAG_L1   0.867314    accuracy       0.039264     4.075016                0.039264           4.075016            1      False         61
# 82           RandomForest_r166_BAG_L1   0.867314    accuracy       0.116103     1.306772                0.116103           1.306772            1       True         76
# 83          NeuralNetTorch_r87_BAG_L1   0.867314    accuracy       0.213957    24.579528                0.213957          24.579528            1      False         72
# 84          NeuralNetTorch_r22_BAG_L1   0.867314    accuracy       0.265625    24.479945                0.265625          24.479945            1      False         20
# 85            RandomForestGini_BAG_L1   0.864078    accuracy       0.123399     0.951432                0.123399           0.951432            1       True          6
# 86            RandomForestEntr_BAG_L1   0.864078    accuracy       0.208147     0.955523                0.208147           0.955523            1       True          7
# 87               CatBoost_r180_BAG_L1   0.860841    accuracy       0.023427    13.479491                0.023427          13.479491            1      False         89
# 88                LightGBM_r30_BAG_L1   0.860841    accuracy       0.026843     3.967471                0.026843           3.967471            1      False         69
# 89              ExtraTrees_r42_BAG_L1   0.860841    accuracy       0.108747     0.972747                0.108747           0.972747            1       True         22
# 90           RandomForest_r195_BAG_L1   0.860841    accuracy       0.133558     1.277595                0.133558           1.277595            1       True         26
# 91                CatBoost_r13_BAG_L1   0.854369    accuracy       0.019248   100.012406                0.019248         100.012406            1      False         25
# 92         NeuralNetFastAI_r37_BAG_L1   0.851133    accuracy       0.163030    17.298418                0.163030          17.298418            1      False         53
# 93         NeuralNetFastAI_r88_BAG_L1   0.847896    accuracy       0.118774    15.832798                0.118774          15.832798            1      False         68
# 94             ExtraTrees_r172_BAG_L1   0.844660    accuracy       0.131388     1.017826                0.131388           1.017826            1       True         36
# 95         NeuralNetFastAI_r65_BAG_L1   0.844660    accuracy       0.171216    15.594440                0.171216          15.594440            1      False         67
# 96        NeuralNetFastAI_r160_BAG_L1   0.841424    accuracy       0.118207    11.995205                0.118207          11.995205            1      False         79
# 97            RandomForest_r39_BAG_L1   0.841424    accuracy       0.142492     1.155983                0.142492           1.155983            1       True         45
# 98        NeuralNetFastAI_r111_BAG_L1   0.838188    accuracy       0.133970    13.778674                0.133970          13.778674            1      False         64
# 99             ExtraTrees_r178_BAG_L1   0.834951    accuracy       0.104629     1.122025                0.104629           1.122025            1       True         75
# 100          RandomForest_r127_BAG_L1   0.828479    accuracy       0.125901     1.297054                0.125901           1.297054            1       True         58
# 101           RandomForest_r15_BAG_L1   0.822006    accuracy       0.132497     1.342609                0.132497           1.342609            1       True         81
# 102       NeuralNetFastAI_r143_BAG_L1   0.812298    accuracy       0.170647    15.670233                0.170647          15.670233            1      False         41
# 103             KNeighborsDist_BAG_L1   0.799353    accuracy       0.007078     0.010453                0.007078           0.010453            1       True          2
# 104               LightGBM_r96_BAG_L1   0.796117    accuracy       0.005194     2.370770                0.005194           2.370770            1      False         19
# 105              ExtraTrees_r4_BAG_L1   0.718447    accuracy       0.125335     0.934550                0.125335           0.934550            1       True         66
# 106           RandomForest_r34_BAG_L1   0.705502    accuracy       0.189019     1.443372                0.189019           1.443372            1       True         60
# 107             KNeighborsUnif_BAG_L1   0.686084    accuracy       0.314249     0.005549                0.314249           0.005549            1       True          1
# 108        KNeighborsDist_BAG_L1_FULL        NaN    accuracy       0.007078     0.010453                0.007078           0.010453            1       True        110
# 109        ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       0.097150     0.829063                0.097150           0.829063            1       True        117
# 110       ExtraTrees_r178_BAG_L1_FULL        NaN    accuracy       0.104629     1.122025                0.104629           1.122025            1       True        183
# 111        ExtraTrees_r42_BAG_L1_FULL        NaN    accuracy       0.108747     0.972747                0.108747           0.972747            1       True        130
# 112     RandomForest_r166_BAG_L1_FULL        NaN    accuracy       0.116103     1.306772                0.116103           1.306772            1       True        184
# 113        ExtraTrees_r49_BAG_L1_FULL        NaN    accuracy       0.123156     1.111301                0.123156           1.111301            1       True        164
# 114      RandomForestGini_BAG_L1_FULL        NaN    accuracy       0.123399     0.951432                0.123399           0.951432            1       True        114
# 115         ExtraTrees_r4_BAG_L1_FULL        NaN    accuracy       0.125335     0.934550                0.125335           0.934550            1       True        174
# 116     RandomForest_r127_BAG_L1_FULL        NaN    accuracy       0.125901     1.297054                0.125901           1.297054            1       True        166
# 117        ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       0.129886     0.811369                0.129886           0.811369            1       True        118
# 118       ExtraTrees_r172_BAG_L1_FULL        NaN    accuracy       0.131388     1.017826                0.131388           1.017826            1       True        144
# 119      RandomForest_r15_BAG_L1_FULL        NaN    accuracy       0.132497     1.342609                0.132497           1.342609            1       True        189
# 120     RandomForest_r195_BAG_L1_FULL        NaN    accuracy       0.133558     1.277595                0.133558           1.277595            1       True        134
# 121      RandomForest_r39_BAG_L1_FULL        NaN    accuracy       0.142492     1.155983                0.142492           1.155983            1       True        153
# 122      RandomForest_r34_BAG_L1_FULL        NaN    accuracy       0.189019     1.443372                0.189019           1.443372            1       True        168
# 123      RandomForestEntr_BAG_L1_FULL        NaN    accuracy       0.208147     0.955523                0.208147           0.955523            1       True        115
# 124        KNeighborsUnif_BAG_L1_FULL        NaN    accuracy       0.314249     0.005549                0.314249           0.005549            1       True        109
# 125           XGBoost_r98_BAG_L1_FULL        NaN    accuracy            NaN     0.144275                     NaN           0.144275            1       True        157
# 126           XGBoost_r89_BAG_L1_FULL        NaN    accuracy            NaN     0.216128                     NaN           0.216128            1       True        137
# 127           XGBoost_r49_BAG_L1_FULL        NaN    accuracy            NaN     0.146459                     NaN           0.146459            1       True        178
# 128           XGBoost_r33_BAG_L1_FULL        NaN    accuracy            NaN     0.184036                     NaN           0.184036            1       True        129
# 129           XGBoost_r31_BAG_L1_FULL        NaN    accuracy            NaN     0.118555                     NaN           0.118555            1       True        185
# 130           XGBoost_r22_BAG_L1_FULL        NaN    accuracy            NaN     0.059667                     NaN           0.059667            1       True        191
# 131          XGBoost_r194_BAG_L1_FULL        NaN    accuracy            NaN     0.148688                     NaN           0.148688            1       True        143
# 132               XGBoost_BAG_L2_FULL        NaN    accuracy            NaN   145.147064                     NaN           0.707039            2       True        207
# 133               XGBoost_BAG_L1_FULL        NaN    accuracy            NaN     0.208227                     NaN           0.208227            1       True        119
# 134          WeightedEnsemble_L3_FULL        NaN    accuracy            NaN   145.107437                     NaN           0.323750            3       True        216
# 135          WeightedEnsemble_L2_FULL        NaN    accuracy            NaN     4.205090                     NaN           0.494858            2       True        198
# 136      RandomForestGini_BAG_L2_FULL        NaN    accuracy            NaN   145.341081                0.139508           0.901055            2       True        202
# 137      RandomForestEntr_BAG_L2_FULL        NaN    accuracy            NaN   145.477905                0.115744           1.037879            2       True        203
# 138    NeuralNetTorch_r87_BAG_L1_FULL        NaN    accuracy            NaN     1.819098                     NaN           1.819098            1       True        180
# 139    NeuralNetTorch_r86_BAG_L1_FULL        NaN    accuracy            NaN     2.990392                     NaN           2.990392            1       True        140
# 140    NeuralNetTorch_r79_BAG_L2_FULL        NaN    accuracy            NaN   146.132948                     NaN           1.692922            2       True        211
# 141    NeuralNetTorch_r79_BAG_L1_FULL        NaN    accuracy            NaN     3.710232                     NaN           3.710232            1       True        123
# 142    NeuralNetTorch_r71_BAG_L1_FULL        NaN    accuracy            NaN     0.681705                     NaN           0.681705            1       True        181
# 143    NeuralNetTorch_r41_BAG_L1_FULL        NaN    accuracy            NaN     1.623909                     NaN           1.623909            1       True        156
# 144    NeuralNetTorch_r31_BAG_L1_FULL        NaN    accuracy            NaN     2.014537                     NaN           2.014537            1       True        173
# 145    NeuralNetTorch_r30_BAG_L1_FULL        NaN    accuracy            NaN     4.795082                     NaN           4.795082            1       True        138
# 146    NeuralNetTorch_r22_BAG_L1_FULL        NaN    accuracy            NaN     2.870631                     NaN           2.870631            1       True        128
# 147   NeuralNetTorch_r197_BAG_L1_FULL        NaN    accuracy            NaN     0.834518                     NaN           0.834518            1       True        162
# 148   NeuralNetTorch_r185_BAG_L1_FULL        NaN    accuracy            NaN     2.319507                     NaN           2.319507            1       True        186
# 149   NeuralNetTorch_r158_BAG_L1_FULL        NaN    accuracy            NaN     4.444815                     NaN           4.444815            1       True        159
# 150    NeuralNetTorch_r14_BAG_L1_FULL        NaN    accuracy            NaN     1.166178                     NaN           1.166178            1       True        147
# 151   NeuralNetTorch_r143_BAG_L1_FULL        NaN    accuracy            NaN     5.709779                     NaN           5.709779            1       True        170
# 152        NeuralNetTorch_BAG_L2_FULL        NaN    accuracy            NaN   146.143921                     NaN           1.703896            2       True        208
# 153        NeuralNetTorch_BAG_L1_FULL        NaN    accuracy            NaN    16.662261                     NaN          16.662261            1       True        120
# 154   NeuralNetFastAI_r95_BAG_L1_FULL        NaN    accuracy            NaN     0.753459                     NaN           0.753459            1       True        155
# 155   NeuralNetFastAI_r88_BAG_L1_FULL        NaN    accuracy            NaN     1.360166                     NaN           1.360166            1       True        176
# 156   NeuralNetFastAI_r69_BAG_L1_FULL        NaN    accuracy            NaN     0.632280                     NaN           0.632280            1       True        192
# 157   NeuralNetFastAI_r65_BAG_L1_FULL        NaN    accuracy            NaN     2.552608                     NaN           2.552608            1       True        175
# 158   NeuralNetFastAI_r37_BAG_L1_FULL        NaN    accuracy            NaN     2.351002                     NaN           2.351002            1       True        161
# 159  NeuralNetFastAI_r191_BAG_L2_FULL        NaN    accuracy            NaN   144.861250                     NaN           0.421224            2       True        213
# 160  NeuralNetFastAI_r191_BAG_L1_FULL        NaN    accuracy            NaN     1.123245                     NaN           1.123245            1       True        125
# 161  NeuralNetFastAI_r172_BAG_L1_FULL        NaN    accuracy            NaN     1.766202                     NaN           1.766202            1       True        196
# 162  NeuralNetFastAI_r160_BAG_L1_FULL        NaN    accuracy            NaN     0.600662                     NaN           0.600662            1       True        187
# 163  NeuralNetFastAI_r156_BAG_L1_FULL        NaN    accuracy            NaN     2.217335                     NaN           2.217335            1       True        151
# 164  NeuralNetFastAI_r145_BAG_L1_FULL        NaN    accuracy            NaN     0.647958                     NaN           0.647958            1       True        136
# 165  NeuralNetFastAI_r143_BAG_L1_FULL        NaN    accuracy            NaN     2.658811                     NaN           2.658811            1       True        149
# 166  NeuralNetFastAI_r138_BAG_L1_FULL        NaN    accuracy            NaN     0.790030                     NaN           0.790030            1       True        194
# 167  NeuralNetFastAI_r134_BAG_L1_FULL        NaN    accuracy            NaN     3.612342                     NaN           3.612342            1       True        167
# 168   NeuralNetFastAI_r11_BAG_L1_FULL        NaN    accuracy            NaN     1.068038                     NaN           1.068038            1       True        142
# 169  NeuralNetFastAI_r111_BAG_L1_FULL        NaN    accuracy            NaN     2.061532                     NaN           2.061532            1       True        172
# 170  NeuralNetFastAI_r103_BAG_L1_FULL        NaN    accuracy            NaN     0.722157                     NaN           0.722157            1       True        146
# 171  NeuralNetFastAI_r102_BAG_L1_FULL        NaN    accuracy            NaN     2.512402                     NaN           2.512402            1       True        132
# 172       NeuralNetFastAI_BAG_L2_FULL        NaN    accuracy            NaN   144.881099                     NaN           0.441074            2       True        199
# 173       NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN     5.502230                     NaN           5.502230            1       True        111
# 174          LightGBM_r96_BAG_L2_FULL        NaN    accuracy            NaN   144.674997                     NaN           0.234971            2       True        215
# 175          LightGBM_r96_BAG_L1_FULL        NaN    accuracy            NaN     0.190139                     NaN           0.190139            1       True        127
# 176          LightGBM_r94_BAG_L1_FULL        NaN    accuracy            NaN     0.353629                     NaN           0.353629            1       True        169
# 177          LightGBM_r30_BAG_L1_FULL        NaN    accuracy            NaN     0.404505                     NaN           0.404505            1       True        177
# 178         LightGBM_r196_BAG_L1_FULL        NaN    accuracy            NaN     0.304074                     NaN           0.304074            1       True        152
# 179         LightGBM_r188_BAG_L1_FULL        NaN    accuracy            NaN     0.274962                     NaN           0.274962            1       True        135
# 180         LightGBM_r161_BAG_L1_FULL        NaN    accuracy            NaN     0.454762                     NaN           0.454762            1       True        148
# 181          LightGBM_r15_BAG_L1_FULL        NaN    accuracy            NaN     0.326553                     NaN           0.326553            1       True        158
# 182         LightGBM_r143_BAG_L1_FULL        NaN    accuracy            NaN     0.353686                     NaN           0.353686            1       True        165
# 183         LightGBM_r135_BAG_L1_FULL        NaN    accuracy            NaN     0.290810                     NaN           0.290810            1       True        190
# 184         LightGBM_r131_BAG_L2_FULL        NaN    accuracy            NaN   144.957605                     NaN           0.517579            2       True        212
# 185         LightGBM_r131_BAG_L1_FULL        NaN    accuracy            NaN     0.291591                     NaN           0.291591            1       True        124
# 186         LightGBM_r130_BAG_L1_FULL        NaN    accuracy            NaN     0.299834                     NaN           0.299834            1       True        139
# 187         LightGBM_r121_BAG_L1_FULL        NaN    accuracy            NaN     0.537842                     NaN           0.537842            1       True        195
# 188              LightGBM_BAG_L2_FULL        NaN    accuracy            NaN   144.783687                     NaN           0.343662            2       True        201
# 189              LightGBM_BAG_L1_FULL        NaN    accuracy            NaN     0.292438                     NaN           0.292438            1       True        113
# 190            LightGBMXT_BAG_L2_FULL        NaN    accuracy            NaN   144.700442                     NaN           0.260416            2       True        200
# 191            LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN     0.349503                     NaN           0.349503            1       True        112
# 192         LightGBMLarge_BAG_L2_FULL        NaN    accuracy            NaN   145.607892                     NaN           1.167866            2       True        209
# 193         LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN     0.646079                     NaN           0.646079            1       True        121
# 194        ExtraTreesGini_BAG_L2_FULL        NaN    accuracy            NaN   145.426923                0.124418           0.986898            2       True        205
# 195        ExtraTreesEntr_BAG_L2_FULL        NaN    accuracy            NaN   145.299858                0.129806           0.859833            2       True        206
# 196           CatBoost_r9_BAG_L2_FULL        NaN    accuracy            NaN   147.054875                     NaN           2.614849            2       True        214
# 197           CatBoost_r9_BAG_L1_FULL        NaN    accuracy            NaN     3.854419                     NaN           3.854419            1       True        126
# 198          CatBoost_r86_BAG_L1_FULL        NaN    accuracy            NaN     4.811051                     NaN           4.811051            1       True        160
# 199          CatBoost_r70_BAG_L1_FULL        NaN    accuracy            NaN     1.278298                     NaN           1.278298            1       True        150
# 200           CatBoost_r6_BAG_L1_FULL        NaN    accuracy            NaN     0.528791                     NaN           0.528791            1       True        193
# 201          CatBoost_r69_BAG_L1_FULL        NaN    accuracy            NaN     1.266460                     NaN           1.266460            1       True        145
# 202          CatBoost_r60_BAG_L1_FULL        NaN    accuracy            NaN     1.450061                     NaN           1.450061            1       True        188
# 203           CatBoost_r5_BAG_L1_FULL        NaN    accuracy            NaN     0.924154                     NaN           0.924154            1       True        179
# 204          CatBoost_r50_BAG_L1_FULL        NaN    accuracy            NaN     0.595643                     NaN           0.595643            1       True        141
# 205          CatBoost_r49_BAG_L1_FULL        NaN    accuracy            NaN     0.922642                     NaN           0.922642            1       True        163
# 206         CatBoost_r180_BAG_L1_FULL        NaN    accuracy            NaN     0.829089                     NaN           0.829089            1       True        197
# 207         CatBoost_r177_BAG_L2_FULL        NaN    accuracy            NaN   147.991668                     NaN           3.551642            2       True        210
# 208         CatBoost_r177_BAG_L1_FULL        NaN    accuracy            NaN     1.501579                     NaN           1.501579            1       True        122
# 209         CatBoost_r167_BAG_L1_FULL        NaN    accuracy            NaN     3.760180                     NaN           3.760180            1       True        154
# 210         CatBoost_r143_BAG_L1_FULL        NaN    accuracy            NaN     1.666479                     NaN           1.666479            1       True        182
# 211          CatBoost_r13_BAG_L1_FULL        NaN    accuracy            NaN     7.287278                     NaN           7.287278            1       True        133
# 212         CatBoost_r137_BAG_L1_FULL        NaN    accuracy            NaN     0.989984                     NaN           0.989984            1       True        131
# 213         CatBoost_r128_BAG_L1_FULL        NaN    accuracy            NaN     2.531583                     NaN           2.531583            1       True        171
# 214              CatBoost_BAG_L2_FULL        NaN    accuracy            NaN   145.302197                     NaN           0.862171            2       True        204
# 215              CatBoost_BAG_L1_FULL        NaN    accuracy            NaN     2.525564                     NaN           2.525564            1       True        116
# Number of models trained: 216
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# LightGBM_BAG_L2_FULL
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.50      0.27      0.35        15
# Exc L2-3 LINC00507 FREM3 superficial       0.61      0.88      0.72        26
#             Exc L2-4 LINC00507 GLP2R       0.00      0.00      0.00         5
#
#                             accuracy                           0.59        46
#                            macro avg       0.37      0.38      0.36        46
#                         weighted avg       0.51      0.59      0.52        46
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ###  模型：CatBoost_BAG_L2_FULL测试效果

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel,model='CatBoost_BAG_L2_FULL')
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.71      0.33      0.45        15
# Exc L2-3 LINC00507 FREM3 superficial       0.67      0.92      0.77        26
#             Exc L2-4 LINC00507 GLP2R       0.67      0.40      0.50         5
#
#                             accuracy                           0.67        46
#                            macro avg       0.68      0.55      0.58        46
#                         weighted avg       0.68      0.67      0.64        46

# %% [markdown]
# ###  模型：XGBoost_r98_BAG_L1_FULL测试效果

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel,model='XGBoost_r98_BAG_L1_FULL')
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.58      0.47      0.52        15
# Exc L2-3 LINC00507 FREM3 superficial       0.77      0.88      0.82        26
#             Exc L2-4 LINC00507 GLP2R       0.75      0.60      0.67         5
#
#                             accuracy                           0.72        46
#                            macro avg       0.70      0.65      0.67        46
#                         weighted avg       0.71      0.72      0.71        46

# %% [markdown]
# ###  模型：LightGBMXT_BAG_L2_FULL测试效果

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel,model='LightGBMXT_BAG_L2_FULL')
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.67      0.27      0.38        15
# Exc L2-3 LINC00507 FREM3 superficial       0.63      0.92      0.75        26
#             Exc L2-4 LINC00507 GLP2R       1.00      0.40      0.57         5
#
#                             accuracy                           0.65        46
#                            macro avg       0.77      0.53      0.57        46
#                         weighted avg       0.68      0.65      0.61        46

# %% [markdown]
# ###  模型：LightGBMXT_BAG_L1_FULL测试效果

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel,model='LightGBMXT_BAG_L1_FULL')
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.62      0.53      0.57        15
# Exc L2-3 LINC00507 FREM3 superficial       0.79      0.85      0.81        26
#             Exc L2-4 LINC00507 GLP2R       0.60      0.60      0.60         5
#
#                             accuracy                           0.72        46
#                            macro avg       0.67      0.66      0.66        46
#                         weighted avg       0.71      0.72      0.71        46

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[ 8  6  1]
#  [ 3 22  1]
#  [ 2  0  3]]
# ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']
# ([<matplotlib.axis.YTick at 0x252ce3efdd0>,
#   <matplotlib.axis.YTick at 0x252ce3ee550>,
#   <matplotlib.axis.YTick at 0x252ce3ee950>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 8  6  1]
#  [ 3 22  1]
#  [ 2  0  3]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.293113                              0.556151
# 1           0.205970                              0.657167
# 2           0.194287                              0.640860
# 3           0.212669                              0.647852
# 4           0.178998                              0.699632
# 5           0.129090                              0.754622
# 6           0.288352                              0.598670
# 7           0.176244                              0.703802
# 8           0.177687                              0.676014
# 9           0.583487                              0.295057
# 10          0.588453                              0.309024
# 11          0.276691                              0.563927
# 12          0.442556                              0.466829
# 13          0.311652                              0.554319
# 14          0.157248                              0.699853
# 15          0.317099                              0.465112
# 16          0.204348                              0.686666
# 17          0.135958                              0.751962
# 18          0.268677                              0.593739
# 19          0.461295                              0.411531
# 20          0.307791                              0.401446
# 21          0.501303                              0.354299
# 22          0.162017                              0.718727
# 23          0.152106                              0.727681
# 24          0.624292                              0.237045
# 25          0.394160                              0.459200
# 26          0.739399                              0.134965
# 27          0.297110                              0.511348
# 28          0.155573                              0.728851
# 29          0.464370                              0.402574
# 30          0.661727                              0.189284
# 31          0.170059                              0.707322
# 32          0.180174                              0.697511
# 33          0.150844                              0.737237
# 34          0.277890                              0.586003
# 35          0.277326                              0.572321
# 36          0.360768                              0.485898
# 37          0.159088                              0.722540
# 38          0.150031                              0.731384
# 39          0.182909                              0.695123
# 40          0.276104                              0.469691
# 41          0.203411                              0.674779
# 42          0.164911                              0.720590
# 43          0.174005                              0.675516
# 44          0.148219                              0.734888
# 45          0.114997                              0.771518
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.150736
# 1                   0.136863
# 2                   0.164853
# 3                   0.139479
# 4                   0.121370
# 5                   0.116288
# 6                   0.112978
# 7                   0.119954
# 8                   0.146299
# 9                   0.121456
# 10                  0.102523
# 11                  0.159382
# 12                  0.090614
# 13                  0.134029
# 14                  0.142899
# 15                  0.217789
# 16                  0.108987
# 17                  0.112079
# 18                  0.137584
# 19                  0.127174
# 20                  0.290763
# 21                  0.144399
# 22                  0.119256
# 23                  0.120213
# 24                  0.138663
# 25                  0.146641
# 26                  0.125636
# 27                  0.191542
# 28                  0.115576
# 29                  0.133056
# 30                  0.148989
# 31                  0.122619
# 32                  0.122315
# 33                  0.111919
# 34                  0.136106
# 35                  0.150353
# 36                  0.153334
# 37                  0.118373
# 38                  0.118584
# 39                  0.121968
# 40                  0.254205
# 41                  0.121810
# 42                  0.114499
# 43                  0.150479
# 44                  0.116893
# 45                  0.113485

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	393.1s	= Expected runtime (78.62s per shuffle set)
# 	27.97s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# FAP_num_APs             0.004348  0.009722  0.186950  5  0.024366 -0.015670
# FAP_maxupstroke        -0.008696  0.039491  0.675869  5  0.072617 -0.090008
# TS1_avg_downstroke     -0.008696  0.032969  0.706475  5  0.059188 -0.076579
# TS2_avg_upstroke       -0.008696  0.011907  0.911096  5  0.015821 -0.033212
# input_resistance       -0.013043  0.019444  0.896000  5  0.026992 -0.053079
# TS1_halfwidth          -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_halfwidth          -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_peak               -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# TS2_maxupstroke        -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_rheobase           -0.017391  0.009722  0.991935  5  0.002626 -0.037409
# TS1_maxupstroke        -0.021739  0.026625  0.929036  5  0.033082 -0.076560
# TS1_adp_index          -0.021739  0.015372  0.982945  5  0.009912 -0.053390
# TS1_rheobase           -0.021739  0.015372  0.982945  5  0.009912 -0.053390
# TS2_avg_downstroke     -0.026087  0.018188  0.983661  5  0.011363 -0.063537
# TS2_adp_index          -0.026087  0.018188  0.983661  5  0.011363 -0.063537
# FAP_threshold          -0.026087  0.018188  0.983661  5  0.011363 -0.063537
# TS2_peak               -0.026087  0.018188  0.983661  5  0.011363 -0.063537
# TS2_up_down_ratio      -0.026087  0.009722  0.998059  5 -0.006069 -0.046105
# vmbaseM                -0.026087  0.009722  0.998059  5 -0.006069 -0.046105
# tau                    -0.026087  0.009722  0.998059  5 -0.006069 -0.046105
# TS1_up_down_ratio      -0.030435  0.019444  0.987552  5  0.009601 -0.070470
# sag                    -0.030435  0.011907  0.997682  5 -0.005918 -0.054951
# FAP_avg_downstroke     -0.030435  0.024786  0.974197  5  0.020601 -0.081470
# FAP_maxdownstroke      -0.030435  0.011907  0.997682  5 -0.005918 -0.054951
# TS1_maxdownstroke      -0.034783  0.011907  0.998581  5 -0.010266 -0.059299
# VmatSag                -0.034783  0.011907  0.998581  5 -0.010266 -0.059299
# TS1_num_APs            -0.034783  0.024786  0.982540  5  0.016253 -0.085818
# TS1_threshold          -0.043478  0.015372  0.998401  5 -0.011827 -0.075129
# TS1_avg_upstroke       -0.047826  0.018188  0.997909  5 -0.010376 -0.085276
# L23_depth_normalized   -0.052174  0.024786  0.995369  5 -0.001138 -0.103209
# TS2_threshold          -0.056522  0.032969  0.990719  5  0.011362 -0.124405
# TS2_maxdownstroke      -0.056522  0.019444  0.998555  5 -0.016486 -0.096557
# TS2_rheobase           -0.065217  0.021739  0.998715  5 -0.020456 -0.109979
# FAP_up_down_ratio      -0.069565  0.009722  0.999955  5 -0.049547 -0.089583
# TS2_num_APs            -0.073913  0.024786  0.998686  5 -0.022877 -0.124949
# FAP_avg_upstroke       -0.073913  0.011907  0.999922  5 -0.049396 -0.098430

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# LightGBM_BAG_L2_FULL
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'accuracy': 0.5869565217391305,
#  'balanced_accuracy': 0.3837606837606838,
#  'mcc': 0.15753589623444023,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     4
#  Exc L2-3 LINC00507 FREM3 superficial                 3
#  Exc L2-4 LINC00507 GLP2R                             1
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                        11
#  Exc L2-3 LINC00507 FREM3 superficial                                    23
#  Exc L2-4 LINC00507 GLP2R                                                 4
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     0  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.5,
#    'recall': 0.26666666666666666,
#    'f1-score': 0.34782608695652173,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.6052631578947368,
#    'recall': 0.8846153846153846,
#    'f1-score': 0.71875,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 0.0,
#    'recall': 0.0,
#    'f1-score': 0.0,
#    'support': 5.0},
#   'accuracy': 0.5869565217391305,
#   'macro avg': {'precision': 0.3684210526315789,
#    'recall': 0.38376068376068373,
#    'f1-score': 0.3555253623188406,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.5051487414187643,
#    'recall': 0.5869565217391305,
#    'f1-score': 0.519671550094518,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                                 model  score_test  score_val eval_metric  \
# 0    NeuralNetFastAI_r172_BAG_L1_FULL    0.760870        NaN    accuracy
# 1    NeuralNetFastAI_r103_BAG_L1_FULL    0.717391        NaN    accuracy
# 2             CatBoost_r5_BAG_L1_FULL    0.717391        NaN    accuracy
# 3           LightGBM_r196_BAG_L1_FULL    0.717391        NaN    accuracy
# 4             XGBoost_r98_BAG_L1_FULL    0.717391        NaN    accuracy
# ..                                ...         ...        ...         ...
# 211        NeuralNetFastAI_r65_BAG_L1         NaN   0.844660    accuracy
# 212       NeuralNetFastAI_r160_BAG_L1         NaN   0.841424    accuracy
# 213       NeuralNetFastAI_r111_BAG_L1         NaN   0.838188    accuracy
# 214       NeuralNetFastAI_r143_BAG_L1         NaN   0.812298    accuracy
# 215               LightGBM_r96_BAG_L1         NaN   0.796117    accuracy
#
#      pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0          0.020509            NaN   1.766202                 0.020509
# 1          0.007161            NaN   0.722157                 0.007161
# 2          0.010146            NaN   0.924154                 0.010146
# 3          0.010307            NaN   0.304074                 0.010307
# 4          0.012239            NaN   0.144275                 0.012239
# ..              ...            ...        ...                      ...
# 211             NaN       0.171216  15.594440                      NaN
# 212             NaN       0.118207  11.995205                      NaN
# 213             NaN       0.133970  13.778674                      NaN
# 214             NaN       0.170647  15.670233                      NaN
# 215             NaN       0.005194   2.370770                      NaN
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                       NaN           1.766202            1       True
# 1                       NaN           0.722157            1       True
# 2                       NaN           0.924154            1       True
# 3                       NaN           0.304074            1       True
# 4                       NaN           0.144275            1       True
# ..                      ...                ...          ...        ...
# 211                0.171216          15.594440            1      False
# 212                0.118207          11.995205            1      False
# 213                0.133970          13.778674            1      False
# 214                0.170647          15.670233            1      False
# 215                0.005194           2.370770            1      False
#
#      fit_order
# 0          196
# 1          146
# 2          179
# 3          152
# 4          157
# ..         ...
# 211         67
# 212         79
# 213         64
# 214         41
# 215         19
#
# [216 rows x 13 columns]

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_39048\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.178972                              0.699529
# 1            0.177383                              0.699886
# 2            0.158016                              0.724559
# 3            0.175441                              0.705148
# 4            0.248757                              0.635363
# ..                ...                                   ...
# 204          0.270571                              0.538761
# 205          0.176181                              0.701835
# 206          0.142680                              0.760215
# 207          0.228524                              0.620201
# 208          0.161870                              0.726422
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.121498
# 1                    0.122731
# 2                    0.117425
# 3                    0.119411
# 4                    0.115880
# ..                        ...
# 204                  0.190668
# 205                  0.121984
# 206                  0.097105
# 207                  0.151276
# 208                  0.111708
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (157, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_BAG_L2_FULL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.541703
# [100]	valid_set's soft_log_loss: -0.453092
# [150]	valid_set's soft_log_loss: -0.442463
# [200]	valid_set's soft_log_loss: -0.458619
# [250]	valid_set's soft_log_loss: -0.479432
# [300]	valid_set's soft_log_loss: -0.512146
# [350]	valid_set's soft_log_loss: -0.531141
# [400]	valid_set's soft_log_loss: -0.550917
# 	Note: model has different eval_metric than default.
# 	-0.4356	 = Validation score   (-soft_log_loss)
# 	1.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# [450]	valid_set's soft_log_loss: -0.570792
# 	Note: model has different eval_metric than default.
# 	-0.4571	 = Validation score   (-soft_log_loss)
# 	0.91s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0747447	test: -1.0847978	best: -1.0847978 (0)	total: 885ms	remaining: 2h 27m 33s
# 20:	learn: -0.8012539	test: -0.8180667	best: -0.8180667 (20)	total: 1.25s	remaining: 9m 51s
# 40:	learn: -0.6962048	test: -0.7004679	best: -0.7004679 (40)	total: 1.59s	remaining: 6m 27s
# 60:	learn: -0.6335566	test: -0.6238774	best: -0.6238774 (60)	total: 1.97s	remaining: 5m 20s
# 80:	learn: -0.5997440	test: -0.5870721	best: -0.5870721 (80)	total: 2.38s	remaining: 4m 51s
# 100:	learn: -0.5689980	test: -0.5497598	best: -0.5497598 (100)	total: 2.73s	remaining: 4m 27s
# 120:	learn: -0.5455789	test: -0.5193757	best: -0.5193757 (120)	total: 3.1s	remaining: 4m 13s
# 140:	learn: -0.5286544	test: -0.5048525	best: -0.5048525 (140)	total: 3.44s	remaining: 4m
# 160:	learn: -0.5138295	test: -0.4857427	best: -0.4857427 (160)	total: 3.79s	remaining: 3m 51s
# 180:	learn: -0.5019509	test: -0.4736971	best: -0.4736971 (180)	total: 4.13s	remaining: 3m 44s
# 200:	learn: -0.4899048	test: -0.4567650	best: -0.4567650 (200)	total: 4.49s	remaining: 3m 39s
# 220:	learn: -0.4801747	test: -0.4517857	best: -0.4517857 (220)	total: 4.84s	remaining: 3m 34s
# 240:	learn: -0.4726945	test: -0.4474224	best: -0.4474224 (240)	total: 5.23s	remaining: 3m 31s
# 260:	learn: -0.4654815	test: -0.4370695	best: -0.4370695 (260)	total: 5.6s	remaining: 3m 29s
# 280:	learn: -0.4591492	test: -0.4327624	best: -0.4327624 (280)	total: 5.97s	remaining: 3m 26s
# 300:	learn: -0.4536020	test: -0.4280102	best: -0.4280102 (300)	total: 6.34s	remaining: 3m 24s
# 320:	learn: -0.4487602	test: -0.4251193	best: -0.4251193 (320)	total: 6.69s	remaining: 3m 21s
# 340:	learn: -0.4445160	test: -0.4232477	best: -0.4229613 (336)	total: 7.04s	remaining: 3m 19s
# 360:	learn: -0.4408110	test: -0.4204960	best: -0.4204960 (360)	total: 7.45s	remaining: 3m 18s
# 380:	learn: -0.4371649	test: -0.4189587	best: -0.4189587 (380)	total: 7.83s	remaining: 3m 17s
# 400:	learn: -0.4338508	test: -0.4162152	best: -0.4162152 (400)	total: 8.19s	remaining: 3m 15s
# 420:	learn: -0.4307586	test: -0.4164379	best: -0.4142970 (411)	total: 8.54s	remaining: 3m 14s
# 440:	learn: -0.4276778	test: -0.4137451	best: -0.4137451 (440)	total: 8.91s	remaining: 3m 13s
# 460:	learn: -0.4250287	test: -0.4107452	best: -0.4107452 (460)	total: 9.29s	remaining: 3m 12s
# 480:	learn: -0.4225483	test: -0.4084615	best: -0.4084615 (480)	total: 9.66s	remaining: 3m 11s
# 500:	learn: -0.4204109	test: -0.4096401	best: -0.4082875 (484)	total: 10s	remaining: 3m 10s
# 520:	learn: -0.4183657	test: -0.4110032	best: -0.4082875 (484)	total: 10.4s	remaining: 3m 9s
# 540:	learn: -0.4166697	test: -0.4102835	best: -0.4082875 (484)	total: 10.8s	remaining: 3m 8s
# 560:	learn: -0.4148708	test: -0.4108963	best: -0.4082875 (484)	total: 11.1s	remaining: 3m 7s
# 580:	learn: -0.4133330	test: -0.4105340	best: -0.4082875 (484)	total: 11.5s	remaining: 3m 6s
# 600:	learn: -0.4118463	test: -0.4116143	best: -0.4082875 (484)	total: 11.8s	remaining: 3m 5s
# 620:	learn: -0.4105902	test: -0.4096111	best: -0.4082875 (484)	total: 12.2s	remaining: 3m 4s
# 640:	learn: -0.4093438	test: -0.4094603	best: -0.4082875 (484)	total: 12.6s	remaining: 3m 3s
# 660:	learn: -0.4081230	test: -0.4095911	best: -0.4082875 (484)	total: 12.9s	remaining: 3m 2s
# 680:	learn: -0.4067610	test: -0.4087095	best: -0.4082875 (484)	total: 13.3s	remaining: 3m 2s
# 700:	learn: -0.4057645	test: -0.4084086	best: -0.4082875 (484)	total: 13.7s	remaining: 3m 1s
# 720:	learn: -0.4046210	test: -0.4063182	best: -0.4061703 (715)	total: 14s	remaining: 3m
# 740:	learn: -0.4035815	test: -0.4075684	best: -0.4061703 (715)	total: 14.4s	remaining: 2m 59s
# 760:	learn: -0.4026546	test: -0.4064554	best: -0.4061703 (715)	total: 14.7s	remaining: 2m 59s
# 780:	learn: -0.4018616	test: -0.4056218	best: -0.4054922 (774)	total: 15.1s	remaining: 2m 58s
# 800:	learn: -0.4010827	test: -0.4058793	best: -0.4054022 (781)	total: 15.5s	remaining: 2m 57s
# 820:	learn: -0.4003846	test: -0.4074992	best: -0.4054022 (781)	total: 15.9s	remaining: 2m 57s
# 840:	learn: -0.3996945	test: -0.4075291	best: -0.4054022 (781)	total: 16.2s	remaining: 2m 56s
# 860:	learn: -0.3990246	test: -0.4076452	best: -0.4054022 (781)	total: 16.6s	remaining: 2m 56s
# 880:	learn: -0.3982806	test: -0.4078609	best: -0.4054022 (781)	total: 17s	remaining: 2m 56s
# 900:	learn: -0.3976504	test: -0.4085484	best: -0.4054022 (781)	total: 17.3s	remaining: 2m 55s
# 920:	learn: -0.3971105	test: -0.4090163	best: -0.4054022 (781)	total: 17.7s	remaining: 2m 54s
# 940:	learn: -0.3965655	test: -0.4088115	best: -0.4054022 (781)	total: 18.1s	remaining: 2m 54s
# 960:	learn: -0.3960067	test: -0.4068447	best: -0.4054022 (781)	total: 18.4s	remaining: 2m 53s
# 980:	learn: -0.3954275	test: -0.4085692	best: -0.4054022 (781)	total: 18.8s	remaining: 2m 52s
# 1000:	learn: -0.3948993	test: -0.4092232	best: -0.4054022 (781)	total: 19.2s	remaining: 2m 52s
# 1020:	learn: -0.3943916	test: -0.4100551	best: -0.4054022 (781)	total: 19.5s	remaining: 2m 51s
# 1040:	learn: -0.3938579	test: -0.4106529	best: -0.4054022 (781)	total: 19.9s	remaining: 2m 51s
# 1060:	learn: -0.3934291	test: -0.4113315	best: -0.4054022 (781)	total: 20.3s	remaining: 2m 50s
# 	Note: model has different eval_metric than default.
# 	-0.4054	 = Validation score   (-soft_log_loss)
# 	22.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# 1080:	learn: -0.3929651	test: -0.4113141	best: -0.4054022 (781)	total: 20.6s	remaining: 2m 50s
#
# bestTest = -0.4054022237
# bestIteration = 781
#
# Shrink model to first 782 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5383	 = Validation score   (-soft_log_loss)
# 	4.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.708, 'LightGBM_DSTL': 0.208, 'RandomForestMSE_DSTL': 0.083}
# 	Note: model has different eval_metric than default.
# 	-0.4021	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_DSTL   0.838710  soft_log_loss       0.000000  22.405116                0.000000          22.405116            1       True        219
# 1             LightGBM_DSTL   0.838710  soft_log_loss       0.004035   1.670377                0.004035           1.670377            1       True        217
# 2  WeightedEnsemble_L2_DSTL   0.838710  soft_log_loss       0.058721  25.023490                0.001567           0.036017            2       True        221
# 3      RandomForestMSE_DSTL   0.806452  soft_log_loss       0.053119   0.911980                0.053119           0.911980            1       True        218
# 4       NeuralNetTorch_DSTL   0.790323  soft_log_loss       0.020157   4.317346                0.020157           4.317346            1       True        220
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                                model  score_test  score_val eval_metric  \
# 130              WeightedEnsemble_L3         NaN   0.941748    accuracy
# 131                  LightGBM_BAG_L2         NaN   0.941748    accuracy
# 132              LightGBM_r96_BAG_L2         NaN   0.938511    accuracy
# 133             LightGBMLarge_BAG_L2         NaN   0.938511    accuracy
# 134             LightGBM_r131_BAG_L2         NaN   0.938511    accuracy
# ..                               ...         ...        ...         ...
# 123  NeuralNetTorch_r158_BAG_L1_FULL    0.478261        NaN    accuracy
# 124   NeuralNetTorch_r79_BAG_L1_FULL    0.434783        NaN    accuracy
# 125         WeightedEnsemble_L2_FULL    0.434783        NaN    accuracy
# 126       KNeighborsUnif_BAG_L1_FULL    0.391304        NaN    accuracy
# 129       KNeighborsDist_BAG_L1_FULL    0.391304        NaN    accuracy
#
#      pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 130             NaN       9.238577  1325.587987                      NaN
# 131             NaN       9.238577  1325.264238                      NaN
# 132             NaN       9.189218  1319.103193                      NaN
# 133             NaN       9.207267  1352.599453                      NaN
# 134             NaN       9.208974  1330.399279                      NaN
# ..              ...            ...          ...                      ...
# 123        0.038817            NaN     4.444815                 0.038817
# 124        0.024794            NaN     3.710232                 0.024794
# 125        0.032808            NaN     4.205090                 0.008014
# 126        0.000000       0.314249     0.005549                 0.000000
# 129        0.009710       0.007078     0.010453                 0.009710
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 130                0.000000           0.323750            3      False
# 131                0.072382           9.451713            2      False
# 132                0.023023           3.290668            2      False
# 133                0.041072          36.786929            2      False
# 134                0.042779          14.586755            2      False
# ..                      ...                ...          ...        ...
# 123                     NaN           4.444815            1       True
# 124                     NaN           3.710232            1       True
# 125                     NaN           0.494858            2       True
# 126                0.314249           0.005549            1       True
# 129                0.007078           0.010453            1       True
#
#      fit_order
# 130        108
# 131         93
# 132        107
# 133        101
# 134        104
# ..         ...
# 123        159
# 124        123
# 125        198
# 126        109
# 129        110
#
# [221 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7391304347826086
# Evaluations on test data:
# {
#     "accuracy": 0.7391304347826086,
#     "balanced_accuracy": 0.682051282051282,
#     "mcc": 0.5371025488716094
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6923076923076923,
#         "recall": 0.6,
#         "f1-score": 0.6428571428571429,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8148148148148148,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8301886792452831,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.6,
#         "f1-score": 0.5454545454545454,
#         "support": 5.0
#     },
#     "accuracy": 0.7391304347826086,
#     "macro avg": {
#         "precision": 0.6690408357075023,
#         "recall": 0.682051282051282,
#         "f1-score": 0.6728334558523238,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7406478384739255,
#         "recall": 0.7391304347826086,
#         "f1-score": 0.7381529463153746,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7391304347826086, 'balanced_accuracy': 0.682051282051282, 'mcc': 0.5371025488716094, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     9
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             2
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             1
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     3  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6923076923076923, 'recall': 0.6, 'f1-score': 0.6428571428571429, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8148148148148148, 'recall': 0.8461538461538461, 'f1-score': 0.8301886792452831, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.6, 'f1-score': 0.5454545454545454, 'support': 5.0}, 'accuracy': 0.7391304347826086, 'macro avg': {'precision': 0.6690408357075023, 'recall': 0.682051282051282, 'f1-score': 0.6728334558523238, 'support': 46.0}, 'weighted avg': {'precision': 0.7406478384739255, 'recall': 0.7391304347826086, 'f1-score': 0.7381529463153746, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.69      0.60      0.64        15
# Exc L2-3 LINC00507 FREM3 superficial       0.81      0.85      0.83        26
#             Exc L2-4 LINC00507 GLP2R       0.50      0.60      0.55         5
#
#                             accuracy                           0.74        46
#                            macro avg       0.67      0.68      0.67        46
#                         weighted avg       0.74      0.74      0.74        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.516506
# [100]	valid_set's soft_log_loss: -0.444983
# [150]	valid_set's soft_log_loss: -0.448503
# [200]	valid_set's soft_log_loss: -0.4687
# [250]	valid_set's soft_log_loss: -0.504474
# [300]	valid_set's soft_log_loss: -0.569353
# 	Note: model has different eval_metric than default.
# 	-0.4433	 = Validation score   (-soft_log_loss)
# 	1.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# [350]	valid_set's soft_log_loss: -0.59071
# [400]	valid_set's soft_log_loss: -0.592426
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4751	 = Validation score   (-soft_log_loss)
# 	0.88s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0719682	test: -1.0722029	best: -1.0722029 (0)	total: 614ms	remaining: 1h 42m 22s
# 20:	learn: -0.7851252	test: -0.8178230	best: -0.8178230 (20)	total: 959ms	remaining: 7m 35s
# 40:	learn: -0.6612021	test: -0.6946892	best: -0.6946892 (40)	total: 1.31s	remaining: 5m 19s
# 60:	learn: -0.5994635	test: -0.6270742	best: -0.6270742 (60)	total: 1.69s	remaining: 4m 35s
# 80:	learn: -0.5599654	test: -0.5864258	best: -0.5864258 (80)	total: 2.02s	remaining: 4m 7s
# 100:	learn: -0.5247700	test: -0.5527494	best: -0.5527494 (100)	total: 2.36s	remaining: 3m 51s
# 120:	learn: -0.4994573	test: -0.5288270	best: -0.5288270 (120)	total: 2.71s	remaining: 3m 41s
# 140:	learn: -0.4786846	test: -0.5148789	best: -0.5148789 (140)	total: 3.09s	remaining: 3m 35s
# 160:	learn: -0.4610819	test: -0.5003301	best: -0.5003301 (160)	total: 3.42s	remaining: 3m 29s
# 180:	learn: -0.4466103	test: -0.4834755	best: -0.4834755 (180)	total: 3.77s	remaining: 3m 24s
# 200:	learn: -0.4323089	test: -0.4723295	best: -0.4723295 (200)	total: 4.12s	remaining: 3m 21s
# 220:	learn: -0.4227145	test: -0.4666604	best: -0.4666604 (220)	total: 4.51s	remaining: 3m 19s
# 240:	learn: -0.4138842	test: -0.4624490	best: -0.4619995 (238)	total: 4.84s	remaining: 3m 16s
# 260:	learn: -0.4055349	test: -0.4540675	best: -0.4540320 (256)	total: 5.19s	remaining: 3m 13s
# 280:	learn: -0.3981233	test: -0.4515863	best: -0.4515863 (280)	total: 5.53s	remaining: 3m 11s
# 300:	learn: -0.3923111	test: -0.4453102	best: -0.4451808 (299)	total: 5.87s	remaining: 3m 9s
# 320:	learn: -0.3871468	test: -0.4420354	best: -0.4420354 (320)	total: 6.22s	remaining: 3m 7s
# 340:	learn: -0.3825655	test: -0.4391520	best: -0.4391520 (340)	total: 6.6s	remaining: 3m 6s
# 360:	learn: -0.3778668	test: -0.4359492	best: -0.4355905 (357)	total: 6.97s	remaining: 3m 6s
# 380:	learn: -0.3740425	test: -0.4316305	best: -0.4316305 (380)	total: 7.32s	remaining: 3m 4s
# 400:	learn: -0.3705004	test: -0.4272551	best: -0.4272551 (400)	total: 7.68s	remaining: 3m 3s
# 420:	learn: -0.3676225	test: -0.4269493	best: -0.4265615 (411)	total: 8.04s	remaining: 3m 2s
# 440:	learn: -0.3645863	test: -0.4255925	best: -0.4255267 (439)	total: 8.41s	remaining: 3m 2s
# 460:	learn: -0.3619212	test: -0.4239271	best: -0.4237058 (452)	total: 8.8s	remaining: 3m 2s
# 480:	learn: -0.3590649	test: -0.4242694	best: -0.4237058 (452)	total: 9.14s	remaining: 3m
# 500:	learn: -0.3561464	test: -0.4241199	best: -0.4232846 (497)	total: 9.53s	remaining: 3m
# 520:	learn: -0.3539175	test: -0.4245953	best: -0.4232846 (497)	total: 9.94s	remaining: 3m
# 540:	learn: -0.3521030	test: -0.4243544	best: -0.4232846 (497)	total: 10.3s	remaining: 2m 59s
# 560:	learn: -0.3501668	test: -0.4239245	best: -0.4230557 (553)	total: 10.6s	remaining: 2m 59s
# 580:	learn: -0.3483870	test: -0.4212328	best: -0.4210280 (577)	total: 11s	remaining: 2m 58s
# 600:	learn: -0.3468970	test: -0.4218195	best: -0.4208451 (583)	total: 11.3s	remaining: 2m 57s
# 620:	learn: -0.3454777	test: -0.4206467	best: -0.4206467 (620)	total: 11.7s	remaining: 2m 56s
# 640:	learn: -0.3439816	test: -0.4207092	best: -0.4204163 (629)	total: 12.1s	remaining: 2m 57s
# 660:	learn: -0.3426720	test: -0.4210293	best: -0.4204163 (629)	total: 12.5s	remaining: 2m 56s
# 680:	learn: -0.3413042	test: -0.4230399	best: -0.4204163 (629)	total: 12.8s	remaining: 2m 55s
# 700:	learn: -0.3400676	test: -0.4231691	best: -0.4204163 (629)	total: 13.2s	remaining: 2m 55s
# 720:	learn: -0.3388644	test: -0.4243132	best: -0.4204163 (629)	total: 13.5s	remaining: 2m 54s
# 740:	learn: -0.3376968	test: -0.4260715	best: -0.4204163 (629)	total: 13.9s	remaining: 2m 54s
# 760:	learn: -0.3366185	test: -0.4259217	best: -0.4204163 (629)	total: 14.3s	remaining: 2m 53s
# 780:	learn: -0.3357244	test: -0.4271183	best: -0.4204163 (629)	total: 14.7s	remaining: 2m 53s
# 800:	learn: -0.3347191	test: -0.4281030	best: -0.4204163 (629)	total: 15.1s	remaining: 2m 53s
# 820:	learn: -0.3336707	test: -0.4283505	best: -0.4204163 (629)	total: 15.4s	remaining: 2m 52s
# 840:	learn: -0.3329562	test: -0.4280939	best: -0.4204163 (629)	total: 15.8s	remaining: 2m 51s
# 860:	learn: -0.3323829	test: -0.4288152	best: -0.4204163 (629)	total: 16.1s	remaining: 2m 51s
# 880:	learn: -0.3315327	test: -0.4317938	best: -0.4204163 (629)	total: 16.5s	remaining: 2m 50s
# 900:	learn: -0.3308927	test: -0.4316326	best: -0.4204163 (629)	total: 16.9s	remaining: 2m 50s
# 920:	learn: -0.3300590	test: -0.4324839	best: -0.4204163 (629)	total: 17.2s	remaining: 2m 49s
#
# bestTest = -0.420416287
# bestIteration = 629
#
# Shrink model to first 630 iterations.
# 	Note: model has different eval_metric than default.
# 	-0.4204	 = Validation score   (-soft_log_loss)
# 	18.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.524	 = Validation score   (-soft_log_loss)
# 	4.51s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.722, 'LightGBM_2_DSTL': 0.278}
# 	Note: model has different eval_metric than default.
# 	-0.4116	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_2_DSTL   0.870968  soft_log_loss       0.000000   1.269862                0.000000           1.269862            1       True        222
# 1       NeuralNetTorch_2_DSTL   0.854839  soft_log_loss       0.022956   4.512725                0.022956           4.512725            1       True        225
# 2  WeightedEnsemble_2_L2_DSTL   0.838710  soft_log_loss       0.005049  19.870147                0.000000           0.030414            2       True        226
# 3             CatBoost_2_DSTL   0.822581  soft_log_loss       0.005049  18.569870                0.005049          18.569870            1       True        224
# 4      RandomForestMSE_2_DSTL   0.822581  soft_log_loss       0.052312   0.882823                0.052312           0.882823            1       True        223
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                                 model  score_test  score_val    eval_metric  \
# 0    NeuralNetFastAI_r172_BAG_L1_FULL    0.760870        NaN       accuracy
# 1                     LightGBM_2_DSTL    0.739130   0.870968  soft_log_loss
# 2                       LightGBM_DSTL    0.739130   0.838710  soft_log_loss
# 3            WeightedEnsemble_L2_DSTL    0.739130   0.838710  soft_log_loss
# 11              ExtraTreesGini_BAG_L1    0.717391   0.889968       accuracy
# ..                                ...         ...        ...            ...
# 221        NeuralNetFastAI_r65_BAG_L1         NaN   0.844660       accuracy
# 222       NeuralNetFastAI_r160_BAG_L1         NaN   0.841424       accuracy
# 223       NeuralNetFastAI_r111_BAG_L1         NaN   0.838188       accuracy
# 224       NeuralNetFastAI_r143_BAG_L1         NaN   0.812298       accuracy
# 225               LightGBM_r96_BAG_L1         NaN   0.796117       accuracy
#
#      pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0          0.017389            NaN   1.766202                 0.017389
# 1          0.010235       0.000000   1.269862                 0.010235
# 2          0.015795       0.004035   1.670377                 0.015795
# 3          0.107816       0.058721  25.023490                 0.000000
# 11         0.069429       0.097150   0.829063                 0.069429
# ..              ...            ...        ...                      ...
# 221             NaN       0.171216  15.594440                      NaN
# 222             NaN       0.118207  11.995205                      NaN
# 223             NaN       0.133970  13.778674                      NaN
# 224             NaN       0.170647  15.670233                      NaN
# 225             NaN       0.005194   2.370770                      NaN
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                       NaN           1.766202            1       True
# 1                  0.000000           1.269862            1       True
# 2                  0.004035           1.670377            1       True
# 3                  0.001567           0.036017            2       True
# 11                 0.097150           0.829063            1       True
# ..                      ...                ...          ...        ...
# 221                0.171216          15.594440            1      False
# 222                0.118207          11.995205            1      False
# 223                0.133970          13.778674            1      False
# 224                0.170647          15.670233            1      False
# 225                0.005194           2.370770            1      False
#
#      fit_order
# 0          196
# 1          222
# 2          217
# 3          221
# 11           9
# ..         ...
# 221         67
# 222         79
# 223         64
# 224         41
# 225         19
#
# [226 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_2_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7391304347826086
# Evaluations on test data:
# {
#     "accuracy": 0.7391304347826086,
#     "balanced_accuracy": 0.7264957264957266,
#     "mcc": 0.558593516778775
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.7272727272727273,
#         "recall": 0.5333333333333333,
#         "f1-score": 0.6153846153846154,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8461538461538461,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8461538461538461,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.4444444444444444,
#         "recall": 0.8,
#         "f1-score": 0.5714285714285714,
#         "support": 5.0
#     },
#     "accuracy": 0.7391304347826086,
#     "macro avg": {
#         "precision": 0.6726236726236726,
#         "recall": 0.7264957264957266,
#         "f1-score": 0.6776556776556776,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7637241985068072,
#         "recall": 0.7391304347826086,
#         "f1-score": 0.7410415671285236,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7391304347826086, 'balanced_accuracy': 0.7264957264957266, 'mcc': 0.558593516778775, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     8
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         4
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             3
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.7272727272727273, 'recall': 0.5333333333333333, 'f1-score': 0.6153846153846154, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8461538461538461, 'recall': 0.8461538461538461, 'f1-score': 0.8461538461538461, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.4444444444444444, 'recall': 0.8, 'f1-score': 0.5714285714285714, 'support': 5.0}, 'accuracy': 0.7391304347826086, 'macro avg': {'precision': 0.6726236726236726, 'recall': 0.7264957264957266, 'f1-score': 0.6776556776556776, 'support': 46.0}, 'weighted avg': {'precision': 0.7637241985068072, 'recall': 0.7391304347826086, 'f1-score': 0.7410415671285236, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x252dc70d550>,
#   <matplotlib.axis.YTick at 0x252dc61ef10>,
#   <matplotlib.axis.YTick at 0x252dc8e9e50>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'CatBoost_r177_BAG_L1', 'NeuralNetTorch_r79_BAG_L1', 'LightGBM_r131_BAG_L1', 'NeuralNetFastAI_r191_BAG_L1', 'CatBoost_r9_BAG_L1', 'LightGBM_r96_BAG_L1', 'NeuralNetTorch_r22_BAG_L1', 'XGBoost_r33_BAG_L1', 'ExtraTrees_r42_BAG_L1', 'CatBoost_r137_BAG_L1', 'NeuralNetFastAI_r102_BAG_L1', 'CatBoost_r13_BAG_L1', 'RandomForest_r195_BAG_L1', 'LightGBM_r188_BAG_L1', 'NeuralNetFastAI_r145_BAG_L1', 'XGBoost_r89_BAG_L1', 'NeuralNetTorch_r30_BAG_L1', 'LightGBM_r130_BAG_L1', 'NeuralNetTorch_r86_BAG_L1', 'CatBoost_r50_BAG_L1', 'NeuralNetFastAI_r11_BAG_L1', 'XGBoost_r194_BAG_L1', 'ExtraTrees_r172_BAG_L1', 'CatBoost_r69_BAG_L1', 'NeuralNetFastAI_r103_BAG_L1', 'NeuralNetTorch_r14_BAG_L1', 'LightGBM_r161_BAG_L1', 'NeuralNetFastAI_r143_BAG_L1', 'CatBoost_r70_BAG_L1', 'NeuralNetFastAI_r156_BAG_L1', 'LightGBM_r196_BAG_L1', 'RandomForest_r39_BAG_L1', 'CatBoost_r167_BAG_L1', 'NeuralNetFastAI_r95_BAG_L1', 'NeuralNetTorch_r41_BAG_L1', 'XGBoost_r98_BAG_L1', 'LightGBM_r15_BAG_L1', 'NeuralNetTorch_r158_BAG_L1', 'CatBoost_r86_BAG_L1', 'NeuralNetFastAI_r37_BAG_L1', 'NeuralNetTorch_r197_BAG_L1', 'CatBoost_r49_BAG_L1', 'ExtraTrees_r49_BAG_L1', 'LightGBM_r143_BAG_L1', 'RandomForest_r127_BAG_L1', 'NeuralNetFastAI_r134_BAG_L1', 'RandomForest_r34_BAG_L1', 'LightGBM_r94_BAG_L1', 'NeuralNetTorch_r143_BAG_L1', 'CatBoost_r128_BAG_L1', 'NeuralNetFastAI_r111_BAG_L1', 'NeuralNetTorch_r31_BAG_L1', 'ExtraTrees_r4_BAG_L1', 'NeuralNetFastAI_r65_BAG_L1', 'NeuralNetFastAI_r88_BAG_L1', 'LightGBM_r30_BAG_L1', 'XGBoost_r49_BAG_L1', 'CatBoost_r5_BAG_L1', 'NeuralNetTorch_r87_BAG_L1', 'NeuralNetTorch_r71_BAG_L1', 'CatBoost_r143_BAG_L1', 'ExtraTrees_r178_BAG_L1', 'RandomForest_r166_BAG_L1', 'XGBoost_r31_BAG_L1', 'NeuralNetTorch_r185_BAG_L1', 'NeuralNetFastAI_r160_BAG_L1', 'CatBoost_r60_BAG_L1', 'RandomForest_r15_BAG_L1', 'LightGBM_r135_BAG_L1', 'XGBoost_r22_BAG_L1', 'NeuralNetFastAI_r69_BAG_L1', 'CatBoost_r6_BAG_L1', 'NeuralNetFastAI_r138_BAG_L1', 'LightGBM_r121_BAG_L1', 'NeuralNetFastAI_r172_BAG_L1', 'CatBoost_r180_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'CatBoost_r177_BAG_L2', 'NeuralNetTorch_r79_BAG_L2', 'LightGBM_r131_BAG_L2', 'NeuralNetFastAI_r191_BAG_L2', 'CatBoost_r9_BAG_L2', 'LightGBM_r96_BAG_L2', 'WeightedEnsemble_L3', 'KNeighborsUnif_BAG_L1_FULL', 'KNeighborsDist_BAG_L1_FULL', 'NeuralNetFastAI_BAG_L1_FULL', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'RandomForestGini_BAG_L1_FULL', 'RandomForestEntr_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'ExtraTreesGini_BAG_L1_FULL', 'ExtraTreesEntr_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'NeuralNetTorch_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'CatBoost_r177_BAG_L1_FULL', 'NeuralNetTorch_r79_BAG_L1_FULL', 'LightGBM_r131_BAG_L1_FULL', 'NeuralNetFastAI_r191_BAG_L1_FULL', 'CatBoost_r9_BAG_L1_FULL', 'LightGBM_r96_BAG_L1_FULL', 'NeuralNetTorch_r22_BAG_L1_FULL', 'XGBoost_r33_BAG_L1_FULL', 'ExtraTrees_r42_BAG_L1_FULL', 'CatBoost_r137_BAG_L1_FULL', 'NeuralNetFastAI_r102_BAG_L1_FULL', 'CatBoost_r13_BAG_L1_FULL', 'RandomForest_r195_BAG_L1_FULL', 'LightGBM_r188_BAG_L1_FULL', 'NeuralNetFastAI_r145_BAG_L1_FULL', 'XGBoost_r89_BAG_L1_FULL', 'NeuralNetTorch_r30_BAG_L1_FULL', 'LightGBM_r130_BAG_L1_FULL', 'NeuralNetTorch_r86_BAG_L1_FULL', 'CatBoost_r50_BAG_L1_FULL', 'NeuralNetFastAI_r11_BAG_L1_FULL', 'XGBoost_r194_BAG_L1_FULL', 'ExtraTrees_r172_BAG_L1_FULL', 'CatBoost_r69_BAG_L1_FULL', 'NeuralNetFastAI_r103_BAG_L1_FULL', 'NeuralNetTorch_r14_BAG_L1_FULL', 'LightGBM_r161_BAG_L1_FULL', 'NeuralNetFastAI_r143_BAG_ ...

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
