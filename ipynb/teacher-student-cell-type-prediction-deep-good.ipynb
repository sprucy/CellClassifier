# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Deep'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Deep
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (83, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 567754968 to 832627767
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance
non-null     object
# dtypes: float64(36), object(1)
# memory usage: 24.1+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 83
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      17 non-null     float64
#  1   sag                   17 non-null     float64
#  2   VmatSag               17 non-null     float64
#  3   vmbaseM               17 non-null     float64
#  4   tau                   17 non-null     float64
#  5   FAP_rheobase          17 non-null     float64
#  6   FAP_num_APs           17 non-null     float64
#  7   TS1_rheobase          17 non-null     float64
#  8   TS1_num_APs           17 non-null     float64
#  9   TS2_rheobase          17 non-null     float64
#  10  TS2_num_APs           17 non-null     float64
#  11  TS1_adp_index         17 non-null     float64
#  12  TS2_adp_index         17 non-null     float64
#  13  FAP_threshold         17 non-null     float64
#  14  FAP_peak              17 non-null     float64
#  15  FAP_maxupstroke       17 non-null     float64
#  16  FAP_maxdownstroke     17 non-null     float64
#  17  FAP_halfwidth         17 non-null     float64
#  18  FAP_avg_upstroke      17 non-null     float64
#  19  FAP_avg_downstroke    17 non-null     float64
#  20  FAP_up_down_ratio     17 non-null     float64
#  21  TS1_threshold         17 non-null     float64
#  22  TS1_maxupstroke       17 non-null     float64
#  23  TS1_maxdownstroke     17 non-null     float64
#  24  TS1_halfwidth         17 non-null     float64
#  25  TS1_avg_upstroke      17 non-null     float64
#  26  TS1_avg_downstroke    17 non-null     float64
#  27  TS1_up_down_ratio     17 non-null     float64
#  28  TS2_threshold         17 non-null     float64
#  29  TS2_peak              17 non-null     float64
#  30  TS2_maxupstroke       17 non-null     float64
#  31  TS2_maxdownstroke     17 non-null     float64
#  32  TS2_avg_upstroke      17 non-null     float64
#  33  TS2_avg_downstroke    17 non-null     float64
#  34  TS2_up_down_ratio     17 non-null     float64
#  35  L23_depth_normalized  17 non-null     float64
#  36  label                 17 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 5.0+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个bag数，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %% [markdown]
# ### presets 配置
# ```
# # Best predictive accuracy with little consideration to inference time or disk usage. Achieve even better results by specifying a large time_limit value.
# #Recommended for applications that benefit from the best possible model accuracy.
# best_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "zeroshot",
#     "time_limit": 3600,
# },
# # High predictive accuracy with fast inference. ~8x faster inference and ~8x lower disk usage than `best_quality`.
# # Recommended for applications that require fast inference speed and/or small model size.
# high_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "zeroshot",
#     "time_limit": 3600,
#     "refit_full": True,
#     "set_best_to_refit_full": True,
#     "save_bag_folds": False,
# },
# # Good predictive accuracy with very fast inference. ~4x faster training, ~8x faster inference and ~8x lower disk usage than `high_quality`.
# # Recommended for applications that require very fast inference speed.
# good_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "light",
#     "time_limit": 3600,
#     "refit_full": True,
#     "set_best_to_refit_full": True,
#     "save_bag_folds": False,
# },
# # Medium predictive accuracy with very fast inference and very fast training time. ~20x faster training than `good_quality`.
# # This is the default preset in AutoGluon, but should generally only be used for quick prototyping, as `good_quality` results in significantly better predictive # accuracy with similar inference time.
# medium_quality={"auto_stack": False},
# # Optimizes result immediately for deployment by deleting unused models and removing training artifacts.
# # Often can reduce disk usage by ~2-4x with no negatives to model accuracy or inference speed.
# # This will disable numerous advanced functionality, but has no impact on inference.
# # Recommended for applications where the inner details of AutoGluon's training is not important and there is no intention of manually choosing between the final models.
# # This preset pairs well with the other presets such as `good_quality` to make a very compact final model.
# # Identical to calling `predictor.delete_models(models_to_keep='best', dry_run=False)` and `predictor.save_space()` directly after `fit()`.
# ```

# %% [markdown]
# # hyperparameters 配置
#     # Default AutoGluon hyperparameters intended to maximize accuracy without significant regard to inference time or disk usage.
#     default={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#         "RF": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "XT": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "KNN": [
#             {"weights": "uniform", "ag_args": {"name_suffix": "Unif"}},
#             {"weights": "distance", "ag_args": {"name_suffix": "Dist"}},
#         ],
#     },
#     # Results in smaller models. Generally will make inference speed much faster and disk usage much lower, but with worse accuracy.
#     light={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#         "RF": [
#             {"criterion": "gini", "max_depth": 15, "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "max_depth": 15, "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "max_depth": 15, "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "XT": [
#             {"criterion": "gini", "max_depth": 15, "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "max_depth": 15, "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "max_depth": 15, "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#     },
#     # Results in much smaller models. Behaves similarly to 'light', but in many cases with over 10x less disk usage and a further reduction in accuracy.
#     very_light={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#     },
#     # Results in extremely quick to train models. Only use this when prototyping, as the model accuracy will be severely reduced.
#     toy={
#         "NN_TORCH": {"num_epochs": 5},
#         "GBM": {"num_boost_round": 10},
#         "CAT": {"iterations": 10},
#         "XGB": {"n_estimators": 10},
#     },
#     # Default AutoGluon hyperparameters intended to maximize accuracy in multimodal tabular + text datasets. Requires GPU.
#     multimodal={
#         "NN_TORCH": {},
#         "GBM": [
#             {},
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         # 'FASTAI': {},  # FastAI gets killed if the dataset is large (400K rows).
#         "AG_AUTOMM": {},
#         "VW": {},
#     },
#     # Hyperparameters intended to find an interpretable model which doesn't sacrifice predictive accuracy
#     interpretable={
#         "IM_RULEFIT": [{"max_rules": 7}, {"max_rules": 12}, {"max_rules": 18}],
#         "IM_FIGS": [{"max_rules": 6}, {"max_rules": 10}, {"max_rules": 15}],
#         # Note: Below are commented out because they are not meaningfully interpretable via the existing API
#         # 'IM_GREEDYTREE': [{'max_leaf_nodes': 7, 'max_leaf_nodes': 18}],
#         # 'IM_BOOSTEDRULES': [{'n_estimators': 5}, {'n_estimators': 10}],
#         # 'IM_HSTREE': [{'max_rules': 6}, {'max_rules': 12}, {'max_rules': 18}],
#     },
#     zeroshot_hpo={
#         "XT": [{"min_samples_leaf": 1, "max_leaf_nodes": 15000, "max_features": 0.5, "ag_args": {"name_suffix": "_r19", "priority": 20}}],
#         "RF": [{"min_samples_leaf": 5, "max_leaf_nodes": 50000, "max_features": 0.5, "ag_args": {"name_suffix": "_r5", "priority": 19}}],
#         "GBM": [
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.7248284762542815,
#                 "learning_rate": 0.07947286942946127,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 89,
#                 "ag_args": {"name_suffix": "_r158", "priority": 18},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7832570544199176,
#                 "learning_rate": 0.021720607471727896,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 21,
#                 "ag_args": {"name_suffix": "_r118", "priority": 17},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7113010892989156,
#                 "learning_rate": 0.012535427424259274,
#                 "min_data_in_leaf": 16,
#                 "num_leaves": 48,
#                 "ag_args": {"name_suffix": "_r97", "priority": 16},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.45555769907110816,
#                 "learning_rate": 0.009591347321206594,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 110,
#                 "ag_args": {"name_suffix": "_r71", "priority": 15},
#             },
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.40979710161022476,
#                 "learning_rate": 0.008708890211023034,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 80,
#                 "ag_args": {"name_suffix": "_r111", "priority": 14},
#             },
#         ],
#         "FASTAI": [
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6167722379778131,
#                 "epochs": 44,
#                 "layers": [200, 100, 50],
#                 "lr": 0.053440377855629266,
#                 "ps": 0.48477211305443607,
#                 "ag_args": {"name_suffix": "_r25", "priority": 13},
#             },
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6046989241462619,
#                 "epochs": 48,
#                 "layers": [200, 100, 50],
#                 "lr": 0.00775309042164966,
#                 "ps": 0.09244767444160731,
#                 "ag_args": {"name_suffix": "_r51", "priority": 12},
#             },
#             {
#                 "bs": 512,
#                 "emb_drop": 0.6557225316526186,
#                 "epochs": 49,
#                 "layers": [200, 100],
#                 "lr": 0.023627682025564638,
#                 "ps": 0.519566584552178,
#                 "ag_args": {"name_suffix": "_r82", "priority": 11},
#             },
#             {
#                 "bs": 2048,
#                 "emb_drop": 0.4066210919034579,
#                 "epochs": 43,
#                 "layers": [400, 200],
#                 "lr": 0.0029598312717673434,
#                 "ps": 0.4378695797438974,
#                 "ag_args": {"name_suffix": "_r121", "priority": 10},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.44339037504795686,
#                 "epochs": 31,
#                 "layers": [400, 200, 100],
#                 "lr": 0.008615195908919904,
#                 "ps": 0.19220253419114286,
#                 "ag_args": {"name_suffix": "_r145", "priority": 9},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.12106594798980945,
#                 "epochs": 38,
#                 "layers": [200, 100, 50],
#                 "lr": 0.037991970245029975,
#                 "ps": 0.33120008492595093,
#                 "ag_args": {"name_suffix": "_r173", "priority": 8},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.4599138419358,
#                 "epochs": 47,
#                 "layers": [200, 100],
#                 "lr": 0.03888383281136287,
#                 "ps": 0.28193673177122863,
#                 "ag_args": {"name_suffix": "_r128", "priority": 7},
#             },
#         ],
#         "CAT": [
#             {"depth": 5, "l2_leaf_reg": 4.774992314058497, "learning_rate": 0.038551267822920274, "ag_args": {"name_suffix": "_r16", "priority": 6}},
#             {"depth": 4, "l2_leaf_reg": 1.9950125740798321, "learning_rate": 0.028091050379971633, "ag_args": {"name_suffix": "_r42", "priority": 5}},
#             {"depth": 6, "l2_leaf_reg": 1.8298803017644376, "learning_rate": 0.017844259810823604, "ag_args": {"name_suffix": "_r93", "priority": 4}},
#             {"depth": 7, "l2_leaf_reg": 4.81099604606794, "learning_rate": 0.019085060180573103, "ag_args": {"name_suffix": "_r44", "priority": 3}},
#         ],
#     },
#     zeroshot_hpo_hybrid={
#         "NN_TORCH": {},
#         "XT": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#             {"min_samples_leaf": 1, "max_leaf_nodes": 15000, "max_features": 0.5, "ag_args": {"name_suffix": "_r19", "priority": 20}},
#         ],
#         "RF": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#             {"min_samples_leaf": 5, "max_leaf_nodes": 50000, "max_features": 0.5, "ag_args": {"name_suffix": "_r5", "priority": 19}},
#         ],
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.7248284762542815,
#                 "learning_rate": 0.07947286942946127,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 89,
#                 "ag_args": {"name_suffix": "_r158", "priority": 18},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7832570544199176,
#                 "learning_rate": 0.021720607471727896,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 21,
#                 "ag_args": {"name_suffix": "_r118", "priority": 17},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7113010892989156,
#                 "learning_rate": 0.012535427424259274,
#                 "min_data_in_leaf": 16,
#                 "num_leaves": 48,
#                 "ag_args": {"name_suffix": "_r97", "priority": 16},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.45555769907110816,
#                 "learning_rate": 0.009591347321206594,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 110,
#                 "ag_args": {"name_suffix": "_r71", "priority": 15},
#             },
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.40979710161022476,
#                 "learning_rate": 0.008708890211023034,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 80,
#                 "ag_args": {"name_suffix": "_r111", "priority": 14},
#             },
#         ],
#         "XGB": {},
#         "FASTAI": [
#             {},
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6167722379778131,
#                 "epochs": 44,
#                 "layers": [200, 100, 50],
#                 "lr": 0.053440377855629266,
#                 "ps": 0.48477211305443607,
#                 "ag_args": {"name_suffix": "_r25", "priority": 13},
#             },
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6046989241462619,
#                 "epochs": 48,
#                 "layers": [200, 100, 50],
#                 "lr": 0.00775309042164966,
#                 "ps": 0.09244767444160731,
#                 "ag_args": {"name_suffix": "_r51", "priority": 12},
#             },
#             {
#                 "bs": 512,
#                 "emb_drop": 0.6557225316526186,
#                 "epochs": 49,
#                 "layers": [200, 100],
#                 "lr": 0.023627682025564638,
#                 "ps": 0.519566584552178,
#                 "ag_args": {"name_suffix": "_r82", "priority": 11},
#             },
#             {
#                 "bs": 2048,
#                 "emb_drop": 0.4066210919034579,
#                 "epochs": 43,
#                 "layers": [400, 200],
#                 "lr": 0.0029598312717673434,
#                 "ps": 0.4378695797438974,
#                 "ag_args": {"name_suffix": "_r121", "priority": 10},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.44339037504795686,
#                 "epochs": 31,
#                 "layers": [400, 200, 100],
#                 "lr": 0.008615195908919904,
#                 "ps": 0.19220253419114286,
#                 "ag_args": {"name_suffix": "_r145", "priority": 9},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.12106594798980945,
#                 "epochs": 38,
#                 "layers": [200, 100, 50],
#                 "lr": 0.037991970245029975,
#                 "ps": 0.33120008492595093,
#                 "ag_args": {"name_suffix": "_r173", "priority": 8},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.4599138419358,
#                 "epochs": 47,
#                 "layers": [200, 100],
#                 "lr": 0.03888383281136287,
#                 "ps": 0.28193673177122863,
#                 "ag_args": {"name_suffix": "_r128", "priority": 7},
#             },
#         ],
#         "CAT": [
#             {},
#             {"depth": 5, "l2_leaf_reg": 4.774992314058497, "learning_rate": 0.038551267822920274, "ag_args": {"name_suffix": "_r16", "priority": 6}},
#             {"depth": 4, "l2_leaf_reg": 1.9950125740798321, "learning_rate": 0.028091050379971633, "ag_args": {"name_suffix": "_r42", "priority": 5}},
#             {"depth": 6, "l2_leaf_reg": 1.8298803017644376, "learning_rate": 0.017844259810823604, "ag_args": {"name_suffix": "_r93", "priority": 4}},
#             {"depth": 7, "l2_leaf_reg": 4.81099604606794, "learning_rate": 0.019085060180573103, "ag_args": {"name_suffix": "_r44", "priority": 3}},
#         ],
#         "KNN": [
#             {"weights": "uniform", "ag_args": {"name_suffix": "Unif"}},
#             {"weights": "distance", "ag_args": {"name_suffix": "Dist"}},
#         ],
#     },
#     zeroshot=hyperparameter_portfolio_zeroshot_2023,

# %%
#设置训练精度
presets='good_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
num_bag_sets=1

# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       6.95 GB / 15.92 GB (43.6%)
# Disk Space Avail:   302.09 GB / 931.51 GB (32.4%)
# ===================================================
# Presets specified: ['good_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 19:18:06,074	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8269
# 		Context path: "models\Teacher\good_quality-20241101-191749\ds_sub_fit\sub_fit_ho"
# (_dystack pid=101196) Running DyStack sub-fit ...
# (_dystack pid=101196) Beginning AutoGluon training ... Time limit = 865s
# (_dystack pid=101196) AutoGluon will save models to "models\Teacher\good_quality-20241101-191749\ds_sub_fit\sub_fit_ho"
# (_dystack pid=101196) Train Data Rows:    77
# (_dystack pid=101196) Train Data Columns: 36
# (_dystack pid=101196) Label Column:       label
# (_dystack pid=101196) Problem Type:       multiclass
# (_dystack pid=101196) Preprocessing data ...
# (_dystack pid=101196) Train Data Class Count: 3
# (_dystack pid=101196) Using Feature Generators to preprocess the data ...
# (_dystack pid=101196) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=101196) 	Available Memory:                    4427.03 MB
# (_dystack pid=101196) 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=101196) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=101196) 	Stage 1 Generators:
# (_dystack pid=101196) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=101196) 	Stage 2 Generators:
# (_dystack pid=101196) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=101196) 	Stage 3 Generators:
# (_dystack pid=101196) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=101196) 	Stage 4 Generators:
# (_dystack pid=101196) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=101196) 	Stage 5 Generators:
# (_dystack pid=101196) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=101196) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=101196) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=101196) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=101196) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=101196) 	0.2s = Fit runtime
# (_dystack pid=101196) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=101196) 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=101196) Data preprocessing and feature engineering runtime = 0.28s ...
# (_dystack pid=101196) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=101196) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=101196) User-specified model hyperparameters to be fit:
# (_dystack pid=101196) {
# (_dystack pid=101196) 	'NN_TORCH': {},
# (_dystack pid=101196) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=101196) 	'CAT': {},
# (_dystack pid=101196) 	'XGB': {},
# (_dystack pid=101196) 	'FASTAI': {},
# (_dystack pid=101196) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=101196) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=101196) }
# (_dystack pid=101196) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=101196) Fitting 11 L1 models ...
# (_dystack pid=101196) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 576.31s of the 864.68s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=101196) 	0.9351	 = Validation score   (accuracy)
# (_dystack pid=101196) 	22.05s	 = Training   runtime
# (_dystack pid=101196) 	0.14s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 527.47s of the 815.84s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=101196) 	0.8831	 = Validation score   (accuracy)
# (_dystack pid=101196) 	4.91s	 = Training   runtime
# (_dystack pid=101196) 	0.02s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBM_BAG_L1 ... Training model for up to 506.54s of the 794.91s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_dystack pid=101196) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=101196) 	6.04s	 = Training   runtime
# (_dystack pid=101196) 	0.01s	 = Validation runtime
# (_dystack pid=101196) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 493.73s of the 782.1s of remaining time.
# (_dystack pid=101196) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=101196) 	2.38s	 = Training   runtime
# (_dystack pid=101196) 	0.19s	 = Validation runtime
# (_dystack pid=101196) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 491.0s of the 779.37s of remaining time.
# (_dystack pid=101196) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=101196) 	2.33s	 = Training   runtime
# (_dystack pid=101196) 	0.18s	 = Validation runtime
# (_dystack pid=101196) Fitting model: CatBoost_BAG_L1 ... Training model for up to 488.45s of the 776.82s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=101196) 	0.8961	 = Validation score   (accuracy)
# (_dystack pid=101196) 	21.92s	 = Training   runtime
# (_dystack pid=101196) 	0.02s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 455.05s of the 743.42s of remaining time.
# (_dystack pid=101196) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=101196) 	2.95s	 = Training   runtime
# (_dystack pid=101196) 	0.27s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 451.74s of the 740.11s of remaining time.
# (_dystack pid=101196) 	0.8312	 = Validation score   (accuracy)
# (_dystack pid=101196) 	2.98s	 = Training   runtime
# (_dystack pid=101196) 	0.22s	 = Validation runtime
# (_dystack pid=101196) Fitting model: XGBoost_BAG_L1 ... Training model for up to 448.49s of the 736.86s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# (_dystack pid=101196) 	0.8312	 = Validation score   (accuracy)
# (_dystack pid=101196) 	10.88s	 = Training   runtime
# (_dystack pid=101196) 	0.04s	 = Validation runtime
# (_dystack pid=101196) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 428.63s of the 717.0s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=97820) Stack (most recent call first):
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=97820)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=97820)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=9576) Stack (most recent call first): [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 36x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 27x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 30x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 30x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 27x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 24x across cluster]
# (_ray_fit pid=9576)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 6x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 6x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 3x across cluster]
# (_ray_fit pid=9576)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 3x across cluster]
# (_ray_fit pid=2920)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py"
# (_ray_fit pid=2920) , line 402
# (_ray_fit pid=2920)  in _ray_fit
# (_ray_fit pid=2920)
# (_ray_fit pid=2920)   File
# (_ray_fit pid=2920) "
# (_ray_fit pid=2920) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py
# (_ray_fit pid=2920) "
# (_ray_fit pid=2920) , line
# (_ray_fit pid=2920) 879 in main_loop
# (_ray_fit pid=2920)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py"
# (_ray_fit pid=2920) , line 282 in
# (_ray_fit pid=2920) <module>
# (_ray_fit pid=2920)
# (_ray_fit pid=98408) Stack (most recent call first): [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 48x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 36x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 40x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 40x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 35x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 32x across cluster]
# (_ray_fit pid=98408)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 8x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 8x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 4x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 3x across cluster]
# (_ray_fit pid=98408)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 3x across cluster]
# (_dystack pid=101196) 	0.8831	 = Validation score   (accuracy)
# (_dystack pid=101196) 	29.7s	 = Training   runtime
# (_dystack pid=101196) 	0.13s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 386.58s of the 674.95s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# (_dystack pid=101196) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=101196) 	18.32s	 = Training   runtime
# (_dystack pid=101196) 	0.06s	 = Validation runtime
# (_dystack pid=101196) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 633.28s of remaining time.
# (_dystack pid=101196) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# (_dystack pid=101196) 	0.9351	 = Validation score   (accuracy)
# (_dystack pid=101196) 	0.27s	 = Training   runtime
# (_dystack pid=101196) 	0.0s	 = Validation runtime
# (_dystack pid=101196) Fitting 11 L2 models ...
# (_dystack pid=101196) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 633.0s of the 633.0s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=101196) 	0.9221	 = Validation score   (accuracy)
# (_dystack pid=101196) 	22.62s	 = Training   runtime
# (_dystack pid=101196) 	0.09s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 588.74s of the 588.73s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=101196) 	0.9351	 = Validation score   (accuracy)
# (_dystack pid=101196) 	6.96s	 = Training   runtime
# (_dystack pid=101196) 	0.03s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBM_BAG_L2 ... Training model for up to 573.11s of the 573.1s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=101196) 	0.9221	 = Validation score   (accuracy)
# (_dystack pid=101196) 	7.54s	 = Training   runtime
# (_dystack pid=101196) 	0.01s	 = Validation runtime
# (_dystack pid=101196) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 547.82s of the 547.8s of remaining time.
# (_dystack pid=101196) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=101196) 	0.99s	 = Training   runtime
# (_dystack pid=101196) 	0.12s	 = Validation runtime
# (_dystack pid=101196) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 546.67s of the 546.66s of remaining time.
# (_dystack pid=101196) 	0.8442	 = Validation score   (accuracy)
# (_dystack pid=101196) 	0.85s	 = Training   runtime
# (_dystack pid=101196) 	0.1s	 = Validation runtime
# (_dystack pid=101196) Fitting model: CatBoost_BAG_L2 ... Training model for up to 545.18s of the 545.16s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=101196) 	0.9221	 = Validation score   (accuracy)
# (_dystack pid=101196) 	25.39s	 = Training   runtime
# (_dystack pid=101196) 	0.03s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 508.45s of the 508.44s of remaining time.
# (_dystack pid=101196) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=101196) 	3.0s	 = Training   runtime
# (_dystack pid=101196) 	0.18s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 505.2s of the 505.18s of remaining time.
# (_dystack pid=101196) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=101196) 	3.04s	 = Training   runtime
# (_dystack pid=101196) 	0.14s	 = Validation runtime
# (_dystack pid=101196) Fitting model: XGBoost_BAG_L2 ... Training model for up to 501.95s of the 501.93s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# (_dystack pid=101196) 	0.961	 = Validation score   (accuracy)
# (_dystack pid=101196) 	11.78s	 = Training   runtime
# (_dystack pid=101196) 	0.04s	 = Validation runtime
# (_dystack pid=101196) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 478.23s of the 478.21s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=99336) Stack (most recent call first):
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=99336)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=99336)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line 1176 in _find_and_load
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py"
# (_ray_fit pid=96216) , line 36
# (_ray_fit pid=96216)  in <module>
# (_ray_fit pid=96216)
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line 690 in
# (_ray_fit pid=96216) _load_unlocked
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line
# (_ray_fit pid=96216) 1147 in _find_and_load_unlocked
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=96216) "
# (_ray_fit pid=96216) , line
# (_ray_fit pid=96216) 1176
# (_ray_fit pid=96216)  in
# (_ray_fit pid=96216) _find_and_load
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line 241 in _call_with_frames_removed
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap_external>", line 940 in
# (_ray_fit pid=96216) exec_module
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line 1147 in _find_and_load_unlocked
# (_ray_fit pid=96216)   File "
# (_ray_fit pid=96216) <frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line
# (_ray_fit pid=96216) 241
# (_ray_fit pid=96216)  in _call_with_frames_removed
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1126
# (_ray_fit pid=96216)  in
# (_ray_fit pid=96216) _find_and_load_unlocked
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=96216) , line 1176 in _find_and_load
# (_ray_fit pid=96216)
# (_ray_fit pid=96216)   File
# (_ray_fit pid=96216) "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap_external>", line
# (_ray_fit pid=96216) 940 in
# (_ray_fit pid=96216) exec_module
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=96216) "
# (_ray_fit pid=96216) , line
# (_ray_fit pid=96216) 690
# (_ray_fit pid=96216) Stack (most recent call first): [repeated 6x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 63x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 6x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 6x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 48x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 52x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 51x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module> [repeated 48x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 42x across cluster]
# (_ray_fit pid=103404)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 10x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 5x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 10x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 5x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 5x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 5x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 5x across cluster]
# (_ray_fit pid=103404)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 5x across cluster]
# (_ray_fit pid=96216)  in _load_unlocked
# (_dystack pid=101196) 	0.9091	 = Validation score   (accuracy)
# (_dystack pid=101196) 	21.77s	 = Training   runtime
# (_dystack pid=101196) 	0.3s	 = Validation runtime
# (_dystack pid=101196) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 444.31s of the 444.3s of remaining time.
# (_dystack pid=101196) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.06%)
# (_ray_fit pid=95804) Stack (most recent call first):
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 18x across cluster]
# (_ray_fit pid=95804)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=95804)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 13x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 15x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 15x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 14x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 12x across cluster]
# (_ray_fit pid=96216)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 4x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 2x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 4x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 2x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 2x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 2x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 2x across cluster]
# (_ray_fit pid=96216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 2x across cluster]
# (_dystack pid=101196) 	0.9091	 = Validation score   (accuracy)
# (_dystack pid=101196) 	12.0s	 = Training   runtime
# (_dystack pid=101196) 	0.03s	 = Validation runtime
# (_dystack pid=101196) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 420.06s of remaining time.
# (_dystack pid=101196) 	Ensemble Weights: {'XGBoost_BAG_L2': 1.0}
# (_dystack pid=101196) 	0.961	 = Validation score   (accuracy)
# (_dystack pid=101196) 	0.43s	 = Training   runtime
# (_dystack pid=101196) 	0.0s	 = Validation runtime
# (_dystack pid=101196) AutoGluon training complete, total runtime = 445.36s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 17.5 rows/s (10 batch size)
# (_dystack pid=101196) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=101196) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=101196) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=101196) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=101196) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=101196) 	Stopping at the best epoch learned earlier - 5.
# (_dystack pid=101196) 	7.31s	 = Training   runtime
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=101196) 	12.06s	 = Training   runtime
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=101196) 	6.08s	 = Training   runtime
# (_dystack pid=101196) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	2.38s	 = Training   runtime
# (_dystack pid=101196) 	0.19s	 = Validation runtime
# (_dystack pid=101196) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	2.33s	 = Training   runtime
# (_dystack pid=101196) 	0.18s	 = Validation runtime
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=101196) 	1.26s	 = Training   runtime
# (_dystack pid=101196) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	2.95s	 = Training   runtime
# (_dystack pid=101196) 	0.27s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	2.98s	 = Training   runtime
# (_dystack pid=101196) 	0.22s	 = Validation runtime
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=101196) 	20.17s	 = Training   runtime
# (_dystack pid=101196) Fitting 1 L1 models ...
# (_dystack pid=101196) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=101196) Stack (most recent call first):
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=101196)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=101196)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=101196)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=101196)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=101196)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=101196)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=101196)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_dystack pid=101196)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# ...
# (_dystack pid=101196) Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	3.0s	 = Training   runtime
# (_dystack pid=101196) 	0.18s	 = Validation runtime
# (_dystack pid=101196) Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	3.04s	 = Training   runtime
# (_dystack pid=101196) 	0.14s	 = Validation runtime
# (_dystack pid=101196) Fitting 1 L2 models ...
# (_dystack pid=101196) Fitting model: XGBoost_BAG_L2_FULL ...
# (_dystack pid=101196) 	0.63s	 = Training   runtime
# (_dystack pid=101196) Fitting 1 L2 models ...
# (_dystack pid=101196) Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# (_dystack pid=101196) 	1.86s	 = Training   runtime
# (_dystack pid=101196) Fitting 1 L2 models ...
# (_dystack pid=101196) Fitting model: LightGBMLarge_BAG_L2_FULL ...
# (_dystack pid=101196) 	0.58s	 = Training   runtime
# (_dystack pid=101196) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=101196) 	Ensemble Weights: {'XGBoost_BAG_L2': 1.0}
# (_dystack pid=101196) 	0.43s	 = Training   runtime
# (_dystack pid=101196) Updated best model to "XGBoost_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "XGBoost_BAG_L2_FULL" for predict() and predict_proba().
# (_dystack pid=101196) Refit complete, total runtime = 209.89s ... Best model: "XGBoost_BAG_L2_FULL"
# (_dystack pid=101196) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\good_quality-20241101-191749\ds_sub_fit\sub_fit_ho")
# (_dystack pid=101196) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    NeuralNetFastAI_BAG_L1_FULL            1.0   0.935065    accuracy        0.047232            NaN    7.305005                 0.047232                     NaN           7.305005            1       True          1
# 1       WeightedEnsemble_L2_FULL            1.0   0.935065    accuracy        0.049233            NaN    7.571954                 0.002001                     NaN           0.266949            2       True         12
# 2   RandomForestGini_BAG_L1_FULL            1.0   0.857143    accuracy        0.074677       0.185753    2.384480                 0.074677                0.185753           2.384480            1       True          4
# 3     ExtraTreesEntr_BAG_L1_FULL            1.0   0.831169    accuracy        0.083851       0.220980    2.982638                 0.083851                0.220980           2.982638            1       True          8
# 4     ExtraTreesGini_BAG_L1_FULL            1.0   0.857143    accuracy        0.087154       0.274540    2.952881                 0.087154                0.274540           2.952881            1       True          7
# 5   RandomForestEntr_BAG_L1_FULL            1.0   0.857143    accuracy        0.093480       0.177483    2.325937                 0.093480                0.177483           2.325937            1       True          5
# 6         LightGBMXT_BAG_L2_FULL            1.0   0.935065    accuracy        0.713191            NaN  213.494910                 0.063323                     NaN           0.346049            2       True         14
# 7           LightGBM_BAG_L2_FULL            1.0   0.922078    accuracy        0.726921            NaN  213.392613                 0.077053                     NaN           0.243753            2       True         15
# 8     NeuralNetTorch_BAG_L2_FULL            1.0   0.909091    accuracy        0.757871            NaN  215.012346                 0.108003                     NaN           1.863486            2       True         22
# 9    NeuralNetFastAI_BAG_L2_FULL            1.0   0.922078    accuracy        0.766007            NaN  214.567269                 0.116139                     NaN           1.418408            2       True         13
# 10  RandomForestEntr_BAG_L2_FULL            1.0   0.844156    accuracy        0.988847            NaN  213.995201                 0.338979                0.097519           0.846341            2       True         17
# 11  RandomForestGini_BAG_L2_FULL            1.0   0.857143    accuracy        1.102753            NaN  214.135109                 0.452885                0.119125           0.986248            2       True         16
# 12    ExtraTreesEntr_BAG_L2_FULL            1.0   0.870130    accuracy        1.207119            NaN  216.191615                 0.557251                0.144078           3.042755            2       True         20
# 13    ExtraTreesGini_BAG_L2_FULL            1.0   0.857143    accuracy        1.254748            NaN  216.153689                 0.604881                0.182030           3.004828            2       True         19
# 14    NeuralNetTorch_BAG_L1_FULL            0.9   0.883117    accuracy        0.112201            NaN   52.745818                 0.112201                     NaN          52.745818            1       True         10
# 15          CatBoost_BAG_L2_FULL            0.9   0.922078    accuracy        0.659977            NaN  213.254640                 0.010109                     NaN           0.105779            2       True         18
# 16           XGBoost_BAG_L2_FULL            0.9   0.961039    accuracy        0.705186            NaN  213.775342                 0.055319                     NaN           0.626482            2       True         21
# 17      WeightedEnsemble_L3_FULL            0.9   0.961039    accuracy        0.708187            NaN  214.209033                 0.003001                     NaN           0.433692            3       True         24
# 18          LightGBM_BAG_L1_FULL            0.8   0.870130    accuracy        0.007001            NaN    6.084155                 0.007001                     NaN           6.084155            1       True          3
# 19          CatBoost_BAG_L1_FULL            0.8   0.896104    accuracy        0.008000            NaN    1.255857                 0.008000                     NaN           1.255857            1       True          6
# 20        LightGBMXT_BAG_L1_FULL            0.8   0.883117    accuracy        0.012122            NaN   12.060894                 0.012122                     NaN          12.060894            1       True          2
# 21           XGBoost_BAG_L1_FULL            0.8   0.831169    accuracy        0.057341            NaN   20.173538                 0.057341                     NaN          20.173538            1       True          9
# 22     LightGBMLarge_BAG_L1_FULL            0.8   0.870130    accuracy        0.066809            NaN  102.877659                 0.066809                     NaN         102.877659            1       True         11
# 23     LightGBMLarge_BAG_L2_FULL            0.8   0.909091    accuracy        0.829910            NaN  213.733176                 0.180043                     NaN           0.584315            2       True         23
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	703s	 = DyStack   runtime |	2897s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2897s
# AutoGluon will save models to "models\Teacher\good_quality-20241101-191749"
# Train Data Rows:    87
# Train Data Columns: 36
# Label Column:       label
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5856.84 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.3s = Fit runtime
# 	36 features in original data used to generate 36 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.49s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2896.13s of the 2896.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.954	 = Validation score   (accuracy)
# 	27.87s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2854.43s of the 2854.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.8966	 = Validation score   (accuracy)
# 	7.89s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2836.69s of the 2836.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.8966	 = Validation score   (accuracy)
# 	6.65s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2818.71s of the 2818.7s of remaining time.
# 	0.8851	 = Validation score   (accuracy)
# 	1.87s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2816.63s of the 2816.62s of remaining time.
# 	0.8851	 = Validation score   (accuracy)
# 	1.2s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2815.23s of the 2815.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.8851	 = Validation score   (accuracy)
# 	14.63s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2793.38s of the 2793.37s of remaining time.
# 	0.8736	 = Validation score   (accuracy)
# 	2.57s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2790.58s of the 2790.57s of remaining time.
# 	0.8736	 = Validation score   (accuracy)
# 	2.83s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2787.5s of the 2787.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# 	0.8966	 = Validation score   (accuracy)
# 	9.73s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2757.12s of the 2757.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# 	0.931	 = Validation score   (accuracy)
# 	23.52s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2726.45s of the 2726.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8851	 = Validation score   (accuracy)
# 	8.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2702.08s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.954	 = Validation score   (accuracy)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 194.89s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 64.7 rows/s (11 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	14.6s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.71s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.72s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.87s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.2s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	0.7s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.57s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.83s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.34s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	6.77s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.3s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.23s	 = Training   runtime
# Updated best model to "NeuralNetFastAI_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "NeuralNetFastAI_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 26.79s ... Best model: "NeuralNetFastAI_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\good_quality-20241101-191749")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: NeuralNetFastAI_BAG_L1_FULL
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         NeuralNetFastAI_BAG_L1   0.954023    accuracy       0.169768  27.869469                0.169768          27.869469            1      False          1
# 1            WeightedEnsemble_L2   0.954023    accuracy       0.170768  28.100218                0.001000           0.230748            2      False         12
# 2          NeuralNetTorch_BAG_L1   0.931034    accuracy       0.159135  23.517047                0.159135          23.517047            1      False         10
# 3                LightGBM_BAG_L1   0.896552    accuracy       0.008999   6.649011                0.008999           6.649011            1      False          3
# 4              LightGBMXT_BAG_L1   0.896552    accuracy       0.010000   7.890896                0.010000           7.890896            1      False          2
# 5                 XGBoost_BAG_L1   0.896552    accuracy       0.023674   9.725472                0.023674           9.725472            1      False          9
# 6           LightGBMLarge_BAG_L1   0.885057    accuracy       0.009857   8.818380                0.009857           8.818380            1      False         11
# 7                CatBoost_BAG_L1   0.885057    accuracy       0.020109  14.629152                0.020109          14.629152            1      False          6
# 8        RandomForestEntr_BAG_L1   0.885057    accuracy       0.156945   1.195818                0.156945           1.195818            1       True          5
# 9        RandomForestGini_BAG_L1   0.885057    accuracy       0.159098   1.873247                0.159098           1.873247            1       True          4
# 10         ExtraTreesGini_BAG_L1   0.873563    accuracy       0.185583   2.566812                0.185583           2.566812            1       True          7
# 11         ExtraTreesEntr_BAG_L1   0.873563    accuracy       0.194149   2.825171                0.194149           2.825171            1       True          8
# 12  RandomForestEntr_BAG_L1_FULL        NaN    accuracy       0.156945   1.195818                0.156945           1.195818            1       True         17
# 13  RandomForestGini_BAG_L1_FULL        NaN    accuracy       0.159098   1.873247                0.159098           1.873247            1       True         16
# 14    ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       0.185583   2.566812                0.185583           2.566812            1       True         19
# 15    ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       0.194149   2.825171                0.194149           2.825171            1       True         20
# 16           XGBoost_BAG_L1_FULL        NaN    accuracy            NaN   0.344578                     NaN           0.344578            1       True         21
# 17      WeightedEnsemble_L2_FULL        NaN    accuracy            NaN  14.832684                     NaN           0.230748            2       True         24
# 18    NeuralNetTorch_BAG_L1_FULL        NaN    accuracy            NaN   6.768390                     NaN           6.768390            1       True         22
# 19   NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN  14.601936                     NaN          14.601936            1       True         13
# 20          LightGBM_BAG_L1_FULL        NaN    accuracy            NaN   0.721711                     NaN           0.721711            1       True         15
# 21        LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN   2.713956                     NaN           2.713956            1       True         14
# 22     LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN   0.304996                     NaN           0.304996            1       True         23
# 23          CatBoost_BAG_L1_FULL        NaN    accuracy            NaN   0.700634                     NaN           0.700634            1       True         18
# Number of models trained: 24
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# NeuralNetFastAI_BAG_L1_FULL
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.75      0.60      0.67         5
#         Exc L3-4 RORB CARM1P1       0.67      0.50      0.57         4
#         Exc L3-5 RORB COL22A1       0.80      1.00      0.89         8
#
#                      accuracy                           0.76        17
#                     macro avg       0.74      0.70      0.71        17
#                  weighted avg       0.75      0.76      0.75        17

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[3 1 1]
#  [1 2 1]
#  [0 0 8]]
# ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']
# ([<matplotlib.axis.YTick at 0x1d7e1a55950>,
#   <matplotlib.axis.YTick at 0x1d7e1a53bd0>,
#   <matplotlib.axis.YTick at 0x1d7e1a50b90>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[3 1 1]
#  [1 2 1]
#  [0 0 8]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                        0.518870               0.188508
# 1                        0.687522               0.198668
# 2                        0.005936               0.006250
# 3                        0.036614               0.018794
# 4                        0.195047               0.144075
# 5                        0.086638               0.861340
# 6                        0.289342               0.420630
# 7                        0.002815               0.001198
# 8                        0.999127               0.000132
# 9                        0.000580               0.000071
# 10                       0.077310               0.884291
# 11                       0.357182               0.004971
# 12                       0.204848               0.161849
# 13                       0.851888               0.114954
# 14                       0.024621               0.055171
# 15                       0.000389               0.000075
# 16                       0.004662               0.000483
#
#     Exc L3-5 RORB COL22A1
# 0                0.292621
# 1                0.113810
# 2                0.987814
# 3                0.944592
# 4                0.660878
# 5                0.052022
# 6                0.290028
# 7                0.995987
# 8                0.000742
# 9                0.999348
# 10               0.038399
# 11               0.637847
# 12               0.633303
# 13               0.033157
# 14               0.920207
# 15               0.999536
# 16               0.994855

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 17 rows with 5 shuffle sets...
# 	4.19s	= Expected runtime (0.84s per shuffle set)
# 	0.82s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                         importance    stddev   p_value  n  p99_high   p99_low
# TS1_rheobase          7.058824e-02  0.064438  0.035242  5  0.203267 -0.062090
# L23_depth_normalized  5.882353e-02  0.072044  0.070964  5  0.207163 -0.089516
# TS2_rheobase          4.705882e-02  0.049215  0.049650  5  0.148394 -0.054276
# TS2_avg_upstroke      4.705882e-02  0.026307  0.008065  5  0.101225 -0.007107
# TS2_maxupstroke       4.705882e-02  0.026307  0.008065  5  0.101225 -0.007107
# TS2_up_down_ratio     3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# TS1_avg_upstroke      3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# TS1_halfwidth         3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# FAP_maxupstroke       3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# input_resistance      3.529412e-02  0.032219  0.035242  5  0.101633 -0.031045
# FAP_avg_upstroke      2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# FAP_num_APs           2.352941e-02  0.067069  0.238310  5  0.161626 -0.114567
# FAP_halfwidth         2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# sag                   2.352941e-02  0.032219  0.088904  5  0.089869 -0.042810
# VmatSag               1.176471e-02  0.026307  0.186950  5  0.065931 -0.042401
# FAP_rheobase          1.176471e-02  0.026307  0.186950  5  0.065931 -0.042401
# TS2_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# vmbaseM               0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# tau                   0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_peak              0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_up_down_ratio     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_num_APs           0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxupstroke       0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_avg_downstroke    0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_peak              0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# FAP_threshold         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_adp_index         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS1_adp_index        -2.220446e-17  0.041595  0.500000  5  0.085644 -0.085644
# FAP_up_down_ratio    -3.529412e-02  0.032219  0.964758  5  0.031045 -0.101633
# TS1_num_APs          -4.705882e-02  0.026307  0.991935  5  0.007107 -0.101225

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# NeuralNetFastAI_BAG_L1_FULL
# {'accuracy': 0.7647058823529411,
#  'balanced_accuracy': 0.7000000000000001,
#  'mcc': 0.6274738949672117,
#  'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
#  Exc L2-3 LINC00507 FREM3 deep                              3
#  Exc L3-4 RORB CARM1P1                                      1
#  Exc L3-5 RORB COL22A1                                      0
#
#                                 Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
#  Exc L2-3 LINC00507 FREM3 deep                      1                      1
#  Exc L3-4 RORB CARM1P1                              2                      1
#  Exc L3-5 RORB COL22A1                              0                      8  ,
#  'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.75,
#    'recall': 0.6,
#    'f1-score': 0.6666666666666666,
#    'support': 5.0},
#   'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666,
#    'recall': 0.5,
#    'f1-score': 0.5714285714285714,
#    'support': 4.0},
#   'Exc L3-5 RORB COL22A1': {'precision': 0.8,
#    'recall': 1.0,
#    'f1-score': 0.8888888888888888,
#    'support': 8.0},
#   'accuracy': 0.7647058823529411,
#   'macro avg': {'precision': 0.7388888888888889,
#    'recall': 0.7000000000000001,
#    'f1-score': 0.708994708994709,
#    'support': 17.0},
#   'weighted avg': {'precision': 0.753921568627451,
#    'recall': 0.7647058823529411,
#    'f1-score': 0.7488328664799253,
#    'support': 17.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data, extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                            model  score_test  score_val eval_metric  \
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN    accuracy
# 1     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN    accuracy
# 2          ExtraTreesGini_BAG_L1    0.823529   0.873563    accuracy
# 3           LightGBM_BAG_L1_FULL    0.764706        NaN    accuracy
# 4       WeightedEnsemble_L2_FULL    0.764706        NaN    accuracy
# 5    NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN    accuracy
# 6         LightGBMXT_BAG_L1_FULL    0.764706        NaN    accuracy
# 7     NeuralNetTorch_BAG_L1_FULL    0.764706        NaN    accuracy
# 8     ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN    accuracy
# 9          ExtraTreesEntr_BAG_L1    0.764706   0.873563    accuracy
# 10       RandomForestEntr_BAG_L1    0.764706   0.885057    accuracy
# 11  RandomForestGini_BAG_L1_FULL    0.764706        NaN    accuracy
# 12  RandomForestEntr_BAG_L1_FULL    0.764706        NaN    accuracy
# 13       RandomForestGini_BAG_L1    0.764706   0.885057    accuracy
# 14          CatBoost_BAG_L1_FULL    0.705882        NaN    accuracy
# 15           XGBoost_BAG_L1_FULL    0.647059        NaN    accuracy
# 16        NeuralNetFastAI_BAG_L1         NaN   0.954023    accuracy
# 17           WeightedEnsemble_L2         NaN   0.954023    accuracy
# 18         NeuralNetTorch_BAG_L1         NaN   0.931034    accuracy
# 19               LightGBM_BAG_L1         NaN   0.896552    accuracy
# 20             LightGBMXT_BAG_L1         NaN   0.896552    accuracy
# 21                XGBoost_BAG_L1         NaN   0.896552    accuracy
# 22          LightGBMLarge_BAG_L1         NaN   0.885057    accuracy
# 23               CatBoost_BAG_L1         NaN   0.885057    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.000000            NaN   0.304996                 0.000000
# 1         0.051349       0.185583   2.566812                 0.051349
# 2         0.067397       0.185583   2.566812                 0.067397
# 3         0.000000            NaN   0.721711                 0.000000
# 4         0.009238            NaN  14.832684                 0.000000
# 5         0.009238            NaN  14.601936                 0.009238
# 6         0.010885            NaN   2.713956                 0.010885
# 7         0.020507            NaN   6.768390                 0.020507
# 8         0.054874       0.194149   2.825171                 0.054874
# 9         0.068109       0.194149   2.825171                 0.068109
# 10        0.068872       0.156945   1.195818                 0.068872
# 11        0.100447       0.159098   1.873247                 0.100447
# 12        0.100982       0.156945   1.195818                 0.100982
# 13        0.104864       0.159098   1.873247                 0.104864
# 14        0.006782            NaN   0.700634                 0.006782
# 15        0.000000            NaN   0.344578                 0.000000
# 16             NaN       0.169768  27.869469                      NaN
# 17             NaN       0.170768  28.100218                      NaN
# 18             NaN       0.159135  23.517047                      NaN
# 19             NaN       0.008999   6.649011                      NaN
# 20             NaN       0.010000   7.890896                      NaN
# 21             NaN       0.023674   9.725472                      NaN
# 22             NaN       0.009857   8.818380                      NaN
# 23             NaN       0.020109  14.629152                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           0.304996            1       True
# 1                 0.185583           2.566812            1       True
# 2                 0.185583           2.566812            1       True
# 3                      NaN           0.721711            1       True
# 4                      NaN           0.230748            2       True
# 5                      NaN          14.601936            1       True
# 6                      NaN           2.713956            1       True
# 7                      NaN           6.768390            1       True
# 8                 0.194149           2.825171            1       True
# 9                 0.194149           2.825171            1       True
# 10                0.156945           1.195818            1       True
# 11                0.159098           1.873247            1       True
# 12                0.156945           1.195818            1       True
# 13                0.159098           1.873247            1       True
# 14                     NaN           0.700634            1       True
# 15                     NaN           0.344578            1       True
# 16                0.169768          27.869469            1      False
# 17                0.001000           0.230748            2      False
# 18                0.159135          23.517047            1      False
# 19                0.008999           6.649011            1      False
# 20                0.010000           7.890896            1      False
# 21                0.023674           9.725472            1      False
# 22                0.009857           8.818380            1      False
# 23                0.020109          14.629152            1      False
#
#     fit_order
# 0          23
# 1          19
# 2           7
# 3          15
# 4          24
# 5          13
# 6          14
# 7          22
# 8          20
# 9           8
# 10          5
# 11         16
# 12         17
# 13          4
# 14         18
# 15         21
# 16          1
# 17         12
# 18         10
# 19          3
# 20          2
# 21          9
# 22         11
# 23          6

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1],model='XGBoost_BAG_L1_FULL')
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_94572\4124418294.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                         0.999912           7.631130e-08
# 1                         0.994909           5.112098e-05
# 2                         0.943839           1.221919e-02
# 3                         0.967286           1.950986e-03
# 4                         0.989655           1.979370e-05
# ..                             ...                    ...
# 204                       0.575833           1.796598e-02
# 205                       0.962750           2.350251e-04
# 206                       0.998642           9.398353e-09
# 207                       0.986761           2.216522e-05
# 208                       0.845030           2.025876e-03
#
#      Exc L3-5 RORB COL22A1
# 0                 0.000088
# 1                 0.005040
# 2                 0.043942
# 3                 0.030763
# 4                 0.010325
# ..                     ...
# 204               0.406201
# 205               0.037015
# 206               0.001358
# 207               0.013217
# 208               0.152944
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]=='Exc L3-4 RORB CARM1P1']])

new_unlabeled_data.shape
# Out:
# (164, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='NeuralNetFastAI_BAG_L1_FULL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.317417
# [100]	valid_set's soft_log_loss: -0.172152
# [150]	valid_set's soft_log_loss: -0.109582
# [200]	valid_set's soft_log_loss: -0.0887806
# [250]	valid_set's soft_log_loss: -0.0761815
# [300]	valid_set's soft_log_loss: -0.0685872
# [350]	valid_set's soft_log_loss: -0.0680186
# [400]	valid_set's soft_log_loss: -0.0670148
# [450]	valid_set's soft_log_loss: -0.0651742
# [500]	valid_set's soft_log_loss: -0.0632391
# [550]	valid_set's soft_log_loss: -0.0618184
# [600]	valid_set's soft_log_loss: -0.0625101
# [650]	valid_set's soft_log_loss: -0.0623678
# [700]	valid_set's soft_log_loss: -0.061822
# [750]	valid_set's soft_log_loss: -0.0624323
# [800]	valid_set's soft_log_loss: -0.0632999
# [850]	valid_set's soft_log_loss: -0.0655144
# [900]	valid_set's soft_log_loss: -0.0653691
# 	Note: model has different eval_metric than default.
# 	-0.0613	 = Validation score   (-soft_log_loss)
# 	3.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.2437	 = Validation score   (-soft_log_loss)
# 	0.84s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0650218	test: -1.0603389	best: -1.0603389 (0)	total: 927ms	remaining: 2h 34m 31s
# 20:	learn: -0.7182127	test: -0.7363172	best: -0.7363172 (20)	total: 1.3s	remaining: 10m 17s
# 40:	learn: -0.5768801	test: -0.5706442	best: -0.5706442 (40)	total: 1.6s	remaining: 6m 28s
# 60:	learn: -0.4979769	test: -0.4589666	best: -0.4589666 (60)	total: 1.86s	remaining: 5m 3s
# 80:	learn: -0.4501738	test: -0.3844755	best: -0.3844755 (80)	total: 2.13s	remaining: 4m 21s
# 100:	learn: -0.4184880	test: -0.3321278	best: -0.3321278 (100)	total: 2.42s	remaining: 3m 56s
# 120:	learn: -0.3955171	test: -0.2942883	best: -0.2942883 (120)	total: 2.68s	remaining: 3m 38s
# 140:	learn: -0.3780868	test: -0.2639217	best: -0.2639217 (140)	total: 2.99s	remaining: 3m 29s
# 160:	learn: -0.3644761	test: -0.2343121	best: -0.2343121 (160)	total: 3.24s	remaining: 3m 18s
# 180:	learn: -0.3536126	test: -0.2167205	best: -0.2167205 (180)	total: 3.5s	remaining: 3m 9s
# 740:	learn: -0.3004405	test: -0.0961182	best: -0.0961182 (740)	total: 11s	remaining: 2m 17s
# 760:	learn: -0.3000977	test: -0.0953404	best: -0.0953404 (760)	total: 11.3s	remaining: 2m 16s
# 780:	learn: -0.2997388	test: -0.0939385	best: -0.0939385 (780)	total: 11.5s	remaining: 2m 16s
# 800:	learn: -0.2993921	test: -0.0934871	best: -0.0934871 (800)	total: 11.8s	remaining: 2m 15s
# 820:	learn: -0.2990920	test: -0.0930619	best: -0.0930619 (820)	total: 12.1s	remaining: 2m 15s
# 840:	learn: -0.2988598	test: -0.0924691	best: -0.0924691 (840)	total: 12.4s	remaining: 2m 15s
# 860:	learn: -0.2986132	test: -0.0915377	best: -0.0915377 (860)	total: 12.7s	remaining: 2m 14s
# 880:	learn: -0.2983567	test: -0.0906464	best: -0.0906464 (880)	total: 12.9s	remaining: 2m 13s
# 900:	learn: -0.2981222	test: -0.0896802	best: -0.0896802 (900)	total: 13.2s	remaining: 2m 13s
# 920:	learn: -0.2978690	test: -0.0884607	best: -0.0884607 (920)	total: 13.4s	remaining: 2m 12s
# 940:	learn: -0.2976614	test: -0.0880998	best: -0.0880998 (940)	total: 13.7s	remaining: 2m 11s
# 960:	learn: -0.2974568	test: -0.0872854	best: -0.0872854 (960)	total: 14s	remaining: 2m 11s
# 980:	learn: -0.2972686	test: -0.0864785	best: -0.0864437 (979)	total: 14.3s	remaining: 2m 11s
# 1000:	learn: -0.2970720	test: -0.0859577	best: -0.0859577 (1000)	total: 14.6s	remaining: 2m 11s
# 1020:	learn: -0.2968828	test: -0.0858455	best: -0.0857694 (1012)	total: 14.9s	remaining: 2m 10s
# 1040:	learn: -0.2966995	test: -0.0852704	best: -0.0852704 (1040)	total: 15.1s	remaining: 2m 10s
# 1060:	learn: -0.2965225	test: -0.0846970	best: -0.0846970 (1060)	total: 15.4s	remaining: 2m 9s
# 1080:	learn: -0.2963826	test: -0.0843897	best: -0.0843795 (1079)	total: 15.6s	remaining: 2m 8s
# 1100:	learn: -0.2962345	test: -0.0838156	best: -0.0838156 (1100)	total: 15.9s	remaining: 2m 8s
# 1120:	learn: -0.2960802	test: -0.0834215	best: -0.0833637 (1115)	total: 16.1s	remaining: 2m 7s
# 1140:	learn: -0.2959171	test: -0.0829074	best: -0.0829074 (1140)	total: 16.4s	remaining: 2m 7s
# 1160:	learn: -0.2957426	test: -0.0822352	best: -0.0822352 (1160)	total: 16.8s	remaining: 2m 7s
# 1180:	learn: -0.2956016	test: -0.0813905	best: -0.0813905 (1180)	total: 17s	remaining: 2m 7s
# 1200:	learn: -0.2954591	test: -0.0807767	best: -0.0807767 (1200)	total: 17.3s	remaining: 2m 6s
# 1220:	learn: -0.2953214	test: -0.0801883	best: -0.0801883 (1220)	total: 17.6s	remaining: 2m 6s
# 1240:	learn: -0.2951917	test: -0.0800383	best: -0.0799560 (1235)	total: 17.8s	remaining: 2m 5s
# 1260:	learn: -0.2950860	test: -0.0795810	best: -0.0795810 (1260)	total: 18.1s	remaining: 2m 5s
# 4500:	learn: -0.2896346	test: -0.0576840	best: -0.0576840 (4500)	total: 1m 2s	remaining: 1m 15s
# 4520:	learn: -0.2896274	test: -0.0576234	best: -0.0576234 (4520)	total: 1m 2s	remaining: 1m 15s
# 4540:	learn: -0.2896177	test: -0.0576865	best: -0.0576234 (4520)	total: 1m 2s	remaining: 1m 15s
# 4560:	learn: -0.2896086	test: -0.0577107	best: -0.0576234 (4520)	total: 1m 3s	remaining: 1m 15s
# 4580:	learn: -0.2895998	test: -0.0576788	best: -0.0576234 (4520)	total: 1m 3s	remaining: 1m 14s
# 4600:	learn: -0.2895903	test: -0.0576263	best: -0.0576234 (4520)	total: 1m 3s	remaining: 1m 14s
# 4620:	learn: -0.2895824	test: -0.0576130	best: -0.0576031 (4612)	total: 1m 3s	remaining: 1m 14s
# 4640:	learn: -0.2895738	test: -0.0575909	best: -0.0575711 (4624)	total: 1m 4s	remaining: 1m 14s
# 4660:	learn: -0.2895642	test: -0.0575551	best: -0.0575551 (4660)	total: 1m 4s	remaining: 1m 13s
# 4680:	learn: -0.2895544	test: -0.0575253	best: -0.0574900 (4672)	total: 1m 4s	remaining: 1m 13s
# 4700:	learn: -0.2895459	test: -0.0574571	best: -0.0574313 (4697)	total: 1m 4s	remaining: 1m 13s
# 4720:	learn: -0.2895371	test: -0.0574086	best: -0.0574086 (4720)	total: 1m 5s	remaining: 1m 12s
# 4740:	learn: -0.2895291	test: -0.0573281	best: -0.0573242 (4728)	total: 1m 5s	remaining: 1m 12s
# 4760:	learn: -0.2895211	test: -0.0573624	best: -0.0573242 (4728)	total: 1m 5s	remaining: 1m 12s
# 4780:	learn: -0.2895137	test: -0.0573558	best: -0.0573242 (4728)	total: 1m 6s	remaining: 1m 12s
# 4800:	learn: -0.2895048	test: -0.0573242	best: -0.0573114 (4798)	total: 1m 6s	remaining: 1m 11s
# 4820:	learn: -0.2894960	test: -0.0572492	best: -0.0572372 (4811)	total: 1m 6s	remaining: 1m 11s
# 4840:	learn: -0.2894872	test: -0.0572992	best: -0.0572222 (4822)	total: 1m 6s	remaining: 1m 11s
# 4860:	learn: -0.2894801	test: -0.0572252	best: -0.0572187 (4859)	total: 1m 7s	remaining: 1m 11s
# 4880:	learn: -0.2894724	test: -0.0571977	best: -0.0571909 (4879)	total: 1m 7s	remaining: 1m 10s
# 4900:	learn: -0.2894652	test: -0.0571511	best: -0.0571330 (4898)	total: 1m 7s	remaining: 1m 10s
# 4920:	learn: -0.2894576	test: -0.0571423	best: -0.0571315 (4908)	total: 1m 7s	remaining: 1m 10s
# 4940:	learn: -0.2894506	test: -0.0570069	best: -0.0570069 (4940)	total: 1m 8s	remaining: 1m 9s
# 4960:	learn: -0.2894426	test: -0.0570279	best: -0.0570025 (4941)	total: 1m 8s	remaining: 1m 9s
# 4980:	learn: -0.2894358	test: -0.0570987	best: -0.0570025 (4941)	total: 1m 8s	remaining: 1m 9s
# 5000:	learn: -0.2894289	test: -0.0571427	best: -0.0570025 (4941)	total: 1m 9s	remaining: 1m 9s
# 5020:	learn: -0.2894213	test: -0.0570956	best: -0.0570025 (4941)	total: 1m 9s	remaining: 1m 8s
# 5040:	learn: -0.2894150	test: -0.0570084	best: -0.0569911 (5039)	total: 1m 9s	remaining: 1m 8s
# 5060:	learn: -0.2894075	test: -0.0569757	best: -0.0569540 (5059)	total: 1m 9s	remaining: 1m 8s
# 5080:	learn: -0.2894021	test: -0.0569138	best: -0.0569106 (5079)	total: 1m 10s	remaining: 1m 7s
# 5100:	learn: -0.2893951	test: -0.0568901	best: -0.0568852 (5098)	total: 1m 10s	remaining: 1m 7s
# 5120:	learn: -0.2893885	test: -0.0568531	best: -0.0568517 (5112)	total: 1m 10s	remaining: 1m 7s
# 5140:	learn: -0.2893814	test: -0.0568424	best: -0.0568374 (5139)	total: 1m 11s	remaining: 1m 7s
# 5160:	learn: -0.2893745	test: -0.0567844	best: -0.0567844 (5160)	total: 1m 11s	remaining: 1m 6s
# 5180:	learn: -0.2893671	test: -0.0567779	best: -0.0567779 (5180)	total: 1m 11s	remaining: 1m 6s
# 5200:	learn: -0.2893591	test: -0.0567961	best: -0.0567533 (5188)	total: 1m 11s	remaining: 1m 6s
# 5220:	learn: -0.2893518	test: -0.0568175	best: -0.0567533 (5188)	total: 1m 12s	remaining: 1m 6s
# 5240:	learn: -0.2893450	test: -0.0567592	best: -0.0567528 (5237)	total: 1m 12s	remaining: 1m 5s
# 5260:	learn: -0.2893376	test: -0.0567947	best: -0.0567528 (5237)	total: 1m 12s	remaining: 1m 5s
# 5280:	learn: -0.2893296	test: -0.0568176	best: -0.0567528 (5237)	total: 1m 12s	remaining: 1m 5s
# 5300:	learn: -0.2893234	test: -0.0568041	best: -0.0567528 (5237)	total: 1m 13s	remaining: 1m 4s
# 5320:	learn: -0.2893174	test: -0.0568066	best: -0.0567528 (5237)	total: 1m 13s	remaining: 1m 4s
# 5340:	learn: -0.2893102	test: -0.0568215	best: -0.0567528 (5237)	total: 1m 13s	remaining: 1m 4s
# 5360:	learn: -0.2893033	test: -0.0567237	best: -0.0567237 (5360)	total: 1m 14s	remaining: 1m 4s
# 5380:	learn: -0.2892976	test: -0.0567462	best: -0.0567076 (5371)	total: 1m 14s	remaining: 1m 3s
# 5400:	learn: -0.2892906	test: -0.0567283	best: -0.0567068 (5395)	total: 1m 14s	remaining: 1m 3s
# 5420:	learn: -0.2892841	test: -0.0567392	best: -0.0567068 (5395)	total: 1m 14s	remaining: 1m 3s
# 5440:	learn: -0.2892785	test: -0.0566805	best: -0.0566578 (5435)	total: 1m 15s	remaining: 1m 2s
# 5460:	learn: -0.2892710	test: -0.0566856	best: -0.0566578 (5435)	total: 1m 15s	remaining: 1m 2s
# 5480:	learn: -0.2892642	test: -0.0566439	best: -0.0566351 (5479)	total: 1m 15s	remaining: 1m 2s
# 5500:	learn: -0.2892583	test: -0.0566422	best: -0.0566279 (5498)	total: 1m 15s	remaining: 1m 2s
# 5520:	learn: -0.2892524	test: -0.0565970	best: -0.0565970 (5520)	total: 1m 16s	remaining: 1m 1s
# 7680:	learn: -0.2887942	test: -0.0548063	best: -0.0547710 (7645)	total: 1m 45s	remaining: 31.8s
# 7700:	learn: -0.2887914	test: -0.0547402	best: -0.0547392 (7699)	total: 1m 45s	remaining: 31.5s
# 7720:	learn: -0.2887881	test: -0.0547274	best: -0.0547068 (7708)	total: 1m 45s	remaining: 31.3s
# 7740:	learn: -0.2887853	test: -0.0547134	best: -0.0547049 (7735)	total: 1m 46s	remaining: 31s
# 7760:	learn: -0.2887822	test: -0.0547914	best: -0.0547049 (7735)	total: 1m 46s	remaining: 30.7s
# 7780:	learn: -0.2887795	test: -0.0547295	best: -0.0547049 (7735)	total: 1m 46s	remaining: 30.4s
# 7800:	learn: -0.2887771	test: -0.0546759	best: -0.0546759 (7800)	total: 1m 46s	remaining: 30.2s
# 7820:	learn: -0.2887742	test: -0.0546770	best: -0.0546759 (7800)	total: 1m 47s	remaining: 29.9s
# 7840:	learn: -0.2887716	test: -0.0546774	best: -0.0546708 (7838)	total: 1m 47s	remaining: 29.6s
# 7860:	learn: -0.2887685	test: -0.0546834	best: -0.0546671 (7844)	total: 1m 47s	remaining: 29.3s
# 7880:	learn: -0.2887653	test: -0.0546720	best: -0.0546445 (7871)	total: 1m 48s	remaining: 29.1s
# 7900:	learn: -0.2887623	test: -0.0545833	best: -0.0545668 (7895)	total: 1m 48s	remaining: 28.8s
# 7920:	learn: -0.2887594	test: -0.0545646	best: -0.0545646 (7920)	total: 1m 48s	remaining: 28.5s
# 7940:	learn: -0.2887567	test: -0.0545656	best: -0.0545525 (7936)	total: 1m 48s	remaining: 28.2s
# 7960:	learn: -0.2887534	test: -0.0545331	best: -0.0545326 (7958)	total: 1m 49s	remaining: 28s
# 7980:	learn: -0.2887501	test: -0.0545806	best: -0.0545326 (7958)	total: 1m 49s	remaining: 27.7s
# 8000:	learn: -0.2887477	test: -0.0545468	best: -0.0545229 (7996)	total: 1m 49s	remaining: 27.4s
# 8020:	learn: -0.2887448	test: -0.0545454	best: -0.0545229 (7996)	total: 1m 49s	remaining: 27.1s
# 8040:	learn: -0.2887418	test: -0.0545450	best: -0.0545033 (8027)	total: 1m 50s	remaining: 26.9s
# 8060:	learn: -0.2887392	test: -0.0544957	best: -0.0544910 (8059)	total: 1m 50s	remaining: 26.6s
# 8080:	learn: -0.2887362	test: -0.0544600	best: -0.0544600 (8080)	total: 1m 50s	remaining: 26.3s
# 8100:	learn: -0.2887335	test: -0.0544629	best: -0.0544280 (8087)	total: 1m 50s	remaining: 26s
# 8120:	learn: -0.2887304	test: -0.0544470	best: -0.0544280 (8087)	total: 1m 51s	remaining: 25.7s
# 8140:	learn: -0.2887279	test: -0.0544119	best: -0.0544119 (8140)	total: 1m 51s	remaining: 25.5s
# 8160:	learn: -0.2887254	test: -0.0543632	best: -0.0543545 (8156)	total: 1m 51s	remaining: 25.2s
# 8180:	learn: -0.2887231	test: -0.0543251	best: -0.0543097 (8178)	total: 1m 52s	remaining: 24.9s
# 9800:	learn: -0.2885487	test: -0.0535690	best: -0.0535660 (9798)	total: 2m 13s	remaining: 2.71s
# 9820:	learn: -0.2885467	test: -0.0535286	best: -0.0535286 (9820)	total: 2m 13s	remaining: 2.43s
# 9840:	learn: -0.2885450	test: -0.0534952	best: -0.0534952 (9840)	total: 2m 13s	remaining: 2.16s
# 9860:	learn: -0.2885431	test: -0.0534957	best: -0.0534671 (9851)	total: 2m 14s	remaining: 1.89s
# 9880:	learn: -0.2885412	test: -0.0534865	best: -0.0534671 (9851)	total: 2m 14s	remaining: 1.62s
# 9900:	learn: -0.2885395	test: -0.0534948	best: -0.0534671 (9851)	total: 2m 14s	remaining: 1.35s
# 9920:	learn: -0.2885379	test: -0.0534878	best: -0.0534671 (9851)	total: 2m 14s	remaining: 1.07s
# 9940:	learn: -0.2885361	test: -0.0534975	best: -0.0534671 (9851)	total: 2m 15s	remaining: 803ms
# 9960:	learn: -0.2885344	test: -0.0534886	best: -0.0534671 (9851)	total: 2m 15s	remaining: 530ms
# 9980:	learn: -0.2885327	test: -0.0535176	best: -0.0534671 (9851)	total: 2m 15s	remaining: 258ms
# 9999:	learn: -0.2885312	test: -0.0534948	best: -0.0534671 (9851)	total: 2m 15s	remaining: 0us
#
# bestTest = -0.05346706845
# bestIteration = 9851
#
# Shrink model to first 9852 iterations.
# 	Note: model has different eval_metric than default.
# 	-0.0535	 = Validation score   (-soft_log_loss)
# 	252.39s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.006	 = Validation score   (-soft_log_loss)
# 	12.79s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.006	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL   1.000000  soft_log_loss       0.000000    3.740134                0.000000           3.740134            1       True         25
# 1             CatBoost_DSTL   1.000000  soft_log_loss       0.005001  252.394898                0.005001         252.394898            1       True         27
# 2  WeightedEnsemble_L2_DSTL   1.000000  soft_log_loss       0.016001   12.828075                0.000000           0.042829            2       True         29
# 3       NeuralNetTorch_DSTL   1.000000  soft_log_loss       0.016001   12.785246                0.016001          12.785246            1       True         28
# 4      RandomForestMSE_DSTL   0.944444  soft_log_loss       0.039451    0.837732                0.039451           0.837732            1       True         26
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 1                  LightGBM_DSTL    0.823529   1.000000  soft_log_loss
# 5                  CatBoost_DSTL    0.823529   1.000000  soft_log_loss
# 11           NeuralNetTorch_DSTL    0.764706   1.000000  soft_log_loss
# 12      WeightedEnsemble_L2_DSTL    0.764706   1.000000  soft_log_loss
# 21        NeuralNetFastAI_BAG_L1         NaN   0.954023       accuracy
# 22           WeightedEnsemble_L2         NaN   0.954023       accuracy
# 3           RandomForestMSE_DSTL    0.823529   0.944444  soft_log_loss
# 23         NeuralNetTorch_BAG_L1         NaN   0.931034       accuracy
# 24               LightGBM_BAG_L1         NaN   0.896552       accuracy
# 25             LightGBMXT_BAG_L1         NaN   0.896552       accuracy
# 26                XGBoost_BAG_L1         NaN   0.896552       accuracy
# 14       RandomForestEntr_BAG_L1    0.764706   0.885057       accuracy
# 18       RandomForestGini_BAG_L1    0.764706   0.885057       accuracy
# 27          LightGBMLarge_BAG_L1         NaN   0.885057       accuracy
# 28               CatBoost_BAG_L1         NaN   0.885057       accuracy
# 4          ExtraTreesGini_BAG_L1    0.823529   0.873563       accuracy
# 15         ExtraTreesEntr_BAG_L1    0.764706   0.873563       accuracy
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN       accuracy
# 2     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN       accuracy
# 6           LightGBM_BAG_L1_FULL    0.764706        NaN       accuracy
# 7         LightGBMXT_BAG_L1_FULL    0.764706        NaN       accuracy
# 8     NeuralNetTorch_BAG_L1_FULL    0.764706        NaN       accuracy
# 9    NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN       accuracy
# 10      WeightedEnsemble_L2_FULL    0.764706        NaN       accuracy
# 13    ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 16  RandomForestGini_BAG_L1_FULL    0.764706        NaN       accuracy
# 17  RandomForestEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 19          CatBoost_BAG_L1_FULL    0.705882        NaN       accuracy
# 20           XGBoost_BAG_L1_FULL    0.647059        NaN       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 1         0.028947       0.000000    3.740134                 0.028947
# 5         0.107900       0.005001  252.394898                 0.107900
# 11        0.029116       0.016001   12.785246                 0.029116
# 12        0.031116       0.016001   12.828075                 0.002001
# 21             NaN       0.169768   27.869469                      NaN
# 22             NaN       0.170768   28.100218                      NaN
# 3         0.082459       0.039451    0.837732                 0.082459
# 23             NaN       0.159135   23.517047                      NaN
# 24             NaN       0.008999    6.649011                      NaN
# 25             NaN       0.010000    7.890896                      NaN
# 26             NaN       0.023674    9.725472                      NaN
# 14        0.068984       0.156945    1.195818                 0.068984
# 18        0.107236       0.159098    1.873247                 0.107236
# 27             NaN       0.009857    8.818380                      NaN
# 28             NaN       0.020109   14.629152                      NaN
# 4         0.083597       0.185583    2.566812                 0.083597
# 15        0.069127       0.194149    2.825171                 0.069127
# 0         0.002001            NaN    0.304996                 0.002001
# 2         0.073183       0.185583    2.566812                 0.073183
# 6         0.002001            NaN    0.721711                 0.002001
# 7         0.003000            NaN    2.713956                 0.003000
# 8         0.012000            NaN    6.768390                 0.012000
# 9         0.016558            NaN   14.601936                 0.016558
# 10        0.018809            NaN   14.832684                 0.002251
# 13        0.055380       0.194149    2.825171                 0.055380
# 16        0.070101       0.159098    1.873247                 0.070101
# 17        0.083123       0.156945    1.195818                 0.083123
# 19        0.004489            NaN    0.700634                 0.004489
# 20        0.005593            NaN    0.344578                 0.005593
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                 0.000000           3.740134            1       True
# 5                 0.005001         252.394898            1       True
# 11                0.016001          12.785246            1       True
# 12                0.000000           0.042829            2       True
# 21                0.169768          27.869469            1      False
# 22                0.001000           0.230748            2      False
# 3                 0.039451           0.837732            1       True
# 23                0.159135          23.517047            1      False
# 24                0.008999           6.649011            1      False
# 25                0.010000           7.890896            1      False
# 26                0.023674           9.725472            1      False
# 14                0.156945           1.195818            1       True
# 18                0.159098           1.873247            1       True
# 27                0.009857           8.818380            1      False
# 28                0.020109          14.629152            1      False
# 4                 0.185583           2.566812            1       True
# 15                0.194149           2.825171            1       True
# 0                      NaN           0.304996            1       True
# 2                 0.185583           2.566812            1       True
# 6                      NaN           0.721711            1       True
# 7                      NaN           2.713956            1       True
# 8                      NaN           6.768390            1       True
# 9                      NaN          14.601936            1       True
# 10                     NaN           0.230748            2       True
# 13                0.194149           2.825171            1       True
# 16                0.159098           1.873247            1       True
# 17                0.156945           1.195818            1       True
# 19                     NaN           0.700634            1       True
# 20                     NaN           0.344578            1       True
#
#     fit_order
# 1          25
# 5          27
# 11         28
# 12         29
# 21          1
# 22         12
# 3          26
# 23         10
# 24          3
# 25          2
# 26          9
# 14          5
# 18          4
# 27         11
# 28          6
# 4           7
# 15          8
# 0          23
# 2          19
# 6          15
# 7          14
# 8          22
# 9          13
# 10         24
# 13         20
# 16         16
# 17         17
# 19         18
# 20         21
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.8235294117647058
# Evaluations on test data:
# {
#     "accuracy": 0.8235294117647058,
#     "balanced_accuracy": 0.7833333333333333,
#     "mcc": 0.7224006147708789
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.75,
#         "recall": 0.6,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.75,
#         "recall": 0.75,
#         "f1-score": 0.75,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.8235294117647058,
#     "macro avg": {
#         "precision": 0.7962962962962963,
#         "recall": 0.7833333333333333,
#         "f1-score": 0.7859477124183005,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.815359477124183,
#         "recall": 0.8235294117647058,
#         "f1-score": 0.8154555940023068,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.8235294117647058, 'balanced_accuracy': 0.7833333333333333, 'mcc': 0.7224006147708789, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      1
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              3                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.75, 'recall': 0.6, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.8235294117647058, 'macro avg': {'precision': 0.7962962962962963, 'recall': 0.7833333333333333, 'f1-score': 0.7859477124183005, 'support': 17.0}, 'weighted avg': {'precision': 0.815359477124183, 'recall': 0.8235294117647058, 'f1-score': 0.8154555940023068, 'support': 17.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.75      0.60      0.67         5
#         Exc L3-4 RORB CARM1P1       0.75      0.75      0.75         4
#         Exc L3-5 RORB COL22A1       0.89      1.00      0.94         8
#
#                      accuracy                           0.82        17
#                     macro avg       0.80      0.78      0.79        17
#                  weighted avg       0.82      0.82      0.82        17

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.345082
# [100]	valid_set's soft_log_loss: -0.202606
# [150]	valid_set's soft_log_loss: -0.161251
# [200]	valid_set's soft_log_loss: -0.135523
# [250]	valid_set's soft_log_loss: -0.124106
# [300]	valid_set's soft_log_loss: -0.121399
# [350]	valid_set's soft_log_loss: -0.127376
# [400]	valid_set's soft_log_loss: -0.125079
# [450]	valid_set's soft_log_loss: -0.121406
# [500]	valid_set's soft_log_loss: -0.121009
# [550]	valid_set's soft_log_loss: -0.122858
# [600]	valid_set's soft_log_loss: -0.119399
# [650]	valid_set's soft_log_loss: -0.119792
# [700]	valid_set's soft_log_loss: -0.116346
# [750]	valid_set's soft_log_loss: -0.112411
# [800]	valid_set's soft_log_loss: -0.114533
# [850]	valid_set's soft_log_loss: -0.119155
# [900]	valid_set's soft_log_loss: -0.12203
# [950]	valid_set's soft_log_loss: -0.122294
# [1000]	valid_set's soft_log_loss: -0.121113
# [1050]	valid_set's soft_log_loss: -0.120013
# 	Note: model has different eval_metric than default.
# 	-0.1122	 = Validation score   (-soft_log_loss)
# 	4.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.2565	 = Validation score   (-soft_log_loss)
# 	0.84s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0633180	test: -1.0710813	best: -1.0710813 (0)	total: 599ms	remaining: 1h 39m 49s
# 20:	learn: -0.6677098	test: -0.7247010	best: -0.7247010 (20)	total: 803ms	remaining: 6m 21s
# 40:	learn: -0.5026791	test: -0.5428478	best: -0.5428478 (40)	total: 1.01s	remaining: 4m 5s
# 60:	learn: -0.4216532	test: -0.4346596	best: -0.4346596 (60)	total: 1.27s	remaining: 3m 27s
# 80:	learn: -0.3725753	test: -0.3710600	best: -0.3710600 (80)	total: 1.51s	remaining: 3m 5s
# 100:	learn: -0.3383396	test: -0.3209571	best: -0.3209571 (100)	total: 1.76s	remaining: 2m 52s
# 120:	learn: -0.3134561	test: -0.2841787	best: -0.2841787 (120)	total: 2.03s	remaining: 2m 45s
# 140:	learn: -0.2934141	test: -0.2466565	best: -0.2466565 (140)	total: 2.27s	remaining: 2m 38s
# 160:	learn: -0.2784860	test: -0.2219188	best: -0.2219188 (160)	total: 2.54s	remaining: 2m 35s
# 180:	learn: -0.2672978	test: -0.2018752	best: -0.2018752 (180)	total: 2.75s	remaining: 2m 29s
# 200:	learn: -0.2581057	test: -0.1852903	best: -0.1852903 (200)	total: 2.98s	remaining: 2m 25s
# 220:	learn: -0.2512376	test: -0.1730715	best: -0.1730715 (220)	total: 3.24s	remaining: 2m 23s
# 240:	learn: -0.2457170	test: -0.1660758	best: -0.1660758 (240)	total: 3.45s	remaining: 2m 19s
# 260:	learn: -0.2413133	test: -0.1592760	best: -0.1592760 (260)	total: 3.69s	remaining: 2m 17s
# 280:	learn: -0.2380624	test: -0.1535536	best: -0.1535536 (280)	total: 3.93s	remaining: 2m 16s
# 300:	learn: -0.2346024	test: -0.1464505	best: -0.1464505 (300)	total: 4.15s	remaining: 2m 13s
# 320:	learn: -0.2319906	test: -0.1411109	best: -0.1410904 (318)	total: 4.38s	remaining: 2m 11s
# 340:	learn: -0.2294993	test: -0.1367601	best: -0.1366627 (339)	total: 4.63s	remaining: 2m 11s
# 360:	learn: -0.2274263	test: -0.1322168	best: -0.1322168 (360)	total: 4.86s	remaining: 2m 9s
# 380:	learn: -0.2254238	test: -0.1273314	best: -0.1273314 (380)	total: 5.11s	remaining: 2m 9s
# 400:	learn: -0.2238277	test: -0.1237112	best: -0.1237112 (400)	total: 5.33s	remaining: 2m 7s
# 420:	learn: -0.2224441	test: -0.1215312	best: -0.1215312 (420)	total: 5.56s	remaining: 2m 6s
# 440:	learn: -0.2211924	test: -0.1192333	best: -0.1192333 (440)	total: 5.78s	remaining: 2m 5s
# 460:	learn: -0.2200303	test: -0.1169401	best: -0.1169401 (460)	total: 6s	remaining: 2m 4s
# 480:	learn: -0.2189941	test: -0.1156538	best: -0.1155524 (479)	total: 6.21s	remaining: 2m 2s
# 500:	learn: -0.2180107	test: -0.1120859	best: -0.1120859 (500)	total: 6.44s	remaining: 2m 2s
# 520:	learn: -0.2171340	test: -0.1096678	best: -0.1096678 (520)	total: 6.68s	remaining: 2m 1s
# 540:	learn: -0.2162762	test: -0.1079141	best: -0.1079141 (540)	total: 6.91s	remaining: 2m
# 560:	learn: -0.2155230	test: -0.1058606	best: -0.1058606 (560)	total: 7.15s	remaining: 2m
# 580:	learn: -0.2147456	test: -0.1043528	best: -0.1043528 (580)	total: 7.39s	remaining: 1m 59s
# 600:	learn: -0.2141082	test: -0.1030852	best: -0.1030852 (600)	total: 7.63s	remaining: 1m 59s
# 620:	learn: -0.2134238	test: -0.1005095	best: -0.1005095 (620)	total: 7.87s	remaining: 1m 58s
# 640:	learn: -0.2128468	test: -0.0986716	best: -0.0986716 (640)	total: 8.09s	remaining: 1m 58s
# 660:	learn: -0.2123504	test: -0.0973338	best: -0.0973338 (660)	total: 8.3s	remaining: 1m 57s
# 680:	learn: -0.2118895	test: -0.0962233	best: -0.0962233 (680)	total: 8.53s	remaining: 1m 56s
# 700:	learn: -0.2114343	test: -0.0949706	best: -0.0949351 (698)	total: 8.76s	remaining: 1m 56s
# 720:	learn: -0.2110232	test: -0.0937113	best: -0.0937113 (720)	total: 9s	remaining: 1m 55s
# 740:	learn: -0.2106208	test: -0.0928929	best: -0.0928252 (738)	total: 9.26s	remaining: 1m 55s
# 760:	learn: -0.2102716	test: -0.0919459	best: -0.0919059 (754)	total: 9.49s	remaining: 1m 55s
# 780:	learn: -0.2099113	test: -0.0912726	best: -0.0911886 (775)	total: 9.74s	remaining: 1m 54s
# 2400:	learn: -0.2019185	test: -0.0661114	best: -0.0661114 (2400)	total: 28.7s	remaining: 1m 30s
# 2420:	learn: -0.2018965	test: -0.0659468	best: -0.0659468 (2420)	total: 28.9s	remaining: 1m 30s
# 2440:	learn: -0.2018709	test: -0.0658935	best: -0.0657967 (2432)	total: 29.1s	remaining: 1m 30s
# 2460:	learn: -0.2018469	test: -0.0656996	best: -0.0656996 (2460)	total: 29.3s	remaining: 1m 29s
# 2480:	learn: -0.2018217	test: -0.0657269	best: -0.0656480 (2475)	total: 29.6s	remaining: 1m 29s
# 2500:	learn: -0.2017961	test: -0.0658037	best: -0.0656480 (2475)	total: 29.8s	remaining: 1m 29s
# 2520:	learn: -0.2017719	test: -0.0656871	best: -0.0656183 (2515)	total: 30s	remaining: 1m 29s
# 2540:	learn: -0.2017486	test: -0.0654780	best: -0.0654279 (2538)	total: 30.2s	remaining: 1m 28s
# 2560:	learn: -0.2017245	test: -0.0653811	best: -0.0653811 (2560)	total: 30.4s	remaining: 1m 28s
# 2580:	learn: -0.2016998	test: -0.0654230	best: -0.0653711 (2575)	total: 30.7s	remaining: 1m 28s
# 2600:	learn: -0.2016761	test: -0.0653673	best: -0.0653521 (2591)	total: 31s	remaining: 1m 28s
# 2620:	learn: -0.2016498	test: -0.0653282	best: -0.0652854 (2610)	total: 31.2s	remaining: 1m 27s
# 2640:	learn: -0.2016285	test: -0.0652645	best: -0.0652398 (2639)	total: 31.5s	remaining: 1m 27s
# 2660:	learn: -0.2016056	test: -0.0651617	best: -0.0651617 (2660)	total: 31.7s	remaining: 1m 27s
# 2680:	learn: -0.2015834	test: -0.0649760	best: -0.0649760 (2680)	total: 32s	remaining: 1m 27s
# 2700:	learn: -0.2015639	test: -0.0650473	best: -0.0649760 (2680)	total: 32.2s	remaining: 1m 27s
# 2720:	learn: -0.2015432	test: -0.0649895	best: -0.0649710 (2718)	total: 32.4s	remaining: 1m 26s
# 2740:	learn: -0.2015229	test: -0.0649840	best: -0.0649377 (2731)	total: 32.7s	remaining: 1m 26s
# 2760:	learn: -0.2015041	test: -0.0647831	best: -0.0647831 (2760)	total: 33s	remaining: 1m 26s
# 2780:	learn: -0.2014824	test: -0.0646159	best: -0.0646028 (2779)	total: 33.2s	remaining: 1m 26s
# 2800:	learn: -0.2014608	test: -0.0645538	best: -0.0645538 (2800)	total: 33.4s	remaining: 1m 25s
# 2820:	learn: -0.2014420	test: -0.0644341	best: -0.0644341 (2820)	total: 33.6s	remaining: 1m 25s
# 2840:	learn: -0.2014221	test: -0.0645800	best: -0.0644286 (2821)	total: 33.9s	remaining: 1m 25s
# 2860:	learn: -0.2014040	test: -0.0644521	best: -0.0644286 (2821)	total: 34.1s	remaining: 1m 24s
# 2880:	learn: -0.2013860	test: -0.0643003	best: -0.0643003 (2880)	total: 34.3s	remaining: 1m 24s
# 2900:	learn: -0.2013681	test: -0.0641800	best: -0.0641519 (2897)	total: 34.6s	remaining: 1m 24s
# 2920:	learn: -0.2013509	test: -0.0641815	best: -0.0640744 (2911)	total: 34.8s	remaining: 1m 24s
# 4000:	learn: -0.2006158	test: -0.0609620	best: -0.0609264 (3993)	total: 47.6s	remaining: 1m 11s
# 4020:	learn: -0.2006054	test: -0.0608561	best: -0.0608368 (4012)	total: 47.8s	remaining: 1m 11s
# 4040:	learn: -0.2005962	test: -0.0607372	best: -0.0607217 (4039)	total: 48.1s	remaining: 1m 10s
# 4060:	learn: -0.2005857	test: -0.0606812	best: -0.0606680 (4050)	total: 48.3s	remaining: 1m 10s
# 4080:	learn: -0.2005778	test: -0.0606113	best: -0.0606113 (4080)	total: 48.6s	remaining: 1m 10s
# 4100:	learn: -0.2005680	test: -0.0605436	best: -0.0605318 (4092)	total: 48.8s	remaining: 1m 10s
# 4120:	learn: -0.2005599	test: -0.0605204	best: -0.0604762 (4114)	total: 49s	remaining: 1m 9s
# 4140:	learn: -0.2005496	test: -0.0605373	best: -0.0604762 (4114)	total: 49.2s	remaining: 1m 9s
# 4160:	learn: -0.2005410	test: -0.0604987	best: -0.0604762 (4114)	total: 49.4s	remaining: 1m 9s
# 4180:	learn: -0.2005318	test: -0.0603317	best: -0.0603317 (4180)	total: 49.7s	remaining: 1m 9s
# 4200:	learn: -0.2005237	test: -0.0602882	best: -0.0602403 (4190)	total: 49.9s	remaining: 1m 8s
# 4220:	learn: -0.2005140	test: -0.0602533	best: -0.0601913 (4206)	total: 50.1s	remaining: 1m 8s
# 4240:	learn: -0.2005060	test: -0.0602089	best: -0.0601584 (4232)	total: 50.4s	remaining: 1m 8s
# 4260:	learn: -0.2004960	test: -0.0601872	best: -0.0601340 (4249)	total: 50.6s	remaining: 1m 8s
# 4280:	learn: -0.2004894	test: -0.0601062	best: -0.0601037 (4272)	total: 50.8s	remaining: 1m 7s
# 4300:	learn: -0.2004794	test: -0.0600763	best: -0.0600691 (4299)	total: 51.1s	remaining: 1m 7s
# 4320:	learn: -0.2004716	test: -0.0599839	best: -0.0599818 (4318)	total: 51.3s	remaining: 1m 7s
# 4340:	learn: -0.2004631	test: -0.0599274	best: -0.0599274 (4340)	total: 51.5s	remaining: 1m 7s
# 4360:	learn: -0.2004559	test: -0.0598260	best: -0.0598234 (4359)	total: 51.8s	remaining: 1m 6s
# 4380:	learn: -0.2004472	test: -0.0597494	best: -0.0597494 (4380)	total: 52s	remaining: 1m 6s
# 4400:	learn: -0.2004394	test: -0.0596949	best: -0.0596949 (4398)	total: 52.3s	remaining: 1m 6s
# 4420:	learn: -0.2004318	test: -0.0596695	best: -0.0596695 (4420)	total: 52.5s	remaining: 1m 6s
# 4440:	learn: -0.2004234	test: -0.0596940	best: -0.0596583 (4423)	total: 52.7s	remaining: 1m 6s
# 4460:	learn: -0.2004147	test: -0.0596798	best: -0.0596583 (4423)	total: 53s	remaining: 1m 5s
# 4480:	learn: -0.2004068	test: -0.0595360	best: -0.0595360 (4480)	total: 53.3s	remaining: 1m 5s
# 4500:	learn: -0.2003994	test: -0.0595419	best: -0.0595221 (4482)	total: 53.5s	remaining: 1m 5s
# 4520:	learn: -0.2003912	test: -0.0596278	best: -0.0595221 (4482)	total: 53.7s	remaining: 1m 5s
# 5620:	learn: -0.2000571	test: -0.0577120	best: -0.0576935 (5613)	total: 1m 6s	remaining: 52s
# 5640:	learn: -0.2000522	test: -0.0576463	best: -0.0576435 (5638)	total: 1m 6s	remaining: 51.8s
# 5660:	learn: -0.2000481	test: -0.0575835	best: -0.0575808 (5656)	total: 1m 7s	remaining: 51.5s
# 5680:	learn: -0.2000435	test: -0.0575381	best: -0.0575381 (5680)	total: 1m 7s	remaining: 51.3s
# 5700:	learn: -0.2000388	test: -0.0574782	best: -0.0574757 (5699)	total: 1m 7s	remaining: 51s
# 5720:	learn: -0.2000343	test: -0.0574807	best: -0.0574650 (5718)	total: 1m 7s	remaining: 50.8s
# 5740:	learn: -0.2000293	test: -0.0575872	best: -0.0574650 (5718)	total: 1m 8s	remaining: 50.5s
# 5760:	learn: -0.2000248	test: -0.0574799	best: -0.0574650 (5718)	total: 1m 8s	remaining: 50.3s
# 5780:	learn: -0.2000199	test: -0.0574489	best: -0.0574386 (5778)	total: 1m 8s	remaining: 50s
# 5800:	learn: -0.2000154	test: -0.0573984	best: -0.0573950 (5794)	total: 1m 8s	remaining: 49.8s
# 5820:	learn: -0.2000107	test: -0.0573753	best: -0.0573690 (5819)	total: 1m 9s	remaining: 49.5s
# 5840:	learn: -0.2000068	test: -0.0572801	best: -0.0572775 (5838)	total: 1m 9s	remaining: 49.3s
# 5860:	learn: -0.2000023	test: -0.0572378	best: -0.0572323 (5859)	total: 1m 9s	remaining: 49.1s
# 5880:	learn: -0.1999983	test: -0.0572495	best: -0.0572094 (5868)	total: 1m 9s	remaining: 48.8s
# 5900:	learn: -0.1999943	test: -0.0572478	best: -0.0572056 (5889)	total: 1m 9s	remaining: 48.6s
# 5920:	learn: -0.1999901	test: -0.0572263	best: -0.0572056 (5889)	total: 1m 10s	remaining: 48.3s
# 5940:	learn: -0.1999856	test: -0.0571746	best: -0.0571702 (5938)	total: 1m 10s	remaining: 48.1s
# 5960:	learn: -0.1999814	test: -0.0571864	best: -0.0571546 (5943)	total: 1m 10s	remaining: 47.9s
# 5980:	learn: -0.1999767	test: -0.0571391	best: -0.0571351 (5975)	total: 1m 10s	remaining: 47.6s
# 6000:	learn: -0.1999722	test: -0.0570716	best: -0.0570663 (5998)	total: 1m 11s	remaining: 47.4s
# 6020:	learn: -0.1999683	test: -0.0570978	best: -0.0570585 (6004)	total: 1m 11s	remaining: 47.2s
# 6040:	learn: -0.1999640	test: -0.0570903	best: -0.0570585 (6004)	total: 1m 11s	remaining: 46.9s
# 6060:	learn: -0.1999604	test: -0.0570861	best: -0.0570585 (6004)	total: 1m 11s	remaining: 46.7s
# 6080:	learn: -0.1999562	test: -0.0570743	best: -0.0570585 (6004)	total: 1m 12s	remaining: 46.5s
# 6100:	learn: -0.1999527	test: -0.0570108	best: -0.0570108 (6100)	total: 1m 12s	remaining: 46.2s
# 6120:	learn: -0.1999484	test: -0.0569343	best: -0.0569343 (6120)	total: 1m 12s	remaining: 46s
# 6140:	learn: -0.1999444	test: -0.0569012	best: -0.0569012 (6140)	total: 1m 12s	remaining: 45.8s
# 6160:	learn: -0.1999401	test: -0.0568257	best: -0.0568151 (6157)	total: 1m 13s	remaining: 45.5s
# 6180:	learn: -0.1999359	test: -0.0567579	best: -0.0567579 (6180)	total: 1m 13s	remaining: 45.3s
# 6200:	learn: -0.1999321	test: -0.0567207	best: -0.0567207 (6200)	total: 1m 13s	remaining: 45s
# 6220:	learn: -0.1999284	test: -0.0567110	best: -0.0567093 (6204)	total: 1m 13s	remaining: 44.8s
# 6240:	learn: -0.1999240	test: -0.0567072	best: -0.0566993 (6221)	total: 1m 13s	remaining: 44.6s
# 6260:	learn: -0.1999196	test: -0.0566132	best: -0.0565785 (6255)	total: 1m 14s	remaining: 44.3s
# 6280:	learn: -0.1999161	test: -0.0565615	best: -0.0565472 (6271)	total: 1m 14s	remaining: 44.1s
# 6300:	learn: -0.1999126	test: -0.0565048	best: -0.0564940 (6297)	total: 1m 14s	remaining: 43.8s
# 6320:	learn: -0.1999083	test: -0.0564788	best: -0.0564496 (6318)	total: 1m 14s	remaining: 43.6s
# 6340:	learn: -0.1999041	test: -0.0563996	best: -0.0563996 (6340)	total: 1m 15s	remaining: 43.4s
# 6360:	learn: -0.1999009	test: -0.0563676	best: -0.0563624 (6357)	total: 1m 15s	remaining: 43.1s
# 6380:	learn: -0.1998974	test: -0.0563805	best: -0.0563408 (6376)	total: 1m 15s	remaining: 42.9s
# 6400:	learn: -0.1998938	test: -0.0563805	best: -0.0563408 (6376)	total: 1m 15s	remaining: 42.7s
# 6420:	learn: -0.1998901	test: -0.0563446	best: -0.0563385 (6415)	total: 1m 16s	remaining: 42.5s
# 6440:	learn: -0.1998863	test: -0.0563322	best: -0.0563251 (6439)	total: 1m 16s	remaining: 42.2s
# 6460:	learn: -0.1998834	test: -0.0562732	best: -0.0562732 (6460)	total: 1m 16s	remaining: 42s
# 6480:	learn: -0.1998796	test: -0.0562635	best: -0.0562614 (6467)	total: 1m 16s	remaining: 41.8s
# 6500:	learn: -0.1998756	test: -0.0562518	best: -0.0562314 (6488)	total: 1m 17s	remaining: 41.5s
# 6520:	learn: -0.1998723	test: -0.0562086	best: -0.0562021 (6518)	total: 1m 17s	remaining: 41.3s
# 6540:	learn: -0.1998686	test: -0.0561589	best: -0.0561419 (6531)	total: 1m 17s	remaining: 41.1s
# 6560:	learn: -0.1998654	test: -0.0562203	best: -0.0561419 (6531)	total: 1m 17s	remaining: 40.8s
# 6580:	learn: -0.1998623	test: -0.0562290	best: -0.0561419 (6531)	total: 1m 18s	remaining: 40.6s
# 6600:	learn: -0.1998589	test: -0.0561347	best: -0.0561347 (6600)	total: 1m 18s	remaining: 40.3s
# 6620:	learn: -0.1998553	test: -0.0560861	best: -0.0560821 (6613)	total: 1m 18s	remaining: 40.1s
# 6640:	learn: -0.1998526	test: -0.0560769	best: -0.0560463 (6630)	total: 1m 18s	remaining: 39.8s
# 6660:	learn: -0.1998494	test: -0.0560410	best: -0.0560192 (6658)	total: 1m 19s	remaining: 39.6s
# 9880:	learn: -0.1994879	test: -0.0525630	best: -0.0525630 (9880)	total: 1m 57s	remaining: 1.42s
# 9900:	learn: -0.1994865	test: -0.0525694	best: -0.0525609 (9882)	total: 1m 57s	remaining: 1.18s
# 9920:	learn: -0.1994850	test: -0.0525272	best: -0.0525200 (9919)	total: 1m 58s	remaining: 940ms
# 9940:	learn: -0.1994834	test: -0.0524974	best: -0.0524971 (9939)	total: 1m 58s	remaining: 702ms
# 9960:	learn: -0.1994821	test: -0.0524983	best: -0.0524679 (9948)	total: 1m 58s	remaining: 464ms
# 9980:	learn: -0.1994807	test: -0.0524635	best: -0.0524484 (9978)	total: 1m 58s	remaining: 226ms
# 9999:	learn: -0.1994791	test: -0.0524297	best: -0.0524297 (9999)	total: 1m 58s	remaining: 0us
#
# bestTest = -0.05242967977
# bestIteration = 9999
# 	Note: model has different eval_metric than default.
# 	-0.0524	 = Validation score   (-soft_log_loss)
# 	237.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.0361	 = Validation score   (-soft_log_loss)
# 	8.65s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_2_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.0361	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   1.000000  soft_log_loss       0.004379  237.249992                0.004379         237.249992            1       True         32
# 1       NeuralNetTorch_2_DSTL   1.000000  soft_log_loss       0.018601    8.651360                0.018601           8.651360            1       True         33
# 2  WeightedEnsemble_2_L2_DSTL   1.000000  soft_log_loss       0.018814    8.693435                0.000213           0.042076            2       True         34
# 3             LightGBM_2_DSTL   0.944444  soft_log_loss       0.002003    4.092738                0.002003           4.092738            1       True         30
# 4      RandomForestMSE_2_DSTL   0.888889  soft_log_loss       0.082295    0.838935                0.082295           0.838935            1       True         31
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 1          NeuralNetTorch_2_DSTL    0.823529   1.000000  soft_log_loss
# 2     WeightedEnsemble_2_L2_DSTL    0.823529   1.000000  soft_log_loss
# 3                  LightGBM_DSTL    0.823529   1.000000  soft_log_loss
# 5                  CatBoost_DSTL    0.823529   1.000000  soft_log_loss
# 7                CatBoost_2_DSTL    0.823529   1.000000  soft_log_loss
# 4                LightGBM_2_DSTL    0.823529   0.944444  soft_log_loss
# 9           RandomForestMSE_DSTL    0.823529   0.944444  soft_log_loss
# 8          ExtraTreesGini_BAG_L1    0.823529   0.873563       accuracy
# 0      LightGBMLarge_BAG_L1_FULL    0.823529        NaN       accuracy
# 6     ExtraTreesGini_BAG_L1_FULL    0.823529        NaN       accuracy
# 15           NeuralNetTorch_DSTL    0.764706   1.000000  soft_log_loss
# 16      WeightedEnsemble_L2_DSTL    0.764706   1.000000  soft_log_loss
# 21        RandomForestMSE_2_DSTL    0.764706   0.888889  soft_log_loss
# 17       RandomForestEntr_BAG_L1    0.764706   0.885057       accuracy
# 23       RandomForestGini_BAG_L1    0.764706   0.885057       accuracy
# 18         ExtraTreesEntr_BAG_L1    0.764706   0.873563       accuracy
# 10          LightGBM_BAG_L1_FULL    0.764706        NaN       accuracy
# 11        LightGBMXT_BAG_L1_FULL    0.764706        NaN       accuracy
# 12    NeuralNetTorch_BAG_L1_FULL    0.764706        NaN       accuracy
# 13   NeuralNetFastAI_BAG_L1_FULL    0.764706        NaN       accuracy
# 14      WeightedEnsemble_L2_FULL    0.764706        NaN       accuracy
# 19  RandomForestGini_BAG_L1_FULL    0.764706        NaN       accuracy
# 20    ExtraTreesEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 22  RandomForestEntr_BAG_L1_FULL    0.764706        NaN       accuracy
# 24          CatBoost_BAG_L1_FULL    0.705882        NaN       accuracy
# 25           XGBoost_BAG_L1_FULL    0.647059        NaN       accuracy
# 26        NeuralNetFastAI_BAG_L1         NaN   0.954023       accuracy
# 27           WeightedEnsemble_L2         NaN   0.954023       accuracy
# 28         NeuralNetTorch_BAG_L1         NaN   0.931034       accuracy
# 29               LightGBM_BAG_L1         NaN   0.896552       accuracy
# 30             LightGBMXT_BAG_L1         NaN   0.896552       accuracy
# 31                XGBoost_BAG_L1         NaN   0.896552       accuracy
# 32          LightGBMLarge_BAG_L1         NaN   0.885057       accuracy
# 33               CatBoost_BAG_L1         NaN   0.885057       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 1         0.025621       0.018601    8.651360                 0.025621
# 2         0.027619       0.018814    8.693435                 0.001998
# 3         0.033654       0.000000    3.740134                 0.033654
# 5         0.052790       0.005001  252.394898                 0.052790
# 7         0.060902       0.004379  237.249992                 0.060902
# 4         0.046431       0.002003    4.092738                 0.046431
# 9         0.101035       0.039451    0.837732                 0.101035
# 8         0.086244       0.185583    2.566812                 0.086244
# 0         0.001999            NaN    0.304996                 0.001999
# 6         0.058881       0.185583    2.566812                 0.058881
# 15        0.022496       0.016001   12.785246                 0.022496
# 16        0.024496       0.016001   12.828075                 0.002001
# 21        0.092376       0.082295    0.838935                 0.092376
# 17        0.072141       0.156945    1.195818                 0.072141
# 23        0.165654       0.159098    1.873247                 0.165654
# 18        0.074123       0.194149    2.825171                 0.074123
# 10        0.003000            NaN    0.721711                 0.003000
# 11        0.005130            NaN    2.713956                 0.005130
# 12        0.014423            NaN    6.768390                 0.014423
# 13        0.017003            NaN   14.601936                 0.017003
# 14        0.019005            NaN   14.832684                 0.002001
# 19        0.082746       0.159098    1.873247                 0.082746
# 20        0.089195       0.194149    2.825171                 0.089195
# 22        0.099961       0.156945    1.195818                 0.099961
# 24        0.005999            NaN    0.700634                 0.005999
# 25        0.005002            NaN    0.344578                 0.005002
# 26             NaN       0.169768   27.869469                      NaN
# 27             NaN       0.170768   28.100218                      NaN
# 28             NaN       0.159135   23.517047                      NaN
# 29             NaN       0.008999    6.649011                      NaN
# 30             NaN       0.010000    7.890896                      NaN
# 31             NaN       0.023674    9.725472                      NaN
# 32             NaN       0.009857    8.818380                      NaN
# 33             NaN       0.020109   14.629152                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                 0.018601           8.651360            1       True
# 2                 0.000213           0.042076            2       True
# 3                 0.000000           3.740134            1       True
# 5                 0.005001         252.394898            1       True
# 7                 0.004379         237.249992            1       True
# 4                 0.002003           4.092738            1       True
# 9                 0.039451           0.837732            1       True
# 8                 0.185583           2.566812            1       True
# 0                      NaN           0.304996            1       True
# 6                 0.185583           2.566812            1       True
# 15                0.016001          12.785246            1       True
# 16                0.000000           0.042829            2       True
# 21                0.082295           0.838935            1       True
# 17                0.156945           1.195818            1       True
# 23                0.159098           1.873247            1       True
# 18                0.194149           2.825171            1       True
# 10                     NaN           0.721711            1       True
# 11                     NaN           2.713956            1       True
# 12                     NaN           6.768390            1       True
# 13                     NaN          14.601936            1       True
# 14                     NaN           0.230748            2       True
# 19                0.159098           1.873247            1       True
# 20                0.194149           2.825171            1       True
# 22                0.156945           1.195818            1       True
# 24                     NaN           0.700634            1       True
# 25                     NaN           0.344578            1       True
# 26                0.169768          27.869469            1      False
# 27                0.001000           0.230748            2      False
# 28                0.159135          23.517047            1      False
# 29                0.008999           6.649011            1      False
# 30                0.010000           7.890896            1      False
# 31                0.023674           9.725472            1      False
# 32                0.009857           8.818380            1      False
# 33                0.020109          14.629152            1      False
#
#     fit_order
# 1          33
# 2          34
# 3          25
# 5          27
# 7          32
# 4          30
# 9          26
# 8           7
# 0          23
# 6          19
# 15         28
# 16         29
# 21         31
# 17          5
# 23          4
# 18          8
# 10         15
# 11         14
# 12         22
# 13         13
# 14         24
# 19         16
# 20         20
# 22         17
# 24         18
# 25         21
# 26          1
# 27         12
# 28         10
# 29          3
# 30          2
# 31          9
# 32         11
# 33          6
# 测试集上的最佳蒸馏模型：
# NeuralNetTorch_2_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.8235294117647058
# Evaluations on test data:
# {
#     "accuracy": 0.8235294117647058,
#     "balanced_accuracy": 0.7666666666666666,
#     "mcc": 0.7285193814377452
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.8,
#         "recall": 0.8,
#         "f1-score": 0.8,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 1.0,
#         "recall": 0.5,
#         "f1-score": 0.6666666666666666,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8,
#         "recall": 1.0,
#         "f1-score": 0.8888888888888888,
#         "support": 8.0
#     },
#     "accuracy": 0.8235294117647058,
#     "macro avg": {
#         "precision": 0.8666666666666667,
#         "recall": 0.7666666666666666,
#         "f1-score": 0.7851851851851852,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.8470588235294118,
#         "recall": 0.8235294117647058,
#         "f1-score": 0.8104575163398692,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.8235294117647058, 'balanced_accuracy': 0.7666666666666666, 'mcc': 0.7285193814377452, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              4
# Exc L3-4 RORB CARM1P1                                      1
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      0                      1
# Exc L3-4 RORB CARM1P1                              2                      1
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.8, 'recall': 0.8, 'f1-score': 0.8, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8, 'recall': 1.0, 'f1-score': 0.8888888888888888, 'support': 8.0}, 'accuracy': 0.8235294117647058, 'macro avg': {'precision': 0.8666666666666667, 'recall': 0.7666666666666666, 'f1-score': 0.7851851851851852, 'support': 17.0}, 'weighted avg': {'precision': 0.8470588235294118, 'recall': 0.8235294117647058, 'f1-score': 0.8104575163398692, 'support': 17.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x1d7815aa010>,
#   <matplotlib.axis.YTick at 0x1d78158c810>,
#   <matplotlib.axis.YTick at 0x1d7825f7050>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L1_FULL', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'RandomForestGini_BAG_L1_FULL', 'RandomForestEntr_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'ExtraTreesGini_BAG_L1_FULL', 'ExtraTreesEntr_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'NeuralNetTorch_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'WeightedEnsemble_L2_FULL', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 4
#       2 i = 0  # index of model to use
#       3 model_to_use = all_models[i]
# ----> 4 model_pred = predictor.predict(test_data, model=model_to_use)
#       5 print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py:2117, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    2115 if decision_threshold is None:
#    2116     decision_threshold = self.decision_threshold
# -> 2117 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:189, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     187     if transform_features:
#     188         X = self.transform_features(X)
# --> 189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#     193 return y_pred_proba
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:837, in AbstractTrainer.predict_proba(self, X, model)
#     835     model = self._get_best()
#     836 cascade = isinstance(model, list)
# --> 837 return self._predict_proba_model(X, model, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:2611, in AbstractTrainer._predict_proba_model(self, X, model, model_pred_proba_dict, cascade)
#    2610 def _predict_proba_model(self, X, model, model_pred_proba_dict=None, cascade=False):
# -> 2611     return self.get_pred_proba_from_model(model=model, X=X, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:851, in AbstractTrainer.get_pred_proba_from_model(self, model, X, model_pred_proba_dict, cascade)
#     849 else:
#     850     models = [model]
# --> 851 model_pred_proba_dict = self.get_model_pred_proba_dict(X=X, models=models, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#     852 if not isinstance(model, str):
#     853     model = model.name
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1100, in AbstractTrainer.get_model_pred_proba_dict(self, X, models, model_pred_proba_dict, model_pred_time_dict, record_pred_time, use_val_cache, cascade, cascade_threshold)
#    1098     else:
#    1099         preprocess_kwargs = dict(infer=False, model_pred_proba_dict=model_pred_proba_dict)
# -> 1100     model_pred_proba_dict[model_name] = model.predict_proba(X, **preprocess_kwargs)
#    1101 else:
#    1102     model_pred_proba_dict[model_name] = model.predict_proba(X)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py:456, in BaggedEnsembleModel._predict_proba_internal(self, X, normalize, **kwargs)
#     454 model = self.load_child(self.models[0])
#     455 X = self.preprocess(X, model=model, **kwargs)
# --> 456 y_pred_proba = model.predict_proba(X=X, preprocess_nonadaptive=False, normalize=normalize)
#     457 for model in self.models[1:]:
#     458     model = self.load_child(model)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:982, in AbstractModel._predict_proba_internal(self, X, normalize, **kwargs)
#     980 if normalize is None:
#     981     normalize = self.normalize_pred_probas
# --> 982 y_pred_proba = self._predict_proba(X=X, **kwargs)
#     983 if normalize:
#     984     y_pred_proba = normalize_pred_probas(y_pred_proba, self.problem_type)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:483, in NNFastAiTabularModel._predict_proba(self, X, **kwargs)
#     479     X = pd.concat([X, X]).reset_index(drop=True)
#     480 # Copy cat_columns and cont_columns because TabularList is mutating the list
#     481 # TODO: This call has very high fixed cost with many features (0.7s for a single row with 3k features)
#     482 #  Primarily due to normalization performed on the inputs
# --> 483 test_dl = self.model.dls.test_dl(X, inplace=True)
#     484 with self.model.no_bar():
#     485     with self.model.no_logging():
#
# AttributeError: 'NoneType' object has no attribute 'dls'

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
predictor.delete_models(models_to_keep='best')
# Out:
# Dry run enabled, AutoGluon would have deleted the following models: ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsUnif_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsDist_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetFastAI_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBMXT_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBM_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\XGBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestMSE_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\WeightedEnsemble_L2_DSTL would have been deleted.
# To perform the deletion, set dry_run=False

# %%
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
