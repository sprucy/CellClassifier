# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='medium_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=True
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
num_bag_sets=1
dynamic_stacking = True
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 8,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       7.11 GB / 15.92 GB (44.6%)
# Disk Space Avail:   313.75 GB / 931.51 GB (33.7%)
# ===================================================
# Presets specified: ['medium_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Starting (repeated-)cross-validation-based sub-fits for dynamic stacking. Context path: "models\Teacher\medium_quality-20241031-210112\ds_sub_fit"Run at most 8 sub-fits based on 1-repeated 8-fold cross-validation.
# 	Starting sub-fit 1. Time limit for the sub-fit of this split is: 112.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-10-31 21:01:17,931	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "models\Teacher\medium_quality-20241031-210112\ds_sub_fit\sub_fit_0"
# (_dystack pid=29688) Running DyStack sub-fit ...
# (_dystack pid=29688) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=29688) AutoGluon will save models to "models\Teacher\medium_quality-20241031-210112\ds_sub_fit\sub_fit_0"
# (_dystack pid=29688) Train Data Rows:    270
# (_dystack pid=29688) Train Data Columns: 36
# (_dystack pid=29688) Label Column:       label
# (_dystack pid=29688) Problem Type:       multiclass
# (_dystack pid=29688) Preprocessing data ...
# (_dystack pid=29688) Train Data Class Count: 3
# (_dystack pid=29688) Using Feature Generators to preprocess the data ...
# (_dystack pid=29688) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=29688) 	Available Memory:                    6761.80 MB
# (_dystack pid=29688) 	Train Data (Original)  Memory Usage: 0.07 MB (0.0% of available memory)
# (_dystack pid=29688) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=29688) 	Stage 1 Generators:
# (_dystack pid=29688) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=29688) 	Stage 2 Generators:
# (_dystack pid=29688) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=29688) 	Stage 3 Generators:
# (_dystack pid=29688) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=29688) 	Stage 4 Generators:
# (_dystack pid=29688) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=29688) 	Stage 5 Generators:
# (_dystack pid=29688) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=29688) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=29688) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=29688) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=29688) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=29688) 	0.1s = Fit runtime
# (_dystack pid=29688) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=29688) 	Train Data (Processed) Memory Usage: 0.07 MB (0.0% of available memory)
# (_dystack pid=29688) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=29688) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=29688) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=29688) User-specified model hyperparameters to be fit:
# (_dystack pid=29688) {
# (_dystack pid=29688) 	'NN_TORCH': {},
# (_dystack pid=29688) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=29688) 	'CAT': {},
# (_dystack pid=29688) 	'XGB': {},
# (_dystack pid=29688) 	'FASTAI': {},
# (_dystack pid=29688) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=29688) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=29688) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=29688) }
# (_dystack pid=29688) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=29688) Fitting 13 L1 models ...
# (_dystack pid=29688) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.39s of the 891.81s of remaining time.
# (_dystack pid=29688) 	0.6667	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.01s	 = Training   runtime
# (_dystack pid=29688) 	0.08s	 = Validation runtime
# (_dystack pid=29688) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 591.98s of the 889.39s of remaining time.
# (_dystack pid=29688) 	0.7963	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.01s	 = Training   runtime
# (_dystack pid=29688) 	0.0s	 = Validation runtime
# (_dystack pid=29688) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 591.95s of the 889.37s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=29688) 	0.8852	 = Validation score   (accuracy)
# (_dystack pid=29688) 	11.01s	 = Training   runtime
# (_dystack pid=29688) 	0.13s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 576.35s of the 873.77s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=29688) 	0.8741	 = Validation score   (accuracy)
# (_dystack pid=29688) 	2.43s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBM_BAG_L1 ... Training model for up to 568.49s of the 865.91s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=29688) 	0.8741	 = Validation score   (accuracy)
# (_dystack pid=29688) 	1.78s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 561.47s of the 858.88s of remaining time.
# (_dystack pid=29688) 	0.837	 = Validation score   (accuracy)
# (_dystack pid=29688) 	1.0s	 = Training   runtime
# (_dystack pid=29688) 	0.09s	 = Validation runtime
# (_dystack pid=29688) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 560.26s of the 857.68s of remaining time.
# (_dystack pid=29688) 	0.8407	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.76s	 = Training   runtime
# (_dystack pid=29688) 	0.09s	 = Validation runtime
# (_dystack pid=29688) Fitting model: CatBoost_BAG_L1 ... Training model for up to 559.38s of the 856.79s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=29688) 	0.8519	 = Validation score   (accuracy)
# (_dystack pid=29688) 	18.44s	 = Training   runtime
# (_dystack pid=29688) 	0.02s	 = Validation runtime
# (_dystack pid=29688) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 535.87s of the 833.29s of remaining time.
# (_dystack pid=29688) 	0.8556	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.75s	 = Training   runtime
# (_dystack pid=29688) 	0.08s	 = Validation runtime
# (_dystack pid=29688) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 535.0s of the 832.42s of remaining time.
# (_dystack pid=29688) 	0.8556	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.87s	 = Training   runtime
# (_dystack pid=29688) 	0.11s	 = Validation runtime
# (_dystack pid=29688) Fitting model: XGBoost_BAG_L1 ... Training model for up to 533.99s of the 831.41s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=29688) 	0.8667	 = Validation score   (accuracy)
# (_dystack pid=29688) 	3.09s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 525.8s of the 823.21s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=33380) Stack (most recent call first):
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33380)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=33380)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=21896)   File "<frozen importlib._bootstrap>", line 1126
# (_ray_fit pid=21896)  in _find_and_load_unlocked
# (_dystack pid=29688) 	0.8778	 = Validation score   (accuracy)
# (_dystack pid=29688) 	15.86s	 = Training   runtime
# (_dystack pid=29688) 	0.21s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 504.7s of the 802.12s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# (_ray_fit pid=33672) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 69x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=33672)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=33672)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=29688) 	0.8741	 = Validation score   (accuracy)
# (_dystack pid=29688) 	4.91s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 791.26s of remaining time.
# (_dystack pid=29688) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.667, 'ExtraTreesGini_BAG_L1': 0.333}
# (_dystack pid=29688) 	0.8889	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.22s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting 11 L2 models ...
# (_dystack pid=29688) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 791.02s of the 790.99s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=29688) 	0.9222	 = Validation score   (accuracy)
# (_dystack pid=29688) 	11.82s	 = Training   runtime
# (_dystack pid=29688) 	0.13s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 773.97s of the 773.95s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_dystack pid=29688) 	0.9296	 = Validation score   (accuracy)
# (_dystack pid=29688) 	2.17s	 = Training   runtime
# (_dystack pid=29688) 	0.02s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBM_BAG_L2 ... Training model for up to 766.81s of the 766.8s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=29688) 	0.9296	 = Validation score   (accuracy)
# (_dystack pid=29688) 	2.65s	 = Training   runtime
# (_dystack pid=29688) 	0.02s	 = Validation runtime
# (_dystack pid=29688) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 758.83s of the 758.82s of remaining time.
# (_dystack pid=29688) 	0.8963	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.76s	 = Training   runtime
# (_dystack pid=29688) 	0.1s	 = Validation runtime
# (_dystack pid=29688) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 757.94s of the 757.93s of remaining time.
# (_dystack pid=29688) 	0.9148	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.72s	 = Training   runtime
# (_dystack pid=29688) 	0.09s	 = Validation runtime
# (_dystack pid=29688) Fitting model: CatBoost_BAG_L2 ... Training model for up to 757.1s of the 757.08s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_dystack pid=29688) 	0.9148	 = Validation score   (accuracy)
# (_dystack pid=29688) 	31.22s	 = Training   runtime
# (_dystack pid=29688) 	0.01s	 = Validation runtime
# (_dystack pid=29688) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 721.19s of the 721.18s of remaining time.
# (_dystack pid=29688) 	0.8926	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.75s	 = Training   runtime
# (_dystack pid=29688) 	0.11s	 = Validation runtime
# (_dystack pid=29688) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 720.29s of the 720.27s of remaining time.
# (_dystack pid=29688) 	0.8926	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.8s	 = Training   runtime
# (_dystack pid=29688) 	0.1s	 = Validation runtime
# (_dystack pid=29688) Fitting model: XGBoost_BAG_L2 ... Training model for up to 719.36s of the 719.34s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=29688) 	0.9296	 = Validation score   (accuracy)
# (_dystack pid=29688) 	4.11s	 = Training   runtime
# (_dystack pid=29688) 	0.07s	 = Validation runtime
# (_dystack pid=29688) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 709.86s of the 709.85s of remaining time.
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=33272) Stack (most recent call first):
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=33272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=33272)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=29688) 	0.9037	 = Validation score   (accuracy)
# (_dystack pid=29688) 	13.36s	 = Training   runtime
# (_dystack pid=29688) 	0.25s	 = Validation runtime
# (_dystack pid=29688) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 690.38s of the 690.36s of remaining time.
# (_ray_fit pid=31692) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=31692)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=31692)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=29688) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.06%)
# (_dystack pid=29688) 	0.9222	 = Validation score   (accuracy)
# (_dystack pid=29688) 	6.45s	 = Training   runtime
# (_dystack pid=29688) 	0.02s	 = Validation runtime
# (_dystack pid=29688) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 677.28s of remaining time.
# (_dystack pid=29688) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.9, 'XGBoost_BAG_L2': 0.1}
# (_dystack pid=29688) 	0.9333	 = Validation score   (accuracy)
# (_dystack pid=29688) 	0.34s	 = Training   runtime
# (_dystack pid=29688) 	0.0s	 = Validation runtime
# (_dystack pid=29688) AutoGluon training complete, total runtime = 214.96s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 60.6 rows/s (34 batch size)
# (_dystack pid=29688) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241031-210112\ds_sub_fit\sub_fit_0")
# (_dystack pid=29688) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBMLarge_BAG_L1       0.897436   0.874074    accuracy        0.124973       0.011098   4.912098                 0.124973                0.011098           4.912098            1       True         13
# 1            XGBoost_BAG_L1       0.897436   0.866667    accuracy        0.224898       0.012710   3.088066                 0.224898                0.012710           3.088066            1       True         11
# 2           CatBoost_BAG_L2       0.897436   0.914815    accuracy        2.603209       0.883090  92.157960                 0.033297                0.013510          31.222462            2       True         20
# 3   RandomForestEntr_BAG_L2       0.897436   0.914815    accuracy        2.636576       0.962240  61.652459                 0.066664                0.092660           0.716961            2       True         19
# 4     ExtraTreesGini_BAG_L2       0.897436   0.892593    accuracy        2.636904       0.976349  61.685359                 0.066993                0.106769           0.749862            2       True         21
# 5     ExtraTreesEntr_BAG_L2       0.897436   0.892593    accuracy        2.643688       0.969783  61.737870                 0.073776                0.100203           0.802372            2       True         22
# 6   RandomForestGini_BAG_L2       0.897436   0.896296    accuracy        2.661996       0.972312  61.695056                 0.092084                0.102732           0.759558            2       True         18
# 7      LightGBMLarge_BAG_L2       0.897436   0.922222    accuracy        2.666652       0.892425  67.389555                 0.096740                0.022845           6.454057            2       True         25
# 8            XGBoost_BAG_L2       0.897436   0.929630    accuracy        2.746384       0.942836  65.049130                 0.176472                0.073256           4.113632            2       True         23
# 9       WeightedEnsemble_L3       0.897436   0.933333    accuracy        2.775426       0.964691  67.561095                 0.002284                0.000000           0.341768            3       True         26
# 10    ExtraTreesGini_BAG_L1       0.871795   0.855556    accuracy        0.097107       0.082990   0.748159                 0.097107                0.082990           0.748159            1       True          9
# 11        LightGBMXT_BAG_L1       0.871795   0.874074    accuracy        0.124716       0.014364   2.431972                 0.124716                0.014364           2.431972            1       True          4
# 12    NeuralNetTorch_BAG_L1       0.871795   0.877778    accuracy        0.168179       0.206846  15.864616                 0.168179                0.206846          15.864616            1       True         12
# 13   NeuralNetFastAI_BAG_L1       0.871795   0.885185    accuracy        0.826515       0.129877  11.014418                 0.826515                0.129877          11.014418            1       True          3
# 14      WeightedEnsemble_L2       0.871795   0.888889    accuracy        0.929636       0.223899  11.986495                 0.006014                0.011031           0.223918            2       True         14
# 15        LightGBMXT_BAG_L2       0.871795   0.929630    accuracy        2.596670       0.891434  63.105696                 0.026758                0.021854           2.170198            2       True         16
# 16          LightGBM_BAG_L2       0.871795   0.929630    accuracy        2.603255       0.890949  63.582720                 0.033343                0.021369           2.647223            2       True         17
# 17   NeuralNetFastAI_BAG_L2       0.871795   0.922222    accuracy        2.717355       1.003637  72.755713                 0.147443                0.134057          11.820215            2       True         15
# 18    NeuralNetTorch_BAG_L2       0.871795   0.903704    accuracy        2.748561       1.115857  74.298093                 0.178649                0.246277          13.362595            2       True         24
# 19          LightGBM_BAG_L1       0.846154   0.874074    accuracy        0.041649       0.011006   1.782268                 0.041649                0.011006           1.782268            1       True          5
# 20    ExtraTreesEntr_BAG_L1       0.846154   0.855556    accuracy        0.079936       0.113175   0.867107                 0.079936                0.113175           0.867107            1       True         10
# 21  RandomForestEntr_BAG_L1       0.846154   0.840741    accuracy        0.083560       0.087132   0.763990                 0.083560                0.087132           0.763990            1       True          7
# 22  RandomForestGini_BAG_L1       0.846154   0.837037    accuracy        0.093726       0.091766   0.995553                 0.093726                0.091766           0.995553            1       True          6
# 23          CatBoost_BAG_L1       0.846154   0.851852    accuracy        0.694399       0.021487  18.442090                 0.694399                0.021487          18.442090            1       True          8
# 24    KNeighborsDist_BAG_L1       0.769231   0.796296    accuracy        0.005216       0.003686   0.010186                 0.005216                0.003686           0.010186            1       True          2
# 25    KNeighborsUnif_BAG_L1       0.564103   0.666667    accuracy        0.005038       0.083444   0.014974                 0.005038                0.083444           0.014974            1       True          1
# 	Starting sub-fit 2. Time limit for the sub-fit of this split is: 95.
# 		Context path: "models\Teacher\medium_quality-20241031-210112\ds_sub_fit\sub_fit_1"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     ExtraTreesEntr_BAG_L1       0.894737   0.848708    accuracy        0.083972       0.099804    0.894185                 0.083972                0.099804           0.894185            1       True         10
# 1         LightGBMXT_BAG_L2       0.894737   0.911439    accuracy        2.533384       1.037625   62.833814                 0.028937                0.012509           2.329148            2       True         16
# 2           CatBoost_BAG_L2       0.894737   0.900369    accuracy        2.536501       1.049625  102.156430                 0.032055                0.024509          41.651764            2       True         20
# 3    NeuralNetFastAI_BAG_L2       0.894737   0.918819    accuracy        2.652264       1.172865   73.486892                 0.147818                0.147749          12.982226            2       True         15
# 4       WeightedEnsemble_L3       0.894737   0.926199    accuracy        2.759063       1.327220  116.332350                 0.002052                0.005008           0.328958            3       True         26
# 5     ExtraTreesGini_BAG_L1       0.868421   0.874539    accuracy        0.123483       0.111665    0.810874                 0.123483                0.111665           0.810874            1       True          9
# 6    NeuralNetFastAI_BAG_L1       0.868421   0.881919    accuracy        0.788704       0.150116   12.094280                 0.788704                0.150116          12.094280            1       True          3
# 7   RandomForestEntr_BAG_L2       0.868421   0.889299    accuracy        2.575444       1.137612   61.317215                 0.070997                0.112496           0.812549            2       True         19
# 8     ExtraTreesEntr_BAG_L2       0.868421   0.874539    accuracy        2.577138       1.149954   61.369403                 0.072692                0.124839           0.864737            2       True         22
# 9   RandomForestGini_BAG_L2       0.868421   0.881919    accuracy        2.589072       1.134878   61.433798                 0.084626                0.109762           0.929132            2       True         18
# 10    NeuralNetTorch_BAG_L2       0.868421   0.896679    accuracy        2.721001       1.293032   73.986954                 0.216555                0.267917          13.482288            2       True         24
# 11     LightGBMLarge_BAG_L1       0.842105   0.881919    accuracy        0.050114       0.015141    4.247092                 0.050114                0.015141           4.247092            1       True         13
# 12          LightGBM_BAG_L1       0.842105   0.892989    accuracy        0.051267       0.036258    2.874659                 0.051267                0.036258           2.874659            1       True          5
# 13      WeightedEnsemble_L2       0.842105   0.892989    accuracy        0.057370       0.036258    3.037717                 0.006103                0.000000           0.163058            2       True         14
# 14     LightGBMLarge_BAG_L2       0.842105   0.892989    accuracy        2.553570       1.035937   67.021399                 0.049124                0.010821           6.516733            2       True         25
# 15    ExtraTreesGini_BAG_L2       0.842105   0.874539    accuracy        2.572616       1.136078   61.349388                 0.068170                0.110963           0.844722            2       True         21
# 16  RandomForestGini_BAG_L1       0.815789   0.848708    accuracy        0.108134       0.115255    0.804826                 0.108134                0.115255           0.804826            1       True          6
# 17          LightGBM_BAG_L2       0.815789   0.911439    accuracy        2.544513       1.038632   63.775655                 0.040067                0.013517           3.270989            2       True         17
# 18           XGBoost_BAG_L2       0.815789   0.900369    accuracy        2.703726       1.051754   64.355119                 0.199280                0.026639           3.850452            2       True         23
# 19  RandomForestEntr_BAG_L1       0.789474   0.845018    accuracy        0.063550       0.096707    0.805552                 0.063550                0.096707           0.805552            1       True          7
# 20           XGBoost_BAG_L1       0.789474   0.885609    accuracy        0.224291       0.040493    3.261381                 0.224291                0.040493           3.261381            1       True         11
# 21        LightGBMXT_BAG_L1       0.763158   0.874539    accuracy        0.132762       0.024655    2.406405                 0.132762                0.024655           2.406405            1       True          4
# 22    KNeighborsDist_BAG_L1       0.736842   0.789668    accuracy        0.000000       0.004506    0.005140                 0.000000                0.004506           0.005140            1       True          2
# 23    NeuralNetTorch_BAG_L1       0.736842   0.848708    accuracy        0.162350       0.206410   14.819967                 0.162350                0.206410          14.819967            1       True         12
# 24          CatBoost_BAG_L1       0.736842   0.867159    accuracy        0.714291       0.017049   17.477234                 0.714291                0.017049          17.477234            1       True          8
# 25    KNeighborsUnif_BAG_L1       0.552632   0.693727    accuracy        0.001528       0.107056    0.003072                 0.001528                0.107056           0.003072            1       True          1
# 	Starting sub-fit 3. Time limit for the sub-fit of this split is: 72.
# 		Context path: "models\Teacher\medium_quality-20241031-210112\ds_sub_fit\sub_fit_2"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# ...
# 0           CatBoost_BAG_L1       0.921053   0.852399    accuracy        0.600819       0.024426  19.283538                 0.600819                0.024426          19.283538            1       True          8
# 1      LightGBMLarge_BAG_L1       0.894737   0.852399    accuracy        0.026279       0.004995   3.550791                 0.026279                0.004995           3.550791            1       True         13
# 2   RandomForestEntr_BAG_L1       0.894737   0.848708    accuracy        0.065079       0.096811   0.788632                 0.065079                0.096811           0.788632            1       True          7
# 3         LightGBMXT_BAG_L1       0.894737   0.856089    accuracy        0.075507       0.011629   2.578696                 0.075507                0.011629           2.578696            1       True          4
# 4   RandomForestGini_BAG_L1       0.868421   0.856089    accuracy        0.067825       0.091681   1.017443                 0.067825                0.091681           1.017443            1       True          6
# 5     ExtraTreesGini_BAG_L1       0.868421   0.863469    accuracy        0.099112       0.078952   0.807374                 0.099112                0.078952           0.807374            1       True          9
# 6    NeuralNetFastAI_BAG_L1       0.868421   0.874539    accuracy        0.739068       0.148418  11.955046                 0.739068                0.148418          11.955046            1       True          3
# 7         LightGBMXT_BAG_L2       0.868421   0.904059    accuracy        2.215712       1.140021  64.113868                 0.024192                0.026852           2.047023            2       True         16
# 8           LightGBM_BAG_L2       0.868421   0.915129    accuracy        2.216436       1.140298  65.052894                 0.024916                0.027130           2.986049            2       True         17
# 9           CatBoost_BAG_L2       0.868421   0.904059    accuracy        2.228167       1.138885  94.803717                 0.036647                0.025717          32.736872            2       True         20
# 10    ExtraTreesGini_BAG_L2       0.868421   0.892989    accuracy        2.265169       1.221124  62.853712                 0.073649                0.107955           0.786867            2       True         21
# 11  RandomForestEntr_BAG_L2       0.868421   0.900369    accuracy        2.269802       1.201940  62.829220                 0.078282                0.088771           0.762375            2       True         19
# 12  RandomForestGini_BAG_L2       0.868421   0.896679    accuracy        2.271103       1.204619  63.063049                 0.079583                0.091451           0.996204            2       True         18
# 13    ExtraTreesEntr_BAG_L2       0.868421   0.896679    accuracy        2.297577       1.251854  62.935385                 0.106057                0.138685           0.868541            2       True         22
# 14   NeuralNetFastAI_BAG_L2       0.868421   0.918819    accuracy        2.322935       1.267667  75.727610                 0.131415                0.154499          13.660765            2       True         15
# 15           XGBoost_BAG_L2       0.868421   0.907749    accuracy        2.367816       1.182425  66.899033                 0.176296                0.069257           4.832188            2       True         23
# 16      WeightedEnsemble_L3       0.868421   0.926199    accuracy        2.504767       1.336924  80.913980                 0.005537                0.000000           0.354183            3       True         24
# 17    KNeighborsDist_BAG_L1       0.842105   0.785978    accuracy        0.005566       0.011670   0.006605                 0.005566                0.011670           0.006605            1       True          2
# 18      WeightedEnsemble_L2       0.842105   0.885609    accuracy        0.080845       0.055230   2.601573                 0.000000                0.000000           0.192590            2       True         14
# 19          LightGBM_BAG_L1       0.842105   0.885609    accuracy        0.080845       0.055230   2.408983                 0.080845                0.055230           2.408983            1       True          5
# 20    ExtraTreesEntr_BAG_L1       0.842105   0.867159    accuracy        0.083130       0.086199   0.717024                 0.083130                0.086199           0.717024            1       True         10
# 21    NeuralNetTorch_BAG_L1       0.842105   0.867159    accuracy        0.142442       0.240946  15.521137                 0.142442                0.240946          15.521137            1       True         12
# 22           XGBoost_BAG_L1       0.842105   0.870849    accuracy        0.203196       0.114160   3.431575                 0.203196                0.114160           3.431575            1       True         11
# 23    KNeighborsUnif_BAG_L1       0.710526   0.671587    accuracy        0.002655       0.148052   0.000000                 0.002655                0.148052           0.000000            1       True          1
# 	Stop cross-validation during dynamic stacking early as no more time left. Consider specifying a larger time_limit.
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	907s	 = DyStack   runtime |	2693s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2693s
# AutoGluon will save models to "models\Teacher\medium_quality-20241031-210112"
# Train Data Rows:    309
# Train Data Columns: 36
# Label Column:       label
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6828.03 MB
# 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.1s = Fit runtime
# 	36 features in original data used to generate 36 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.23s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1794.44s of the 2692.33s of remaining time.
# 	0.6861	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1791.24s of the 2689.13s of remaining time.
# 	0.7994	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1791.21s of the 2689.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9029	 = Validation score   (accuracy)
# 	10.2s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1775.95s of the 2673.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.14%)
# 	0.8932	 = Validation score   (accuracy)
# 	3.07s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1767.34s of the 2665.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.8964	 = Validation score   (accuracy)
# 	3.44s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1758.47s of the 2656.36s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.8s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1757.54s of the 2655.43s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.74s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1756.64s of the 2654.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.8738	 = Validation score   (accuracy)
# 	25.75s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1724.54s of the 2622.43s of remaining time.
# 	0.89	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1723.57s of the 2621.46s of remaining time.
# 	0.8964	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1722.5s of the 2620.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	0.8835	 = Validation score   (accuracy)
# 	3.78s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1713.56s of the 2611.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8835	 = Validation score   (accuracy)
# 	16.65s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1691.45s of the 2589.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8997	 = Validation score   (accuracy)
# 	5.44s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2577.69s of remaining time.
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L1': 0.667, 'NeuralNetFastAI_BAG_L1': 0.333}
# 	0.9159	 = Validation score   (accuracy)
# 	0.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2577.5s of the 2577.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9256	 = Validation score   (accuracy)
# 	9.92s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2561.62s of the 2561.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.9288	 = Validation score   (accuracy)
# 	2.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2552.22s of the 2552.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	0.932	 = Validation score   (accuracy)
# 	3.34s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 2543.25s of the 2543.23s of remaining time.
# 	0.9126	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 2542.11s of the 2542.1s of remaining time.
# 	0.9126	 = Validation score   (accuracy)
# 	0.85s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2541.1s of the 2541.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.9256	 = Validation score   (accuracy)
# 	33.23s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 2502.67s of the 2502.65s of remaining time.
# 	0.9191	 = Validation score   (accuracy)
# 	0.84s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 2501.66s of the 2501.64s of remaining time.
# 	0.9256	 = Validation score   (accuracy)
# 	0.75s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2500.77s of the 2500.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.9288	 = Validation score   (accuracy)
# 	3.63s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2492.08s of the 2492.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9256	 = Validation score   (accuracy)
# 	13.82s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2472.87s of the 2472.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.9288	 = Validation score   (accuracy)
# 	6.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 2460.59s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.5, 'LightGBM_BAG_L2': 0.5}
# 	0.9353	 = Validation score   (accuracy)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 232.35s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 66.3 rows/s (39 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241031-210112")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\medium_quality-20241008-171554"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L3
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.935275    accuracy       1.177177   78.040189                0.000000           0.335845            3       True         26
# 1           LightGBM_BAG_L2   0.932039    accuracy       1.163808   74.987408                0.014007           3.335510            2       True         17
# 2         LightGBMXT_BAG_L2   0.928803    accuracy       1.163170   74.368833                0.013369           2.716936            2       True         16
# 3      LightGBMLarge_BAG_L2   0.928803    accuracy       1.173699   77.688952                0.023898           6.037055            2       True         25
# 4            XGBoost_BAG_L2   0.928803    accuracy       1.186385   75.282667                0.036584           3.630770            2       True         23
# 5           CatBoost_BAG_L2   0.925566    accuracy       1.163090  104.878240                0.013289          33.226343            2       True         20
# 6     ExtraTreesEntr_BAG_L2   0.925566    accuracy       1.237215   72.399780                0.087414           0.747883            2       True         22
# 7    NeuralNetFastAI_BAG_L2   0.925566    accuracy       1.255491   81.571959                0.105690           9.920061            2       True         15
# 8     NeuralNetTorch_BAG_L2   0.925566    accuracy       1.445442   85.473687                0.295641          13.821790            2       True         24
# 9     ExtraTreesGini_BAG_L2   0.919094    accuracy       1.250327   72.496833                0.100526           0.844936            2       True         21
# 10      WeightedEnsemble_L2   0.915858    accuracy       0.219176   11.237940                0.000000           0.176431            2       True         14
# 11  RandomForestGini_BAG_L2   0.912621    accuracy       1.255462   72.608198                0.105661           0.956301            2       True         18
# 12  RandomForestEntr_BAG_L2   0.912621    accuracy       1.258216   72.503094                0.108415           0.851197            2       True         19
# 13   NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.120100   10.202697                0.120100          10.202697            1       True          3
# 14     LightGBMLarge_BAG_L1   0.899676    accuracy       0.031628    5.443710                0.031628           5.443710            1       True         13
# 15          LightGBM_BAG_L1   0.896440    accuracy       0.017013    3.436378                0.017013           3.436378            1       True          5
# 16    ExtraTreesEntr_BAG_L1   0.896440    accuracy       0.128262    0.892560                0.128262           0.892560            1       True         10
# 17        LightGBMXT_BAG_L1   0.893204    accuracy       0.030024    3.070101                0.030024           3.070101            1       True          4
# 18    ExtraTreesGini_BAG_L1   0.889968    accuracy       0.099077    0.858812                0.099077           0.858812            1       True          9
# 19           XGBoost_BAG_L1   0.883495    accuracy       0.032801    3.783630                0.032801           3.783630            1       True         11
# 20    NeuralNetTorch_BAG_L1   0.883495    accuracy       0.223907   16.649767                0.223907          16.649767            1       True         12
# 21          CatBoost_BAG_L1   0.873786    accuracy       0.020774   25.745481                0.020774          25.745481            1       True          8
# 22  RandomForestGini_BAG_L1   0.864078    accuracy       0.086533    0.804581                0.086533           0.804581            1       True          6
# 23  RandomForestEntr_BAG_L1   0.864078    accuracy       0.119646    0.742724                0.119646           0.742724            1       True          7
# 24    KNeighborsDist_BAG_L1   0.799353    accuracy       0.006321    0.010081                0.006321           0.010081            1       True          2
# 25    KNeighborsUnif_BAG_L1   0.686084    accuracy       0.233714    0.011375                0.233714           0.011375            1       True          1
# Number of models trained: 26
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L3
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       1.00      0.27      0.42        15
# Exc L2-3 LINC00507 FREM3 superficial       0.62      1.00      0.76        26
#             Exc L2-4 LINC00507 GLP2R       0.00      0.00      0.00         5
#
#                             accuracy                           0.65        46
#                            macro avg       0.54      0.42      0.40        46
#                         weighted avg       0.68      0.65      0.57        46
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 4 11  0]
#  [ 0 26  0]
#  [ 0  5  0]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.302150                              0.431159
# 1           0.275788                              0.458335
# 2           0.318964                              0.399494
# 3           0.276812                              0.456077
# 4           0.274198                              0.459278
# 5           0.289132                              0.441424
# 6           0.332966                              0.399239
# 7           0.270338                              0.461988
# 8           0.290610                              0.424659
# 9           0.351354                              0.379271
# 10          0.418452                              0.321455
# 11          0.290351                              0.425138
# 12          0.399165                              0.338103
# 13          0.291602                              0.441169
# 14          0.272209                              0.457670
# 15          0.277378                              0.439330
# 16          0.283151                              0.450701
# 17          0.269789                              0.458684
# 18          0.270894                              0.459305
# 19          0.343504                              0.393184
# 20          0.284033                              0.396062
# 21          0.333663                              0.402819
# 22          0.278616                              0.454755
# 23          0.274738                              0.458472
# 24          0.336017                              0.396466
# 25          0.331637                              0.397639
# 26          0.442274                              0.287782
# 27          0.276137                              0.457434
# 28          0.273997                              0.457241
# 29          0.356146                              0.375103
# 30          0.415906                              0.308651
# 31          0.277518                              0.455488
# 32          0.266938                              0.460576
# 33          0.276787                              0.455678
# 34          0.269734                              0.462609
# 35          0.315406                              0.410008
# 36          0.319792                              0.406145
# 37          0.273531                              0.459762
# 38          0.272657                              0.461173
# 39          0.268572                              0.457985
# 40          0.313677                              0.349473
# 41          0.278321                              0.452221
# 42          0.273553                              0.460043
# 43          0.278423                              0.450016
# 44          0.274640                              0.458927
# 45          0.272223                              0.459150
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.266691
# 1                   0.265877
# 2                   0.281542
# 3                   0.267111
# 4                   0.266524
# 5                   0.269444
# 6                   0.267795
# 7                   0.267674
# 8                   0.284730
# 9                   0.269375
# 10                  0.260093
# 11                  0.284511
# 12                  0.262732
# 13                  0.267229
# 14                  0.270121
# 15                  0.283292
# 16                  0.266148
# 17                  0.271527
# 18                  0.269801
# 19                  0.263312
# 20                  0.319905
# 21                  0.263518
# 22                  0.266629
# 23                  0.266790
# 24                  0.267518
# 25                  0.270724
# 26                  0.269944
# 27                  0.266429
# 28                  0.268762
# 29                  0.268751
# 30                  0.275443
# 31                  0.266993
# 32                  0.272485
# 33                  0.267535
# 34                  0.267657
# 35                  0.274586
# 36                  0.274063
# 37                  0.266706
# 38                  0.266170
# 39                  0.273443
# 40                  0.336850
# 41                  0.269457
# 42                  0.266404
# 43                  0.271561
# 44                  0.266434
# 45                  0.268627

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	211.69s	= Expected runtime (42.34s per shuffle set)
# 	10.62s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# TS1_adp_index           0.056522  0.024786  0.003494  5  0.107557  0.005486
# FAP_rheobase            0.043478  0.015372  0.001599  5  0.075129  0.011827
# FAP_up_down_ratio       0.043478  0.000000  0.500000  5  0.043478  0.043478
# input_resistance        0.039130  0.009722  0.000422  5  0.059148  0.019113
# TS2_avg_upstroke        0.030435  0.011907  0.002318  5  0.054951  0.005918
# TS2_up_down_ratio       0.026087  0.009722  0.001941  5  0.046105  0.006069
# TS2_avg_downstroke      0.026087  0.009722  0.001941  5  0.046105  0.006069
# TS1_avg_downstroke      0.026087  0.023814  0.035242  5  0.075120 -0.022946
# TS2_maxupstroke         0.021739  0.000000  0.500000  5  0.021739  0.021739
# TS1_up_down_ratio       0.021739  0.000000  0.500000  5  0.021739  0.021739
# TS2_adp_index           0.021739  0.015372  0.017055  5  0.053390 -0.009912
# sag                     0.021739  0.030744  0.094502  5  0.085041 -0.041563
# tau                     0.017391  0.018188  0.049650  5  0.054841 -0.020059
# TS1_threshold           0.017391  0.009722  0.008065  5  0.037409 -0.002626
# FAP_halfwidth           0.013043  0.011907  0.035242  5  0.037560 -0.011473
# L23_depth_normalized    0.013043  0.024786  0.152279  5  0.064079 -0.037992
# TS1_rheobase            0.013043  0.024786  0.152279  5  0.064079 -0.037992
# FAP_threshold           0.013043  0.011907  0.035242  5  0.037560 -0.011473
# FAP_maxupstroke         0.013043  0.024786  0.152279  5  0.064079 -0.037992
# FAP_peak                0.008696  0.011907  0.088904  5  0.033212 -0.015821
# FAP_avg_downstroke      0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS1_halfwidth           0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS1_avg_upstroke        0.008696  0.024786  0.238310  5  0.059731 -0.042340
# vmbaseM                 0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS1_maxupstroke         0.004348  0.009722  0.186950  5  0.024366 -0.015670
# TS1_maxdownstroke       0.004348  0.009722  0.186950  5  0.024366 -0.015670
# TS2_rheobase            0.000000  0.015372  0.500000  5  0.031651 -0.031651
# VmatSag                 0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_num_APs             0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke      -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# FAP_maxdownstroke      -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# TS2_threshold          -0.004348  0.018188  0.689346  5  0.033102 -0.041798
# TS2_peak               -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_num_APs            -0.013043  0.019444  0.896000  5  0.026992 -0.053079
# TS2_num_APs            -0.013043  0.011907  0.964758  5  0.011473 -0.037560
# FAP_avg_upstroke       -0.039130  0.032244  0.973331  5  0.027261 -0.105522

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L3
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'accuracy': 0.6521739130434783,
#  'balanced_accuracy': 0.4222222222222223,
#  'mcc': 0.3605717748270388,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     4
#  Exc L2-3 LINC00507 FREM3 superficial                 0
#  Exc L2-4 LINC00507 GLP2R                             0
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                        11
#  Exc L2-3 LINC00507 FREM3 superficial                                    26
#  Exc L2-4 LINC00507 GLP2R                                                 5
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     0  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 1.0,
#    'recall': 0.26666666666666666,
#    'f1-score': 0.42105263157894735,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.6190476190476191,
#    'recall': 1.0,
#    'f1-score': 0.7647058823529411,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 0.0,
#    'recall': 0.0,
#    'f1-score': 0.0,
#    'support': 5.0},
#   'accuracy': 0.6521739130434783,
#   'macro avg': {'precision': 0.5396825396825397,
#    'recall': 0.4222222222222222,
#    'f1-score': 0.39525283797729616,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.6759834368530021,
#    'recall': 0.6521739130434783,
#    'f1-score': 0.569524835105667,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
#leaderboard.to_csv('leaderboard_medium.csv')
# Out:
#                       model  score_test  score_val eval_metric  \
# 0       WeightedEnsemble_L2    0.760870   0.915858    accuracy
# 1    NeuralNetFastAI_BAG_L1    0.739130   0.902913    accuracy
# 2     ExtraTreesGini_BAG_L1    0.717391   0.889968    accuracy
# 3   RandomForestGini_BAG_L1    0.717391   0.864078    accuracy
# 4     ExtraTreesEntr_BAG_L1    0.695652   0.896440    accuracy
# 5           LightGBM_BAG_L1    0.695652   0.896440    accuracy
# 6   RandomForestEntr_BAG_L1    0.695652   0.864078    accuracy
# 7         LightGBMXT_BAG_L2    0.695652   0.928803    accuracy
# 8    NeuralNetFastAI_BAG_L2    0.695652   0.925566    accuracy
# 9           CatBoost_BAG_L1    0.673913   0.873786    accuracy
# 10        LightGBMXT_BAG_L1    0.673913   0.893204    accuracy
# 11     LightGBMLarge_BAG_L1    0.673913   0.899676    accuracy
# 12    NeuralNetTorch_BAG_L1    0.673913   0.883495    accuracy
# 13          CatBoost_BAG_L2    0.673913   0.925566    accuracy
# 14  RandomForestEntr_BAG_L2    0.673913   0.912621    accuracy
# 15    ExtraTreesEntr_BAG_L2    0.673913   0.925566    accuracy
# 16    ExtraTreesGini_BAG_L2    0.673913   0.919094    accuracy
# 17  RandomForestGini_BAG_L2    0.673913   0.912621    accuracy
# 18    NeuralNetTorch_BAG_L2    0.673913   0.925566    accuracy
# 19           XGBoost_BAG_L1    0.652174   0.883495    accuracy
# 20          LightGBM_BAG_L2    0.652174   0.932039    accuracy
# 21      WeightedEnsemble_L3    0.652174   0.935275    accuracy
# 22     LightGBMLarge_BAG_L2    0.652174   0.928803    accuracy
# 23           XGBoost_BAG_L2    0.652174   0.928803    accuracy
# 24    KNeighborsUnif_BAG_L1    0.391304   0.686084    accuracy
# 25    KNeighborsDist_BAG_L1    0.391304   0.799353    accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0         0.202048       0.219176   11.237940                 0.000000
# 1         0.110514       0.120100   10.202697                 0.110514
# 2         0.091533       0.099077    0.858812                 0.091533
# 3         0.108881       0.086533    0.804581                 0.108881
# 4         0.068321       0.128262    0.892560                 0.068321
# 5         0.074241       0.017013    3.436378                 0.074241
# 6         0.091693       0.119646    0.742724                 0.091693
# 7         1.144675       1.163170   74.368833                 0.013187
# 8         1.236570       1.255491   81.571959                 0.105082
# 9         0.036300       0.020774   25.745481                 0.036300
# 10        0.097350       0.030024    3.070101                 0.097350
# 11        0.102961       0.031628    5.443710                 0.102961
# 12        0.148283       0.223907   16.649767                 0.148283
# 13        1.165166       1.163090  104.878240                 0.033678
# 14        1.201071       1.258216   72.503094                 0.069583
# 15        1.206287       1.237215   72.399780                 0.074800
# 16        1.212488       1.250327   72.496833                 0.081000
# 17        1.217783       1.255462   72.608198                 0.086295
# 18        1.320843       1.445442   85.473687                 0.189355
# 19        0.181155       0.032801    3.783630                 0.181155
# 20        1.157476       1.163808   74.987408                 0.025989
# 21        1.170663       1.177177   78.040189                 0.000000
# 22        1.193113       1.173699   77.688952                 0.061625
# 23        1.290368       1.186385   75.282667                 0.158880
# 24        0.000000       0.233714    0.011375                 0.000000
# 25        0.020254       0.006321    0.010081                 0.020254
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000000           0.176431            2       True
# 1                 0.120100          10.202697            1       True
# 2                 0.099077           0.858812            1       True
# 3                 0.086533           0.804581            1       True
# 4                 0.128262           0.892560            1       True
# 5                 0.017013           3.436378            1       True
# 6                 0.119646           0.742724            1       True
# 7                 0.013369           2.716936            2       True
# 8                 0.105690           9.920061            2       True
# 9                 0.020774          25.745481            1       True
# 10                0.030024           3.070101            1       True
# 11                0.031628           5.443710            1       True
# 12                0.223907          16.649767            1       True
# 13                0.013289          33.226343            2       True
# 14                0.108415           0.851197            2       True
# 15                0.087414           0.747883            2       True
# 16                0.100526           0.844936            2       True
# 17                0.105661           0.956301            2       True
# 18                0.295641          13.821790            2       True
# 19                0.032801           3.783630            1       True
# 20                0.014007           3.335510            2       True
# 21                0.000000           0.335845            3       True
# 22                0.023898           6.037055            2       True
# 23                0.036584           3.630770            2       True
# 24                0.233714           0.011375            1       True
# 25                0.006321           0.010081            1       True
#
#     fit_order
# 0          14
# 1           3
# 2           9
# 3           6
# 4          10
# 5           5
# 6           7
# 7          16
# 8          15
# 9           8
# 10          4
# 11         13
# 12         12
# 13         20
# 14         19
# 15         22
# 16         21
# 17         18
# 18         24
# 19         11
# 20         17
# 21         26
# 22         25
# 23         23
# 24          1
# 25          2

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_27500\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204    Exc L2-3 LINC00507 FREM3 superficial
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.272161                              0.460791
# 1            0.269458                              0.457258
# 2            0.269342                              0.463959
# 3            0.270480                              0.463004
# 4            0.280826                              0.452648
# ..                ...                                   ...
# 204          0.300609                              0.419441
# 205          0.271686                              0.462225
# 206          0.308820                              0.422101
# 207          0.290669                              0.441192
# 208          0.282442                              0.449944
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.267048
# 1                    0.273284
# 2                    0.266699
# 3                    0.266515
# 4                    0.266527
# ..                        ...
# 204                  0.279950
# 205                  0.266090
# 206                  0.269080
# 207                  0.268139
# 208                  0.267614
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (157, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L3', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.580605
# [100]	valid_set's soft_log_loss: -0.517342
# [150]	valid_set's soft_log_loss: -0.517393
# [200]	valid_set's soft_log_loss: -0.529226
# [250]	valid_set's soft_log_loss: -0.570893
# [300]	valid_set's soft_log_loss: -0.600392
# [350]	valid_set's soft_log_loss: -0.633587
# [400]	valid_set's soft_log_loss: -0.656321
# 	Note: model has different eval_metric than default.
# 	-0.5093	 = Validation score   (-soft_log_loss)
# 	1.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4559	 = Validation score   (-soft_log_loss)
# 	0.9s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0835171	test: -1.0747809	best: -1.0747809 (0)	total: 939ms	remaining: 2h 36m 26s
# 20:	learn: -0.8969371	test: -0.8346285	best: -0.8346285 (20)	total: 1.35s	remaining: 10m 42s
# 40:	learn: -0.8073905	test: -0.7180194	best: -0.7180194 (40)	total: 1.69s	remaining: 6m 50s
# 60:	learn: -0.7558255	test: -0.6473657	best: -0.6473657 (60)	total: 2.01s	remaining: 5m 28s
# 80:	learn: -0.7244733	test: -0.6150345	best: -0.6150345 (80)	total: 2.33s	remaining: 4m 44s
# 100:	learn: -0.6940576	test: -0.5810658	best: -0.5810658 (100)	total: 2.69s	remaining: 4m 23s
# 120:	learn: -0.6688451	test: -0.5549152	best: -0.5549152 (120)	total: 3.05s	remaining: 4m 8s
# 140:	learn: -0.6509248	test: -0.5380633	best: -0.5380633 (140)	total: 3.4s	remaining: 3m 58s
# 160:	learn: -0.6356631	test: -0.5255304	best: -0.5255304 (160)	total: 3.74s	remaining: 3m 48s
# 180:	learn: -0.6218722	test: -0.5144824	best: -0.5144824 (180)	total: 4.08s	remaining: 3m 41s
# 200:	learn: -0.6090314	test: -0.5063101	best: -0.5062167 (196)	total: 4.41s	remaining: 3m 34s
# 220:	learn: -0.5996425	test: -0.5020245	best: -0.5020245 (220)	total: 4.75s	remaining: 3m 30s
# 240:	learn: -0.5894606	test: -0.4930832	best: -0.4930832 (240)	total: 5.15s	remaining: 3m 28s
# 260:	learn: -0.5821273	test: -0.4859784	best: -0.4853700 (258)	total: 5.51s	remaining: 3m 25s
# 280:	learn: -0.5759157	test: -0.4820576	best: -0.4819358 (278)	total: 5.89s	remaining: 3m 23s
# 300:	learn: -0.5701560	test: -0.4810598	best: -0.4810598 (300)	total: 6.22s	remaining: 3m 20s
# 320:	learn: -0.5647809	test: -0.4734232	best: -0.4733506 (319)	total: 6.58s	remaining: 3m 18s
# 340:	learn: -0.5603984	test: -0.4699891	best: -0.4697028 (339)	total: 6.91s	remaining: 3m 15s
# 360:	learn: -0.5562071	test: -0.4664488	best: -0.4660481 (359)	total: 7.24s	remaining: 3m 13s
# 380:	learn: -0.5526003	test: -0.4636779	best: -0.4636779 (380)	total: 7.58s	remaining: 3m 11s
# 400:	learn: -0.5493578	test: -0.4615149	best: -0.4615149 (400)	total: 7.93s	remaining: 3m 9s
# 420:	learn: -0.5464015	test: -0.4568371	best: -0.4568371 (420)	total: 8.29s	remaining: 3m 8s
# 440:	learn: -0.5434602	test: -0.4535312	best: -0.4535078 (439)	total: 8.61s	remaining: 3m 6s
# 460:	learn: -0.5405805	test: -0.4526079	best: -0.4524286 (452)	total: 8.96s	remaining: 3m 5s
# 480:	learn: -0.5380914	test: -0.4505295	best: -0.4505295 (480)	total: 9.29s	remaining: 3m 3s
# 500:	learn: -0.5358879	test: -0.4491159	best: -0.4483456 (490)	total: 9.63s	remaining: 3m 2s
# 520:	learn: -0.5339542	test: -0.4491931	best: -0.4483456 (490)	total: 9.97s	remaining: 3m 1s
# 540:	learn: -0.5321982	test: -0.4490578	best: -0.4483456 (490)	total: 10.3s	remaining: 3m
# 560:	learn: -0.5304415	test: -0.4472396	best: -0.4470802 (559)	total: 10.7s	remaining: 2m 59s
# 580:	learn: -0.5289191	test: -0.4476777	best: -0.4470558 (561)	total: 11s	remaining: 2m 58s
# 600:	learn: -0.5273949	test: -0.4486552	best: -0.4470558 (561)	total: 11.4s	remaining: 2m 57s
# 620:	learn: -0.5261625	test: -0.4498131	best: -0.4470558 (561)	total: 11.7s	remaining: 2m 56s
# 640:	learn: -0.5247841	test: -0.4508020	best: -0.4470558 (561)	total: 12.1s	remaining: 2m 56s
# 660:	learn: -0.5235796	test: -0.4511358	best: -0.4470558 (561)	total: 12.5s	remaining: 2m 55s
# 680:	learn: -0.5222672	test: -0.4489964	best: -0.4470558 (561)	total: 12.8s	remaining: 2m 54s
# 700:	learn: -0.5211084	test: -0.4495877	best: -0.4470558 (561)	total: 13.1s	remaining: 2m 54s
# 720:	learn: -0.5199859	test: -0.4487134	best: -0.4470558 (561)	total: 13.4s	remaining: 2m 52s
# 740:	learn: -0.5189499	test: -0.4498427	best: -0.4470558 (561)	total: 13.8s	remaining: 2m 51s
# 760:	learn: -0.5180420	test: -0.4511068	best: -0.4470558 (561)	total: 14.1s	remaining: 2m 51s
# 780:	learn: -0.5170239	test: -0.4533390	best: -0.4470558 (561)	total: 14.5s	remaining: 2m 51s
# 800:	learn: -0.5161403	test: -0.4531252	best: -0.4470558 (561)	total: 14.8s	remaining: 2m 50s
# 820:	learn: -0.5152814	test: -0.4542487	best: -0.4470558 (561)	total: 15.2s	remaining: 2m 49s
# 840:	learn: -0.5146501	test: -0.4534105	best: -0.4470558 (561)	total: 15.5s	remaining: 2m 49s
# 	Note: model has different eval_metric than default.
# 	-0.4471	 = Validation score   (-soft_log_loss)
# 	16.91s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# 860:	learn: -0.5140265	test: -0.4532250	best: -0.4470558 (561)	total: 15.9s	remaining: 2m 48s
#
# bestTest = -0.4470558172
# bestIteration = 561
#
# Shrink model to first 562 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5788	 = Validation score   (-soft_log_loss)
# 	17.95s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.583, 'RandomForestMSE_DSTL': 0.417}
# 	Note: model has different eval_metric than default.
# 	-0.4345	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_DSTL   0.838710  soft_log_loss       0.010095  16.905084                0.010095          16.905084            1       True         29
# 1             LightGBM_DSTL   0.822581  soft_log_loss       0.000000   1.201399                0.000000           1.201399            1       True         27
# 2  WeightedEnsemble_L2_DSTL   0.822581  soft_log_loss       0.057889  17.838501                0.000000           0.033506            2       True         31
# 3      RandomForestMSE_DSTL   0.806452  soft_log_loss       0.047794   0.899911                0.047794           0.899911            1       True         28
# 4       NeuralNetTorch_DSTL   0.790323  soft_log_loss       0.024172  17.947553                0.024172          17.947553            1       True         30
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                        model  score_test  score_val    eval_metric  \
# 25       WeightedEnsemble_L3    0.652174   0.935275       accuracy
# 24           LightGBM_BAG_L2    0.652174   0.932039       accuracy
# 11         LightGBMXT_BAG_L2    0.695652   0.928803       accuracy
# 26      LightGBMLarge_BAG_L2    0.652174   0.928803       accuracy
# 27            XGBoost_BAG_L2    0.652174   0.928803       accuracy
# 12    NeuralNetFastAI_BAG_L2    0.695652   0.925566       accuracy
# 17           CatBoost_BAG_L2    0.673913   0.925566       accuracy
# 18     ExtraTreesEntr_BAG_L2    0.673913   0.925566       accuracy
# 22     NeuralNetTorch_BAG_L2    0.673913   0.925566       accuracy
# 19     ExtraTreesGini_BAG_L2    0.673913   0.919094       accuracy
# 1        WeightedEnsemble_L2    0.760870   0.915858       accuracy
# 20   RandomForestEntr_BAG_L2    0.673913   0.912621       accuracy
# 21   RandomForestGini_BAG_L2    0.673913   0.912621       accuracy
# 2     NeuralNetFastAI_BAG_L1    0.739130   0.902913       accuracy
# 15      LightGBMLarge_BAG_L1    0.673913   0.899676       accuracy
# 9      ExtraTreesEntr_BAG_L1    0.695652   0.896440       accuracy
# 10           LightGBM_BAG_L1    0.695652   0.896440       accuracy
# 14         LightGBMXT_BAG_L1    0.673913   0.893204       accuracy
# 5      ExtraTreesGini_BAG_L1    0.717391   0.889968       accuracy
# 16     NeuralNetTorch_BAG_L1    0.673913   0.883495       accuracy
# 23            XGBoost_BAG_L1    0.652174   0.883495       accuracy
# 13           CatBoost_BAG_L1    0.673913   0.873786       accuracy
# 6    RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 8    RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 4              CatBoost_DSTL    0.717391   0.838710  soft_log_loss
# 0   WeightedEnsemble_L2_DSTL    0.760870   0.822581  soft_log_loss
# 3              LightGBM_DSTL    0.717391   0.822581  soft_log_loss
# 7       RandomForestMSE_DSTL    0.717391   0.806452  soft_log_loss
# 30     KNeighborsDist_BAG_L1    0.391304   0.799353       accuracy
# 28       NeuralNetTorch_DSTL    0.630435   0.790323  soft_log_loss
# 29     KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 25        1.191307       1.177177   78.040189                 0.000000
# 24        1.170910       1.163808   74.987408                 0.019525
# 11        1.171782       1.163170   74.368833                 0.020396
# 26        1.230318       1.173699   77.688952                 0.078933
# 27        1.305818       1.186385   75.282667                 0.154433
# 12        1.268421       1.255491   81.571959                 0.117036
# 17        1.187252       1.163090  104.878240                 0.035867
# 18        1.206511       1.237215   72.399780                 0.055126
# 22        1.323512       1.445442   85.473687                 0.172127
# 19        1.215500       1.250327   72.496833                 0.064115
# 1         0.202737       0.219176   11.237940                 0.000000
# 20        1.231843       1.258216   72.503094                 0.080458
# 21        1.234864       1.255462   72.608198                 0.083478
# 2         0.116199       0.120100   10.202697                 0.116199
# 15        0.093379       0.031628    5.443710                 0.093379
# 9         0.080770       0.128262    0.892560                 0.080770
# 10        0.111177       0.017013    3.436378                 0.111177
# 14        0.082625       0.030024    3.070101                 0.082625
# 5         0.086538       0.099077    0.858812                 0.086538
# 16        0.156821       0.223907   16.649767                 0.156821
# 23        0.203438       0.032801    3.783630                 0.203438
# 13        0.043937       0.020774   25.745481                 0.043937
# 6         0.091039       0.086533    0.804581                 0.091039
# 8         0.070837       0.119646    0.742724                 0.070837
# 4         0.010312       0.010095   16.905084                 0.010312
# 0         0.128614       0.057889   17.838501                 0.000707
# 3         0.000000       0.000000    1.201399                 0.000000
# 7         0.117595       0.047794    0.899911                 0.117595
# 30        0.009624       0.006321    0.010081                 0.009624
# 28        0.020871       0.024172   17.947553                 0.020871
# 29        0.005001       0.233714    0.011375                 0.005001
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 25                0.000000           0.335845            3       True
# 24                0.014007           3.335510            2       True
# 11                0.013369           2.716936            2       True
# 26                0.023898           6.037055            2       True
# 27                0.036584           3.630770            2       True
# 12                0.105690           9.920061            2       True
# 17                0.013289          33.226343            2       True
# 18                0.087414           0.747883            2       True
# 22                0.295641          13.821790            2       True
# 19                0.100526           0.844936            2       True
# 1                 0.000000           0.176431            2       True
# 20                0.108415           0.851197            2       True
# 21                0.105661           0.956301            2       True
# 2                 0.120100          10.202697            1       True
# 15                0.031628           5.443710            1       True
# 9                 0.128262           0.892560            1       True
# 10                0.017013           3.436378            1       True
# 14                0.030024           3.070101            1       True
# 5                 0.099077           0.858812            1       True
# 16                0.223907          16.649767            1       True
# 23                0.032801           3.783630            1       True
# 13                0.020774          25.745481            1       True
# 6                 0.086533           0.804581            1       True
# 8                 0.119646           0.742724            1       True
# 4                 0.010095          16.905084            1       True
# 0                 0.000000           0.033506            2       True
# 3                 0.000000           1.201399            1       True
# 7                 0.047794           0.899911            1       True
# 30                0.006321           0.010081            1       True
# 28                0.024172          17.947553            1       True
# 29                0.233714           0.011375            1       True
#
#     fit_order
# 25         26
# 24         17
# 11         16
# 26         25
# 27         23
# 12         15
# 17         20
# 18         22
# 22         24
# 19         21
# 1          14
# 20         19
# 21         18
# 2           3
# 15         13
# 9          10
# 10          5
# 14          4
# 5           9
# 16         12
# 23         11
# 13          8
# 6           6
# 8           7
# 4          29
# 0          31
# 3          27
# 7          28
# 30          2
# 28         30
# 29          1
# 测试集上的最佳蒸馏模型：
# CatBoost_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7042735042735043,
#     "mcc": 0.5089280034288846
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.7,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.56,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7857142857142857,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8148148148148148,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.8,
#         "f1-score": 0.6153846153846154,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6619047619047619,
#         "recall": 0.7042735042735043,
#         "f1-score": 0.6633998100664767,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7267080745341615,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7100458317849622,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7042735042735043, 'mcc': 0.5089280034288846, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 2
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         6
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             2
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.7, 'recall': 0.4666666666666667, 'f1-score': 0.56, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7857142857142857, 'recall': 0.8461538461538461, 'f1-score': 0.8148148148148148, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.8, 'f1-score': 0.6153846153846154, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6619047619047619, 'recall': 0.7042735042735043, 'f1-score': 0.6633998100664767, 'support': 46.0}, 'weighted avg': {'precision': 0.7267080745341615, 'recall': 0.717391304347826, 'f1-score': 0.7100458317849622, 'support': 46.0}}}

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7608695652173914
# Evaluations on test data:
# {
#     "accuracy": 0.7608695652173914,
#     "balanced_accuracy": 0.72991452991453,
#     "mcc": 0.5805712721073776
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.7777777777777778,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5833333333333334,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8,
#         "recall": 0.9230769230769231,
#         "f1-score": 0.8571428571428571,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "accuracy": 0.7608695652173914,
#     "macro avg": {
#         "precision": 0.7164021164021165,
#         "recall": 0.72991452991453,
#         "f1-score": 0.7023809523809524,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7679089026915114,
#         "recall": 0.7608695652173914,
#         "f1-score": 0.7471532091097309,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.7608695652173914, 'balanced_accuracy': 0.72991452991453, 'mcc': 0.5805712721073776, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 1
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         6
# Exc L2-3 LINC00507 FREM3 superficial                                    24
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             2
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.7777777777777778, 'recall': 0.4666666666666667, 'f1-score': 0.5833333333333334, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8, 'recall': 0.9230769230769231, 'f1-score': 0.8571428571428571, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5714285714285714, 'recall': 0.8, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'accuracy': 0.7608695652173914, 'macro avg': {'precision': 0.7164021164021165, 'recall': 0.72991452991453, 'f1-score': 0.7023809523809524, 'support': 46.0}, 'weighted avg': {'precision': 0.7679089026915114, 'recall': 0.7608695652173914, 'f1-score': 0.7471532091097309, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.70      0.47      0.56        15
# Exc L2-3 LINC00507 FREM3 superficial       0.79      0.85      0.81        26
#             Exc L2-4 LINC00507 GLP2R       0.50      0.80      0.62         5
#
#                             accuracy                           0.72        46
#                            macro avg       0.66      0.70      0.66        46
#                         weighted avg       0.73      0.72      0.71        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best('WeightedEnsemble_L2_DSTL')#best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.563293
# [100]	valid_set's soft_log_loss: -0.512193
# [150]	valid_set's soft_log_loss: -0.504687
# [200]	valid_set's soft_log_loss: -0.539527
# [250]	valid_set's soft_log_loss: -0.567268
# [300]	valid_set's soft_log_loss: -0.609536
# [350]	valid_set's soft_log_loss: -0.635983
# 	Note: model has different eval_metric than default.
# 	-0.4947	 = Validation score   (-soft_log_loss)
# 	1.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# [400]	valid_set's soft_log_loss: -0.64679
# 	Note: model has different eval_metric than default.
# 	-0.4623	 = Validation score   (-soft_log_loss)
# 	0.83s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0826493	test: -1.0767123	best: -1.0767123 (0)	total: 620ms	remaining: 1h 43m 15s
# 20:	learn: -0.8696693	test: -0.8183081	best: -0.8183081 (20)	total: 950ms	remaining: 7m 31s
# 40:	learn: -0.7635324	test: -0.7171676	best: -0.7171676 (40)	total: 1.28s	remaining: 5m 10s
# 60:	learn: -0.7022207	test: -0.6480325	best: -0.6480325 (60)	total: 1.62s	remaining: 4m 24s
# 80:	learn: -0.6663784	test: -0.6043571	best: -0.6043571 (80)	total: 1.99s	remaining: 4m 3s
# 100:	learn: -0.6327300	test: -0.5680121	best: -0.5680121 (100)	total: 2.3s	remaining: 3m 45s
# 120:	learn: -0.6080537	test: -0.5462255	best: -0.5462255 (120)	total: 2.63s	remaining: 3m 34s
# 140:	learn: -0.5880228	test: -0.5278558	best: -0.5278558 (140)	total: 2.95s	remaining: 3m 26s
# 160:	learn: -0.5703143	test: -0.5138201	best: -0.5138201 (160)	total: 3.28s	remaining: 3m 20s
# 180:	learn: -0.5544675	test: -0.4988419	best: -0.4988419 (180)	total: 3.67s	remaining: 3m 18s
# 200:	learn: -0.5407362	test: -0.4921836	best: -0.4914721 (193)	total: 3.97s	remaining: 3m 13s
# 220:	learn: -0.5302848	test: -0.4856414	best: -0.4856414 (220)	total: 4.29s	remaining: 3m 9s
# 240:	learn: -0.5219044	test: -0.4822818	best: -0.4822818 (240)	total: 4.61s	remaining: 3m 6s
# 260:	learn: -0.5149474	test: -0.4795778	best: -0.4794605 (256)	total: 4.97s	remaining: 3m 5s
# 280:	learn: -0.5081791	test: -0.4758710	best: -0.4758710 (280)	total: 5.3s	remaining: 3m 3s
# 300:	learn: -0.5021531	test: -0.4728346	best: -0.4728346 (300)	total: 5.63s	remaining: 3m 1s
# 320:	learn: -0.4954778	test: -0.4686793	best: -0.4685043 (319)	total: 6.03s	remaining: 3m 1s
# 340:	learn: -0.4905256	test: -0.4640439	best: -0.4639997 (337)	total: 6.38s	remaining: 3m
# 360:	learn: -0.4859338	test: -0.4603074	best: -0.4602982 (357)	total: 6.74s	remaining: 2m 59s
# 380:	learn: -0.4818573	test: -0.4583889	best: -0.4580925 (378)	total: 7.06s	remaining: 2m 58s
# 400:	learn: -0.4776184	test: -0.4588074	best: -0.4580925 (378)	total: 7.38s	remaining: 2m 56s
# 420:	learn: -0.4741926	test: -0.4568238	best: -0.4568238 (420)	total: 7.74s	remaining: 2m 56s
# 440:	learn: -0.4709175	test: -0.4571743	best: -0.4563086 (430)	total: 8.11s	remaining: 2m 55s
# 460:	learn: -0.4682381	test: -0.4566488	best: -0.4561300 (444)	total: 8.43s	remaining: 2m 54s
# 480:	learn: -0.4658096	test: -0.4568908	best: -0.4560546 (471)	total: 8.77s	remaining: 2m 53s
# 500:	learn: -0.4631106	test: -0.4557896	best: -0.4557896 (500)	total: 9.12s	remaining: 2m 52s
# 520:	learn: -0.4605567	test: -0.4553000	best: -0.4553000 (520)	total: 9.46s	remaining: 2m 52s
# 540:	learn: -0.4581417	test: -0.4542811	best: -0.4542811 (540)	total: 9.78s	remaining: 2m 51s
# 560:	learn: -0.4560523	test: -0.4526061	best: -0.4526061 (560)	total: 10.1s	remaining: 2m 50s
# 580:	learn: -0.4542105	test: -0.4512549	best: -0.4509296 (579)	total: 10.5s	remaining: 2m 49s
# 600:	learn: -0.4524555	test: -0.4516827	best: -0.4505148 (592)	total: 10.8s	remaining: 2m 48s
# 620:	learn: -0.4508140	test: -0.4510248	best: -0.4505148 (592)	total: 11.1s	remaining: 2m 47s
# 640:	learn: -0.4492438	test: -0.4498213	best: -0.4497998 (639)	total: 11.4s	remaining: 2m 46s
# 660:	learn: -0.4479817	test: -0.4500575	best: -0.4492695 (643)	total: 11.8s	remaining: 2m 46s
# 680:	learn: -0.4466558	test: -0.4499849	best: -0.4492695 (643)	total: 12.1s	remaining: 2m 45s
# 700:	learn: -0.4454815	test: -0.4507776	best: -0.4492695 (643)	total: 12.4s	remaining: 2m 44s
# 720:	learn: -0.4442162	test: -0.4510917	best: -0.4492695 (643)	total: 12.7s	remaining: 2m 43s
# 740:	learn: -0.4433460	test: -0.4509470	best: -0.4492695 (643)	total: 13s	remaining: 2m 43s
# 760:	learn: -0.4423705	test: -0.4513317	best: -0.4492695 (643)	total: 13.4s	remaining: 2m 42s
# 780:	learn: -0.4414611	test: -0.4525517	best: -0.4492695 (643)	total: 13.7s	remaining: 2m 41s
# 800:	learn: -0.4404476	test: -0.4535092	best: -0.4492695 (643)	total: 14s	remaining: 2m 40s
# 820:	learn: -0.4396657	test: -0.4559923	best: -0.4492695 (643)	total: 14.3s	remaining: 2m 40s
# 840:	learn: -0.4389486	test: -0.4559847	best: -0.4492695 (643)	total: 14.7s	remaining: 2m 39s
# 860:	learn: -0.4383588	test: -0.4573905	best: -0.4492695 (643)	total: 15s	remaining: 2m 39s
# 880:	learn: -0.4375885	test: -0.4571506	best: -0.4492695 (643)	total: 15.3s	remaining: 2m 38s
# 900:	learn: -0.4369555	test: -0.4582949	best: -0.4492695 (643)	total: 15.7s	remaining: 2m 38s
# 920:	learn: -0.4362684	test: -0.4600675	best: -0.4492695 (643)	total: 16s	remaining: 2m 37s
# 	Note: model has different eval_metric than default.
# 	-0.4493	 = Validation score   (-soft_log_loss)
# 	17.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# 940:	learn: -0.4356028	test: -0.4615468	best: -0.4492695 (643)	total: 16.3s	remaining: 2m 37s
#
# bestTest = -0.4492694527
# bestIteration = 643
#
# Shrink model to first 644 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.575	 = Validation score   (-soft_log_loss)
# 	2.53s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.571, 'RandomForestMSE_2_DSTL': 0.429}
# 	Note: model has different eval_metric than default.
# 	-0.4322	 = Validation score   (-soft_log_loss)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   0.822581  soft_log_loss       0.000000  17.378031                0.000000          17.378031            1       True         34
# 1             LightGBM_2_DSTL   0.822581  soft_log_loss       0.000280   1.179480                0.000280           1.179480            1       True         32
# 2  WeightedEnsemble_2_L2_DSTL   0.822581  soft_log_loss       0.048200  18.234642                0.000000           0.024817            2       True         36
# 3      RandomForestMSE_2_DSTL   0.822581  soft_log_loss       0.048200   0.831794                0.048200           0.831794            1       True         33
# 4       NeuralNetTorch_2_DSTL   0.790323  soft_log_loss       0.022101   2.532539                0.022101           2.532539            1       True         35
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                          model  score_test  score_val    eval_metric  \
# 1          WeightedEnsemble_L2    0.760870   0.915858       accuracy
# 0     WeightedEnsemble_L2_DSTL    0.760870   0.822581  soft_log_loss
# 2       NeuralNetFastAI_BAG_L1    0.739130   0.902913       accuracy
# 6        ExtraTreesGini_BAG_L1    0.717391   0.889968       accuracy
# 7      RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 3                CatBoost_DSTL    0.717391   0.838710  soft_log_loss
# 4                LightGBM_DSTL    0.717391   0.822581  soft_log_loss
# 5              LightGBM_2_DSTL    0.717391   0.822581  soft_log_loss
# 9       RandomForestMSE_2_DSTL    0.717391   0.822581  soft_log_loss
# 10  WeightedEnsemble_2_L2_DSTL    0.717391   0.822581  soft_log_loss
# 8         RandomForestMSE_DSTL    0.717391   0.806452  soft_log_loss
# 16           LightGBMXT_BAG_L2    0.695652   0.928803       accuracy
# 17      NeuralNetFastAI_BAG_L2    0.695652   0.925566       accuracy
# 13       ExtraTreesEntr_BAG_L1    0.695652   0.896440       accuracy
# 14             LightGBM_BAG_L1    0.695652   0.896440       accuracy
# 15     RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 11             CatBoost_2_DSTL    0.695652   0.822581  soft_log_loss
# 12       NeuralNetTorch_2_DSTL    0.695652   0.790323  soft_log_loss
# 22             CatBoost_BAG_L2    0.673913   0.925566       accuracy
# 26       ExtraTreesEntr_BAG_L2    0.673913   0.925566       accuracy
# 27       NeuralNetTorch_BAG_L2    0.673913   0.925566       accuracy
# 23       ExtraTreesGini_BAG_L2    0.673913   0.919094       accuracy
# 24     RandomForestEntr_BAG_L2    0.673913   0.912621       accuracy
# 25     RandomForestGini_BAG_L2    0.673913   0.912621       accuracy
# 20        LightGBMLarge_BAG_L1    0.673913   0.899676       accuracy
# 19           LightGBMXT_BAG_L1    0.673913   0.893204       accuracy
# 21       NeuralNetTorch_BAG_L1    0.673913   0.883495       accuracy
# 18             CatBoost_BAG_L1    0.673913   0.873786       accuracy
# 30         WeightedEnsemble_L3    0.652174   0.935275       accuracy
# 29             LightGBM_BAG_L2    0.652174   0.932039       accuracy
# 31        LightGBMLarge_BAG_L2    0.652174   0.928803       accuracy
# 32              XGBoost_BAG_L2    0.652174   0.928803       accuracy
# 28              XGBoost_BAG_L1    0.652174   0.883495       accuracy
# 33         NeuralNetTorch_DSTL    0.630435   0.790323  soft_log_loss
# 34       KNeighborsDist_BAG_L1    0.391304   0.799353       accuracy
# 35       KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#     pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 1         0.187918       0.219176   11.237940                 0.015638
# 0         0.098075       0.057889   17.838501                 0.000000
# 2         0.102689       0.120100   10.202697                 0.102689
# 6         0.069591       0.099077    0.858812                 0.069591
# 7         0.079076       0.086533    0.804581                 0.079076
# 3         0.000000       0.010095   16.905084                 0.000000
# 4         0.010111       0.000000    1.201399                 0.010111
# 5         0.014657       0.000280    1.179480                 0.014657
# 9         0.109189       0.048200    0.831794                 0.109189
# 10        0.114816       0.048200   18.234642                 0.000000
# 8         0.098075       0.047794    0.899911                 0.098075
# 16        1.082360       1.163170   74.368833                 0.040524
# 17        1.206748       1.255491   81.571959                 0.164912
# 13        0.063937       0.128262    0.892560                 0.063937
# 14        0.071059       0.017013    3.436378                 0.071059
# 15        0.071174       0.119646    0.742724                 0.071174
# 11        0.005627       0.000000   17.378031                 0.005627
# 12        0.035042       0.022101    2.532539                 0.035042
# 22        1.077638       1.163090  104.878240                 0.035802
# 26        1.150693       1.237215   72.399780                 0.108857
# 27        1.228641       1.445442   85.473687                 0.186805
# 23        1.117181       1.250327   72.496833                 0.075344
# 24        1.139463       1.258216   72.503094                 0.097626
# 25        1.144769       1.255462   72.608198                 0.102933
# 20        0.091023       0.031628    5.443710                 0.091023
# 19        0.085297       0.030024    3.070101                 0.085297
# 21        0.163130       0.223907   16.649767                 0.163130
# 18        0.056985       0.020774   25.745481                 0.056985
# 30        1.102773       1.177177   78.040189                 0.000000
# 29        1.062249       1.163808   74.987408                 0.020413
# 31        1.105599       1.173699   77.688952                 0.063763
# 32        1.198637       1.186385   75.282667                 0.156801
# 28        0.174931       0.032801    3.783630                 0.174931
# 33        0.025900       0.024172   17.947553                 0.025900
# 34        0.005286       0.006321    0.010081                 0.005286
# 35        0.007659       0.233714    0.011375                 0.007659
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                 0.000000           0.176431            2       True
# 0                 0.000000           0.033506            2       True
# 2                 0.120100          10.202697            1       True
# 6                 0.099077           0.858812            1       True
# 7                 0.086533           0.804581            1       True
# 3                 0.010095          16.905084            1       True
# 4                 0.000000           1.201399            1       True
# 5                 0.000280           1.179480            1       True
# 9                 0.048200           0.831794            1       True
# 10                0.000000           0.024817            2       True
# 8                 0.047794           0.899911            1       True
# 16                0.013369           2.716936            2       True
# 17                0.105690           9.920061            2       True
# 13                0.128262           0.892560            1       True
# 14                0.017013           3.436378            1       True
# 15                0.119646           0.742724            1       True
# 11                0.000000          17.378031            1       True
# 12                0.022101           2.532539            1       True
# 22                0.013289          33.226343            2       True
# 26                0.087414           0.747883            2       True
# 27                0.295641          13.821790            2       True
# 23                0.100526           0.844936            2       True
# 24                0.108415           0.851197            2       True
# 25                0.105661           0.956301            2       True
# 20                0.031628           5.443710            1       True
# 19                0.030024           3.070101            1       True
# 21                0.223907          16.649767            1       True
# 18                0.020774          25.745481            1       True
# 30                0.000000           0.335845            3       True
# 29                0.014007           3.335510            2       True
# 31                0.023898           6.037055            2       True
# 32                0.036584           3.630770            2       True
# 28                0.032801           3.783630            1       True
# 33                0.024172          17.947553            1       True
# 34                0.006321           0.010081            1       True
# 35                0.233714           0.011375            1       True
#
#     fit_order
# 1          14
# 0          31
# 2           3
# 6           9
# 7           6
# 3          29
# 4          27
# 5          32
# 9          33
# 10         36
# 8          28
# 16         16
# 17         15
# 13         10
# 14          5
# 15          7
# 11         34
# 12         35
# 22         20
# 26         22
# 27         24
# 23         21
# 24         19
# 25         18
# 20         13
# 19          4
# 21         12
# 18          8
# 30         26
# 29         17
# 31         25
# 32         23
# 28         11
# 33         30
# 34          2
# 35          1
# 测试集上的最佳蒸馏模型：
# WeightedEnsemble_L2_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_2_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7042735042735043,
#     "mcc": 0.5108759939945801
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6363636363636364,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5384615384615384,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8148148148148148,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8301886792452831,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.8,
#         "f1-score": 0.6153846153846154,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6503928170594837,
#         "recall": 0.7042735042735043,
#         "f1-score": 0.6613449443638123,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7224052115356463,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7117119959613807,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7042735042735043, 'mcc': 0.5108759939945801, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             3
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6363636363636364, 'recall': 0.4666666666666667, 'f1-score': 0.5384615384615384, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8148148148148148, 'recall': 0.8461538461538461, 'f1-score': 0.8301886792452831, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.8, 'f1-score': 0.6153846153846154, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6503928170594837, 'recall': 0.7042735042735043, 'f1-score': 0.6613449443638123, 'support': 46.0}, 'weighted avg': {'precision': 0.7224052115356463, 'recall': 0.717391304347826, 'f1-score': 0.7117119959613807, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'WeightedEnsemble_L3', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
