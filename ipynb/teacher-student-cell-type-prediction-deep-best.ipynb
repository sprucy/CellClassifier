# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Deep'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Deep
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (83, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 567754968 to 832627767
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      83 non-null     float64
#  1   sag                   83 non-null     float64
#  2   VmatSag               83 non-null     float64
#  3   vmbaseM               83 non-null     float64
#  4   tau                   83 non-null     float64
#  5   FAP_rheobase          83 non-null     float64
#  6   FAP_num_APs           83 non-null     float64
#  7   TS1_rheobase          83 non-null     float64
#  8   TS1_num_APs           83 non-null     float64
#  9   TS2_rheobase          83 non-null     float64
#  10  TS2_num_APs           83 non-null     float64
#  11  TS1_adp_index         59 non-null     float64
#  12  TS2_adp_index         67 non-null     float64
#  13  FAP_threshold         83 non-null     float64
#  14  FAP_peak              83 non-null     float64
#  15  FAP_maxupstroke       83 non-null     float64
#  16  FAP_maxdownstroke     83 non-null     float64
#  17  FAP_halfwidth         83 non-null     float64
#  18  FAP_avg_upstroke      83 non-null     float64
#  19  FAP_avg_downstroke    83 non-null     float64
#  20  FAP_up_down_ratio     83 non-null     float64
#  21  TS1_threshold         83 non-null     float64
#  22  TS1_maxupstroke       83 non-null     float64
#  23  TS1_maxdownstroke     83 non-null     float64
#  24  TS1_halfwidth         83 non-null     float64
#  25  TS1_avg_upstroke      83 non-null     float64
#  26  TS1_avg_downstroke    83 non-null     float64
#  27  TS1_up_down_ratio     83 non-null     float64
#  28  TS2_threshold         83 non-null     float64
#  29  TS2_peak              83 non-null     float64
#  30  TS2_maxupstroke       83 non-null     float64
#  31  TS2_maxdownstroke     83 non-null     float64
#  32  TS2_avg_upstroke      83 non-null     float64
#  33  TS2_avg_downstroke    83 non-null     float64
#  34  TS2_up_down_ratio     83 non-null     float64
#  35  L23_depth_normalized  73 non-null     float64
#  36  label                 83 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 26.7+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      83 non-null     float64
#  1   sag                   83 non-null     float64
#  2   VmatSag               83 non-null     float64
#  3   vmbaseM               83 non-null     float64
#  4   tau                   83 non-null     float64
#  5   FAP_rheobase          83 non-null     float64
#  6   FAP_num_APs           83 non-null     float64
#  7   TS1_rheobase          83 non-null     float64
#  8   TS1_num_APs           83 non-null     float64
#  9   TS2_rheobase          83 non-null     float64
#  10  TS2_num_APs           83 non-null     float64
#  11  TS1_adp_index         83 non-null     float64
#  12  TS2_adp_index         83 non-null     float64
#  13  FAP_threshold         83 non-null     float64
#  14  FAP_peak              83 non-null     float64
#  15  FAP_maxupstroke       83 non-null     float64
#  16  FAP_maxdownstroke     83 non-null     float64
#  17  FAP_halfwidth         83 non-null     float64
#  18  FAP_avg_upstroke      83 non-null     float64
#  19  FAP_avg_downstroke    83 non-null     float64
#  20  FAP_up_down_ratio     83 non-null     float64
#  21  TS1_threshold         83 non-null     float64
#  22  TS1_maxupstroke       83 non-null     float64
#  23  TS1_maxdownstroke     83 non-null     float64
#  24  TS1_halfwidth         83 non-null     float64
#  25  TS1_avg_upstroke      83 non-null     float64
#  26  TS1_avg_downstroke    83 non-null     float64
#  27  TS1_up_down_ratio     83 non-null     float64
#  28  TS2_threshold         83 non-null     float64
#  29  TS2_peak              83 non-null     float64
#  30  TS2_maxupstroke       83 non-null     float64
#  31  TS2_maxdownstroke     83 non-null     float64
#  32  TS2_avg_upstroke      83 non-null     float64
#  33  TS2_avg_downstroke    83 non-null     float64
#  34  TS2_up_down_ratio     83 non-null     float64
#  35  L23_depth_normalized  83 non-null     float64
#  36  label                 83 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 24.1+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 83
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      17 non-null     float64
#  1   sag                   17 non-null     float64
#  2   VmatSag               17 non-null     float64
#  3   vmbaseM               17 non-null     float64
#  4   tau                   17 non-null     float64
#  5   FAP_rheobase          17 non-null     float64
#  6   FAP_num_APs           17 non-null     float64
#  7   TS1_rheobase          17 non-null     float64
#  8   TS1_num_APs           17 non-null     float64
#  9   TS2_rheobase          17 non-null     float64
#  10  TS2_num_APs           17 non-null     float64
#  11  TS1_adp_index         17 non-null     float64
#  12  TS2_adp_index         17 non-null     float64
#  13  FAP_threshold         17 non-null     float64
#  14  FAP_peak              17 non-null     float64
#  15  FAP_maxupstroke       17 non-null     float64
#  16  FAP_maxdownstroke     17 non-null     float64
#  17  FAP_halfwidth         17 non-null     float64
#  18  FAP_avg_upstroke      17 non-null     float64
#  19  FAP_avg_downstroke    17 non-null     float64
#  20  FAP_up_down_ratio     17 non-null     float64
#  21  TS1_threshold         17 non-null     float64
#  22  TS1_maxupstroke       17 non-null     float64
#  23  TS1_maxdownstroke     17 non-null     float64
#  24  TS1_halfwidth         17 non-null     float64
#  25  TS1_avg_upstroke      17 non-null     float64
#  26  TS1_avg_downstroke    17 non-null     float64
#  27  TS1_up_down_ratio     17 non-null     float64
#  28  TS2_threshold         17 non-null     float64
#  29  TS2_peak              17 non-null     float64
#  30  TS2_maxupstroke       17 non-null     float64
#  31  TS2_maxdownstroke     17 non-null     float64
#  32  TS2_avg_upstroke      17 non-null     float64
#  33  TS2_avg_downstroke    17 non-null     float64
#  34  TS2_up_down_ratio     17 non-null     float64
#  35  L23_depth_normalized  17 non-null     float64
#  36  label                 17 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 5.0+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='best_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       9.00 GB / 15.92 GB (56.5%)
# Disk Space Avail:   310.79 GB / 931.51 GB (33.4%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 14:55:13,139	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "models\Teacher\best_quality-20241101-145506\ds_sub_fit\sub_fit_ho"
# (_dystack pid=48672) Running DyStack sub-fit ...
# (_dystack pid=48672) Beginning AutoGluon training ... Time limit = 890s
# (_dystack pid=48672) AutoGluon will save models to "models\Teacher\best_quality-20241101-145506\ds_sub_fit\sub_fit_ho"
# (_dystack pid=48672) Train Data Rows:    77
# (_dystack pid=48672) Train Data Columns: 36
# (_dystack pid=48672) Label Column:       label
# (_dystack pid=48672) Problem Type:       multiclass
# (_dystack pid=48672) Preprocessing data ...
# (_dystack pid=48672) Train Data Class Count: 3
# (_dystack pid=48672) Using Feature Generators to preprocess the data ...
# (_dystack pid=48672) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=48672) 	Available Memory:                    8585.20 MB
# (_dystack pid=48672) 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=48672) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=48672) 	Stage 1 Generators:
# (_dystack pid=48672) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=48672) 	Stage 2 Generators:
# (_dystack pid=48672) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=48672) 	Stage 3 Generators:
# (_dystack pid=48672) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=48672) 	Stage 4 Generators:
# (_dystack pid=48672) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=48672) 	Stage 5 Generators:
# (_dystack pid=48672) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=48672) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=48672) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=48672) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=48672) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=48672) 	0.1s = Fit runtime
# (_dystack pid=48672) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=48672) 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# (_dystack pid=48672) Data preprocessing and feature engineering runtime = 0.07s ...
# (_dystack pid=48672) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=48672) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=48672) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=48672) User-specified model hyperparameters to be fit:
# (_dystack pid=48672) {
# (_dystack pid=48672) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=48672) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=48672) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=48672) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=48672) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=48672) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=48672) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=48672) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=48672) }
# (_dystack pid=48672) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=48672) Fitting 110 L1 models ...
# (_dystack pid=48672) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 593.14s of the 889.9s of remaining time.
# (_dystack pid=48672) 	0.6883	 = Validation score   (accuracy)
# (_dystack pid=48672) 	0.0s	 = Training   runtime
# (_dystack pid=48672) 	0.18s	 = Validation runtime
# (_dystack pid=48672) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 590.67s of the 887.44s of remaining time.
# (_dystack pid=48672) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=48672) 	0.01s	 = Training   runtime
# (_dystack pid=48672) 	0.0s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 590.64s of the 887.41s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=48672) 	0.9351	 = Validation score   (accuracy)
# (_dystack pid=48672) 	8.87s	 = Training   runtime
# (_dystack pid=48672) 	0.1s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 577.33s of the 874.1s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_dystack pid=48672) 	0.8831	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.75s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBM_BAG_L1 ... Training model for up to 569.53s of the 866.3s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_dystack pid=48672) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.53s	 = Training   runtime
# (_dystack pid=48672) 	0.0s	 = Validation runtime
# (_dystack pid=48672) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 562.02s of the 858.79s of remaining time.
# (_dystack pid=48672) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=48672) 	1.0s	 = Training   runtime
# (_dystack pid=48672) 	0.09s	 = Validation runtime
# (_dystack pid=48672) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 560.9s of the 857.67s of remaining time.
# (_dystack pid=48672) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=48672) 	0.84s	 = Training   runtime
# (_dystack pid=48672) 	0.08s	 = Validation runtime
# (_dystack pid=48672) Fitting model: CatBoost_BAG_L1 ... Training model for up to 559.95s of the 856.72s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=48672) 	0.8961	 = Validation score   (accuracy)
# (_dystack pid=48672) 	7.23s	 = Training   runtime
# (_dystack pid=48672) 	0.01s	 = Validation runtime
# (_dystack pid=48672) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 548.11s of the 844.88s of remaining time.
# (_dystack pid=48672) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=48672) 	0.79s	 = Training   runtime
# (_dystack pid=48672) 	0.09s	 = Validation runtime
# (_dystack pid=48672) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 547.22s of the 843.98s of remaining time.
# (_dystack pid=48672) 	0.8312	 = Validation score   (accuracy)
# (_dystack pid=48672) 	0.79s	 = Training   runtime
# (_dystack pid=48672) 	0.09s	 = Validation runtime
# (_dystack pid=48672) Fitting model: XGBoost_BAG_L1 ... Training model for up to 546.3s of the 843.07s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=48672) 	0.8312	 = Validation score   (accuracy)
# (_dystack pid=48672) 	3.39s	 = Training   runtime
# (_dystack pid=48672) 	0.03s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 538.32s of the 835.09s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=65588) Stack (most recent call first):
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=65588)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=65588)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=48672) 	0.8831	 = Validation score   (accuracy)
# (_dystack pid=48672) 	30.97s	 = Training   runtime
# (_dystack pid=48672) 	0.11s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 502.61s of the 799.38s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=52216) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=52216)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=52216)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=48672) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.84s	 = Training   runtime
# (_dystack pid=48672) 	0.0s	 = Validation runtime
# (_dystack pid=48672) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 494.61s of the 791.38s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=48672) 	0.8961	 = Validation score   (accuracy)
# (_dystack pid=48672) 	7.12s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 482.16s of the 778.93s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=63524) Stack (most recent call first):
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=63524)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=63524)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=48672) 	0.9221	 = Validation score   (accuracy)
# (_dystack pid=48672) 	19.39s	 = Training   runtime
# (_dystack pid=48672) 	0.13s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 457.54s of the 754.31s of remaining time.
# (_ray_fit pid=55772) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=55772)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=55772)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=48672) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.61s	 = Training   runtime
# (_dystack pid=48672) 	0.01s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 449.65s of the 746.42s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=48672) 	0.9481	 = Validation score   (accuracy)
# (_dystack pid=48672) 	10.23s	 = Training   runtime
# (_dystack pid=48672) 	0.13s	 = Validation runtime
# (_dystack pid=48672) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 434.23s of the 731.0s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.80%)
# (_dystack pid=48672) 	0.8701	 = Validation score   (accuracy)
# (_dystack pid=48672) 	14.92s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 414.0s of the 710.77s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=48672) 	0.3117	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.46s	 = Training   runtime
# (_dystack pid=48672) 	0.01s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 406.87s of the 703.64s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_ray_fit pid=66060) Stack (most recent call first):
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=66060)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=66060)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=48672) 	0.9221	 = Validation score   (accuracy)
# (_dystack pid=48672) 	17.94s	 = Training   runtime
# (_dystack pid=48672) 	0.11s	 = Validation runtime
# (_dystack pid=48672) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 384.18s of the 680.94s of remaining time.
# (_ray_fit pid=65996) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=65996)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=65996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.33%)
# (_dystack pid=48672) 	0.8571	 = Validation score   (accuracy)
# (_dystack pid=48672) 	3.14s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 376.17s of the 672.94s of remaining time.
# (_dystack pid=48672) 	0.8312	 = Validation score   (accuracy)
# (_dystack pid=48672) 	1.0s	 = Training   runtime
# (_dystack pid=48672) 	0.1s	 = Validation runtime
# (_dystack pid=48672) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 375.04s of the 671.81s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.04%)
# (_dystack pid=48672) 	0.8831	 = Validation score   (accuracy)
# (_dystack pid=48672) 	4.53s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 365.76s of the 662.53s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.00%)
# (_dystack pid=48672) 	0.9481	 = Validation score   (accuracy)
# (_dystack pid=48672) 	8.96s	 = Training   runtime
# (_dystack pid=48672) 	0.08s	 = Validation runtime
# (_dystack pid=48672) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 352.02s of the 648.79s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.79%)
# (_dystack pid=48672) 	0.8961	 = Validation score   (accuracy)
# (_dystack pid=48672) 	17.5s	 = Training   runtime
# (_dystack pid=48672) 	0.02s	 = Validation runtime
# (_dystack pid=48672) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 329.07s of the 625.84s of remaining time.
# (_dystack pid=48672) 	0.8442	 = Validation score   (accuracy)
# (_dystack pid=48672) 	1.31s	 = Training   runtime
# (_dystack pid=48672) 	0.09s	 = Validation runtime
# (_dystack pid=48672) Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 327.62s of the 624.39s of remaining time.
# (_dystack pid=48672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# (_dystack pid=48672) 	0.8961	 = Validation score   (accuracy)
# (_dystack pid=48672) 	2.75s	 = Training   runtime
# (_dystack pid=48672) 	0.01s	 = Validation runtime
# ...
# 	10.34s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1277.69s of the 1277.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.95%)
# 	0.9425	 = Validation score   (accuracy)
# 	2.87s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1269.14s of the 1268.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	0.931	 = Validation score   (accuracy)
# 	3.3s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1260.49s of the 1259.85s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	0.85s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 1259.41s of the 1258.78s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	0.88s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1258.26s of the 1257.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.63%)
# 	0.954	 = Validation score   (accuracy)
# 	73.41s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 1179.88s of the 1179.26s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	1.02s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 1178.6s of the 1177.98s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1177.57s of the 1176.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	0.9195	 = Validation score   (accuracy)
# 	3.87s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1168.98s of the 1168.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.931	 = Validation score   (accuracy)
# 	17.63s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1146.05s of the 1145.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.46%)
# 	0.9655	 = Validation score   (accuracy)
# 	6.57s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 1134.36s of the 1133.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.68%)
# 	0.954	 = Validation score   (accuracy)
# 	66.31s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 1063.04s of the 1062.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.954	 = Validation score   (accuracy)
# 	17.52s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 1040.69s of the 1040.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	0.954	 = Validation score   (accuracy)
# 	3.56s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 1031.56s of the 1030.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9655	 = Validation score   (accuracy)
# 	11.05s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 1015.09s of the 1014.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=8.44%)
# 	0.9425	 = Validation score   (accuracy)
# 	136.36s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 873.1s of the 872.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.2759	 = Validation score   (accuracy)
# 	2.99s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 865.32s of the 864.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.931	 = Validation score   (accuracy)
# 	20.19s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 839.81s of the 839.2s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.71% memory usage per fold, 54.83%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=13.71%)
# 	0.9195	 = Validation score   (accuracy)
# 	11.27s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 824.11s of the 823.49s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	0.83s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 823.06s of the 822.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.954	 = Validation score   (accuracy)
# 	28.24s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 789.75s of the 789.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.954	 = Validation score   (accuracy)
# 	9.75s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 775.13s of the 774.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=8.00%)
# 	0.931	 = Validation score   (accuracy)
# 	186.95s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 582.57s of the 581.95s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	1.2s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 581.12s of the 580.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.22%)
# 	0.9425	 = Validation score   (accuracy)
# 	3.56s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 572.4s of the 571.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.954	 = Validation score   (accuracy)
# 	10.06s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 557.29s of the 556.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.05%)
# 	0.9195	 = Validation score   (accuracy)
# 	3.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 547.9s of the 547.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9425	 = Validation score   (accuracy)
# 	19.47s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 523.1s of the 522.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.41%)
# 	0.2759	 = Validation score   (accuracy)
# 	2.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 514.94s of the 514.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9425	 = Validation score   (accuracy)
# 	17.86s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 491.82s of the 491.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.954	 = Validation score   (accuracy)
# 	26.95s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 459.18s of the 458.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.954	 = Validation score   (accuracy)
# 	11.3s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L2 ... Training model for up to 442.5s of the 441.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.91%)
# 	0.9195	 = Validation score   (accuracy)
# 	4.94s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L2 ... Training model for up to 431.91s of the 431.28s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L2 ... Training model for up to 430.66s of the 430.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	0.954	 = Validation score   (accuracy)
# 	35.36s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 390.09s of the 389.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.954	 = Validation score   (accuracy)
# 	10.83s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 374.0s of the 373.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9425	 = Validation score   (accuracy)
# 	19.23s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L2 ... Training model for up to 349.27s of the 348.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=6.97%)
# 	0.954	 = Validation score   (accuracy)
# 	3.89s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L2 ... Training model for up to 340.33s of the 339.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9425	 = Validation score   (accuracy)
# 	9.84s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L2 ... Training model for up to 325.12s of the 324.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.10%)
# 	0.954	 = Validation score   (accuracy)
# 	67.8s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L2 ... Training model for up to 251.47s of the 250.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9425	 = Validation score   (accuracy)
# 	10.0s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L2 ... Training model for up to 236.31s of the 235.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.04%)
# 	0.9425	 = Validation score   (accuracy)
# 	3.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L2 ... Training model for up to 227.2s of the 226.59s of remaining time.
# 	0.9425	 = Validation score   (accuracy)
# 	1.23s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L2 ... Training model for up to 225.73s of the 225.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.25%)
# 	0.9655	 = Validation score   (accuracy)
# 	144.68s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L2 ... Training model for up to 75.95s of the 75.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.9425	 = Validation score   (accuracy)
# 	9.64s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L2 ... Training model for up to 61.29s of the 60.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.954	 = Validation score   (accuracy)
# 	18.53s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L2 ... Training model for up to 36.97s of the 36.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=7.99%)
# 	0.931	 = Validation score   (accuracy)
# 	7.35s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L2 ... Training model for up to 24.17s of the 23.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.954	 = Validation score   (accuracy)
# 	5.07s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L2 ... Training model for up to 13.73s of the 13.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	Time limit exceeded... Skipping NeuralNetTorch_r158_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -22.76s of remaining time.
# 	Ensemble Weights: {'CatBoost_r167_BAG_L2': 1.0}
# 	0.9655	 = Validation score   (accuracy)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2707.61s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 105.9 rows/s (11 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\best_quality-20241101-145506")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L2
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      NeuralNetTorch_r86_BAG_L1   0.965517    accuracy       0.103736    27.697286                0.103736          27.697286            1       True         32
# 1            WeightedEnsemble_L2   0.965517    accuracy       0.104735    27.962879                0.000999           0.265593            2       True        111
# 2      NeuralNetTorch_r41_BAG_L1   0.965517    accuracy       0.117216    16.496765                0.117216          16.496765            1       True         48
# 3           LightGBMLarge_BAG_L2   0.965517    accuracy       7.593093   930.770206                0.035126           6.567408            2       True        122
# 4           CatBoost_r167_BAG_L2   0.965517    accuracy       7.639868  1068.881655                0.081901         144.678856            2       True        155
# 5            WeightedEnsemble_L3   0.965517    accuracy       7.640871  1069.152618                0.001003           0.270963            3       True        160
# 6    NeuralNetFastAI_r191_BAG_L2   0.965517    accuracy       7.707662   935.255164                0.149694          11.052365            2       True        126
# 7     NeuralNetFastAI_r88_BAG_L1   0.954023    accuracy       0.072147     9.703797                0.072147           9.703797            1       True         68
# 8    NeuralNetFastAI_r156_BAG_L1   0.954023    accuracy       0.074910     9.490406                0.074910           9.490406            1       True         43
# 9         NeuralNetFastAI_BAG_L1   0.954023    accuracy       0.082581     9.689507                0.082581           9.689507            1       True          3
# 10     NeuralNetFastAI_r4_BAG_L1   0.954023    accuracy       0.082998     9.786351                0.082998           9.786351            1       True         98
# 11    NeuralNetFastAI_r37_BAG_L1   0.954023    accuracy       0.087507     9.872644                0.087507           9.872644            1       True         53
# 12   NeuralNetFastAI_r138_BAG_L1   0.954023    accuracy       0.090039    10.293633                0.090039          10.293633            1       True         86
# 13      NeuralNetTorch_r1_BAG_L1   0.954023    accuracy       0.100590    30.155870                0.100590          30.155870            1       True        109
# 14     NeuralNetTorch_r30_BAG_L1   0.954023    accuracy       0.105265    17.724272                0.105265          17.724272            1       True         30
# 15     NeuralNetTorch_r89_BAG_L1   0.954023    accuracy       0.108089    20.484988                0.108089          20.484988            1       True        110
# 16    NeuralNetTorch_r135_BAG_L1   0.954023    accuracy       0.109789    18.736941                0.109789          18.736941            1       True         97
# 17   NeuralNetFastAI_r134_BAG_L1   0.954023    accuracy       0.111870     9.650221                0.111870           9.650221            1       True         59
# 18     NeuralNetTorch_r79_BAG_L1   0.954023    accuracy       0.117283    16.499540                0.117283          16.499540            1       True         15
# 19   NeuralNetFastAI_r191_BAG_L1   0.954023    accuracy       0.122960    11.211611                0.122960          11.211611            1       True         17
# 20           LightGBM_r15_BAG_L2   0.954023    accuracy       7.587838   929.274437                0.029871           5.071638            2       True        159
# 21          LightGBM_r161_BAG_L2   0.954023    accuracy       7.588308   928.093422                0.030341           3.890623            2       True        149
# 22          LightGBM_r131_BAG_L2   0.954023    accuracy       7.589700   927.759474                0.031733           3.556675            2       True        125
# 23           CatBoost_r70_BAG_L2   0.954023    accuracy       7.634410   991.999663                0.076443          67.796865            2       True        151
# 24          CatBoost_r177_BAG_L2   0.954023    accuracy       7.638200   990.512502                0.080233          66.309704            2       True        123
# 25           CatBoost_r69_BAG_L2   0.954023    accuracy       7.641579   959.563691                0.083611          35.360892            2       True        146
# 26           CatBoost_r50_BAG_L2   0.954023    accuracy       7.645043   951.149973                0.087076          26.947174            2       True        142
# 27               CatBoost_BAG_L2   0.954023    accuracy       7.648233   997.613371                0.090266          73.410572            2       True        117
# 28          CatBoost_r137_BAG_L2   0.954023    accuracy       7.648997   952.443703                0.091030          28.240904            2       True        132
# 29        NeuralNetFastAI_BAG_L2   0.954023    accuracy       7.651122   934.545635                0.093155          10.342836            2       True        112
# 30   NeuralNetFastAI_r102_BAG_L2   0.954023    accuracy       7.659314   933.949119                0.101347           9.746320            2       True        133
# 31   NeuralNetFastAI_r145_BAG_L2   0.954023    accuracy       7.665240   934.260679                0.107273          10.057880            2       True        137
# 32   NeuralNetFastAI_r103_BAG_L2   0.954023    accuracy       7.717641   935.036027                0.159673          10.833228            2       True        147
# 33    NeuralNetFastAI_r11_BAG_L2   0.954023    accuracy       7.735907   935.499963                0.177939          11.297164            2       True        143
# 34     NeuralNetTorch_r79_BAG_L2   0.954023    accuracy       8.241332   941.726559                0.683365          17.523760            2       True        124
# 35     NeuralNetTorch_r41_BAG_L2   0.954023    accuracy       8.285368   942.732152                0.727401          18.529354            2       True        157
# 36   NeuralNetFastAI_r187_BAG_L1   0.942529    accuracy       0.083935     9.407429                0.083935           9.407429            1       True        104
# 37   NeuralNetFastAI_r127_BAG_L1   0.942529    accuracy       0.086875     9.494927                0.086875           9.494927            1       True         93
# 38   NeuralNetFastAI_r102_BAG_L1   0.942529    accuracy       0.086926     8.865211                0.086926           8.865211            1       True         24
# 39   NeuralNetFastAI_r111_BAG_L1   0.942529    accuracy       0.090184     9.076520                0.090184           9.076520            1       True         64
# 40    NeuralNetFastAI_r11_BAG_L1   0.942529    accuracy       0.090236    10.132104                0.090236          10.132104            1       True         34
# 41   NeuralNetFastAI_r145_BAG_L1   0.942529    accuracy       0.098488     9.614904                0.098488           9.614904            1       True         28
# 42    NeuralNetFastAI_r95_BAG_L1   0.942529    accuracy       0.101385     9.467503                0.101385           9.467503            1       True         47
# 43   NeuralNetFastAI_r172_BAG_L1   0.942529    accuracy       0.101875     9.657977                0.101875           9.657977            1       True         88
# 44    NeuralNetFastAI_r69_BAG_L1   0.942529    accuracy       0.102713     9.327862                0.102713           9.327862            1       True         84
# 45     NeuralNetTorch_r19_BAG_L1   0.942529    accuracy       0.106238    15.516469                0.106238          15.516469            1       True        105
# 46   NeuralNetFastAI_r100_BAG_L1   0.942529    accuracy       0.107601    10.607859                0.107601          10.607859            1       True        101
# 47     NeuralNetTorch_r87_BAG_L1   0.942529    accuracy       0.115982    28.255358                0.115982          28.255358            1       True         72
# 48   NeuralNetFastAI_r194_BAG_L1   0.942529    accuracy       0.118672     9.071962                0.118672           9.071962            1       True         95
# 49     NeuralNetTorch_r76_BAG_L1   0.942529    accuracy       0.119555    16.026224                0.119555          16.026224            1       True         90
# 50    NeuralNetTorch_r185_BAG_L1   0.942529    accuracy       0.125419    16.851429                0.125419          16.851429            1       True         78
# 51     NeuralNetTorch_r36_BAG_L1   0.942529    accuracy       0.129144    20.378737                0.129144          20.378737            1       True        100
# 52    NeuralNetTorch_r121_BAG_L1   0.942529    accuracy       0.131994    33.199236                0.131994          33.199236            1       True         92
# 53     NeuralNetTorch_r31_BAG_L1   0.942529    accuracy       0.138127    16.986570                0.138127          16.986570            1       True         65
# 54    NeuralNetTorch_r143_BAG_L1   0.942529    accuracy       0.146039    17.477765                0.146039          17.477765            1       True         62
# 55          LightGBM_r188_BAG_L2   0.942529    accuracy       7.584079   927.765207                0.026112           3.562408            2       True        136
# 56          LightGBM_r196_BAG_L2   0.942529    accuracy       7.585206   928.085221                0.027239           3.882422            2       True        153
# 57             LightGBMXT_BAG_L2   0.942529    accuracy       7.586862   927.072151                0.028894           2.869352            2       True        113
# 58            CatBoost_r9_BAG_L2   0.942529    accuracy       7.640166  1060.565038                0.082199         136.362239            2       True        127
# 59         ExtraTreesGini_BAG_L2   0.942529    accuracy       7.644815   925.217952                0.086848           1.015153            2       True        118
# 60       RandomForestGini_BAG_L2   0.942529    accuracy       7.646844   925.048312                0.088877           0.845514            2       True        115
# 61         ExtraTrees_r42_BAG_L2   0.942529    accuracy       7.647093   925.028321                0.089126           0.825522            2       True        131
# 62      RandomForest_r195_BAG_L2   0.942529    accuracy       7.649974   925.398043                0.092007           1.195244            2       True        135
# 63         ExtraTreesEntr_BAG_L2   0.942529    accuracy       7.650236   925.012177                0.092269           0.809379            2       True        119
# 64       RandomForest_r39_BAG_L2   0.942529    accuracy       7.660684   925.434092                0.102717           1.231293            2       True        154
# 65   NeuralNetFastAI_r156_BAG_L2   0.942529    accuracy       7.664049   934.201641                0.106081           9.998842            2       True        152
# 66       RandomForestEntr_BAG_L2   0.942529    accuracy       7.668092   925.080193                0.110125           0.877394            2       True        116
# 67   NeuralNetFastAI_r143_BAG_L2   0.942529    accuracy       7.676880   934.041165                0.118913           9.838367            2       True        150
# 68    NeuralNetFastAI_r95_BAG_L2   0.942529    accuracy       7.683163   933.846936                0.125196           9.644137            2       True        156
# 69        ExtraTrees_r172_BAG_L2   0.942529    accuracy       7.695559   925.146554                0.137592           0.943755            2       True        145
# 70     NeuralNetTorch_r14_BAG_L2   0.942529    accuracy       8.202371   943.427854                0.644404          19.225055            2       True        148
# 71     NeuralNetTorch_r86_BAG_L2   0.942529    accuracy       8.224964   942.065445                0.666997          17.862646            2       True        141
# 72     NeuralNetTorch_r30_BAG_L2   0.942529    accuracy       8.277993   943.667823                0.720026          19.465024            2       True        139
# 73            CatBoost_r9_BAG_L1   0.931034    accuracy       0.025455    15.205216                0.025455          15.205216            1       True         18
# 74   NeuralNetFastAI_r103_BAG_L1   0.931034    accuracy       0.077826     9.766586                0.077826           9.766586            1       True         38
# 75     NeuralNetTorch_r14_BAG_L1   0.931034    accuracy       0.098483    19.007817                0.098483          19.007817            1       True         39
# 76   NeuralNetFastAI_r160_BAG_L1   0.931034    accuracy       0.102852     9.675376                0.102852           9.675376            1       True         79
# 77     NeuralNetTorch_r22_BAG_L1   0.931034    accuracy       0.117704    16.841386                0.117704          16.841386            1       True         20
# 78         NeuralNetTorch_BAG_L1   0.931034    accuracy       0.124958    17.297689                0.124958          17.297689            1       True         12
# 79     NeuralNetTorch_r71_BAG_L1   0.931034    accuracy       0.130220    14.883496                0.130220          14.883496            1       True         73
# 80               LightGBM_BAG_L2   0.931034    accuracy       7.584629   927.507313                0.026661           3.304515            2       True        114
# 81           CatBoost_r13_BAG_L2   0.931034    accuracy       7.633142  1111.153066                0.075174         186.950267            2       True        134
# 82            XGBoost_r98_BAG_L2   0.931034    accuracy       8.079817   931.557148                0.521850           7.354349            2       True        158
# 83     NeuralNetTorch_r22_BAG_L2   0.931034    accuracy       8.312250   944.394009                0.754283          20.191210            2       True        129
# 84         NeuralNetTorch_BAG_L2   0.931034    accuracy       8.336029   941.830246                0.778062          17.627447            2       True        121
# 85           CatBoost_r70_BAG_L1   0.919540    accuracy       0.006809     8.275281                0.006809           8.275281            1       True         42
# 86          LightGBM_r188_BAG_L1   0.919540    accuracy       0.010288     2.529449                0.010288           2.529449            1       True         27
# 87          CatBoost_r128_BAG_L1   0.919540    accuracy       0.011578    15.607149                0.011578          15.607149            1       True         63
# 88            XGBoost_r98_BAG_L1   0.919540    accuracy       0.071681     3.517468                0.071681           3.517468            1       True         49
# 89   NeuralNetFastAI_r143_BAG_L1   0.919540    accuracy       0.109841     9.702709                0.109841           9.702709            1       True         41
# 90    NeuralNetTorch_r197_BAG_L1   0.919540    accuracy       0.111228    15.649009                0.111228          15.649009            1       True         54
# 91    NeuralNetTorch_r158_BAG_L1   0.919540    accuracy       0.119384    17.722170                0.119384          17.722170            1       True         51
# 92                XGBoost_BAG_L2   0.919540    accuracy       7.585433   928.076047                0.027466           3.873249            2       True        120
# 93            XGBoost_r89_BAG_L2   0.919540    accuracy       7.588326   928.084840                0.030359           3.882041            2       True        138
# 94            XGBoost_r33_BAG_L2   0.919540    accuracy       7.610194   935.472851                0.052227          11.270052            2       True        130
# 95           XGBoost_r194_BAG_L2   0.919540    accuracy       8.064231   929.143196                0.506263           4.940398            2       True        144
# 96            CatBoost_r5_BAG_L1   0.908046    accuracy       0.001696     4.376611                0.001696           4.376611            1       True         71
# 97          LightGBM_r143_BAG_L1   0.908046    accuracy       0.010106     2.666860                0.010106           2.666860            1       True         57
# 98           LightGBM_r42_BAG_L1   0.908046    accuracy       0.011096     3.135934                0.011096           3.135934            1       True        108
# 99          CatBoost_r143_BAG_L1   0.908046    accuracy       0.012000    12.288756                0.012000          12.288756            1       True         74
# 100         CatBoost_r180_BAG_L1   0.908046    accuracy       0.014594    12.842113                0.014594          12.842113            1       True         89
# 101           XGBoost_r49_BAG_L1   0.908046    accuracy       0.015306     3.358400                0.015306           3.358400            1       True         70
# 102         CatBoost_r137_BAG_L1   0.908046    accuracy       0.015378     4.374563                0.015378           4.374563            1       True         23
# 103          CatBoost_r69_BAG_L1   0.908046    accuracy       0.016407     5.598168                0.016407           5.598168            1       True         37
# 104          CatBoost_r49_BAG_L1   0.908046    accuracy       0.017005     4.622526                0.017005           4.622526            1       True         55
# 105         CatBoost_r163_BAG_L1   0.908046    accuracy       0.019617     5.719927                0.019617           5.719927            1       True        102
# 106          CatBoost_r12_BAG_L1   0.908046    accuracy       0.020007    11.863769                0.020007          11.863769            1       True         96
# 107          CatBoost_r60_BAG_L1   0.908046    accuracy       0.020329     5.769377                0.020329           5.769377            1       True         80
# 108           XGBoost_r89_BAG_L1   0.908046    accuracy       0.026380     3.012790                0.026380           3.012790            1       True         29
# 109           XGBoost_r33_BAG_L1   0.908046    accuracy       0.026740     3.477171                0.026740           3.477171            1       True         21
# 110           XGBoost_r34_BAG_L1   0.908046    accuracy       0.033111     2.914037                0.033111           2.914037            1       True        107
# 111         CatBoost_r167_BAG_L1   0.896552    accuracy       0.000858    10.881328                0.000858          10.881328            1       True         46
# 112        KNeighborsDist_BAG_L1   0.896552    accuracy       0.003002     0.006997                0.003002           0.006997            1       True          2
# 113          LightGBM_r30_BAG_L1   0.896552    accuracy       0.007315     3.422204                0.007315           3.422204            1       True         69
# 114            LightGBMXT_BAG_L1   0.896552    accuracy       0.008998     2.705620                0.008998           2.705620            1       True          4
# 115              LightGBM_BAG_L1   0.896552    accuracy       0.009005     2.695637                0.009005           2.695637            1       True          5
# 116         LightGBM_r196_BAG_L1   0.896552    accuracy       0.010073     2.670430                0.010073           2.670430            1       True         44
# 117          CatBoost_r86_BAG_L1   0.896552    accuracy       0.012368    17.976503                0.012368          17.976503            1       True         52
# 118         CatBoost_r177_BAG_L1   0.896552    accuracy       0.015955    10.566167                0.015955          10.566167            1       True         14
# 119          CatBoost_r50_BAG_L1   0.896552    accuracy       0.016088     5.919930                0.016088           5.919930            1       True         33
# 120         LightGBM_r161_BAG_L1   0.896552    accuracy       0.016752     2.600372                0.016752           2.600372            1       True         40
# 121           CatBoost_r6_BAG_L1   0.896552    accuracy       0.022996     5.295414                0.022996           5.295414            1       True         85
# 122               XGBoost_BAG_L1   0.896552    accuracy       0.024004     3.039401                0.024004           3.039401            1       True         11
# 123           XGBoost_r31_BAG_L1   0.896552    accuracy       0.027006     3.805883                0.027006           3.805883            1       True         77
# 124          XGBoost_r194_BAG_L1   0.896552    accuracy       0.061716     2.954905                0.061716           2.954905            1       True         35
# 125         LightGBM_r121_BAG_L1   0.885057    accuracy       0.009832     2.922542                0.009832           2.922542            1       True         87
# 126         LightGBMLarge_BAG_L1   0.885057    accuracy       0.010545     3.073891                0.010545           3.073891            1       True         13
# 127              CatBoost_BAG_L1   0.885057    accuracy       0.014823     7.304457                0.014823           7.304457            1       True          8
# 128          CatBoost_r13_BAG_L1   0.885057    accuracy       0.015259    17.044015                0.015259          17.044015            1       True         25
# 129         CatBoost_r198_BAG_L1   0.885057    accuracy       0.015373     7.619859                0.015373           7.619859            1       True        103
# 130           XGBoost_r22_BAG_L1   0.885057    accuracy       0.023001     3.084143                0.023001           3.084143            1       True         83
# 131           XGBoost_r95_BAG_L1   0.885057    accuracy       0.028959     3.465314                0.028959           3.465314            1       True        106
# 132   NeuralNetFastAI_r65_BAG_L1   0.885057    accuracy       0.076982     9.958515                0.076982           9.958515            1       True         67
# 133     RandomForest_r195_BAG_L1   0.885057    accuracy       0.083397     1.130933                0.083397           1.130933            1       True         26
# 134      RandomForest_r39_BAG_L1   0.885057    accuracy       0.085131     1.114525                0.085131           1.114525            1       True         45
# 135      RandomForest_r15_BAG_L1   0.885057    accuracy       0.087698     1.179801                0.087698           1.179801            1       True         81
# 136     RandomForest_r127_BAG_L1   0.885057    accuracy       0.091923     1.222647                0.091923           1.222647            1       True         58
# 137      RandomForestEntr_BAG_L1   0.885057    accuracy       0.098040     0.850911                0.098040           0.850911            1       True          7
# 138      RandomForestGini_BAG_L1   0.885057    accuracy       0.111212     0.791032                0.111212           0.791032            1       True          6
# 139       ExtraTrees_r178_BAG_L1   0.885057    accuracy       0.121996     0.973277                0.121996           0.973277            1       True         75
# 140       ExtraTrees_r126_BAG_L1   0.885057    accuracy       0.141408     1.284802                0.141408           1.284802            1       True         99
# 141         LightGBM_r131_BAG_L1   0.873563    accuracy       0.009899     2.686401                0.009899           2.686401            1       True         16
# 142          LightGBM_r15_BAG_L1   0.873563    accuracy       0.012686     3.679296                0.012686           3.679296            1       True         50
# 143        ExtraTreesEntr_BAG_L1   0.873563    accuracy       0.083195     0.762223                0.083195           0.762223            1       True         10
# 144        ExtraTrees_r49_BAG_L1   0.873563    accuracy       0.086196     1.035186                0.086196           1.035186            1       True         56
# 145        ExtraTreesGini_BAG_L1   0.873563    accuracy       0.086331     0.755624                0.086331           0.755624            1       True          9
# 146      RandomForest_r16_BAG_L1   0.873563    accuracy       0.088398     1.563785                0.088398           1.563785            1       True         94
# 147       ExtraTrees_r197_BAG_L1   0.873563    accuracy       0.092695     1.361506                0.092695           1.361506            1       True         91
# 148        ExtraTrees_r42_BAG_L1   0.873563    accuracy       0.095074     0.847460                0.095074           0.847460            1       True         22
# 149     RandomForest_r166_BAG_L1   0.873563    accuracy       0.100409     1.292530                0.100409           1.292530            1       True         76
# 150       ExtraTrees_r172_BAG_L1   0.873563    accuracy       0.107974     0.760032                0.107974           0.760032            1       True         36
# 151          LightGBM_r94_BAG_L1   0.770115    accuracy       0.010384     3.001719                0.010384           3.001719            1       True         61
# 152        KNeighborsUnif_BAG_L1   0.701149    accuracy       0.314503     0.004997                0.314503           0.004997            1       True          1
# 153         ExtraTrees_r4_BAG_L1   0.620690    accuracy       0.153246     1.028894                0.153246           1.028894            1       True         66
# 154          LightGBM_r96_BAG_L1   0.275862    accuracy       0.008276     2.524881                0.008276           2.524881            1       True         19
# 155         LightGBM_r135_BAG_L1   0.275862    accuracy       0.009888     2.690822                0.009888           2.690822            1       True         82
# 156         LightGBM_r130_BAG_L1   0.275862    accuracy       0.017996     2.563767                0.017996           2.563767            1       True         31
# 157         LightGBM_r130_BAG_L2   0.275862    accuracy       7.583158   927.087389                0.025191           2.884591            2       True        140
# 158          LightGBM_r96_BAG_L2   0.275862    accuracy       7.584771   927.191799                0.026804           2.989000            2       True        128
# 159      RandomForest_r34_BAG_L1   0.011494    accuracy       0.082655     1.470538                0.082655           1.470538            1       True         60
# Number of models trained: 160
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L2
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       1.00      0.80      0.89         5
#         Exc L3-4 RORB CARM1P1       0.50      0.25      0.33         4
#         Exc L3-5 RORB COL22A1       0.73      1.00      0.84         8
#
#                      accuracy                           0.76        17
#                     macro avg       0.74      0.68      0.69        17
#                  weighted avg       0.75      0.76      0.74        17

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[4 1 0]
#  [0 1 3]
#  [0 0 8]]
# ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']
# ([<matplotlib.axis.YTick at 0x1dcf85b5a10>,
#   <matplotlib.axis.YTick at 0x1dbc79b4d50>,
#   <matplotlib.axis.YTick at 0x1dcf85af190>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[4 1 0]
#  [0 1 3]
#  [0 0 8]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                    2.503527e-01           5.662553e-02
# 1                    9.410077e-01           4.972140e-02
# 2                    2.188855e-08           3.579876e-07
# 3                    2.716585e-06           1.638740e-05
# 4                    8.198792e-03           1.284802e-02
# 5                    4.773553e-02           9.287253e-01
# 6                    7.314375e-02           2.587112e-01
# 7                    8.252173e-06           4.719492e-05
# 8                    9.400415e-01           5.800841e-02
# 9                    1.583097e-10           4.440382e-09
# 10                   4.987190e-02           8.172031e-01
# 11                   9.350801e-01           5.608635e-02
# 12                   1.415323e-02           2.081547e-02
# 13                   9.422860e-01           5.046451e-02
# 14                   1.170582e-02           8.657753e-02
# 15                   1.441962e-07           1.739809e-06
# 16                   7.350562e-06           3.452627e-05
#
#     Exc L3-5 RORB COL22A1
# 0                0.693022
# 1                0.009271
# 2                1.000000
# 3                0.999981
# 4                0.978953
# 5                0.023539
# 6                0.668145
# 7                0.999945
# 8                0.001950
# 9                1.000000
# 10               0.132925
# 11               0.008833
# 12               0.965031
# 13               0.007249
# 14               0.901717
# 15               0.999998
# 16               0.999958

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 17 rows with 5 shuffle sets...
# 	19.42s	= Expected runtime (3.88s per shuffle set)
# 	1.05s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# FAP_rheobase            0.070588  0.087249  0.072352  5  0.250236 -0.109059
# L23_depth_normalized    0.058824  0.000000  0.500000  5  0.058824  0.058824
# TS2_rheobase            0.047059  0.049215  0.049650  5  0.148394 -0.054276
# TS1_rheobase            0.035294  0.067069  0.152279  5  0.173390 -0.102802
# TS2_avg_upstroke        0.011765  0.026307  0.186950  5  0.065931 -0.042401
# FAP_halfwidth           0.011765  0.026307  0.186950  5  0.065931 -0.042401
# FAP_maxupstroke         0.011765  0.026307  0.186950  5  0.065931 -0.042401
# input_resistance        0.011765  0.026307  0.186950  5  0.065931 -0.042401
# FAP_avg_upstroke        0.011765  0.026307  0.186950  5  0.065931 -0.042401
# TS1_threshold           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_up_down_ratio       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_avg_downstroke      0.000000  0.000000  0.500000  5  0.000000  0.000000
# VmatSag                 0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxupstroke         0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_peak                0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_threshold           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_up_down_ratio       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_avg_downstroke      0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_avg_upstroke        0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_halfwidth           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxupstroke         0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_up_down_ratio       0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_avg_downstroke      0.000000  0.000000  0.500000  5  0.000000  0.000000
# sag                     0.000000  0.000000  0.500000  5  0.000000  0.000000
# vmbaseM                 0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_maxdownstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_peak                0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_threshold           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_adp_index           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_adp_index           0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_num_APs             0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS1_maxdownstroke      -0.023529  0.032219  0.911096  5  0.042810 -0.089869
# FAP_num_APs            -0.035294  0.032219  0.964758  5  0.031045 -0.101633
# tau                    -0.035294  0.032219  0.964758  5  0.031045 -0.101633
# TS1_num_APs            -0.047059  0.026307  0.991935  5  0.007107 -0.101225

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L2
# {'accuracy': 0.7647058823529411,
#  'balanced_accuracy': 0.6833333333333332,
#  'mcc': 0.6362818423023819,
#  'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
#  Exc L2-3 LINC00507 FREM3 deep                              4
#  Exc L3-4 RORB CARM1P1                                      0
#  Exc L3-5 RORB COL22A1                                      0
#
#                                 Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
#  Exc L2-3 LINC00507 FREM3 deep                      1                      0
#  Exc L3-4 RORB CARM1P1                              1                      3
#  Exc L3-5 RORB COL22A1                              0                      8  ,
#  'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 1.0,
#    'recall': 0.8,
#    'f1-score': 0.8888888888888888,
#    'support': 5.0},
#   'Exc L3-4 RORB CARM1P1': {'precision': 0.5,
#    'recall': 0.25,
#    'f1-score': 0.3333333333333333,
#    'support': 4.0},
#   'Exc L3-5 RORB COL22A1': {'precision': 0.7272727272727273,
#    'recall': 1.0,
#    'f1-score': 0.8421052631578947,
#    'support': 8.0},
#   'accuracy': 0.7647058823529411,
#   'macro avg': {'precision': 0.7424242424242425,
#    'recall': 0.6833333333333332,
#    'f1-score': 0.6881091617933723,
#    'support': 17.0},
#   'weighted avg': {'precision': 0.7540106951871658,
#    'recall': 0.7647058823529411,
#    'f1-score': 0.7361541107671139,
#    'support': 17.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data, extra_metrics=['accuracy','f1_macro', 'balanced_accuracy','f1_micro', 'f1_weighted'],extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                        model  score_test  accuracy  f1_macro  \
# 0      KNeighborsUnif_BAG_L1    0.941176  0.941176  0.925926
# 1      KNeighborsDist_BAG_L1    0.941176  0.941176  0.925926
# 2            LightGBM_BAG_L1    0.882353  0.882353  0.850000
# 3       LightGBM_r131_BAG_L1    0.882353  0.882353  0.850000
# 4       LightGBM_r121_BAG_L1    0.882353  0.882353  0.850000
# ..                       ...         ...       ...       ...
# 155     LightGBM_r135_BAG_L1    0.294118  0.294118  0.151515
# 156      LightGBM_r96_BAG_L1    0.294118  0.294118  0.151515
# 157  RandomForest_r34_BAG_L1    0.294118  0.294118  0.151515
# 158     LightGBM_r130_BAG_L2    0.294118  0.294118  0.151515
# 159      LightGBM_r96_BAG_L2    0.294118  0.294118  0.151515
#
#      balanced_accuracy  f1_micro  f1_weighted  score_val eval_metric  \
# 0             0.933333  0.941176     0.941176   0.701149    accuracy
# 1             0.933333  0.941176     0.941176   0.896552    accuracy
# 2             0.850000  0.882353     0.882353   0.896552    accuracy
# 3             0.850000  0.882353     0.882353   0.873563    accuracy
# 4             0.850000  0.882353     0.882353   0.885057    accuracy
# ..                 ...       ...          ...        ...         ...
# 155           0.333333  0.294118     0.133690   0.275862    accuracy
# 156           0.333333  0.294118     0.133690   0.275862    accuracy
# 157           0.333333  0.294118     0.133690   0.011494    accuracy
# 158           0.333333  0.294118     0.133690   0.275862    accuracy
# 159           0.333333  0.294118     0.133690   0.275862    accuracy
#
#      pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0          0.003639       0.314503    0.004997                 0.003639
# 1          0.006999       0.003002    0.006997                 0.006999
# 2          0.014703       0.009005    2.695637                 0.014703
# 3          0.017195       0.009899    2.686401                 0.017195
# 4          0.017517       0.009832    2.922542                 0.017517
# ..              ...            ...         ...                      ...
# 155        0.011479       0.009888    2.690822                 0.011479
# 156        0.016336       0.008276    2.524881                 0.016336
# 157        0.065659       0.082655    1.470538                 0.065659
# 158        9.500488       7.583158  927.087389                 0.026604
# 159        9.502530       7.584771  927.191799                 0.028646
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                  0.314503           0.004997            1       True
# 1                  0.003002           0.006997            1       True
# 2                  0.009005           2.695637            1       True
# 3                  0.009899           2.686401            1       True
# 4                  0.009832           2.922542            1       True
# ..                      ...                ...          ...        ...
# 155                0.009888           2.690822            1       True
# 156                0.008276           2.524881            1       True
# 157                0.082655           1.470538            1       True
# 158                0.025191           2.884591            2       True
# 159                0.026804           2.989000            2       True
#
#      fit_order
# 0            1
# 1            2
# 2            5
# 3           16
# 4           87
# ..         ...
# 155         82
# 156         19
# 157         60
# 158        140
# 159        128
#
# [160 rows x 18 columns]

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_55556\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                         0.954928               0.043439
# 1                         0.947507               0.048568
# 2                         0.935865               0.049878
# 3                         0.953365               0.040756
# 4                         0.956375               0.041033
# ..                             ...                    ...
# 204                       0.825522               0.041995
# 205                       0.954788               0.041796
# 206                       0.956264               0.043604
# 207                       0.963298               0.035499
# 208                       0.888220               0.031416
#
#      Exc L3-5 RORB COL22A1
# 0                 0.001633
# 1                 0.003925
# 2                 0.014257
# 3                 0.005879
# 4                 0.002593
# ..                     ...
# 204               0.132483
# 205               0.003415
# 206               0.000132
# 207               0.001203
# 208               0.080364
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]=='Exc L3-4 RORB CARM1P1']])

new_unlabeled_data.shape
# Out:
# (161, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.296927
# [100]	valid_set's soft_log_loss: -0.145799
# [150]	valid_set's soft_log_loss: -0.105993
# [200]	valid_set's soft_log_loss: -0.105129
# [250]	valid_set's soft_log_loss: -0.107786
# [300]	valid_set's soft_log_loss: -0.105555
# [350]	valid_set's soft_log_loss: -0.107745
# [400]	valid_set's soft_log_loss: -0.107511
# [450]	valid_set's soft_log_loss: -0.108785
# 	Note: model has different eval_metric than default.
# 	-0.1031	 = Validation score   (-soft_log_loss)
# 	1.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.2257	 = Validation score   (-soft_log_loss)
# 	0.8s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0649584	test: -1.0615155	best: -1.0615155 (0)	total: 885ms	remaining: 2h 27m 25s
# 20:	learn: -0.7074590	test: -0.7194591	best: -0.7194591 (20)	total: 1.12s	remaining: 8m 54s
# 40:	learn: -0.5681565	test: -0.5617919	best: -0.5617919 (40)	total: 1.35s	remaining: 5m 29s
# 60:	learn: -0.4958027	test: -0.4587702	best: -0.4587702 (60)	total: 1.6s	remaining: 4m 20s
# 80:	learn: -0.4495938	test: -0.3859528	best: -0.3859528 (80)	total: 1.84s	remaining: 3m 45s
# 100:	learn: -0.4217930	test: -0.3352973	best: -0.3352973 (100)	total: 2.08s	remaining: 3m 23s
# 120:	learn: -0.4016488	test: -0.2973874	best: -0.2973874 (120)	total: 2.33s	remaining: 3m 9s
# 140:	learn: -0.3855170	test: -0.2627930	best: -0.2627930 (140)	total: 2.57s	remaining: 2m 59s
# 160:	learn: -0.3738889	test: -0.2377030	best: -0.2377030 (160)	total: 2.83s	remaining: 2m 53s
# 180:	learn: -0.3640422	test: -0.2194316	best: -0.2194316 (180)	total: 3.08s	remaining: 2m 47s
# 200:	learn: -0.3570906	test: -0.2059093	best: -0.2059093 (200)	total: 3.33s	remaining: 2m 42s
# 220:	learn: -0.3509596	test: -0.1942373	best: -0.1942373 (220)	total: 3.57s	remaining: 2m 37s
# 240:	learn: -0.3463386	test: -0.1847876	best: -0.1847876 (240)	total: 3.8s	remaining: 2m 34s
# 260:	learn: -0.3425036	test: -0.1762393	best: -0.1762393 (260)	total: 4.04s	remaining: 2m 30s
# 280:	learn: -0.3392387	test: -0.1701801	best: -0.1701801 (280)	total: 4.28s	remaining: 2m 27s
# 300:	learn: -0.3361812	test: -0.1654962	best: -0.1654804 (299)	total: 4.56s	remaining: 2m 27s
# 320:	learn: -0.3339322	test: -0.1628505	best: -0.1628505 (320)	total: 4.8s	remaining: 2m 24s
# 340:	learn: -0.3316290	test: -0.1563753	best: -0.1563753 (340)	total: 5.03s	remaining: 2m 22s
# 360:	learn: -0.3294460	test: -0.1527833	best: -0.1527833 (360)	total: 5.26s	remaining: 2m 20s
# 380:	learn: -0.3274969	test: -0.1488148	best: -0.1488138 (379)	total: 5.48s	remaining: 2m 18s
# 400:	learn: -0.3259168	test: -0.1452609	best: -0.1451913 (399)	total: 5.72s	remaining: 2m 16s
# 420:	learn: -0.3245124	test: -0.1421717	best: -0.1421717 (420)	total: 5.95s	remaining: 2m 15s
# 440:	learn: -0.3229411	test: -0.1399835	best: -0.1399021 (438)	total: 6.18s	remaining: 2m 14s
# 460:	learn: -0.3216445	test: -0.1370596	best: -0.1370596 (460)	total: 6.42s	remaining: 2m 12s
# 480:	learn: -0.3205438	test: -0.1346291	best: -0.1346291 (480)	total: 6.65s	remaining: 2m 11s
# 500:	learn: -0.3195909	test: -0.1329590	best: -0.1329590 (500)	total: 6.91s	remaining: 2m 10s
# 520:	learn: -0.3187045	test: -0.1308146	best: -0.1306445 (518)	total: 7.19s	remaining: 2m 10s
# 540:	learn: -0.3178635	test: -0.1288093	best: -0.1288093 (540)	total: 7.42s	remaining: 2m 9s
# 560:	learn: -0.3170565	test: -0.1275569	best: -0.1275569 (560)	total: 7.67s	remaining: 2m 9s
# 580:	learn: -0.3162906	test: -0.1254367	best: -0.1254367 (580)	total: 7.92s	remaining: 2m 8s
# 600:	learn: -0.3155376	test: -0.1236817	best: -0.1236817 (600)	total: 8.16s	remaining: 2m 7s
# 620:	learn: -0.3149189	test: -0.1226617	best: -0.1226617 (620)	total: 8.42s	remaining: 2m 7s
# 640:	learn: -0.3142727	test: -0.1209139	best: -0.1209139 (640)	total: 8.66s	remaining: 2m 6s
# 660:	learn: -0.3136058	test: -0.1194448	best: -0.1194448 (660)	total: 8.88s	remaining: 2m 5s
# 680:	learn: -0.3130987	test: -0.1186283	best: -0.1186118 (676)	total: 9.12s	remaining: 2m 4s
# 700:	learn: -0.3125444	test: -0.1168790	best: -0.1168790 (700)	total: 9.37s	remaining: 2m 4s
# 720:	learn: -0.3120400	test: -0.1161665	best: -0.1161665 (720)	total: 9.61s	remaining: 2m 3s
# 740:	learn: -0.3115160	test: -0.1151255	best: -0.1149696 (739)	total: 9.86s	remaining: 2m 3s
# 760:	learn: -0.3110454	test: -0.1139652	best: -0.1139299 (758)	total: 10.1s	remaining: 2m 2s
# 780:	learn: -0.3105926	test: -0.1131766	best: -0.1131766 (780)	total: 10.4s	remaining: 2m 2s
# 800:	learn: -0.3101612	test: -0.1116600	best: -0.1116600 (800)	total: 10.7s	remaining: 2m 2s
# 820:	learn: -0.3097848	test: -0.1105489	best: -0.1105489 (820)	total: 10.9s	remaining: 2m 1s
# 840:	learn: -0.3094188	test: -0.1094612	best: -0.1094612 (840)	total: 11.1s	remaining: 2m 1s
# 860:	learn: -0.3090691	test: -0.1081939	best: -0.1081939 (860)	total: 11.4s	remaining: 2m
# 880:	learn: -0.3087326	test: -0.1077279	best: -0.1077250 (878)	total: 11.7s	remaining: 2m
# 900:	learn: -0.3083570	test: -0.1067985	best: -0.1067985 (900)	total: 11.9s	remaining: 2m
# 920:	learn: -0.3080313	test: -0.1058790	best: -0.1058162 (919)	total: 12.1s	remaining: 1m 59s
# 940:	learn: -0.3077579	test: -0.1055886	best: -0.1055052 (937)	total: 12.4s	remaining: 1m 58s
# 960:	learn: -0.3074834	test: -0.1050067	best: -0.1050067 (960)	total: 12.6s	remaining: 1m 58s
# 980:	learn: -0.3072132	test: -0.1039513	best: -0.1039513 (980)	total: 12.9s	remaining: 1m 58s
# 1000:	learn: -0.3069368	test: -0.1030292	best: -0.1030227 (998)	total: 13.1s	remaining: 1m 57s
# 1020:	learn: -0.3067239	test: -0.1025054	best: -0.1025054 (1020)	total: 13.4s	remaining: 1m 57s
# 1040:	learn: -0.3065161	test: -0.1018950	best: -0.1018950 (1040)	total: 13.6s	remaining: 1m 57s
# 1060:	learn: -0.3063082	test: -0.1014910	best: -0.1014910 (1060)	total: 13.9s	remaining: 1m 56s
# 1080:	learn: -0.3060587	test: -0.1006080	best: -0.1006046 (1079)	total: 14.1s	remaining: 1m 56s
# 1100:	learn: -0.3058344	test: -0.1004038	best: -0.1004038 (1100)	total: 14.4s	remaining: 1m 56s
# 1120:	learn: -0.3056580	test: -0.1000151	best: -0.1000151 (1120)	total: 14.6s	remaining: 1m 55s
# 1140:	learn: -0.3054761	test: -0.0995812	best: -0.0994487 (1138)	total: 14.9s	remaining: 1m 55s
# 1160:	learn: -0.3052884	test: -0.0993041	best: -0.0992183 (1156)	total: 15.1s	remaining: 1m 55s
# 1180:	learn: -0.3051162	test: -0.0991539	best: -0.0991539 (1180)	total: 15.3s	remaining: 1m 54s
# 1200:	learn: -0.3049379	test: -0.0986494	best: -0.0986494 (1200)	total: 15.6s	remaining: 1m 54s
# 1220:	learn: -0.3047647	test: -0.0985237	best: -0.0985120 (1219)	total: 15.8s	remaining: 1m 53s
# 1240:	learn: -0.3046164	test: -0.0975841	best: -0.0975841 (1240)	total: 16s	remaining: 1m 53s
# 1260:	learn: -0.3044531	test: -0.0976695	best: -0.0974049 (1251)	total: 16.3s	remaining: 1m 52s
# 1280:	learn: -0.3042917	test: -0.0973360	best: -0.0972750 (1274)	total: 16.5s	remaining: 1m 52s
# 1300:	learn: -0.3041531	test: -0.0968685	best: -0.0968685 (1300)	total: 16.7s	remaining: 1m 51s
# 1320:	learn: -0.3040082	test: -0.0966827	best: -0.0966239 (1308)	total: 17s	remaining: 1m 51s
# 1340:	learn: -0.3038589	test: -0.0965619	best: -0.0964940 (1336)	total: 17.2s	remaining: 1m 51s
# 1360:	learn: -0.3037293	test: -0.0961651	best: -0.0961651 (1360)	total: 17.4s	remaining: 1m 50s
# 1380:	learn: -0.3035921	test: -0.0957417	best: -0.0957417 (1380)	total: 17.7s	remaining: 1m 50s
# 1400:	learn: -0.3034646	test: -0.0953111	best: -0.0953111 (1400)	total: 17.9s	remaining: 1m 50s
# 1420:	learn: -0.3033578	test: -0.0953446	best: -0.0952234 (1417)	total: 18.2s	remaining: 1m 49s
# 1440:	learn: -0.3032550	test: -0.0951791	best: -0.0951619 (1427)	total: 18.4s	remaining: 1m 49s
# 1460:	learn: -0.3031535	test: -0.0949465	best: -0.0949446 (1459)	total: 18.6s	remaining: 1m 48s
# 1480:	learn: -0.3030388	test: -0.0948423	best: -0.0948308 (1473)	total: 18.9s	remaining: 1m 48s
# 1500:	learn: -0.3029277	test: -0.0945172	best: -0.0944978 (1499)	total: 19.1s	remaining: 1m 48s
# 1520:	learn: -0.3028181	test: -0.0940315	best: -0.0940315 (1520)	total: 19.3s	remaining: 1m 47s
# 1540:	learn: -0.3027238	test: -0.0937410	best: -0.0937410 (1540)	total: 19.6s	remaining: 1m 47s
# 1560:	learn: -0.3026193	test: -0.0936620	best: -0.0935625 (1558)	total: 19.8s	remaining: 1m 47s
# 1580:	learn: -0.3025105	test: -0.0928939	best: -0.0928939 (1580)	total: 20.1s	remaining: 1m 46s
# 1600:	learn: -0.3024208	test: -0.0928140	best: -0.0927488 (1593)	total: 20.3s	remaining: 1m 46s
# 1620:	learn: -0.3023315	test: -0.0924313	best: -0.0923969 (1616)	total: 20.5s	remaining: 1m 46s
# 1640:	learn: -0.3022523	test: -0.0921184	best: -0.0921184 (1640)	total: 20.8s	remaining: 1m 45s
# 1660:	learn: -0.3021640	test: -0.0918584	best: -0.0917709 (1654)	total: 21s	remaining: 1m 45s
# 1680:	learn: -0.3020748	test: -0.0917329	best: -0.0916785 (1673)	total: 21.2s	remaining: 1m 45s
# 1700:	learn: -0.3019911	test: -0.0917500	best: -0.0916785 (1673)	total: 21.5s	remaining: 1m 44s
# 1720:	learn: -0.3019164	test: -0.0917533	best: -0.0916785 (1673)	total: 21.8s	remaining: 1m 44s
# 1740:	learn: -0.3018408	test: -0.0918532	best: -0.0916785 (1673)	total: 22s	remaining: 1m 44s
# 1760:	learn: -0.3017609	test: -0.0914585	best: -0.0914585 (1760)	total: 22.2s	remaining: 1m 44s
# 1780:	learn: -0.3016789	test: -0.0912329	best: -0.0912329 (1780)	total: 22.5s	remaining: 1m 43s
# 1800:	learn: -0.3015949	test: -0.0910059	best: -0.0909653 (1794)	total: 22.8s	remaining: 1m 43s
# 1820:	learn: -0.3015221	test: -0.0908058	best: -0.0907586 (1818)	total: 23s	remaining: 1m 43s
# 1840:	learn: -0.3014592	test: -0.0904622	best: -0.0904622 (1840)	total: 23.2s	remaining: 1m 42s
# 1860:	learn: -0.3013863	test: -0.0903629	best: -0.0903605 (1859)	total: 23.4s	remaining: 1m 42s
# 1880:	learn: -0.3013134	test: -0.0902102	best: -0.0901775 (1876)	total: 23.7s	remaining: 1m 42s
# 1900:	learn: -0.3012538	test: -0.0901452	best: -0.0900800 (1884)	total: 24s	remaining: 1m 42s
# 1920:	learn: -0.3012035	test: -0.0899245	best: -0.0898933 (1918)	total: 24.2s	remaining: 1m 41s
# 1940:	learn: -0.3011386	test: -0.0900042	best: -0.0898870 (1935)	total: 24.5s	remaining: 1m 41s
# 1960:	learn: -0.3010744	test: -0.0899261	best: -0.0898830 (1952)	total: 24.7s	remaining: 1m 41s
# 1980:	learn: -0.3010156	test: -0.0898077	best: -0.0897477 (1967)	total: 24.9s	remaining: 1m 40s
# 2000:	learn: -0.3009584	test: -0.0895906	best: -0.0895526 (1996)	total: 25.2s	remaining: 1m 40s
# 2020:	learn: -0.3009023	test: -0.0893418	best: -0.0893317 (2016)	total: 25.4s	remaining: 1m 40s
# 2040:	learn: -0.3008412	test: -0.0891716	best: -0.0891275 (2030)	total: 25.7s	remaining: 1m 40s
# 2060:	learn: -0.3007931	test: -0.0889420	best: -0.0889420 (2060)	total: 25.9s	remaining: 1m 39s
# 2080:	learn: -0.3007430	test: -0.0887227	best: -0.0887113 (2078)	total: 26.1s	remaining: 1m 39s
# 2100:	learn: -0.3006841	test: -0.0884369	best: -0.0884087 (2098)	total: 26.4s	remaining: 1m 39s
# 2120:	learn: -0.3006251	test: -0.0882895	best: -0.0882230 (2113)	total: 26.7s	remaining: 1m 39s
# 2140:	learn: -0.3005705	test: -0.0881926	best: -0.0881734 (2139)	total: 26.9s	remaining: 1m 38s
# 2160:	learn: -0.3005237	test: -0.0882427	best: -0.0881631 (2141)	total: 27.1s	remaining: 1m 38s
# 2180:	learn: -0.3004687	test: -0.0881594	best: -0.0881320 (2178)	total: 27.4s	remaining: 1m 38s
# 2200:	learn: -0.3004237	test: -0.0880758	best: -0.0880643 (2199)	total: 27.6s	remaining: 1m 37s
# 2220:	learn: -0.3003709	test: -0.0881994	best: -0.0880499 (2206)	total: 27.8s	remaining: 1m 37s
# 2240:	learn: -0.3003203	test: -0.0882218	best: -0.0880499 (2206)	total: 28.1s	remaining: 1m 37s
# 2260:	learn: -0.3002848	test: -0.0882148	best: -0.0880499 (2206)	total: 28.3s	remaining: 1m 36s
# 2280:	learn: -0.3002469	test: -0.0882801	best: -0.0880499 (2206)	total: 28.6s	remaining: 1m 36s
# 2300:	learn: -0.3002057	test: -0.0882050	best: -0.0880499 (2206)	total: 28.8s	remaining: 1m 36s
# 2320:	learn: -0.3001654	test: -0.0881016	best: -0.0880349 (2312)	total: 29s	remaining: 1m 35s
# 2340:	learn: -0.3001216	test: -0.0877570	best: -0.0877570 (2340)	total: 29.3s	remaining: 1m 35s
# 2360:	learn: -0.3000821	test: -0.0875241	best: -0.0874864 (2359)	total: 29.5s	remaining: 1m 35s
# 2380:	learn: -0.3000506	test: -0.0876399	best: -0.0874864 (2359)	total: 29.7s	remaining: 1m 35s
# 2400:	learn: -0.3000038	test: -0.0876649	best: -0.0874864 (2359)	total: 30s	remaining: 1m 34s
# 2420:	learn: -0.2999667	test: -0.0874908	best: -0.0874192 (2417)	total: 30.2s	remaining: 1m 34s
# 2440:	learn: -0.2999345	test: -0.0873089	best: -0.0872760 (2433)	total: 30.5s	remaining: 1m 34s
# 2460:	learn: -0.2999024	test: -0.0871809	best: -0.0871809 (2460)	total: 30.7s	remaining: 1m 34s
# 2480:	learn: -0.2998618	test: -0.0868662	best: -0.0868384 (2477)	total: 30.9s	remaining: 1m 33s
# 2500:	learn: -0.2998272	test: -0.0868585	best: -0.0868196 (2491)	total: 31.2s	remaining: 1m 33s
# 2520:	learn: -0.2997897	test: -0.0869003	best: -0.0868196 (2491)	total: 31.4s	remaining: 1m 33s
# 2540:	learn: -0.2997547	test: -0.0868777	best: -0.0867878 (2527)	total: 31.6s	remaining: 1m 32s
# 2560:	learn: -0.2997223	test: -0.0867001	best: -0.0866855 (2559)	total: 31.8s	remaining: 1m 32s
# 2580:	learn: -0.2996905	test: -0.0865321	best: -0.0864820 (2578)	total: 32.1s	remaining: 1m 32s
# 2600:	learn: -0.2996567	test: -0.0861820	best: -0.0861820 (2600)	total: 32.3s	remaining: 1m 32s
# 2620:	learn: -0.2996254	test: -0.0862910	best: -0.0861618 (2601)	total: 32.6s	remaining: 1m 31s
# 2640:	learn: -0.2996001	test: -0.0861202	best: -0.0861202 (2640)	total: 32.8s	remaining: 1m 31s
# 2660:	learn: -0.2995722	test: -0.0862170	best: -0.0861202 (2640)	total: 33.1s	remaining: 1m 31s
# 2680:	learn: -0.2995430	test: -0.0860693	best: -0.0860237 (2674)	total: 33.3s	remaining: 1m 30s
# 2700:	learn: -0.2995161	test: -0.0860254	best: -0.0860237 (2674)	total: 33.5s	remaining: 1m 30s
# 2720:	learn: -0.2994867	test: -0.0859551	best: -0.0859190 (2715)	total: 33.8s	remaining: 1m 30s
# 2740:	learn: -0.2994636	test: -0.0858090	best: -0.0857622 (2738)	total: 34s	remaining: 1m 30s
# 2760:	learn: -0.2994359	test: -0.0856552	best: -0.0856544 (2757)	total: 34.3s	remaining: 1m 29s
# 2780:	learn: -0.2994115	test: -0.0854971	best: -0.0854850 (2778)	total: 34.5s	remaining: 1m 29s
# 2800:	learn: -0.2993854	test: -0.0854385	best: -0.0854097 (2798)	total: 34.7s	remaining: 1m 29s
# 2820:	learn: -0.2993562	test: -0.0854693	best: -0.0854097 (2798)	total: 35s	remaining: 1m 28s
# 2840:	learn: -0.2993307	test: -0.0854453	best: -0.0853887 (2836)	total: 35.2s	remaining: 1m 28s
# 2860:	learn: -0.2993070	test: -0.0853622	best: -0.0853622 (2860)	total: 35.4s	remaining: 1m 28s
# 2880:	learn: -0.2992802	test: -0.0854656	best: -0.0853108 (2861)	total: 35.7s	remaining: 1m 28s
# 2900:	learn: -0.2992538	test: -0.0854757	best: -0.0853108 (2861)	total: 35.9s	remaining: 1m 27s
# 2920:	learn: -0.2992331	test: -0.0854636	best: -0.0853108 (2861)	total: 36.2s	remaining: 1m 27s
# 2940:	learn: -0.2992137	test: -0.0853886	best: -0.0853108 (2861)	total: 36.4s	remaining: 1m 27s
# 2960:	learn: -0.2991894	test: -0.0854016	best: -0.0853108 (2861)	total: 36.7s	remaining: 1m 27s
# 2980:	learn: -0.2991695	test: -0.0853875	best: -0.0853108 (2861)	total: 36.9s	remaining: 1m 26s
# 3000:	learn: -0.2991416	test: -0.0855241	best: -0.0853108 (2861)	total: 37.1s	remaining: 1m 26s
# 3020:	learn: -0.2991193	test: -0.0853936	best: -0.0853108 (2861)	total: 37.4s	remaining: 1m 26s
# 3040:	learn: -0.2990961	test: -0.0854199	best: -0.0853108 (2861)	total: 37.6s	remaining: 1m 26s
# 3060:	learn: -0.2990739	test: -0.0853094	best: -0.0853094 (3060)	total: 37.9s	remaining: 1m 25s
# 3080:	learn: -0.2990482	test: -0.0850737	best: -0.0850729 (3079)	total: 38.1s	remaining: 1m 25s
# 3100:	learn: -0.2990283	test: -0.0849653	best: -0.0849593 (3099)	total: 38.3s	remaining: 1m 25s
# 3120:	learn: -0.2990093	test: -0.0848441	best: -0.0848441 (3120)	total: 38.6s	remaining: 1m 25s
# 3140:	learn: -0.2989928	test: -0.0848396	best: -0.0847883 (3135)	total: 38.8s	remaining: 1m 24s
# 3160:	learn: -0.2989722	test: -0.0848382	best: -0.0847883 (3135)	total: 39.1s	remaining: 1m 24s
# 3180:	learn: -0.2989529	test: -0.0847825	best: -0.0847755 (3173)	total: 39.3s	remaining: 1m 24s
# 3200:	learn: -0.2989343	test: -0.0848954	best: -0.0847263 (3191)	total: 39.6s	remaining: 1m 24s
# 3220:	learn: -0.2989154	test: -0.0848939	best: -0.0847263 (3191)	total: 39.8s	remaining: 1m 23s
# 3240:	learn: -0.2988992	test: -0.0848259	best: -0.0847263 (3191)	total: 40.1s	remaining: 1m 23s
# 3260:	learn: -0.2988784	test: -0.0849003	best: -0.0847263 (3191)	total: 40.3s	remaining: 1m 23s
# 3280:	learn: -0.2988588	test: -0.0848668	best: -0.0847263 (3191)	total: 40.5s	remaining: 1m 23s
# 3300:	learn: -0.2988406	test: -0.0849644	best: -0.0847263 (3191)	total: 40.8s	remaining: 1m 22s
# 3320:	learn: -0.2988198	test: -0.0849641	best: -0.0847263 (3191)	total: 41s	remaining: 1m 22s
# 3340:	learn: -0.2988022	test: -0.0849249	best: -0.0847263 (3191)	total: 41.2s	remaining: 1m 22s
# 3360:	learn: -0.2987836	test: -0.0847301	best: -0.0847170 (3357)	total: 41.5s	remaining: 1m 21s
# 3380:	learn: -0.2987671	test: -0.0846388	best: -0.0846337 (3379)	total: 41.7s	remaining: 1m 21s
# 3400:	learn: -0.2987512	test: -0.0846882	best: -0.0845837 (3392)	total: 42s	remaining: 1m 21s
# 3420:	learn: -0.2987364	test: -0.0847503	best: -0.0845837 (3392)	total: 42.2s	remaining: 1m 21s
# 3440:	learn: -0.2987230	test: -0.0846930	best: -0.0845837 (3392)	total: 42.5s	remaining: 1m 20s
# 3460:	learn: -0.2987066	test: -0.0847176	best: -0.0845837 (3392)	total: 42.7s	remaining: 1m 20s
# 3480:	learn: -0.2986884	test: -0.0847914	best: -0.0845837 (3392)	total: 42.9s	remaining: 1m 20s
# 3500:	learn: -0.2986750	test: -0.0848190	best: -0.0845837 (3392)	total: 43.2s	remaining: 1m 20s
# 3520:	learn: -0.2986579	test: -0.0847918	best: -0.0845837 (3392)	total: 43.4s	remaining: 1m 19s
# 3540:	learn: -0.2986410	test: -0.0847066	best: -0.0845837 (3392)	total: 43.7s	remaining: 1m 19s
# 3560:	learn: -0.2986260	test: -0.0846797	best: -0.0845837 (3392)	total: 43.9s	remaining: 1m 19s
# 3580:	learn: -0.2986110	test: -0.0847403	best: -0.0845837 (3392)	total: 44.2s	remaining: 1m 19s
# 3600:	learn: -0.2985964	test: -0.0847429	best: -0.0845837 (3392)	total: 44.4s	remaining: 1m 18s
# 3620:	learn: -0.2985815	test: -0.0846419	best: -0.0845837 (3392)	total: 44.7s	remaining: 1m 18s
# 3640:	learn: -0.2985659	test: -0.0845427	best: -0.0844843 (3635)	total: 44.9s	remaining: 1m 18s
# 3660:	learn: -0.2985526	test: -0.0846201	best: -0.0844843 (3635)	total: 45.2s	remaining: 1m 18s
# 3680:	learn: -0.2985380	test: -0.0845274	best: -0.0844720 (3673)	total: 45.4s	remaining: 1m 17s
# 3700:	learn: -0.2985248	test: -0.0844142	best: -0.0843864 (3698)	total: 45.6s	remaining: 1m 17s
# 3720:	learn: -0.2985090	test: -0.0843219	best: -0.0843144 (3719)	total: 45.9s	remaining: 1m 17s
# 3740:	learn: -0.2984974	test: -0.0843601	best: -0.0843144 (3719)	total: 46.2s	remaining: 1m 17s
# 3760:	learn: -0.2984854	test: -0.0843728	best: -0.0843144 (3719)	total: 46.4s	remaining: 1m 16s
# 3780:	learn: -0.2984721	test: -0.0844323	best: -0.0843144 (3719)	total: 46.6s	remaining: 1m 16s
# 3800:	learn: -0.2984579	test: -0.0844498	best: -0.0843144 (3719)	total: 46.9s	remaining: 1m 16s
# 3820:	learn: -0.2984443	test: -0.0843948	best: -0.0843144 (3719)	total: 47.1s	remaining: 1m 16s
# 3840:	learn: -0.2984275	test: -0.0843808	best: -0.0843144 (3719)	total: 47.4s	remaining: 1m 15s
# 3860:	learn: -0.2984128	test: -0.0842709	best: -0.0842685 (3857)	total: 47.6s	remaining: 1m 15s
# 3880:	learn: -0.2984017	test: -0.0843904	best: -0.0842553 (3865)	total: 47.9s	remaining: 1m 15s
# 3900:	learn: -0.2983908	test: -0.0842846	best: -0.0842553 (3865)	total: 48.1s	remaining: 1m 15s
# 3920:	learn: -0.2983783	test: -0.0842674	best: -0.0842553 (3865)	total: 48.4s	remaining: 1m 14s
# 3940:	learn: -0.2983633	test: -0.0841330	best: -0.0841330 (3940)	total: 48.6s	remaining: 1m 14s
# 3960:	learn: -0.2983526	test: -0.0841394	best: -0.0841291 (3946)	total: 48.8s	remaining: 1m 14s
# 3980:	learn: -0.2983414	test: -0.0843238	best: -0.0841291 (3946)	total: 49.1s	remaining: 1m 14s
# 4000:	learn: -0.2983288	test: -0.0842761	best: -0.0841291 (3946)	total: 49.3s	remaining: 1m 13s
# 4020:	learn: -0.2983165	test: -0.0842899	best: -0.0841291 (3946)	total: 49.5s	remaining: 1m 13s
# 4040:	learn: -0.2983053	test: -0.0842687	best: -0.0841291 (3946)	total: 49.8s	remaining: 1m 13s
# 4060:	learn: -0.2982946	test: -0.0843426	best: -0.0841291 (3946)	total: 50.1s	remaining: 1m 13s
# 4080:	learn: -0.2982845	test: -0.0843165	best: -0.0841291 (3946)	total: 50.3s	remaining: 1m 12s
# 4100:	learn: -0.2982730	test: -0.0842448	best: -0.0841291 (3946)	total: 50.5s	remaining: 1m 12s
# 4120:	learn: -0.2982641	test: -0.0842834	best: -0.0841291 (3946)	total: 50.8s	remaining: 1m 12s
# 4140:	learn: -0.2982521	test: -0.0841931	best: -0.0841291 (3946)	total: 51s	remaining: 1m 12s
# 4160:	learn: -0.2982403	test: -0.0842067	best: -0.0841291 (3946)	total: 51.3s	remaining: 1m 11s
# 4180:	learn: -0.2982284	test: -0.0842595	best: -0.0841291 (3946)	total: 51.5s	remaining: 1m 11s
# 4200:	learn: -0.2982163	test: -0.0842178	best: -0.0841291 (3946)	total: 51.7s	remaining: 1m 11s
# 4220:	learn: -0.2982054	test: -0.0842343	best: -0.0841291 (3946)	total: 52s	remaining: 1m 11s
# 4240:	learn: -0.2981934	test: -0.0841633	best: -0.0841291 (3946)	total: 52.2s	remaining: 1m 10s
# 4260:	learn: -0.2981817	test: -0.0842353	best: -0.0841291 (3946)	total: 52.5s	remaining: 1m 10s
# 4280:	learn: -0.2981711	test: -0.0841098	best: -0.0840976 (4276)	total: 52.7s	remaining: 1m 10s
# 4300:	learn: -0.2981611	test: -0.0840911	best: -0.0840911 (4300)	total: 53s	remaining: 1m 10s
# 4320:	learn: -0.2981505	test: -0.0841336	best: -0.0840523 (4311)	total: 53.2s	remaining: 1m 9s
# 4340:	learn: -0.2981388	test: -0.0841238	best: -0.0840523 (4311)	total: 53.4s	remaining: 1m 9s
# 4360:	learn: -0.2981283	test: -0.0839790	best: -0.0839790 (4360)	total: 53.7s	remaining: 1m 9s
# 4380:	learn: -0.2981185	test: -0.0838780	best: -0.0838780 (4380)	total: 53.9s	remaining: 1m 9s
# 4400:	learn: -0.2981089	test: -0.0837367	best: -0.0837250 (4397)	total: 54.2s	remaining: 1m 8s
# 4420:	learn: -0.2980979	test: -0.0838003	best: -0.0837189 (4403)	total: 54.4s	remaining: 1m 8s
# 4440:	learn: -0.2980868	test: -0.0838244	best: -0.0837189 (4403)	total: 54.6s	remaining: 1m 8s
# 4460:	learn: -0.2980769	test: -0.0838222	best: -0.0837189 (4403)	total: 54.9s	remaining: 1m 8s
# 4480:	learn: -0.2980681	test: -0.0838222	best: -0.0837189 (4403)	total: 55.1s	remaining: 1m 7s
# 4500:	learn: -0.2980595	test: -0.0838263	best: -0.0837189 (4403)	total: 55.4s	remaining: 1m 7s
# 4520:	learn: -0.2980510	test: -0.0838606	best: -0.0837189 (4403)	total: 55.6s	remaining: 1m 7s
# 4540:	learn: -0.2980418	test: -0.0838953	best: -0.0837189 (4403)	total: 55.8s	remaining: 1m 7s
# 4560:	learn: -0.2980333	test: -0.0838818	best: -0.0837189 (4403)	total: 56.1s	remaining: 1m 6s
# 4580:	learn: -0.2980247	test: -0.0838425	best: -0.0837189 (4403)	total: 56.3s	remaining: 1m 6s
# 4600:	learn: -0.2980160	test: -0.0838885	best: -0.0837189 (4403)	total: 56.5s	remaining: 1m 6s
# 4620:	learn: -0.2980066	test: -0.0838054	best: -0.0837189 (4403)	total: 56.8s	remaining: 1m 6s
# 4640:	learn: -0.2979988	test: -0.0836416	best: -0.0836416 (4640)	total: 57s	remaining: 1m 5s
# 4660:	learn: -0.2979898	test: -0.0835958	best: -0.0835944 (4658)	total: 57.3s	remaining: 1m 5s
# 4680:	learn: -0.2979823	test: -0.0835698	best: -0.0835379 (4667)	total: 57.5s	remaining: 1m 5s
# 4700:	learn: -0.2979743	test: -0.0836115	best: -0.0835379 (4667)	total: 57.8s	remaining: 1m 5s
# 4720:	learn: -0.2979667	test: -0.0837446	best: -0.0835379 (4667)	total: 58s	remaining: 1m 4s
# 4740:	learn: -0.2979584	test: -0.0837042	best: -0.0835379 (4667)	total: 58.3s	remaining: 1m 4s
# 4760:	learn: -0.2979506	test: -0.0837938	best: -0.0835379 (4667)	total: 58.5s	remaining: 1m 4s
# 4780:	learn: -0.2979414	test: -0.0837585	best: -0.0835379 (4667)	total: 58.8s	remaining: 1m 4s
# 4800:	learn: -0.2979324	test: -0.0838216	best: -0.0835379 (4667)	total: 59s	remaining: 1m 3s
# 4820:	learn: -0.2979250	test: -0.0837251	best: -0.0835379 (4667)	total: 59.2s	remaining: 1m 3s
# 4840:	learn: -0.2979163	test: -0.0837392	best: -0.0835379 (4667)	total: 59.5s	remaining: 1m 3s
# 4860:	learn: -0.2979081	test: -0.0837409	best: -0.0835379 (4667)	total: 59.7s	remaining: 1m 3s
# 4880:	learn: -0.2979013	test: -0.0837497	best: -0.0835379 (4667)	total: 59.9s	remaining: 1m 2s
# 4900:	learn: -0.2978936	test: -0.0838829	best: -0.0835379 (4667)	total: 1m	remaining: 1m 2s
# 4920:	learn: -0.2978867	test: -0.0838921	best: -0.0835379 (4667)	total: 1m	remaining: 1m 2s
# 4940:	learn: -0.2978779	test: -0.0837646	best: -0.0835379 (4667)	total: 1m	remaining: 1m 2s
# 4960:	learn: -0.2978707	test: -0.0838258	best: -0.0835379 (4667)	total: 1m	remaining: 1m 1s
# 4980:	learn: -0.2978617	test: -0.0837346	best: -0.0835379 (4667)	total: 1m 1s	remaining: 1m 1s
# 5000:	learn: -0.2978533	test: -0.0837983	best: -0.0835379 (4667)	total: 1m 1s	remaining: 1m 1s
# 5020:	learn: -0.2978444	test: -0.0836873	best: -0.0835379 (4667)	total: 1m 1s	remaining: 1m 1s
# 5040:	learn: -0.2978386	test: -0.0836832	best: -0.0835379 (4667)	total: 1m 1s	remaining: 1m
# 5060:	learn: -0.2978314	test: -0.0835600	best: -0.0835379 (4667)	total: 1m 2s	remaining: 1m
# 5080:	learn: -0.2978244	test: -0.0835356	best: -0.0835062 (5078)	total: 1m 2s	remaining: 1m
# 5100:	learn: -0.2978175	test: -0.0835167	best: -0.0835062 (5078)	total: 1m 2s	remaining: 1m
# 5120:	learn: -0.2978111	test: -0.0836180	best: -0.0835062 (5078)	total: 1m 2s	remaining: 59.8s
# 5140:	learn: -0.2978045	test: -0.0836379	best: -0.0835062 (5078)	total: 1m 3s	remaining: 59.6s
# 5160:	learn: -0.2977976	test: -0.0836721	best: -0.0835062 (5078)	total: 1m 3s	remaining: 59.3s
# 5180:	learn: -0.2977907	test: -0.0835824	best: -0.0835062 (5078)	total: 1m 3s	remaining: 59.1s
# 5200:	learn: -0.2977825	test: -0.0836393	best: -0.0835062 (5078)	total: 1m 3s	remaining: 58.8s
# 5220:	learn: -0.2977758	test: -0.0836594	best: -0.0835062 (5078)	total: 1m 3s	remaining: 58.5s
# 5240:	learn: -0.2977697	test: -0.0836996	best: -0.0835062 (5078)	total: 1m 4s	remaining: 58.3s
# 5260:	learn: -0.2977615	test: -0.0837459	best: -0.0835062 (5078)	total: 1m 4s	remaining: 58s
# 5280:	learn: -0.2977559	test: -0.0838484	best: -0.0835062 (5078)	total: 1m 4s	remaining: 57.8s
# 5300:	learn: -0.2977493	test: -0.0838000	best: -0.0835062 (5078)	total: 1m 4s	remaining: 57.6s
# 5320:	learn: -0.2977428	test: -0.0838639	best: -0.0835062 (5078)	total: 1m 5s	remaining: 57.3s
# 5340:	learn: -0.2977359	test: -0.0839163	best: -0.0835062 (5078)	total: 1m 5s	remaining: 57.1s
# 5360:	learn: -0.2977292	test: -0.0839970	best: -0.0835062 (5078)	total: 1m 5s	remaining: 56.8s
# 5380:	learn: -0.2977225	test: -0.0839681	best: -0.0835062 (5078)	total: 1m 5s	remaining: 56.6s
# 5400:	learn: -0.2977152	test: -0.0840061	best: -0.0835062 (5078)	total: 1m 6s	remaining: 56.3s
# 5420:	learn: -0.2977091	test: -0.0840277	best: -0.0835062 (5078)	total: 1m 6s	remaining: 56s
# 5440:	learn: -0.2977024	test: -0.0840019	best: -0.0835062 (5078)	total: 1m 6s	remaining: 55.8s
# 5460:	learn: -0.2976969	test: -0.0839171	best: -0.0835062 (5078)	total: 1m 6s	remaining: 55.5s
# 5480:	learn: -0.2976906	test: -0.0838460	best: -0.0835062 (5078)	total: 1m 7s	remaining: 55.3s
# 5500:	learn: -0.2976844	test: -0.0837206	best: -0.0835062 (5078)	total: 1m 7s	remaining: 55s
# 5520:	learn: -0.2976778	test: -0.0837366	best: -0.0835062 (5078)	total: 1m 7s	remaining: 54.8s
# 5540:	learn: -0.2976715	test: -0.0837696	best: -0.0835062 (5078)	total: 1m 7s	remaining: 54.5s
# 5560:	learn: -0.2976655	test: -0.0838034	best: -0.0835062 (5078)	total: 1m 7s	remaining: 54.3s
# 5580:	learn: -0.2976593	test: -0.0837968	best: -0.0835062 (5078)	total: 1m 8s	remaining: 54s
# 5600:	learn: -0.2976539	test: -0.0838043	best: -0.0835062 (5078)	total: 1m 8s	remaining: 53.8s
# 5620:	learn: -0.2976485	test: -0.0838037	best: -0.0835062 (5078)	total: 1m 8s	remaining: 53.5s
# 5640:	learn: -0.2976429	test: -0.0837878	best: -0.0835062 (5078)	total: 1m 8s	remaining: 53.2s
# 5660:	learn: -0.2976373	test: -0.0838762	best: -0.0835062 (5078)	total: 1m 9s	remaining: 53s
# 5680:	learn: -0.2976313	test: -0.0836886	best: -0.0835062 (5078)	total: 1m 9s	remaining: 52.8s
# 5700:	learn: -0.2976256	test: -0.0836453	best: -0.0835062 (5078)	total: 1m 9s	remaining: 52.5s
# 5720:	learn: -0.2976200	test: -0.0835772	best: -0.0835062 (5078)	total: 1m 9s	remaining: 52.3s
# 5740:	learn: -0.2976146	test: -0.0835866	best: -0.0835062 (5078)	total: 1m 10s	remaining: 52s
# 5760:	learn: -0.2976090	test: -0.0835478	best: -0.0835062 (5078)	total: 1m 10s	remaining: 51.8s
# 5780:	learn: -0.2976041	test: -0.0835684	best: -0.0835062 (5078)	total: 1m 10s	remaining: 51.5s
# 5800:	learn: -0.2975987	test: -0.0835214	best: -0.0835062 (5078)	total: 1m 10s	remaining: 51.3s
# 5820:	learn: -0.2975942	test: -0.0835280	best: -0.0834974 (5803)	total: 1m 11s	remaining: 51.1s
# 5840:	learn: -0.2975890	test: -0.0835425	best: -0.0834974 (5803)	total: 1m 11s	remaining: 50.8s
# 5860:	learn: -0.2975830	test: -0.0835610	best: -0.0834974 (5803)	total: 1m 11s	remaining: 50.6s
# 5880:	learn: -0.2975778	test: -0.0836729	best: -0.0834974 (5803)	total: 1m 11s	remaining: 50.3s
# 5900:	learn: -0.2975714	test: -0.0836649	best: -0.0834974 (5803)	total: 1m 12s	remaining: 50.1s
# 5920:	learn: -0.2975664	test: -0.0836640	best: -0.0834974 (5803)	total: 1m 12s	remaining: 49.8s
# 5940:	learn: -0.2975612	test: -0.0837068	best: -0.0834974 (5803)	total: 1m 12s	remaining: 49.6s
# 5960:	learn: -0.2975560	test: -0.0836452	best: -0.0834974 (5803)	total: 1m 12s	remaining: 49.3s
# 5980:	learn: -0.2975509	test: -0.0836110	best: -0.0834974 (5803)	total: 1m 13s	remaining: 49.1s
# 6000:	learn: -0.2975465	test: -0.0836194	best: -0.0834974 (5803)	total: 1m 13s	remaining: 48.9s
# 6020:	learn: -0.2975415	test: -0.0835709	best: -0.0834974 (5803)	total: 1m 13s	remaining: 48.6s
# 6040:	learn: -0.2975368	test: -0.0836031	best: -0.0834974 (5803)	total: 1m 13s	remaining: 48.4s
# 6060:	learn: -0.2975326	test: -0.0835617	best: -0.0834974 (5803)	total: 1m 14s	remaining: 48.1s
# 6080:	learn: -0.2975279	test: -0.0836074	best: -0.0834974 (5803)	total: 1m 14s	remaining: 47.9s
# 6100:	learn: -0.2975227	test: -0.0835866	best: -0.0834974 (5803)	total: 1m 14s	remaining: 47.6s
# 6120:	learn: -0.2975182	test: -0.0835330	best: -0.0834974 (5803)	total: 1m 14s	remaining: 47.4s
# 6140:	learn: -0.2975135	test: -0.0835746	best: -0.0834974 (5803)	total: 1m 15s	remaining: 47.1s
# 6160:	learn: -0.2975090	test: -0.0835675	best: -0.0834974 (5803)	total: 1m 15s	remaining: 46.9s
# 6180:	learn: -0.2975045	test: -0.0835619	best: -0.0834974 (5803)	total: 1m 15s	remaining: 46.7s
# 6200:	learn: -0.2974998	test: -0.0835966	best: -0.0834974 (5803)	total: 1m 15s	remaining: 46.4s
# 6220:	learn: -0.2974957	test: -0.0836540	best: -0.0834974 (5803)	total: 1m 15s	remaining: 46.2s
# 6240:	learn: -0.2974906	test: -0.0835513	best: -0.0834974 (5803)	total: 1m 16s	remaining: 45.9s
# 6260:	learn: -0.2974857	test: -0.0835531	best: -0.0834974 (5803)	total: 1m 16s	remaining: 45.7s
# 6280:	learn: -0.2974806	test: -0.0835404	best: -0.0834974 (5803)	total: 1m 16s	remaining: 45.4s
# 6300:	learn: -0.2974764	test: -0.0834853	best: -0.0834833 (6288)	total: 1m 16s	remaining: 45.2s
# 6320:	learn: -0.2974714	test: -0.0834962	best: -0.0834603 (6311)	total: 1m 17s	remaining: 44.9s
# 6340:	learn: -0.2974660	test: -0.0834507	best: -0.0834419 (6336)	total: 1m 17s	remaining: 44.7s
# 6360:	learn: -0.2974615	test: -0.0834490	best: -0.0834225 (6347)	total: 1m 17s	remaining: 44.5s
# 6380:	learn: -0.2974576	test: -0.0834099	best: -0.0834099 (6380)	total: 1m 17s	remaining: 44.2s
# 6400:	learn: -0.2974531	test: -0.0833898	best: -0.0833593 (6395)	total: 1m 18s	remaining: 44s
# 6420:	learn: -0.2974495	test: -0.0834655	best: -0.0833593 (6395)	total: 1m 18s	remaining: 43.7s
# 6440:	learn: -0.2974448	test: -0.0834888	best: -0.0833593 (6395)	total: 1m 18s	remaining: 43.5s
# 6460:	learn: -0.2974405	test: -0.0835232	best: -0.0833593 (6395)	total: 1m 18s	remaining: 43.2s
# 6480:	learn: -0.2974359	test: -0.0835051	best: -0.0833593 (6395)	total: 1m 19s	remaining: 43s
# 6500:	learn: -0.2974306	test: -0.0835691	best: -0.0833593 (6395)	total: 1m 19s	remaining: 42.7s
# 6520:	learn: -0.2974268	test: -0.0835731	best: -0.0833593 (6395)	total: 1m 19s	remaining: 42.5s
# 6540:	learn: -0.2974228	test: -0.0835541	best: -0.0833593 (6395)	total: 1m 19s	remaining: 42.3s
# 6560:	learn: -0.2974185	test: -0.0835695	best: -0.0833593 (6395)	total: 1m 20s	remaining: 42s
# 6580:	learn: -0.2974142	test: -0.0835439	best: -0.0833593 (6395)	total: 1m 20s	remaining: 41.8s
# 6600:	learn: -0.2974106	test: -0.0836806	best: -0.0833593 (6395)	total: 1m 20s	remaining: 41.5s
# 6620:	learn: -0.2974072	test: -0.0836526	best: -0.0833593 (6395)	total: 1m 20s	remaining: 41.3s
# 6640:	learn: -0.2974030	test: -0.0836973	best: -0.0833593 (6395)	total: 1m 21s	remaining: 41s
# 6660:	learn: -0.2973992	test: -0.0837151	best: -0.0833593 (6395)	total: 1m 21s	remaining: 40.8s
# 6680:	learn: -0.2973956	test: -0.0837514	best: -0.0833593 (6395)	total: 1m 21s	remaining: 40.5s
# 6700:	learn: -0.2973915	test: -0.0837323	best: -0.0833593 (6395)	total: 1m 21s	remaining: 40.3s
# 6720:	learn: -0.2973873	test: -0.0837762	best: -0.0833593 (6395)	total: 1m 22s	remaining: 40s
# 6740:	learn: -0.2973834	test: -0.0838247	best: -0.0833593 (6395)	total: 1m 22s	remaining: 39.8s
# 6760:	learn: -0.2973794	test: -0.0838605	best: -0.0833593 (6395)	total: 1m 22s	remaining: 39.5s
# 6780:	learn: -0.2973759	test: -0.0838247	best: -0.0833593 (6395)	total: 1m 22s	remaining: 39.3s
# 6800:	learn: -0.2973715	test: -0.0838272	best: -0.0833593 (6395)	total: 1m 23s	remaining: 39.1s
# 6820:	learn: -0.2973679	test: -0.0838334	best: -0.0833593 (6395)	total: 1m 23s	remaining: 38.8s
# 6840:	learn: -0.2973638	test: -0.0838603	best: -0.0833593 (6395)	total: 1m 23s	remaining: 38.6s
# 6860:	learn: -0.2973599	test: -0.0838474	best: -0.0833593 (6395)	total: 1m 23s	remaining: 38.3s
# 6880:	learn: -0.2973558	test: -0.0838327	best: -0.0833593 (6395)	total: 1m 24s	remaining: 38.1s
# 6900:	learn: -0.2973521	test: -0.0838177	best: -0.0833593 (6395)	total: 1m 24s	remaining: 37.8s
# 6920:	learn: -0.2973479	test: -0.0837739	best: -0.0833593 (6395)	total: 1m 24s	remaining: 37.6s
# 6940:	learn: -0.2973445	test: -0.0837751	best: -0.0833593 (6395)	total: 1m 24s	remaining: 37.3s
# 6960:	learn: -0.2973408	test: -0.0837811	best: -0.0833593 (6395)	total: 1m 24s	remaining: 37.1s
# 6980:	learn: -0.2973369	test: -0.0837603	best: -0.0833593 (6395)	total: 1m 25s	remaining: 36.9s
# 7000:	learn: -0.2973329	test: -0.0837883	best: -0.0833593 (6395)	total: 1m 25s	remaining: 36.6s
# 7020:	learn: -0.2973288	test: -0.0837562	best: -0.0833593 (6395)	total: 1m 25s	remaining: 36.4s
# 7040:	learn: -0.2973256	test: -0.0836776	best: -0.0833593 (6395)	total: 1m 25s	remaining: 36.1s
# 7060:	learn: -0.2973222	test: -0.0837388	best: -0.0833593 (6395)	total: 1m 26s	remaining: 35.9s
# 7080:	learn: -0.2973191	test: -0.0837049	best: -0.0833593 (6395)	total: 1m 26s	remaining: 35.6s
# 7100:	learn: -0.2973154	test: -0.0837462	best: -0.0833593 (6395)	total: 1m 26s	remaining: 35.4s
# 7120:	learn: -0.2973119	test: -0.0837530	best: -0.0833593 (6395)	total: 1m 26s	remaining: 35.1s
# 7140:	learn: -0.2973080	test: -0.0838141	best: -0.0833593 (6395)	total: 1m 27s	remaining: 34.9s
# 7160:	learn: -0.2973044	test: -0.0837616	best: -0.0833593 (6395)	total: 1m 27s	remaining: 34.6s
# 7180:	learn: -0.2973009	test: -0.0836695	best: -0.0833593 (6395)	total: 1m 27s	remaining: 34.4s
# 7200:	learn: -0.2972970	test: -0.0836765	best: -0.0833593 (6395)	total: 1m 27s	remaining: 34.2s
# 7220:	learn: -0.2972936	test: -0.0836965	best: -0.0833593 (6395)	total: 1m 28s	remaining: 33.9s
# 7240:	learn: -0.2972891	test: -0.0836405	best: -0.0833593 (6395)	total: 1m 28s	remaining: 33.7s
# 7260:	learn: -0.2972859	test: -0.0836876	best: -0.0833593 (6395)	total: 1m 28s	remaining: 33.4s
# 7280:	learn: -0.2972826	test: -0.0837012	best: -0.0833593 (6395)	total: 1m 28s	remaining: 33.2s
# 7300:	learn: -0.2972793	test: -0.0836852	best: -0.0833593 (6395)	total: 1m 29s	remaining: 32.9s
# 7320:	learn: -0.2972760	test: -0.0837100	best: -0.0833593 (6395)	total: 1m 29s	remaining: 32.7s
# 7340:	learn: -0.2972726	test: -0.0837596	best: -0.0833593 (6395)	total: 1m 29s	remaining: 32.5s
# 7360:	learn: -0.2972693	test: -0.0837806	best: -0.0833593 (6395)	total: 1m 29s	remaining: 32.2s
# 7380:	learn: -0.2972664	test: -0.0837614	best: -0.0833593 (6395)	total: 1m 30s	remaining: 32s
# 7400:	learn: -0.2972626	test: -0.0837708	best: -0.0833593 (6395)	total: 1m 30s	remaining: 31.7s
# 7420:	learn: -0.2972591	test: -0.0837049	best: -0.0833593 (6395)	total: 1m 30s	remaining: 31.5s
# 7440:	learn: -0.2972557	test: -0.0838025	best: -0.0833593 (6395)	total: 1m 30s	remaining: 31.2s
# 7460:	learn: -0.2972527	test: -0.0837827	best: -0.0833593 (6395)	total: 1m 31s	remaining: 31s
# 7480:	learn: -0.2972495	test: -0.0837859	best: -0.0833593 (6395)	total: 1m 31s	remaining: 30.8s
# 7500:	learn: -0.2972464	test: -0.0838510	best: -0.0833593 (6395)	total: 1m 31s	remaining: 30.5s
# 7520:	learn: -0.2972426	test: -0.0838999	best: -0.0833593 (6395)	total: 1m 31s	remaining: 30.3s
# 7540:	learn: -0.2972392	test: -0.0838627	best: -0.0833593 (6395)	total: 1m 32s	remaining: 30s
# 7560:	learn: -0.2972360	test: -0.0838720	best: -0.0833593 (6395)	total: 1m 32s	remaining: 29.8s
# 7580:	learn: -0.2972330	test: -0.0838986	best: -0.0833593 (6395)	total: 1m 32s	remaining: 29.5s
# 7600:	learn: -0.2972303	test: -0.0838962	best: -0.0833593 (6395)	total: 1m 32s	remaining: 29.3s
# 7620:	learn: -0.2972271	test: -0.0838855	best: -0.0833593 (6395)	total: 1m 32s	remaining: 29s
# 7640:	learn: -0.2972241	test: -0.0839350	best: -0.0833593 (6395)	total: 1m 33s	remaining: 28.8s
# 7660:	learn: -0.2972208	test: -0.0839059	best: -0.0833593 (6395)	total: 1m 33s	remaining: 28.5s
# 7680:	learn: -0.2972180	test: -0.0839547	best: -0.0833593 (6395)	total: 1m 33s	remaining: 28.3s
# 7700:	learn: -0.2972148	test: -0.0840069	best: -0.0833593 (6395)	total: 1m 33s	remaining: 28.1s
# 7720:	learn: -0.2972121	test: -0.0840129	best: -0.0833593 (6395)	total: 1m 34s	remaining: 27.8s
# 7740:	learn: -0.2972087	test: -0.0839902	best: -0.0833593 (6395)	total: 1m 34s	remaining: 27.6s
# 7760:	learn: -0.2972054	test: -0.0839429	best: -0.0833593 (6395)	total: 1m 34s	remaining: 27.3s
# 7780:	learn: -0.2972026	test: -0.0839069	best: -0.0833593 (6395)	total: 1m 34s	remaining: 27.1s
# 7800:	learn: -0.2971996	test: -0.0838846	best: -0.0833593 (6395)	total: 1m 35s	remaining: 26.8s
# 7820:	learn: -0.2971965	test: -0.0838381	best: -0.0833593 (6395)	total: 1m 35s	remaining: 26.6s
# 7840:	learn: -0.2971935	test: -0.0838669	best: -0.0833593 (6395)	total: 1m 35s	remaining: 26.3s
# 7860:	learn: -0.2971900	test: -0.0837842	best: -0.0833593 (6395)	total: 1m 35s	remaining: 26.1s
# 7880:	learn: -0.2971871	test: -0.0837646	best: -0.0833593 (6395)	total: 1m 36s	remaining: 25.9s
# 7900:	learn: -0.2971839	test: -0.0836792	best: -0.0833593 (6395)	total: 1m 36s	remaining: 25.6s
# 7920:	learn: -0.2971810	test: -0.0837162	best: -0.0833593 (6395)	total: 1m 36s	remaining: 25.4s
# 7940:	learn: -0.2971782	test: -0.0837137	best: -0.0833593 (6395)	total: 1m 36s	remaining: 25.1s
# 7960:	learn: -0.2971755	test: -0.0837665	best: -0.0833593 (6395)	total: 1m 37s	remaining: 24.9s
# 7980:	learn: -0.2971728	test: -0.0837459	best: -0.0833593 (6395)	total: 1m 37s	remaining: 24.6s
# 8000:	learn: -0.2971704	test: -0.0837484	best: -0.0833593 (6395)	total: 1m 37s	remaining: 24.4s
# 8020:	learn: -0.2971677	test: -0.0837625	best: -0.0833593 (6395)	total: 1m 37s	remaining: 24.1s
# 8040:	learn: -0.2971655	test: -0.0837688	best: -0.0833593 (6395)	total: 1m 38s	remaining: 23.9s
# 8060:	learn: -0.2971628	test: -0.0836995	best: -0.0833593 (6395)	total: 1m 38s	remaining: 23.6s
# 8080:	learn: -0.2971596	test: -0.0836300	best: -0.0833593 (6395)	total: 1m 38s	remaining: 23.4s
# 8100:	learn: -0.2971568	test: -0.0836212	best: -0.0833593 (6395)	total: 1m 38s	remaining: 23.2s
# 8120:	learn: -0.2971540	test: -0.0836559	best: -0.0833593 (6395)	total: 1m 39s	remaining: 22.9s
# 8140:	learn: -0.2971520	test: -0.0836586	best: -0.0833593 (6395)	total: 1m 39s	remaining: 22.7s
# 8160:	learn: -0.2971494	test: -0.0835467	best: -0.0833593 (6395)	total: 1m 39s	remaining: 22.4s
# 8180:	learn: -0.2971472	test: -0.0836073	best: -0.0833593 (6395)	total: 1m 39s	remaining: 22.2s
# 8200:	learn: -0.2971444	test: -0.0835689	best: -0.0833593 (6395)	total: 1m 39s	remaining: 21.9s
# 8220:	learn: -0.2971415	test: -0.0835875	best: -0.0833593 (6395)	total: 1m 40s	remaining: 21.7s
# 8240:	learn: -0.2971391	test: -0.0835785	best: -0.0833593 (6395)	total: 1m 40s	remaining: 21.4s
# 8260:	learn: -0.2971361	test: -0.0835499	best: -0.0833593 (6395)	total: 1m 40s	remaining: 21.2s
# 8280:	learn: -0.2971336	test: -0.0835390	best: -0.0833593 (6395)	total: 1m 40s	remaining: 21s
# 8300:	learn: -0.2971309	test: -0.0835610	best: -0.0833593 (6395)	total: 1m 41s	remaining: 20.7s
# 8320:	learn: -0.2971284	test: -0.0835506	best: -0.0833593 (6395)	total: 1m 41s	remaining: 20.5s
# 	Note: model has different eval_metric than default.
# 	-0.0834	 = Validation score   (-soft_log_loss)
# 	170.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# bestTest = -0.08335927158
# bestIteration = 6395
#
# Shrink model to first 6396 iterations.
# Fitting model: NeuralNetTorch_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.0162	 = Validation score   (-soft_log_loss)
# 	15.21s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.0162	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL        1.0  soft_log_loss       0.001002    1.295770                0.001002           1.295770            1       True        161
# 1             CatBoost_DSTL        1.0  soft_log_loss       0.003013  170.261275                0.003013         170.261275            1       True        163
# 2       NeuralNetTorch_DSTL        1.0  soft_log_loss       0.020633   15.209923                0.020633          15.209923            1       True        164
# 3  WeightedEnsemble_L2_DSTL        1.0  soft_log_loss       0.021633   15.248049                0.001000           0.038127            2       True        165
# 4      RandomForestMSE_DSTL        1.0  soft_log_loss       0.042643    0.798809                0.042643           0.798809            1       True        162
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                         model  score_test  score_val    eval_metric  \
# 2               LightGBM_DSTL    0.882353   1.000000  soft_log_loss
# 12        NeuralNetTorch_DSTL    0.823529   1.000000  soft_log_loss
# 13   WeightedEnsemble_L2_DSTL    0.823529   1.000000  soft_log_loss
# 25              CatBoost_DSTL    0.823529   1.000000  soft_log_loss
# 85       RandomForestMSE_DSTL    0.764706   1.000000  soft_log_loss
# ..                        ...         ...        ...            ...
# 160       LightGBM_r96_BAG_L1    0.294118   0.275862       accuracy
# 161      LightGBM_r135_BAG_L1    0.294118   0.275862       accuracy
# 163       LightGBM_r96_BAG_L2    0.294118   0.275862       accuracy
# 164      LightGBM_r130_BAG_L2    0.294118   0.275862       accuracy
# 162   RandomForest_r34_BAG_L1    0.294118   0.011494       accuracy
#
#      pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 2          0.008596       0.001002    1.295770                 0.008596
# 12         0.017568       0.020633   15.209923                 0.017568
# 13         0.018567       0.021633   15.248049                 0.000999
# 25         0.045118       0.003013  170.261275                 0.045118
# 85         0.069655       0.042643    0.798809                 0.069655
# ..              ...            ...         ...                      ...
# 160        0.009000       0.008276    2.524881                 0.009000
# 161        0.010998       0.009888    2.690822                 0.010998
# 163        9.475014       7.584771  927.191799                 0.028761
# 164        9.475160       7.583158  927.087389                 0.028907
# 162        0.097894       0.082655    1.470538                 0.097894
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 2                  0.001002           1.295770            1       True
# 12                 0.020633          15.209923            1       True
# 13                 0.001000           0.038127            2       True
# 25                 0.003013         170.261275            1       True
# 85                 0.042643           0.798809            1       True
# ..                      ...                ...          ...        ...
# 160                0.008276           2.524881            1       True
# 161                0.009888           2.690822            1       True
# 163                0.026804           2.989000            2       True
# 164                0.025191           2.884591            2       True
# 162                0.082655           1.470538            1       True
#
#      fit_order
# 2          161
# 12         164
# 13         165
# 25         163
# 85         162
# ..         ...
# 160         19
# 161         82
# 163        128
# 164        140
# 162         60
#
# [165 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.8823529411764706
# Evaluations on test data:
# {
#     "accuracy": 0.8823529411764706,
#     "balanced_accuracy": 0.85,
#     "mcc": 0.8152173913043478
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.8,
#         "recall": 0.8,
#         "f1-score": 0.8,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.75,
#         "recall": 0.75,
#         "f1-score": 0.75,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 8.0
#     },
#     "accuracy": 0.8823529411764706,
#     "macro avg": {
#         "precision": 0.85,
#         "recall": 0.85,
#         "f1-score": 0.85,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.8823529411764706,
#         "recall": 0.8823529411764706,
#         "f1-score": 0.8823529411764706,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.8823529411764706, 'balanced_accuracy': 0.85, 'mcc': 0.8152173913043478, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              4
# Exc L3-4 RORB CARM1P1                                      1
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      0
# Exc L3-4 RORB CARM1P1                              3                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.8, 'recall': 0.8, 'f1-score': 0.8, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0}, 'accuracy': 0.8823529411764706, 'macro avg': {'precision': 0.85, 'recall': 0.85, 'f1-score': 0.85, 'support': 17.0}, 'weighted avg': {'precision': 0.8823529411764706, 'recall': 0.8823529411764706, 'f1-score': 0.8823529411764706, 'support': 17.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.80      0.80      0.80         5
#         Exc L3-4 RORB CARM1P1       0.75      0.75      0.75         4
#         Exc L3-5 RORB COL22A1       1.00      1.00      1.00         8
#
#                      accuracy                           0.88        17
#                     macro avg       0.85      0.85      0.85        17
#                  weighted avg       0.88      0.88      0.88        17

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.316471
# [100]	valid_set's soft_log_loss: -0.16232
# [150]	valid_set's soft_log_loss: -0.13402
# [200]	valid_set's soft_log_loss: -0.124167
# [250]	valid_set's soft_log_loss: -0.116185
# [300]	valid_set's soft_log_loss: -0.122245
# [350]	valid_set's soft_log_loss: -0.124212
# [400]	valid_set's soft_log_loss: -0.121454
# [450]	valid_set's soft_log_loss: -0.12157
# [500]	valid_set's soft_log_loss: -0.122612
# [550]	valid_set's soft_log_loss: -0.122187
# 	Note: model has different eval_metric than default.
# 	-0.1162	 = Validation score   (-soft_log_loss)
# 	1.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.1993	 = Validation score   (-soft_log_loss)
# 	0.77s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0627177	test: -1.0660591	best: -1.0660591 (0)	total: 549ms	remaining: 1h 31m 32s
# 20:	learn: -0.6453197	test: -0.7323055	best: -0.7323055 (20)	total: 767ms	remaining: 6m 4s
# 40:	learn: -0.4745619	test: -0.5438454	best: -0.5438454 (40)	total: 996ms	remaining: 4m 1s
# 60:	learn: -0.3962175	test: -0.4407848	best: -0.4407848 (60)	total: 1.23s	remaining: 3m 19s
# 80:	learn: -0.3532464	test: -0.3733488	best: -0.3733488 (80)	total: 1.43s	remaining: 2m 54s
# 100:	learn: -0.3247373	test: -0.3280281	best: -0.3280281 (100)	total: 1.62s	remaining: 2m 38s
# 120:	learn: -0.3047368	test: -0.2912847	best: -0.2912847 (120)	total: 1.83s	remaining: 2m 29s
# 140:	learn: -0.2902687	test: -0.2612089	best: -0.2612089 (140)	total: 2.04s	remaining: 2m 22s
# 160:	learn: -0.2807755	test: -0.2440885	best: -0.2440885 (160)	total: 2.27s	remaining: 2m 18s
# 180:	learn: -0.2735067	test: -0.2318093	best: -0.2318093 (180)	total: 2.51s	remaining: 2m 16s
# 200:	learn: -0.2668135	test: -0.2208094	best: -0.2207214 (199)	total: 2.76s	remaining: 2m 14s
# 220:	learn: -0.2615728	test: -0.2103328	best: -0.2103328 (220)	total: 2.97s	remaining: 2m 11s
# 240:	learn: -0.2572260	test: -0.2015061	best: -0.2015061 (240)	total: 3.21s	remaining: 2m 10s
# 260:	learn: -0.2535053	test: -0.1927454	best: -0.1927454 (260)	total: 3.43s	remaining: 2m 7s
# 280:	learn: -0.2505148	test: -0.1865827	best: -0.1865827 (280)	total: 3.65s	remaining: 2m 6s
# 300:	learn: -0.2474099	test: -0.1802682	best: -0.1802682 (300)	total: 3.89s	remaining: 2m 5s
# 320:	learn: -0.2453856	test: -0.1769139	best: -0.1769139 (320)	total: 4.08s	remaining: 2m 3s
# 340:	learn: -0.2432122	test: -0.1720527	best: -0.1720527 (340)	total: 4.28s	remaining: 2m 1s
# 360:	learn: -0.2411419	test: -0.1680625	best: -0.1680625 (360)	total: 4.53s	remaining: 2m
# 380:	learn: -0.2394333	test: -0.1654469	best: -0.1654469 (380)	total: 4.78s	remaining: 2m
# 400:	learn: -0.2380362	test: -0.1624963	best: -0.1624963 (400)	total: 5.02s	remaining: 2m
# 420:	learn: -0.2368918	test: -0.1603665	best: -0.1603665 (420)	total: 5.22s	remaining: 1m 58s
# 440:	learn: -0.2358716	test: -0.1588665	best: -0.1588213 (438)	total: 5.49s	remaining: 1m 58s
# 460:	learn: -0.2347791	test: -0.1564197	best: -0.1564197 (460)	total: 5.7s	remaining: 1m 58s
# 480:	learn: -0.2337797	test: -0.1524883	best: -0.1524883 (480)	total: 5.95s	remaining: 1m 57s
# 500:	learn: -0.2327411	test: -0.1501623	best: -0.1499190 (498)	total: 6.17s	remaining: 1m 57s
# 520:	learn: -0.2319602	test: -0.1493758	best: -0.1492403 (512)	total: 6.38s	remaining: 1m 56s
# 540:	learn: -0.2310783	test: -0.1472142	best: -0.1470478 (538)	total: 6.57s	remaining: 1m 54s
# 560:	learn: -0.2305420	test: -0.1466859	best: -0.1466859 (560)	total: 6.76s	remaining: 1m 53s
# 580:	learn: -0.2298007	test: -0.1459046	best: -0.1457234 (570)	total: 6.99s	remaining: 1m 53s
# 600:	learn: -0.2291487	test: -0.1440161	best: -0.1440161 (600)	total: 7.22s	remaining: 1m 52s
# 620:	learn: -0.2284898	test: -0.1414194	best: -0.1414194 (620)	total: 7.43s	remaining: 1m 52s
# 640:	learn: -0.2279275	test: -0.1407229	best: -0.1407229 (640)	total: 7.64s	remaining: 1m 51s
# 660:	learn: -0.2274576	test: -0.1398003	best: -0.1396362 (658)	total: 7.88s	remaining: 1m 51s
# 680:	learn: -0.2269207	test: -0.1403574	best: -0.1394616 (663)	total: 8.1s	remaining: 1m 50s
# 700:	learn: -0.2265022	test: -0.1387583	best: -0.1387002 (698)	total: 8.32s	remaining: 1m 50s
# 720:	learn: -0.2260203	test: -0.1370361	best: -0.1370361 (720)	total: 8.57s	remaining: 1m 50s
# 740:	learn: -0.2255990	test: -0.1361990	best: -0.1361990 (740)	total: 8.79s	remaining: 1m 49s
# 760:	learn: -0.2252803	test: -0.1355052	best: -0.1354063 (755)	total: 8.98s	remaining: 1m 48s
# 780:	learn: -0.2249066	test: -0.1344255	best: -0.1344255 (780)	total: 9.18s	remaining: 1m 48s
# 800:	learn: -0.2245547	test: -0.1330915	best: -0.1330915 (800)	total: 9.44s	remaining: 1m 48s
# 820:	learn: -0.2242450	test: -0.1326905	best: -0.1322564 (813)	total: 9.68s	remaining: 1m 48s
# 840:	learn: -0.2238906	test: -0.1312835	best: -0.1312835 (840)	total: 9.89s	remaining: 1m 47s
# 860:	learn: -0.2235927	test: -0.1306578	best: -0.1304595 (859)	total: 10.1s	remaining: 1m 47s
# 880:	learn: -0.2233201	test: -0.1298651	best: -0.1298651 (880)	total: 10.4s	remaining: 1m 47s
# 900:	learn: -0.2230619	test: -0.1293961	best: -0.1293961 (900)	total: 10.6s	remaining: 1m 47s
# 920:	learn: -0.2228119	test: -0.1292928	best: -0.1292220 (916)	total: 10.9s	remaining: 1m 47s
# 940:	learn: -0.2225581	test: -0.1288339	best: -0.1288339 (940)	total: 11.1s	remaining: 1m 46s
# 960:	learn: -0.2222912	test: -0.1282702	best: -0.1282650 (959)	total: 11.3s	remaining: 1m 46s
# 980:	learn: -0.2220794	test: -0.1279865	best: -0.1279396 (975)	total: 11.5s	remaining: 1m 45s
# 1000:	learn: -0.2218732	test: -0.1277023	best: -0.1275364 (994)	total: 11.7s	remaining: 1m 45s
# 1020:	learn: -0.2217015	test: -0.1268677	best: -0.1268569 (1019)	total: 12s	remaining: 1m 45s
# 1040:	learn: -0.2215056	test: -0.1263548	best: -0.1262443 (1039)	total: 12.2s	remaining: 1m 44s
# 1060:	learn: -0.2213594	test: -0.1259256	best: -0.1259256 (1060)	total: 12.4s	remaining: 1m 44s
# 1080:	learn: -0.2211667	test: -0.1251949	best: -0.1251949 (1080)	total: 12.7s	remaining: 1m 44s
# 1100:	learn: -0.2209836	test: -0.1247484	best: -0.1247484 (1100)	total: 12.9s	remaining: 1m 44s
# 1120:	learn: -0.2207883	test: -0.1241367	best: -0.1241367 (1120)	total: 13.1s	remaining: 1m 43s
# 1140:	learn: -0.2206172	test: -0.1236079	best: -0.1236079 (1140)	total: 13.4s	remaining: 1m 43s
# 1160:	learn: -0.2204694	test: -0.1231127	best: -0.1231127 (1160)	total: 13.6s	remaining: 1m 43s
# 1180:	learn: -0.2203171	test: -0.1229690	best: -0.1228689 (1179)	total: 13.8s	remaining: 1m 42s
# 1200:	learn: -0.2201614	test: -0.1228092	best: -0.1228060 (1198)	total: 14s	remaining: 1m 42s
# 1220:	learn: -0.2200403	test: -0.1229837	best: -0.1227093 (1203)	total: 14.2s	remaining: 1m 42s
# 1240:	learn: -0.2199175	test: -0.1230331	best: -0.1227093 (1203)	total: 14.4s	remaining: 1m 41s
# 1260:	learn: -0.2197732	test: -0.1227792	best: -0.1227093 (1203)	total: 14.7s	remaining: 1m 41s
# 1280:	learn: -0.2196402	test: -0.1224756	best: -0.1224639 (1279)	total: 14.9s	remaining: 1m 41s
# 1300:	learn: -0.2195148	test: -0.1221226	best: -0.1220775 (1298)	total: 15.1s	remaining: 1m 41s
# 1320:	learn: -0.2193948	test: -0.1224434	best: -0.1220769 (1301)	total: 15.4s	remaining: 1m 40s
# 1340:	learn: -0.2192864	test: -0.1220809	best: -0.1220471 (1339)	total: 15.6s	remaining: 1m 40s
# 1360:	learn: -0.2191797	test: -0.1216739	best: -0.1216426 (1358)	total: 15.8s	remaining: 1m 40s
# 1380:	learn: -0.2190814	test: -0.1208674	best: -0.1208674 (1380)	total: 16s	remaining: 1m 39s
# 1400:	learn: -0.2189788	test: -0.1205929	best: -0.1203984 (1387)	total: 16.2s	remaining: 1m 39s
# 1420:	learn: -0.2188798	test: -0.1200421	best: -0.1199626 (1418)	total: 16.5s	remaining: 1m 39s
# 1440:	learn: -0.2187648	test: -0.1193697	best: -0.1193697 (1440)	total: 16.7s	remaining: 1m 39s
# 1460:	learn: -0.2186827	test: -0.1194029	best: -0.1193349 (1445)	total: 16.9s	remaining: 1m 38s
# 1480:	learn: -0.2185953	test: -0.1193636	best: -0.1193349 (1445)	total: 17.2s	remaining: 1m 38s
# 1500:	learn: -0.2185165	test: -0.1189229	best: -0.1189229 (1500)	total: 17.4s	remaining: 1m 38s
# 1520:	learn: -0.2184293	test: -0.1186712	best: -0.1186009 (1518)	total: 17.6s	remaining: 1m 38s
# 1540:	learn: -0.2183576	test: -0.1183220	best: -0.1183220 (1540)	total: 17.8s	remaining: 1m 37s
# 1560:	learn: -0.2182758	test: -0.1176984	best: -0.1176984 (1560)	total: 18s	remaining: 1m 37s
# 1580:	learn: -0.2182057	test: -0.1175430	best: -0.1175050 (1577)	total: 18.3s	remaining: 1m 37s
# 1600:	learn: -0.2181233	test: -0.1169212	best: -0.1169212 (1600)	total: 18.5s	remaining: 1m 36s
# 1620:	learn: -0.2180577	test: -0.1171897	best: -0.1169212 (1600)	total: 18.7s	remaining: 1m 36s
# 1640:	learn: -0.2179984	test: -0.1170925	best: -0.1169212 (1600)	total: 19s	remaining: 1m 36s
# 1660:	learn: -0.2179380	test: -0.1171527	best: -0.1169212 (1600)	total: 19.2s	remaining: 1m 36s
# 1680:	learn: -0.2178730	test: -0.1170503	best: -0.1169212 (1600)	total: 19.4s	remaining: 1m 36s
# 1700:	learn: -0.2178115	test: -0.1172715	best: -0.1169212 (1600)	total: 19.7s	remaining: 1m 36s
# 1720:	learn: -0.2177486	test: -0.1171646	best: -0.1169195 (1708)	total: 19.9s	remaining: 1m 35s
# 1740:	learn: -0.2176965	test: -0.1170117	best: -0.1169195 (1708)	total: 20.1s	remaining: 1m 35s
# 1760:	learn: -0.2176335	test: -0.1171298	best: -0.1169195 (1708)	total: 20.3s	remaining: 1m 35s
# 1780:	learn: -0.2175730	test: -0.1168912	best: -0.1167754 (1775)	total: 20.5s	remaining: 1m 34s
# 1800:	learn: -0.2175161	test: -0.1169707	best: -0.1167754 (1775)	total: 20.7s	remaining: 1m 34s
# 1820:	learn: -0.2174600	test: -0.1168531	best: -0.1167754 (1775)	total: 21s	remaining: 1m 34s
# 1840:	learn: -0.2173966	test: -0.1168313	best: -0.1167754 (1775)	total: 21.2s	remaining: 1m 34s
# 1860:	learn: -0.2173415	test: -0.1167047	best: -0.1166367 (1854)	total: 21.5s	remaining: 1m 33s
# 1880:	learn: -0.2172859	test: -0.1165740	best: -0.1164700 (1865)	total: 21.7s	remaining: 1m 33s
# 1900:	learn: -0.2172408	test: -0.1165152	best: -0.1164336 (1893)	total: 21.9s	remaining: 1m 33s
# 1920:	learn: -0.2171873	test: -0.1162695	best: -0.1162695 (1920)	total: 22.1s	remaining: 1m 32s
# 1940:	learn: -0.2171444	test: -0.1158695	best: -0.1158683 (1938)	total: 22.3s	remaining: 1m 32s
# 1960:	learn: -0.2170974	test: -0.1155146	best: -0.1155146 (1960)	total: 22.6s	remaining: 1m 32s
# 1980:	learn: -0.2170458	test: -0.1152621	best: -0.1152621 (1980)	total: 22.8s	remaining: 1m 32s
# 2000:	learn: -0.2169965	test: -0.1151142	best: -0.1149833 (1996)	total: 23s	remaining: 1m 32s
# 2020:	learn: -0.2169528	test: -0.1150991	best: -0.1149833 (1996)	total: 23.3s	remaining: 1m 31s
# 2040:	learn: -0.2169066	test: -0.1152066	best: -0.1149833 (1996)	total: 23.5s	remaining: 1m 31s
# 2060:	learn: -0.2168578	test: -0.1152811	best: -0.1149833 (1996)	total: 23.7s	remaining: 1m 31s
# 2080:	learn: -0.2168122	test: -0.1152626	best: -0.1149833 (1996)	total: 23.9s	remaining: 1m 30s
# 2100:	learn: -0.2167814	test: -0.1150671	best: -0.1149833 (1996)	total: 24.1s	remaining: 1m 30s
# 2120:	learn: -0.2167440	test: -0.1149429	best: -0.1149083 (2109)	total: 24.3s	remaining: 1m 30s
# 2140:	learn: -0.2167111	test: -0.1149918	best: -0.1148650 (2131)	total: 24.5s	remaining: 1m 30s
# 2160:	learn: -0.2166780	test: -0.1150386	best: -0.1148650 (2131)	total: 24.8s	remaining: 1m 29s
# 2180:	learn: -0.2166390	test: -0.1149597	best: -0.1148031 (2171)	total: 25s	remaining: 1m 29s
# 2200:	learn: -0.2166060	test: -0.1145924	best: -0.1145924 (2200)	total: 25.3s	remaining: 1m 29s
# 2220:	learn: -0.2165720	test: -0.1143720	best: -0.1143513 (2219)	total: 25.5s	remaining: 1m 29s
# 2240:	learn: -0.2165315	test: -0.1141159	best: -0.1141159 (2240)	total: 25.7s	remaining: 1m 29s
# 2260:	learn: -0.2164992	test: -0.1142868	best: -0.1140937 (2241)	total: 25.9s	remaining: 1m 28s
# 2280:	learn: -0.2164630	test: -0.1143169	best: -0.1140937 (2241)	total: 26.1s	remaining: 1m 28s
# 2300:	learn: -0.2164208	test: -0.1144375	best: -0.1140937 (2241)	total: 26.4s	remaining: 1m 28s
# 2320:	learn: -0.2163880	test: -0.1144548	best: -0.1140937 (2241)	total: 26.6s	remaining: 1m 27s
# 2340:	learn: -0.2163535	test: -0.1144758	best: -0.1140937 (2241)	total: 26.9s	remaining: 1m 27s
# 2360:	learn: -0.2163177	test: -0.1144073	best: -0.1140937 (2241)	total: 27.1s	remaining: 1m 27s
# 2380:	learn: -0.2162842	test: -0.1143998	best: -0.1140937 (2241)	total: 27.3s	remaining: 1m 27s
# 2400:	learn: -0.2162526	test: -0.1141925	best: -0.1140937 (2241)	total: 27.6s	remaining: 1m 27s
# 2420:	learn: -0.2162280	test: -0.1140116	best: -0.1139730 (2416)	total: 27.8s	remaining: 1m 27s
# 2440:	learn: -0.2161999	test: -0.1139783	best: -0.1138683 (2430)	total: 28s	remaining: 1m 26s
# 2460:	learn: -0.2161737	test: -0.1138139	best: -0.1138047 (2456)	total: 28.2s	remaining: 1m 26s
# 2480:	learn: -0.2161469	test: -0.1138484	best: -0.1137278 (2469)	total: 28.5s	remaining: 1m 26s
# 2500:	learn: -0.2161157	test: -0.1138135	best: -0.1137278 (2469)	total: 28.7s	remaining: 1m 26s
# 2520:	learn: -0.2160903	test: -0.1137258	best: -0.1136956 (2519)	total: 29s	remaining: 1m 25s
# 2540:	learn: -0.2160606	test: -0.1133341	best: -0.1133341 (2540)	total: 29.2s	remaining: 1m 25s
# 2560:	learn: -0.2160395	test: -0.1132389	best: -0.1132176 (2559)	total: 29.4s	remaining: 1m 25s
# 2580:	learn: -0.2160135	test: -0.1131612	best: -0.1131612 (2580)	total: 29.6s	remaining: 1m 25s
# 2600:	learn: -0.2159884	test: -0.1130564	best: -0.1130413 (2592)	total: 29.8s	remaining: 1m 24s
# 2620:	learn: -0.2159625	test: -0.1127215	best: -0.1126935 (2618)	total: 30.1s	remaining: 1m 24s
# 2640:	learn: -0.2159393	test: -0.1128493	best: -0.1126935 (2618)	total: 30.3s	remaining: 1m 24s
# 2660:	learn: -0.2159106	test: -0.1128809	best: -0.1126935 (2618)	total: 30.6s	remaining: 1m 24s
# 2680:	learn: -0.2158880	test: -0.1127767	best: -0.1126935 (2618)	total: 30.8s	remaining: 1m 24s
# 2700:	learn: -0.2158672	test: -0.1126859	best: -0.1126707 (2699)	total: 31s	remaining: 1m 23s
# 2720:	learn: -0.2158430	test: -0.1124078	best: -0.1123952 (2719)	total: 31.3s	remaining: 1m 23s
# 2740:	learn: -0.2158202	test: -0.1124852	best: -0.1123952 (2719)	total: 31.5s	remaining: 1m 23s
# 2760:	learn: -0.2157949	test: -0.1124763	best: -0.1123952 (2719)	total: 31.7s	remaining: 1m 23s
# 2780:	learn: -0.2157756	test: -0.1124526	best: -0.1123800 (2772)	total: 31.9s	remaining: 1m 22s
# 2800:	learn: -0.2157555	test: -0.1125385	best: -0.1123800 (2772)	total: 32.1s	remaining: 1m 22s
# 2820:	learn: -0.2157327	test: -0.1126791	best: -0.1123800 (2772)	total: 32.4s	remaining: 1m 22s
# 2840:	learn: -0.2157103	test: -0.1125510	best: -0.1123800 (2772)	total: 32.6s	remaining: 1m 22s
# 2860:	learn: -0.2156895	test: -0.1124285	best: -0.1123800 (2772)	total: 32.9s	remaining: 1m 22s
# 2880:	learn: -0.2156709	test: -0.1126003	best: -0.1123800 (2772)	total: 33.1s	remaining: 1m 21s
# 2900:	learn: -0.2156495	test: -0.1124856	best: -0.1123800 (2772)	total: 33.4s	remaining: 1m 21s
# 2920:	learn: -0.2156292	test: -0.1123818	best: -0.1123274 (2915)	total: 33.6s	remaining: 1m 21s
# 2940:	learn: -0.2156073	test: -0.1123985	best: -0.1123274 (2915)	total: 33.8s	remaining: 1m 21s
# 2960:	learn: -0.2155923	test: -0.1124381	best: -0.1123274 (2915)	total: 34.1s	remaining: 1m 21s
# 2980:	learn: -0.2155754	test: -0.1124054	best: -0.1123274 (2915)	total: 34.3s	remaining: 1m 20s
# 3000:	learn: -0.2155590	test: -0.1121995	best: -0.1121708 (2988)	total: 34.6s	remaining: 1m 20s
# 3020:	learn: -0.2155429	test: -0.1119837	best: -0.1119497 (3018)	total: 34.8s	remaining: 1m 20s
# 3040:	learn: -0.2155263	test: -0.1120292	best: -0.1118304 (3034)	total: 35s	remaining: 1m 20s
# 3060:	learn: -0.2155085	test: -0.1119398	best: -0.1118304 (3034)	total: 35.2s	remaining: 1m 19s
# 3080:	learn: -0.2154934	test: -0.1119723	best: -0.1118304 (3034)	total: 35.5s	remaining: 1m 19s
# 3100:	learn: -0.2154767	test: -0.1120386	best: -0.1118304 (3034)	total: 35.7s	remaining: 1m 19s
# 3120:	learn: -0.2154574	test: -0.1118926	best: -0.1118304 (3034)	total: 36s	remaining: 1m 19s
# 3140:	learn: -0.2154398	test: -0.1118395	best: -0.1117717 (3129)	total: 36.2s	remaining: 1m 19s
# 3160:	learn: -0.2154230	test: -0.1117723	best: -0.1117697 (3159)	total: 36.4s	remaining: 1m 18s
# 3180:	learn: -0.2154079	test: -0.1118339	best: -0.1117674 (3165)	total: 36.7s	remaining: 1m 18s
# 3200:	learn: -0.2153910	test: -0.1117147	best: -0.1117147 (3200)	total: 36.9s	remaining: 1m 18s
# 3220:	learn: -0.2153773	test: -0.1117508	best: -0.1116554 (3209)	total: 37.1s	remaining: 1m 18s
# 3240:	learn: -0.2153619	test: -0.1117289	best: -0.1116554 (3209)	total: 37.3s	remaining: 1m 17s
# 3260:	learn: -0.2153502	test: -0.1117240	best: -0.1116554 (3209)	total: 37.6s	remaining: 1m 17s
# 3280:	learn: -0.2153344	test: -0.1116311	best: -0.1116311 (3280)	total: 37.8s	remaining: 1m 17s
# 3300:	learn: -0.2153218	test: -0.1116949	best: -0.1116050 (3284)	total: 38s	remaining: 1m 17s
# 3320:	learn: -0.2153076	test: -0.1118341	best: -0.1116050 (3284)	total: 38.3s	remaining: 1m 16s
# 3340:	learn: -0.2152925	test: -0.1117843	best: -0.1116050 (3284)	total: 38.5s	remaining: 1m 16s
# 3360:	learn: -0.2152776	test: -0.1117623	best: -0.1116050 (3284)	total: 38.7s	remaining: 1m 16s
# 3380:	learn: -0.2152630	test: -0.1117658	best: -0.1116050 (3284)	total: 38.9s	remaining: 1m 16s
# 3400:	learn: -0.2152499	test: -0.1116376	best: -0.1116050 (3284)	total: 39.1s	remaining: 1m 15s
# 3420:	learn: -0.2152342	test: -0.1114451	best: -0.1113918 (3414)	total: 39.4s	remaining: 1m 15s
# 3440:	learn: -0.2152201	test: -0.1114162	best: -0.1113381 (3431)	total: 39.6s	remaining: 1m 15s
# 3460:	learn: -0.2152070	test: -0.1114120	best: -0.1113348 (3449)	total: 39.8s	remaining: 1m 15s
# 3480:	learn: -0.2151954	test: -0.1113093	best: -0.1113093 (3480)	total: 40s	remaining: 1m 14s
# 3500:	learn: -0.2151833	test: -0.1112254	best: -0.1112093 (3494)	total: 40.2s	remaining: 1m 14s
# 3520:	learn: -0.2151680	test: -0.1113322	best: -0.1112051 (3503)	total: 40.4s	remaining: 1m 14s
# 3540:	learn: -0.2151568	test: -0.1112804	best: -0.1112051 (3503)	total: 40.7s	remaining: 1m 14s
# 3560:	learn: -0.2151452	test: -0.1112840	best: -0.1112051 (3503)	total: 40.9s	remaining: 1m 14s
# 3580:	learn: -0.2151334	test: -0.1112973	best: -0.1112051 (3503)	total: 41.2s	remaining: 1m 13s
# 3600:	learn: -0.2151206	test: -0.1112191	best: -0.1111337 (3594)	total: 41.4s	remaining: 1m 13s
# 3620:	learn: -0.2151097	test: -0.1110211	best: -0.1110197 (3619)	total: 41.6s	remaining: 1m 13s
# 3640:	learn: -0.2151000	test: -0.1110024	best: -0.1109939 (3621)	total: 41.9s	remaining: 1m 13s
# 3660:	learn: -0.2150891	test: -0.1109314	best: -0.1109314 (3660)	total: 42.1s	remaining: 1m 12s
# 3680:	learn: -0.2150783	test: -0.1110369	best: -0.1109301 (3662)	total: 42.3s	remaining: 1m 12s
# 3700:	learn: -0.2150666	test: -0.1109301	best: -0.1108891 (3698)	total: 42.6s	remaining: 1m 12s
# 3720:	learn: -0.2150557	test: -0.1110074	best: -0.1108891 (3698)	total: 42.8s	remaining: 1m 12s
# 3740:	learn: -0.2150473	test: -0.1109487	best: -0.1108891 (3698)	total: 43s	remaining: 1m 11s
# 3760:	learn: -0.2150347	test: -0.1107034	best: -0.1106958 (3752)	total: 43.3s	remaining: 1m 11s
# 3780:	learn: -0.2150254	test: -0.1106293	best: -0.1106092 (3779)	total: 43.5s	remaining: 1m 11s
# 3800:	learn: -0.2150141	test: -0.1104707	best: -0.1104707 (3800)	total: 43.7s	remaining: 1m 11s
# 3820:	learn: -0.2150040	test: -0.1105728	best: -0.1104351 (3803)	total: 43.9s	remaining: 1m 11s
# 3840:	learn: -0.2149917	test: -0.1105989	best: -0.1104351 (3803)	total: 44.2s	remaining: 1m 10s
# 3860:	learn: -0.2149818	test: -0.1105390	best: -0.1104351 (3803)	total: 44.4s	remaining: 1m 10s
# 3880:	learn: -0.2149727	test: -0.1106564	best: -0.1104351 (3803)	total: 44.7s	remaining: 1m 10s
# 3900:	learn: -0.2149632	test: -0.1105639	best: -0.1104351 (3803)	total: 44.9s	remaining: 1m 10s
# 3920:	learn: -0.2149526	test: -0.1105115	best: -0.1104351 (3803)	total: 45.1s	remaining: 1m 9s
# 3940:	learn: -0.2149421	test: -0.1104584	best: -0.1104048 (3933)	total: 45.3s	remaining: 1m 9s
# 3960:	learn: -0.2149316	test: -0.1104062	best: -0.1103952 (3957)	total: 45.5s	remaining: 1m 9s
# 3980:	learn: -0.2149217	test: -0.1103562	best: -0.1103502 (3979)	total: 45.8s	remaining: 1m 9s
# 4000:	learn: -0.2149114	test: -0.1103509	best: -0.1102911 (3995)	total: 46s	remaining: 1m 8s
# 4020:	learn: -0.2149021	test: -0.1104122	best: -0.1102681 (4010)	total: 46.2s	remaining: 1m 8s
# 4040:	learn: -0.2148940	test: -0.1103614	best: -0.1102681 (4010)	total: 46.4s	remaining: 1m 8s
# 4060:	learn: -0.2148829	test: -0.1104707	best: -0.1102681 (4010)	total: 46.7s	remaining: 1m 8s
# 4080:	learn: -0.2148740	test: -0.1104515	best: -0.1102681 (4010)	total: 46.8s	remaining: 1m 7s
# 4100:	learn: -0.2148651	test: -0.1105516	best: -0.1102681 (4010)	total: 47.1s	remaining: 1m 7s
# 4120:	learn: -0.2148565	test: -0.1105769	best: -0.1102681 (4010)	total: 47.3s	remaining: 1m 7s
# 4140:	learn: -0.2148488	test: -0.1105603	best: -0.1102681 (4010)	total: 47.6s	remaining: 1m 7s
# 4160:	learn: -0.2148375	test: -0.1103931	best: -0.1102681 (4010)	total: 47.8s	remaining: 1m 7s
# 4180:	learn: -0.2148303	test: -0.1103821	best: -0.1102681 (4010)	total: 48s	remaining: 1m 6s
# 4200:	learn: -0.2148217	test: -0.1103422	best: -0.1102681 (4010)	total: 48.2s	remaining: 1m 6s
# 4220:	learn: -0.2148122	test: -0.1103362	best: -0.1102681 (4010)	total: 48.4s	remaining: 1m 6s
# 4240:	learn: -0.2148048	test: -0.1101643	best: -0.1101643 (4240)	total: 48.7s	remaining: 1m 6s
# 4260:	learn: -0.2147963	test: -0.1101682	best: -0.1101043 (4246)	total: 48.9s	remaining: 1m 5s
# 4280:	learn: -0.2147888	test: -0.1101622	best: -0.1101043 (4246)	total: 49.1s	remaining: 1m 5s
# 4300:	learn: -0.2147805	test: -0.1101538	best: -0.1101043 (4246)	total: 49.4s	remaining: 1m 5s
# 4320:	learn: -0.2147728	test: -0.1102858	best: -0.1101043 (4246)	total: 49.6s	remaining: 1m 5s
# 4340:	learn: -0.2147635	test: -0.1101910	best: -0.1101043 (4246)	total: 49.8s	remaining: 1m 4s
# 4360:	learn: -0.2147551	test: -0.1101395	best: -0.1100974 (4343)	total: 50s	remaining: 1m 4s
# 4380:	learn: -0.2147469	test: -0.1101600	best: -0.1100974 (4343)	total: 50.2s	remaining: 1m 4s
# 4400:	learn: -0.2147408	test: -0.1101451	best: -0.1100974 (4343)	total: 50.5s	remaining: 1m 4s
# 4420:	learn: -0.2147321	test: -0.1101488	best: -0.1100875 (4413)	total: 50.7s	remaining: 1m 3s
# 4440:	learn: -0.2147236	test: -0.1101941	best: -0.1100875 (4413)	total: 50.9s	remaining: 1m 3s
# 4460:	learn: -0.2147156	test: -0.1102553	best: -0.1100875 (4413)	total: 51.1s	remaining: 1m 3s
# 4480:	learn: -0.2147077	test: -0.1103200	best: -0.1100875 (4413)	total: 51.3s	remaining: 1m 3s
# 4500:	learn: -0.2147001	test: -0.1102987	best: -0.1100875 (4413)	total: 51.5s	remaining: 1m 2s
# 4520:	learn: -0.2146924	test: -0.1102592	best: -0.1100875 (4413)	total: 51.8s	remaining: 1m 2s
# 4540:	learn: -0.2146846	test: -0.1102947	best: -0.1100875 (4413)	total: 52s	remaining: 1m 2s
# 4560:	learn: -0.2146769	test: -0.1102776	best: -0.1100875 (4413)	total: 52.3s	remaining: 1m 2s
# 4580:	learn: -0.2146695	test: -0.1102587	best: -0.1100875 (4413)	total: 52.5s	remaining: 1m 2s
# 4600:	learn: -0.2146615	test: -0.1102022	best: -0.1100875 (4413)	total: 52.8s	remaining: 1m 1s
# 4620:	learn: -0.2146552	test: -0.1103047	best: -0.1100875 (4413)	total: 53s	remaining: 1m 1s
# 4640:	learn: -0.2146490	test: -0.1102908	best: -0.1100875 (4413)	total: 53.2s	remaining: 1m 1s
# 4660:	learn: -0.2146429	test: -0.1102371	best: -0.1100875 (4413)	total: 53.4s	remaining: 1m 1s
# 4680:	learn: -0.2146369	test: -0.1103015	best: -0.1100875 (4413)	total: 53.6s	remaining: 1m
# 4700:	learn: -0.2146303	test: -0.1103187	best: -0.1100875 (4413)	total: 53.8s	remaining: 1m
# 4720:	learn: -0.2146242	test: -0.1102078	best: -0.1100875 (4413)	total: 54s	remaining: 1m
# 4740:	learn: -0.2146174	test: -0.1102090	best: -0.1100875 (4413)	total: 54.3s	remaining: 1m
# 4760:	learn: -0.2146095	test: -0.1100465	best: -0.1100465 (4760)	total: 54.5s	remaining: 60s
# 4780:	learn: -0.2146024	test: -0.1099970	best: -0.1099714 (4778)	total: 54.7s	remaining: 59.7s
# 4800:	learn: -0.2145967	test: -0.1100115	best: -0.1099568 (4789)	total: 55s	remaining: 59.5s
# 4820:	learn: -0.2145904	test: -0.1099813	best: -0.1099527 (4816)	total: 55.2s	remaining: 59.3s
# 4840:	learn: -0.2145839	test: -0.1101175	best: -0.1099527 (4816)	total: 55.4s	remaining: 59s
# 4860:	learn: -0.2145776	test: -0.1101031	best: -0.1099527 (4816)	total: 55.6s	remaining: 58.8s
# 4880:	learn: -0.2145714	test: -0.1102162	best: -0.1099527 (4816)	total: 55.8s	remaining: 58.6s
# 4900:	learn: -0.2145649	test: -0.1101973	best: -0.1099527 (4816)	total: 56s	remaining: 58.3s
# 4920:	learn: -0.2145595	test: -0.1101840	best: -0.1099527 (4816)	total: 56.3s	remaining: 58.1s
# 4940:	learn: -0.2145545	test: -0.1102777	best: -0.1099527 (4816)	total: 56.5s	remaining: 57.9s
# 4960:	learn: -0.2145494	test: -0.1102639	best: -0.1099527 (4816)	total: 56.8s	remaining: 57.6s
# 4980:	learn: -0.2145430	test: -0.1102086	best: -0.1099527 (4816)	total: 57s	remaining: 57.4s
# 5000:	learn: -0.2145373	test: -0.1102130	best: -0.1099527 (4816)	total: 57.2s	remaining: 57.2s
# 5020:	learn: -0.2145313	test: -0.1102200	best: -0.1099527 (4816)	total: 57.4s	remaining: 56.9s
# 5040:	learn: -0.2145252	test: -0.1102368	best: -0.1099527 (4816)	total: 57.7s	remaining: 56.7s
# 5060:	learn: -0.2145190	test: -0.1102661	best: -0.1099527 (4816)	total: 57.9s	remaining: 56.5s
# 5080:	learn: -0.2145144	test: -0.1101840	best: -0.1099527 (4816)	total: 58.1s	remaining: 56.3s
# 5100:	learn: -0.2145089	test: -0.1100989	best: -0.1099527 (4816)	total: 58.4s	remaining: 56.1s
# 5120:	learn: -0.2145036	test: -0.1100699	best: -0.1099527 (4816)	total: 58.6s	remaining: 55.8s
# 5140:	learn: -0.2144984	test: -0.1102102	best: -0.1099527 (4816)	total: 58.8s	remaining: 55.6s
# 5160:	learn: -0.2144936	test: -0.1100953	best: -0.1099527 (4816)	total: 59s	remaining: 55.3s
# 5180:	learn: -0.2144889	test: -0.1100442	best: -0.1099527 (4816)	total: 59.2s	remaining: 55.1s
# 5200:	learn: -0.2144837	test: -0.1100001	best: -0.1099527 (4816)	total: 59.5s	remaining: 54.9s
# 5220:	learn: -0.2144779	test: -0.1099394	best: -0.1099371 (5219)	total: 59.7s	remaining: 54.6s
# 5240:	learn: -0.2144725	test: -0.1099615	best: -0.1099196 (5224)	total: 59.9s	remaining: 54.4s
# 5260:	learn: -0.2144661	test: -0.1099538	best: -0.1099196 (5224)	total: 1m	remaining: 54.2s
# 5280:	learn: -0.2144602	test: -0.1098816	best: -0.1098816 (5280)	total: 1m	remaining: 54s
# 5300:	learn: -0.2144555	test: -0.1099315	best: -0.1098594 (5281)	total: 1m	remaining: 53.7s
# 5320:	learn: -0.2144509	test: -0.1098920	best: -0.1098594 (5281)	total: 1m	remaining: 53.5s
# 5340:	learn: -0.2144456	test: -0.1098653	best: -0.1098392 (5323)	total: 1m 1s	remaining: 53.3s
# 5360:	learn: -0.2144410	test: -0.1098287	best: -0.1098209 (5349)	total: 1m 1s	remaining: 53.1s
# 5380:	learn: -0.2144373	test: -0.1097274	best: -0.1097198 (5379)	total: 1m 1s	remaining: 52.8s
# 5400:	learn: -0.2144322	test: -0.1097035	best: -0.1096923 (5398)	total: 1m 1s	remaining: 52.6s
# 5420:	learn: -0.2144273	test: -0.1096345	best: -0.1096345 (5420)	total: 1m 1s	remaining: 52.3s
# 5440:	learn: -0.2144226	test: -0.1096235	best: -0.1096019 (5421)	total: 1m 2s	remaining: 52.1s
# 5460:	learn: -0.2144182	test: -0.1096223	best: -0.1096019 (5421)	total: 1m 2s	remaining: 51.9s
# 5480:	learn: -0.2144132	test: -0.1095653	best: -0.1095653 (5480)	total: 1m 2s	remaining: 51.7s
# 5500:	learn: -0.2144079	test: -0.1097018	best: -0.1095624 (5481)	total: 1m 2s	remaining: 51.5s
# 5520:	learn: -0.2144035	test: -0.1096448	best: -0.1095624 (5481)	total: 1m 3s	remaining: 51.2s
# 5540:	learn: -0.2143989	test: -0.1096568	best: -0.1095624 (5481)	total: 1m 3s	remaining: 51s
# 5560:	learn: -0.2143936	test: -0.1096650	best: -0.1095624 (5481)	total: 1m 3s	remaining: 50.7s
# 5580:	learn: -0.2143891	test: -0.1096541	best: -0.1095624 (5481)	total: 1m 3s	remaining: 50.5s
# 5600:	learn: -0.2143851	test: -0.1096020	best: -0.1095624 (5481)	total: 1m 4s	remaining: 50.3s
# 5620:	learn: -0.2143800	test: -0.1094962	best: -0.1094940 (5619)	total: 1m 4s	remaining: 50.1s
# 5640:	learn: -0.2143763	test: -0.1094545	best: -0.1094380 (5629)	total: 1m 4s	remaining: 49.9s
# 5660:	learn: -0.2143719	test: -0.1095074	best: -0.1094380 (5629)	total: 1m 4s	remaining: 49.6s
# 5680:	learn: -0.2143672	test: -0.1094423	best: -0.1094309 (5672)	total: 1m 4s	remaining: 49.4s
# 5700:	learn: -0.2143637	test: -0.1094404	best: -0.1094193 (5686)	total: 1m 5s	remaining: 49.2s
# 5720:	learn: -0.2143579	test: -0.1094733	best: -0.1094193 (5686)	total: 1m 5s	remaining: 48.9s
# 5740:	learn: -0.2143538	test: -0.1094457	best: -0.1094193 (5686)	total: 1m 5s	remaining: 48.7s
# 5760:	learn: -0.2143501	test: -0.1094149	best: -0.1094149 (5760)	total: 1m 5s	remaining: 48.5s
# 5780:	learn: -0.2143446	test: -0.1094091	best: -0.1094091 (5780)	total: 1m 6s	remaining: 48.2s
# 5800:	learn: -0.2143398	test: -0.1094497	best: -0.1093830 (5786)	total: 1m 6s	remaining: 48s
# 5820:	learn: -0.2143362	test: -0.1093394	best: -0.1093335 (5819)	total: 1m 6s	remaining: 47.8s
# 5840:	learn: -0.2143326	test: -0.1093046	best: -0.1093046 (5840)	total: 1m 6s	remaining: 47.5s
# 5860:	learn: -0.2143283	test: -0.1093053	best: -0.1092834 (5849)	total: 1m 7s	remaining: 47.3s
# 5880:	learn: -0.2143243	test: -0.1093199	best: -0.1092834 (5849)	total: 1m 7s	remaining: 47.1s
# 5900:	learn: -0.2143205	test: -0.1093136	best: -0.1092800 (5895)	total: 1m 7s	remaining: 46.9s
# 5920:	learn: -0.2143161	test: -0.1093090	best: -0.1092800 (5895)	total: 1m 7s	remaining: 46.6s
# 5940:	learn: -0.2143118	test: -0.1093213	best: -0.1092730 (5933)	total: 1m 7s	remaining: 46.4s
# 5960:	learn: -0.2143083	test: -0.1094346	best: -0.1092730 (5933)	total: 1m 8s	remaining: 46.2s
# 5980:	learn: -0.2143043	test: -0.1095294	best: -0.1092730 (5933)	total: 1m 8s	remaining: 46s
# 6000:	learn: -0.2143003	test: -0.1095427	best: -0.1092730 (5933)	total: 1m 8s	remaining: 45.7s
# 6020:	learn: -0.2142966	test: -0.1095614	best: -0.1092730 (5933)	total: 1m 8s	remaining: 45.5s
# 6040:	learn: -0.2142923	test: -0.1095409	best: -0.1092730 (5933)	total: 1m 9s	remaining: 45.3s
# 6060:	learn: -0.2142889	test: -0.1094901	best: -0.1092730 (5933)	total: 1m 9s	remaining: 45.1s
# 6080:	learn: -0.2142847	test: -0.1094917	best: -0.1092730 (5933)	total: 1m 9s	remaining: 44.8s
# 6100:	learn: -0.2142812	test: -0.1094973	best: -0.1092730 (5933)	total: 1m 9s	remaining: 44.6s
# 6120:	learn: -0.2142771	test: -0.1094829	best: -0.1092730 (5933)	total: 1m 9s	remaining: 44.4s
# 6140:	learn: -0.2142731	test: -0.1095029	best: -0.1092730 (5933)	total: 1m 10s	remaining: 44.1s
# 6160:	learn: -0.2142695	test: -0.1094982	best: -0.1092730 (5933)	total: 1m 10s	remaining: 43.9s
# 6180:	learn: -0.2142656	test: -0.1095686	best: -0.1092730 (5933)	total: 1m 10s	remaining: 43.7s
# 6200:	learn: -0.2142619	test: -0.1095446	best: -0.1092730 (5933)	total: 1m 11s	remaining: 43.5s
# 6220:	learn: -0.2142584	test: -0.1095527	best: -0.1092730 (5933)	total: 1m 11s	remaining: 43.3s
# 6240:	learn: -0.2142546	test: -0.1095722	best: -0.1092730 (5933)	total: 1m 11s	remaining: 43s
# 6260:	learn: -0.2142518	test: -0.1096003	best: -0.1092730 (5933)	total: 1m 11s	remaining: 42.8s
# 6280:	learn: -0.2142482	test: -0.1095881	best: -0.1092730 (5933)	total: 1m 11s	remaining: 42.6s
# 6300:	learn: -0.2142444	test: -0.1095468	best: -0.1092730 (5933)	total: 1m 12s	remaining: 42.4s
# 6320:	learn: -0.2142408	test: -0.1094360	best: -0.1092730 (5933)	total: 1m 12s	remaining: 42.1s
# 6340:	learn: -0.2142369	test: -0.1094382	best: -0.1092730 (5933)	total: 1m 12s	remaining: 41.9s
# 6360:	learn: -0.2142335	test: -0.1093801	best: -0.1092730 (5933)	total: 1m 12s	remaining: 41.7s
# 6380:	learn: -0.2142301	test: -0.1093707	best: -0.1092730 (5933)	total: 1m 13s	remaining: 41.5s
# 6400:	learn: -0.2142266	test: -0.1093911	best: -0.1092730 (5933)	total: 1m 13s	remaining: 41.2s
# 6420:	learn: -0.2142229	test: -0.1094106	best: -0.1092730 (5933)	total: 1m 13s	remaining: 41s
# 6440:	learn: -0.2142192	test: -0.1094883	best: -0.1092730 (5933)	total: 1m 13s	remaining: 40.8s
# 6460:	learn: -0.2142159	test: -0.1095206	best: -0.1092730 (5933)	total: 1m 14s	remaining: 40.5s
# 6480:	learn: -0.2142126	test: -0.1095686	best: -0.1092730 (5933)	total: 1m 14s	remaining: 40.3s
# 6500:	learn: -0.2142087	test: -0.1095773	best: -0.1092730 (5933)	total: 1m 14s	remaining: 40.1s
# 6520:	learn: -0.2142054	test: -0.1096674	best: -0.1092730 (5933)	total: 1m 14s	remaining: 39.9s
# 6540:	learn: -0.2142021	test: -0.1097697	best: -0.1092730 (5933)	total: 1m 14s	remaining: 39.6s
# 6560:	learn: -0.2141988	test: -0.1097336	best: -0.1092730 (5933)	total: 1m 15s	remaining: 39.4s
# 6580:	learn: -0.2141954	test: -0.1096877	best: -0.1092730 (5933)	total: 1m 15s	remaining: 39.2s
# 6600:	learn: -0.2141920	test: -0.1096748	best: -0.1092730 (5933)	total: 1m 15s	remaining: 39s
# 6620:	learn: -0.2141894	test: -0.1096306	best: -0.1092730 (5933)	total: 1m 15s	remaining: 38.7s
# 6640:	learn: -0.2141861	test: -0.1096042	best: -0.1092730 (5933)	total: 1m 16s	remaining: 38.5s
# 6660:	learn: -0.2141831	test: -0.1096022	best: -0.1092730 (5933)	total: 1m 16s	remaining: 38.3s
# 6680:	learn: -0.2141798	test: -0.1095366	best: -0.1092730 (5933)	total: 1m 16s	remaining: 38s
# 6700:	learn: -0.2141767	test: -0.1094810	best: -0.1092730 (5933)	total: 1m 16s	remaining: 37.8s
# 6720:	learn: -0.2141737	test: -0.1095030	best: -0.1092730 (5933)	total: 1m 17s	remaining: 37.6s
# 6740:	learn: -0.2141708	test: -0.1094415	best: -0.1092730 (5933)	total: 1m 17s	remaining: 37.4s
# 6760:	learn: -0.2141679	test: -0.1094753	best: -0.1092730 (5933)	total: 1m 17s	remaining: 37.1s
# 6780:	learn: -0.2141650	test: -0.1094211	best: -0.1092730 (5933)	total: 1m 17s	remaining: 36.9s
# 6800:	learn: -0.2141621	test: -0.1094253	best: -0.1092730 (5933)	total: 1m 18s	remaining: 36.7s
# 6820:	learn: -0.2141590	test: -0.1093697	best: -0.1092730 (5933)	total: 1m 18s	remaining: 36.5s
# 6840:	learn: -0.2141563	test: -0.1093560	best: -0.1092730 (5933)	total: 1m 18s	remaining: 36.2s
# 6860:	learn: -0.2141535	test: -0.1093875	best: -0.1092730 (5933)	total: 1m 18s	remaining: 36s
# 6880:	learn: -0.2141504	test: -0.1093520	best: -0.1092730 (5933)	total: 1m 18s	remaining: 35.8s
# 6900:	learn: -0.2141476	test: -0.1093256	best: -0.1092730 (5933)	total: 1m 19s	remaining: 35.5s
# 6920:	learn: -0.2141447	test: -0.1092692	best: -0.1092692 (6920)	total: 1m 19s	remaining: 35.3s
# 6940:	learn: -0.2141423	test: -0.1093419	best: -0.1092629 (6933)	total: 1m 19s	remaining: 35.1s
# 6960:	learn: -0.2141397	test: -0.1092807	best: -0.1092629 (6933)	total: 1m 19s	remaining: 34.8s
# 6980:	learn: -0.2141376	test: -0.1092930	best: -0.1092616 (6966)	total: 1m 20s	remaining: 34.6s
# 7000:	learn: -0.2141346	test: -0.1092533	best: -0.1092533 (7000)	total: 1m 20s	remaining: 34.4s
# 7020:	learn: -0.2141314	test: -0.1093457	best: -0.1092533 (7000)	total: 1m 20s	remaining: 34.1s
# 7040:	learn: -0.2141285	test: -0.1092932	best: -0.1092533 (7000)	total: 1m 20s	remaining: 33.9s
# 7060:	learn: -0.2141261	test: -0.1092798	best: -0.1092533 (7000)	total: 1m 20s	remaining: 33.7s
# 7080:	learn: -0.2141233	test: -0.1091734	best: -0.1091728 (7079)	total: 1m 21s	remaining: 33.5s
# 7100:	learn: -0.2141206	test: -0.1091825	best: -0.1091675 (7093)	total: 1m 21s	remaining: 33.2s
# 7120:	learn: -0.2141180	test: -0.1091986	best: -0.1091558 (7109)	total: 1m 21s	remaining: 33s
# 7140:	learn: -0.2141160	test: -0.1091979	best: -0.1091558 (7109)	total: 1m 21s	remaining: 32.8s
# 7160:	learn: -0.2141133	test: -0.1091636	best: -0.1091558 (7109)	total: 1m 22s	remaining: 32.5s
# 7180:	learn: -0.2141108	test: -0.1092000	best: -0.1091558 (7109)	total: 1m 22s	remaining: 32.3s
# 7200:	learn: -0.2141082	test: -0.1092037	best: -0.1091558 (7109)	total: 1m 22s	remaining: 32.1s
# 7220:	learn: -0.2141056	test: -0.1091645	best: -0.1091558 (7109)	total: 1m 22s	remaining: 31.8s
# 7240:	learn: -0.2141030	test: -0.1092060	best: -0.1091558 (7109)	total: 1m 22s	remaining: 31.6s
# 7260:	learn: -0.2141002	test: -0.1091691	best: -0.1091558 (7109)	total: 1m 23s	remaining: 31.4s
# 7280:	learn: -0.2140979	test: -0.1091976	best: -0.1091558 (7109)	total: 1m 23s	remaining: 31.2s
# 7300:	learn: -0.2140953	test: -0.1092206	best: -0.1091558 (7109)	total: 1m 23s	remaining: 30.9s
# 7320:	learn: -0.2140933	test: -0.1092351	best: -0.1091558 (7109)	total: 1m 23s	remaining: 30.7s
# 7340:	learn: -0.2140909	test: -0.1091842	best: -0.1091558 (7109)	total: 1m 24s	remaining: 30.5s
# 7360:	learn: -0.2140881	test: -0.1091399	best: -0.1091399 (7360)	total: 1m 24s	remaining: 30.3s
# 7380:	learn: -0.2140855	test: -0.1091500	best: -0.1091399 (7360)	total: 1m 24s	remaining: 30s
# 7400:	learn: -0.2140827	test: -0.1091325	best: -0.1091036 (7399)	total: 1m 24s	remaining: 29.8s
# 7420:	learn: -0.2140800	test: -0.1092258	best: -0.1091036 (7399)	total: 1m 25s	remaining: 29.6s
# 7440:	learn: -0.2140776	test: -0.1091548	best: -0.1091036 (7399)	total: 1m 25s	remaining: 29.3s
# 7460:	learn: -0.2140753	test: -0.1091707	best: -0.1091036 (7399)	total: 1m 25s	remaining: 29.1s
# 7480:	learn: -0.2140727	test: -0.1092111	best: -0.1091036 (7399)	total: 1m 25s	remaining: 28.9s
# 7500:	learn: -0.2140704	test: -0.1092338	best: -0.1091036 (7399)	total: 1m 25s	remaining: 28.6s
# 7520:	learn: -0.2140679	test: -0.1092397	best: -0.1091036 (7399)	total: 1m 26s	remaining: 28.4s
# 7540:	learn: -0.2140657	test: -0.1093201	best: -0.1091036 (7399)	total: 1m 26s	remaining: 28.2s
# 7560:	learn: -0.2140636	test: -0.1093023	best: -0.1091036 (7399)	total: 1m 26s	remaining: 28s
# 7580:	learn: -0.2140616	test: -0.1093404	best: -0.1091036 (7399)	total: 1m 26s	remaining: 27.7s
# 7600:	learn: -0.2140597	test: -0.1093192	best: -0.1091036 (7399)	total: 1m 27s	remaining: 27.5s
# 7620:	learn: -0.2140574	test: -0.1092983	best: -0.1091036 (7399)	total: 1m 27s	remaining: 27.3s
# 7640:	learn: -0.2140548	test: -0.1092765	best: -0.1091036 (7399)	total: 1m 27s	remaining: 27s
# 7660:	learn: -0.2140522	test: -0.1092689	best: -0.1091036 (7399)	total: 1m 27s	remaining: 26.8s
# 7680:	learn: -0.2140498	test: -0.1092560	best: -0.1091036 (7399)	total: 1m 28s	remaining: 26.6s
# 7700:	learn: -0.2140474	test: -0.1092611	best: -0.1091036 (7399)	total: 1m 28s	remaining: 26.4s
# 7720:	learn: -0.2140450	test: -0.1092461	best: -0.1091036 (7399)	total: 1m 28s	remaining: 26.1s
# 7740:	learn: -0.2140428	test: -0.1092601	best: -0.1091036 (7399)	total: 1m 28s	remaining: 25.9s
# 7760:	learn: -0.2140406	test: -0.1091530	best: -0.1091036 (7399)	total: 1m 29s	remaining: 25.7s
# 7780:	learn: -0.2140383	test: -0.1091551	best: -0.1091036 (7399)	total: 1m 29s	remaining: 25.4s
# 7800:	learn: -0.2140361	test: -0.1092286	best: -0.1091036 (7399)	total: 1m 29s	remaining: 25.2s
# 7820:	learn: -0.2140344	test: -0.1092312	best: -0.1091036 (7399)	total: 1m 29s	remaining: 25s
# 7840:	learn: -0.2140322	test: -0.1092663	best: -0.1091036 (7399)	total: 1m 29s	remaining: 24.7s
# 7860:	learn: -0.2140300	test: -0.1092359	best: -0.1091036 (7399)	total: 1m 30s	remaining: 24.5s
# 7880:	learn: -0.2140283	test: -0.1091996	best: -0.1091036 (7399)	total: 1m 30s	remaining: 24.3s
# 7900:	learn: -0.2140259	test: -0.1092611	best: -0.1091036 (7399)	total: 1m 30s	remaining: 24.1s
# 7920:	learn: -0.2140237	test: -0.1092076	best: -0.1091036 (7399)	total: 1m 30s	remaining: 23.8s
# 7940:	learn: -0.2140214	test: -0.1092206	best: -0.1091036 (7399)	total: 1m 31s	remaining: 23.6s
# 7960:	learn: -0.2140192	test: -0.1092721	best: -0.1091036 (7399)	total: 1m 31s	remaining: 23.4s
# 7980:	learn: -0.2140169	test: -0.1092794	best: -0.1091036 (7399)	total: 1m 31s	remaining: 23.1s
# 8000:	learn: -0.2140147	test: -0.1092864	best: -0.1091036 (7399)	total: 1m 31s	remaining: 22.9s
# 8020:	learn: -0.2140120	test: -0.1093315	best: -0.1091036 (7399)	total: 1m 31s	remaining: 22.7s
# 8040:	learn: -0.2140098	test: -0.1093931	best: -0.1091036 (7399)	total: 1m 32s	remaining: 22.5s
# 8060:	learn: -0.2140074	test: -0.1093720	best: -0.1091036 (7399)	total: 1m 32s	remaining: 22.2s
# 8080:	learn: -0.2140049	test: -0.1093235	best: -0.1091036 (7399)	total: 1m 32s	remaining: 22s
# 8100:	learn: -0.2140031	test: -0.1093798	best: -0.1091036 (7399)	total: 1m 32s	remaining: 21.8s
# 8120:	learn: -0.2140009	test: -0.1094095	best: -0.1091036 (7399)	total: 1m 33s	remaining: 21.5s
# 8140:	learn: -0.2139983	test: -0.1093745	best: -0.1091036 (7399)	total: 1m 33s	remaining: 21.3s
# 8160:	learn: -0.2139962	test: -0.1093893	best: -0.1091036 (7399)	total: 1m 33s	remaining: 21.1s
# 8180:	learn: -0.2139938	test: -0.1093071	best: -0.1091036 (7399)	total: 1m 33s	remaining: 20.8s
# 8200:	learn: -0.2139919	test: -0.1094027	best: -0.1091036 (7399)	total: 1m 33s	remaining: 20.6s
# 8220:	learn: -0.2139903	test: -0.1093532	best: -0.1091036 (7399)	total: 1m 34s	remaining: 20.4s
# 8240:	learn: -0.2139883	test: -0.1093512	best: -0.1091036 (7399)	total: 1m 34s	remaining: 20.2s
# 8260:	learn: -0.2139860	test: -0.1093732	best: -0.1091036 (7399)	total: 1m 34s	remaining: 19.9s
# 8280:	learn: -0.2139840	test: -0.1093920	best: -0.1091036 (7399)	total: 1m 34s	remaining: 19.7s
# 8300:	learn: -0.2139820	test: -0.1093995	best: -0.1091036 (7399)	total: 1m 35s	remaining: 19.5s
# 8320:	learn: -0.2139802	test: -0.1093295	best: -0.1091036 (7399)	total: 1m 35s	remaining: 19.2s
# 8340:	learn: -0.2139781	test: -0.1093335	best: -0.1091036 (7399)	total: 1m 35s	remaining: 19s
# 8360:	learn: -0.2139764	test: -0.1093272	best: -0.1091036 (7399)	total: 1m 35s	remaining: 18.8s
# 8380:	learn: -0.2139741	test: -0.1093961	best: -0.1091036 (7399)	total: 1m 36s	remaining: 18.5s
# 8400:	learn: -0.2139723	test: -0.1093786	best: -0.1091036 (7399)	total: 1m 36s	remaining: 18.3s
# 8420:	learn: -0.2139701	test: -0.1093483	best: -0.1091036 (7399)	total: 1m 36s	remaining: 18.1s
# 8440:	learn: -0.2139683	test: -0.1093832	best: -0.1091036 (7399)	total: 1m 36s	remaining: 17.9s
# 8460:	learn: -0.2139664	test: -0.1093826	best: -0.1091036 (7399)	total: 1m 36s	remaining: 17.6s
# 8480:	learn: -0.2139643	test: -0.1093633	best: -0.1091036 (7399)	total: 1m 37s	remaining: 17.4s
# 8500:	learn: -0.2139627	test: -0.1093534	best: -0.1091036 (7399)	total: 1m 37s	remaining: 17.2s
# 8520:	learn: -0.2139606	test: -0.1094191	best: -0.1091036 (7399)	total: 1m 37s	remaining: 17s
# 8540:	learn: -0.2139585	test: -0.1093508	best: -0.1091036 (7399)	total: 1m 37s	remaining: 16.7s
# 8560:	learn: -0.2139566	test: -0.1094291	best: -0.1091036 (7399)	total: 1m 38s	remaining: 16.5s
# 8580:	learn: -0.2139550	test: -0.1094406	best: -0.1091036 (7399)	total: 1m 38s	remaining: 16.3s
# 8600:	learn: -0.2139531	test: -0.1094533	best: -0.1091036 (7399)	total: 1m 38s	remaining: 16s
# 8620:	learn: -0.2139515	test: -0.1094959	best: -0.1091036 (7399)	total: 1m 38s	remaining: 15.8s
# 8640:	learn: -0.2139495	test: -0.1094909	best: -0.1091036 (7399)	total: 1m 39s	remaining: 15.6s
# 8660:	learn: -0.2139477	test: -0.1094763	best: -0.1091036 (7399)	total: 1m 39s	remaining: 15.3s
# 8680:	learn: -0.2139461	test: -0.1095103	best: -0.1091036 (7399)	total: 1m 39s	remaining: 15.1s
# 8700:	learn: -0.2139444	test: -0.1094909	best: -0.1091036 (7399)	total: 1m 39s	remaining: 14.9s
# 8720:	learn: -0.2139426	test: -0.1094772	best: -0.1091036 (7399)	total: 1m 39s	remaining: 14.7s
# 8740:	learn: -0.2139407	test: -0.1094744	best: -0.1091036 (7399)	total: 1m 40s	remaining: 14.4s
# 8760:	learn: -0.2139389	test: -0.1094219	best: -0.1091036 (7399)	total: 1m 40s	remaining: 14.2s
# 8780:	learn: -0.2139371	test: -0.1094588	best: -0.1091036 (7399)	total: 1m 40s	remaining: 14s
# 8800:	learn: -0.2139353	test: -0.1094969	best: -0.1091036 (7399)	total: 1m 40s	remaining: 13.8s
# 8820:	learn: -0.2139336	test: -0.1094860	best: -0.1091036 (7399)	total: 1m 41s	remaining: 13.5s
# 8840:	learn: -0.2139320	test: -0.1095465	best: -0.1091036 (7399)	total: 1m 41s	remaining: 13.3s
# 8860:	learn: -0.2139303	test: -0.1095345	best: -0.1091036 (7399)	total: 1m 41s	remaining: 13.1s
# 8880:	learn: -0.2139284	test: -0.1095809	best: -0.1091036 (7399)	total: 1m 41s	remaining: 12.8s
# 8900:	learn: -0.2139265	test: -0.1095326	best: -0.1091036 (7399)	total: 1m 42s	remaining: 12.6s
# 8920:	learn: -0.2139250	test: -0.1095037	best: -0.1091036 (7399)	total: 1m 42s	remaining: 12.4s
# 2024-11-01 16:02:25,173	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 8940:	learn: -0.2139232	test: -0.1094925	best: -0.1091036 (7399)	total: 1m 42s	remaining: 12.2s
# 8960:	learn: -0.2139216	test: -0.1095335	best: -0.1091036 (7399)	total: 1m 42s	remaining: 11.9s
# 8980:	learn: -0.2139200	test: -0.1095557	best: -0.1091036 (7399)	total: 1m 43s	remaining: 11.7s
# 9000:	learn: -0.2139185	test: -0.1095544	best: -0.1091036 (7399)	total: 1m 43s	remaining: 11.5s
# 9020:	learn: -0.2139167	test: -0.1095603	best: -0.1091036 (7399)	total: 1m 43s	remaining: 11.2s
# 9040:	learn: -0.2139154	test: -0.1095333	best: -0.1091036 (7399)	total: 1m 43s	remaining: 11s
# 9060:	learn: -0.2139137	test: -0.1095057	best: -0.1091036 (7399)	total: 1m 44s	remaining: 10.8s
# 2024-11-01 16:02:29,253	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-01 16:02:29,283	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 9080:	learn: -0.2139122	test: -0.1094599	best: -0.1091036 (7399)	total: 1m 44s	remaining: 10.5s
# 9100:	learn: -0.2139102	test: -0.1094137	best: -0.1091036 (7399)	total: 1m 44s	remaining: 10.3s
# 9120:	learn: -0.2139084	test: -0.1094250	best: -0.1091036 (7399)	total: 1m 44s	remaining: 10.1s
# 9140:	learn: -0.2139070	test: -0.1094094	best: -0.1091036 (7399)	total: 1m 44s	remaining: 9.86s
# 9160:	learn: -0.2139053	test: -0.1094201	best: -0.1091036 (7399)	total: 1m 45s	remaining: 9.63s
# 9180:	learn: -0.2139036	test: -0.1094951	best: -0.1091036 (7399)	total: 1m 45s	remaining: 9.4s
# 9200:	learn: -0.2139020	test: -0.1094494	best: -0.1091036 (7399)	total: 1m 45s	remaining: 9.18s
# 9220:	learn: -0.2139004	test: -0.1094112	best: -0.1091036 (7399)	total: 1m 45s	remaining: 8.95s
# 9240:	learn: -0.2138985	test: -0.1093908	best: -0.1091036 (7399)	total: 1m 46s	remaining: 8.71s
# 9260:	learn: -0.2138969	test: -0.1094002	best: -0.1091036 (7399)	total: 1m 46s	remaining: 8.48s
# 9280:	learn: -0.2138954	test: -0.1094190	best: -0.1091036 (7399)	total: 1m 46s	remaining: 8.26s
# 9300:	learn: -0.2138936	test: -0.1094528	best: -0.1091036 (7399)	total: 1m 46s	remaining: 8.03s
# 9320:	learn: -0.2138923	test: -0.1094248	best: -0.1091036 (7399)	total: 1m 47s	remaining: 7.8s
# 9340:	learn: -0.2138911	test: -0.1094354	best: -0.1091036 (7399)	total: 1m 47s	remaining: 7.56s
# 9360:	learn: -0.2138897	test: -0.1094285	best: -0.1091036 (7399)	total: 1m 47s	remaining: 7.33s
# 9380:	learn: -0.2138885	test: -0.1094043	best: -0.1091036 (7399)	total: 1m 47s	remaining: 7.11s
# 9400:	learn: -0.2138868	test: -0.1094358	best: -0.1091036 (7399)	total: 1m 47s	remaining: 6.88s
# 9420:	learn: -0.2138852	test: -0.1094455	best: -0.1091036 (7399)	total: 1m 48s	remaining: 6.65s
# 9440:	learn: -0.2138840	test: -0.1094632	best: -0.1091036 (7399)	total: 1m 48s	remaining: 6.42s
# 9460:	learn: -0.2138824	test: -0.1094729	best: -0.1091036 (7399)	total: 1m 48s	remaining: 6.19s
# 9480:	learn: -0.2138810	test: -0.1094670	best: -0.1091036 (7399)	total: 1m 48s	remaining: 5.96s
# 9500:	learn: -0.2138792	test: -0.1095268	best: -0.1091036 (7399)	total: 1m 49s	remaining: 5.73s
# 9520:	learn: -0.2138776	test: -0.1095058	best: -0.1091036 (7399)	total: 1m 49s	remaining: 5.5s
# 9540:	learn: -0.2138760	test: -0.1095063	best: -0.1091036 (7399)	total: 1m 49s	remaining: 5.27s
# 9560:	learn: -0.2138744	test: -0.1095528	best: -0.1091036 (7399)	total: 1m 49s	remaining: 5.04s
# 9580:	learn: -0.2138730	test: -0.1095893	best: -0.1091036 (7399)	total: 1m 50s	remaining: 4.81s
# 9600:	learn: -0.2138715	test: -0.1096742	best: -0.1091036 (7399)	total: 1m 50s	remaining: 4.58s
# 9620:	learn: -0.2138701	test: -0.1096706	best: -0.1091036 (7399)	total: 1m 50s	remaining: 4.35s
# 	Note: model has different eval_metric than default.
# 	-0.1091	 = Validation score   (-soft_log_loss)
# bestTest = -0.1091036358
# bestIteration = 7399
#
# Shrink model to first 7400 iterations.
# 	202.84s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.0213	 = Validation score   (-soft_log_loss)
# 	5.91s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_2_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.0213	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   1.000000  soft_log_loss       0.003631  202.839666                0.003631         202.839666            1       True        168
# 1       NeuralNetTorch_2_DSTL   1.000000  soft_log_loss       0.014997    5.910244                0.014997           5.910244            1       True        169
# 2  WeightedEnsemble_2_L2_DSTL   1.000000  soft_log_loss       0.015996    5.944885                0.000998           0.034641            2       True        170
# 3             LightGBM_2_DSTL   0.944444  soft_log_loss       0.000998    1.484764                0.000998           1.484764            1       True        166
# 4      RandomForestMSE_2_DSTL   0.944444  soft_log_loss       0.058905    0.768171                0.058905           0.768171            1       True        167
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                           model  score_test  score_val    eval_metric  \
# 1         KNeighborsDist_BAG_L1    0.941176   0.896552       accuracy
# 0         KNeighborsUnif_BAG_L1    0.941176   0.701149       accuracy
# 2                 LightGBM_DSTL    0.882353   1.000000  soft_log_loss
# 5         NeuralNetTorch_2_DSTL    0.882353   1.000000  soft_log_loss
# 6    WeightedEnsemble_2_L2_DSTL    0.882353   1.000000  soft_log_loss
# ..                          ...         ...        ...            ...
# 165        LightGBM_r130_BAG_L1    0.294118   0.275862       accuracy
# 166        LightGBM_r135_BAG_L1    0.294118   0.275862       accuracy
# 168        LightGBM_r130_BAG_L2    0.294118   0.275862       accuracy
# 169         LightGBM_r96_BAG_L2    0.294118   0.275862       accuracy
# 167     RandomForest_r34_BAG_L1    0.294118   0.011494       accuracy
#
#      pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 1          0.003998       0.003002    0.006997                 0.003998
# 0          0.003505       0.314503    0.004997                 0.003505
# 2          0.008529       0.001002    1.295770                 0.008529
# 5          0.022210       0.014997    5.910244                 0.022210
# 6          0.024204       0.015996    5.944885                 0.001995
# ..              ...            ...         ...                      ...
# 165        0.009670       0.017996    2.563767                 0.009670
# 166        0.010001       0.009888    2.690822                 0.010001
# 168        9.333247       7.583158  927.087389                 0.030005
# 169        9.351232       7.584771  927.191799                 0.047990
# 167        0.113735       0.082655    1.470538                 0.113735
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                  0.003002           0.006997            1       True
# 0                  0.314503           0.004997            1       True
# 2                  0.001002           1.295770            1       True
# 5                  0.014997           5.910244            1       True
# 6                  0.000998           0.034641            2       True
# ..                      ...                ...          ...        ...
# 165                0.017996           2.563767            1       True
# 166                0.009888           2.690822            1       True
# 168                0.025191           2.884591            2       True
# 169                0.026804           2.989000            2       True
# 167                0.082655           1.470538            1       True
#
#      fit_order
# 1            2
# 0            1
# 2          161
# 5          169
# 6          170
# ..         ...
# 165         31
# 166         82
# 168        140
# 169        128
# 167         60
#
# [170 rows x 13 columns]
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.8823529411764706
# Evaluations on test data:
# {
#     "accuracy": 0.8823529411764706,
#     "balanced_accuracy": 0.85,
#     "mcc": 0.8152173913043478
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.8,
#         "recall": 0.8,
#         "f1-score": 0.8,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.75,
#         "recall": 0.75,
#         "f1-score": 0.75,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 8.0
#     },
#     "accuracy": 0.8823529411764706,
#     "macro avg": {
#         "precision": 0.85,
#         "recall": 0.85,
#         "f1-score": 0.85,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.8823529411764706,
#         "recall": 0.8823529411764706,
#         "f1-score": 0.8823529411764706,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.8823529411764706, 'balanced_accuracy': 0.85, 'mcc': 0.8152173913043478, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              4
# Exc L3-4 RORB CARM1P1                                      1
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      0
# Exc L3-4 RORB CARM1P1                              3                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.8, 'recall': 0.8, 'f1-score': 0.8, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0}, 'accuracy': 0.8823529411764706, 'macro avg': {'precision': 0.85, 'recall': 0.85, 'f1-score': 0.85, 'support': 17.0}, 'weighted avg': {'precision': 0.8823529411764706, 'recall': 0.8823529411764706, 'f1-score': 0.8823529411764706, 'support': 17.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x1db8a40d110>,
#   <matplotlib.axis.YTick at 0x1db89fd2110>,
#   <matplotlib.axis.YTick at 0x1db8a40f190>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'CatBoost_r177_BAG_L1', 'NeuralNetTorch_r79_BAG_L1', 'LightGBM_r131_BAG_L1', 'NeuralNetFastAI_r191_BAG_L1', 'CatBoost_r9_BAG_L1', 'LightGBM_r96_BAG_L1', 'NeuralNetTorch_r22_BAG_L1', 'XGBoost_r33_BAG_L1', 'ExtraTrees_r42_BAG_L1', 'CatBoost_r137_BAG_L1', 'NeuralNetFastAI_r102_BAG_L1', 'CatBoost_r13_BAG_L1', 'RandomForest_r195_BAG_L1', 'LightGBM_r188_BAG_L1', 'NeuralNetFastAI_r145_BAG_L1', 'XGBoost_r89_BAG_L1', 'NeuralNetTorch_r30_BAG_L1', 'LightGBM_r130_BAG_L1', 'NeuralNetTorch_r86_BAG_L1', 'CatBoost_r50_BAG_L1', 'NeuralNetFastAI_r11_BAG_L1', 'XGBoost_r194_BAG_L1', 'ExtraTrees_r172_BAG_L1', 'CatBoost_r69_BAG_L1', 'NeuralNetFastAI_r103_BAG_L1', 'NeuralNetTorch_r14_BAG_L1', 'LightGBM_r161_BAG_L1', 'NeuralNetFastAI_r143_BAG_L1', 'CatBoost_r70_BAG_L1', 'NeuralNetFastAI_r156_BAG_L1', 'LightGBM_r196_BAG_L1', 'RandomForest_r39_BAG_L1', 'CatBoost_r167_BAG_L1', 'NeuralNetFastAI_r95_BAG_L1', 'NeuralNetTorch_r41_BAG_L1', 'XGBoost_r98_BAG_L1', 'LightGBM_r15_BAG_L1', 'NeuralNetTorch_r158_BAG_L1', 'CatBoost_r86_BAG_L1', 'NeuralNetFastAI_r37_BAG_L1', 'NeuralNetTorch_r197_BAG_L1', 'CatBoost_r49_BAG_L1', 'ExtraTrees_r49_BAG_L1', 'LightGBM_r143_BAG_L1', 'RandomForest_r127_BAG_L1', 'NeuralNetFastAI_r134_BAG_L1', 'RandomForest_r34_BAG_L1', 'LightGBM_r94_BAG_L1', 'NeuralNetTorch_r143_BAG_L1', 'CatBoost_r128_BAG_L1', 'NeuralNetFastAI_r111_BAG_L1', 'NeuralNetTorch_r31_BAG_L1', 'ExtraTrees_r4_BAG_L1', 'NeuralNetFastAI_r65_BAG_L1', 'NeuralNetFastAI_r88_BAG_L1', 'LightGBM_r30_BAG_L1', 'XGBoost_r49_BAG_L1', 'CatBoost_r5_BAG_L1', 'NeuralNetTorch_r87_BAG_L1', 'NeuralNetTorch_r71_BAG_L1', 'CatBoost_r143_BAG_L1', 'ExtraTrees_r178_BAG_L1', 'RandomForest_r166_BAG_L1', 'XGBoost_r31_BAG_L1', 'NeuralNetTorch_r185_BAG_L1', 'NeuralNetFastAI_r160_BAG_L1', 'CatBoost_r60_BAG_L1', 'RandomForest_r15_BAG_L1', 'LightGBM_r135_BAG_L1', 'XGBoost_r22_BAG_L1', 'NeuralNetFastAI_r69_BAG_L1', 'CatBoost_r6_BAG_L1', 'NeuralNetFastAI_r138_BAG_L1', 'LightGBM_r121_BAG_L1', 'NeuralNetFastAI_r172_BAG_L1', 'CatBoost_r180_BAG_L1', 'NeuralNetTorch_r76_BAG_L1', 'ExtraTrees_r197_BAG_L1', 'NeuralNetTorch_r121_BAG_L1', 'NeuralNetFastAI_r127_BAG_L1', 'RandomForest_r16_BAG_L1', 'NeuralNetFastAI_r194_BAG_L1', 'CatBoost_r12_BAG_L1', 'NeuralNetTorch_r135_BAG_L1', 'NeuralNetFastAI_r4_BAG_L1', 'ExtraTrees_r126_BAG_L1', 'NeuralNetTorch_r36_BAG_L1', 'NeuralNetFastAI_r100_BAG_L1', 'CatBoost_r163_BAG_L1', 'CatBoost_r198_BAG_L1', 'NeuralNetFastAI_r187_BAG_L1', 'NeuralNetTorch_r19_BAG_L1', 'XGBoost_r95_BAG_L1', 'XGBoost_r34_BAG_L1', 'LightGBM_r42_BAG_L1', 'NeuralNetTorch_r1_BAG_L1', 'NeuralNetTorch_r89_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L2', 'LightGBMXT_BAG_L2', 'LightGBM_BAG_L2', 'RandomForestGini_BAG_L2', 'RandomForestEntr_BAG_L2', 'CatBoost_BAG_L2', 'ExtraTreesGini_BAG_L2', 'ExtraTreesEntr_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'LightGBMLarge_BAG_L2', 'CatBoost_r177_BAG_L2', 'NeuralNetTorch_r79_BAG_L2', 'LightGBM_r131_BAG_L2', 'NeuralNetFastAI_r191_BAG_L2', 'CatBoost_r9_BAG_L2', 'LightGBM_r96_BAG_L2', 'NeuralNetTorch_r22_BAG_L2', 'XGBoost_r33_BAG_L2', 'ExtraTrees_r42_BAG_L2', 'CatBoost_r137_BAG_L2', 'NeuralNetFastAI_r102_BAG_L2', 'CatBoost_r13_BAG_L2', 'RandomForest_r195_BAG_L2', 'LightGBM_r188_BAG_L2', 'NeuralNetFastAI_r145_BAG_L2', 'XGBoost_r89_BAG_L2', 'NeuralNetTorch_r30_BAG_L2', 'LightGBM_r130_BAG_L2', 'NeuralNetTorch_r86_BAG_L2', 'CatBoost_r50_BAG_L2', 'NeuralNetFastAI_r11_BAG_L2', 'XGBoost_r194_BAG_L2', 'ExtraTrees_r172_BAG_L2', 'CatBoost_r69_BAG_L2', 'NeuralNetFastAI_r103_BAG_L2', 'NeuralNetTorch_r14_BAG_L2', 'LightGBM_r161_BAG_L2', 'NeuralNetFastAI_r143_BAG_L2', 'CatBoost_r70_BAG_L2', 'NeuralNetFastAI_r156_BAG_L2', 'LightGBM_r196_BAG_L2', 'RandomForest_r39_BAG_L2' ...

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L3-4 RORB CARM1P1

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
# predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
