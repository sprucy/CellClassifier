# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个bag数，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %% [markdown]
# ### presets 配置
# ```
# # Best predictive accuracy with little consideration to inference time or disk usage. Achieve even better results by specifying a large time_limit value.
# #Recommended for applications that benefit from the best possible model accuracy.
# best_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "zeroshot",
#     "time_limit": 3600,
# },
# # High predictive accuracy with fast inference. ~8x faster inference and ~8x lower disk usage than `best_quality`.
# # Recommended for applications that require fast inference speed and/or small model size.
# high_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "zeroshot",
#     "time_limit": 3600,
#     "refit_full": True,
#     "set_best_to_refit_full": True,
#     "save_bag_folds": False,
# },
# # Good predictive accuracy with very fast inference. ~4x faster training, ~8x faster inference and ~8x lower disk usage than `high_quality`.
# # Recommended for applications that require very fast inference speed.
# good_quality={
#     "auto_stack": True,
#     "dynamic_stacking": "auto",
#     "num_bag_sets": 1,
#     "hyperparameters": "light",
#     "time_limit": 3600,
#     "refit_full": True,
#     "set_best_to_refit_full": True,
#     "save_bag_folds": False,
# },
# # Medium predictive accuracy with very fast inference and very fast training time. ~20x faster training than `good_quality`.
# # This is the default preset in AutoGluon, but should generally only be used for quick prototyping, as `good_quality` results in significantly better predictive # accuracy with similar inference time.
# medium_quality={"auto_stack": False},
# # Optimizes result immediately for deployment by deleting unused models and removing training artifacts.
# # Often can reduce disk usage by ~2-4x with no negatives to model accuracy or inference speed.
# # This will disable numerous advanced functionality, but has no impact on inference.
# # Recommended for applications where the inner details of AutoGluon's training is not important and there is no intention of manually choosing between the final models.
# # This preset pairs well with the other presets such as `good_quality` to make a very compact final model.
# # Identical to calling `predictor.delete_models(models_to_keep='best', dry_run=False)` and `predictor.save_space()` directly after `fit()`.
# ```

# %% [markdown]
# # hyperparameters 配置
#     # Default AutoGluon hyperparameters intended to maximize accuracy without significant regard to inference time or disk usage.
#     default={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#         "RF": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "XT": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "KNN": [
#             {"weights": "uniform", "ag_args": {"name_suffix": "Unif"}},
#             {"weights": "distance", "ag_args": {"name_suffix": "Dist"}},
#         ],
#     },
#     # Results in smaller models. Generally will make inference speed much faster and disk usage much lower, but with worse accuracy.
#     light={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#         "RF": [
#             {"criterion": "gini", "max_depth": 15, "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "max_depth": 15, "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "max_depth": 15, "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#         "XT": [
#             {"criterion": "gini", "max_depth": 15, "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "max_depth": 15, "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "max_depth": 15, "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#         ],
#     },
#     # Results in much smaller models. Behaves similarly to 'light', but in many cases with over 10x less disk usage and a further reduction in accuracy.
#     very_light={
#         "NN_TORCH": {},
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         "FASTAI": {},
#     },
#     # Results in extremely quick to train models. Only use this when prototyping, as the model accuracy will be severely reduced.
#     toy={
#         "NN_TORCH": {"num_epochs": 5},
#         "GBM": {"num_boost_round": 10},
#         "CAT": {"iterations": 10},
#         "XGB": {"n_estimators": 10},
#     },
#     # Default AutoGluon hyperparameters intended to maximize accuracy in multimodal tabular + text datasets. Requires GPU.
#     multimodal={
#         "NN_TORCH": {},
#         "GBM": [
#             {},
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             "GBMLarge",
#         ],
#         "CAT": {},
#         "XGB": {},
#         # 'FASTAI': {},  # FastAI gets killed if the dataset is large (400K rows).
#         "AG_AUTOMM": {},
#         "VW": {},
#     },
#     # Hyperparameters intended to find an interpretable model which doesn't sacrifice predictive accuracy
#     interpretable={
#         "IM_RULEFIT": [{"max_rules": 7}, {"max_rules": 12}, {"max_rules": 18}],
#         "IM_FIGS": [{"max_rules": 6}, {"max_rules": 10}, {"max_rules": 15}],
#         # Note: Below are commented out because they are not meaningfully interpretable via the existing API
#         # 'IM_GREEDYTREE': [{'max_leaf_nodes': 7, 'max_leaf_nodes': 18}],
#         # 'IM_BOOSTEDRULES': [{'n_estimators': 5}, {'n_estimators': 10}],
#         # 'IM_HSTREE': [{'max_rules': 6}, {'max_rules': 12}, {'max_rules': 18}],
#     },
#     zeroshot_hpo={
#         "XT": [{"min_samples_leaf": 1, "max_leaf_nodes": 15000, "max_features": 0.5, "ag_args": {"name_suffix": "_r19", "priority": 20}}],
#         "RF": [{"min_samples_leaf": 5, "max_leaf_nodes": 50000, "max_features": 0.5, "ag_args": {"name_suffix": "_r5", "priority": 19}}],
#         "GBM": [
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.7248284762542815,
#                 "learning_rate": 0.07947286942946127,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 89,
#                 "ag_args": {"name_suffix": "_r158", "priority": 18},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7832570544199176,
#                 "learning_rate": 0.021720607471727896,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 21,
#                 "ag_args": {"name_suffix": "_r118", "priority": 17},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7113010892989156,
#                 "learning_rate": 0.012535427424259274,
#                 "min_data_in_leaf": 16,
#                 "num_leaves": 48,
#                 "ag_args": {"name_suffix": "_r97", "priority": 16},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.45555769907110816,
#                 "learning_rate": 0.009591347321206594,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 110,
#                 "ag_args": {"name_suffix": "_r71", "priority": 15},
#             },
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.40979710161022476,
#                 "learning_rate": 0.008708890211023034,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 80,
#                 "ag_args": {"name_suffix": "_r111", "priority": 14},
#             },
#         ],
#         "FASTAI": [
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6167722379778131,
#                 "epochs": 44,
#                 "layers": [200, 100, 50],
#                 "lr": 0.053440377855629266,
#                 "ps": 0.48477211305443607,
#                 "ag_args": {"name_suffix": "_r25", "priority": 13},
#             },
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6046989241462619,
#                 "epochs": 48,
#                 "layers": [200, 100, 50],
#                 "lr": 0.00775309042164966,
#                 "ps": 0.09244767444160731,
#                 "ag_args": {"name_suffix": "_r51", "priority": 12},
#             },
#             {
#                 "bs": 512,
#                 "emb_drop": 0.6557225316526186,
#                 "epochs": 49,
#                 "layers": [200, 100],
#                 "lr": 0.023627682025564638,
#                 "ps": 0.519566584552178,
#                 "ag_args": {"name_suffix": "_r82", "priority": 11},
#             },
#             {
#                 "bs": 2048,
#                 "emb_drop": 0.4066210919034579,
#                 "epochs": 43,
#                 "layers": [400, 200],
#                 "lr": 0.0029598312717673434,
#                 "ps": 0.4378695797438974,
#                 "ag_args": {"name_suffix": "_r121", "priority": 10},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.44339037504795686,
#                 "epochs": 31,
#                 "layers": [400, 200, 100],
#                 "lr": 0.008615195908919904,
#                 "ps": 0.19220253419114286,
#                 "ag_args": {"name_suffix": "_r145", "priority": 9},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.12106594798980945,
#                 "epochs": 38,
#                 "layers": [200, 100, 50],
#                 "lr": 0.037991970245029975,
#                 "ps": 0.33120008492595093,
#                 "ag_args": {"name_suffix": "_r173", "priority": 8},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.4599138419358,
#                 "epochs": 47,
#                 "layers": [200, 100],
#                 "lr": 0.03888383281136287,
#                 "ps": 0.28193673177122863,
#                 "ag_args": {"name_suffix": "_r128", "priority": 7},
#             },
#         ],
#         "CAT": [
#             {"depth": 5, "l2_leaf_reg": 4.774992314058497, "learning_rate": 0.038551267822920274, "ag_args": {"name_suffix": "_r16", "priority": 6}},
#             {"depth": 4, "l2_leaf_reg": 1.9950125740798321, "learning_rate": 0.028091050379971633, "ag_args": {"name_suffix": "_r42", "priority": 5}},
#             {"depth": 6, "l2_leaf_reg": 1.8298803017644376, "learning_rate": 0.017844259810823604, "ag_args": {"name_suffix": "_r93", "priority": 4}},
#             {"depth": 7, "l2_leaf_reg": 4.81099604606794, "learning_rate": 0.019085060180573103, "ag_args": {"name_suffix": "_r44", "priority": 3}},
#         ],
#     },
#     zeroshot_hpo_hybrid={
#         "NN_TORCH": {},
#         "XT": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#             {"min_samples_leaf": 1, "max_leaf_nodes": 15000, "max_features": 0.5, "ag_args": {"name_suffix": "_r19", "priority": 20}},
#         ],
#         "RF": [
#             {"criterion": "gini", "ag_args": {"name_suffix": "Gini", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "entropy", "ag_args": {"name_suffix": "Entr", "problem_types": ["binary", "multiclass"]}},
#             {"criterion": "squared_error", "ag_args": {"name_suffix": "MSE", "problem_types": ["regression", "quantile"]}},
#             {"min_samples_leaf": 5, "max_leaf_nodes": 50000, "max_features": 0.5, "ag_args": {"name_suffix": "_r5", "priority": 19}},
#         ],
#         "GBM": [
#             {"extra_trees": True, "ag_args": {"name_suffix": "XT"}},
#             {},
#             "GBMLarge",
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.7248284762542815,
#                 "learning_rate": 0.07947286942946127,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 89,
#                 "ag_args": {"name_suffix": "_r158", "priority": 18},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7832570544199176,
#                 "learning_rate": 0.021720607471727896,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 21,
#                 "ag_args": {"name_suffix": "_r118", "priority": 17},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.7113010892989156,
#                 "learning_rate": 0.012535427424259274,
#                 "min_data_in_leaf": 16,
#                 "num_leaves": 48,
#                 "ag_args": {"name_suffix": "_r97", "priority": 16},
#             },
#             {
#                 "extra_trees": True,
#                 "feature_fraction": 0.45555769907110816,
#                 "learning_rate": 0.009591347321206594,
#                 "min_data_in_leaf": 50,
#                 "num_leaves": 110,
#                 "ag_args": {"name_suffix": "_r71", "priority": 15},
#             },
#             {
#                 "extra_trees": False,
#                 "feature_fraction": 0.40979710161022476,
#                 "learning_rate": 0.008708890211023034,
#                 "min_data_in_leaf": 3,
#                 "num_leaves": 80,
#                 "ag_args": {"name_suffix": "_r111", "priority": 14},
#             },
#         ],
#         "XGB": {},
#         "FASTAI": [
#             {},
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6167722379778131,
#                 "epochs": 44,
#                 "layers": [200, 100, 50],
#                 "lr": 0.053440377855629266,
#                 "ps": 0.48477211305443607,
#                 "ag_args": {"name_suffix": "_r25", "priority": 13},
#             },
#             {
#                 "bs": 1024,
#                 "emb_drop": 0.6046989241462619,
#                 "epochs": 48,
#                 "layers": [200, 100, 50],
#                 "lr": 0.00775309042164966,
#                 "ps": 0.09244767444160731,
#                 "ag_args": {"name_suffix": "_r51", "priority": 12},
#             },
#             {
#                 "bs": 512,
#                 "emb_drop": 0.6557225316526186,
#                 "epochs": 49,
#                 "layers": [200, 100],
#                 "lr": 0.023627682025564638,
#                 "ps": 0.519566584552178,
#                 "ag_args": {"name_suffix": "_r82", "priority": 11},
#             },
#             {
#                 "bs": 2048,
#                 "emb_drop": 0.4066210919034579,
#                 "epochs": 43,
#                 "layers": [400, 200],
#                 "lr": 0.0029598312717673434,
#                 "ps": 0.4378695797438974,
#                 "ag_args": {"name_suffix": "_r121", "priority": 10},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.44339037504795686,
#                 "epochs": 31,
#                 "layers": [400, 200, 100],
#                 "lr": 0.008615195908919904,
#                 "ps": 0.19220253419114286,
#                 "ag_args": {"name_suffix": "_r145", "priority": 9},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.12106594798980945,
#                 "epochs": 38,
#                 "layers": [200, 100, 50],
#                 "lr": 0.037991970245029975,
#                 "ps": 0.33120008492595093,
#                 "ag_args": {"name_suffix": "_r173", "priority": 8},
#             },
#             {
#                 "bs": 128,
#                 "emb_drop": 0.4599138419358,
#                 "epochs": 47,
#                 "layers": [200, 100],
#                 "lr": 0.03888383281136287,
#                 "ps": 0.28193673177122863,
#                 "ag_args": {"name_suffix": "_r128", "priority": 7},
#             },
#         ],
#         "CAT": [
#             {},
#             {"depth": 5, "l2_leaf_reg": 4.774992314058497, "learning_rate": 0.038551267822920274, "ag_args": {"name_suffix": "_r16", "priority": 6}},
#             {"depth": 4, "l2_leaf_reg": 1.9950125740798321, "learning_rate": 0.028091050379971633, "ag_args": {"name_suffix": "_r42", "priority": 5}},
#             {"depth": 6, "l2_leaf_reg": 1.8298803017644376, "learning_rate": 0.017844259810823604, "ag_args": {"name_suffix": "_r93", "priority": 4}},
#             {"depth": 7, "l2_leaf_reg": 4.81099604606794, "learning_rate": 0.019085060180573103, "ag_args": {"name_suffix": "_r44", "priority": 3}},
#         ],
#         "KNN": [
#             {"weights": "uniform", "ag_args": {"name_suffix": "Unif"}},
#             {"weights": "distance", "ag_args": {"name_suffix": "Dist"}},
#         ],
#     },
#     zeroshot=hyperparameter_portfolio_zeroshot_2023,

# %%
#设置训练精度
presets='good_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=5
# stacking的级别
num_stack_levels=2
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.11 GB / 15.92 GB (50.9%)
# Disk Space Avail:   311.11 GB / 931.51 GB (33.4%)
# ===================================================
# Presets specified: ['good_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-01 12:02:41,840	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "models\Teacher\good_quality-20241101-120236\ds_sub_fit\sub_fit_ho"
# (_dystack pid=43532) Running DyStack sub-fit ...
# (_dystack pid=43532) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=43532) AutoGluon will save models to "models\Teacher\good_quality-20241101-120236\ds_sub_fit\sub_fit_ho"
# (_dystack pid=43532) Train Data Rows:    274
# (_dystack pid=43532) Train Data Columns: 36
# (_dystack pid=43532) Label Column:       label
# (_dystack pid=43532) Problem Type:       multiclass
# (_dystack pid=43532) Preprocessing data ...
# (_dystack pid=43532) Train Data Class Count: 3
# (_dystack pid=43532) Using Feature Generators to preprocess the data ...
# (_dystack pid=43532) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=43532) 	Available Memory:                    7793.28 MB
# (_dystack pid=43532) 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=43532) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=43532) 	Stage 1 Generators:
# (_dystack pid=43532) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=43532) 	Stage 2 Generators:
# (_dystack pid=43532) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=43532) 	Stage 3 Generators:
# (_dystack pid=43532) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=43532) 	Stage 4 Generators:
# (_dystack pid=43532) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=43532) 	Stage 5 Generators:
# (_dystack pid=43532) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=43532) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=43532) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=43532) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=43532) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=43532) 	0.1s = Fit runtime
# (_dystack pid=43532) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=43532) 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# (_dystack pid=43532) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=43532) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=43532) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=43532) User-specified model hyperparameters to be fit:
# (_dystack pid=43532) {
# (_dystack pid=43532) 	'NN_TORCH': {},
# (_dystack pid=43532) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=43532) 	'CAT': {},
# (_dystack pid=43532) 	'XGB': {},
# (_dystack pid=43532) 	'FASTAI': {},
# (_dystack pid=43532) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=43532) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=43532) }
# (_dystack pid=43532) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=43532) Fitting 11 L1 models ...
# (_dystack pid=43532) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 594.15s of the 891.45s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=43532) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=43532) 	11.23s	 = Training   runtime
# (_dystack pid=43532) 	0.14s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 575.87s of the 873.17s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=43532) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=43532) 	3.02s	 = Training   runtime
# (_dystack pid=43532) 	0.03s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBM_BAG_L1 ... Training model for up to 567.53s of the 864.83s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_dystack pid=43532) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=43532) 	2.99s	 = Training   runtime
# (_dystack pid=43532) 	0.01s	 = Validation runtime
# (_dystack pid=43532) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 559.51s of the 856.8s of remaining time.
# (_dystack pid=43532) 	0.8504	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.84s	 = Training   runtime
# (_dystack pid=43532) 	0.08s	 = Validation runtime
# (_dystack pid=43532) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 558.47s of the 855.77s of remaining time.
# (_dystack pid=43532) 	0.8394	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.79s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: CatBoost_BAG_L1 ... Training model for up to 557.56s of the 854.86s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_dystack pid=43532) 	0.854	 = Validation score   (accuracy)
# (_dystack pid=43532) 	17.33s	 = Training   runtime
# (_dystack pid=43532) 	0.01s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 535.16s of the 832.46s of remaining time.
# (_dystack pid=43532) 	0.8686	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.8s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 534.23s of the 831.53s of remaining time.
# (_dystack pid=43532) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.75s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: XGBoost_BAG_L1 ... Training model for up to 533.36s of the 830.66s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_dystack pid=43532) 	0.865	 = Validation score   (accuracy)
# (_dystack pid=43532) 	3.23s	 = Training   runtime
# (_dystack pid=43532) 	0.03s	 = Validation runtime
# (_dystack pid=43532) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 525.27s of the 822.57s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=37676) Stack (most recent call first):
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=37676)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=37676)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap_external>
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line
# (_ray_fit pid=41996) 940
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) exec_module
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=41996) 690 in
# (_ray_fit pid=41996) _load_unlocked
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 1147 in
# (_ray_fit pid=41996) _find_and_load_unlocked
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line
# (_ray_fit pid=41996) 241
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) _call_with_frames_removed
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File
# (_ray_fit pid=41996) "<frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 1232 in _handle_fromlist
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line
# (_ray_fit pid=41996) 40 in <module>
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 241 in _call_with_frames_removed
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap_external>"
# (_ray_fit pid=41996) , line 940
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) exec_module
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap>", line
# (_ray_fit pid=41996) 690 in _load_unlocked
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 1147
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) _find_and_load_unlocked
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 1176 in _find_and_load
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 241
# (_ray_fit pid=41996)  in _call_with_frames_removed
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>"
# (_ray_fit pid=41996) , line 1232
# (_ray_fit pid=41996)  in _handle_fromlist
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>", line 241
# (_ray_fit pid=41996)  in _call_with_frames_removed
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap_external>
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line
# (_ray_fit pid=41996) 940 in
# (_ray_fit pid=41996) exec_module
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) <frozen importlib._bootstrap>
# (_ray_fit pid=41996) ", line 690 in
# (_ray_fit pid=41996) _load_unlocked
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File "<frozen importlib._bootstrap>", line
# (_ray_fit pid=41996) 1147 in _find_and_load_unlocked
# (_ray_fit pid=41996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line 22 in inner
# (_ray_fit pid=41996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line 284 in
# (_ray_fit pid=41996) __init__
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line 45
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) __init__
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=41996)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py"
# (_ray_fit pid=41996) , line 196
# (_ray_fit pid=41996)  in _fit
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line 856
# (_ray_fit pid=41996)  in
# (_ray_fit pid=41996) fit
# (_ray_fit pid=41996)   File
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py"
# (_ray_fit pid=41996) , line 402 in _ray_fit
# (_ray_fit pid=41996)
# (_ray_fit pid=41996)   File
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py"
# (_ray_fit pid=41996) , line
# (_ray_fit pid=41996) 879 in
# (_ray_fit pid=41996) main_loop
# (_ray_fit pid=41996)   File "
# (_ray_fit pid=41996) d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py
# (_ray_fit pid=41996) "
# (_ray_fit pid=41996) , line 282 in <module>
# (_dystack pid=43532) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=43532) 	21.51s	 = Training   runtime
# (_dystack pid=43532) 	0.17s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 498.3s of the 795.6s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_ray_fit pid=45260) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 80x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 60x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 67x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 68x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 61x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 53x across cluster]
# (_ray_fit pid=45260)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 12x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 6x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 12x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 6x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 6x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 6x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 6x across cluster]
# (_ray_fit pid=45260)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 6x across cluster]
# (_dystack pid=43532) 	0.8723	 = Validation score   (accuracy)
# (_dystack pid=43532) 	5.52s	 = Training   runtime
# (_dystack pid=43532) 	0.03s	 = Validation runtime
# (_dystack pid=43532) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 784.86s of remaining time.
# (_dystack pid=43532) 	Ensemble Weights: {'ExtraTreesEntr_BAG_L1': 0.333, 'XGBoost_BAG_L1': 0.2, 'LightGBMLarge_BAG_L1': 0.2, 'NeuralNetFastAI_BAG_L1': 0.133, 'LightGBM_BAG_L1': 0.067, 'NeuralNetTorch_BAG_L1': 0.067}
# (_dystack pid=43532) 	0.9015	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.23s	 = Training   runtime
# (_dystack pid=43532) 	0.0s	 = Validation runtime
# (_dystack pid=43532) Fitting 11 L2 models ...
# (_dystack pid=43532) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 784.62s of the 784.6s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=43532) 	0.9124	 = Validation score   (accuracy)
# (_dystack pid=43532) 	11.59s	 = Training   runtime
# (_dystack pid=43532) 	0.14s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 767.1s of the 767.07s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=43532) 	0.9051	 = Validation score   (accuracy)
# (_dystack pid=43532) 	2.8s	 = Training   runtime
# (_dystack pid=43532) 	0.01s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBM_BAG_L2 ... Training model for up to 757.99s of the 757.96s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.19%)
# (_dystack pid=43532) 	0.9051	 = Validation score   (accuracy)
# (_dystack pid=43532) 	2.77s	 = Training   runtime
# (_dystack pid=43532) 	0.01s	 = Validation runtime
# (_dystack pid=43532) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 749.94s of the 749.92s of remaining time.
# (_dystack pid=43532) 	0.8905	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.91s	 = Training   runtime
# (_dystack pid=43532) 	0.14s	 = Validation runtime
# (_dystack pid=43532) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 748.83s of the 748.81s of remaining time.
# (_dystack pid=43532) 	0.8978	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.87s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: CatBoost_BAG_L2 ... Training model for up to 747.82s of the 747.8s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=43532) 	0.9051	 = Validation score   (accuracy)
# (_dystack pid=43532) 	32.63s	 = Training   runtime
# (_dystack pid=43532) 	0.03s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 710.27s of the 710.24s of remaining time.
# (_dystack pid=43532) 	0.8942	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.83s	 = Training   runtime
# (_dystack pid=43532) 	0.09s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 709.3s of the 709.29s of remaining time.
# (_dystack pid=43532) 	0.8905	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.81s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: XGBoost_BAG_L2 ... Training model for up to 708.35s of the 708.34s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# (_dystack pid=43532) 	0.8978	 = Validation score   (accuracy)
# (_dystack pid=43532) 	3.87s	 = Training   runtime
# (_dystack pid=43532) 	0.05s	 = Validation runtime
# (_dystack pid=43532) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 699.65s of the 699.63s of remaining time.
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=45660) Stack (most recent call first):
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=45660)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=45660)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=43532) 	0.9088	 = Validation score   (accuracy)
# (_dystack pid=43532) 	17.17s	 = Training   runtime
# (_dystack pid=43532) 	0.2s	 = Validation runtime
# (_dystack pid=43532) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 677.33s of the 677.31s of remaining time.
# (_ray_fit pid=42696) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=42696)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=42696)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=43532) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# (_dystack pid=43532) 	0.9161	 = Validation score   (accuracy)
# (_dystack pid=43532) 	6.36s	 = Training   runtime
# (_dystack pid=43532) 	0.01s	 = Validation runtime
# (_dystack pid=43532) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 665.28s of remaining time.
# (_dystack pid=43532) 	Ensemble Weights: {'LightGBMLarge_BAG_L2': 1.0}
# (_dystack pid=43532) 	0.9161	 = Validation score   (accuracy)
# (_dystack pid=43532) 	0.27s	 = Training   runtime
# (_dystack pid=43532) 	0.0s	 = Validation runtime
# (_dystack pid=43532) AutoGluon training complete, total runtime = 226.65s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 74.9 rows/s (35 batch size)
# (_dystack pid=43532) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=43532) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=43532) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=43532) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=43532) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=43532) 	Stopping at the best epoch learned earlier - 11.
# (_dystack pid=43532) 	0.4s	 = Training   runtime
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=43532) 	0.25s	 = Training   runtime
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=43532) 	0.15s	 = Training   runtime
# (_dystack pid=43532) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	0.84s	 = Training   runtime
# (_dystack pid=43532) 	0.08s	 = Validation runtime
# (_dystack pid=43532) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	0.79s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=43532) 	1.3s	 = Training   runtime
# (_dystack pid=43532) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	0.8s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	0.75s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=43532) 	0.14s	 = Training   runtime
# (_dystack pid=43532) Fitting 1 L1 models ...
# (_dystack pid=43532) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=43532) Stack (most recent call first):
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_dystack pid=43532)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_dystack pid=43532)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# ...
# (_dystack pid=43532) 	0.83s	 = Training   runtime
# (_dystack pid=43532) 	0.09s	 = Validation runtime
# (_dystack pid=43532) Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	0.81s	 = Training   runtime
# (_dystack pid=43532) 	0.1s	 = Validation runtime
# (_dystack pid=43532) Fitting 1 L2 models ...
# (_dystack pid=43532) Fitting model: XGBoost_BAG_L2_FULL ...
# (_dystack pid=43532) 	0.17s	 = Training   runtime
# (_dystack pid=43532) Fitting 1 L2 models ...
# (_dystack pid=43532) Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# (_dystack pid=43532) 	0.88s	 = Training   runtime
# (_dystack pid=43532) Fitting 1 L2 models ...
# (_dystack pid=43532) Fitting model: LightGBMLarge_BAG_L2_FULL ...
# (_dystack pid=43532) 	0.34s	 = Training   runtime
# (_dystack pid=43532) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=43532) 	Ensemble Weights: {'LightGBMLarge_BAG_L2': 1.0}
# (_dystack pid=43532) 	0.27s	 = Training   runtime
# (_dystack pid=43532) Updated best model to "LightGBMLarge_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "LightGBMLarge_BAG_L2_FULL" for predict() and predict_proba().
# (_dystack pid=43532) Refit complete, total runtime = 35.27s ... Best model: "LightGBMLarge_BAG_L2_FULL"
# (_dystack pid=43532) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\good_quality-20241101-120236\ds_sub_fit\sub_fit_ho")
# (_dystack pid=43532) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBMXT_BAG_L2_FULL       0.971429   0.905109    accuracy        0.378258            NaN  34.943623                 0.001214                     NaN           0.161211            2       True         14
# 1           CatBoost_BAG_L2_FULL       0.971429   0.905109    accuracy        0.382046            NaN  35.112170                 0.005001                     NaN           0.329758            2       True         18
# 2     ExtraTreesGini_BAG_L2_FULL       0.971429   0.894161    accuracy        0.424407            NaN  35.609862                 0.047362                0.087165           0.827450            2       True         19
# 3     ExtraTreesEntr_BAG_L2_FULL       0.971429   0.890511    accuracy        0.440570            NaN  35.589590                 0.063525                0.104470           0.807178            2       True         20
# 4   RandomForestEntr_BAG_L2_FULL       0.971429   0.897810    accuracy        0.466490            NaN  35.653451                 0.089445                0.095218           0.871040            2       True         17
# 5   RandomForestGini_BAG_L2_FULL       0.942857   0.890511    accuracy        0.489662            NaN  35.692477                 0.112617                0.142227           0.910065            2       True         16
# 6           LightGBM_BAG_L1_FULL       0.914286   0.872263    accuracy        0.000000            NaN   0.151237                 0.000000                     NaN           0.151237            1       True          3
# 7            XGBoost_BAG_L1_FULL       0.914286   0.864964    accuracy        0.004573            NaN   0.136536                 0.004573                     NaN           0.136536            1       True          9
# 8       WeightedEnsemble_L2_FULL       0.914286   0.901460    accuracy        0.126339            NaN  31.030255                 0.007377                     NaN           0.227101            2       True         12
# 9           LightGBM_BAG_L2_FULL       0.914286   0.905109    accuracy        0.381050            NaN  34.942296                 0.004005                     NaN           0.159884            2       True         15
# 10           XGBoost_BAG_L2_FULL       0.914286   0.897810    accuracy        0.383044            NaN  34.956542                 0.006000                     NaN           0.174130            2       True         21
# 11    NeuralNetTorch_BAG_L2_FULL       0.914286   0.908759    accuracy        0.409748            NaN  35.661493                 0.032703                     NaN           0.879081            2       True         22
# 12        LightGBMXT_BAG_L1_FULL       0.885714   0.872263    accuracy        0.006429            NaN   0.246912                 0.006429                     NaN           0.246912            1       True          2
# 13     LightGBMLarge_BAG_L1_FULL       0.885714   0.872263    accuracy        0.015097            NaN   0.568908                 0.015097                     NaN           0.568908            1       True         11
# 14    ExtraTreesGini_BAG_L1_FULL       0.885714   0.868613    accuracy        0.062805       0.095020   0.797215                 0.062805                0.095020           0.797215            1       True          7
# 15  RandomForestEntr_BAG_L1_FULL       0.885714   0.839416    accuracy        0.076531       0.098168   0.792607                 0.076531                0.098168           0.792607            1       True          5
# 16   NeuralNetFastAI_BAG_L2_FULL       0.885714   0.912409    accuracy        0.390045            NaN  35.016558                 0.013000                     NaN           0.234147            2       True         13
# 17      WeightedEnsemble_L3_FULL       0.885714   0.916058    accuracy        0.397214            NaN  35.386159                 0.000000                     NaN           0.268681            3       True         24
# 18     LightGBMLarge_BAG_L2_FULL       0.885714   0.916058    accuracy        0.397214            NaN  35.117478                 0.020169                     NaN           0.335067            2       True         23
# 19    ExtraTreesEntr_BAG_L1_FULL       0.857143   0.864964    accuracy        0.076253       0.097554   0.752181                 0.076253                0.097554           0.752181            1       True          8
# 20  RandomForestGini_BAG_L1_FULL       0.857143   0.850365    accuracy        0.106316       0.083277   0.840971                 0.106316                0.083277           0.840971            1       True          4
# 21          CatBoost_BAG_L1_FULL       0.800000   0.854015    accuracy        0.006001            NaN   1.301552                 0.006001                     NaN           1.301552            1       True          6
# 22    NeuralNetTorch_BAG_L1_FULL       0.800000   0.872263    accuracy        0.010037            NaN  28.798371                 0.010037                     NaN          28.798371            1       True         10
# 23   NeuralNetFastAI_BAG_L1_FULL       0.742857   0.872263    accuracy        0.013001            NaN   0.395920                 0.013001                     NaN           0.395920            1       True          1
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	274s	 = DyStack   runtime |	3326s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 3326s
# AutoGluon will save models to "models\Teacher\good_quality-20241101-120236"
# Train Data Rows:    309
# Train Data Columns: 36
# Label Column:       label
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7310.67 MB
# 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.1s = Fit runtime
# 	36 features in original data used to generate 36 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.27s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3325.95s of the 3325.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9029	 = Validation score   (accuracy)
# 	8.73s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3309.58s of the 3309.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.8932	 = Validation score   (accuracy)
# 	2.67s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3301.32s of the 3301.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.8964	 = Validation score   (accuracy)
# 	3.05s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 3293.39s of the 3293.38s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 3292.38s of the 3292.38s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.83s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3291.39s of the 3291.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	0.8738	 = Validation score   (accuracy)
# 	24.29s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 3262.43s of the 3262.43s of remaining time.
# 	0.8932	 = Validation score   (accuracy)
# 	0.87s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 3261.43s of the 3261.43s of remaining time.
# 	0.8932	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3260.52s of the 3260.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	0.8835	 = Validation score   (accuracy)
# 	3.25s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3252.43s of the 3252.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8835	 = Validation score   (accuracy)
# 	31.65s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3215.87s of the 3215.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8997	 = Validation score   (accuracy)
# 	4.83s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3206.55s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.333, 'ExtraTreesGini_BAG_L1': 0.333, 'ExtraTreesEntr_BAG_L1': 0.333}
# 	0.9159	 = Validation score   (accuracy)
# 	0.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 119.88s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 295.5 rows/s (39 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	0.44s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	0.29s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.28s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.86s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.83s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	2.23s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.87s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.76s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.11s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	10.26s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.53s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.333, 'ExtraTreesGini_BAG_L1': 0.333, 'ExtraTreesEntr_BAG_L1': 0.333}
# 	0.17s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "WeightedEnsemble_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 14.81s ... Best model: "WeightedEnsemble_L2_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\good_quality-20241101-120236")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L2_FULL
# *** Summary of fit() ***
# Estimated performance of each model:
#                            model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            WeightedEnsemble_L2   0.915858    accuracy       0.301683  10.529340                0.001000           0.174354            2      False         12
# 1         NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.107444   8.728442                0.107444           8.728442            1      False          1
# 2           LightGBMLarge_BAG_L1   0.899676    accuracy       0.010947   4.829864                0.010947           4.829864            1      False         11
# 3                LightGBM_BAG_L1   0.896440    accuracy       0.009708   3.049304                0.009708           3.049304            1      False          3
# 4              LightGBMXT_BAG_L1   0.893204    accuracy       0.009556   2.666023                0.009556           2.666023            1      False          2
# 5          ExtraTreesGini_BAG_L1   0.893204    accuracy       0.088104   0.867973                0.088104           0.867973            1       True          7
# 6          ExtraTreesEntr_BAG_L1   0.893204    accuracy       0.105135   0.758571                0.105135           0.758571            1       True          8
# 7                 XGBoost_BAG_L1   0.883495    accuracy       0.011522   3.248828                0.011522           3.248828            1      False          9
# 8          NeuralNetTorch_BAG_L1   0.883495    accuracy       0.149203  31.649343                0.149203          31.649343            1      False         10
# 9                CatBoost_BAG_L1   0.873786    accuracy       0.016008  24.288788                0.016008          24.288788            1      False          6
# 10       RandomForestGini_BAG_L1   0.864078    accuracy       0.089584   0.857883                0.089584           0.857883            1       True          4
# 11       RandomForestEntr_BAG_L1   0.864078    accuracy       0.118437   0.834222                0.118437           0.834222            1       True          5
# 12    ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       0.088104   0.867973                0.088104           0.867973            1       True         19
# 13  RandomForestGini_BAG_L1_FULL        NaN    accuracy       0.089584   0.857883                0.089584           0.857883            1       True         16
# 14    ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       0.105135   0.758571                0.105135           0.758571            1       True         20
# 15  RandomForestEntr_BAG_L1_FULL        NaN    accuracy       0.118437   0.834222                0.118437           0.834222            1       True         17
# 16           XGBoost_BAG_L1_FULL        NaN    accuracy            NaN   0.111098                     NaN           0.111098            1       True         21
# 17      WeightedEnsemble_L2_FULL        NaN    accuracy            NaN   2.240902                     NaN           0.174354            2       True         24
# 18    NeuralNetTorch_BAG_L1_FULL        NaN    accuracy            NaN  10.262152                     NaN          10.262152            1       True         22
# 19   NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN   0.440005                     NaN           0.440005            1       True         13
# 20          LightGBM_BAG_L1_FULL        NaN    accuracy            NaN   0.280909                     NaN           0.280909            1       True         15
# 21        LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN   0.293106                     NaN           0.293106            1       True         14
# 22     LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN   0.531866                     NaN           0.531866            1       True         23
# 23          CatBoost_BAG_L1_FULL        NaN    accuracy            NaN   2.225530                     NaN           2.225530            1       True         18
# Number of models trained: 24
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L2_FULL
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.62      0.53      0.57        15
# Exc L2-3 LINC00507 FREM3 superficial       0.77      0.88      0.82        26
#             Exc L2-4 LINC00507 GLP2R       1.00      0.60      0.75         5
#
#                             accuracy                           0.74        46
#                            macro avg       0.79      0.67      0.71        46
#                         weighted avg       0.74      0.74      0.73        46

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[ 8  7  0]
#  [ 3 23  0]
#  [ 2  0  3]]
# ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']
# ([<matplotlib.axis.YTick at 0x1b91e2e4690>,
#   <matplotlib.axis.YTick at 0x1b91e2da450>,
#   <matplotlib.axis.YTick at 0x1b91e308350>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 8  7  0]
#  [ 3 23  0]
#  [ 2  0  3]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.545308                              0.419805
# 1           0.213762                              0.733845
# 2           0.468306                              0.260289
# 3           0.327140                              0.555491
# 4           0.068103                              0.915279
# 5           0.308028                              0.607023
# 6           0.373393                              0.597136
# 7           0.062203                              0.839268
# 8           0.211592                              0.562364
# 9           0.523318                              0.365616
# 10          0.716079                              0.260934
# 11          0.204735                              0.326338
# 12          0.581169                              0.362765
# 13          0.211890                              0.670095
# 14          0.090923                              0.621965
# 15          0.271064                              0.503635
# 16          0.318386                              0.622322
# 17          0.217071                              0.583671
# 18          0.257050                              0.528094
# 19          0.522663                              0.421532
# 20          0.179697                              0.227205
# 21          0.552654                              0.401227
# 22          0.182560                              0.758169
# 23          0.137154                              0.816733
# 24          0.615751                              0.263438
# 25          0.446282                              0.454782
# 26          0.744747                              0.196897
# 27          0.294670                              0.674673
# 28          0.130332                              0.724167
# 29          0.561834                              0.377213
# 30          0.712532                              0.183447
# 31          0.108526                              0.868123
# 32          0.032693                              0.942574
# 33          0.214153                              0.712162
# 34          0.105832                              0.773876
# 35          0.413452                              0.402481
# 36          0.397891                              0.396874
# 37          0.125335                              0.720535
# 38          0.169618                              0.697242
# 39          0.038770                              0.908285
# 40          0.361404                              0.212634
# 41          0.203798                              0.671856
# 42          0.203060                              0.703232
# 43          0.369915                              0.444684
# 44          0.330873                              0.565036
# 45          0.201502                              0.630333
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.034887
# 1                   0.052392
# 2                   0.271405
# 3                   0.117369
# 4                   0.016618
# 5                   0.084949
# 6                   0.029471
# 7                   0.098529
# 8                   0.226043
# 9                   0.111066
# 10                  0.022988
# 11                  0.468927
# 12                  0.056066
# 13                  0.118015
# 14                  0.287112
# 15                  0.225301
# 16                  0.059292
# 17                  0.199258
# 18                  0.214856
# 19                  0.055805
# 20                  0.593098
# 21                  0.046119
# 22                  0.059271
# 23                  0.046113
# 24                  0.120811
# 25                  0.098936
# 26                  0.058355
# 27                  0.030657
# 28                  0.145501
# 29                  0.060952
# 30                  0.104021
# 31                  0.023352
# 32                  0.024733
# 33                  0.073685
# 34                  0.120293
# 35                  0.184067
# 36                  0.205235
# 37                  0.154130
# 38                  0.133140
# 39                  0.052944
# 40                  0.425962
# 41                  0.124345
# 42                  0.093708
# 43                  0.185401
# 44                  0.104091
# 45                  0.168164

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	35.7s	= Expected runtime (7.14s per shuffle set)
# 	1.74s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                         importance    stddev   p_value  n  p99_high   p99_low
# L23_depth_normalized  9.565217e-02  0.032969  0.001455  5  0.163536  0.027768
# FAP_rheobase          9.130435e-02  0.041816  0.004073  5  0.177404  0.005205
# input_resistance      4.347826e-02  0.034373  0.023710  5  0.114252 -0.027295
# VmatSag               3.913043e-02  0.018188  0.004290  5  0.076580  0.001681
# TS2_avg_upstroke      3.478261e-02  0.011907  0.001419  5  0.059299  0.010266
# tau                   3.478261e-02  0.024786  0.017460  5  0.085818 -0.016253
# FAP_num_APs           3.043478e-02  0.011907  0.002318  5  0.054951  0.005918
# TS2_up_down_ratio     3.043478e-02  0.019444  0.012448  5  0.070470 -0.009601
# TS2_rheobase          3.043478e-02  0.024786  0.025803  5  0.081470 -0.020601
# FAP_avg_downstroke    2.608696e-02  0.018188  0.016339  5  0.063537 -0.011363
# TS1_avg_downstroke    2.173913e-02  0.000000  0.500000  5  0.021739  0.021739
# FAP_threshold         2.173913e-02  0.030744  0.094502  5  0.085041 -0.041563
# FAP_peak              1.304348e-02  0.011907  0.035242  5  0.037560 -0.011473
# sag                   1.304348e-02  0.024786  0.152279  5  0.064079 -0.037992
# FAP_maxdownstroke     8.695652e-03  0.011907  0.088904  5  0.033212 -0.015821
# TS2_maxupstroke       8.695652e-03  0.011907  0.088904  5  0.033212 -0.015821
# vmbaseM               8.695652e-03  0.011907  0.088904  5  0.033212 -0.015821
# TS2_threshold         8.695652e-03  0.019444  0.186950  5  0.048731 -0.031340
# TS2_adp_index         8.695652e-03  0.032969  0.293525  5  0.076579 -0.059188
# TS1_threshold         8.695652e-03  0.019444  0.186950  5  0.048731 -0.031340
# TS1_num_APs           8.695652e-03  0.019444  0.186950  5  0.048731 -0.031340
# TS2_num_APs           8.695652e-03  0.019444  0.186950  5  0.048731 -0.031340
# TS1_adp_index         4.347826e-03  0.018188  0.310654  5  0.041798 -0.033102
# TS1_halfwidth         0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_avg_downstroke   -2.220446e-17  0.015372  0.500000  5  0.031651 -0.031651
# FAP_halfwidth        -2.220446e-17  0.015372  0.500000  5  0.031651 -0.031651
# TS1_rheobase         -4.440892e-17  0.026625  0.500000  5  0.054821 -0.054821
# TS2_peak             -4.347826e-03  0.009722  0.813050  5  0.015670 -0.024366
# TS1_maxupstroke      -4.347826e-03  0.009722  0.813050  5  0.015670 -0.024366
# TS1_up_down_ratio    -4.347826e-03  0.018188  0.689346  5  0.033102 -0.041798
# FAP_up_down_ratio    -8.695652e-03  0.011907  0.911096  5  0.015821 -0.033212
# TS1_maxdownstroke    -8.695652e-03  0.019444  0.813050  5  0.031340 -0.048731
# FAP_maxupstroke      -1.304348e-02  0.011907  0.964758  5  0.011473 -0.037560
# TS2_maxdownstroke    -1.739130e-02  0.009722  0.991935  5  0.002626 -0.037409
# TS1_avg_upstroke     -2.173913e-02  0.015372  0.982945  5  0.009912 -0.053390
# FAP_avg_upstroke     -2.173913e-02  0.000000  0.500000  5 -0.021739 -0.021739

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L2_FULL
# {'accuracy': 0.7391304347826086,
#  'balanced_accuracy': 0.6726495726495726,
#  'mcc': 0.5164636199645736,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     8
#  Exc L2-3 LINC00507 FREM3 superficial                 3
#  Exc L2-4 LINC00507 GLP2R                             2
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                         7
#  Exc L2-3 LINC00507 FREM3 superficial                                    23
#  Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     3  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6153846153846154,
#    'recall': 0.5333333333333333,
#    'f1-score': 0.5714285714285714,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7666666666666667,
#    'recall': 0.8846153846153846,
#    'f1-score': 0.8214285714285714,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 1.0,
#    'recall': 0.6,
#    'f1-score': 0.75,
#    'support': 5.0},
#   'accuracy': 0.7391304347826086,
#   'macro avg': {'precision': 0.794017094017094,
#    'recall': 0.6726495726495726,
#    'f1-score': 0.7142857142857143,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.7426978818283166,
#    'recall': 0.7391304347826086,
#    'f1-score': 0.7321428571428572,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data, extra_metrics=['accuracy','f1_macro', 'balanced_accuracy','f1_micro', 'f1_weighted'],extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                            model  score_test  accuracy  f1_macro  \
# 0       WeightedEnsemble_L2_FULL    0.739130  0.739130  0.714286
# 1         LightGBMXT_BAG_L1_FULL    0.717391  0.717391  0.662081
# 2   RandomForestGini_BAG_L1_FULL    0.717391  0.717391  0.670715
# 3        RandomForestGini_BAG_L1    0.717391  0.717391  0.670715
# 4           LightGBM_BAG_L1_FULL    0.695652  0.695652  0.659213
# 5     ExtraTreesEntr_BAG_L1_FULL    0.695652  0.695652  0.596375
# 6          ExtraTreesEntr_BAG_L1    0.695652  0.695652  0.596375
# 7          ExtraTreesGini_BAG_L1    0.695652  0.695652  0.597853
# 8   RandomForestEntr_BAG_L1_FULL    0.695652  0.695652  0.626263
# 9        RandomForestEntr_BAG_L1    0.695652  0.695652  0.626263
# 10    ExtraTreesGini_BAG_L1_FULL    0.695652  0.695652  0.597853
# 11          CatBoost_BAG_L1_FULL    0.673913  0.673913  0.612636
# 12   NeuralNetFastAI_BAG_L1_FULL    0.673913  0.673913  0.666667
# 13    NeuralNetTorch_BAG_L1_FULL    0.673913  0.673913  0.622799
# 14           XGBoost_BAG_L1_FULL    0.652174  0.652174  0.506173
# 15     LightGBMLarge_BAG_L1_FULL    0.608696  0.608696  0.550991
# 16           WeightedEnsemble_L2         NaN       NaN       NaN
# 17        NeuralNetFastAI_BAG_L1         NaN       NaN       NaN
# 18          LightGBMLarge_BAG_L1         NaN       NaN       NaN
# 19               LightGBM_BAG_L1         NaN       NaN       NaN
# 20             LightGBMXT_BAG_L1         NaN       NaN       NaN
# 21                XGBoost_BAG_L1         NaN       NaN       NaN
# 22         NeuralNetTorch_BAG_L1         NaN       NaN       NaN
# 23               CatBoost_BAG_L1         NaN       NaN       NaN
#
#     balanced_accuracy  f1_micro  f1_weighted  score_val eval_metric  \
# 0            0.672650  0.739130     0.732143        NaN    accuracy
# 1            0.659829  0.717391     0.712100        NaN    accuracy
# 2            0.650427  0.717391     0.704189        NaN    accuracy
# 3            0.650427  0.717391     0.704189   0.864078    accuracy
# 4            0.691453  0.695652     0.689454        NaN    accuracy
# 5            0.574359  0.695652     0.672616        NaN    accuracy
# 6            0.574359  0.695652     0.672616   0.893204    accuracy
# 7            0.574359  0.695652     0.670707   0.893204    accuracy
# 8            0.637607  0.695652     0.688918        NaN    accuracy
# 9            0.637607  0.695652     0.688918   0.864078    accuracy
# 10           0.574359  0.695652     0.670707        NaN    accuracy
# 11           0.624786  0.673913     0.670240        NaN    accuracy
# 12           0.624786  0.673913     0.668478        NaN    accuracy
# 13           0.580342  0.673913     0.667645        NaN    accuracy
# 14           0.504274  0.652174     0.642995        NaN    accuracy
# 15           0.586325  0.608696     0.614643        NaN    accuracy
# 16                NaN       NaN          NaN   0.915858    accuracy
# 17                NaN       NaN          NaN   0.902913    accuracy
# 18                NaN       NaN          NaN   0.899676    accuracy
# 19                NaN       NaN          NaN   0.896440    accuracy
# 20                NaN       NaN          NaN   0.893204    accuracy
# 21                NaN       NaN          NaN   0.883495    accuracy
# 22                NaN       NaN          NaN   0.883495    accuracy
# 23                NaN       NaN          NaN   0.873786    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.176749            NaN   2.240902                 0.000000
# 1         0.010198            NaN   0.293106                 0.010198
# 2         0.092157       0.089584   0.857883                 0.092157
# 3         0.103734       0.089584   0.857883                 0.103734
# 4         0.010088            NaN   0.280909                 0.010088
# 5         0.073816       0.105135   0.758571                 0.073816
# 6         0.075752       0.105135   0.758571                 0.075752
# 7         0.080381       0.088104   0.867973                 0.080381
# 8         0.081129       0.118437   0.834222                 0.081129
# 9         0.091528       0.118437   0.834222                 0.091528
# 10        0.092851       0.088104   0.867973                 0.092851
# 11        0.003224            NaN   2.225530                 0.003224
# 12        0.010082            NaN   0.440005                 0.010082
# 13        0.025824            NaN  10.262152                 0.025824
# 14        0.006186            NaN   0.111098                 0.006186
# 15        0.020199            NaN   0.531866                 0.020199
# 16             NaN       0.301683  10.529340                      NaN
# 17             NaN       0.107444   8.728442                      NaN
# 18             NaN       0.010947   4.829864                      NaN
# 19             NaN       0.009708   3.049304                      NaN
# 20             NaN       0.009556   2.666023                      NaN
# 21             NaN       0.011522   3.248828                      NaN
# 22             NaN       0.149203  31.649343                      NaN
# 23             NaN       0.016008  24.288788                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           0.174354            2       True
# 1                      NaN           0.293106            1       True
# 2                 0.089584           0.857883            1       True
# 3                 0.089584           0.857883            1       True
# 4                      NaN           0.280909            1       True
# 5                 0.105135           0.758571            1       True
# 6                 0.105135           0.758571            1       True
# 7                 0.088104           0.867973            1       True
# 8                 0.118437           0.834222            1       True
# 9                 0.118437           0.834222            1       True
# 10                0.088104           0.867973            1       True
# 11                     NaN           2.225530            1       True
# 12                     NaN           0.440005            1       True
# 13                     NaN          10.262152            1       True
# 14                     NaN           0.111098            1       True
# 15                     NaN           0.531866            1       True
# 16                0.001000           0.174354            2      False
# 17                0.107444           8.728442            1      False
# 18                0.010947           4.829864            1      False
# 19                0.009708           3.049304            1      False
# 20                0.009556           2.666023            1      False
# 21                0.011522           3.248828            1      False
# 22                0.149203          31.649343            1      False
# 23                0.016008          24.288788            1      False
#
#     fit_order
# 0          24
# 1          14
# 2          16
# 3           4
# 4          15
# 5          20
# 6           8
# 7           7
# 8          17
# 9           5
# 10         19
# 11         18
# 12         13
# 13         22
# 14         21
# 15         23
# 16         12
# 17          1
# 18         11
# 19          3
# 20          2
# 21          9
# 22         10
# 23          6

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_15688\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207                        Exc L2 LAMP5 LTK
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207                        Exc L2 LAMP5 LTK
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.070224                              0.899738
# 1            0.034202                              0.945466
# 2            0.118319                              0.771265
# 3            0.148939                              0.742081
# 4            0.172799                              0.777483
# ..                ...                                   ...
# 204          0.471782                              0.248943
# 205          0.113129                              0.823922
# 206          0.300644                              0.590286
# 207          0.558669                              0.376963
# 208          0.149949                              0.738216
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.030038
# 1                    0.020332
# 2                    0.110416
# 3                    0.108980
# 4                    0.049718
# ..                        ...
# 204                  0.279275
# 205                  0.062949
# 206                  0.109070
# 207                  0.064369
# 208                  0.111835
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (159, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2_FULL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.530028
# [100]	valid_set's soft_log_loss: -0.422841
# [150]	valid_set's soft_log_loss: -0.411497
# [200]	valid_set's soft_log_loss: -0.440128
# [250]	valid_set's soft_log_loss: -0.453876
# [300]	valid_set's soft_log_loss: -0.453796
# [350]	valid_set's soft_log_loss: -0.467933
# [400]	valid_set's soft_log_loss: -0.481704
# 	Note: model has different eval_metric than default.
# 	-0.4094	 = Validation score   (-soft_log_loss)
# 	1.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4681	 = Validation score   (-soft_log_loss)
# 	0.89s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0693958	test: -1.0838335	best: -1.0838335 (0)	total: 850ms	remaining: 2h 21m 35s
# 20:	learn: -0.7547858	test: -0.8117828	best: -0.8117828 (20)	total: 1.2s	remaining: 9m 28s
# 40:	learn: -0.6409283	test: -0.7035768	best: -0.7035768 (40)	total: 1.57s	remaining: 6m 22s
# 60:	learn: -0.5754659	test: -0.6248580	best: -0.6248580 (60)	total: 1.89s	remaining: 5m 8s
# 80:	learn: -0.5389876	test: -0.5866550	best: -0.5866550 (80)	total: 2.21s	remaining: 4m 30s
# 100:	learn: -0.5074115	test: -0.5540483	best: -0.5540483 (100)	total: 2.56s	remaining: 4m 10s
# 120:	learn: -0.4824281	test: -0.5278222	best: -0.5278222 (120)	total: 2.93s	remaining: 3m 59s
# 140:	learn: -0.4654168	test: -0.5094582	best: -0.5094582 (140)	total: 3.26s	remaining: 3m 47s
# 160:	learn: -0.4512471	test: -0.4984478	best: -0.4984478 (160)	total: 3.6s	remaining: 3m 40s
# 180:	learn: -0.4381457	test: -0.4808616	best: -0.4808616 (180)	total: 3.97s	remaining: 3m 35s
# 200:	learn: -0.4259624	test: -0.4694060	best: -0.4694060 (200)	total: 4.32s	remaining: 3m 30s
# 220:	learn: -0.4169940	test: -0.4575463	best: -0.4575463 (220)	total: 4.64s	remaining: 3m 25s
# 240:	learn: -0.4084267	test: -0.4539225	best: -0.4524181 (232)	total: 5.05s	remaining: 3m 24s
# 260:	learn: -0.4017440	test: -0.4482507	best: -0.4482507 (260)	total: 5.41s	remaining: 3m 21s
# 280:	learn: -0.3953384	test: -0.4416419	best: -0.4416419 (280)	total: 5.73s	remaining: 3m 18s
# 300:	learn: -0.3896016	test: -0.4351091	best: -0.4351091 (300)	total: 6.07s	remaining: 3m 15s
# 320:	learn: -0.3839883	test: -0.4306150	best: -0.4306150 (320)	total: 6.4s	remaining: 3m 13s
# 340:	learn: -0.3796024	test: -0.4295698	best: -0.4295698 (340)	total: 6.72s	remaining: 3m 10s
# 360:	learn: -0.3756925	test: -0.4268400	best: -0.4268400 (360)	total: 7.06s	remaining: 3m 8s
# 380:	learn: -0.3715344	test: -0.4226935	best: -0.4226935 (380)	total: 7.38s	remaining: 3m 6s
# 400:	learn: -0.3687773	test: -0.4208727	best: -0.4206932 (396)	total: 7.74s	remaining: 3m 5s
# 420:	learn: -0.3659152	test: -0.4175060	best: -0.4169845 (418)	total: 8.08s	remaining: 3m 3s
# 440:	learn: -0.3627547	test: -0.4158678	best: -0.4158120 (437)	total: 8.45s	remaining: 3m 3s
# 460:	learn: -0.3604597	test: -0.4159062	best: -0.4155800 (450)	total: 8.75s	remaining: 3m 1s
# 480:	learn: -0.3578402	test: -0.4160932	best: -0.4155800 (450)	total: 9.11s	remaining: 3m
# 500:	learn: -0.3558538	test: -0.4148942	best: -0.4142025 (495)	total: 9.47s	remaining: 2m 59s
# 520:	learn: -0.3539498	test: -0.4121379	best: -0.4121379 (520)	total: 9.85s	remaining: 2m 59s
# 540:	learn: -0.3521230	test: -0.4111524	best: -0.4108687 (539)	total: 10.3s	remaining: 3m
# 560:	learn: -0.3504212	test: -0.4093278	best: -0.4089297 (557)	total: 10.7s	remaining: 2m 59s
# 580:	learn: -0.3487131	test: -0.4084695	best: -0.4084695 (580)	total: 11.1s	remaining: 2m 59s
# 600:	learn: -0.3472104	test: -0.4087998	best: -0.4078386 (583)	total: 11.5s	remaining: 3m
# 620:	learn: -0.3458988	test: -0.4074192	best: -0.4063464 (612)	total: 11.9s	remaining: 3m
# 640:	learn: -0.3445926	test: -0.4089204	best: -0.4063464 (612)	total: 12.3s	remaining: 2m 59s
# 660:	learn: -0.3433512	test: -0.4067205	best: -0.4063464 (612)	total: 12.6s	remaining: 2m 58s
# 680:	learn: -0.3422376	test: -0.4053316	best: -0.4052000 (678)	total: 13s	remaining: 2m 57s
# 700:	learn: -0.3409721	test: -0.4044625	best: -0.4038827 (698)	total: 13.3s	remaining: 2m 57s
# 720:	learn: -0.3399443	test: -0.4033010	best: -0.4030958 (714)	total: 13.7s	remaining: 2m 56s
# 740:	learn: -0.3387497	test: -0.4044519	best: -0.4019377 (728)	total: 14.1s	remaining: 2m 56s
# 760:	learn: -0.3378291	test: -0.4034023	best: -0.4019377 (728)	total: 14.5s	remaining: 2m 55s
# 780:	learn: -0.3369408	test: -0.4040622	best: -0.4019377 (728)	total: 14.8s	remaining: 2m 54s
# 800:	learn: -0.3361171	test: -0.4046994	best: -0.4019377 (728)	total: 15.1s	remaining: 2m 53s
# 820:	learn: -0.3353182	test: -0.4063771	best: -0.4019377 (728)	total: 15.5s	remaining: 2m 52s
# 840:	learn: -0.3346003	test: -0.4070835	best: -0.4019377 (728)	total: 15.8s	remaining: 2m 52s
# 860:	learn: -0.3338189	test: -0.4071114	best: -0.4019377 (728)	total: 16.2s	remaining: 2m 52s
# 880:	learn: -0.3330800	test: -0.4068832	best: -0.4019377 (728)	total: 16.6s	remaining: 2m 51s
# 900:	learn: -0.3323859	test: -0.4081161	best: -0.4019377 (728)	total: 16.9s	remaining: 2m 51s
# 920:	learn: -0.3317948	test: -0.4082133	best: -0.4019377 (728)	total: 17.3s	remaining: 2m 50s
# 940:	learn: -0.3312779	test: -0.4090881	best: -0.4019377 (728)	total: 17.6s	remaining: 2m 49s
# 960:	learn: -0.3307455	test: -0.4090463	best: -0.4019377 (728)	total: 18s	remaining: 2m 49s
# 980:	learn: -0.3302131	test: -0.4097905	best: -0.4019377 (728)	total: 18.4s	remaining: 2m 48s
# 1000:	learn: -0.3296107	test: -0.4101941	best: -0.4019377 (728)	total: 18.7s	remaining: 2m 48s
# 	Note: model has different eval_metric than default.
# 	-0.4019	 = Validation score   (-soft_log_loss)
# 	20.66s	 = Training   runtime
# 	0.0s	 = Validation runtime
# 1020:	learn: -0.3291771	test: -0.4106712	best: -0.4019377 (728)	total: 19s	remaining: 2m 47s
#
# bestTest = -0.4019376689
# bestIteration = 728
#
# Shrink model to first 729 iterations.
# Fitting model: NeuralNetTorch_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5604	 = Validation score   (-soft_log_loss)
# 	3.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.526, 'LightGBM_DSTL': 0.474}
# 	Note: model has different eval_metric than default.
# 	-0.3866	 = Validation score   (-soft_log_loss)
# 	0.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2_DSTL   0.854839  soft_log_loss       0.000000  22.112017                0.000000           0.086285            2       True         29
# 1             LightGBM_DSTL   0.838710  soft_log_loss       0.000000   1.362115                0.000000           1.362115            1       True         25
# 2             CatBoost_DSTL   0.838710  soft_log_loss       0.000000  20.663618                0.000000          20.663618            1       True         27
# 3      RandomForestMSE_DSTL   0.806452  soft_log_loss       0.066279   0.885648                0.066279           0.885648            1       True         26
# 4       NeuralNetTorch_DSTL   0.774194  soft_log_loss       0.010070   3.023380                0.010070           3.023380            1       True         28
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 21           WeightedEnsemble_L2         NaN   0.915858       accuracy
# 22        NeuralNetFastAI_BAG_L1         NaN   0.902913       accuracy
# 23          LightGBMLarge_BAG_L1         NaN   0.899676       accuracy
# 24               LightGBM_BAG_L1         NaN   0.896440       accuracy
# 10         ExtraTreesGini_BAG_L1    0.695652   0.893204       accuracy
# 12         ExtraTreesEntr_BAG_L1    0.695652   0.893204       accuracy
# 25             LightGBMXT_BAG_L1         NaN   0.893204       accuracy
# 26                XGBoost_BAG_L1         NaN   0.883495       accuracy
# 27         NeuralNetTorch_BAG_L1         NaN   0.883495       accuracy
# 28               CatBoost_BAG_L1         NaN   0.873786       accuracy
# 3        RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 8        RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 2       WeightedEnsemble_L2_DSTL    0.717391   0.854839  soft_log_loss
# 5                  LightGBM_DSTL    0.695652   0.838710  soft_log_loss
# 15                 CatBoost_DSTL    0.673913   0.838710  soft_log_loss
# 19          RandomForestMSE_DSTL    0.652174   0.806452  soft_log_loss
# 17           NeuralNetTorch_DSTL    0.673913   0.774194  soft_log_loss
# 0       WeightedEnsemble_L2_FULL    0.739130        NaN       accuracy
# 1         LightGBMXT_BAG_L1_FULL    0.717391        NaN       accuracy
# 4   RandomForestGini_BAG_L1_FULL    0.717391        NaN       accuracy
# 6           LightGBM_BAG_L1_FULL    0.695652        NaN       accuracy
# 7     ExtraTreesEntr_BAG_L1_FULL    0.695652        NaN       accuracy
# 9   RandomForestEntr_BAG_L1_FULL    0.695652        NaN       accuracy
# 11    ExtraTreesGini_BAG_L1_FULL    0.695652        NaN       accuracy
# 13          CatBoost_BAG_L1_FULL    0.673913        NaN       accuracy
# 14   NeuralNetFastAI_BAG_L1_FULL    0.673913        NaN       accuracy
# 16    NeuralNetTorch_BAG_L1_FULL    0.673913        NaN       accuracy
# 18           XGBoost_BAG_L1_FULL    0.652174        NaN       accuracy
# 20     LightGBMLarge_BAG_L1_FULL    0.608696        NaN       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 21             NaN       0.301683  10.529340                      NaN
# 22             NaN       0.107444   8.728442                      NaN
# 23             NaN       0.010947   4.829864                      NaN
# 24             NaN       0.009708   3.049304                      NaN
# 10        0.088011       0.088104   0.867973                 0.088011
# 12        0.099722       0.105135   0.758571                 0.099722
# 25             NaN       0.009556   2.666023                      NaN
# 26             NaN       0.011522   3.248828                      NaN
# 27             NaN       0.149203  31.649343                      NaN
# 28             NaN       0.016008  24.288788                      NaN
# 3         0.072579       0.089584   0.857883                 0.072579
# 8         0.071612       0.118437   0.834222                 0.071612
# 2         0.022282       0.000000  22.112017                 0.000000
# 5         0.010233       0.000000   1.362115                 0.010233
# 15        0.012049       0.000000  20.663618                 0.012049
# 19        0.090362       0.066279   0.885648                 0.090362
# 17        0.018264       0.010070   3.023380                 0.018264
# 0         0.169509            NaN   2.240902                 0.006509
# 1         0.006070            NaN   0.293106                 0.006070
# 4         0.121494       0.089584   0.857883                 0.121494
# 6         0.010512            NaN   0.280909                 0.010512
# 7         0.063339       0.105135   0.758571                 0.063339
# 9         0.084805       0.118437   0.834222                 0.084805
# 11        0.088284       0.088104   0.867973                 0.088284
# 13        0.004071            NaN   2.225530                 0.004071
# 14        0.011377            NaN   0.440005                 0.011377
# 16        0.017267            NaN  10.262152                 0.017267
# 18        0.007128            NaN   0.111098                 0.007128
# 20        0.012427            NaN   0.531866                 0.012427
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 21                0.001000           0.174354            2      False
# 22                0.107444           8.728442            1      False
# 23                0.010947           4.829864            1      False
# 24                0.009708           3.049304            1      False
# 10                0.088104           0.867973            1       True
# 12                0.105135           0.758571            1       True
# 25                0.009556           2.666023            1      False
# 26                0.011522           3.248828            1      False
# 27                0.149203          31.649343            1      False
# 28                0.016008          24.288788            1      False
# 3                 0.089584           0.857883            1       True
# 8                 0.118437           0.834222            1       True
# 2                 0.000000           0.086285            2       True
# 5                 0.000000           1.362115            1       True
# 15                0.000000          20.663618            1       True
# 19                0.066279           0.885648            1       True
# 17                0.010070           3.023380            1       True
# 0                      NaN           0.174354            2       True
# 1                      NaN           0.293106            1       True
# 4                 0.089584           0.857883            1       True
# 6                      NaN           0.280909            1       True
# 7                 0.105135           0.758571            1       True
# 9                 0.118437           0.834222            1       True
# 11                0.088104           0.867973            1       True
# 13                     NaN           2.225530            1       True
# 14                     NaN           0.440005            1       True
# 16                     NaN          10.262152            1       True
# 18                     NaN           0.111098            1       True
# 20                     NaN           0.531866            1       True
#
#     fit_order
# 21         12
# 22          1
# 23         11
# 24          3
# 10          7
# 12          8
# 25          2
# 26          9
# 27         10
# 28          6
# 3           4
# 8           5
# 2          29
# 5          25
# 15         27
# 19         26
# 17         28
# 0          24
# 1          14
# 4          16
# 6          15
# 7          20
# 9          17
# 11         19
# 13         18
# 14         13
# 16         22
# 18         21
# 20         23
# 测试集上的最佳蒸馏模型：
# WeightedEnsemble_L2_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7136752136752138,
#     "mcc": 0.5041953405754462
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5333333333333333,
#         "f1-score": 0.5925925925925926,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7777777777777778,
#         "recall": 0.8076923076923077,
#         "f1-score": 0.7924528301886793,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.671957671957672,
#         "recall": 0.7136752136752138,
#         "f1-score": 0.6839040298159795,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7191166321601103,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7136086045027801,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7136752136752138, 'mcc': 0.5041953405754462, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     8
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         6
# Exc L2-3 LINC00507 FREM3 superficial                                    21
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             1
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6666666666666666, 'recall': 0.5333333333333333, 'f1-score': 0.5925925925925926, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7777777777777778, 'recall': 0.8076923076923077, 'f1-score': 0.7924528301886793, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5714285714285714, 'recall': 0.8, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.671957671957672, 'recall': 0.7136752136752138, 'f1-score': 0.6839040298159795, 'support': 46.0}, 'weighted avg': {'precision': 0.7191166321601103, 'recall': 0.717391304347826, 'f1-score': 0.7136086045027801, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.67      0.53      0.59        15
# Exc L2-3 LINC00507 FREM3 superficial       0.78      0.81      0.79        26
#             Exc L2-4 LINC00507 GLP2R       0.57      0.80      0.67         5
#
#                             accuracy                           0.72        46
#                            macro avg       0.67      0.71      0.68        46
#                         weighted avg       0.72      0.72      0.71        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.498899
# [100]	valid_set's soft_log_loss: -0.426963
# [150]	valid_set's soft_log_loss: -0.434768
# [200]	valid_set's soft_log_loss: -0.449519
# [250]	valid_set's soft_log_loss: -0.491376
# [300]	valid_set's soft_log_loss: -0.530972
# 	Note: model has different eval_metric than default.
# 	-0.4248	 = Validation score   (-soft_log_loss)
# 	1.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# [350]	valid_set's soft_log_loss: -0.56425
# [400]	valid_set's soft_log_loss: -0.584133
# 	Note: model has different eval_metric than default.
# 	-0.4636	 = Validation score   (-soft_log_loss)
# 	0.8s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0692006	test: -1.0848175	best: -1.0848175 (0)	total: 548ms	remaining: 1h 31m 21s
# 20:	learn: -0.7357200	test: -0.8164472	best: -0.8164472 (20)	total: 882ms	remaining: 6m 59s
# 40:	learn: -0.5978462	test: -0.6882638	best: -0.6882638 (40)	total: 1.21s	remaining: 4m 53s
# 60:	learn: -0.5228254	test: -0.6090505	best: -0.6090505 (60)	total: 1.53s	remaining: 4m 10s
# 80:	learn: -0.4784167	test: -0.5600599	best: -0.5600599 (80)	total: 1.86s	remaining: 3m 48s
# 100:	learn: -0.4432292	test: -0.5200793	best: -0.5200793 (100)	total: 2.17s	remaining: 3m 32s
# 120:	learn: -0.4172839	test: -0.4916922	best: -0.4916922 (120)	total: 2.48s	remaining: 3m 22s
# 140:	learn: -0.3973677	test: -0.4750253	best: -0.4750253 (140)	total: 2.79s	remaining: 3m 14s
# 160:	learn: -0.3791794	test: -0.4565542	best: -0.4565542 (160)	total: 3.09s	remaining: 3m 8s
# 180:	learn: -0.3650615	test: -0.4415107	best: -0.4415107 (180)	total: 3.41s	remaining: 3m 5s
# 200:	learn: -0.3520658	test: -0.4331323	best: -0.4331323 (200)	total: 3.72s	remaining: 3m 1s
# 220:	learn: -0.3417883	test: -0.4296342	best: -0.4296342 (220)	total: 4.02s	remaining: 2m 57s
# 240:	learn: -0.3328154	test: -0.4242304	best: -0.4242304 (240)	total: 4.31s	remaining: 2m 54s
# 260:	learn: -0.3250844	test: -0.4186854	best: -0.4186854 (260)	total: 4.62s	remaining: 2m 52s
# 280:	learn: -0.3184944	test: -0.4140200	best: -0.4140200 (280)	total: 4.94s	remaining: 2m 50s
# 300:	learn: -0.3127844	test: -0.4114354	best: -0.4113128 (299)	total: 5.26s	remaining: 2m 49s
# 320:	learn: -0.3075714	test: -0.4047278	best: -0.4047278 (320)	total: 5.57s	remaining: 2m 47s
# 340:	learn: -0.3034169	test: -0.4028653	best: -0.4028653 (340)	total: 5.86s	remaining: 2m 46s
# 360:	learn: -0.3002032	test: -0.4026617	best: -0.4025019 (342)	total: 6.18s	remaining: 2m 45s
# 380:	learn: -0.2963404	test: -0.4009926	best: -0.4005771 (378)	total: 6.51s	remaining: 2m 44s
# 400:	learn: -0.2926578	test: -0.3982532	best: -0.3977947 (392)	total: 6.86s	remaining: 2m 44s
# 420:	learn: -0.2898929	test: -0.3968056	best: -0.3965617 (417)	total: 7.29s	remaining: 2m 45s
# 440:	learn: -0.2869856	test: -0.3955531	best: -0.3951972 (437)	total: 7.66s	remaining: 2m 45s
# 460:	learn: -0.2839349	test: -0.3950656	best: -0.3950656 (460)	total: 7.98s	remaining: 2m 45s
# 480:	learn: -0.2811436	test: -0.3931130	best: -0.3928390 (476)	total: 8.29s	remaining: 2m 44s
# 500:	learn: -0.2793991	test: -0.3922676	best: -0.3920865 (499)	total: 8.61s	remaining: 2m 43s
# 520:	learn: -0.2775624	test: -0.3918181	best: -0.3918181 (520)	total: 8.91s	remaining: 2m 42s
# 540:	learn: -0.2755148	test: -0.3907051	best: -0.3906065 (539)	total: 9.23s	remaining: 2m 41s
# 560:	learn: -0.2736553	test: -0.3911267	best: -0.3904816 (556)	total: 9.52s	remaining: 2m 40s
# 580:	learn: -0.2720962	test: -0.3891408	best: -0.3889721 (579)	total: 9.84s	remaining: 2m 39s
# 600:	learn: -0.2704701	test: -0.3889516	best: -0.3881335 (583)	total: 10.1s	remaining: 2m 38s
# 620:	learn: -0.2689447	test: -0.3881632	best: -0.3875654 (617)	total: 10.4s	remaining: 2m 37s
# 640:	learn: -0.2677146	test: -0.3887680	best: -0.3875654 (617)	total: 10.8s	remaining: 2m 37s
# 660:	learn: -0.2666038	test: -0.3893662	best: -0.3875654 (617)	total: 11.1s	remaining: 2m 36s
# 680:	learn: -0.2656639	test: -0.3893276	best: -0.3875654 (617)	total: 11.4s	remaining: 2m 35s
# 700:	learn: -0.2644605	test: -0.3907953	best: -0.3875654 (617)	total: 11.7s	remaining: 2m 34s
# 720:	learn: -0.2633785	test: -0.3905670	best: -0.3875654 (617)	total: 12.1s	remaining: 2m 35s
# 740:	learn: -0.2624379	test: -0.3887510	best: -0.3875654 (617)	total: 12.4s	remaining: 2m 34s
# 760:	learn: -0.2614974	test: -0.3892830	best: -0.3875654 (617)	total: 12.7s	remaining: 2m 33s
# 780:	learn: -0.2607608	test: -0.3907826	best: -0.3875654 (617)	total: 13s	remaining: 2m 33s
# 800:	learn: -0.2600294	test: -0.3906254	best: -0.3875654 (617)	total: 13.3s	remaining: 2m 33s
# 820:	learn: -0.2591632	test: -0.3916374	best: -0.3875654 (617)	total: 13.7s	remaining: 2m 32s
# 840:	learn: -0.2584706	test: -0.3934277	best: -0.3875654 (617)	total: 14s	remaining: 2m 31s
# 860:	learn: -0.2577324	test: -0.3945850	best: -0.3875654 (617)	total: 14.3s	remaining: 2m 31s
# 880:	learn: -0.2571212	test: -0.3947605	best: -0.3875654 (617)	total: 14.6s	remaining: 2m 30s
# 900:	learn: -0.2563720	test: -0.3954215	best: -0.3875654 (617)	total: 14.9s	remaining: 2m 30s
# 	Note: model has different eval_metric than default.
# 	-0.3876	 = Validation score   (-soft_log_loss)
# 	16.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# bestTest = -0.3875654138
# bestIteration = 617
#
# Shrink model to first 618 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5818	 = Validation score   (-soft_log_loss)
# 	3.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.786, 'LightGBM_2_DSTL': 0.214}
# 	Note: model has different eval_metric than default.
# 	-0.3842	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_2_DSTL   0.870968  soft_log_loss       0.001001   1.152376                0.001001           1.152376            1       True         30
# 1  WeightedEnsemble_2_L2_DSTL   0.854839  soft_log_loss       0.002566  17.349061                0.000000           0.030715            2       True         34
# 2             CatBoost_2_DSTL   0.838710  soft_log_loss       0.001565  16.165970                0.001565          16.165970            1       True         32
# 3      RandomForestMSE_2_DSTL   0.806452  soft_log_loss       0.061520   0.800544                0.061520           0.800544            1       True         31
# 4       NeuralNetTorch_2_DSTL   0.774194  soft_log_loss       0.020397   3.235674                0.020397           3.235674            1       True         33
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                            model  score_test  score_val    eval_metric  \
# 0       WeightedEnsemble_L2_FULL    0.739130        NaN       accuracy
# 1                LightGBM_2_DSTL    0.717391   0.870968  soft_log_loss
# 4        RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 3       WeightedEnsemble_L2_DSTL    0.717391   0.854839  soft_log_loss
# 2         LightGBMXT_BAG_L1_FULL    0.717391        NaN       accuracy
# 5   RandomForestGini_BAG_L1_FULL    0.717391        NaN       accuracy
# 11         ExtraTreesGini_BAG_L1    0.695652   0.893204       accuracy
# 14         ExtraTreesEntr_BAG_L1    0.695652   0.893204       accuracy
# 9        RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 8     WeightedEnsemble_2_L2_DSTL    0.695652   0.854839  soft_log_loss
# 7                  LightGBM_DSTL    0.695652   0.838710  soft_log_loss
# 6           LightGBM_BAG_L1_FULL    0.695652        NaN       accuracy
# 10    ExtraTreesGini_BAG_L1_FULL    0.695652        NaN       accuracy
# 12    ExtraTreesEntr_BAG_L1_FULL    0.695652        NaN       accuracy
# 13  RandomForestEntr_BAG_L1_FULL    0.695652        NaN       accuracy
# 17               CatBoost_2_DSTL    0.673913   0.838710  soft_log_loss
# 18                 CatBoost_DSTL    0.673913   0.838710  soft_log_loss
# 20           NeuralNetTorch_DSTL    0.673913   0.774194  soft_log_loss
# 15          CatBoost_BAG_L1_FULL    0.673913        NaN       accuracy
# 16   NeuralNetFastAI_BAG_L1_FULL    0.673913        NaN       accuracy
# 19    NeuralNetTorch_BAG_L1_FULL    0.673913        NaN       accuracy
# 22          RandomForestMSE_DSTL    0.652174   0.806452  soft_log_loss
# 21           XGBoost_BAG_L1_FULL    0.652174        NaN       accuracy
# 24        RandomForestMSE_2_DSTL    0.630435   0.806452  soft_log_loss
# 23         NeuralNetTorch_2_DSTL    0.630435   0.774194  soft_log_loss
# 25     LightGBMLarge_BAG_L1_FULL    0.608696        NaN       accuracy
# 26           WeightedEnsemble_L2         NaN   0.915858       accuracy
# 27        NeuralNetFastAI_BAG_L1         NaN   0.902913       accuracy
# 28          LightGBMLarge_BAG_L1         NaN   0.899676       accuracy
# 29               LightGBM_BAG_L1         NaN   0.896440       accuracy
# 30             LightGBMXT_BAG_L1         NaN   0.893204       accuracy
# 31                XGBoost_BAG_L1         NaN   0.883495       accuracy
# 32         NeuralNetTorch_BAG_L1         NaN   0.883495       accuracy
# 33               CatBoost_BAG_L1         NaN   0.873786       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.163907            NaN   2.240902                 0.000000
# 1         0.003005       0.001001   1.152376                 0.003005
# 4         0.095580       0.089584   0.857883                 0.095580
# 3         0.028395       0.000000  22.112017                 0.001173
# 2         0.010090            NaN   0.293106                 0.010090
# 5         0.097170       0.089584   0.857883                 0.097170
# 11        0.078395       0.088104   0.867973                 0.078395
# 14        0.101043       0.105135   0.758571                 0.101043
# 9         0.073962       0.118437   0.834222                 0.073962
# 8         0.018205       0.002566  17.349061                 0.005092
# 7         0.015637       0.000000   1.362115                 0.015637
# 6         0.010006            NaN   0.280909                 0.010006
# 10        0.074304       0.088104   0.867973                 0.074304
# 12        0.082716       0.105135   0.758571                 0.082716
# 13        0.099172       0.118437   0.834222                 0.099172
# 17        0.010107       0.001565  16.165970                 0.010107
# 18        0.011585       0.000000  20.663618                 0.011585
# 20        0.022049       0.010070   3.023380                 0.022049
# 15        0.006695            NaN   2.225530                 0.006695
# 16        0.006887            NaN   0.440005                 0.006887
# 19        0.018391            NaN  10.262152                 0.018391
# 22        0.140055       0.066279   0.885648                 0.140055
# 21        0.000000            NaN   0.111098                 0.000000
# 24        0.170062       0.061520   0.800544                 0.170062
# 23        0.025663       0.020397   3.235674                 0.025663
# 25        0.020104            NaN   0.531866                 0.020104
# 26             NaN       0.301683  10.529340                      NaN
# 27             NaN       0.107444   8.728442                      NaN
# 28             NaN       0.010947   4.829864                      NaN
# 29             NaN       0.009708   3.049304                      NaN
# 30             NaN       0.009556   2.666023                      NaN
# 31             NaN       0.011522   3.248828                      NaN
# 32             NaN       0.149203  31.649343                      NaN
# 33             NaN       0.016008  24.288788                      NaN
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                      NaN           0.174354            2       True
# 1                 0.001001           1.152376            1       True
# 4                 0.089584           0.857883            1       True
# 3                 0.000000           0.086285            2       True
# 2                      NaN           0.293106            1       True
# 5                 0.089584           0.857883            1       True
# 11                0.088104           0.867973            1       True
# 14                0.105135           0.758571            1       True
# 9                 0.118437           0.834222            1       True
# 8                 0.000000           0.030715            2       True
# 7                 0.000000           1.362115            1       True
# 6                      NaN           0.280909            1       True
# 10                0.088104           0.867973            1       True
# 12                0.105135           0.758571            1       True
# 13                0.118437           0.834222            1       True
# 17                0.001565          16.165970            1       True
# 18                0.000000          20.663618            1       True
# 20                0.010070           3.023380            1       True
# 15                     NaN           2.225530            1       True
# 16                     NaN           0.440005            1       True
# 19                     NaN          10.262152            1       True
# 22                0.066279           0.885648            1       True
# 21                     NaN           0.111098            1       True
# 24                0.061520           0.800544            1       True
# 23                0.020397           3.235674            1       True
# 25                     NaN           0.531866            1       True
# 26                0.001000           0.174354            2      False
# 27                0.107444           8.728442            1      False
# 28                0.010947           4.829864            1      False
# 29                0.009708           3.049304            1      False
# 30                0.009556           2.666023            1      False
# 31                0.011522           3.248828            1      False
# 32                0.149203          31.649343            1      False
# 33                0.016008          24.288788            1      False
#
#     fit_order
# 0          24
# 1          30
# 4           4
# 3          29
# 2          14
# 5          16
# 11          7
# 14          8
# 9           5
# 8          34
# 7          25
# 6          15
# 10         19
# 12         20
# 13         17
# 17         32
# 18         27
# 20         28
# 15         18
# 16         13
# 19         22
# 22         26
# 21         21
# 24         31
# 23         33
# 25         23
# 26         12
# 27          1
# 28         11
# 29          3
# 30          2
# 31          9
# 32         10
# 33          6
# 测试集上的最佳蒸馏模型：
# LightGBM_2_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7136752136752138,
#     "mcc": 0.523866514639908
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5333333333333333,
#         "f1-score": 0.5925925925925926,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.84,
#         "recall": 0.8076923076923077,
#         "f1-score": 0.8235294117647058,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.4444444444444444,
#         "recall": 0.8,
#         "f1-score": 0.5714285714285714,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6503703703703704,
#         "recall": 0.7136752136752138,
#         "f1-score": 0.66251685859529,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7404830917874397,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7208216619981325,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7136752136752138, 'mcc': 0.523866514639908, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     8
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         4
# Exc L2-3 LINC00507 FREM3 superficial                                    21
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             3
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6666666666666666, 'recall': 0.5333333333333333, 'f1-score': 0.5925925925925926, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.84, 'recall': 0.8076923076923077, 'f1-score': 0.8235294117647058, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.4444444444444444, 'recall': 0.8, 'f1-score': 0.5714285714285714, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6503703703703704, 'recall': 0.7136752136752138, 'f1-score': 0.66251685859529, 'support': 46.0}, 'weighted avg': {'precision': 0.7404830917874397, 'recall': 0.717391304347826, 'f1-score': 0.7208216619981325, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x1b9386dd3d0>,
#   <matplotlib.axis.YTick at 0x1b938642b10>,
#   <matplotlib.axis.YTick at 0x1b938729ad0>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'NeuralNetFastAI_BAG_L1_FULL', 'LightGBMXT_BAG_L1_FULL', 'LightGBM_BAG_L1_FULL', 'RandomForestGini_BAG_L1_FULL', 'RandomForestEntr_BAG_L1_FULL', 'CatBoost_BAG_L1_FULL', 'ExtraTreesGini_BAG_L1_FULL', 'ExtraTreesEntr_BAG_L1_FULL', 'XGBoost_BAG_L1_FULL', 'NeuralNetTorch_BAG_L1_FULL', 'LightGBMLarge_BAG_L1_FULL', 'WeightedEnsemble_L2_FULL', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
print("Using model: %s" % model_to_use)
model_pred = predictor.predict(test_data_nolabel, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Using model: NeuralNetFastAI_BAG_L1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 5
#       3 model_to_use = all_models[i]
#       4 print("Using model: %s" % model_to_use)
# ----> 5 model_pred = predictor.predict(test_data_nolabel, model=model_to_use)
#       6 print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\predictor\predictor.py:2117, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    2115 if decision_threshold is None:
#    2116     decision_threshold = self.decision_threshold
# -> 2117 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:189, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     187     if transform_features:
#     188         X = self.transform_features(X)
# --> 189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#     193 return y_pred_proba
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:837, in AbstractTrainer.predict_proba(self, X, model)
#     835     model = self._get_best()
#     836 cascade = isinstance(model, list)
# --> 837 return self._predict_proba_model(X, model, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:2611, in AbstractTrainer._predict_proba_model(self, X, model, model_pred_proba_dict, cascade)
#    2610 def _predict_proba_model(self, X, model, model_pred_proba_dict=None, cascade=False):
# -> 2611     return self.get_pred_proba_from_model(model=model, X=X, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:851, in AbstractTrainer.get_pred_proba_from_model(self, model, X, model_pred_proba_dict, cascade)
#     849 else:
#     850     models = [model]
# --> 851 model_pred_proba_dict = self.get_model_pred_proba_dict(X=X, models=models, model_pred_proba_dict=model_pred_proba_dict, cascade=cascade)
#     852 if not isinstance(model, str):
#     853     model = model.name
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1100, in AbstractTrainer.get_model_pred_proba_dict(self, X, models, model_pred_proba_dict, model_pred_time_dict, record_pred_time, use_val_cache, cascade, cascade_threshold)
#    1098     else:
#    1099         preprocess_kwargs = dict(infer=False, model_pred_proba_dict=model_pred_proba_dict)
# -> 1100     model_pred_proba_dict[model_name] = model.predict_proba(X, **preprocess_kwargs)
#    1101 else:
#    1102     model_pred_proba_dict[model_name] = model.predict_proba(X)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py:456, in BaggedEnsembleModel._predict_proba_internal(self, X, normalize, **kwargs)
#     454 model = self.load_child(self.models[0])
#     455 X = self.preprocess(X, model=model, **kwargs)
# --> 456 y_pred_proba = model.predict_proba(X=X, preprocess_nonadaptive=False, normalize=normalize)
#     457 for model in self.models[1:]:
#     458     model = self.load_child(model)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:968, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#     943 """
#     944 Returns class prediction probabilities of X.
#     945 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#     964     The prediction probabilities
#     965 """
#     966 time_start = time.time() if record_time else None
# --> 968 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#     970 if self.params_aux.get("temperature_scalar", None) is not None:
#     971     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py:982, in AbstractModel._predict_proba_internal(self, X, normalize, **kwargs)
#     980 if normalize is None:
#     981     normalize = self.normalize_pred_probas
# --> 982 y_pred_proba = self._predict_proba(X=X, **kwargs)
#     983 if normalize:
#     984     y_pred_proba = normalize_pred_probas(y_pred_proba, self.problem_type)
#
# File d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py:483, in NNFastAiTabularModel._predict_proba(self, X, **kwargs)
#     479     X = pd.concat([X, X]).reset_index(drop=True)
#     480 # Copy cat_columns and cont_columns because TabularList is mutating the list
#     481 # TODO: This call has very high fixed cost with many features (0.7s for a single row with 3k features)
#     482 #  Primarily due to normalization performed on the inputs
# --> 483 test_dl = self.model.dls.test_dl(X, inplace=True)
#     484 with self.model.no_bar():
#     485     with self.model.no_logging():
#
# AttributeError: 'NoneType' object has no attribute 'dls'

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
# predictor.delete_models(models_to_keep='best')
# Out:
# Dry run enabled, AutoGluon would have deleted the following models: ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsUnif_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsDist_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetFastAI_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBMXT_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBM_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\XGBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestMSE_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\WeightedEnsemble_L2_DSTL would have been deleted.
# To perform the deletion, set dry_run=False

# %%
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
