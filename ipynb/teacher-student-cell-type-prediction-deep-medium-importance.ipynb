# %% [markdown]
# # 减少特征重要性低的特征生成单模型独立训练集训练程序 version 2.0
# 未进行蒸馏

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Deep'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Deep
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (83, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 567754968 to 832627767
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      83 non-null     float64
#  1   sag                   83 non-null     float64
#  2   VmatSag               83 non-null     float64
#  3   vmbaseM               83 non-null     float64
#  4   tau                   83 non-null     float64
#  5   FAP_rheobase          83 non-null     float64
#  6   FAP_num_APs           83 non-null     float64
#  7   TS1_rheobase          83 non-null     float64
#  8   TS1_num_APs           83 non-null     float64
#  9   TS2_rheobase          83 non-null     float64
#  10  TS2_num_APs           83 non-null     float64
#  11  TS1_adp_index         59 non-null     float64
#  12  TS2_adp_index         67 non-null     float64
#  13  FAP_threshold         83 non-null     float64
#  14  FAP_peak              83 non-null     float64
#  15  FAP_maxupstroke       83 non-null     float64
#  16  FAP_maxdownstroke     83 non-null     float64
#  17  FAP_halfwidth         83 non-null     float64
#  18  FAP_avg_upstroke      83 non-null     float64
#  19  FAP_avg_downstroke    83 non-null     float64
#  20  FAP_up_down_ratio     83 non-null     float64
#  21  TS1_threshold         83 non-null     float64
#  22  TS1_maxupstroke       83 non-null     float64
#  23  TS1_maxdownstroke     83 non-null     float64
#  24  TS1_halfwidth         83 non-null     float64
#  25  TS1_avg_upstroke      83 non-null     float64
#  26  TS1_avg_downstroke    83 non-null     float64
#  27  TS1_up_down_ratio     83 non-null     float64
#  28  TS2_threshold         83 non-null     float64
#  29  TS2_peak              83 non-null     float64
#  30  TS2_maxupstroke       83 non-null     float64
#  31  TS2_maxdownstroke     83 non-null     float64
#  32  TS2_avg_upstroke      83 non-null     float64
#  33  TS2_avg_downstroke    83 non-null     float64
#  34  TS2_up_down_ratio     83 non-null     float64
#  35  L23_depth_normalized  73 non-null     float64
#  36  label                 83 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 26.7+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      83 non-null     float64
#  1   sag                   83 non-null     float64
#  2   VmatSag               83 non-null     float64
#  3   vmbaseM               83 non-null     float64
#  4   tau                   83 non-null     float64
#  5   FAP_rheobase          83 non-null     float64
#  6   FAP_num_APs           83 non-null     float64
#  7   TS1_rheobase          83 non-null     float64
#  8   TS1_num_APs           83 non-null     float64
#  9   TS2_rheobase          83 non-null     float64
#  10  TS2_num_APs           83 non-null     float64
#  11  TS1_adp_index         83 non-null     float64
#  12  TS2_adp_index         83 non-null     float64
#  13  FAP_threshold         83 non-null     float64
#  14  FAP_peak              83 non-null     float64
#  15  FAP_maxupstroke       83 non-null     float64
#  16  FAP_maxdownstroke     83 non-null     float64
#  17  FAP_halfwidth         83 non-null     float64
#  18  FAP_avg_upstroke      83 non-null     float64
#  19  FAP_avg_downstroke    83 non-null     float64
#  20  FAP_up_down_ratio     83 non-null     float64
#  21  TS1_threshold         83 non-null     float64
#  22  TS1_maxupstroke       83 non-null     float64
#  23  TS1_maxdownstroke     83 non-null     float64
#  24  TS1_halfwidth         83 non-null     float64
#  25  TS1_avg_upstroke      83 non-null     float64
#  26  TS1_avg_downstroke    83 non-null     float64
#  27  TS1_up_down_ratio     83 non-null     float64
#  28  TS2_threshold         83 non-null     float64
#  29  TS2_peak              83 non-null     float64
#  30  TS2_maxupstroke       83 non-null     float64
#  31  TS2_maxdownstroke     83 non-null     float64
#  32  TS2_avg_upstroke      83 non-null     float64
#  33  TS2_avg_downstroke    83 non-null     float64
#  34  TS2_up_down_ratio     83 non-null     float64
#  35  L23_depth_normalized  83 non-null     float64
#  36  label                 83 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 24.1+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 83
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      17 non-null     float64
#  1   sag                   17 non-null     float64
#  2   VmatSag               17 non-null     float64
#  3   vmbaseM               17 non-null     float64
#  4   tau                   17 non-null     float64
#  5   FAP_rheobase          17 non-null     float64
#  6   FAP_num_APs           17 non-null     float64
#  7   TS1_rheobase          17 non-null     float64
#  8   TS1_num_APs           17 non-null     float64
#  9   TS2_rheobase          17 non-null     float64
#  10  TS2_num_APs           17 non-null     float64
#  11  TS1_adp_index         17 non-null     float64
#  12  TS2_adp_index         17 non-null     float64
#  13  FAP_threshold         17 non-null     float64
#  14  FAP_peak              17 non-null     float64
#  15  FAP_maxupstroke       17 non-null     float64
#  16  FAP_maxdownstroke     17 non-null     float64
#  17  FAP_halfwidth         17 non-null     float64
#  18  FAP_avg_upstroke      17 non-null     float64
#  19  FAP_avg_downstroke    17 non-null     float64
#  20  FAP_up_down_ratio     17 non-null     float64
#  21  TS1_threshold         17 non-null     float64
#  22  TS1_maxupstroke       17 non-null     float64
#  23  TS1_maxdownstroke     17 non-null     float64
#  24  TS1_halfwidth         17 non-null     float64
#  25  TS1_avg_upstroke      17 non-null     float64
#  26  TS1_avg_downstroke    17 non-null     float64
#  27  TS1_up_down_ratio     17 non-null     float64
#  28  TS2_threshold         17 non-null     float64
#  29  TS2_peak              17 non-null     float64
#  30  TS2_maxupstroke       17 non-null     float64
#  31  TS2_maxdownstroke     17 non-null     float64
#  32  TS2_avg_upstroke      17 non-null     float64
#  33  TS2_avg_downstroke    17 non-null     float64
#  34  TS2_up_down_ratio     17 non-null     float64
#  35  L23_depth_normalized  17 non-null     float64
#  36  label                 17 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 5.0+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training
# 初始话训练参数

# %%
#设置训练精度
presets='medium_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# %% [markdown]
# ### 5.1 生成数据训练模型
# 删除重要性低的特征生成模型独立数据集，并单独训练模型
# 注意：系统支持的算法类别与模型的类别不一一对应，例如KNN算法对应了两个模型:'KNeighborsUnif', 'KNeighborsDist',因此根据'KNeighborsUnif'和'KNeighborsDist'模型计算的特征重要性数据也是两份,分别生成的训练数据集也都是两份，这是利用KNN算法进行训练这两份数据就分别又得到'KNeighborsUnif', 'KNeighborsDist'两个模型和一个在这两个模型基础上的WeightedEnsemble_L2权重集成模型,共6个模型,这里的权重模型没有意义,进行了删除，因此分析时需要根据各自的数据集进行选择分析。

# %%
# 系统支持的算法类别和模型对比列表
models_list = ['KNN','KNN','FASTAI','GBM','GBM','GBM','RF','RF','CAT','XT','XT','XGB','NN_TORCH']
modellist = ['KNeighborsUnif', 'KNeighborsDist', 'NeuralNetFastAI', 'LightGBM', 'LightGBMXT','LightGBMLarge',
             'RandomForestGini', 'RandomForestEntr', 'CatBoost', 'ExtraTreesGini', 'ExtraTreesEntr', 
             'XGBoost', 'NeuralNetTorch']
# 读取该类别特征重要性文件，文件名为：{modality}-{cell_subset}-medium-importance.csv
featureimportance = Path(f'featureimportance\{modality}\{cell_subset}')
leaderboard = pd.DataFrame()
for i in range(len(modellist)):
    model_to_use = modellist[i]
    filename = f'{modality}-{cell_subset}-{model_to_use}-featureimportance.csv'
    importances_path = featureimportance / filename 
    importances_data = pd.read_csv(importances_path, index_col=0) 
    # 根据特征重要性条件筛选出保留的特征
    col_list = importances_data[(importances_data['importance']>0.005) | (importances_data['importance']<-0.005)].index.to_list()
    #col_list = importances_data[importances_data['importance']!=0].index.to_list()
    #重新生成训练集和测试集
    only_test_data_nolabel = test_data_nolabel[col_list]
    col_list.append(LABEL_COLUMN)
    only_train_data = train_data[col_list]
    only_test_data = test_data[col_list]

    # 开始训练
    predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
    if auto_stack and dynamic_stacking:
        predictor.fit(only_train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                            num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args, included_model_types = [models_list[i]])
    elif auto_stack and not dynamic_stacking:
        predictor.fit(only_train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                            num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets, included_model_types = [models_list[i]])
    elif not auto_stack and dynamic_stacking:
        predictor.fit(only_train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args, included_model_types = [models_list[i]])
    else:
        predictor.fit(only_train_data, presets=presets, time_limit=time_limit, included_model_types = [models_list[i]])

    # 模型评估
    models=predictor.leaderboard(only_test_data)
    # 将单模型的评估结果合并到leaderboard中
    leaderboard = pd.concat([leaderboard,models],axis=0)
# 删除权重集成模型
leaderboard = leaderboard[leaderboard['model']!='WeightedEnsemble_L2']
# 按模型排序
leaderboard.sort_values(by=['model','score_test','score_val'], ascending=False, inplace=True)
# 保存模型的结果到文件
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
leaderboard.to_csv(f'{modality}-{cell_subset}-{pst}{cv}-importance.csv')
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.20 GB / 15.92 GB (51.5%)
# Disk Space Avail:   307.85 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 15
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8397.18 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'FAP_rheobase', 'TS1_maxupstroke', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'FAP_rheobase', 'TS1_maxupstroke', ...]
# 	0.1s = Fit runtime
# 	15 features in original data used to generate 15 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['KNN'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3599.9s of the 3599.9s of remaining time.
# 	0.8333	 = Validation score   (accuracy)
# 	2.55s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3597.32s of the 3597.32s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3597.27s of remaining time.
# 	Ensemble Weights: {'KNeighborsDist': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2.79s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 902.1 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.08 GB / 15.92 GB (50.8%)
# Disk Space Avail:   307.85 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 21
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8276.89 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 21 | ['input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'FAP_rheobase', 'TS2_maxupstroke', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 21 | ['input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'FAP_rheobase', 'TS2_maxupstroke', ...]
# 	0.1s = Fit runtime
# 	21 features in original data used to generate 21 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['KNN'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3599.9s of the 3599.9s of remaining time.
# 	0.8333	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3599.67s of the 3599.67s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3599.61s of remaining time.
# 	Ensemble Weights: {'KNeighborsDist': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 0.48s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 492.8 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.08 GB / 15.92 GB (50.7%)
# Disk Space Avail:   307.85 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 20
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8274.77 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 20 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 20 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# 	0.1s = Fit runtime
# 	20 features in original data used to generate 20 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['FASTAI'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI ... Training model for up to 3599.91s of the 3599.91s of remaining time.
# No improvement since epoch 3: early stopping
# 	0.9444	 = Validation score   (accuracy)
# 	1.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.56s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1.5s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1764.9 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.16 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 18
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8360.45 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 18 | ['tau', 'L23_depth_normalized', 'FAP_maxupstroke', 'VmatSag', 'TS2_avg_downstroke', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 18 | ['tau', 'L23_depth_normalized', 'FAP_maxupstroke', 'VmatSag', 'TS2_avg_downstroke', ...]
# 	0.1s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 3 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3599.91s of the 3599.9s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3599.53s of the 3599.52s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3599.12s of the 3599.11s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.55s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.5s of remaining time.
# 	Ensemble Weights: {'LightGBMXT': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1.57s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 8975.0 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.16 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 8
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8352.56 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['FAP_rheobase', 'FAP_avg_downstroke', 'FAP_halfwidth', 'TS2_maxupstroke', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['FAP_rheobase', 'FAP_avg_downstroke', 'FAP_halfwidth', 'TS2_maxupstroke', 'tau', ...]
# 	0.0s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 3 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3599.89s of the 3599.89s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3599.63s of the 3599.62s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3599.28s of the 3599.28s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.9s of remaining time.
# 	Ensemble Weights: {'LightGBM': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\default_learner.py:144: RuntimeWarning: divide by zero encountered in scalar divide
#   log_throughput = f" | Estimated inference throughput: {(1/predict_n_time_per_row):.1f} rows/s ({int(predict_n_size)} batch size)"
# AutoGluon training complete, total runtime = 1.18s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: inf rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.15 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 15
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8343.88 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['tau', 'VmatSag', 'FAP_rheobase', 'TS1_rheobase', 'TS2_rheobase', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 15 | ['tau', 'VmatSag', 'FAP_rheobase', 'TS1_rheobase', 'TS2_rheobase', ...]
# 	0.1s = Fit runtime
# 	15 features in original data used to generate 15 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 3 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3599.89s of the 3599.89s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3599.64s of the 3599.64s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3599.38s of the 3599.38s of remaining time.
# 	1.0	 = Validation score   (accuracy)
# 	0.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.91s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge': 1.0}
# 	1.0	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\learner\default_learner.py:144: RuntimeWarning: divide by zero encountered in scalar divide
#   log_throughput = f" | Estimated inference throughput: {(1/predict_n_time_per_row):.1f} rows/s ({int(predict_n_size)} batch size)"
# AutoGluon training complete, total runtime = 1.18s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: inf rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.15 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 2
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8342.65 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['tau', 'FAP_halfwidth']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['tau', 'FAP_halfwidth']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['RF'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: RandomForestGini ... Training model for up to 3599.91s of the 3599.91s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3598.82s of the 3598.82s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.72s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.0s of remaining time.
# 	Ensemble Weights: {'RandomForestGini': 1.0}
# 	0.8889	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2.06s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 147.9 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.15 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 2
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8330.96 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['tau', 'FAP_halfwidth']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['tau', 'FAP_halfwidth']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['RF'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: RandomForestGini ... Training model for up to 3599.91s of the 3599.9s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.94s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3598.87s of the 3598.86s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.91s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3597.88s of remaining time.
# 	Ensemble Weights: {'RandomForestGini': 1.0}
# 	0.8889	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2.2s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 266.3 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.16 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 27
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8353.39 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 27 | ['tau', 'input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'TS2_threshold', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 27 | ['tau', 'input_resistance', 'TS1_rheobase', 'TS2_rheobase', 'TS2_threshold', ...]
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['CAT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 1 L1 models ...
# Fitting model: CatBoost ... Training model for up to 3599.88s of the 3599.88s of remaining time.
# 	1.0	 = Validation score   (accuracy)
# 	1.77s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.1s of remaining time.
# 	Ensemble Weights: {'CatBoost': 1.0}
# 	1.0	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1.94s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 18001.3 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.16 GB / 15.92 GB (51.3%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 4
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8354.59 MB
# 	Train Data (Original)  Memory Usage: 0.00 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 4 | ['FAP_halfwidth', 'FAP_num_APs', 'TS1_avg_downstroke', 'FAP_avg_upstroke']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 4 | ['FAP_halfwidth', 'FAP_num_APs', 'TS1_avg_downstroke', 'FAP_avg_upstroke']
# 	0.0s = Fit runtime
# 	4 features in original data used to generate 4 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.00 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: ExtraTreesGini ... Training model for up to 3599.9s of the 3599.9s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.73s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3599.07s of the 3599.07s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.82s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.18s of remaining time.
# 	Ensemble Weights: {'ExtraTreesGini': 1.0}
# 	0.8889	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1.89s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 245.4 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.16 GB / 15.92 GB (51.2%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 9
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8352.07 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 9 | ['TS1_threshold', 'FAP_up_down_ratio', 'FAP_maxdownstroke', 'TS2_num_APs', 'TS2_maxupstroke', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 9 | ['TS1_threshold', 'FAP_up_down_ratio', 'FAP_maxdownstroke', 'TS2_num_APs', 'TS2_maxupstroke', ...]
# 	0.0s = Fit runtime
# 	9 features in original data used to generate 9 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['XT'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 2 L1 models ...
# Fitting model: ExtraTreesGini ... Training model for up to 3599.88s of the 3599.88s of remaining time.
# 	0.8333	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3599.04s of the 3599.04s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3598.17s of remaining time.
# 	Ensemble Weights: {'ExtraTreesEntr': 1.0}
# 	0.8889	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1.91s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 422.1 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.14 GB / 15.92 GB (51.1%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 13
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8332.00 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['tau', 'FAP_maxupstroke', 'FAP_avg_downstroke', 'FAP_rheobase', 'TS1_rheobase', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['tau', 'FAP_maxupstroke', 'FAP_avg_downstroke', 'FAP_rheobase', 'TS1_rheobase', ...]
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['XGB'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 1 L1 models ...
# Fitting model: XGBoost ... Training model for up to 3599.85s of the 3599.84s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.24s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3599.57s of remaining time.
# 	Ensemble Weights: {'XGBoost': 1.0}
# 	0.9444	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 0.48s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1781.1 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models\Teacher\medium_quality-20241105-100857"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.14 GB / 15.92 GB (51.1%)
# Disk Space Avail:   307.84 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-100857"
# Train Data Rows:    87
# Train Data Columns: 27
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8330.40 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 27 | ['TS1_num_APs', 'FAP_num_APs', 'FAP_rheobase', 'TS1_rheobase', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 27 | ['TS1_num_APs', 'FAP_num_APs', 'FAP_rheobase', 'TS1_rheobase', 'tau', ...]
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Included models: ['NN_TORCH'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch ... Training model for up to 3599.87s of the 3599.86s of remaining time.
# 	1.0	 = Validation score   (accuracy)
# 	5.35s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3594.47s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch': 1.0}
# 	1.0	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5.57s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 685.6 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-100857")
