# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Deep'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Deep
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (83, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# 删除特征重要性低的特征

# %%
# 读取特征重要性文件，文件名为：{modality}-{cell_subset}-WeightedEnsemble_L2-featureimportance.csv'
featureimportance = Path(f'featureimportance\{modality}\{cell_subset}')
filename = f'{modality}-{cell_subset}-WeightedEnsemble_L2-featureimportance.csv'
importances_data = pd.read_csv(featureimportance / filename, index_col=0) 
print(importances_data['importance'])
# col_list = importances_data[(importances_data['importance']>0.005) | (importances_data['importance']<-0.005)].index.to_list()
col_list = importances_data[importances_data['importance']!=0].index.to_list()
col_list.append(LABEL_COLUMN)
labeled_data = labeled_data[col_list]
unlabeled_data = unlabeled_data[col_list]
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# L23_depth_normalized    0.071264
# sag                     0.043678
# vmbaseM                 0.041379
# tau                     0.041379
# input_resistance        0.027586
# TS1_adp_index           0.025287
# TS1_rheobase            0.013793
# TS1_num_APs             0.011494
# VmatSag                 0.011494
# FAP_rheobase            0.009195
# TS2_rheobase            0.009195
# TS2_adp_index           0.009195
# FAP_peak                0.009195
# TS1_avg_upstroke        0.009195
# TS1_maxdownstroke       0.009195
# TS1_maxupstroke         0.009195
# TS1_threshold           0.006897
# TS2_up_down_ratio       0.006897
# TS1_halfwidth           0.006897
# FAP_halfwidth           0.006897
# TS2_num_APs             0.004598
# TS2_peak                0.002299
# TS2_threshold           0.002299
# TS2_maxupstroke         0.000000
# TS2_maxdownstroke       0.000000
# TS2_avg_downstroke      0.000000
# TS2_avg_upstroke        0.000000
# FAP_up_down_ratio       0.000000
# TS1_up_down_ratio       0.000000
# TS1_avg_downstroke      0.000000
# FAP_num_APs             0.000000
# FAP_avg_downstroke      0.000000
# FAP_maxdownstroke       0.000000
# FAP_maxupstroke         0.000000
# FAP_threshold           0.000000
# FAP_avg_upstroke        0.000000
# Name: importance, dtype: float64
# Labeled_data:     (83, 24)
# Unlabeled_data:   (209, 24)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 567754968 to 832627767
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   L23_depth_normalized  73 non-null     float64
#  1   sag                   83 non-null     float64
#  2   vmbaseM               83 non-null     float64
#  3   tau                   83 non-null     float64
#  4   input_resistance      83 non-null     float64
#  5   TS1_adp_index         59 non-null     float64
#  6   TS1_rheobase          83 non-null     float64
#  7   TS1_num_APs           83 non-null     float64
#  8   VmatSag               83 non-null     float64
#  9   FAP_rheobase          83 non-null     float64
#  10  TS2_rheobase          83 non-null     float64
#  11  TS2_adp_index         67 non-null     float64
#  12  FAP_peak              83 non-null     float64
#  13  TS1_avg_upstroke      83 non-null     float64
#  14  TS1_maxdownstroke     83 non-null     float64
#  15  TS1_maxupstroke       83 non-null     float64
#  16  TS1_threshold         83 non-null     float64
#  17  TS2_up_down_ratio     83 non-null     float64
#  18  TS1_halfwidth         83 non-null     float64
#  19  FAP_halfwidth         83 non-null     float64
#  20  TS2_num_APs           83 non-null     float64
#  21  TS2_peak              83 non-null     float64
#  22  TS2_threshold         83 non-null     float64
#  23  label                 83 non-null     object
# dtypes: float64(23), object(1)
# memory usage: 18.3+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   L23_depth_normalized  83 non-null     float64
#  1   sag                   83 non-null     float64
#  2   vmbaseM               83 non-null     float64
#  3   tau                   83 non-null     float64
#  4   input_resistance      83 non-null     float64
#  5   TS1_adp_index         83 non-null     float64
#  6   TS1_rheobase          83 non-null     float64
#  7   TS1_num_APs           83 non-null     float64
#  8   VmatSag               83 non-null     float64
#  9   FAP_rheobase          83 non-null     float64
#  10  TS2_rheobase          83 non-null     float64
#  11  TS2_adp_index         83 non-null     float64
#  12  FAP_peak              83 non-null     float64
#  13  TS1_avg_upstroke      83 non-null     float64
#  14  TS1_maxdownstroke     83 non-null     float64
#  15  TS1_maxupstroke       83 non-null     float64
#  16  TS1_threshold         83 non-null     float64
#  17  TS2_up_down_ratio     83 non-null     float64
#  18  TS1_halfwidth         83 non-null     float64
#  19  FAP_halfwidth         83 non-null     float64
#  20  TS2_num_APs           83 non-null     float64
#  21  TS2_peak              83 non-null     float64
#  22  TS2_threshold         83 non-null     float64
#  23  label                 83 non-null     object
# dtypes: float64(23), object(1)
# memory usage: 15.7+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   L23_depth_normalized  209 non-null    float64
#  1   sag                   207 non-null    float64
#  2   vmbaseM               209 non-null    float64
#  3   tau                   200 non-null    float64
#  4   input_resistance      207 non-null    float64
#  5   TS1_adp_index         186 non-null    float64
#  6   TS1_rheobase          209 non-null    float64
#  7   TS1_num_APs           208 non-null    float64
#  8   VmatSag               207 non-null    float64
#  9   FAP_rheobase          209 non-null    float64
#  10  TS2_rheobase          208 non-null    float64
#  11  TS2_adp_index         196 non-null    float64
#  12  FAP_peak              187 non-null    float64
#  13  TS1_avg_upstroke      209 non-null    float64
#  14  TS1_maxdownstroke     209 non-null    float64
#  15  TS1_maxupstroke       209 non-null    float64
#  16  TS1_threshold         209 non-null    float64
#  17  TS2_up_down_ratio     208 non-null    float64
#  18  TS1_halfwidth         209 non-null    float64
#  19  FAP_halfwidth         209 non-null    float64
#  20  TS2_num_APs           208 non-null    float64
#  21  TS2_peak              208 non-null    float64
#  22  TS2_threshold         208 non-null    float64
#  23  label                 0 non-null      object
# dtypes: float64(23), object(1)
# memory usage: 40.8+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   L23_depth_normalized  209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   vmbaseM               209 non-null    float64
#  3   tau                   209 non-null    float64
#  4   input_resistance      209 non-null    float64
#  5   TS1_adp_index         209 non-null    float64
#  6   TS1_rheobase          209 non-null    float64
#  7   TS1_num_APs           209 non-null    float64
#  8   VmatSag               209 non-null    float64
#  9   FAP_rheobase          209 non-null    float64
#  10  TS2_rheobase          209 non-null    float64
#  11  TS2_adp_index         209 non-null    float64
#  12  FAP_peak              209 non-null    float64
#  13  TS1_avg_upstroke      209 non-null    float64
#  14  TS1_maxdownstroke     209 non-null    float64
#  15  TS1_maxupstroke       209 non-null    float64
#  16  TS1_threshold         209 non-null    float64
#  17  TS2_up_down_ratio     209 non-null    float64
#  18  TS1_halfwidth         209 non-null    float64
#  19  FAP_halfwidth         209 non-null    float64
#  20  TS2_num_APs           209 non-null    float64
#  21  TS2_peak              209 non-null    float64
#  22  TS2_threshold         209 non-null    float64
#  23  label                 0 non-null      float64
# dtypes: float64(24)
# memory usage: 39.3 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 83
# feature num: 23
# feature list: ['L23_depth_normalized' 'sag' 'vmbaseM' 'tau' 'input_resistance'
#  'TS1_adp_index' 'TS1_rheobase' 'TS1_num_APs' 'VmatSag' 'FAP_rheobase'
#  'TS2_rheobase' 'TS2_adp_index' 'FAP_peak' 'TS1_avg_upstroke'
#  'TS1_maxdownstroke' 'TS1_maxupstroke' 'TS1_threshold' 'TS2_up_down_ratio'
#  'TS1_halfwidth' 'FAP_halfwidth' 'TS2_num_APs' 'TS2_peak' 'TS2_threshold']
# cell type num: 3
# cell type list: ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   L23_depth_normalized  17 non-null     float64
#  1   sag                   17 non-null     float64
#  2   vmbaseM               17 non-null     float64
#  3   tau                   17 non-null     float64
#  4   input_resistance      17 non-null     float64
#  5   TS1_adp_index         17 non-null     float64
#  6   TS1_rheobase          17 non-null     float64
#  7   TS1_num_APs           17 non-null     float64
#  8   VmatSag               17 non-null     float64
#  9   FAP_rheobase          17 non-null     float64
#  10  TS2_rheobase          17 non-null     float64
#  11  TS2_adp_index         17 non-null     float64
#  12  FAP_peak              17 non-null     float64
#  13  TS1_avg_upstroke      17 non-null     float64
#  14  TS1_maxdownstroke     17 non-null     float64
#  15  TS1_maxupstroke       17 non-null     float64
#  16  TS1_threshold         17 non-null     float64
#  17  TS2_up_down_ratio     17 non-null     float64
#  18  TS1_halfwidth         17 non-null     float64
#  19  FAP_halfwidth         17 non-null     float64
#  20  TS2_num_APs           17 non-null     float64
#  21  TS2_peak              17 non-null     float64
#  22  TS2_threshold         17 non-null     float64
#  23  label                 17 non-null     object
# dtypes: float64(23), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='medium_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=False
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
num_bag_sets=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
dynamic_stacking = False
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.98 GB / 15.92 GB (56.4%)
# Disk Space Avail:   307.64 GB / 931.51 GB (33.0%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241105-202021"
# Train Data Rows:    87
# Train Data Columns: 23
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9200.58 MB
# 	Train Data (Original)  Memory Usage: 0.02 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 23 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 23 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# 	0.1s = Fit runtime
# 	23 features in original data used to generate 23 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.02 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 69, Val Rows: 18
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3599.85s of the 3599.84s of remaining time.
# 	0.8333	 = Validation score   (accuracy)
# 	2.76s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3596.9s of the 3596.89s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3596.87s of the 3596.86s of remaining time.
# No improvement since epoch 9: early stopping
# 	0.9444	 = Validation score   (accuracy)
# 	1.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3595.39s of the 3595.38s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3594.91s of the 3594.9s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.31s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 3594.6s of the 3594.59s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3593.69s of the 3593.68s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.9s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3592.7s of the 3592.69s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	1.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 3591.55s of the 3591.54s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3590.69s of the 3590.68s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.87s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3589.73s of the 3589.72s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3589.46s of the 3589.45s of remaining time.
# 	0.8889	 = Validation score   (accuracy)
# 	5.58s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3583.86s of the 3583.85s of remaining time.
# 	0.9444	 = Validation score   (accuracy)
# 	0.49s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3583.34s of remaining time.
# 	Ensemble Weights: {'CatBoost': 0.944, 'NeuralNetFastAI': 0.056}
# 	1.0	 = Validation score   (accuracy)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 16.87s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 8252.0 rows/s (18 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241105-202021")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\good_quality-20241003-123247"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 23 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# Best Model: WeightedEnsemble_L2
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val eval_metric  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2   1.000000    accuracy       0.002181  2.731405                0.000000           0.155218            2       True         14
# 1            LightGBMXT   0.944444    accuracy       0.000000  0.350920                0.000000           0.350920            1       True          4
# 2              LightGBM   0.944444    accuracy       0.000000  0.306873                0.000000           0.306873            1       True          5
# 3        KNeighborsDist   0.944444    accuracy       0.000000  0.010643                0.000000           0.010643            1       True          2
# 4              CatBoost   0.944444    accuracy       0.000000  1.128586                0.000000           1.128586            1       True          8
# 5         LightGBMLarge   0.944444    accuracy       0.001000  0.486470                0.001000           0.486470            1       True         13
# 6       NeuralNetFastAI   0.944444    accuracy       0.002181  1.447600                0.002181           1.447600            1       True          3
# 7        ExtraTreesGini   0.944444    accuracy       0.074526  0.762370                0.074526           0.762370            1       True          9
# 8               XGBoost   0.888889    accuracy       0.000000  0.244022                0.000000           0.244022            1       True         11
# 9        NeuralNetTorch   0.888889    accuracy       0.012775  5.581058                0.012775           5.581058            1       True         12
# 10     RandomForestEntr   0.888889    accuracy       0.056738  0.897537                0.056738           0.897537            1       True          7
# 11       ExtraTreesEntr   0.888889    accuracy       0.069777  0.872721                0.069777           0.872721            1       True         10
# 12     RandomForestGini   0.888889    accuracy       0.074130  0.814634                0.074130           0.814634            1       True          6
# 13       KNeighborsUnif   0.833333    accuracy       0.187289  2.759497                0.187289           2.759497            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'XTModel', 'XGBoostModel', 'CatBoostModel', 'NNFastAiTabularModel', 'RFModel', 'TabularNeuralNetTorchModel', 'LGBModel', 'WeightedEnsembleModel', 'KNNModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 23 | ['L23_depth_normalized', 'sag', 'vmbaseM', 'tau', 'input_resistance', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L2
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.60      0.60      0.60         5
#         Exc L3-4 RORB CARM1P1       0.67      0.50      0.57         4
#         Exc L3-5 RORB COL22A1       0.89      1.00      0.94         8
#
#                      accuracy                           0.76        17
#                     macro avg       0.72      0.70      0.70        17
#                  weighted avg       0.75      0.76      0.75        17

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[3 1 1]
#  [2 2 0]
#  [0 0 8]]
# ['Exc L2-3 LINC00507 FREM3 deep' 'Exc L3-4 RORB CARM1P1'
#  'Exc L3-5 RORB COL22A1']
# ([<matplotlib.axis.YTick at 0x25583d58a90>,
#   <matplotlib.axis.YTick at 0x25583d566d0>,
#   <matplotlib.axis.YTick at 0x25583dab350>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[3 1 1]
#  [2 2 0]
#  [0 0 8]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                        0.360284               0.326993
# 1                        0.400402               0.298377
# 2                        0.262793               0.262678
# 3                        0.265604               0.275198
# 4                        0.342189               0.302427
# 5                        0.353135               0.361470
# 6                        0.333662               0.351049
# 7                        0.261708               0.276804
# 8                        0.420367               0.308362
# 9                        0.282499               0.282353
# 10                       0.343016               0.367213
# 11                       0.325737               0.325181
# 12                       0.359677               0.313561
# 13                       0.414044               0.302771
# 14                       0.269578               0.285841
# 15                       0.266938               0.274627
# 16                       0.290539               0.328951
#
#     Exc L3-5 RORB COL22A1
# 0                0.312723
# 1                0.301221
# 2                0.474529
# 3                0.459198
# 4                0.355383
# 5                0.285396
# 6                0.315289
# 7                0.461488
# 8                0.271271
# 9                0.435148
# 10               0.289771
# 11               0.349082
# 12               0.326762
# 13               0.283185
# 14               0.444580
# 15               0.458435
# 16               0.380509

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 23 features using 17 rows with 5 shuffle sets...
# 	2.92s	= Expected runtime (0.58s per shuffle set)
# 	0.43s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                       importance    stddev   p_value  n  p99_high   p99_low
# FAP_rheobase            0.082353  0.067069  0.025803  5  0.220449 -0.055743
# TS2_up_down_ratio       0.082353  0.032219  0.002318  5  0.148692  0.016014
# input_resistance        0.070588  0.049215  0.016339  5  0.171923 -0.030747
# TS2_num_APs             0.070588  0.026307  0.001941  5  0.124754  0.016422
# TS2_peak                0.058824  0.041595  0.017055  5  0.144467 -0.026820
# TS2_rheobase            0.058824  0.041595  0.017055  5  0.144467 -0.026820
# TS1_adp_index           0.058824  0.000000  0.500000  5  0.058824  0.058824
# TS1_maxdownstroke       0.035294  0.052613  0.104000  5  0.143626 -0.073038
# FAP_halfwidth           0.035294  0.067069  0.152279  5  0.173390 -0.102802
# TS1_halfwidth           0.035294  0.032219  0.035242  5  0.101633 -0.031045
# VmatSag                 0.035294  0.032219  0.035242  5  0.101633 -0.031045
# sag                     0.023529  0.032219  0.088904  5  0.089869 -0.042810
# TS1_avg_upstroke        0.023529  0.067069  0.238310  5  0.161626 -0.114567
# TS1_rheobase            0.023529  0.067069  0.238310  5  0.161626 -0.114567
# FAP_peak                0.011765  0.026307  0.186950  5  0.065931 -0.042401
# TS1_maxupstroke         0.011765  0.026307  0.186950  5  0.065931 -0.042401
# TS1_threshold           0.011765  0.026307  0.186950  5  0.065931 -0.042401
# vmbaseM                 0.011765  0.026307  0.186950  5  0.065931 -0.042401
# TS2_threshold           0.011765  0.026307  0.186950  5  0.065931 -0.042401
# L23_depth_normalized    0.011765  0.049215  0.310654  5  0.113100 -0.089570
# TS1_num_APs             0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_adp_index           0.000000  0.000000  0.500000  5  0.000000  0.000000
# tau                    -0.011765  0.026307  0.813050  5  0.042401 -0.065931

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L2
# {'accuracy': 0.7647058823529411,
#  'balanced_accuracy': 0.7000000000000001,
#  'mcc': 0.6259425676138543,
#  'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
#  Exc L2-3 LINC00507 FREM3 deep                              3
#  Exc L3-4 RORB CARM1P1                                      2
#  Exc L3-5 RORB COL22A1                                      0
#
#                                 Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
#  Exc L2-3 LINC00507 FREM3 deep                      1                      1
#  Exc L3-4 RORB CARM1P1                              2                      0
#  Exc L3-5 RORB COL22A1                              0                      8  ,
#  'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.6,
#    'recall': 0.6,
#    'f1-score': 0.6,
#    'support': 5.0},
#   'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666,
#    'recall': 0.5,
#    'f1-score': 0.5714285714285714,
#    'support': 4.0},
#   'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888,
#    'recall': 1.0,
#    'f1-score': 0.9411764705882353,
#    'support': 8.0},
#   'accuracy': 0.7647058823529411,
#   'macro avg': {'precision': 0.7185185185185184,
#    'recall': 0.7000000000000001,
#    'f1-score': 0.7042016806722687,
#    'support': 17.0},
#   'weighted avg': {'precision': 0.7516339869281046,
#    'recall': 0.7647058823529411,
#    'f1-score': 0.7538309441423628,
#    'support': 17.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data, extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0        KNeighborsUnif    0.882353   0.833333    accuracy        0.004380
# 1        KNeighborsDist    0.882353   0.944444    accuracy        0.006083
# 2              LightGBM    0.764706   0.944444    accuracy        0.001364
# 3            LightGBMXT    0.764706   0.944444    accuracy        0.004999
# 4        NeuralNetTorch    0.764706   0.888889    accuracy        0.010230
# 5   WeightedEnsemble_L2    0.764706   1.000000    accuracy        0.016651
# 6      RandomForestEntr    0.764706   0.888889    accuracy        0.061269
# 7        ExtraTreesEntr    0.764706   0.888889    accuracy        0.066829
# 8        ExtraTreesGini    0.764706   0.944444    accuracy        0.087255
# 9      RandomForestGini    0.764706   0.888889    accuracy        0.113425
# 10        LightGBMLarge    0.705882   0.944444    accuracy        0.000000
# 11      NeuralNetFastAI    0.705882   0.944444    accuracy        0.014532
# 12             CatBoost    0.647059   0.944444    accuracy        0.002119
# 13              XGBoost    0.647059   0.888889    accuracy        0.017042
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.187289  2.759497                 0.004380                0.187289
# 1        0.000000  0.010643                 0.006083                0.000000
# 2        0.000000  0.306873                 0.001364                0.000000
# 3        0.000000  0.350920                 0.004999                0.000000
# 4        0.012775  5.581058                 0.010230                0.012775
# 5        0.002181  2.731405                 0.000000                0.000000
# 6        0.056738  0.897537                 0.061269                0.056738
# 7        0.069777  0.872721                 0.066829                0.069777
# 8        0.074526  0.762370                 0.087255                0.074526
# 9        0.074130  0.814634                 0.113425                0.074130
# 10       0.001000  0.486470                 0.000000                0.001000
# 11       0.002181  1.447600                 0.014532                0.002181
# 12       0.000000  1.128586                 0.002119                0.000000
# 13       0.000000  0.244022                 0.017042                0.000000
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            2.759497            1       True          1
# 1            0.010643            1       True          2
# 2            0.306873            1       True          5
# 3            0.350920            1       True          4
# 4            5.581058            1       True         12
# 5            0.155218            2       True         14
# 6            0.897537            1       True          7
# 7            0.872721            1       True         10
# 8            0.762370            1       True          9
# 9            0.814634            1       True          6
# 10           0.486470            1       True         13
# 11           1.447600            1       True          3
# 12           1.128586            1       True          8
# 13           0.244022            1       True         11

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_12140\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 deep
# 1      Exc L2-3 LINC00507 FREM3 deep
# 2      Exc L2-3 LINC00507 FREM3 deep
# 3      Exc L2-3 LINC00507 FREM3 deep
# 4      Exc L2-3 LINC00507 FREM3 deep
#                    ...
# 204    Exc L2-3 LINC00507 FREM3 deep
# 205    Exc L2-3 LINC00507 FREM3 deep
# 206    Exc L2-3 LINC00507 FREM3 deep
# 207    Exc L2-3 LINC00507 FREM3 deep
# 208    Exc L2-3 LINC00507 FREM3 deep
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2-3 LINC00507 FREM3 deep  Exc L3-4 RORB CARM1P1  \
# 0                         0.396922               0.321562
# 1                         0.375452               0.309414
# 2                         0.377330               0.335744
# 3                         0.415085               0.297902
# 4                         0.407559               0.290311
# ..                             ...                    ...
# 204                       0.380471               0.305521
# 205                       0.370856               0.306660
# 206                       0.404816               0.307625
# 207                       0.375485               0.313314
# 208                       0.400487               0.295442
#
#      Exc L3-5 RORB COL22A1
# 0                 0.281515
# 1                 0.315134
# 2                 0.286926
# 3                 0.287013
# 4                 0.302130
# ..                     ...
# 204               0.314008
# 205               0.322485
# 206               0.287559
# 207               0.311200
# 208               0.304070
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]=='Exc L3-4 RORB CARM1P1']])

new_unlabeled_data.shape
# Out:
# (166, 24)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.52634
# [100]	valid_set's soft_log_loss: -0.367428
# [150]	valid_set's soft_log_loss: -0.323156
# [200]	valid_set's soft_log_loss: -0.29081
# [250]	valid_set's soft_log_loss: -0.274598
# [300]	valid_set's soft_log_loss: -0.267195
# [350]	valid_set's soft_log_loss: -0.261232
# [400]	valid_set's soft_log_loss: -0.260064
# [450]	valid_set's soft_log_loss: -0.267175
# [500]	valid_set's soft_log_loss: -0.268277
# [550]	valid_set's soft_log_loss: -0.270009
# [600]	valid_set's soft_log_loss: -0.267357
# [650]	valid_set's soft_log_loss: -0.268027
# 	Note: model has different eval_metric than default.
# 	-0.2592	 = Validation score   (-soft_log_loss)
# 	0.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.3716	 = Validation score   (-soft_log_loss)
# 	0.67s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0944989	test: -1.0909789	best: -1.0909789 (0)	total: 826ms	remaining: 2h 17m 42s
# 20:	learn: -1.0124388	test: -0.8046387	best: -0.8046387 (20)	total: 1.02s	remaining: 8m 5s
# 40:	learn: -0.9657559	test: -0.6564422	best: -0.6564422 (40)	total: 1.21s	remaining: 4m 55s
# 60:	learn: -0.9388759	test: -0.5677723	best: -0.5677723 (60)	total: 1.4s	remaining: 3m 48s
# 80:	learn: -0.9201894	test: -0.5031748	best: -0.5031748 (80)	total: 1.6s	remaining: 3m 16s
# 100:	learn: -0.9080838	test: -0.4682492	best: -0.4679398 (99)	total: 1.77s	remaining: 2m 53s
# 120:	learn: -0.8976478	test: -0.4349597	best: -0.4349597 (120)	total: 1.94s	remaining: 2m 38s
# 140:	learn: -0.8880330	test: -0.4083542	best: -0.4083542 (140)	total: 2.13s	remaining: 2m 28s
# 160:	learn: -0.8807013	test: -0.3895292	best: -0.3894736 (159)	total: 2.35s	remaining: 2m 23s
# 180:	learn: -0.8747695	test: -0.3814796	best: -0.3814796 (180)	total: 2.54s	remaining: 2m 17s
# 200:	learn: -0.8697573	test: -0.3727349	best: -0.3727349 (200)	total: 2.73s	remaining: 2m 13s
# 220:	learn: -0.8655198	test: -0.3625749	best: -0.3625749 (220)	total: 2.91s	remaining: 2m 8s
# 240:	learn: -0.8619519	test: -0.3555202	best: -0.3550223 (239)	total: 3.1s	remaining: 2m 5s
# 260:	learn: -0.8586892	test: -0.3500815	best: -0.3500815 (260)	total: 3.3s	remaining: 2m 3s
# 280:	learn: -0.8560152	test: -0.3425446	best: -0.3425446 (280)	total: 3.46s	remaining: 1m 59s
# 300:	learn: -0.8533531	test: -0.3359417	best: -0.3356871 (298)	total: 3.67s	remaining: 1m 58s
# 320:	learn: -0.8511887	test: -0.3346712	best: -0.3340821 (316)	total: 3.84s	remaining: 1m 55s
# 340:	learn: -0.8497677	test: -0.3311502	best: -0.3311502 (340)	total: 4.05s	remaining: 1m 54s
# 360:	learn: -0.8483487	test: -0.3277919	best: -0.3277919 (360)	total: 4.25s	remaining: 1m 53s
# 380:	learn: -0.8469524	test: -0.3235114	best: -0.3235114 (380)	total: 4.44s	remaining: 1m 52s
# 400:	learn: -0.8455424	test: -0.3183922	best: -0.3183922 (400)	total: 4.64s	remaining: 1m 51s
# 420:	learn: -0.8442719	test: -0.3137223	best: -0.3137223 (420)	total: 4.83s	remaining: 1m 49s
# 440:	learn: -0.8432516	test: -0.3100467	best: -0.3100467 (440)	total: 5s	remaining: 1m 48s
# 460:	learn: -0.8421219	test: -0.3080802	best: -0.3080802 (460)	total: 5.2s	remaining: 1m 47s
# 480:	learn: -0.8412555	test: -0.3056262	best: -0.3053797 (476)	total: 5.38s	remaining: 1m 46s
# 500:	learn: -0.8403059	test: -0.3026211	best: -0.3026211 (500)	total: 5.56s	remaining: 1m 45s
# 520:	learn: -0.8396301	test: -0.3024722	best: -0.3024722 (520)	total: 5.77s	remaining: 1m 44s
# 540:	learn: -0.8388580	test: -0.3038754	best: -0.3024722 (520)	total: 5.96s	remaining: 1m 44s
# 560:	learn: -0.8381237	test: -0.2994535	best: -0.2994535 (560)	total: 6.16s	remaining: 1m 43s
# 580:	learn: -0.8375414	test: -0.2986847	best: -0.2983908 (578)	total: 6.34s	remaining: 1m 42s
# 600:	learn: -0.8369594	test: -0.2978355	best: -0.2977723 (590)	total: 6.52s	remaining: 1m 41s
# 620:	learn: -0.8364029	test: -0.2955413	best: -0.2955413 (620)	total: 6.7s	remaining: 1m 41s
# 640:	learn: -0.8359370	test: -0.2946675	best: -0.2943073 (638)	total: 6.88s	remaining: 1m 40s
# 660:	learn: -0.8354368	test: -0.2938227	best: -0.2938053 (658)	total: 7.06s	remaining: 1m 39s
# 680:	learn: -0.8349507	test: -0.2936552	best: -0.2928353 (672)	total: 7.24s	remaining: 1m 39s
# 700:	learn: -0.8345502	test: -0.2937676	best: -0.2928353 (672)	total: 7.43s	remaining: 1m 38s
# 720:	learn: -0.8341337	test: -0.2910263	best: -0.2910263 (720)	total: 7.62s	remaining: 1m 38s
# 740:	learn: -0.8338390	test: -0.2905989	best: -0.2905989 (740)	total: 7.81s	remaining: 1m 37s
# 760:	learn: -0.8334929	test: -0.2903321	best: -0.2898475 (756)	total: 8.03s	remaining: 1m 37s
# 780:	learn: -0.8331047	test: -0.2882794	best: -0.2881070 (777)	total: 8.19s	remaining: 1m 36s
# 800:	learn: -0.8328122	test: -0.2872311	best: -0.2871224 (799)	total: 8.38s	remaining: 1m 36s
# 820:	learn: -0.8324936	test: -0.2865143	best: -0.2865143 (820)	total: 8.6s	remaining: 1m 36s
# 840:	learn: -0.8321870	test: -0.2854275	best: -0.2854275 (840)	total: 8.79s	remaining: 1m 35s
# 860:	learn: -0.8319644	test: -0.2863652	best: -0.2853791 (841)	total: 8.99s	remaining: 1m 35s
# 880:	learn: -0.8316825	test: -0.2852012	best: -0.2851119 (872)	total: 9.18s	remaining: 1m 35s
# 900:	learn: -0.8314328	test: -0.2837131	best: -0.2836532 (899)	total: 9.36s	remaining: 1m 34s
# 920:	learn: -0.8312150	test: -0.2830858	best: -0.2830858 (920)	total: 9.54s	remaining: 1m 34s
# 940:	learn: -0.8310095	test: -0.2821550	best: -0.2819967 (938)	total: 9.72s	remaining: 1m 33s
# 960:	learn: -0.8307843	test: -0.2816406	best: -0.2813377 (956)	total: 9.91s	remaining: 1m 33s
# 980:	learn: -0.8305689	test: -0.2817399	best: -0.2813377 (956)	total: 10.1s	remaining: 1m 32s
# 1000:	learn: -0.8303837	test: -0.2815339	best: -0.2811888 (987)	total: 10.3s	remaining: 1m 32s
# 1020:	learn: -0.8302053	test: -0.2823221	best: -0.2811888 (987)	total: 10.5s	remaining: 1m 32s
# 1040:	learn: -0.8300363	test: -0.2817500	best: -0.2811888 (987)	total: 10.7s	remaining: 1m 31s
# 1060:	learn: -0.8298890	test: -0.2819579	best: -0.2811888 (987)	total: 10.9s	remaining: 1m 31s
# 1080:	learn: -0.8297213	test: -0.2823132	best: -0.2811888 (987)	total: 11s	remaining: 1m 30s
# 1100:	learn: -0.8295537	test: -0.2815733	best: -0.2811888 (987)	total: 11.2s	remaining: 1m 30s
# 1120:	learn: -0.8293944	test: -0.2815080	best: -0.2811888 (987)	total: 11.4s	remaining: 1m 30s
# 1140:	learn: -0.8292522	test: -0.2810112	best: -0.2808073 (1139)	total: 11.6s	remaining: 1m 29s
# 1160:	learn: -0.8291226	test: -0.2806348	best: -0.2806147 (1159)	total: 11.7s	remaining: 1m 29s
# 1180:	learn: -0.8289959	test: -0.2811035	best: -0.2805704 (1165)	total: 11.9s	remaining: 1m 29s
# 1200:	learn: -0.8288502	test: -0.2803950	best: -0.2803067 (1198)	total: 12.1s	remaining: 1m 28s
# 1220:	learn: -0.8287387	test: -0.2802937	best: -0.2800527 (1217)	total: 12.3s	remaining: 1m 28s
# 1240:	learn: -0.8285855	test: -0.2798656	best: -0.2798656 (1240)	total: 12.5s	remaining: 1m 28s
# 1260:	learn: -0.8284770	test: -0.2798130	best: -0.2794423 (1248)	total: 12.7s	remaining: 1m 27s
# 1280:	learn: -0.8283499	test: -0.2795660	best: -0.2794423 (1248)	total: 12.9s	remaining: 1m 27s
# 1300:	learn: -0.8282303	test: -0.2795317	best: -0.2794423 (1248)	total: 13s	remaining: 1m 27s
# 1320:	learn: -0.8281110	test: -0.2807172	best: -0.2794423 (1248)	total: 13.2s	remaining: 1m 26s
# 1340:	learn: -0.8279974	test: -0.2801819	best: -0.2794423 (1248)	total: 13.4s	remaining: 1m 26s
# 1360:	learn: -0.8278887	test: -0.2795520	best: -0.2794174 (1357)	total: 13.6s	remaining: 1m 26s
# 1380:	learn: -0.8277900	test: -0.2789418	best: -0.2789418 (1380)	total: 13.8s	remaining: 1m 26s
# 1400:	learn: -0.8276790	test: -0.2782253	best: -0.2781978 (1399)	total: 14s	remaining: 1m 25s
# 1420:	learn: -0.8276041	test: -0.2774911	best: -0.2774911 (1420)	total: 14.2s	remaining: 1m 25s
# 1440:	learn: -0.8275088	test: -0.2770169	best: -0.2768516 (1436)	total: 14.4s	remaining: 1m 25s
# 1460:	learn: -0.8274111	test: -0.2770583	best: -0.2768516 (1436)	total: 14.6s	remaining: 1m 25s
# 1480:	learn: -0.8273193	test: -0.2768603	best: -0.2767570 (1466)	total: 14.7s	remaining: 1m 24s
# 1500:	learn: -0.8272292	test: -0.2767956	best: -0.2766491 (1483)	total: 14.9s	remaining: 1m 24s
# 1520:	learn: -0.8271529	test: -0.2768036	best: -0.2766491 (1483)	total: 15.1s	remaining: 1m 24s
# 1540:	learn: -0.8270700	test: -0.2769347	best: -0.2764680 (1525)	total: 15.3s	remaining: 1m 24s
# 1560:	learn: -0.8269972	test: -0.2774130	best: -0.2764680 (1525)	total: 15.5s	remaining: 1m 23s
# 1580:	learn: -0.8269198	test: -0.2772545	best: -0.2764680 (1525)	total: 15.7s	remaining: 1m 23s
# 1600:	learn: -0.8268474	test: -0.2775010	best: -0.2764680 (1525)	total: 15.9s	remaining: 1m 23s
# 1620:	learn: -0.8267706	test: -0.2773256	best: -0.2764680 (1525)	total: 16.1s	remaining: 1m 23s
# 1640:	learn: -0.8267094	test: -0.2769034	best: -0.2764680 (1525)	total: 16.3s	remaining: 1m 22s
# 1660:	learn: -0.8266403	test: -0.2766967	best: -0.2764625 (1655)	total: 16.5s	remaining: 1m 22s
# 1680:	learn: -0.8265849	test: -0.2770751	best: -0.2764625 (1655)	total: 16.6s	remaining: 1m 22s
# 1700:	learn: -0.8265148	test: -0.2770866	best: -0.2764625 (1655)	total: 16.8s	remaining: 1m 22s
# 1720:	learn: -0.8264479	test: -0.2777398	best: -0.2764625 (1655)	total: 17s	remaining: 1m 21s
# 1740:	learn: -0.8263903	test: -0.2774111	best: -0.2764625 (1655)	total: 17.2s	remaining: 1m 21s
# 1760:	learn: -0.8263246	test: -0.2778249	best: -0.2764625 (1655)	total: 17.4s	remaining: 1m 21s
# 1780:	learn: -0.8262628	test: -0.2778703	best: -0.2764625 (1655)	total: 17.6s	remaining: 1m 21s
# 1800:	learn: -0.8262016	test: -0.2776123	best: -0.2764625 (1655)	total: 17.8s	remaining: 1m 21s
# 1820:	learn: -0.8261566	test: -0.2768497	best: -0.2764625 (1655)	total: 18s	remaining: 1m 21s
# 1840:	learn: -0.8260919	test: -0.2763796	best: -0.2763796 (1840)	total: 18.2s	remaining: 1m 20s
# 1860:	learn: -0.8260419	test: -0.2765503	best: -0.2763713 (1845)	total: 18.4s	remaining: 1m 20s
# 1880:	learn: -0.8259960	test: -0.2764002	best: -0.2762811 (1872)	total: 18.6s	remaining: 1m 20s
# 1900:	learn: -0.8259539	test: -0.2762442	best: -0.2762442 (1900)	total: 18.8s	remaining: 1m 20s
# 1920:	learn: -0.8259118	test: -0.2764935	best: -0.2762442 (1900)	total: 19s	remaining: 1m 20s
# 1940:	learn: -0.8258608	test: -0.2759919	best: -0.2759919 (1940)	total: 19.2s	remaining: 1m 19s
# 1960:	learn: -0.8258149	test: -0.2757781	best: -0.2757102 (1953)	total: 19.4s	remaining: 1m 19s
# 1980:	learn: -0.8257688	test: -0.2755738	best: -0.2755738 (1980)	total: 19.6s	remaining: 1m 19s
# 2000:	learn: -0.8257278	test: -0.2754095	best: -0.2754095 (2000)	total: 19.8s	remaining: 1m 19s
# 2020:	learn: -0.8256837	test: -0.2753407	best: -0.2748967 (2017)	total: 20s	remaining: 1m 18s
# 2040:	learn: -0.8256454	test: -0.2756507	best: -0.2748967 (2017)	total: 20.2s	remaining: 1m 18s
# 2060:	learn: -0.8256070	test: -0.2753562	best: -0.2748967 (2017)	total: 20.4s	remaining: 1m 18s
# 2080:	learn: -0.8255701	test: -0.2760715	best: -0.2748967 (2017)	total: 20.6s	remaining: 1m 18s
# 2100:	learn: -0.8255308	test: -0.2759284	best: -0.2748967 (2017)	total: 20.8s	remaining: 1m 18s
# 2120:	learn: -0.8254894	test: -0.2762059	best: -0.2748967 (2017)	total: 21s	remaining: 1m 17s
# 2140:	learn: -0.8254434	test: -0.2759339	best: -0.2748967 (2017)	total: 21.2s	remaining: 1m 17s
# 2160:	learn: -0.8254075	test: -0.2759315	best: -0.2748967 (2017)	total: 21.3s	remaining: 1m 17s
# 2180:	learn: -0.8253672	test: -0.2761432	best: -0.2748967 (2017)	total: 21.5s	remaining: 1m 17s
# 2200:	learn: -0.8253357	test: -0.2762569	best: -0.2748967 (2017)	total: 21.7s	remaining: 1m 17s
# 2220:	learn: -0.8253042	test: -0.2761644	best: -0.2748967 (2017)	total: 21.9s	remaining: 1m 16s
# 2240:	learn: -0.8252725	test: -0.2762466	best: -0.2748967 (2017)	total: 22.1s	remaining: 1m 16s
# 2260:	learn: -0.8252401	test: -0.2761335	best: -0.2748967 (2017)	total: 22.3s	remaining: 1m 16s
# 2280:	learn: -0.8252053	test: -0.2760108	best: -0.2748967 (2017)	total: 22.5s	remaining: 1m 16s
# 2300:	learn: -0.8251714	test: -0.2757480	best: -0.2748967 (2017)	total: 22.7s	remaining: 1m 15s
# 2320:	learn: -0.8251457	test: -0.2758260	best: -0.2748967 (2017)	total: 22.9s	remaining: 1m 15s
# 2340:	learn: -0.8251123	test: -0.2758075	best: -0.2748967 (2017)	total: 23.1s	remaining: 1m 15s
# 2360:	learn: -0.8250779	test: -0.2759626	best: -0.2748967 (2017)	total: 23.3s	remaining: 1m 15s
# 2380:	learn: -0.8250509	test: -0.2762550	best: -0.2748967 (2017)	total: 23.5s	remaining: 1m 15s
# 2400:	learn: -0.8250203	test: -0.2762998	best: -0.2748967 (2017)	total: 23.7s	remaining: 1m 14s
# 2420:	learn: -0.8249942	test: -0.2762211	best: -0.2748967 (2017)	total: 23.9s	remaining: 1m 14s
# 2440:	learn: -0.8249664	test: -0.2763456	best: -0.2748967 (2017)	total: 24s	remaining: 1m 14s
# 2460:	learn: -0.8249384	test: -0.2762506	best: -0.2748967 (2017)	total: 24.2s	remaining: 1m 14s
# 2480:	learn: -0.8249121	test: -0.2763932	best: -0.2748967 (2017)	total: 24.4s	remaining: 1m 14s
# 2500:	learn: -0.8248836	test: -0.2761974	best: -0.2748967 (2017)	total: 24.6s	remaining: 1m 13s
# 2520:	learn: -0.8248589	test: -0.2759789	best: -0.2748967 (2017)	total: 24.9s	remaining: 1m 13s
# 2540:	learn: -0.8248344	test: -0.2758773	best: -0.2748967 (2017)	total: 25.1s	remaining: 1m 13s
# 2560:	learn: -0.8248068	test: -0.2761723	best: -0.2748967 (2017)	total: 25.3s	remaining: 1m 13s
# 2580:	learn: -0.8247813	test: -0.2762763	best: -0.2748967 (2017)	total: 25.4s	remaining: 1m 13s
# 2600:	learn: -0.8247571	test: -0.2764890	best: -0.2748967 (2017)	total: 25.7s	remaining: 1m 13s
# 2620:	learn: -0.8247327	test: -0.2766045	best: -0.2748967 (2017)	total: 25.9s	remaining: 1m 12s
# 	Note: model has different eval_metric than default.
# 	-0.2749	 = Validation score   (-soft_log_loss)
# 	33.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# 2640:	learn: -0.8247117	test: -0.2767029	best: -0.2748967 (2017)	total: 26.1s	remaining: 1m 12s
#
# bestTest = -0.2748967139
# bestIteration = 2017
#
# Shrink model to first 2018 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.3651	 = Validation score   (-soft_log_loss)
# 	2.5s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'LightGBM_DSTL': 0.737, 'CatBoost_DSTL': 0.263}
# 	Note: model has different eval_metric than default.
# 	-0.258	 = Validation score   (-soft_log_loss)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2_DSTL   0.888889  soft_log_loss       0.000000  33.910043                0.000000           0.023909            2       True         19
# 1             LightGBM_DSTL   0.888889  soft_log_loss       0.000000   0.848510                0.000000           0.848510            1       True         15
# 2      RandomForestMSE_DSTL   0.888889  soft_log_loss       0.060858   0.668337                0.060858           0.668337            1       True         16
# 3             CatBoost_DSTL   0.833333  soft_log_loss       0.000000  33.037623                0.000000          33.037623            1       True         17
# 4       NeuralNetTorch_DSTL   0.833333  soft_log_loss       0.011905   2.501716                0.011905           2.501716            1       True         18
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                        model  score_test  score_val    eval_metric  \
# 8        WeightedEnsemble_L2    0.764706   1.000000       accuracy
# 0             KNeighborsDist    0.882353   0.944444       accuracy
# 2                   LightGBM    0.764706   0.944444       accuracy
# 4                 LightGBMXT    0.764706   0.944444       accuracy
# 10            ExtraTreesGini    0.764706   0.944444       accuracy
# 15             LightGBMLarge    0.705882   0.944444       accuracy
# 16           NeuralNetFastAI    0.705882   0.944444       accuracy
# 17                  CatBoost    0.647059   0.944444       accuracy
# 3             NeuralNetTorch    0.764706   0.888889       accuracy
# 6              LightGBM_DSTL    0.764706   0.888889  soft_log_loss
# 9   WeightedEnsemble_L2_DSTL    0.764706   0.888889  soft_log_loss
# 11          RandomForestGini    0.764706   0.888889       accuracy
# 12            ExtraTreesEntr    0.764706   0.888889       accuracy
# 13          RandomForestEntr    0.764706   0.888889       accuracy
# 14      RandomForestMSE_DSTL    0.764706   0.888889  soft_log_loss
# 18                   XGBoost    0.647059   0.888889       accuracy
# 1             KNeighborsUnif    0.882353   0.833333       accuracy
# 5              CatBoost_DSTL    0.764706   0.833333  soft_log_loss
# 7        NeuralNetTorch_DSTL    0.764706   0.833333  soft_log_loss
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 8         0.030231       0.002181   2.731405                 0.000000
# 0         0.000000       0.000000   0.010643                 0.000000
# 2         0.001811       0.000000   0.306873                 0.001811
# 4         0.004558       0.000000   0.350920                 0.004558
# 10        0.049764       0.074526   0.762370                 0.049764
# 15        0.000000       0.001000   0.486470                 0.000000
# 16        0.024524       0.002181   1.447600                 0.024524
# 17        0.005707       0.000000   1.128586                 0.005707
# 3         0.004160       0.012775   5.581058                 0.004160
# 6         0.022852       0.000000   0.848510                 0.022852
# 9         0.032859       0.000000  33.910043                 0.000000
# 11        0.075036       0.074130   0.814634                 0.075036
# 12        0.090636       0.069777   0.872721                 0.090636
# 13        0.096677       0.056738   0.897537                 0.096677
# 14        0.098860       0.060858   0.668337                 0.098860
# 18        0.015999       0.000000   0.244022                 0.015999
# 1         0.000000       0.187289   2.759497                 0.000000
# 5         0.010007       0.000000  33.037623                 0.010007
# 7         0.023936       0.011905   2.501716                 0.023936
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 8                 0.000000           0.155218            2       True
# 0                 0.000000           0.010643            1       True
# 2                 0.000000           0.306873            1       True
# 4                 0.000000           0.350920            1       True
# 10                0.074526           0.762370            1       True
# 15                0.001000           0.486470            1       True
# 16                0.002181           1.447600            1       True
# 17                0.000000           1.128586            1       True
# 3                 0.012775           5.581058            1       True
# 6                 0.000000           0.848510            1       True
# 9                 0.000000           0.023909            2       True
# 11                0.074130           0.814634            1       True
# 12                0.069777           0.872721            1       True
# 13                0.056738           0.897537            1       True
# 14                0.060858           0.668337            1       True
# 18                0.000000           0.244022            1       True
# 1                 0.187289           2.759497            1       True
# 5                 0.000000          33.037623            1       True
# 7                 0.011905           2.501716            1       True
#
#     fit_order
# 8          14
# 0           2
# 2           5
# 4           4
# 10          9
# 15         13
# 16          3
# 17          8
# 3          12
# 6          15
# 9          19
# 11          6
# 12         10
# 13          7
# 14         16
# 18         11
# 1           1
# 5          17
# 7          18
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7647058823529411
# Evaluations on test data:
# {
#     "accuracy": 0.7647058823529411,
#     "balanced_accuracy": 0.7000000000000001,
#     "mcc": 0.6259425676138543
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.6,
#         "recall": 0.6,
#         "f1-score": 0.6,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5,
#         "f1-score": 0.5714285714285714,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.7647058823529411,
#     "macro avg": {
#         "precision": 0.7185185185185184,
#         "recall": 0.7000000000000001,
#         "f1-score": 0.7042016806722687,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.7516339869281046,
#         "recall": 0.7647058823529411,
#         "f1-score": 0.7538309441423628,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.7647058823529411, 'balanced_accuracy': 0.7000000000000001, 'mcc': 0.6259425676138543, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      2
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              2                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666, 'recall': 0.5, 'f1-score': 0.5714285714285714, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.7185185185185184, 'recall': 0.7000000000000001, 'f1-score': 0.7042016806722687, 'support': 17.0}, 'weighted avg': {'precision': 0.7516339869281046, 'recall': 0.7647058823529411, 'f1-score': 0.7538309441423628, 'support': 17.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                precision    recall  f1-score   support
#
# Exc L2-3 LINC00507 FREM3 deep       0.60      0.60      0.60         5
#         Exc L3-4 RORB CARM1P1       0.67      0.50      0.57         4
#         Exc L3-5 RORB COL22A1       0.89      1.00      0.94         8
#
#                      accuracy                           0.76        17
#                     macro avg       0.72      0.70      0.70        17
#                  weighted avg       0.75      0.76      0.75        17

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='LightGBM_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.544567
# [100]	valid_set's soft_log_loss: -0.368335
# [150]	valid_set's soft_log_loss: -0.304422
# [200]	valid_set's soft_log_loss: -0.272408
# [250]	valid_set's soft_log_loss: -0.263926
# [300]	valid_set's soft_log_loss: -0.262553
# [350]	valid_set's soft_log_loss: -0.258436
# [400]	valid_set's soft_log_loss: -0.257065
# [450]	valid_set's soft_log_loss: -0.258769
# [500]	valid_set's soft_log_loss: -0.255464
# [550]	valid_set's soft_log_loss: -0.255429
# [600]	valid_set's soft_log_loss: -0.254149
# [650]	valid_set's soft_log_loss: -0.251801
# [700]	valid_set's soft_log_loss: -0.251114
# [750]	valid_set's soft_log_loss: -0.251529
# [800]	valid_set's soft_log_loss: -0.253925
# [850]	valid_set's soft_log_loss: -0.250718
# [900]	valid_set's soft_log_loss: -0.247089
# [950]	valid_set's soft_log_loss: -0.244711
# [1000]	valid_set's soft_log_loss: -0.244095
# [1050]	valid_set's soft_log_loss: -0.244953
# [1100]	valid_set's soft_log_loss: -0.245933
# [1150]	valid_set's soft_log_loss: -0.243673
# [1200]	valid_set's soft_log_loss: -0.243017
# [1250]	valid_set's soft_log_loss: -0.241088
# [1300]	valid_set's soft_log_loss: -0.239904
# [1350]	valid_set's soft_log_loss: -0.239952
# [1400]	valid_set's soft_log_loss: -0.240743
# [1450]	valid_set's soft_log_loss: -0.240685
# [1500]	valid_set's soft_log_loss: -0.241182
# [1550]	valid_set's soft_log_loss: -0.240995
# [1600]	valid_set's soft_log_loss: -0.241075
# [1650]	valid_set's soft_log_loss: -0.241139
# [1700]	valid_set's soft_log_loss: -0.240491
# [1750]	valid_set's soft_log_loss: -0.240886
# 	Note: model has different eval_metric than default.
# 	-0.239	 = Validation score   (-soft_log_loss)
# 	1.82s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.3614	 = Validation score   (-soft_log_loss)
# 	0.68s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0911947	test: -1.0747753	best: -1.0747753 (0)	total: 511ms	remaining: 1h 25m 9s
# 20:	learn: -0.9907474	test: -0.7924533	best: -0.7924533 (20)	total: 676ms	remaining: 5m 21s
# 40:	learn: -0.9413799	test: -0.6572002	best: -0.6572002 (40)	total: 826ms	remaining: 3m 20s
# 60:	learn: -0.9080108	test: -0.5593287	best: -0.5593287 (60)	total: 980ms	remaining: 2m 39s
# 80:	learn: -0.8875565	test: -0.4960090	best: -0.4960090 (80)	total: 1.13s	remaining: 2m 18s
# 100:	learn: -0.8719696	test: -0.4545098	best: -0.4545098 (100)	total: 1.28s	remaining: 2m 5s
# 120:	learn: -0.8598734	test: -0.4235021	best: -0.4235021 (120)	total: 1.42s	remaining: 1m 56s
# 140:	learn: -0.8481177	test: -0.3946375	best: -0.3946375 (140)	total: 1.57s	remaining: 1m 49s
# 160:	learn: -0.8391876	test: -0.3715368	best: -0.3715368 (160)	total: 1.72s	remaining: 1m 45s
# 180:	learn: -0.8314427	test: -0.3535055	best: -0.3535055 (180)	total: 1.86s	remaining: 1m 41s
# 200:	learn: -0.8256260	test: -0.3390694	best: -0.3390694 (200)	total: 2s	remaining: 1m 37s
# 220:	learn: -0.8204295	test: -0.3297095	best: -0.3297095 (220)	total: 2.15s	remaining: 1m 35s
# 240:	learn: -0.8155023	test: -0.3171557	best: -0.3171557 (240)	total: 2.31s	remaining: 1m 33s
# 260:	learn: -0.8117859	test: -0.3096201	best: -0.3096201 (260)	total: 2.46s	remaining: 1m 31s
# 280:	learn: -0.8089586	test: -0.2995686	best: -0.2995686 (280)	total: 2.62s	remaining: 1m 30s
# 300:	learn: -0.8060710	test: -0.2950822	best: -0.2947037 (299)	total: 2.77s	remaining: 1m 29s
# 320:	learn: -0.8034720	test: -0.2914340	best: -0.2914177 (319)	total: 2.95s	remaining: 1m 28s
# 340:	learn: -0.8015227	test: -0.2846182	best: -0.2846182 (340)	total: 3.09s	remaining: 1m 27s
# 360:	learn: -0.7995462	test: -0.2805033	best: -0.2805033 (360)	total: 3.23s	remaining: 1m 26s
# 380:	learn: -0.7978524	test: -0.2787800	best: -0.2787800 (380)	total: 3.39s	remaining: 1m 25s
# 400:	learn: -0.7963865	test: -0.2748370	best: -0.2745266 (398)	total: 3.54s	remaining: 1m 24s
# 420:	learn: -0.7950912	test: -0.2740124	best: -0.2737059 (415)	total: 3.69s	remaining: 1m 23s
# 440:	learn: -0.7938660	test: -0.2719423	best: -0.2718741 (437)	total: 3.85s	remaining: 1m 23s
# 460:	learn: -0.7926205	test: -0.2689287	best: -0.2687491 (459)	total: 4s	remaining: 1m 22s
# 480:	learn: -0.7914817	test: -0.2662661	best: -0.2662661 (480)	total: 4.17s	remaining: 1m 22s
# 500:	learn: -0.7905978	test: -0.2640540	best: -0.2640540 (500)	total: 4.32s	remaining: 1m 21s
# 520:	learn: -0.7897406	test: -0.2621763	best: -0.2621763 (520)	total: 4.48s	remaining: 1m 21s
# 540:	learn: -0.7889555	test: -0.2607496	best: -0.2607496 (540)	total: 4.63s	remaining: 1m 20s
# 560:	learn: -0.7883032	test: -0.2590510	best: -0.2590510 (560)	total: 4.78s	remaining: 1m 20s
# 580:	learn: -0.7876515	test: -0.2577495	best: -0.2577495 (580)	total: 4.92s	remaining: 1m 19s
# 600:	learn: -0.7869599	test: -0.2559373	best: -0.2555137 (597)	total: 5.07s	remaining: 1m 19s
# 620:	learn: -0.7863418	test: -0.2545988	best: -0.2545182 (618)	total: 5.21s	remaining: 1m 18s
# 640:	learn: -0.7857564	test: -0.2524944	best: -0.2524944 (640)	total: 5.36s	remaining: 1m 18s
# 660:	learn: -0.7852592	test: -0.2510087	best: -0.2508961 (659)	total: 5.53s	remaining: 1m 18s
# 680:	learn: -0.7847873	test: -0.2502346	best: -0.2501392 (675)	total: 5.69s	remaining: 1m 17s
# 700:	learn: -0.7842906	test: -0.2485238	best: -0.2484476 (699)	total: 5.85s	remaining: 1m 17s
# 720:	learn: -0.7838678	test: -0.2475369	best: -0.2475369 (720)	total: 6s	remaining: 1m 17s
# 740:	learn: -0.7834608	test: -0.2466940	best: -0.2466940 (740)	total: 6.17s	remaining: 1m 17s
# 760:	learn: -0.7830411	test: -0.2453177	best: -0.2453177 (760)	total: 6.33s	remaining: 1m 16s
# 780:	learn: -0.7826901	test: -0.2446886	best: -0.2446886 (780)	total: 6.48s	remaining: 1m 16s
# 800:	learn: -0.7823517	test: -0.2441228	best: -0.2440140 (798)	total: 6.63s	remaining: 1m 16s
# 820:	learn: -0.7820452	test: -0.2433934	best: -0.2433934 (820)	total: 6.78s	remaining: 1m 15s
# 840:	learn: -0.7817351	test: -0.2425556	best: -0.2425556 (840)	total: 6.94s	remaining: 1m 15s
# 860:	learn: -0.7814274	test: -0.2424662	best: -0.2424662 (860)	total: 7.09s	remaining: 1m 15s
# 880:	learn: -0.7811176	test: -0.2412364	best: -0.2411644 (879)	total: 7.24s	remaining: 1m 14s
# 900:	learn: -0.7808671	test: -0.2404029	best: -0.2404029 (900)	total: 7.39s	remaining: 1m 14s
# 920:	learn: -0.7806250	test: -0.2403547	best: -0.2403547 (920)	total: 7.53s	remaining: 1m 14s
# 940:	learn: -0.7803783	test: -0.2401686	best: -0.2401535 (939)	total: 7.68s	remaining: 1m 13s
# 960:	learn: -0.7801027	test: -0.2388726	best: -0.2388726 (960)	total: 7.84s	remaining: 1m 13s
# 980:	learn: -0.7798845	test: -0.2377476	best: -0.2377476 (980)	total: 8s	remaining: 1m 13s
# 1000:	learn: -0.7797223	test: -0.2371097	best: -0.2370257 (998)	total: 8.14s	remaining: 1m 13s
# 1020:	learn: -0.7795263	test: -0.2371065	best: -0.2370093 (1012)	total: 8.29s	remaining: 1m 12s
# 1040:	learn: -0.7792925	test: -0.2357400	best: -0.2357360 (1038)	total: 8.45s	remaining: 1m 12s
# 1060:	learn: -0.7790907	test: -0.2352628	best: -0.2352628 (1060)	total: 8.6s	remaining: 1m 12s
# 1080:	learn: -0.7788827	test: -0.2342196	best: -0.2341299 (1079)	total: 8.76s	remaining: 1m 12s
# 1100:	learn: -0.7787184	test: -0.2344522	best: -0.2341299 (1079)	total: 8.91s	remaining: 1m 11s
# 1120:	learn: -0.7785662	test: -0.2341814	best: -0.2341299 (1079)	total: 9.05s	remaining: 1m 11s
# 1140:	learn: -0.7783715	test: -0.2334662	best: -0.2334525 (1139)	total: 9.21s	remaining: 1m 11s
# 1160:	learn: -0.7781864	test: -0.2342303	best: -0.2334525 (1139)	total: 9.37s	remaining: 1m 11s
# 1180:	learn: -0.7779918	test: -0.2341817	best: -0.2334525 (1139)	total: 9.51s	remaining: 1m 11s
# 1200:	learn: -0.7778466	test: -0.2337741	best: -0.2334525 (1139)	total: 9.66s	remaining: 1m 10s
# 1220:	learn: -0.7777123	test: -0.2332164	best: -0.2332164 (1220)	total: 9.81s	remaining: 1m 10s
# 1240:	learn: -0.7775419	test: -0.2328233	best: -0.2326912 (1239)	total: 9.96s	remaining: 1m 10s
# 1260:	learn: -0.7774276	test: -0.2326056	best: -0.2326056 (1260)	total: 10.1s	remaining: 1m 10s
# 1280:	learn: -0.7773063	test: -0.2324560	best: -0.2323001 (1276)	total: 10.3s	remaining: 1m 9s
# 1300:	learn: -0.7771592	test: -0.2317219	best: -0.2316929 (1299)	total: 10.4s	remaining: 1m 9s
# 1320:	learn: -0.7770275	test: -0.2315220	best: -0.2314610 (1310)	total: 10.6s	remaining: 1m 9s
# 1340:	learn: -0.7769009	test: -0.2318732	best: -0.2314361 (1335)	total: 10.7s	remaining: 1m 9s
# 1360:	learn: -0.7767808	test: -0.2319495	best: -0.2314361 (1335)	total: 10.9s	remaining: 1m 9s
# 1380:	learn: -0.7766731	test: -0.2320149	best: -0.2314361 (1335)	total: 11s	remaining: 1m 8s
# 1400:	learn: -0.7765755	test: -0.2321603	best: -0.2314361 (1335)	total: 11.2s	remaining: 1m 8s
# 1420:	learn: -0.7764543	test: -0.2321332	best: -0.2314361 (1335)	total: 11.3s	remaining: 1m 8s
# 1440:	learn: -0.7763534	test: -0.2314166	best: -0.2313935 (1439)	total: 11.5s	remaining: 1m 8s
# 1460:	learn: -0.7762664	test: -0.2313537	best: -0.2312791 (1459)	total: 11.6s	remaining: 1m 8s
# 1480:	learn: -0.7761480	test: -0.2314301	best: -0.2311991 (1467)	total: 11.8s	remaining: 1m 8s
# 1500:	learn: -0.7760621	test: -0.2311022	best: -0.2310985 (1499)	total: 12s	remaining: 1m 7s
# 1520:	learn: -0.7759776	test: -0.2307117	best: -0.2306413 (1518)	total: 12.1s	remaining: 1m 7s
# 1540:	learn: -0.7758880	test: -0.2308448	best: -0.2306413 (1518)	total: 12.3s	remaining: 1m 7s
# 1560:	learn: -0.7758022	test: -0.2306670	best: -0.2304813 (1556)	total: 12.4s	remaining: 1m 7s
# 1580:	learn: -0.7757178	test: -0.2305378	best: -0.2303179 (1572)	total: 12.6s	remaining: 1m 6s
# 1600:	learn: -0.7756460	test: -0.2305567	best: -0.2303179 (1572)	total: 12.7s	remaining: 1m 6s
# 1620:	learn: -0.7755705	test: -0.2307765	best: -0.2303179 (1572)	total: 12.9s	remaining: 1m 6s
# 1640:	learn: -0.7755005	test: -0.2304737	best: -0.2303179 (1572)	total: 13s	remaining: 1m 6s
# 1660:	learn: -0.7754173	test: -0.2300883	best: -0.2299217 (1656)	total: 13.2s	remaining: 1m 6s
# 1680:	learn: -0.7753405	test: -0.2294244	best: -0.2292903 (1676)	total: 13.3s	remaining: 1m 5s
# 1700:	learn: -0.7752809	test: -0.2294253	best: -0.2290726 (1692)	total: 13.5s	remaining: 1m 5s
# 1720:	learn: -0.7752177	test: -0.2291623	best: -0.2290726 (1692)	total: 13.7s	remaining: 1m 5s
# 1740:	learn: -0.7751654	test: -0.2291851	best: -0.2290726 (1692)	total: 13.8s	remaining: 1m 5s
# 1760:	learn: -0.7751024	test: -0.2289896	best: -0.2289896 (1760)	total: 14s	remaining: 1m 5s
# 1780:	learn: -0.7750375	test: -0.2291776	best: -0.2288705 (1766)	total: 14.1s	remaining: 1m 5s
# 1800:	learn: -0.7749815	test: -0.2293598	best: -0.2288705 (1766)	total: 14.3s	remaining: 1m 5s
# 1820:	learn: -0.7749073	test: -0.2294470	best: -0.2288705 (1766)	total: 14.5s	remaining: 1m 5s
# 1840:	learn: -0.7748475	test: -0.2294815	best: -0.2288705 (1766)	total: 14.6s	remaining: 1m 4s
# 1860:	learn: -0.7747930	test: -0.2298199	best: -0.2288705 (1766)	total: 14.8s	remaining: 1m 4s
# 1880:	learn: -0.7747447	test: -0.2295024	best: -0.2288705 (1766)	total: 15s	remaining: 1m 4s
# 1900:	learn: -0.7746931	test: -0.2292834	best: -0.2288705 (1766)	total: 15.1s	remaining: 1m 4s
# 1920:	learn: -0.7746411	test: -0.2296725	best: -0.2288705 (1766)	total: 15.3s	remaining: 1m 4s
# 1940:	learn: -0.7745846	test: -0.2292851	best: -0.2288705 (1766)	total: 15.4s	remaining: 1m 4s
# 1960:	learn: -0.7745362	test: -0.2290654	best: -0.2288705 (1766)	total: 15.6s	remaining: 1m 3s
# 1980:	learn: -0.7744934	test: -0.2291322	best: -0.2288705 (1766)	total: 15.7s	remaining: 1m 3s
# 2000:	learn: -0.7744479	test: -0.2286577	best: -0.2286538 (1997)	total: 15.9s	remaining: 1m 3s
# 2020:	learn: -0.7744105	test: -0.2285749	best: -0.2285128 (2004)	total: 16s	remaining: 1m 3s
# 2040:	learn: -0.7743680	test: -0.2283401	best: -0.2282783 (2036)	total: 16.2s	remaining: 1m 3s
# 2060:	learn: -0.7743212	test: -0.2282358	best: -0.2282358 (2060)	total: 16.4s	remaining: 1m 3s
# 2080:	learn: -0.7742805	test: -0.2284095	best: -0.2280642 (2066)	total: 16.5s	remaining: 1m 2s
# 2100:	learn: -0.7742297	test: -0.2282749	best: -0.2280642 (2066)	total: 16.7s	remaining: 1m 2s
# 2120:	learn: -0.7741889	test: -0.2281651	best: -0.2280642 (2066)	total: 16.8s	remaining: 1m 2s
# 2140:	learn: -0.7741560	test: -0.2282315	best: -0.2280642 (2066)	total: 17s	remaining: 1m 2s
# 2160:	learn: -0.7741101	test: -0.2282249	best: -0.2280642 (2066)	total: 17.1s	remaining: 1m 2s
# 2180:	learn: -0.7740708	test: -0.2286626	best: -0.2280642 (2066)	total: 17.3s	remaining: 1m 1s
# 2200:	learn: -0.7740359	test: -0.2284651	best: -0.2280642 (2066)	total: 17.4s	remaining: 1m 1s
# 2220:	learn: -0.7739995	test: -0.2281809	best: -0.2280642 (2066)	total: 17.6s	remaining: 1m 1s
# 2240:	learn: -0.7739583	test: -0.2286196	best: -0.2280642 (2066)	total: 17.7s	remaining: 1m 1s
# 2260:	learn: -0.7739192	test: -0.2282627	best: -0.2280642 (2066)	total: 17.9s	remaining: 1m 1s
# 2280:	learn: -0.7738798	test: -0.2279053	best: -0.2279053 (2280)	total: 18.1s	remaining: 1m 1s
# 2300:	learn: -0.7738477	test: -0.2274998	best: -0.2274795 (2299)	total: 18.2s	remaining: 1m
# 2320:	learn: -0.7738164	test: -0.2275583	best: -0.2274407 (2309)	total: 18.4s	remaining: 1m
# 2340:	learn: -0.7737839	test: -0.2272736	best: -0.2272311 (2335)	total: 18.5s	remaining: 1m
# 2360:	learn: -0.7737508	test: -0.2271852	best: -0.2271852 (2360)	total: 18.7s	remaining: 1m
# 2380:	learn: -0.7737161	test: -0.2271849	best: -0.2270796 (2364)	total: 18.9s	remaining: 1m
# 2400:	learn: -0.7736825	test: -0.2271551	best: -0.2270338 (2387)	total: 19s	remaining: 1m
# 2420:	learn: -0.7736542	test: -0.2273971	best: -0.2270338 (2387)	total: 19.2s	remaining: 1m
# 2440:	learn: -0.7736222	test: -0.2276609	best: -0.2270338 (2387)	total: 19.4s	remaining: 59.9s
# 2460:	learn: -0.7735869	test: -0.2280510	best: -0.2270338 (2387)	total: 19.5s	remaining: 59.8s
# 2480:	learn: -0.7735610	test: -0.2284214	best: -0.2270338 (2387)	total: 19.7s	remaining: 59.6s
# 2500:	learn: -0.7735348	test: -0.2281201	best: -0.2270338 (2387)	total: 19.8s	remaining: 59.5s
# 2520:	learn: -0.7735050	test: -0.2281921	best: -0.2270338 (2387)	total: 20s	remaining: 59.3s
# 2540:	learn: -0.7734755	test: -0.2283399	best: -0.2270338 (2387)	total: 20.1s	remaining: 59.1s
# 2560:	learn: -0.7734505	test: -0.2282640	best: -0.2270338 (2387)	total: 20.3s	remaining: 58.9s
# 2580:	learn: -0.7734190	test: -0.2281195	best: -0.2270338 (2387)	total: 20.4s	remaining: 58.8s
# 2600:	learn: -0.7733961	test: -0.2280080	best: -0.2270338 (2387)	total: 20.6s	remaining: 58.6s
# 2620:	learn: -0.7733689	test: -0.2280434	best: -0.2270338 (2387)	total: 20.8s	remaining: 58.5s
# 2640:	learn: -0.7733446	test: -0.2283788	best: -0.2270338 (2387)	total: 20.9s	remaining: 58.3s
# 2660:	learn: -0.7733186	test: -0.2283515	best: -0.2270338 (2387)	total: 21.1s	remaining: 58.1s
# 2680:	learn: -0.7732941	test: -0.2280435	best: -0.2270338 (2387)	total: 21.2s	remaining: 58s
# 2700:	learn: -0.7732719	test: -0.2280418	best: -0.2270338 (2387)	total: 21.4s	remaining: 57.8s
# 2720:	learn: -0.7732475	test: -0.2282957	best: -0.2270338 (2387)	total: 21.5s	remaining: 57.6s
# 2740:	learn: -0.7732269	test: -0.2282841	best: -0.2270338 (2387)	total: 21.7s	remaining: 57.5s
# 2760:	learn: -0.7732065	test: -0.2282433	best: -0.2270338 (2387)	total: 21.9s	remaining: 57.3s
# 2780:	learn: -0.7731895	test: -0.2283214	best: -0.2270338 (2387)	total: 22s	remaining: 57.2s
# 2800:	learn: -0.7731654	test: -0.2286762	best: -0.2270338 (2387)	total: 22.2s	remaining: 57s
# 2820:	learn: -0.7731438	test: -0.2287344	best: -0.2270338 (2387)	total: 22.3s	remaining: 56.8s
# 2840:	learn: -0.7731246	test: -0.2286370	best: -0.2270338 (2387)	total: 22.5s	remaining: 56.7s
# 2860:	learn: -0.7731054	test: -0.2288023	best: -0.2270338 (2387)	total: 22.6s	remaining: 56.5s
# 2880:	learn: -0.7730873	test: -0.2286269	best: -0.2270338 (2387)	total: 22.8s	remaining: 56.4s
# 2900:	learn: -0.7730643	test: -0.2283231	best: -0.2270338 (2387)	total: 23s	remaining: 56.2s
# 2920:	learn: -0.7730453	test: -0.2284859	best: -0.2270338 (2387)	total: 23.1s	remaining: 56.1s
# 2940:	learn: -0.7730264	test: -0.2283825	best: -0.2270338 (2387)	total: 23.3s	remaining: 55.9s
# 2960:	learn: -0.7730098	test: -0.2285292	best: -0.2270338 (2387)	total: 23.4s	remaining: 55.7s
# 2980:	learn: -0.7729942	test: -0.2284701	best: -0.2270338 (2387)	total: 23.6s	remaining: 55.5s
# 3000:	learn: -0.7729777	test: -0.2284007	best: -0.2270338 (2387)	total: 23.7s	remaining: 55.4s
# 3020:	learn: -0.7729580	test: -0.2283887	best: -0.2270338 (2387)	total: 23.9s	remaining: 55.2s
# 3040:	learn: -0.7729366	test: -0.2284218	best: -0.2270338 (2387)	total: 24.1s	remaining: 55s
# 3060:	learn: -0.7729163	test: -0.2284401	best: -0.2270338 (2387)	total: 24.2s	remaining: 54.9s
# 3080:	learn: -0.7728961	test: -0.2283854	best: -0.2270338 (2387)	total: 24.4s	remaining: 54.7s
# 3100:	learn: -0.7728783	test: -0.2282762	best: -0.2270338 (2387)	total: 24.5s	remaining: 54.6s
# 	Note: model has different eval_metric than default.
# 	-0.227	 = Validation score   (-soft_log_loss)
# 	33.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# 3120:	learn: -0.7728616	test: -0.2282601	best: -0.2270338 (2387)	total: 24.7s	remaining: 54.4s
#
# bestTest = -0.2270338175
# bestIteration = 2387
#
# Shrink model to first 2388 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.1205	 = Validation score   (-soft_log_loss)
# 	3.52s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'NeuralNetTorch_2_DSTL': 1.0}
# 	Note: model has different eval_metric than default.
# 	-0.1205	 = Validation score   (-soft_log_loss)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_2_L2_DSTL   0.944444  soft_log_loss       0.015223   3.544137                0.000000           0.019741            2       True         24
# 1       NeuralNetTorch_2_DSTL   0.944444  soft_log_loss       0.015223   3.524395                0.015223           3.524395            1       True         23
# 2             LightGBM_2_DSTL   0.888889  soft_log_loss       0.000000   1.824318                0.000000           1.824318            1       True         20
# 3             CatBoost_2_DSTL   0.888889  soft_log_loss       0.000000  33.450050                0.000000          33.450050            1       True         22
# 4      RandomForestMSE_2_DSTL   0.888889  soft_log_loss       0.054568   0.684992                0.054568           0.684992            1       True         21
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}-importance-old.csv')
# Out:
# 按测试集分数对所有模型排序：
#                          model  score_test  score_val    eval_metric  \
# 1               KNeighborsDist    0.882353   0.944444       accuracy
# 0               KNeighborsUnif    0.882353   0.833333       accuracy
# 6          WeightedEnsemble_L2    0.764706   1.000000       accuracy
# 2                     LightGBM    0.764706   0.944444       accuracy
# 3                   LightGBMXT    0.764706   0.944444       accuracy
# 9   WeightedEnsemble_2_L2_DSTL    0.764706   0.944444  soft_log_loss
# 10       NeuralNetTorch_2_DSTL    0.764706   0.944444  soft_log_loss
# 15              ExtraTreesGini    0.764706   0.944444       accuracy
# 4              CatBoost_2_DSTL    0.764706   0.888889  soft_log_loss
# 8               NeuralNetTorch    0.764706   0.888889       accuracy
# 11               LightGBM_DSTL    0.764706   0.888889  soft_log_loss
# 12    WeightedEnsemble_L2_DSTL    0.764706   0.888889  soft_log_loss
# 13              ExtraTreesEntr    0.764706   0.888889       accuracy
# 14            RandomForestEntr    0.764706   0.888889       accuracy
# 16            RandomForestGini    0.764706   0.888889       accuracy
# 17        RandomForestMSE_DSTL    0.764706   0.888889  soft_log_loss
# 5          NeuralNetTorch_DSTL    0.764706   0.833333  soft_log_loss
# 7                CatBoost_DSTL    0.764706   0.833333  soft_log_loss
# 18               LightGBMLarge    0.705882   0.944444       accuracy
# 19             NeuralNetFastAI    0.705882   0.944444       accuracy
# 20             LightGBM_2_DSTL    0.705882   0.888889  soft_log_loss
# 21                    CatBoost    0.647059   0.944444       accuracy
# 22                     XGBoost    0.647059   0.888889       accuracy
# 23      RandomForestMSE_2_DSTL    0.588235   0.888889  soft_log_loss
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 1         0.013118       0.000000   0.010643                 0.013118
# 0         0.000000       0.187289   2.759497                 0.000000
# 6         0.011689       0.002181   2.731405                 0.000000
# 2         0.003592       0.000000   0.306873                 0.003592
# 3         0.006751       0.000000   0.350920                 0.006751
# 9         0.020179       0.015223   3.544137                 0.000000
# 10        0.020179       0.015223   3.524395                 0.020179
# 15        0.090331       0.074526   0.762370                 0.090331
# 4         0.008898       0.000000  33.450050                 0.008898
# 8         0.013095       0.012775   5.581058                 0.013095
# 11        0.020508       0.000000   0.848510                 0.020508
# 12        0.032663       0.000000  33.910043                 0.000000
# 13        0.071563       0.069777   0.872721                 0.071563
# 14        0.080475       0.056738   0.897537                 0.080475
# 16        0.098959       0.074130   0.814634                 0.098959
# 17        0.118673       0.060858   0.668337                 0.118673
# 5         0.010129       0.011905   2.501716                 0.010129
# 7         0.012155       0.000000  33.037623                 0.012155
# 18        0.000000       0.001000   0.486470                 0.000000
# 19        0.011689       0.002181   1.447600                 0.011689
# 20        0.057021       0.000000   1.824318                 0.057021
# 21        0.000000       0.000000   1.128586                 0.000000
# 22        0.024478       0.000000   0.244022                 0.024478
# 23        0.123359       0.054568   0.684992                 0.123359
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 1                 0.000000           0.010643            1       True
# 0                 0.187289           2.759497            1       True
# 6                 0.000000           0.155218            2       True
# 2                 0.000000           0.306873            1       True
# 3                 0.000000           0.350920            1       True
# 9                 0.000000           0.019741            2       True
# 10                0.015223           3.524395            1       True
# 15                0.074526           0.762370            1       True
# 4                 0.000000          33.450050            1       True
# 8                 0.012775           5.581058            1       True
# 11                0.000000           0.848510            1       True
# 12                0.000000           0.023909            2       True
# 13                0.069777           0.872721            1       True
# 14                0.056738           0.897537            1       True
# 16                0.074130           0.814634            1       True
# 17                0.060858           0.668337            1       True
# 5                 0.011905           2.501716            1       True
# 7                 0.000000          33.037623            1       True
# 18                0.001000           0.486470            1       True
# 19                0.002181           1.447600            1       True
# 20                0.000000           1.824318            1       True
# 21                0.000000           1.128586            1       True
# 22                0.000000           0.244022            1       True
# 23                0.054568           0.684992            1       True
#
#     fit_order
# 1           2
# 0           1
# 6          14
# 2           5
# 3           4
# 9          24
# 10         23
# 15          9
# 4          22
# 8          12
# 11         15
# 12         19
# 13         10
# 14          7
# 16          6
# 17         16
# 5          18
# 7          17
# 18         13
# 19          3
# 20         20
# 21          8
# 22         11
# 23         21
# 测试集上的最佳蒸馏模型：
# WeightedEnsemble_2_L2_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.7647058823529411
# Evaluations on test data:
# {
#     "accuracy": 0.7647058823529411,
#     "balanced_accuracy": 0.7000000000000001,
#     "mcc": 0.6259425676138543
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.6,
#         "recall": 0.6,
#         "f1-score": 0.6,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5,
#         "f1-score": 0.5714285714285714,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.7647058823529411,
#     "macro avg": {
#         "precision": 0.7185185185185184,
#         "recall": 0.7000000000000001,
#         "f1-score": 0.7042016806722687,
#         "support": 17.0
#     },
#     "weighted avg": {
#         "precision": 0.7516339869281046,
#         "recall": 0.7647058823529411,
#         "f1-score": 0.7538309441423628,
#         "support": 17.0
#     }
# }
# {'accuracy': 0.7647058823529411, 'balanced_accuracy': 0.7000000000000001, 'mcc': 0.6259425676138543, 'confusion_matrix':                                Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2-3 LINC00507 FREM3 deep                              3
# Exc L3-4 RORB CARM1P1                                      2
# Exc L3-5 RORB COL22A1                                      0
#
#                                Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# Exc L2-3 LINC00507 FREM3 deep                      1                      1
# Exc L3-4 RORB CARM1P1                              2                      0
# Exc L3-5 RORB COL22A1                              0                      8  , 'classification_report': {'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.6, 'recall': 0.6, 'f1-score': 0.6, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 0.6666666666666666, 'recall': 0.5, 'f1-score': 0.5714285714285714, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.7647058823529411, 'macro avg': {'precision': 0.7185185185185184, 'recall': 0.7000000000000001, 'f1-score': 0.7042016806722687, 'support': 17.0}, 'weighted avg': {'precision': 0.7516339869281046, 'recall': 0.7647058823529411, 'f1-score': 0.7538309441423628, 'support': 17.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x25586f46d50>,
#   <matplotlib.axis.YTick at 0x25586f95e10>,
#   <matplotlib.axis.YTick at 0x2558717b810>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-3 LINC00507 FREM3 deep')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif', 'KNeighborsDist', 'NeuralNetFastAI', 'LightGBMXT', 'LightGBM', 'RandomForestGini', 'RandomForestEntr', 'CatBoost', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'NeuralNetTorch', 'LightGBMLarge', 'WeightedEnsemble_L2', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif model: Exc L3-4 RORB CARM1P1

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
predictor.delete_models(models_to_keep='best')
# Out:
# Dry run enabled, AutoGluon would have deleted the following models: ['KNeighborsUnif', 'KNeighborsDist', 'NeuralNetFastAI', 'LightGBMXT', 'LightGBM', 'RandomForestGini', 'RandomForestEntr', 'CatBoost', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'NeuralNetTorch', 'LightGBMLarge', 'WeightedEnsemble_L2', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']
# 	Directory models\Teacher\medium_quality-20241105-202021\models\KNeighborsUnif would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\KNeighborsDist would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\NeuralNetFastAI would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\LightGBMXT would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\LightGBM would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\RandomForestGini would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\RandomForestEntr would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\CatBoost would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\ExtraTreesGini would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\ExtraTreesEntr would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\XGBoost would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\NeuralNetTorch would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\LightGBMLarge would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\WeightedEnsemble_L2 would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\RandomForestMSE_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\CatBoost_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\NeuralNetTorch_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\WeightedEnsemble_L2_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\LightGBM_2_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\RandomForestMSE_2_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\CatBoost_2_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\NeuralNetTorch_2_DSTL would have been deleted.
# 	Directory models\Teacher\medium_quality-20241105-202021\models\WeightedEnsemble_2_L2_DSTL would have been deleted.
# To perform the deletion, set dry_run=False
