# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       7 from autogluon.tabular import TabularDataset, TabularPredictor
#       8 import matplotlib.pyplot as plt
# ----> 9 from utils import *
#
# File c:\Users\JSJ\cells\tcell\ipynb\utils.py:564
#     560     with st_redirect(sys.stderr, dst):
#     561         yield
# --> 564 @st.dialog("Model Loading", width='large')
#     565 def load_modelset():
#     566     config = st.session_state['config']
#     567     dataset = st.session_state['dataset']
#
# NameError: name 'st' is not defined

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 36)
# Unlabeled_data:   (209, 36)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_resistance    230 non-null    float64
#  1   sag                 230 non-null    float64
#  2   VmatSag             230 non-null    float64
#  3   vmbaseM             230 non-null    float64
#  4   tau                 230 non-null    float64
#  5   FAP_rheobase        230 non-null    float64
#  6   FAP_num_APs         230 non-null    float64
#  7   TS1_rheobase        230 non-null    float64
#  8   TS1_num_APs         230 non-null    float64
#  9   TS2_rheobase        230 non-null    float64
#  10  TS2_num_APs         230 non-null    float64
#  11  TS1_adp_index       201 non-null    float64
#  12  TS2_adp_index       211 non-null    float64
#  13  FAP_threshold       230 non-null    float64
#  14  FAP_peak            230 non-null    float64
#  15  FAP_maxupstroke     230 non-null    float64
#  16  FAP_maxdownstroke   230 non-null    float64
#  17  FAP_halfwidth       230 non-null    float64
#  18  FAP_avg_upstroke    230 non-null    float64
#  19  FAP_avg_downstroke  230 non-null    float64
#  20  FAP_up_down_ratio   230 non-null    float64
#  21  TS1_threshold       230 non-null    float64
#  22  TS1_maxupstroke     230 non-null    float64
#  23  TS1_maxdownstroke   230 non-null    float64
#  24  TS1_halfwidth       230 non-null    float64
#  25  TS1_avg_upstroke    230 non-null    float64
#  26  TS1_avg_downstroke  230 non-null    float64
#  27  TS1_up_down_ratio   230 non-null    float64
#  28  TS2_threshold       230 non-null    float64
#  29  TS2_peak            230 non-null    float64
#  30  TS2_maxupstroke     230 non-null    float64
#  31  TS2_maxdownstroke   230 non-null    float64
#  32  TS2_avg_upstroke    230 non-null    float64
#  33  TS2_avg_downstroke  230 non-null    float64
#  34  TS2_up_down_ratio   230 non-null    float64
#  35  label               230 non-null    object
# dtypes: float64(35), object(1)
# memory usage: 74.6+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_resistance    230 non-null    float64
#  1   sag                 230 non-null    float64
#  2   VmatSag             230 non-null    float64
#  3   vmbaseM             230 non-null    float64
#  4   tau                 230 non-null    float64
#  5   FAP_rheobase        230 non-null    float64
#  6   FAP_num_APs         230 non-null    float64
#  7   TS1_rheobase        230 non-null    float64
#  8   TS1_num_APs         230 non-null    float64
#  9   TS2_rheobase        230 non-null    float64
#  10  TS2_num_APs         230 non-null    float64
#  11  TS1_adp_index       230 non-null    float64
#  12  TS2_adp_index       230 non-null    float64
#  13  FAP_threshold       230 non-null    float64
#  14  FAP_peak            230 non-null    float64
#  15  FAP_maxupstroke     230 non-null    float64
#  16  FAP_maxdownstroke   230 non-null    float64
#  17  FAP_halfwidth       230 non-null    float64
#  18  FAP_avg_upstroke    230 non-null    float64
#  19  FAP_avg_downstroke  230 non-null    float64
#  20  FAP_up_down_ratio   230 non-null    float64
#  21  TS1_threshold       230 non-null    float64
#  22  TS1_maxupstroke     230 non-null    float64
#  23  TS1_maxdownstroke   230 non-null    float64
#  24  TS1_halfwidth       230 non-null    float64
#  25  TS1_avg_upstroke    230 non-null    float64
#  26  TS1_avg_downstroke  230 non-null    float64
#  27  TS1_up_down_ratio   230 non-null    float64
#  28  TS2_threshold       230 non-null    float64
#  29  TS2_peak            230 non-null    float64
#  30  TS2_maxupstroke     230 non-null    float64
#  31  TS2_maxdownstroke   230 non-null    float64
#  32  TS2_avg_upstroke    230 non-null    float64
#  33  TS2_avg_downstroke  230 non-null    float64
#  34  TS2_up_down_ratio   230 non-null    float64
#  35  label               230 non-null    object
# dtypes: float64(35), object(1)
# memory usage: 64.8+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_resistance    207 non-null    float64
#  1   sag                 207 non-null    float64
#  2   VmatSag             207 non-null    float64
#  3   vmbaseM             209 non-null    float64
#  4   tau                 200 non-null    float64
#  5   FAP_rheobase        209 non-null    float64
#  6   FAP_num_APs         209 non-null    float64
#  7   TS1_rheobase        209 non-null    float64
#  8   TS1_num_APs         208 non-null    float64
#  9   TS2_rheobase        208 non-null    float64
#  10  TS2_num_APs         208 non-null    float64
#  11  TS1_adp_index       186 non-null    float64
#  12  TS2_adp_index       196 non-null    float64
#  13  FAP_threshold       209 non-null    float64
#  14  FAP_peak            187 non-null    float64
#  15  FAP_maxupstroke     209 non-null    float64
#  16  FAP_maxdownstroke   209 non-null    float64
#  17  FAP_halfwidth       209 non-null    float64
#  18  FAP_avg_upstroke    209 non-null    float64
#  19  FAP_avg_downstroke  209 non-null    float64
#  20  FAP_up_down_ratio   209 non-null    float64
#  21  TS1_threshold       209 non-null    float64
#  22  TS1_maxupstroke     209 non-null    float64
#  23  TS1_maxdownstroke   209 non-null    float64
#  24  TS1_halfwidth       209 non-null    float64
#  25  TS1_avg_upstroke    209 non-null    float64
#  26  TS1_avg_downstroke  209 non-null    float64
#  27  TS1_up_down_ratio   209 non-null    float64
#  28  TS2_threshold       208 non-null    float64
#  29  TS2_peak            208 non-null    float64
#  30  TS2_maxupstroke     208 non-null    float64
#  31  TS2_maxdownstroke   208 non-null    float64
#  32  TS2_avg_upstroke    208 non-null    float64
#  33  TS2_avg_downstroke  208 non-null    float64
#  34  TS2_up_down_ratio   208 non-null    float64
#  35  label               0 non-null      object
# dtypes: float64(35), object(1)
# memory usage: 60.4+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_resistance    209 non-null    float64
#  1   sag                 209 non-null    float64
#  2   VmatSag             209 non-null    float64
#  3   vmbaseM             209 non-null    float64
#  4   tau                 209 non-null    float64
#  5   FAP_rheobase        209 non-null    float64
#  6   FAP_num_APs         209 non-null    float64
#  7   TS1_rheobase        209 non-null    float64
#  8   TS1_num_APs         209 non-null    float64
#  9   TS2_rheobase        209 non-null    float64
#  10  TS2_num_APs         209 non-null    float64
#  11  TS1_adp_index       209 non-null    float64
#  12  TS2_adp_index       209 non-null    float64
#  13  FAP_threshold       209 non-null    float64
#  14  FAP_peak            209 non-null    float64
#  15  FAP_maxupstroke     209 non-null    float64
#  16  FAP_maxdownstroke   209 non-null    float64
#  17  FAP_halfwidth       209 non-null    float64
#  18  FAP_avg_upstroke    209 non-null    float64
#  19  FAP_avg_downstroke  209 non-null    float64
#  20  FAP_up_down_ratio   209 non-null    float64
#  21  TS1_threshold       209 non-null    float64
#  22  TS1_maxupstroke     209 non-null    float64
#  23  TS1_maxdownstroke   209 non-null    float64
#  24  TS1_halfwidth       209 non-null    float64
#  25  TS1_avg_upstroke    209 non-null    float64
#  26  TS1_avg_downstroke  209 non-null    float64
#  27  TS1_up_down_ratio   209 non-null    float64
#  28  TS2_threshold       209 non-null    float64
#  29  TS2_peak            209 non-null    float64
#  30  TS2_maxupstroke     209 non-null    float64
#  31  TS2_maxdownstroke   209 non-null    float64
#  32  TS2_avg_upstroke    209 non-null    float64
#  33  TS2_avg_downstroke  209 non-null    float64
#  34  TS2_up_down_ratio   209 non-null    float64
#  35  label               0 non-null      float64
# dtypes: float64(36)
# memory usage: 58.9 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 35
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_resistance    46 non-null     float64
#  1   sag                 46 non-null     float64
#  2   VmatSag             46 non-null     float64
#  3   vmbaseM             46 non-null     float64
#  4   tau                 46 non-null     float64
#  5   FAP_rheobase        46 non-null     float64
#  6   FAP_num_APs         46 non-null     float64
#  7   TS1_rheobase        46 non-null     float64
#  8   TS1_num_APs         46 non-null     float64
#  9   TS2_rheobase        46 non-null     float64
#  10  TS2_num_APs         46 non-null     float64
#  11  TS1_adp_index       46 non-null     float64
#  12  TS2_adp_index       46 non-null     float64
#  13  FAP_threshold       46 non-null     float64
#  14  FAP_peak            46 non-null     float64
#  15  FAP_maxupstroke     46 non-null     float64
#  16  FAP_maxdownstroke   46 non-null     float64
#  17  FAP_halfwidth       46 non-null     float64
#  18  FAP_avg_upstroke    46 non-null     float64
#  19  FAP_avg_downstroke  46 non-null     float64
#  20  FAP_up_down_ratio   46 non-null     float64
#  21  TS1_threshold       46 non-null     float64
#  22  TS1_maxupstroke     46 non-null     float64
#  23  TS1_maxdownstroke   46 non-null     float64
#  24  TS1_halfwidth       46 non-null     float64
#  25  TS1_avg_upstroke    46 non-null     float64
#  26  TS1_avg_downstroke  46 non-null     float64
#  27  TS1_up_down_ratio   46 non-null     float64
#  28  TS2_threshold       46 non-null     float64
#  29  TS2_peak            46 non-null     float64
#  30  TS2_maxupstroke     46 non-null     float64
#  31  TS2_maxdownstroke   46 non-null     float64
#  32  TS2_avg_upstroke    46 non-null     float64
#  33  TS2_avg_downstroke  46 non-null     float64
#  34  TS2_up_down_ratio   46 non-null     float64
#  35  label               46 non-null     object
# dtypes: float64(35), object(1)
# memory usage: 13.1+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='medium_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=True
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
num_bag_sets=1
dynamic_stacking = True
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 5,
    'n_repeats': 20,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       8.22 GB / 15.92 GB (51.6%)
# Disk Space Avail:   321.97 GB / 931.51 GB (34.6%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Teacher\medium_quality-20241001-181902"
# Train Data Rows:    309
# Train Data Columns: 35
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	3 unique label values:  ['Exc L2-3 LINC00507 FREM3 superficial', 'Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8428.65 MB
# 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.1s = Fit runtime
# 	35 features in original data used to generate 35 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 247, Val Rows: 62
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3599.87s of the 3599.87s of remaining time.
# 	0.6129	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3599.8s of the 3599.8s of remaining time.
# 	0.7258	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3599.78s of the 3599.78s of remaining time.
# 	0.8226	 = Validation score   (accuracy)
# 	2.35s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3597.4s of the 3597.4s of remaining time.
# 	0.8548	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3596.84s of the 3596.84s of remaining time.
# 	0.8387	 = Validation score   (accuracy)
# 	0.48s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 3596.34s of the 3596.34s of remaining time.
# 	0.8387	 = Validation score   (accuracy)
# 	0.88s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3595.39s of the 3595.39s of remaining time.
# 	0.8548	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3594.46s of the 3594.46s of remaining time.
# 	0.8548	 = Validation score   (accuracy)
# 	6.52s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 3587.92s of the 3587.92s of remaining time.
# 	0.8871	 = Validation score   (accuracy)
# 	0.87s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3586.95s of the 3586.95s of remaining time.
# 	0.8548	 = Validation score   (accuracy)
# 	0.88s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3585.98s of the 3585.98s of remaining time.
# 	0.8548	 = Validation score   (accuracy)
# 	0.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3585.39s of the 3585.39s of remaining time.
# 	0.8226	 = Validation score   (accuracy)
# 	2.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3583.1s of the 3583.1s of remaining time.
# 	0.8387	 = Validation score   (accuracy)
# 	1.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3582.01s of remaining time.
# 	Ensemble Weights: {'ExtraTreesGini': 1.0}
# 	0.8871	 = Validation score   (accuracy)
# 	0.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18.18s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 955.0 rows/s (62 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241001-181902")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "Models\Teacher\medium_quality-20240902-131345"
#teacher_predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L2
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val eval_metric  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2   0.887097    accuracy       0.064922  1.021678                0.000000           0.148968            2       True         14
# 1        ExtraTreesGini   0.887097    accuracy       0.064922  0.872710                0.064922           0.872710            1       True          9
# 2               XGBoost   0.854839    accuracy       0.000000  0.560399                0.000000           0.560399            1       True         11
# 3            LightGBMXT   0.854839    accuracy       0.000000  0.520830                0.000000           0.520830            1       True          4
# 4              CatBoost   0.854839    accuracy       0.000000  6.519294                0.000000           6.519294            1       True          8
# 5        ExtraTreesEntr   0.854839    accuracy       0.059064  0.882522                0.059064           0.882522            1       True         10
# 6      RandomForestEntr   0.854839    accuracy       0.064964  0.859300                0.064964           0.859300            1       True          7
# 7         LightGBMLarge   0.838710    accuracy       0.000000  1.040842                0.000000           1.040842            1       True         13
# 8              LightGBM   0.838710    accuracy       0.000000  0.475719                0.000000           0.475719            1       True          5
# 9      RandomForestGini   0.838710    accuracy       0.057174  0.875706                0.057174           0.875706            1       True          6
# 10       NeuralNetTorch   0.822581    accuracy       0.015622  2.238977                0.015622           2.238977            1       True         12
# 11      NeuralNetFastAI   0.822581    accuracy       0.015625  2.349362                0.015625           2.349362            1       True          3
# 12       KNeighborsDist   0.725806    accuracy       0.005020  0.009998                0.005020           0.009998            1       True          2
# 13       KNeighborsUnif   0.612903    accuracy       0.003980  0.012131                0.003980           0.012131            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'WeightedEnsembleModel', 'LGBModel', 'XTModel', 'TabularNeuralNetTorchModel', 'RFModel', 'XGBoostModel', 'KNNModel', 'CatBoostModel', 'NNFastAiTabularModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.64      0.47      0.54        15
# Exc L2-3 LINC00507 FREM3 superficial       0.73      0.92      0.81        26
#             Exc L2-4 LINC00507 GLP2R       0.50      0.20      0.29         5
#
#                             accuracy                           0.70        46
#                            macro avg       0.62      0.53      0.55        46
#                         weighted avg       0.67      0.70      0.67        46
#                                predicted                                actual
# 0                       Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 1   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 2                       Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 3   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 4   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 5   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 6   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 7   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 8   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 9                       Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 10                      Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 11  Exc L2-3 LINC00507 FREM3 superficial              Exc L2-4 LINC00507 GLP2R
# 12                      Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 13  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 14  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 15  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 16  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 17  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 18  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 19                      Exc L2 LAMP5 LTK              Exc L2-4 LINC00507 GLP2R
# 20              Exc L2-4 LINC00507 GLP2R              Exc L2-4 LINC00507 GLP2R
# 21                      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial
# 22  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 23  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 24                      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial
# 25  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 26                      Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 27  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 28  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 29  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 30                      Exc L2 LAMP5 LTK                      Exc L2 LAMP5 LTK
# 31  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 32  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 33  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 34  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 35  Exc L2-3 LINC00507 FREM3 superficial              Exc L2-4 LINC00507 GLP2R
# 36              Exc L2-4 LINC00507 GLP2R                      Exc L2 LAMP5 LTK
# 37  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 38  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 39  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 40                      Exc L2 LAMP5 LTK              Exc L2-4 LINC00507 GLP2R
# 41  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 42  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 43  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 44  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 45  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# ### (1) 利用SNS的热力图函数绘制混淆矩阵
# #### SNS的版本和matplotlib的版本不匹配时，图中只显示第一行的数字，详细信息见https://blog.csdn.net/qq_63295638/article/details/135006122
# #### seaborn=0.12.2和matplotlib=3.8.0时，发现该问题，将matplotlib降为3.7.5解决该问题

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
print(t_types_updated)
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right", fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right", fontsize=10)
# Out:
# [[ 7  7  1]
#  [ 2 24  0]
#  [ 2  2  1]]
# ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']
# ([<matplotlib.axis.YTick at 0x2993aceef10>,
#   <matplotlib.axis.YTick at 0x29933dda850>,
#   <matplotlib.axis.YTick at 0x29933db16d0>],
#  [Text(0, 0, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 1, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 2, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 7  7  1]
#  [ 2 24  0]
#  [ 2  2  1]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.463333                              0.406667
# 1           0.133333                              0.746667
# 2           0.396667                              0.380000
# 3           0.273333                              0.550000
# 4           0.086667                              0.866667
# 5           0.246667                              0.510000
# 6           0.350000                              0.580000
# 7           0.096667                              0.693333
# 8           0.310000                              0.356667
# 9           0.510000                              0.260000
# 10          0.590000                              0.343333
# 11          0.303333                              0.420000
# 12          0.543333                              0.296667
# 13          0.270000                              0.556667
# 14          0.130000                              0.573333
# 15          0.330000                              0.443333
# 16          0.363333                              0.466667
# 17          0.216667                              0.513333
# 18          0.253333                              0.493333
# 19          0.573333                              0.270000
# 20          0.286667                              0.316667
# 21          0.430000                              0.386667
# 22          0.203333                              0.640000
# 23          0.170000                              0.753333
# 24          0.490000                              0.333333
# 25          0.363333                              0.400000
# 26          0.613333                              0.196667
# 27          0.276667                              0.616667
# 28          0.270000                              0.566667
# 29          0.293333                              0.533333
# 30          0.560000                              0.153333
# 31          0.116667                              0.820000
# 32          0.076667                              0.876667
# 33          0.320000                              0.620000
# 34          0.120000                              0.673333
# 35          0.356667                              0.386667
# 36          0.280000                              0.293333
# 37          0.123333                              0.753333
# 38          0.073333                              0.666667
# 39          0.046667                              0.800000
# 40          0.410000                              0.226667
# 41          0.360000                              0.443333
# 42          0.260000                              0.600000
# 43          0.363333                              0.453333
# 44          0.240000                              0.600000
# 45          0.236667                              0.580000
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.130000
# 1                   0.120000
# 2                   0.223333
# 3                   0.176667
# 4                   0.046667
# 5                   0.243333
# 6                   0.070000
# 7                   0.210000
# 8                   0.333333
# 9                   0.230000
# 10                  0.066667
# 11                  0.276667
# 12                  0.160000
# 13                  0.173333
# 14                  0.296667
# 15                  0.226667
# 16                  0.170000
# 17                  0.270000
# 18                  0.253333
# 19                  0.156667
# 20                  0.396667
# 21                  0.183333
# 22                  0.156667
# 23                  0.076667
# 24                  0.176667
# 25                  0.236667
# 26                  0.190000
# 27                  0.106667
# 28                  0.163333
# 29                  0.173333
# 30                  0.286667
# 31                  0.063333
# 32                  0.046667
# 33                  0.060000
# 34                  0.206667
# 35                  0.256667
# 36                  0.426667
# 37                  0.123333
# 38                  0.260000
# 39                  0.153333
# 40                  0.363333
# 41                  0.196667
# 42                  0.140000
# 43                  0.183333
# 44                  0.160000
# 45                  0.183333

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 35 features using 46 rows with 5 shuffle sets...
# 	14.31s	= Expected runtime (2.86s per shuffle set)
# 	0.67s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                     importance    stddev   p_value  n  p99_high   p99_low
# input_resistance      0.065217  0.015372  0.000344  5  0.096868  0.033566
# vmbaseM               0.026087  0.018188  0.016339  5  0.063537 -0.011363
# FAP_num_APs           0.021739  0.000000  0.500000  5  0.021739  0.021739
# TS2_peak              0.021739  0.000000  0.500000  5  0.021739  0.021739
# TS1_rheobase          0.021739  0.015372  0.017055  5  0.053390 -0.009912
# FAP_halfwidth         0.021739  0.015372  0.017055  5  0.053390 -0.009912
# TS2_rheobase          0.017391  0.009722  0.008065  5  0.037409 -0.002626
# sag                   0.017391  0.032244  0.147128  5  0.083783 -0.049000
# VmatSag               0.017391  0.018188  0.049650  5  0.054841 -0.020059
# TS2_threshold         0.017391  0.009722  0.008065  5  0.037409 -0.002626
# tau                   0.017391  0.009722  0.008065  5  0.037409 -0.002626
# FAP_rheobase          0.013043  0.024786  0.152279  5  0.064079 -0.037992
# TS1_adp_index         0.013043  0.019444  0.104000  5  0.053079 -0.026992
# FAP_threshold         0.013043  0.011907  0.035242  5  0.037560 -0.011473
# FAP_maxdownstroke     0.013043  0.011907  0.035242  5  0.037560 -0.011473
# TS1_threshold         0.013043  0.011907  0.035242  5  0.037560 -0.011473
# TS2_avg_upstroke      0.008696  0.011907  0.088904  5  0.033212 -0.015821
# TS1_halfwidth         0.004348  0.018188  0.310654  5  0.041798 -0.033102
# FAP_maxupstroke       0.004348  0.009722  0.186950  5  0.024366 -0.015670
# TS2_avg_downstroke    0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxdownstroke     0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_maxupstroke       0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_up_down_ratio     0.000000  0.015372  0.500000  5  0.031651 -0.031651
# FAP_avg_downstroke    0.000000  0.000000  0.500000  5  0.000000  0.000000
# FAP_peak              0.000000  0.000000  0.500000  5  0.000000  0.000000
# TS2_adp_index         0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS1_num_APs           0.000000  0.015372  0.500000  5  0.031651 -0.031651
# TS1_maxdownstroke    -0.004348  0.009722  0.813050  5  0.015670 -0.024366
# TS1_maxupstroke      -0.008696  0.019444  0.813050  5  0.031340 -0.048731
# TS1_avg_downstroke   -0.008696  0.011907  0.911096  5  0.015821 -0.033212
# TS2_num_APs          -0.008696  0.039491  0.675869  5  0.072617 -0.090008
# FAP_up_down_ratio    -0.013043  0.024786  0.847721  5  0.037992 -0.064079
# TS1_up_down_ratio    -0.030435  0.011907  0.997682  5 -0.005918 -0.054951
# FAP_avg_upstroke     -0.034783  0.011907  0.998581  5 -0.010266 -0.059299
# TS1_avg_upstroke     -0.039130  0.009722  0.999578  5 -0.019113 -0.059148

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
eval_result
# Out:
# {'accuracy': 0.6956521739130435,
#  'balanced_accuracy': 0.5299145299145299,
#  'mcc': 0.4237285928087824,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     7
#  Exc L2-3 LINC00507 FREM3 superficial                 2
#  Exc L2-4 LINC00507 GLP2R                             2
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                         7
#  Exc L2-3 LINC00507 FREM3 superficial                                    24
#  Exc L2-4 LINC00507 GLP2R                                                 2
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             1
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     1  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6363636363636364,
#    'recall': 0.4666666666666667,
#    'f1-score': 0.5384615384615384,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7272727272727273,
#    'recall': 0.9230769230769231,
#    'f1-score': 0.8135593220338984,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5,
#    'recall': 0.2,
#    'f1-score': 0.2857142857142857,
#    'support': 5.0},
#   'accuracy': 0.6956521739130435,
#   'macro avg': {'precision': 0.6212121212121212,
#    'recall': 0.5299145299145299,
#    'f1-score': 0.5459117154032408,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.6729249011857708,
#    'recall': 0.6956521739130435,
#    'f1-score': 0.6664790625733883,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data, extra_metrics=['accuracy', 'balanced_accuracy','f1_macro','f1_micro', 'f1_weighted'],extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
print('best model',predictor.model_best)
# Out:
#                   model  score_test  accuracy  balanced_accuracy  f1_macro  \
# 0      RandomForestEntr    0.717391  0.717391           0.596581  0.622016
# 1      RandomForestGini    0.717391  0.717391           0.596581  0.622016
# 2            LightGBMXT    0.695652  0.695652           0.574359  0.584010
# 3        ExtraTreesEntr    0.695652  0.695652           0.539316  0.554720
# 4        ExtraTreesGini    0.695652  0.695652           0.529915  0.545912
# 5   WeightedEnsemble_L2    0.695652  0.695652           0.529915  0.545912
# 6              CatBoost    0.673913  0.673913           0.507692  0.520271
# 7              LightGBM    0.652174  0.652174           0.548718  0.548148
# 8        NeuralNetTorch    0.652174  0.652174           0.548718  0.573386
# 9       NeuralNetFastAI    0.652174  0.652174           0.548718  0.549084
# 10        LightGBMLarge    0.586957  0.586957           0.465812  0.469562
# 11              XGBoost    0.586957  0.586957           0.456410  0.464286
# 12       KNeighborsUnif    0.347826  0.347826           0.296581  0.293017
# 13       KNeighborsDist    0.347826  0.347826           0.287179  0.283660
#
#     f1_micro  f1_weighted  score_val eval_metric  pred_time_test  \
# 0   0.717391     0.697699   0.854839    accuracy        0.083308
# 1   0.717391     0.697699   0.838710    accuracy        0.091455
# 2   0.695652     0.672597   0.854839    accuracy        0.006490
# 3   0.695652     0.673532   0.854839    accuracy        0.089202
# 4   0.695652     0.666479   0.887097    accuracy        0.123952
# 5   0.695652     0.666479   0.887097    accuracy        0.139580
# 6   0.673913     0.641395   0.854839    accuracy        0.003115
# 7   0.652174     0.640580   0.838710    accuracy        0.000621
# 8   0.652174     0.633635   0.822581    accuracy        0.013872
# 9   0.652174     0.638079   0.822581    accuracy        0.020203
# 10  0.586957     0.579321   0.838710    accuracy        0.000000
# 11  0.586957     0.570652   0.854839    accuracy        0.023147
# 12  0.347826     0.381819   0.612903    accuracy        0.003982
# 13  0.347826     0.379454   0.725806    accuracy        0.008001
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.064964  0.859300                 0.083308                0.064964
# 1        0.057174  0.875706                 0.091455                0.057174
# 2        0.000000  0.520830                 0.006490                0.000000
# 3        0.059064  0.882522                 0.089202                0.059064
# 4        0.064922  0.872710                 0.123952                0.064922
# 5        0.064922  1.021678                 0.015627                0.000000
# 6        0.000000  6.519294                 0.003115                0.000000
# 7        0.000000  0.475719                 0.000621                0.000000
# 8        0.015622  2.238977                 0.013872                0.015622
# 9        0.015625  2.349362                 0.020203                0.015625
# 10       0.000000  1.040842                 0.000000                0.000000
# 11       0.000000  0.560399                 0.023147                0.000000
# 12       0.003980  0.012131                 0.003982                0.003980
# 13       0.005020  0.009998                 0.008001                0.005020
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.859300            1       True          7
# 1            0.875706            1       True          6
# 2            0.520830            1       True          4
# 3            0.882522            1       True         10
# 4            0.872710            1       True          9
# 5            0.148968            2       True         14
# 6            6.519294            1       True          8
# 7            0.475719            1       True          5
# 8            2.238977            1       True         12
# 9            2.349362            1       True          3
# 10           1.040842            1       True         13
# 11           0.560399            1       True         11
# 12           0.012131            1       True          1
# 13           0.009998            1       True          2
# best model WeightedEnsemble_L2

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_10028\723293454.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206                        Exc L2 LAMP5 LTK
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206                        Exc L2 LAMP5 LTK
# 207    Exc L2-3 LINC00507 FREM3 superficial
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.080000                              0.873333
# 1            0.053333                              0.903333
# 2            0.206667                              0.623333
# 3            0.163333                              0.703333
# 4            0.226667                              0.736667
# ..                ...                                   ...
# 204          0.586667                              0.320000
# 205          0.133333                              0.793333
# 206          0.513333                              0.356667
# 207          0.473333                              0.503333
# 208          0.223333                              0.680000
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.046667
# 1                    0.043333
# 2                    0.170000
# 3                    0.133333
# 4                    0.036667
# ..                        ...
# 204                  0.093333
# 205                  0.073333
# 206                  0.130000
# 207                  0.023333
# 208                  0.096667
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()['25%']].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
new_unlabeled_data=unlabeled_data.loc[idx_filted,:]
new_unlabeled_data.shape
# Out:
# (157, 36)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 7. 利用教师模型预测未标注数据集的标签训练学生模型
# #### <font color='Red'>注意未标注数据预测只有4个类别，因此训练的学生模型的类别数也应该为4</font>

# %%
#设置训练精度, 如不设置使用教师模型设置的参数
#presets='medium_quality'
# eval_metric = 'accuracy'
# problem_type='multiclass'
# auto_stack=True
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = student_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")
# 开始训练
student_predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    student_predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    student_predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels)
else:
    student_predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       7.62 GB / 15.92 GB (47.8%)
# Disk Space Avail:   499.95 GB / 931.51 GB (53.7%)
# ===================================================
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "models\Student\medium_quality-20240925-204300"
# Train Data Rows:    234
# Train Data Columns: 35
# Label Column:       label
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	6 unique label values:  ['Exc L3-5 RORB COL22A1', 'Exc L2-3 LINC00507 FREM3 superficial', 'Exc L3-4 RORB CARM1P1', 'Exc L2 LAMP5 LTK', 'Exc L2-3 LINC00507 FREM3 deep', 'Exc L2-4 LINC00507 GLP2R']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 6
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7784.75 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 35 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.1s = Fit runtime
# 	35 features in original data used to generate 35 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.06 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.42s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 187, Val Rows: 47
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3599.58s of the 3599.58s of remaining time.
# 	0.617	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3599.55s of the 3599.55s of remaining time.
# 	0.5745	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3599.52s of the 3599.52s of remaining time.
# No improvement since epoch 4: early stopping
# 	0.6383	 = Validation score   (accuracy)
# 	1.61s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3597.86s of the 3597.86s of remaining time.
# 	0.6596	 = Validation score   (accuracy)
# 	0.77s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3597.04s of the 3597.04s of remaining time.
# 	0.617	 = Validation score   (accuracy)
# 	0.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 3596.45s of the 3596.45s of remaining time.
# 	0.5745	 = Validation score   (accuracy)
# 	0.99s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3595.29s of the 3595.29s of remaining time.
# 	0.5957	 = Validation score   (accuracy)
# 	0.93s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3594.27s of the 3594.27s of remaining time.
# 	0.6809	 = Validation score   (accuracy)
# 	4.95s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 3589.3s of the 3589.3s of remaining time.
# 	0.5106	 = Validation score   (accuracy)
# 	0.95s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3588.26s of the 3588.26s of remaining time.
# 	0.5319	 = Validation score   (accuracy)
# 	1.03s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3587.1s of the 3587.1s of remaining time.
# 	0.5957	 = Validation score   (accuracy)
# 	0.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3586.21s of the 3586.21s of remaining time.
# 	0.617	 = Validation score   (accuracy)
# 	1.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 3585.16s of the 3585.16s of remaining time.
# 	0.6383	 = Validation score   (accuracy)
# 	1.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3583.84s of remaining time.
# 	Ensemble Weights: {'CatBoost': 0.923, 'RandomForestGini': 0.077}
# 	0.7021	 = Validation score   (accuracy)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 16.34s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 372.1 rows/s (47 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Student\medium_quality-20240925-204300")

# %% [markdown]
# ## 7. 利用初步训练的学生模型预测测试集
# <font color=Red>这里预测test_data，注意这里有两个分类是0，因为训练的学生模型不包括这两个分类</font>

# %%
from sklearn.metrics import classification_report
y_pred = student_predictor.predict(test_data_nolabel)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.50      0.47      0.49        19
#        Exc L2-3 LINC00507 FREM3 deep       0.00      0.00      0.00         7
# Exc L2-3 LINC00507 FREM3 superficial       0.57      0.85      0.68        33
#             Exc L2-4 LINC00507 GLP2R       0.00      0.00      0.00         6
#                Exc L3-4 RORB CARM1P1       0.50      0.20      0.29         5
#                Exc L3-5 RORB COL22A1       0.89      0.89      0.89         9
#
#                             accuracy                           0.58        79
#                            macro avg       0.41      0.40      0.39        79
#                         weighted avg       0.49      0.58      0.52        79
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                predicted                                actual
# 0   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 1   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 2   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 3   Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 4   Exc L2-3 LINC00507 FREM3 superficial         Exc L2-3 LINC00507 FREM3 deep
# ..                                   ...                                   ...
# 74  Exc L2-3 LINC00507 FREM3 superficial                      Exc L2 LAMP5 LTK
# 75  Exc L2-3 LINC00507 FREM3 superficial  Exc L2-3 LINC00507 FREM3 superficial
# 76  Exc L2-3 LINC00507 FREM3 superficial              Exc L2-4 LINC00507 GLP2R
# 77                      Exc L2 LAMP5 LTK         Exc L2-3 LINC00507 FREM3 deep
# 78  Exc L2-3 LINC00507 FREM3 superficial         Exc L2-3 LINC00507 FREM3 deep
#
# [79 rows x 2 columns]

# %% [markdown]
# ### 7.1 以概率方式显示预测结果
# **可通过概率筛选预测结果中概率高的前n个结果**

# %% [markdown]
# <font color=Red>这里预测test_data的概率</font>

# %%
y_pred_proba = student_predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 deep  \
# 0           0.085208                       0.122235
# 1           0.263774                       0.130358
# 2           0.019805                       0.050328
# 3           0.053725                       0.007914
# 4           0.053880                       0.021745
# ..               ...                            ...
# 58          0.094137                       0.016386
# 59          0.024284                       0.110385
# 60          0.059416                       0.017206
# 61          0.554363                       0.038029
# 62          0.621737                       0.012512
#
#     Exc L2-3 LINC00507 FREM3 superficial  Exc L2-4 LINC00507 GLP2R  \
# 0                               0.155684                  0.034862
# 1                               0.047818                  0.020813
# 2                               0.888572                  0.010356
# 3                               0.862100                  0.063933
# 4                               0.902711                  0.007958
# ..                                   ...                       ...
# 58                              0.735302                  0.023774
# 59                              0.826858                  0.009573
# 60                              0.874558                  0.025071
# 61                              0.347982                  0.014513
# 62                              0.103756                  0.240558
#
#     Exc L3-4 RORB CARM1P1  Exc L3-5 RORB COL22A1
# 0                0.061910               0.540101
# 1                0.087964               0.449273
# 2                0.019288               0.011651
# 3                0.004339               0.007988
# 4                0.005177               0.008528
# ..                    ...                    ...
# 58               0.008107               0.122294
# 59               0.015546               0.013353
# 60               0.011245               0.012505
# 61               0.011049               0.034064
# 62               0.007402               0.014035
#
# [63 rows x 6 columns]

# %% [markdown]
# ### 7.2 初步训练的学生模型评估预测效果
# #### 下面的出现的错误是由于有些类别未出现在预测结果中，因为模型中有两个分类不存来，因此无法预测，所以计算错误，具体解释可见https://blog.csdn.net/qq_43391414/article/details/120543028

# %% [markdown]
# <font color=Red>这里评估test_data数据集</font>

# %%
eval_result = student_predictor.evaluate(test_data, display=True, detailed_report=True)
# Out:
# Evaluation: accuracy on test data: 0.5822784810126582
# Evaluations on test data:
# {
#     "accuracy": 0.5822784810126582,
#     "balanced_accuracy": 0.4018429913166756,
#     "mcc": 0.3970139047474395
# }
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.5,
#         "recall": 0.47368421052631576,
#         "f1-score": 0.4864864864864865,
#         "support": 19.0
#     },
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 7.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8484848484848485,
#         "f1-score": 0.6829268292682927,
#         "support": 33.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 6.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 0.5,
#         "recall": 0.2,
#         "f1-score": 0.2857142857142857,
#         "support": 5.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 0.8888888888888888,
#         "f1-score": 0.8888888888888888,
#         "support": 9.0
#     },
#     "accuracy": 0.5822784810126582,
#     "macro avg": {
#         "precision": 0.41005291005291006,
#         "recall": 0.4018429913166755,
#         "f1-score": 0.39066941505965896,
#         "support": 79.0
#     },
#     "weighted avg": {
#         "precision": 0.49186256781193494,
#         "recall": 0.5822784810126582,
#         "f1-score": 0.5216253169325106,
#         "support": 79.0
#     }
# }

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.546341
# [100]	valid_set's soft_log_loss: -0.433893
# [150]	valid_set's soft_log_loss: -0.414063
# [200]	valid_set's soft_log_loss: -0.414742
# [250]	valid_set's soft_log_loss: -0.414822
# [300]	valid_set's soft_log_loss: -0.422732
# [350]	valid_set's soft_log_loss: -0.427731
# [400]	valid_set's soft_log_loss: -0.439167
# [450]	valid_set's soft_log_loss: -0.441864
# 	Note: model has different eval_metric than default.
# 	-0.4111	 = Validation score   (-soft_log_loss)
# 	1.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4435	 = Validation score   (-soft_log_loss)
# 	0.8s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0763795	test: -1.0839255	best: -1.0839255 (0)	total: 511ms	remaining: 1h 25m 10s
# 20:	learn: -0.8142677	test: -0.8610724	best: -0.8610724 (20)	total: 825ms	remaining: 6m 31s
# 40:	learn: -0.6979860	test: -0.7398026	best: -0.7398026 (40)	total: 1.14s	remaining: 4m 36s
# 60:	learn: -0.6358313	test: -0.6673544	best: -0.6673544 (60)	total: 1.44s	remaining: 3m 53s
# 80:	learn: -0.5941579	test: -0.6200900	best: -0.6200900 (80)	total: 1.73s	remaining: 3m 31s
# 100:	learn: -0.5619205	test: -0.5818516	best: -0.5818516 (100)	total: 2.03s	remaining: 3m 18s
# 120:	learn: -0.5378891	test: -0.5531604	best: -0.5531604 (120)	total: 2.35s	remaining: 3m 11s
# 140:	learn: -0.5183783	test: -0.5263240	best: -0.5263240 (140)	total: 2.66s	remaining: 3m 5s
# 160:	learn: -0.4991825	test: -0.5023497	best: -0.5023497 (160)	total: 2.97s	remaining: 3m 1s
# 180:	learn: -0.4844532	test: -0.4850919	best: -0.4850919 (180)	total: 3.29s	remaining: 2m 58s
# 200:	learn: -0.4709550	test: -0.4689333	best: -0.4688160 (199)	total: 3.59s	remaining: 2m 55s
# 220:	learn: -0.4605141	test: -0.4558791	best: -0.4558791 (220)	total: 3.92s	remaining: 2m 53s
# 240:	learn: -0.4519650	test: -0.4459354	best: -0.4459354 (240)	total: 4.22s	remaining: 2m 50s
# 260:	learn: -0.4429414	test: -0.4354404	best: -0.4354404 (260)	total: 4.53s	remaining: 2m 49s
# 280:	learn: -0.4364160	test: -0.4257819	best: -0.4257819 (280)	total: 4.85s	remaining: 2m 47s
# 300:	learn: -0.4302097	test: -0.4184532	best: -0.4184532 (300)	total: 5.15s	remaining: 2m 46s
# 320:	learn: -0.4243997	test: -0.4133521	best: -0.4133521 (320)	total: 5.46s	remaining: 2m 44s
# 340:	learn: -0.4196893	test: -0.4064865	best: -0.4062266 (339)	total: 5.79s	remaining: 2m 44s
# 360:	learn: -0.4143291	test: -0.3993790	best: -0.3993790 (360)	total: 6.12s	remaining: 2m 43s
# 380:	learn: -0.4099245	test: -0.3971235	best: -0.3967671 (374)	total: 6.42s	remaining: 2m 42s
# 400:	learn: -0.4064196	test: -0.3923610	best: -0.3923610 (400)	total: 6.73s	remaining: 2m 41s
# 420:	learn: -0.4030866	test: -0.3897067	best: -0.3891156 (419)	total: 7.04s	remaining: 2m 40s
# 440:	learn: -0.3998154	test: -0.3870160	best: -0.3870160 (440)	total: 7.36s	remaining: 2m 39s
# 460:	learn: -0.3966685	test: -0.3844457	best: -0.3839817 (459)	total: 7.65s	remaining: 2m 38s
# 480:	learn: -0.3939186	test: -0.3817122	best: -0.3817122 (480)	total: 7.95s	remaining: 2m 37s
# 500:	learn: -0.3910771	test: -0.3800142	best: -0.3800125 (499)	total: 8.27s	remaining: 2m 36s
# 520:	learn: -0.3887538	test: -0.3784745	best: -0.3780077 (515)	total: 8.59s	remaining: 2m 36s
# 540:	learn: -0.3864528	test: -0.3754684	best: -0.3754464 (539)	total: 8.9s	remaining: 2m 35s
# 560:	learn: -0.3844031	test: -0.3733676	best: -0.3731874 (559)	total: 9.21s	remaining: 2m 34s
# 580:	learn: -0.3826419	test: -0.3708732	best: -0.3708732 (580)	total: 9.54s	remaining: 2m 34s
# 600:	learn: -0.3808858	test: -0.3698598	best: -0.3696976 (590)	total: 9.84s	remaining: 2m 33s
# 620:	learn: -0.3791402	test: -0.3686805	best: -0.3681507 (618)	total: 10.1s	remaining: 2m 33s
# 640:	learn: -0.3776056	test: -0.3678507	best: -0.3677670 (636)	total: 10.5s	remaining: 2m 32s
# 660:	learn: -0.3763087	test: -0.3661981	best: -0.3660739 (656)	total: 10.8s	remaining: 2m 32s
# 680:	learn: -0.3751408	test: -0.3646800	best: -0.3646800 (680)	total: 11.1s	remaining: 2m 31s
# 700:	learn: -0.3738171	test: -0.3631230	best: -0.3629790 (698)	total: 11.4s	remaining: 2m 31s
# 720:	learn: -0.3728016	test: -0.3605423	best: -0.3605423 (720)	total: 11.7s	remaining: 2m 30s
# 740:	learn: -0.3718928	test: -0.3599982	best: -0.3599323 (739)	total: 12s	remaining: 2m 29s
# 760:	learn: -0.3707919	test: -0.3590770	best: -0.3587146 (752)	total: 12.3s	remaining: 2m 29s
# 780:	learn: -0.3697798	test: -0.3588785	best: -0.3583518 (778)	total: 12.6s	remaining: 2m 28s
# 800:	learn: -0.3688421	test: -0.3590608	best: -0.3583518 (778)	total: 12.9s	remaining: 2m 28s
# 820:	learn: -0.3679677	test: -0.3594447	best: -0.3583518 (778)	total: 13.2s	remaining: 2m 27s
# 840:	learn: -0.3670269	test: -0.3580334	best: -0.3580334 (840)	total: 13.5s	remaining: 2m 27s
# 860:	learn: -0.3660828	test: -0.3584352	best: -0.3578523 (843)	total: 13.8s	remaining: 2m 26s
# 880:	learn: -0.3653532	test: -0.3571542	best: -0.3571542 (880)	total: 14.1s	remaining: 2m 26s
# 900:	learn: -0.3645747	test: -0.3565773	best: -0.3564135 (899)	total: 14.4s	remaining: 2m 25s
# 920:	learn: -0.3639463	test: -0.3556742	best: -0.3556742 (920)	total: 14.8s	remaining: 2m 25s
# 940:	learn: -0.3632009	test: -0.3551550	best: -0.3551550 (940)	total: 15.1s	remaining: 2m 25s
# 960:	learn: -0.3625469	test: -0.3553761	best: -0.3551550 (940)	total: 15.4s	remaining: 2m 25s
# 980:	learn: -0.3619796	test: -0.3551582	best: -0.3545815 (973)	total: 15.7s	remaining: 2m 24s
# 1000:	learn: -0.3613137	test: -0.3551130	best: -0.3545815 (973)	total: 16s	remaining: 2m 23s
# 1020:	learn: -0.3607634	test: -0.3548715	best: -0.3545815 (973)	total: 16.3s	remaining: 2m 23s
# 1040:	learn: -0.3602223	test: -0.3543230	best: -0.3542132 (1037)	total: 16.6s	remaining: 2m 22s
# 1060:	learn: -0.3597558	test: -0.3551140	best: -0.3541707 (1041)	total: 16.9s	remaining: 2m 22s
# 1080:	learn: -0.3591827	test: -0.3553037	best: -0.3541707 (1041)	total: 17.2s	remaining: 2m 22s
# 1100:	learn: -0.3586926	test: -0.3559737	best: -0.3541707 (1041)	total: 17.6s	remaining: 2m 21s
# 1120:	learn: -0.3582524	test: -0.3562841	best: -0.3541707 (1041)	total: 17.9s	remaining: 2m 21s
# 1140:	learn: -0.3577719	test: -0.3568476	best: -0.3541707 (1041)	total: 18.2s	remaining: 2m 21s
# 1160:	learn: -0.3572743	test: -0.3561462	best: -0.3541707 (1041)	total: 18.5s	remaining: 2m 20s
# 1180:	learn: -0.3568757	test: -0.3556375	best: -0.3541707 (1041)	total: 18.8s	remaining: 2m 20s
# 1200:	learn: -0.3564668	test: -0.3551662	best: -0.3541707 (1041)	total: 19.1s	remaining: 2m 20s
# 1220:	learn: -0.3560905	test: -0.3559128	best: -0.3541707 (1041)	total: 19.4s	remaining: 2m 19s
# 1240:	learn: -0.3557539	test: -0.3562110	best: -0.3541707 (1041)	total: 19.8s	remaining: 2m 19s
# 1260:	learn: -0.3554356	test: -0.3571096	best: -0.3541707 (1041)	total: 20.1s	remaining: 2m 19s
# 1280:	learn: -0.3551248	test: -0.3568630	best: -0.3541707 (1041)	total: 20.4s	remaining: 2m 18s
# 1300:	learn: -0.3548257	test: -0.3568042	best: -0.3541707 (1041)	total: 20.7s	remaining: 2m 18s
# 1320:	learn: -0.3545352	test: -0.3568816	best: -0.3541707 (1041)	total: 21s	remaining: 2m 18s
# 1340:	learn: -0.3541937	test: -0.3569398	best: -0.3541707 (1041)	total: 21.3s	remaining: 2m 17s
# 1360:	learn: -0.3538893	test: -0.3578688	best: -0.3541707 (1041)	total: 21.7s	remaining: 2m 17s
# 	Note: model has different eval_metric than default.
# 	-0.3542	 = Validation score   (-soft_log_loss)
# 	23.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# bestTest = -0.3541707082
# bestIteration = 1041
#
# Shrink model to first 1042 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.6325	 = Validation score   (-soft_log_loss)
# 	3.66s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.923, 'LightGBM_2_DSTL': 0.077}
# 	Note: model has different eval_metric than default.
# 	-0.3534	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   0.854839  soft_log_loss       0.008680  23.760714                0.008680          23.760714            1       True         22
# 1  WeightedEnsemble_2_L2_DSTL   0.854839  soft_log_loss       0.009679  24.794225                0.001000           0.028449            2       True         24
# 2             LightGBM_2_DSTL   0.838710  soft_log_loss       0.000000   1.005063                0.000000           1.005063            1       True         20
# 3      RandomForestMSE_2_DSTL   0.838710  soft_log_loss       0.066152   0.797948                0.066152           0.797948            1       True         21
# 4       NeuralNetTorch_2_DSTL   0.806452  soft_log_loss       0.015625   3.663259                0.015625           3.663259            1       True         23
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                          model  score_test  score_val    eval_metric  \
# 6          WeightedEnsemble_L2    0.695652   0.887097       accuracy
# 7               ExtraTreesGini    0.695652   0.887097       accuracy
# 10               CatBoost_DSTL    0.673913   0.870968  soft_log_loss
# 12    WeightedEnsemble_L2_DSTL    0.673913   0.870968  soft_log_loss
# 0             RandomForestEntr    0.717391   0.854839       accuracy
# 2              CatBoost_2_DSTL    0.695652   0.854839  soft_log_loss
# 3                   LightGBMXT    0.695652   0.854839       accuracy
# 5   WeightedEnsemble_2_L2_DSTL    0.695652   0.854839  soft_log_loss
# 8               ExtraTreesEntr    0.695652   0.854839       accuracy
# 9                     CatBoost    0.673913   0.854839       accuracy
# 21                     XGBoost    0.586957   0.854839       accuracy
# 1             RandomForestGini    0.717391   0.838710       accuracy
# 4                LightGBM_DSTL    0.695652   0.838710  soft_log_loss
# 11      RandomForestMSE_2_DSTL    0.673913   0.838710  soft_log_loss
# 13                    LightGBM    0.652174   0.838710       accuracy
# 18             LightGBM_2_DSTL    0.630435   0.838710  soft_log_loss
# 20               LightGBMLarge    0.586957   0.838710       accuracy
# 14             NeuralNetFastAI    0.652174   0.822581       accuracy
# 15              NeuralNetTorch    0.652174   0.822581       accuracy
# 17       NeuralNetTorch_2_DSTL    0.630435   0.806452  soft_log_loss
# 16        RandomForestMSE_DSTL    0.652174   0.790323  soft_log_loss
# 19         NeuralNetTorch_DSTL    0.608696   0.774194  soft_log_loss
# 23              KNeighborsDist    0.347826   0.725806       accuracy
# 22              KNeighborsUnif    0.347826   0.612903       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 6         0.064908       0.063061   1.020767                 0.000000
# 7         0.064908       0.063061   0.895064                 0.064908
# 10        0.011683       0.000000  28.098028                 0.011683
# 12        0.135444       0.066541  28.877918                 0.000000
# 0         0.073928       0.066464   0.850498                 0.073928
# 2         0.011863       0.008680  23.760714                 0.011863
# 3         0.018188       0.000000   0.467296                 0.018188
# 5         0.041028       0.009679  24.794225                 0.000000
# 8         0.074059       0.058406   0.904502                 0.074059
# 9         0.008701       0.000000   6.139141                 0.008701
# 21        0.021747       0.000000   0.521024                 0.021747
# 1         0.117192       0.068510   0.846716                 0.117192
# 4         0.020759       0.000000   0.892958                 0.020759
# 11        0.121768       0.066152   0.797948                 0.121768
# 13        0.004995       0.000000   0.434038                 0.004995
# 18        0.029165       0.000000   1.005063                 0.029165
# 20        0.000000       0.000000   0.979578                 0.000000
# 14        0.011181       0.018439   2.366042                 0.011181
# 15        0.016395       0.015625   2.290926                 0.016395
# 17        0.019850       0.015625   3.663259                 0.019850
# 16        0.123761       0.065358   0.749856                 0.123761
# 19        0.015016       0.017957   3.690589                 0.015016
# 23        0.009182       0.001343   0.008012                 0.009182
# 22        0.004998       0.013062   0.000000                 0.004998
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 6                 0.000000           0.125703            2       True
# 7                 0.063061           0.895064            1       True
# 10                0.000000          28.098028            1       True
# 12                0.001183           0.030034            2       True
# 0                 0.066464           0.850498            1       True
# 2                 0.008680          23.760714            1       True
# 3                 0.000000           0.467296            1       True
# 5                 0.001000           0.028449            2       True
# 8                 0.058406           0.904502            1       True
# 9                 0.000000           6.139141            1       True
# 21                0.000000           0.521024            1       True
# 1                 0.068510           0.846716            1       True
# 4                 0.000000           0.892958            1       True
# 11                0.066152           0.797948            1       True
# 13                0.000000           0.434038            1       True
# 18                0.000000           1.005063            1       True
# 20                0.000000           0.979578            1       True
# 14                0.018439           2.366042            1       True
# 15                0.015625           2.290926            1       True
# 17                0.015625           3.663259            1       True
# 16                0.065358           0.749856            1       True
# 19                0.017957           3.690589            1       True
# 23                0.001343           0.008012            1       True
# 22                0.013062           0.000000            1       True
#
#     fit_order
# 6          14
# 7           9
# 10         17
# 12         19
# 0           7
# 2          22
# 3           4
# 5          24
# 8          10
# 9           8
# 21         11
# 1           6
# 4          15
# 11         21
# 13          5
# 18         20
# 20         13
# 14          3
# 15         12
# 17         23
# 16         16
# 19         18
# 23          2
# 22          1
# 测试集上的最佳蒸馏模型：
# CatBoost_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.6031746031746031
# Evaluations on test data:
# {
#     "accuracy": 0.6031746031746031,
#     "balanced_accuracy": 0.5348290598290598,
#     "mcc": 0.4560919418629847
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.5833333333333334,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5185185185185185,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 0.42857142857142855,
#         "recall": 0.6,
#         "f1-score": 0.5,
#         "support": 5.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.6,
#         "recall": 0.6923076923076923,
#         "f1-score": 0.6428571428571429,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.25,
#         "recall": 0.2,
#         "f1-score": 0.2222222222222222,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 1.0,
#         "recall": 0.25,
#         "f1-score": 0.4,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.6031746031746031,
#     "macro avg": {
#         "precision": 0.6251322751322751,
#         "recall": 0.5348290598290598,
#         "f1-score": 0.5374623923643531,
#         "support": 63.0
#     },
#     "weighted avg": {
#         "precision": 0.6167296548248928,
#         "recall": 0.6031746031746031,
#         "f1-score": 0.5909934344108013,
#         "support": 63.0
#     }
# }
# {'accuracy': 0.6031746031746031, 'balanced_accuracy': 0.5348290598290598, 'mcc': 0.4560919418629847, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 deep                        0
# Exc L2-3 LINC00507 FREM3 superficial                 4
# Exc L2-4 LINC00507 GLP2R                             1
# Exc L3-4 RORB CARM1P1                                0
# Exc L3-5 RORB COL22A1                                0
#
#                                       Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2 LAMP5 LTK                                                  0
# Exc L2-3 LINC00507 FREM3 deep                                     3
# Exc L2-3 LINC00507 FREM3 superficial                              2
# Exc L2-4 LINC00507 GLP2R                                          0
# Exc L3-4 RORB CARM1P1                                             2
# Exc L3-5 RORB COL22A1                                             0
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         7
# Exc L2-3 LINC00507 FREM3 deep                                            1
# Exc L2-3 LINC00507 FREM3 superficial                                    18
# Exc L2-4 LINC00507 GLP2R                                                 3
# Exc L3-4 RORB CARM1P1                                                    1
# Exc L3-5 RORB COL22A1                                                    0
#
#                                       Exc L2-4 LINC00507 GLP2R  \
# Exc L2 LAMP5 LTK                                             0
# Exc L2-3 LINC00507 FREM3 deep                                1
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     1
# Exc L3-4 RORB CARM1P1                                        0
# Exc L3-5 RORB COL22A1                                        0
#
#                                       Exc L3-4 RORB CARM1P1  \
# Exc L2 LAMP5 LTK                                          0
# Exc L2-3 LINC00507 FREM3 deep                             0
# Exc L2-3 LINC00507 FREM3 superficial                      0
# Exc L2-4 LINC00507 GLP2R                                  0
# Exc L3-4 RORB CARM1P1                                     1
# Exc L3-5 RORB COL22A1                                     0
#
#                                       Exc L3-5 RORB COL22A1
# Exc L2 LAMP5 LTK                                          1
# Exc L2-3 LINC00507 FREM3 deep                             0
# Exc L2-3 LINC00507 FREM3 superficial                      0
# Exc L2-4 LINC00507 GLP2R                                  0
# Exc L3-4 RORB CARM1P1                                     0
# Exc L3-5 RORB COL22A1                                     8  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.5833333333333334, 'recall': 0.4666666666666667, 'f1-score': 0.5185185185185185, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 deep': {'precision': 0.42857142857142855, 'recall': 0.6, 'f1-score': 0.5, 'support': 5.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.6, 'recall': 0.6923076923076923, 'f1-score': 0.6428571428571429, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.25, 'recall': 0.2, 'f1-score': 0.2222222222222222, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 1.0, 'recall': 0.25, 'f1-score': 0.4, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.6031746031746031, 'macro avg': {'precision': 0.6251322751322751, 'recall': 0.5348290598290598, 'f1-score': 0.5374623923643531, 'support': 63.0}, 'weighted avg': {'precision': 0.6167296548248928, 'recall': 0.6031746031746031, 'f1-score': 0.5909934344108013, 'support': 63.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.58      0.47      0.52        15
#        Exc L2-3 LINC00507 FREM3 deep       0.43      0.60      0.50         5
# Exc L2-3 LINC00507 FREM3 superficial       0.60      0.69      0.64        26
#             Exc L2-4 LINC00507 GLP2R       0.25      0.20      0.22         5
#                Exc L3-4 RORB CARM1P1       1.00      0.25      0.40         4
#                Exc L3-5 RORB COL22A1       0.89      1.00      0.94         8
#
#                             accuracy                           0.60        63
#                            macro avg       0.63      0.53      0.54        63
#                         weighted avg       0.62      0.60      0.59        63

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best(best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='NeuralNetTorch_3_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_4_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_4_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_4_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_4_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_4_DSTL', 'RandomForestMSE_4_DSTL', 'CatBoost_4_DSTL', 'NeuralNetTorch_4_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_4_DSTL ...
# [50]	valid_set's soft_log_loss: -0.517322
# [100]	valid_set's soft_log_loss: -0.320373
# [150]	valid_set's soft_log_loss: -0.294037
# [200]	valid_set's soft_log_loss: -0.314013
# [250]	valid_set's soft_log_loss: -0.323629
# [300]	valid_set's soft_log_loss: -0.347582
# [350]	valid_set's soft_log_loss: -0.359778
# [400]	valid_set's soft_log_loss: -0.369269
# [450]	valid_set's soft_log_loss: -0.381391
# 	Note: model has different eval_metric than default.
# 	-0.2902	 = Validation score   (-soft_log_loss)
# 	1.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_4_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.3478	 = Validation score   (-soft_log_loss)
# 	0.84s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_4_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.7332571	test: -1.7331742	best: -1.7331742 (0)	total: 550ms	remaining: 1h 31m 41s
# 20:	learn: -1.0854626	test: -1.1419791	best: -1.1419791 (20)	total: 1.12s	remaining: 8m 51s
# 40:	learn: -0.8091493	test: -0.9096470	best: -0.9096470 (40)	total: 1.72s	remaining: 6m 57s
# 60:	learn: -0.6557653	test: -0.7751977	best: -0.7751977 (60)	total: 2.31s	remaining: 6m 16s
# 80:	learn: -0.5533062	test: -0.6852166	best: -0.6852166 (80)	total: 2.95s	remaining: 6m 1s
# 100:	learn: -0.4794640	test: -0.6204029	best: -0.6204029 (100)	total: 3.54s	remaining: 5m 47s
# 120:	learn: -0.4262186	test: -0.5771247	best: -0.5771247 (120)	total: 4.2s	remaining: 5m 42s
# 140:	learn: -0.3847624	test: -0.5407073	best: -0.5407073 (140)	total: 4.8s	remaining: 5m 35s
# 160:	learn: -0.3502903	test: -0.5104381	best: -0.5104381 (160)	total: 5.39s	remaining: 5m 29s
# 180:	learn: -0.3236271	test: -0.4863296	best: -0.4863296 (180)	total: 5.99s	remaining: 5m 25s
# 200:	learn: -0.3017044	test: -0.4696425	best: -0.4696425 (200)	total: 6.62s	remaining: 5m 22s
# 220:	learn: -0.2828997	test: -0.4538486	best: -0.4538486 (220)	total: 7.2s	remaining: 5m 18s
# 240:	learn: -0.2661713	test: -0.4387259	best: -0.4387259 (240)	total: 7.78s	remaining: 5m 15s
# 260:	learn: -0.2529241	test: -0.4267454	best: -0.4267454 (260)	total: 8.36s	remaining: 5m 11s
# 280:	learn: -0.2411251	test: -0.4164721	best: -0.4164721 (280)	total: 8.94s	remaining: 5m 9s
# 300:	learn: -0.2292898	test: -0.4078691	best: -0.4078691 (300)	total: 9.53s	remaining: 5m 7s
# 320:	learn: -0.2205599	test: -0.3991544	best: -0.3991544 (320)	total: 10.1s	remaining: 5m 4s
# 340:	learn: -0.2129234	test: -0.3917133	best: -0.3916335 (338)	total: 10.7s	remaining: 5m 3s
# 360:	learn: -0.2055852	test: -0.3881172	best: -0.3874601 (358)	total: 11.3s	remaining: 5m 1s
# 380:	learn: -0.1987535	test: -0.3799429	best: -0.3799429 (380)	total: 11.9s	remaining: 5m 1s
# 400:	learn: -0.1925431	test: -0.3728875	best: -0.3728875 (400)	total: 12.6s	remaining: 5m
# 420:	learn: -0.1860889	test: -0.3680711	best: -0.3680711 (420)	total: 13.2s	remaining: 5m 1s
# 440:	learn: -0.1811703	test: -0.3620321	best: -0.3620321 (440)	total: 13.8s	remaining: 4m 59s
# 460:	learn: -0.1769191	test: -0.3571822	best: -0.3571822 (460)	total: 14.4s	remaining: 4m 57s
# 480:	learn: -0.1719119	test: -0.3523495	best: -0.3523495 (480)	total: 15s	remaining: 4m 57s
# 500:	learn: -0.1675537	test: -0.3483137	best: -0.3483137 (500)	total: 15.6s	remaining: 4m 55s
# 520:	learn: -0.1635202	test: -0.3447219	best: -0.3446850 (519)	total: 16.2s	remaining: 4m 54s
# 540:	learn: -0.1597498	test: -0.3402688	best: -0.3402688 (540)	total: 16.7s	remaining: 4m 52s
# 560:	learn: -0.1564580	test: -0.3379016	best: -0.3379016 (560)	total: 17.4s	remaining: 4m 52s
# 580:	learn: -0.1535966	test: -0.3345349	best: -0.3345349 (580)	total: 17.9s	remaining: 4m 50s
# 600:	learn: -0.1509707	test: -0.3327334	best: -0.3327334 (600)	total: 18.5s	remaining: 4m 49s
# 620:	learn: -0.1483784	test: -0.3314939	best: -0.3314939 (620)	total: 19.1s	remaining: 4m 48s
# 640:	learn: -0.1460366	test: -0.3289580	best: -0.3289580 (640)	total: 19.7s	remaining: 4m 47s
# 660:	learn: -0.1437671	test: -0.3260308	best: -0.3259129 (659)	total: 20.3s	remaining: 4m 46s
# 680:	learn: -0.1416911	test: -0.3242851	best: -0.3239836 (678)	total: 20.9s	remaining: 4m 45s
# 700:	learn: -0.1398992	test: -0.3224965	best: -0.3224906 (699)	total: 21.5s	remaining: 4m 45s
# 720:	learn: -0.1378909	test: -0.3205864	best: -0.3205864 (720)	total: 22.1s	remaining: 4m 44s
# 740:	learn: -0.1361203	test: -0.3196314	best: -0.3192235 (735)	total: 22.7s	remaining: 4m 43s
# 760:	learn: -0.1343050	test: -0.3185914	best: -0.3184491 (751)	total: 23.3s	remaining: 4m 42s
# 780:	learn: -0.1325817	test: -0.3180199	best: -0.3180199 (780)	total: 23.9s	remaining: 4m 42s
# 800:	learn: -0.1311196	test: -0.3167792	best: -0.3165915 (798)	total: 24.5s	remaining: 4m 41s
# 820:	learn: -0.1298303	test: -0.3163736	best: -0.3162471 (817)	total: 25.1s	remaining: 4m 40s
# 840:	learn: -0.1286033	test: -0.3150974	best: -0.3150974 (840)	total: 25.7s	remaining: 4m 40s
# 860:	learn: -0.1272379	test: -0.3143524	best: -0.3143524 (860)	total: 26.3s	remaining: 4m 39s
# 880:	learn: -0.1260230	test: -0.3130779	best: -0.3128172 (877)	total: 26.9s	remaining: 4m 38s
# 900:	learn: -0.1250152	test: -0.3122526	best: -0.3122116 (899)	total: 27.5s	remaining: 4m 37s
# 920:	learn: -0.1240623	test: -0.3121210	best: -0.3120448 (918)	total: 28.1s	remaining: 4m 37s
# 940:	learn: -0.1228795	test: -0.3115189	best: -0.3113695 (939)	total: 28.7s	remaining: 4m 36s
# 960:	learn: -0.1219212	test: -0.3112003	best: -0.3112003 (960)	total: 29.3s	remaining: 4m 35s
# 980:	learn: -0.1209515	test: -0.3110411	best: -0.3102942 (968)	total: 29.9s	remaining: 4m 34s
# 1000:	learn: -0.1199515	test: -0.3105776	best: -0.3102942 (968)	total: 30.4s	remaining: 4m 33s
# 1020:	learn: -0.1191009	test: -0.3104573	best: -0.3102942 (968)	total: 31s	remaining: 4m 32s
# 1040:	learn: -0.1183037	test: -0.3108830	best: -0.3101768 (1022)	total: 31.6s	remaining: 4m 31s
# 1060:	learn: -0.1174940	test: -0.3105972	best: -0.3101768 (1022)	total: 32.2s	remaining: 4m 31s
# 1080:	learn: -0.1167786	test: -0.3106272	best: -0.3101768 (1022)	total: 32.8s	remaining: 4m 30s
# 1100:	learn: -0.1161532	test: -0.3106107	best: -0.3101768 (1022)	total: 33.4s	remaining: 4m 29s
# 1120:	learn: -0.1154269	test: -0.3103015	best: -0.3100026 (1115)	total: 33.9s	remaining: 4m 28s
# 1140:	learn: -0.1148860	test: -0.3102382	best: -0.3100026 (1115)	total: 34.5s	remaining: 4m 27s
# 1160:	learn: -0.1142327	test: -0.3099732	best: -0.3099051 (1158)	total: 35.1s	remaining: 4m 27s
# 1180:	learn: -0.1136649	test: -0.3093572	best: -0.3093572 (1180)	total: 35.7s	remaining: 4m 26s
# 1200:	learn: -0.1130589	test: -0.3098435	best: -0.3093572 (1180)	total: 36.3s	remaining: 4m 25s
# 1220:	learn: -0.1125038	test: -0.3098240	best: -0.3093572 (1180)	total: 36.9s	remaining: 4m 25s
# 1240:	learn: -0.1119468	test: -0.3102558	best: -0.3093572 (1180)	total: 37.4s	remaining: 4m 23s
# 1260:	learn: -0.1114169	test: -0.3103256	best: -0.3093572 (1180)	total: 38s	remaining: 4m 23s
# 1280:	learn: -0.1109015	test: -0.3098124	best: -0.3093572 (1180)	total: 38.6s	remaining: 4m 22s
# 1300:	learn: -0.1104658	test: -0.3100146	best: -0.3093572 (1180)	total: 39.2s	remaining: 4m 21s
# 1320:	learn: -0.1100337	test: -0.3096734	best: -0.3093572 (1180)	total: 39.7s	remaining: 4m 21s
# 1340:	learn: -0.1095878	test: -0.3093194	best: -0.3092756 (1337)	total: 40.3s	remaining: 4m 20s
# 1360:	learn: -0.1091024	test: -0.3086048	best: -0.3085276 (1358)	total: 40.9s	remaining: 4m 19s
# 1380:	learn: -0.1087085	test: -0.3088253	best: -0.3085276 (1358)	total: 41.5s	remaining: 4m 18s
# 1400:	learn: -0.1082649	test: -0.3092697	best: -0.3085276 (1358)	total: 42s	remaining: 4m 17s
# 1420:	learn: -0.1078636	test: -0.3096754	best: -0.3085276 (1358)	total: 42.6s	remaining: 4m 17s
# 1440:	learn: -0.1075205	test: -0.3104304	best: -0.3085276 (1358)	total: 43.2s	remaining: 4m 16s
# 1460:	learn: -0.1071460	test: -0.3102564	best: -0.3085276 (1358)	total: 43.8s	remaining: 4m 15s
# 1480:	learn: -0.1067623	test: -0.3102629	best: -0.3085276 (1358)	total: 44.4s	remaining: 4m 15s
# 1500:	learn: -0.1063717	test: -0.3112214	best: -0.3085276 (1358)	total: 45s	remaining: 4m 14s
# 1520:	learn: -0.1060639	test: -0.3115014	best: -0.3085276 (1358)	total: 45.6s	remaining: 4m 14s
# 1540:	learn: -0.1057370	test: -0.3115898	best: -0.3085276 (1358)	total: 46.1s	remaining: 4m 13s
# 1560:	learn: -0.1053883	test: -0.3120700	best: -0.3085276 (1358)	total: 46.7s	remaining: 4m 12s
# 1580:	learn: -0.1050672	test: -0.3123326	best: -0.3085276 (1358)	total: 47.3s	remaining: 4m 11s
# 1600:	learn: -0.1047866	test: -0.3127094	best: -0.3085276 (1358)	total: 47.8s	remaining: 4m 10s
# 1620:	learn: -0.1045151	test: -0.3130588	best: -0.3085276 (1358)	total: 48.4s	remaining: 4m 10s
# 1640:	learn: -0.1042413	test: -0.3127498	best: -0.3085276 (1358)	total: 49s	remaining: 4m 9s
# 1660:	learn: -0.1039871	test: -0.3129430	best: -0.3085276 (1358)	total: 49.6s	remaining: 4m 9s
# 1680:	learn: -0.1036594	test: -0.3129498	best: -0.3085276 (1358)	total: 50.2s	remaining: 4m 8s
# 1700:	learn: -0.1033732	test: -0.3128630	best: -0.3085276 (1358)	total: 50.8s	remaining: 4m 8s
# 1720:	learn: -0.1031409	test: -0.3134980	best: -0.3085276 (1358)	total: 51.5s	remaining: 4m 7s
# 1740:	learn: -0.1028862	test: -0.3130355	best: -0.3085276 (1358)	total: 52.1s	remaining: 4m 7s
# 1760:	learn: -0.1026754	test: -0.3129349	best: -0.3085276 (1358)	total: 52.7s	remaining: 4m 6s
# 1780:	learn: -0.1024665	test: -0.3133413	best: -0.3085276 (1358)	total: 53.3s	remaining: 4m 6s
# 	Note: model has different eval_metric than default.
# 	-0.3085	 = Validation score   (-soft_log_loss)
# 	56.75s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_4_DSTL ...
# bestTest = -0.3085275661
# bestIteration = 1358
#
# Shrink model to first 1359 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.4575	 = Validation score   (-soft_log_loss)
# 	5.69s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_4_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_4_L2_DSTL']
# Fitting model: WeightedEnsemble_4_L2_DSTL ...
# 	Ensemble Weights: {'LightGBM_4_DSTL': 0.778, 'RandomForestMSE_4_DSTL': 0.222}
# 	Note: model has different eval_metric than default.
# 	-0.2781	 = Validation score   (-soft_log_loss)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_4_DSTL   0.895161  soft_log_loss       0.000000   1.825742                0.000000           1.825742            1       True         30
# 1             CatBoost_4_DSTL   0.895161  soft_log_loss       0.002130  56.745183                0.002130          56.745183            1       True         32
# 2  WeightedEnsemble_4_L2_DSTL   0.895161  soft_log_loss       0.076032   2.708763                0.000998           0.038145            2       True         34
# 3       NeuralNetTorch_4_DSTL   0.870968  soft_log_loss       0.015626   5.686048                0.015626           5.686048            1       True         33
# 4      RandomForestMSE_4_DSTL   0.870968  soft_log_loss       0.075034   0.844877                0.075034           0.844877            1       True         31
# ['LightGBM_4_DSTL', 'RandomForestMSE_4_DSTL', 'CatBoost_4_DSTL', 'NeuralNetTorch_4_DSTL', 'WeightedEnsemble_4_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                          model  score_test  score_val    eval_metric  \
# 0        NeuralNetTorch_3_DSTL    0.634921   0.887097  soft_log_loss
# 1                     CatBoost    0.619048   0.903226       accuracy
# 3   WeightedEnsemble_3_L2_DSTL    0.619048   0.895161  soft_log_loss
# 2   WeightedEnsemble_2_L2_DSTL    0.619048   0.887097  soft_log_loss
# 4                     LightGBM    0.603175   0.919355       accuracy
# 6                LightGBM_DSTL    0.603175   0.911290  soft_log_loss
# 7              CatBoost_2_DSTL    0.603175   0.895161  soft_log_loss
# 8                CatBoost_DSTL    0.603175   0.895161  soft_log_loss
# 9              LightGBM_2_DSTL    0.603175   0.895161  soft_log_loss
# 5        NeuralNetTorch_4_DSTL    0.603175   0.870968  soft_log_loss
# 10                  LightGBMXT    0.587302   0.919355       accuracy
# 13                     XGBoost    0.587302   0.903226       accuracy
# 11             CatBoost_4_DSTL    0.587302   0.895161  soft_log_loss
# 14  WeightedEnsemble_4_L2_DSTL    0.587302   0.895161  soft_log_loss
# 12       NeuralNetTorch_2_DSTL    0.587302   0.862903  soft_log_loss
# 21         WeightedEnsemble_L2    0.571429   0.935484       accuracy
# 18               LightGBMLarge    0.571429   0.927419       accuracy
# 20    WeightedEnsemble_L2_DSTL    0.571429   0.919355  soft_log_loss
# 15             LightGBM_3_DSTL    0.571429   0.895161  soft_log_loss
# 16             CatBoost_3_DSTL    0.571429   0.895161  soft_log_loss
# 19            RandomForestGini    0.571429   0.895161       accuracy
# 17              ExtraTreesEntr    0.571429   0.870968       accuracy
# 22             LightGBM_4_DSTL    0.555556   0.895161  soft_log_loss
# 23            RandomForestEntr    0.555556   0.895161       accuracy
# 24        RandomForestMSE_DSTL    0.555556   0.895161  soft_log_loss
# 25         NeuralNetTorch_DSTL    0.539683   0.887097  soft_log_loss
# 26      RandomForestMSE_3_DSTL    0.539683   0.887097  soft_log_loss
# 28      RandomForestMSE_2_DSTL    0.523810   0.870968  soft_log_loss
# 27              NeuralNetTorch    0.523810   0.854839       accuracy
# 29             NeuralNetFastAI    0.507937   0.870968       accuracy
# 31      RandomForestMSE_4_DSTL    0.507937   0.870968  soft_log_loss
# 30              ExtraTreesGini    0.507937   0.854839       accuracy
# 32              KNeighborsDist    0.460317   0.846774       accuracy
# 33              KNeighborsUnif    0.444444   0.725806       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.020254       0.020003  12.984582                 0.020254
# 1         0.008707       0.000000  19.250818                 0.008707
# 3         0.193744       0.100708  78.070190                 0.003001
# 2         0.185880       0.085453  61.887890                 0.000000
# 4         0.000000       0.000575   0.783901                 0.000000
# 6         0.015626       0.015662   2.442972                 0.015626
# 7         0.015637       0.005469  59.095027                 0.015637
# 8         0.017808       0.000000  74.735154                 0.017808
# 9         0.031253       0.004001   1.872072                 0.031253
# 5         0.015622       0.015626   5.686048                 0.015622
# 10        0.012878       0.000000   2.026765                 0.012878
# 13        0.086877       0.004002   1.483651                 0.086877
# 11        0.015624       0.002130  56.745183                 0.015624
# 14        0.138450       0.076032   2.708763                 0.000000
# 12        0.031250       0.015626   5.632700                 0.031250
# 21        0.220820       0.121217   4.386427                 0.000000
# 18        0.078126       0.014423   3.024698                 0.078126
# 20        0.171828       0.135633  18.530637                 0.000000
# 15        0.015623       0.006383   2.369200                 0.015623
# 16        0.021508       0.000000  63.920446                 0.021508
# 19        0.142694       0.106795   1.228542                 0.142694
# 17        0.074396       0.073394   0.977520                 0.074396
# 22        0.024551       0.000000   1.825742                 0.024551
# 23        0.081555       0.087413   1.088705                 0.081555
# 24        0.130322       0.086753   1.108503                 0.130322
# 25        0.025880       0.032215  14.948735                 0.025880
# 26        0.148981       0.080705   1.125670                 0.148981
# 28        0.138990       0.075983   0.885346                 0.138990
# 27        0.031252       0.015633  48.619976                 0.031252
# 29        0.034245       0.026514   5.205909                 0.034245
# 31        0.113899       0.075034   0.844877                 0.113899
# 30        0.073708       0.098453   1.137593                 0.073708
# 32        0.012153       0.031239   0.003421                 0.012153
# 33        0.004649       0.656982   9.558845                 0.004649
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.020003          12.984582            1       True
# 1                 0.000000          19.250818            1       True
# 3                 0.000000           0.039492            2       True
# 2                 0.000000           0.035444            2       True
# 4                 0.000575           0.783901            1       True
# 6                 0.015662           2.442972            1       True
# 7                 0.005469          59.095027            1       True
# 8                 0.000000          74.735154            1       True
# 9                 0.004001           1.872072            1       True
# 5                 0.015626           5.686048            1       True
# 10                0.000000           2.026765            1       True
# 13                0.004002           1.483651            1       True
# 11                0.002130          56.745183            1       True
# 14                0.000998           0.038145            2       True
# 12                0.015626           5.632700            1       True
# 21                0.000000           0.133187            2       True
# 18                0.014423           3.024698            1       True
# 20                0.001003           0.030426            2       True
# 15                0.006383           2.369200            1       True
# 16                0.000000          63.920446            1       True
# 19                0.106795           1.228542            1       True
# 17                0.073394           0.977520            1       True
# 22                0.000000           1.825742            1       True
# 23                0.087413           1.088705            1       True
# 24                0.086753           1.108503            1       True
# 25                0.032215          14.948735            1       True
# 26                0.080705           1.125670            1       True
# 28                0.075983           0.885346            1       True
# 27                0.015633          48.619976            1       True
# 29                0.026514           5.205909            1       True
# 31                0.075034           0.844877            1       True
# 30                0.098453           1.137593            1       True
# 32                0.031239           0.003421            1       True
# 33                0.656982           9.558845            1       True
#
#     fit_order
# 0          28
# 1           8
# 3          29
# 2          24
# 4           5
# 6          15
# 7          22
# 8          17
# 9          20
# 5          33
# 10          4
# 13         11
# 11         32
# 14         34
# 12         23
# 21         14
# 18         13
# 20         19
# 15         25
# 16         27
# 19          6
# 17         10
# 22         30
# 23          7
# 24         16
# 25         18
# 26         26
# 28         21
# 27         12
# 29          3
# 31         31
# 30          9
# 32          2
# 33          1
# 测试集上的最佳蒸馏模型：
# NeuralNetTorch_3_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.6349206349206349
# Evaluations on test data:
# {
#     "accuracy": 0.6349206349206349,
#     "balanced_accuracy": 0.5559829059829059,
#     "mcc": 0.4886832344975332
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.5,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.4827586206896552,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 deep": {
#         "precision": 1.0,
#         "recall": 0.4,
#         "f1-score": 0.5714285714285714,
#         "support": 5.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.6060606060606061,
#         "recall": 0.7692307692307693,
#         "f1-score": 0.6779661016949152,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.3333333333333333,
#         "recall": 0.2,
#         "f1-score": 0.25,
#         "support": 5.0
#     },
#     "Exc L3-4 RORB CARM1P1": {
#         "precision": 1.0,
#         "recall": 0.5,
#         "f1-score": 0.6666666666666666,
#         "support": 4.0
#     },
#     "Exc L3-5 RORB COL22A1": {
#         "precision": 0.8888888888888888,
#         "recall": 1.0,
#         "f1-score": 0.9411764705882353,
#         "support": 8.0
#     },
#     "accuracy": 0.6349206349206349,
#     "macro avg": {
#         "precision": 0.7213804713804715,
#         "recall": 0.5559829059829059,
#         "f1-score": 0.5983327385113406,
#         "support": 63.0
#     },
#     "weighted avg": {
#         "precision": 0.6513548180214846,
#         "recall": 0.6349206349206349,
#         "f1-score": 0.6217733213163179,
#         "support": 63.0
#     }
# }
# {'accuracy': 0.6349206349206349, 'balanced_accuracy': 0.5559829059829059, 'mcc': 0.4886832344975332, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 deep                        0
# Exc L2-3 LINC00507 FREM3 superficial                 5
# Exc L2-4 LINC00507 GLP2R                             1
# Exc L3-4 RORB CARM1P1                                1
# Exc L3-5 RORB COL22A1                                0
#
#                                       Exc L2-3 LINC00507 FREM3 deep  \
# Exc L2 LAMP5 LTK                                                  0
# Exc L2-3 LINC00507 FREM3 deep                                     2
# Exc L2-3 LINC00507 FREM3 superficial                              0
# Exc L2-4 LINC00507 GLP2R                                          0
# Exc L3-4 RORB CARM1P1                                             0
# Exc L3-5 RORB COL22A1                                             0
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         7
# Exc L2-3 LINC00507 FREM3 deep                                            2
# Exc L2-3 LINC00507 FREM3 superficial                                    20
# Exc L2-4 LINC00507 GLP2R                                                 3
# Exc L3-4 RORB CARM1P1                                                    1
# Exc L3-5 RORB COL22A1                                                    0
#
#                                       Exc L2-4 LINC00507 GLP2R  \
# Exc L2 LAMP5 LTK                                             0
# Exc L2-3 LINC00507 FREM3 deep                                1
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     1
# Exc L3-4 RORB CARM1P1                                        0
# Exc L3-5 RORB COL22A1                                        0
#
#                                       Exc L3-4 RORB CARM1P1  \
# Exc L2 LAMP5 LTK                                          0
# Exc L2-3 LINC00507 FREM3 deep                             0
# Exc L2-3 LINC00507 FREM3 superficial                      0
# Exc L2-4 LINC00507 GLP2R                                  0
# Exc L3-4 RORB CARM1P1                                     2
# Exc L3-5 RORB COL22A1                                     0
#
#                                       Exc L3-5 RORB COL22A1
# Exc L2 LAMP5 LTK                                          1
# Exc L2-3 LINC00507 FREM3 deep                             0
# Exc L2-3 LINC00507 FREM3 superficial                      0
# Exc L2-4 LINC00507 GLP2R                                  0
# Exc L3-4 RORB CARM1P1                                     0
# Exc L3-5 RORB COL22A1                                     8  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.5, 'recall': 0.4666666666666667, 'f1-score': 0.4827586206896552, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 deep': {'precision': 1.0, 'recall': 0.4, 'f1-score': 0.5714285714285714, 'support': 5.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.6060606060606061, 'recall': 0.7692307692307693, 'f1-score': 0.6779661016949152, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.3333333333333333, 'recall': 0.2, 'f1-score': 0.25, 'support': 5.0}, 'Exc L3-4 RORB CARM1P1': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 4.0}, 'Exc L3-5 RORB COL22A1': {'precision': 0.8888888888888888, 'recall': 1.0, 'f1-score': 0.9411764705882353, 'support': 8.0}, 'accuracy': 0.6349206349206349, 'macro avg': {'precision': 0.7213804713804715, 'recall': 0.5559829059829059, 'f1-score': 0.5983327385113406, 'support': 63.0}, 'weighted avg': {'precision': 0.6513548180214846, 'recall': 0.6349206349206349, 'f1-score': 0.6217733213163179, 'support': 63.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### (1) 利用SNS的热力图函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
# 计算混淆矩阵
cfm = confusion_matrix(results['actual'], results['predicted'])
cfm = cfm[::-1]
# 画热力图
ax = plt.subplots(figsize=(8, 6))#调整画布大小
ax = sns.heatmap(cfm, annot=True, linewidth=.5, cmap="crest")#画热力图   annot=True 表示显示系数
plt.title("Confusion Matrix",fontsize=25)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25, rotation_mode="anchor", ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated[::-1], rotation=0, rotation_mode="anchor", ha="right",fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x21235cd6f50>,
#   <matplotlib.axis.YTick at 0x21235d07f10>,
#   <matplotlib.axis.YTick at 0x21235d02390>,
#   <matplotlib.axis.YTick at 0x21235daf110>,
#   <matplotlib.axis.YTick at 0x21235d51550>,
#   <matplotlib.axis.YTick at 0x21235d47290>],
#  [Text(0, 0, 'Exc L3-5 RORB COL22A1'),
#   Text(0, 1, 'Exc L3-4 RORB CARM1P1'),
#   Text(0, 2, 'Exc L2-4 LINC00507 GLP2R'),
#   Text(0, 3, 'Exc L2-3 LINC00507 FREM3 superficial'),
#   Text(0, 4, 'Exc L2-3 LINC00507 FREM3 deep'),
#   Text(0, 5, 'Exc L2 LAMP5 LTK')])

# %% [markdown]
# #### (2) 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2 LAMP5 LTK

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
predictor.delete_models(models_to_keep='best')
# Out:
# Dry run enabled, AutoGluon would have deleted the following models: ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsUnif_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\KNeighborsDist_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetFastAI_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBMXT_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\LightGBM_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesGini_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\ExtraTreesEntr_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\XGBoost_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_BAG_L1 would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\RandomForestMSE_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\CatBoost_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\NeuralNetTorch_DSTL would have been deleted.
# 	Directory Models\Teacher\medium_quality-20240726-161331\models\WeightedEnsemble_L2_DSTL would have been deleted.
# To perform the deletion, set dry_run=False

# %%
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
