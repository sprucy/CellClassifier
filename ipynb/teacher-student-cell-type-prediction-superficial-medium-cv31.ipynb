# %% [markdown]
# # 利用知识蒸馏进行教师学生模型训练程序 version 3.0
# ### 1. 程序说明
# 1.1. 原始cell程序将UNKNOWN类型作为已知分类，实际为未标注数据，程序做了修改，通过数据预处理，将数据集分为标注数据集和未标注数据集。
# 1.2. 原来cell程序中，modality = 'both'时，二者取并集,共有102行,通过对其分类分析，每个分类大于15条样本的分类只有2个，因此原来的程序训练的实际为二分类问题, 这里将每个分类改为5来保留所有分类，
# version 1.0 updated
# 1. 实现程序结构优化
# 2. 针对小样本(样本数量仅有102条)的问题，将min_cells_per_type修改为5，保留了所有分类。
# 3. 针对样本不均衡问题，利用bagging和stacking方法，对模型进行集成，实现模型融合，解决小样本不均衡问题，提高模型精度。
# 4. 通过训练教师模型，标注无标签数据，利用所标注的数据训练学生模型，将教师模型的输出作为学生模型的输入，实现知识蒸馏，提高模型精度。
# version 2.0 updated
# 1. 针对小样本的不均衡问题，增加了欠采样处理函数，实现了SMOTE, SMOTEN, SMOTENC, BorderlineSMOTE, SVMSMOTE, KMeansSMOTE, RandomOverSampler, ADASYN等采样方法，教师模型准确度有较大提升。
# 2. 增加了部分绘图函数，实现可视化。
# version 3.0 updated
# 1. 修改程序构架，将函数和常量统一移入utils.py文件中，方便统一调用。
# ### 2. 数据集说明
# 2.1. ephys数据集文件:382行，标题行1行，数据行381行，其中：标注数据313行，未标注数据68行；共42列，第0列为specimen_id索引列，特征列41列
# 2.2. morph数据集文件:170行，标题行1行，数据行170行，其中：标注数据102行，未标注数据68行；共26列，第0列为specimen_id索引列，特征列25列

# %% [markdown]
# ## 1. Import Libraries

# %%
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ## 2. Program initialization
# #### <font color='Red'>注意：缺失值补插和过采样在此处设置</font>

# %%
taxonomy = 'Berg'                   # choose which taxonomy:        'Berg', 'SEA_AD' or 'Mouse'
cell_subset = 'Superficial'         # choose which cells:           'All', 'Superficial' or 'Deep'
modality = 'Ephys'                  # choose which modality:        'Both', 'Ephys' or 'Morph'
rowfilte = True                     # choose if you want to row filter: True or False
scaler_method = None                # choose your data format:      'standard','minmax','robust','normalizer','quantile'
impute_method = 'knn'                # choose which imputer:         None or 'knn' or 'liner' or 'Polynomial' or 'decisiontree':
oversample_method = 'random'            # choose which oversampler:      None or 'random' or 'smote' or 'smoten' or 'smotenc' or 'borderline' or 'adasyn' or 'svmsmote' or 'kmeans'

# %%
# 设置缺省参数
# min_num_features = 8              # minimum number of features left to classify (e.g. 5)
# threshold_percentile = 5          # minimum percentage a feature needs to contribute to accurate prediction (e.g. 5)
min_cells_per_type = 5              # minimum cells necessary in the training data per group/label/cell-type (e.g. 5 or 10)
null_threshold = 0.2                       # row filter null value threshold
test_size =0.20                     # test size for cross validation (e.g. 0.2)
#depth_threshold = 0.575            # choose depth threshold
#index_column = 'specimen_id'       # index column name
#label_column = 'label'             # label column name
#FREM3_list = ['Exc L2-3 LINC00507 FREM3']                                    # 需区分浅层和深层FREM3细胞的列表
#superficial_t_types = ['Exc L2 LAMP5 LTK', 'Exc L2-4 LINC00507 GLP2R', 'Exc L2-3 LINC00507 FREM3 superficial']
#deep_t_types = ['Exc L2-3 LINC00507 FREM3 deep', 'Exc L3-4 RORB CARM1P1', 'Exc L3-5 RORB COL22A1']
teacher_model_path = 'models\\Teacher\\'
student_model_path = 'models\\Student\\'
#random_state = 42

# %% [markdown]
# ## 3. Data Loading
# ### 3.1 读取数据文件

# %%
# # Define the path to the files and read in the data
meta_data_path = Path("..\data\meta_data_withVU.csv")        # read the meta data file
ephys_path = Path("..\data\ephys_data_withVU.csv")           # read the ephys data file
morph_path = Path("..\data\morph_data_withVU.csv")           # read the morph data file
# Read in the data files
meta_data = pd.read_csv(meta_data_path, index_col=0) 
ephys_data = pd.read_csv(ephys_path, index_col=0)
morph_data = pd.read_csv(morph_path, index_col=0)
print('原始数据文件：')
print('ephys_dataset:', ephys_data.shape)
print('morph_dataset:', morph_data.shape)
# Out:
# 原始数据文件：
# ephys_dataset: (522, 35)
# morph_dataset: (170, 25)

# %% [markdown]
# ### 3.2 分离标注数据和非标注数据
# 统一索引列和更新L23_depth_normalized列,根据taxonomy设置标签列,根据modality设置数据集的特征列,根据cell type过滤数据集样本(行)

# %%
labeled_data, unlabeled_data =  load_data_l23_depth_normalized(meta_data, ephys_data, morph_data, taxonomy = taxonomy, modality = modality, cell_subset = cell_subset)
print('--- Init Setup ---')
print('Cell_subset: ',cell_subset)
print('Modality:    ', modality)
print('Taxonomy:    ', taxonomy)
print('Labeled_data:    ', labeled_data.shape)
print('Unlabeled_data:  ', unlabeled_data.shape)
# Out:
# --- Init Setup ---
# Cell_subset:  Superficial
# Modality:     Ephys
# Taxonomy:     Berg
# Labeled_data:     (230, 37)
# Unlabeled_data:   (209, 37)

# %% [markdown]
# #### 3.2.1 原始的分类数和每个分类的样本数

# %%
ax = labeled_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Original Dataset Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 4 Data preprocessing

# %% [markdown]
# ### 4.1 行过滤
# 根据每个分类最小样本数(min_cells_per_type)过滤数据集的样本(行)，根据每行空值数过滤。

# %%
if rowfilte:
    labeled_data = filter(labeled_data,min_cells_per_type=min_cells_per_type, threshold=null_threshold)

# %% [markdown]
# 过滤后的分类数和每个分类的样本数绘图
# 因为最少的几个分类为5、8、9，当min_cells_per_type>5时，分类会减少,这里绘图用于对比

# %%
plt.figure(figsize=(10,4))
labeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 补插空值
# 根据impute_method设置执行

# %% [markdown]
# #### 4.2.1 对label_data数据集补插缺失值

# %%
if impute_method:
    print('-------------------------------            Imputing Dataset            -------------------------------')
    print('1. Imputing Labeled Dataset')
    # 不包含标签列进行补插
    print('补插前标记数据集信息:')
    t_type_labels = labeled_data.iloc[:, -1].values
    print(labeled_data.info())
    labeled_data = impute(labeled_data.iloc[:,0:labeled_data.columns.size-1],method=impute_method)
    labeled_data[LABEL_COLUMN] = t_type_labels
    print('补插后标记数据集信息:')
    print(labeled_data.info())
# Out:
# -------------------------------            Imputing Dataset            -------------------------------
# 1. Imputing Labeled Dataset
# 补插前标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 541549258 to 811939096
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         201 non-null    float64
#  12  TS2_adp_index         211 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  210 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 76.4+ KB
# None
# 补插后标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      230 non-null    float64
#  1   sag                   230 non-null    float64
#  2   VmatSag               230 non-null    float64
#  3   vmbaseM               230 non-null    float64
#  4   tau                   230 non-null    float64
#  5   FAP_rheobase          230 non-null    float64
#  6   FAP_num_APs           230 non-null    float64
#  7   TS1_rheobase          230 non-null    float64
#  8   TS1_num_APs           230 non-null    float64
#  9   TS2_rheobase          230 non-null    float64
#  10  TS2_num_APs           230 non-null    float64
#  11  TS1_adp_index         230 non-null    float64
#  12  TS2_adp_index         230 non-null    float64
#  13  FAP_threshold         230 non-null    float64
#  14  FAP_peak              230 non-null    float64
#  15  FAP_maxupstroke       230 non-null    float64
#  16  FAP_maxdownstroke     230 non-null    float64
#  17  FAP_halfwidth         230 non-null    float64
#  18  FAP_avg_upstroke      230 non-null    float64
#  19  FAP_avg_downstroke    230 non-null    float64
#  20  FAP_up_down_ratio     230 non-null    float64
#  21  TS1_threshold         230 non-null    float64
#  22  TS1_maxupstroke       230 non-null    float64
#  23  TS1_maxdownstroke     230 non-null    float64
#  24  TS1_halfwidth         230 non-null    float64
#  25  TS1_avg_upstroke      230 non-null    float64
#  26  TS1_avg_downstroke    230 non-null    float64
#  27  TS1_up_down_ratio     230 non-null    float64
#  28  TS2_threshold         230 non-null    float64
#  29  TS2_peak              230 non-null    float64
#  30  TS2_maxupstroke       230 non-null    float64
#  31  TS2_maxdownstroke     230 non-null    float64
#  32  TS2_avg_upstroke      230 non-null    float64
#  33  TS2_avg_downstroke    230 non-null    float64
#  34  TS2_up_down_ratio     230 non-null    float64
#  35  L23_depth_normalized  230 non-null    float64
#  36  label                 230 non-null    object
# dtypes: float64(36), object(1)
# memory usage: 66.6+ KB
# None

# %% [markdown]
# #### 4.2.2 对unlabel_data数据集补插

# %%
if impute_method:
    print('2. Imputing Unlabeled Dataset')
    # 对unlabel_data数据集补插 
    print('补插前未标记数据集信息:')
    print(unlabeled_data.info())
    unlabeled_data = impute(unlabeled_data.iloc[:,0:unlabeled_data.columns.size-1],method=impute_method)
    unlabeled_data[LABEL_COLUMN] = np.nan
    print('补插后未标记数据集信息:')
    print(unlabeled_data.info())
# Out:
# 2. Imputing Unlabeled Dataset
# 补插前未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 110000001 to H23.29.252.11.91.02
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      207 non-null    float64
#  1   sag                   207 non-null    float64
#  2   VmatSag               207 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   200 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           208 non-null    float64
#  9   TS2_rheobase          208 non-null    float64
#  10  TS2_num_APs           208 non-null    float64
#  11  TS1_adp_index         186 non-null    float64
#  12  TS2_adp_index         196 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              187 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         208 non-null    float64
#  29  TS2_peak              208 non-null    float64
#  30  TS2_maxupstroke       208 non-null    float64
#  31  TS2_maxdownstroke     208 non-null    float64
#  32  TS2_avg_upstroke      208 non-null    float64
#  33  TS2_avg_downstroke    208 non-null    float64
#  34  TS2_up_down_ratio     208 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      object
# dtypes: float64(36), object(1)
# memory usage: 62.0+ KB
# None
# 补插后未标记数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      209 non-null    float64
#  1   sag                   209 non-null    float64
#  2   VmatSag               209 non-null    float64
#  3   vmbaseM               209 non-null    float64
#  4   tau                   209 non-null    float64
#  5   FAP_rheobase          209 non-null    float64
#  6   FAP_num_APs           209 non-null    float64
#  7   TS1_rheobase          209 non-null    float64
#  8   TS1_num_APs           209 non-null    float64
#  9   TS2_rheobase          209 non-null    float64
#  10  TS2_num_APs           209 non-null    float64
#  11  TS1_adp_index         209 non-null    float64
#  12  TS2_adp_index         209 non-null    float64
#  13  FAP_threshold         209 non-null    float64
#  14  FAP_peak              209 non-null    float64
#  15  FAP_maxupstroke       209 non-null    float64
#  16  FAP_maxdownstroke     209 non-null    float64
#  17  FAP_halfwidth         209 non-null    float64
#  18  FAP_avg_upstroke      209 non-null    float64
#  19  FAP_avg_downstroke    209 non-null    float64
#  20  FAP_up_down_ratio     209 non-null    float64
#  21  TS1_threshold         209 non-null    float64
#  22  TS1_maxupstroke       209 non-null    float64
#  23  TS1_maxdownstroke     209 non-null    float64
#  24  TS1_halfwidth         209 non-null    float64
#  25  TS1_avg_upstroke      209 non-null    float64
#  26  TS1_avg_downstroke    209 non-null    float64
#  27  TS1_up_down_ratio     209 non-null    float64
#  28  TS2_threshold         209 non-null    float64
#  29  TS2_peak              209 non-null    float64
#  30  TS2_maxupstroke       209 non-null    float64
#  31  TS2_maxdownstroke     209 non-null    float64
#  32  TS2_avg_upstroke      209 non-null    float64
#  33  TS2_avg_downstroke    209 non-null    float64
#  34  TS2_up_down_ratio     209 non-null    float64
#  35  L23_depth_normalized  209 non-null    float64
#  36  label                 0 non-null      float64
# dtypes: float64(37)
# memory usage: 60.5 KB
# None

# %% [markdown]
# ### 4.3 标准化
# 根据scaler_method设置执行

# %%
# 转换为numpy数组
data_array = labeled_data.iloc[:,0:labeled_data.columns.size-1].values              # transform the data to an array

# Check if data needs to be scoring
if scaler_method:
    print('-------------------------------             Scaling Dataset            -------------------------------')
    data_array = scale(data_array, scalemethod = scaler_method)                     # apply scoring method 


cell_ids_subset = labeled_data.index                                                # extract the cell IDs of the subset
# Create a list of features
feature_list = labeled_data.iloc[:,0:labeled_data.columns.size-1].keys().values
# normalized_depths = labeled_data['L23_depth_normalized'].values                     # extract normalized depth values
t_type_labels = labeled_data.iloc[:, -1].values                                     # extract t-type labels of the data subset
t_types_updated = np.unique(t_type_labels)
print('dataset rownum:',data_array.shape[0])
print('feature num:',len(feature_list))
print('feature list:',feature_list)
print('cell type num:',len(t_types_updated))
print('cell type list:',t_types_updated)
# Out:
# dataset rownum: 230
# feature num: 36
# feature list: ['input_resistance' 'sag' 'VmatSag' 'vmbaseM' 'tau' 'FAP_rheobase'
#  'FAP_num_APs' 'TS1_rheobase' 'TS1_num_APs' 'TS2_rheobase' 'TS2_num_APs'
#  'TS1_adp_index' 'TS2_adp_index' 'FAP_threshold' 'FAP_peak'
#  'FAP_maxupstroke' 'FAP_maxdownstroke' 'FAP_halfwidth' 'FAP_avg_upstroke'
#  'FAP_avg_downstroke' 'FAP_up_down_ratio' 'TS1_threshold'
#  'TS1_maxupstroke' 'TS1_maxdownstroke' 'TS1_halfwidth' 'TS1_avg_upstroke'
#  'TS1_avg_downstroke' 'TS1_up_down_ratio' 'TS2_threshold' 'TS2_peak'
#  'TS2_maxupstroke' 'TS2_maxdownstroke' 'TS2_avg_upstroke'
#  'TS2_avg_downstroke' 'TS2_up_down_ratio' 'L23_depth_normalized']
# cell type num: 3
# cell type list: ['Exc L2 LAMP5 LTK' 'Exc L2-3 LINC00507 FREM3 superficial'
#  'Exc L2-4 LINC00507 GLP2R']

# %% [markdown]
# ### 4.4 训练集测试集数据拆分

# %%
# Split the data into a training and test dataset
X_train, X_test, y_train, y_test = train_test_split(data_array, t_type_labels, test_size=test_size, stratify=t_type_labels, random_state=RANDOM_STATE)

# %% [markdown]
# ### 4.5 过采样解决样本不平衡问题
# 利用imblearn库的SMOTE、SMOTEENN、ADASYN和KMeansSMOTE算法, 解决样本不平衡问题，过采样，需要补插缺失值，否则会报错。

# %%
# 组合X_train数据为dataframe，未包含label列
train_data= pd.DataFrame(data = X_train, columns = feature_list)

if oversample_method:
    # 过采样的数据集不能有空值
    # 当程序未设置插值方法,这里使用默认的knn方法,否则使用设定的插值方法
    if impute_method:
        train_data = impute(train_data, method = impute_method, random_state = RANDOM_STATE)
    else:
        train_data = impute(train_data, random_state = RANDOM_STATE)
    # 进行过采样
    X_train, y_train = oversampler(train_data.values, y_train, method = oversample_method)    
    train_data= pd.DataFrame(data = X_train, columns = feature_list)
train_data[LABEL_COLUMN] = y_train

# %%
if oversample_method:    
    # 绘制过采样后的训练集的每分类的数量
    plt.figure(figsize=(10,6))
    train_data[LABEL_COLUMN].value_counts().plot(kind='bar')
    # 为条形图添加数值标签
    plt.bar_label(plt.gca().containers[0])
    figtitle = 'Oversampled Dataset Number of samples per classification'
    plt.title(figtitle, fontsize=14)
    plt.xticks(rotation=30,fontsize=8)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Oversampled Dataset Number of samples per classification

# %%
if oversample_method:  
    ax = train_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f%%')
    figtitle = 'Over-sampled Dataset Class Distribution'
    ax.set_title(figtitle)
    print(f'Save Figure:{figtitle}')
    plt.show()
# Out:
# Save Figure:Over-sampled Dataset Class Distribution

# %% [markdown]
# ### 4.6 生成测试数据

# %%
test_data_nolabel = pd.DataFrame(data = X_test, columns = feature_list)
test_data = test_data_nolabel.copy()
test_data[LABEL_COLUMN] = pd.DataFrame(y_test, columns = [LABEL_COLUMN])
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   input_resistance      46 non-null     float64
#  1   sag                   46 non-null     float64
#  2   VmatSag               46 non-null     float64
#  3   vmbaseM               46 non-null     float64
#  4   tau                   46 non-null     float64
#  5   FAP_rheobase          46 non-null     float64
#  6   FAP_num_APs           46 non-null     float64
#  7   TS1_rheobase          46 non-null     float64
#  8   TS1_num_APs           46 non-null     float64
#  9   TS2_rheobase          46 non-null     float64
#  10  TS2_num_APs           46 non-null     float64
#  11  TS1_adp_index         46 non-null     float64
#  12  TS2_adp_index         46 non-null     float64
#  13  FAP_threshold         46 non-null     float64
#  14  FAP_peak              46 non-null     float64
#  15  FAP_maxupstroke       46 non-null     float64
#  16  FAP_maxdownstroke     46 non-null     float64
#  17  FAP_halfwidth         46 non-null     float64
#  18  FAP_avg_upstroke      46 non-null     float64
#  19  FAP_avg_downstroke    46 non-null     float64
#  20  FAP_up_down_ratio     46 non-null     float64
#  21  TS1_threshold         46 non-null     float64
#  22  TS1_maxupstroke       46 non-null     float64
#  23  TS1_maxdownstroke     46 non-null     float64
#  24  TS1_halfwidth         46 non-null     float64
#  25  TS1_avg_upstroke      46 non-null     float64
#  26  TS1_avg_downstroke    46 non-null     float64
#  27  TS1_up_down_ratio     46 non-null     float64
#  28  TS2_threshold         46 non-null     float64
#  29  TS2_peak              46 non-null     float64
#  30  TS2_maxupstroke       46 non-null     float64
#  31  TS2_maxdownstroke     46 non-null     float64
#  32  TS2_avg_upstroke      46 non-null     float64
#  33  TS2_avg_downstroke    46 non-null     float64
#  34  TS2_up_down_ratio     46 non-null     float64
#  35  L23_depth_normalized  46 non-null     float64
#  36  label                 46 non-null     object
# dtypes: float64(36), object(1)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 4.6.1 test数据集按分类的分布

# %%
plt.figure(figsize=(10,4))
test_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %%
ax = test_data[LABEL_COLUMN].value_counts().plot.pie(autopct='%.2f')
ax.set_title("Over-sampling Dataset Class Distribution")
plt.show()

# %% [markdown]
# ## 5. teacher model training

# %% [markdown]
# ### 5.1 训练教师模型

# %% [markdown]
# **待确认的问题：**
# **1. 标准化处理是否自动进行有待确认，测试发现是否进行标准化似乎结果一致**。
# **2. 训练教师模型是否需要拆分出测试集，拆分后参与训练的数据减少会影响训练的结果，对于教师学生模型这种模式，需要通过教师模型预测未标注数据集，然后利用预测结果去训练学生模型，再利用学生模型学习教师模型，最终利用蒸馏得到的学生模型对标注数据集进行评估，因此开始拆分出测试集的必要性有待确认。**
#
# 经测试发现数据集无需进行空值补插，框架自动进行特征工程、空值补插等操作。
# * Stage 1 Generators:
#     * Fitting AsTypeFeatureGenerator...
# * Stage 2 Generators:
#     * Fitting FillNaFeatureGenerator...
# * Stage 3 Generators:
# 	* Fitting IdentityFeatureGenerator...
# * Stage 4 Generators:
# 	* Fitting DropUniqueFeatureGenerator...
# * Stage 5 Generators:
# 	* Fitting DropDuplicatesFeatureGenerator...
# 因此可以直接进行训练和测试。
#
# 模型的精度的选择：
# 关于训练后模型的命名规则详见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
# 参数的设置，增加训练时间的一般都会增加输出精度
# * time_limit : 模型训练的最长等待时间，通常不设置
# * eval_metric: 指定评价指标例如，AUC还是精度等
#     * ‘f1’ (for binary classification),
#     * ‘roc_auc’ (for binary classification),
#     * ‘log_loss’ (for classification), ‘
#     * ‘mean_absolute_error’ (for regression),
#     * ‘median_absolute_error’ (for regression)
# * presets： 默认为’medium_quality_faster_train’, 可以按medium_quality good_quality high_quality best_quality的顺序测试，找到适合的模型。折中的办法就是：presets=[‘good_quality’, ‘optimize_for_deployment’]。Available Presets: [‘best_quality’, ‘high_quality’, ‘good_quality’, ‘medium_quality’, ‘optimize_for_deployment’, ‘interpretable’, ‘ignore_text’]
#     * presets='best_quality'   : Maximize accuracy. Default time_limit=3600.  利用bagging/staking,准确度高但是运行时间长。
# 	* presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	* presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	* presets='medium_quality' : Fast training time, ideal for initial prototyping. 选择的算法运行时间较短，但准确率会差一点。
# 目测presets='good_quality'以上时,缺省会采用stacking/bagging算法。关于模型的stacking/bagging算法，详见：https://www.jianshu.com/p/50bc90f87a05和https://blog.csdn.net/ueke1/article/details/137190677
# * Tuning_data: 这个作为验证集数据的参数，官网建议如果没有特别的理由时不加，让机器自己从训练集中分割出一小部分验证集，这边值得一提的是机器还能自己根据数据使用分层抽样等，可以说是非常人性化了。
# * holdout_frac：这个参数指定从训练集出分割出多少比例的验证集
# * num_bag_folds = 5-10，这个应该是类似k倍交叉验证，会增加训练时间
# * num_stack_levels = 1-3，stacking 水平
# * num_bag_sets:减少方差，但是增加训练时间
# **详细说明见下列连接：**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.html**
# **https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html**
#
# <font color='red'>可以设置num_bag_folds，num_stack_levels的值，并在fit函数中应用，来空值bagging和stacking</font>
# <font color='red'>设置k折交叉验证，需设置auto_stack为True和dynamic_stacking为True,并在ds_arg中设置参数才起作用</font>

# %%
#设置训练精度
presets='medium_quality'
eval_metric = 'accuracy'
verbosity = 2
time_limit = 3600
auto_stack=True
# bagging的折数,缺省好像未8
num_bag_folds=8
# stacking的级别
num_stack_levels=1
# n折交叉验证,设置auto_stack为True和dynamic_stacking为True
num_bag_sets=1
dynamic_stacking = True
# n_fold为交叉验证折数,n_repeats为交叉验证重复次数
ds_args = {
    'validation_procedure': 'cv',
    'n_folds': 3,
    'n_repeats': 1,
}
# 模型的保存路径，详细的模型命名规则见：https://auto.gluon.ai/stable/api/autogluon.tabular.models.html
save_path = teacher_model_path + presets + datetime.datetime.now().strftime("-%Y%m%d-%H%M%S")

# 开始训练
predictor = TabularPredictor(label=LABEL_COLUMN, verbosity=verbosity,eval_metric=eval_metric, path=save_path, log_to_file=True,log_file_path='auto')
if auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds, 
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets,dynamic_stacking=dynamic_stacking, ds_args=ds_args)
elif auto_stack and not dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, num_bag_folds=num_bag_folds,
                        num_stack_levels=num_stack_levels, num_bag_sets=num_bag_sets)
elif not auto_stack and dynamic_stacking:
    predictor.fit(train_data, presets=presets, time_limit=time_limit, auto_stack=auto_stack, dynamic_stacking=dynamic_stacking, ds_args=ds_args)
else:
    predictor.fit(train_data, presets=presets, time_limit=time_limit)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.7
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          8
# Memory Avail:       6.75 GB / 15.92 GB (42.4%)
# Disk Space Avail:   312.73 GB / 931.51 GB (33.6%)
# ===================================================
# Presets specified: ['medium_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Starting (repeated-)cross-validation-based sub-fits for dynamic stacking. Context path: "models\Teacher\medium_quality-20241031-214904\ds_sub_fit"Run at most 3 sub-fits based on 1-repeated 3-fold cross-validation.
# 	Starting sub-fit 1. Time limit for the sub-fit of this split is: 300.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-10-31 21:49:09,743	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8267
# 		Context path: "models\Teacher\medium_quality-20241031-214904\ds_sub_fit\sub_fit_0"
# (_dystack pid=30464) Running DyStack sub-fit ...
# (_dystack pid=30464) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=30464) AutoGluon will save models to "models\Teacher\medium_quality-20241031-214904\ds_sub_fit\sub_fit_0"
# (_dystack pid=30464) Train Data Rows:    206
# (_dystack pid=30464) Train Data Columns: 36
# (_dystack pid=30464) Label Column:       label
# (_dystack pid=30464) Problem Type:       multiclass
# (_dystack pid=30464) Preprocessing data ...
# (_dystack pid=30464) Train Data Class Count: 3
# (_dystack pid=30464) Using Feature Generators to preprocess the data ...
# (_dystack pid=30464) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=30464) 	Available Memory:                    6430.31 MB
# (_dystack pid=30464) 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# (_dystack pid=30464) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=30464) 	Stage 1 Generators:
# (_dystack pid=30464) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=30464) 	Stage 2 Generators:
# (_dystack pid=30464) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=30464) 	Stage 3 Generators:
# (_dystack pid=30464) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=30464) 	Stage 4 Generators:
# (_dystack pid=30464) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=30464) 	Stage 5 Generators:
# (_dystack pid=30464) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=30464) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=30464) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=30464) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=30464) 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# (_dystack pid=30464) 	0.1s = Fit runtime
# (_dystack pid=30464) 	36 features in original data used to generate 36 features in processed data.
# (_dystack pid=30464) 	Train Data (Processed) Memory Usage: 0.06 MB (0.0% of available memory)
# (_dystack pid=30464) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=30464) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=30464) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=30464) User-specified model hyperparameters to be fit:
# (_dystack pid=30464) {
# (_dystack pid=30464) 	'NN_TORCH': {},
# (_dystack pid=30464) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=30464) 	'CAT': {},
# (_dystack pid=30464) 	'XGB': {},
# (_dystack pid=30464) 	'FASTAI': {},
# (_dystack pid=30464) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=30464) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=30464) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=30464) }
# (_dystack pid=30464) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=30464) Fitting 13 L1 models ...
# (_dystack pid=30464) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.19s of the 891.5s of remaining time.
# (_dystack pid=30464) 	0.665	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.0s	 = Training   runtime
# (_dystack pid=30464) 	0.15s	 = Validation runtime
# (_dystack pid=30464) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 591.61s of the 888.93s of remaining time.
# (_dystack pid=30464) 	0.767	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.01s	 = Training   runtime
# (_dystack pid=30464) 	0.0s	 = Validation runtime
# (_dystack pid=30464) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 591.6s of the 888.92s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_dystack pid=30464) 	0.8835	 = Validation score   (accuracy)
# (_dystack pid=30464) 	10.65s	 = Training   runtime
# (_dystack pid=30464) 	0.09s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 575.91s of the 873.23s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=30464) 	0.8544	 = Validation score   (accuracy)
# (_dystack pid=30464) 	2.99s	 = Training   runtime
# (_dystack pid=30464) 	0.01s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBM_BAG_L1 ... Training model for up to 567.1s of the 864.42s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=30464) 	0.8689	 = Validation score   (accuracy)
# (_dystack pid=30464) 	2.46s	 = Training   runtime
# (_dystack pid=30464) 	0.01s	 = Validation runtime
# (_dystack pid=30464) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 559.28s of the 856.58s of remaining time.
# (_dystack pid=30464) 	0.8301	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.96s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 558.09s of the 855.41s of remaining time.
# (_dystack pid=30464) 	0.835	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.81s	 = Training   runtime
# (_dystack pid=30464) 	0.11s	 = Validation runtime
# (_dystack pid=30464) Fitting model: CatBoost_BAG_L1 ... Training model for up to 557.11s of the 854.43s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=30464) 	0.8592	 = Validation score   (accuracy)
# (_dystack pid=30464) 	19.24s	 = Training   runtime
# (_dystack pid=30464) 	0.0s	 = Validation runtime
# (_dystack pid=30464) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 532.42s of the 829.73s of remaining time.
# (_dystack pid=30464) 	0.8252	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.78s	 = Training   runtime
# (_dystack pid=30464) 	0.09s	 = Validation runtime
# (_dystack pid=30464) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 531.53s of the 828.85s of remaining time.
# (_dystack pid=30464) 	0.8252	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.75s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: XGBoost_BAG_L1 ... Training model for up to 530.65s of the 827.96s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=30464) 	0.8495	 = Validation score   (accuracy)
# (_dystack pid=30464) 	3.09s	 = Training   runtime
# (_dystack pid=30464) 	0.01s	 = Validation runtime
# (_dystack pid=30464) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 522.49s of the 819.81s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=40400) Stack (most recent call first):
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=40400)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=40400)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_dystack pid=30464) 	0.8689	 = Validation score   (accuracy)
# (_dystack pid=30464) 	15.86s	 = Training   runtime
# (_dystack pid=30464) 	0.18s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 501.12s of the 798.44s of remaining time.
# (_ray_fit pid=39768) Stack (most recent call first): [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 70x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=39768)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=39768)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=30464) 	0.8641	 = Validation score   (accuracy)
# (_dystack pid=30464) 	3.22s	 = Training   runtime
# (_dystack pid=30464) 	0.01s	 = Validation runtime
# (_dystack pid=30464) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 789.53s of remaining time.
# (_dystack pid=30464) 	Ensemble Weights: {'RandomForestEntr_BAG_L1': 0.5, 'NeuralNetFastAI_BAG_L1': 0.25, 'LightGBMXT_BAG_L1': 0.25}
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.29s	 = Training   runtime
# (_dystack pid=30464) 	0.0s	 = Validation runtime
# (_dystack pid=30464) Fitting 11 L2 models ...
# (_dystack pid=30464) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 789.23s of the 789.21s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.02%)
# (_dystack pid=30464) 	0.9029	 = Validation score   (accuracy)
# (_dystack pid=30464) 	10.7s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 772.99s of the 772.99s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	2.21s	 = Training   runtime
# (_dystack pid=30464) 	0.04s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBM_BAG_L2 ... Training model for up to 764.93s of the 764.91s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	2.47s	 = Training   runtime
# (_dystack pid=30464) 	0.02s	 = Validation runtime
# (_dystack pid=30464) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 756.81s of the 756.8s of remaining time.
# (_dystack pid=30464) 	0.8786	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.93s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 755.73s of the 755.72s of remaining time.
# (_dystack pid=30464) 	0.8835	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.74s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: CatBoost_BAG_L2 ... Training model for up to 754.85s of the 754.84s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	29.22s	 = Training   runtime
# (_dystack pid=30464) 	0.02s	 = Validation runtime
# (_dystack pid=30464) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 720.38s of the 720.37s of remaining time.
# (_dystack pid=30464) 	0.8689	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.78s	 = Training   runtime
# (_dystack pid=30464) 	0.1s	 = Validation runtime
# (_dystack pid=30464) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 719.46s of the 719.45s of remaining time.
# (_dystack pid=30464) 	0.8835	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.82s	 = Training   runtime
# (_dystack pid=30464) 	0.12s	 = Validation runtime
# (_dystack pid=30464) Fitting model: XGBoost_BAG_L2 ... Training model for up to 718.49s of the 718.48s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	3.52s	 = Training   runtime
# (_dystack pid=30464) 	0.04s	 = Validation runtime
# (_dystack pid=30464) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 709.89s of the 709.88s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# (_ray_fit pid=36028) Stack (most recent call first):
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 676 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\onnx\__init__.py", line 77 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\_internal\onnxruntime.py", line 36 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\onnx\__init__.py", line 59 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py", line 13 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\variables\__init__.py", line 34 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\trace_rules.py", line 50 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\convert_frame.py", line 40 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_dynamo\__init__.py", line 2 in <module>
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (_ray_fit pid=36028)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\optimizer.py", line 284 in __init__
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop
# (_ray_fit pid=36028)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module>
# (_ray_fit pid=38112)   File "<frozen importlib._bootstrap_external>
# (_ray_fit pid=38112) "
# (_ray_fit pid=38112) , line 1233 in create_module
# (_ray_fit pid=38112)   File "
# (_ray_fit pid=38112) <frozen importlib._bootstrap>
# (_ray_fit pid=38112) ", line 573 in module_from_spec
# (_ray_fit pid=38112)   File
# (_ray_fit pid=38112) "
# (_ray_fit pid=38112) <frozen importlib._bootstrap>"
# (_ray_fit pid=38112) , line
# (_ray_fit pid=38112) 1147 in
# (_ray_fit pid=38112) _find_and_load_unlocked
# (_dystack pid=30464) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=30464) 	13.57s	 = Training   runtime
# (_dystack pid=30464) 	0.26s	 = Validation runtime
# (_dystack pid=30464) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 690.9s of the 690.89s of remaining time.
# (_dystack pid=30464) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.09%)
# (_ray_fit pid=37752) Stack (most recent call first): [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed [repeated 84x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap_external>", line 1233 in create_module [repeated 6x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 573 in module_from_spec [repeated 6x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked [repeated 63x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked [repeated 69x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load [repeated 70x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\workers\default_worker.py", line 282 in <module> [repeated 63x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module [repeated 56x across cluster]
# (_ray_fit pid=37752)   File "<frozen importlib._bootstrap>", line 1232 in _handle_fromlist [repeated 14x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\_compile.py", line 22 in inner [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\optim\adam.py", line 45 in __init__ [repeated 14x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 561 in _init_optimizer [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 196 in _fit [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856 in fit [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402 in _ray_fit [repeated 7x across cluster]
# (_ray_fit pid=37752)   File "d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\ray\_private\worker.py", line 879 in main_loop [repeated 7x across cluster]
# (_dystack pid=30464) 	0.8932	 = Validation score   (accuracy)
# (_dystack pid=30464) 	4.77s	 = Training   runtime
# (_dystack pid=30464) 	0.01s	 = Validation runtime
# (_dystack pid=30464) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 680.45s of remaining time.
# (_dystack pid=30464) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.917, 'CatBoost_BAG_L1': 0.083}
# (_dystack pid=30464) 	0.9078	 = Validation score   (accuracy)
# (_dystack pid=30464) 	0.33s	 = Training   runtime
# (_dystack pid=30464) 	0.0s	 = Validation runtime
# (_dystack pid=30464) AutoGluon training complete, total runtime = 211.49s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 55.9 rows/s (26 batch size)
# (_dystack pid=30464) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241031-214904\ds_sub_fit\sub_fit_0")
# (_dystack pid=30464) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L1       0.815534   0.868932    accuracy        0.037886       0.008278   2.456223                 0.037886                0.008278           2.456223            1       True          5
# 1         LightGBMXT_BAG_L2       0.815534   0.898058    accuracy        2.443525       0.873196  63.049304                 0.020226                0.035525           2.212545            2       True         16
# 2           LightGBM_BAG_L2       0.815534   0.898058    accuracy        2.443640       0.854253  63.301799                 0.020341                0.016581           2.465040            2       True         17
# 3     ExtraTreesGini_BAG_L2       0.815534   0.868932    accuracy        2.486597       0.939167  61.620979                 0.063299                0.101496           0.784220            2       True         21
# 4   RandomForestEntr_BAG_L2       0.815534   0.883495    accuracy        2.488405       0.932721  61.578524                 0.065107                0.095049           0.741766            2       True         19
# 5   RandomForestGini_BAG_L2       0.815534   0.878641    accuracy        2.500258       0.941080  61.763564                 0.076960                0.103408           0.926805            2       True         18
# 6     ExtraTreesEntr_BAG_L2       0.815534   0.883495    accuracy        2.511554       0.954360  61.653311                 0.088256                0.116688           0.816552            2       True         22
# 7      LightGBMLarge_BAG_L2       0.805825   0.893204    accuracy        2.491669       0.850810  65.610678                 0.068371                0.013138           4.773920            2       True         25
# 8       WeightedEnsemble_L3       0.805825   0.907767    accuracy        2.602773       0.935410  71.865384                 0.000000                0.000000           0.328523            3       True         26
# 9    NeuralNetFastAI_BAG_L2       0.805825   0.902913    accuracy        2.602773       0.935410  71.536861                 0.179475                0.097739          10.700103            2       True         15
# 10           XGBoost_BAG_L2       0.805825   0.898058    accuracy        2.613106       0.877857  64.357633                 0.189808                0.040186           3.520874            2       True         23
# 11    ExtraTreesGini_BAG_L1       0.796117   0.825243    accuracy        0.090743       0.085159   0.782160                 0.090743                0.085159           0.782160            1       True          9
# 12    NeuralNetTorch_BAG_L1       0.796117   0.868932    accuracy        0.121326       0.175320  15.860241                 0.121326                0.175320          15.860241            1       True         12
# 13   NeuralNetFastAI_BAG_L1       0.796117   0.883495    accuracy        0.807165       0.088873  10.650743                 0.807165                0.088873          10.650743            1       True          3
# 14          CatBoost_BAG_L2       0.796117   0.898058    accuracy        2.457654       0.859248  90.054552                 0.034356                0.021576          29.217794            2       True         20
# 15  RandomForestGini_BAG_L1       0.786408   0.830097    accuracy        0.088591       0.101399   0.963612                 0.088591                0.101399           0.963612            1       True          6
# 16        LightGBMXT_BAG_L1       0.786408   0.854369    accuracy        0.123248       0.006338   2.991947                 0.123248                0.006338           2.991947            1       True          4
# 17           XGBoost_BAG_L1       0.786408   0.849515    accuracy        0.212066       0.009432   3.090012                 0.212066                0.009432           3.090012            1       True         11
# 18    NeuralNetTorch_BAG_L2       0.786408   0.898058    accuracy        2.604944       1.098154  74.409504                 0.181646                0.260482          13.572746            2       True         24
# 19     LightGBMLarge_BAG_L1       0.776699   0.864078    accuracy        0.033303       0.010341   3.224684                 0.033303                0.010341           3.224684            1       True         13
# 20  RandomForestEntr_BAG_L1       0.776699   0.834951    accuracy        0.064816       0.105300   0.813003                 0.064816                0.105300           0.813003            1       True          7
# 21    ExtraTreesEntr_BAG_L1       0.776699   0.825243    accuracy        0.080957       0.100008   0.754317                 0.080957                0.100008           0.754317            1       True         10
# 22          CatBoost_BAG_L1       0.776699   0.859223    accuracy        0.742617       0.001040  19.239806                 0.742617                0.001040          19.239806            1       True          8
# 23      WeightedEnsemble_L2       0.776699   0.898058    accuracy        0.995229       0.200511  14.745969                 0.000000                0.000000           0.290276            2       True         14
# 24    KNeighborsDist_BAG_L1       0.631068   0.766990    accuracy        0.010534       0.000000   0.010012                 0.010534                0.000000           0.010012            1       True          2
# 25    KNeighborsUnif_BAG_L1       0.514563   0.665049    accuracy        0.010046       0.146183   0.000000                 0.010046                0.146183           0.000000            1       True          1
# 	Starting sub-fit 2. Time limit for the sub-fit of this split is: 337.
# 		Context path: "models\Teacher\medium_quality-20241031-214904\ds_sub_fit\sub_fit_1"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestGini_BAG_L2       0.873786   0.883495    accuracy        2.514693       1.014369  58.494641                 0.077680                0.111219           1.107253            2       True         18
# 1   RandomForestEntr_BAG_L2       0.873786   0.883495    accuracy        2.519586       0.979444  58.180679                 0.082573                0.076294           0.793292            2       True         19
# 2    NeuralNetFastAI_BAG_L2       0.873786   0.893204    accuracy        2.615495       1.064625  68.683276                 0.178482                0.161475          11.295889            2       True         15
# 3         LightGBMXT_BAG_L2       0.864078   0.902913    accuracy        2.458108       0.908743  59.140211                 0.021095                0.005594           1.752824            2       True         16
# 4           CatBoost_BAG_L2       0.864078   0.927184    accuracy        2.459156       0.937301  82.836678                 0.022143                0.034151          25.449291            2       True         20
# 5       WeightedEnsemble_L3       0.864078   0.936893    accuracy        2.479561       0.955829  85.750861                 0.000000                0.002538           0.370814            3       True         26
# 6     ExtraTreesEntr_BAG_L2       0.864078   0.888350    accuracy        2.523584       0.998528  58.130146                 0.086571                0.095378           0.742758            2       True         22
# 7            XGBoost_BAG_L2       0.864078   0.883495    accuracy        2.598174       0.934020  60.674257                 0.161162                0.030870           3.286869            2       True         23
# 8     NeuralNetTorch_BAG_L2       0.864078   0.888350    accuracy        2.620637       1.131824  71.169261                 0.183624                0.228675          13.781874            2       True         24
# 9      LightGBMLarge_BAG_L2       0.854369   0.907767    accuracy        2.453750       0.908241  61.909185                 0.016738                0.005091           4.521798            2       True         25
# 10    ExtraTreesGini_BAG_L2       0.854369   0.883495    accuracy        2.537227       0.996479  58.187376                 0.100215                0.093329           0.799989            2       True         21
# 11    NeuralNetTorch_BAG_L1       0.844660   0.849515    accuracy        0.136487       0.199737  15.200205                 0.136487                0.199737          15.200205            1       True         12
# 12          LightGBM_BAG_L2       0.834951   0.902913    accuracy        2.457418       0.919140  59.930757                 0.020406                0.015990           2.543369            2       True         17
# 13          LightGBM_BAG_L1       0.825243   0.868932    accuracy        0.039324       0.020869   2.069085                 0.039324                0.020869           2.069085            1       True          5
# 14  RandomForestEntr_BAG_L1       0.825243   0.844660    accuracy        0.063475       0.085674   0.728256                 0.063475                0.085674           0.728256            1       True          7
# 15     LightGBMLarge_BAG_L1       0.825243   0.878641    accuracy        0.063569       0.008972   3.505759                 0.063569                0.008972           3.505759            1       True         13
# 16    ExtraTreesGini_BAG_L1       0.825243   0.815534    accuracy        0.113726       0.099378   0.801651                 0.113726                0.099378           0.801651            1       True          9
# 17  RandomForestGini_BAG_L1       0.815534   0.834951    accuracy        0.108554       0.105906   1.052850                 0.108554                0.105906           1.052850            1       True          6
# 18      WeightedEnsemble_L2       0.815534   0.883495    accuracy        0.177295       0.118391   4.460752                 0.000000                0.010042           0.153342            2       True         14
# 19   NeuralNetFastAI_BAG_L1       0.815534   0.859223    accuracy        0.854465       0.098245  10.689682                 0.854465                0.098245          10.689682            1       True          3
# 20    ExtraTreesEntr_BAG_L1       0.805825   0.830097    accuracy        0.089110       0.093825   0.727509                 0.089110                0.093825           0.727509            1       True         10
# 21           XGBoost_BAG_L1       0.805825   0.849515    accuracy        0.197596       0.031646   3.160444                 0.197596                0.031646           3.160444            1       True         11
# 22        LightGBMXT_BAG_L1       0.796117   0.859223    accuracy        0.090706       0.024570   2.495991                 0.090706                0.024570           2.495991            1       True          4
# 23    KNeighborsDist_BAG_L1       0.786408   0.733010    accuracy        0.016486       0.007611   0.002806                 0.016486                0.007611           0.002806            1       True          2
# 24          CatBoost_BAG_L1       0.776699   0.868932    accuracy        0.662914       0.027083  16.944422                 0.662914                0.027083          16.944422            1       True          8
# 25    KNeighborsUnif_BAG_L1       0.640777   0.577670    accuracy        0.000599       0.099633   0.008728                 0.000599                0.099633           0.008728            1       True          1
# 	Starting sub-fit 3. Time limit for the sub-fit of this split is: 463.
# 		Context path: "models\Teacher\medium_quality-20241031-214904\ds_sub_fit\sub_fit_2"
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            XGBoost_BAG_L1       0.854369   0.864078    accuracy        0.194599       0.038581   3.096950                 0.194599                0.038581           3.096950            1       True         11
# 1           LightGBM_BAG_L1       0.834951   0.883495    accuracy        0.036166       0.002002   2.344091                 0.036166                0.002002           2.344091            1       True          5
# 2       WeightedEnsemble_L2       0.834951   0.893204    accuracy        0.230766       0.040583   5.686909                 0.000000                0.000000           0.245869            2       True         14
# 3     ExtraTreesGini_BAG_L1       0.815534   0.849515    accuracy        0.092405       0.107456   0.765291                 0.092405                0.107456           0.765291            1       True          9
# 4      LightGBMLarge_BAG_L1       0.805825   0.864078    accuracy        0.034058       0.027280   3.362547                 0.034058                0.027280           3.362547            1       True         13
# 5         LightGBMXT_BAG_L1       0.805825   0.873786    accuracy        0.114685       0.025043   2.999516                 0.114685                0.025043           2.999516            1       True          4
# 6           CatBoost_BAG_L1       0.805825   0.859223    accuracy        0.665042       0.027768  14.967030                 0.665042                0.027768          14.967030            1       True          8
# 7    NeuralNetFastAI_BAG_L1       0.805825   0.873786    accuracy        0.789251       0.071426  10.842232                 0.789251                0.071426          10.842232            1       True          3
# 8   RandomForestGini_BAG_L2       0.805825   0.883495    accuracy        2.420115       0.995794  56.280740                 0.082890                0.104179           0.789550            2       True         18
# 9   RandomForestEntr_BAG_L1       0.796117   0.839806    accuracy        0.064031       0.086179   0.790899                 0.064031                0.086179           0.790899            1       True          7
# 10  RandomForestGini_BAG_L1       0.786408   0.849515    accuracy        0.092476       0.116937   1.000858                 0.092476                0.116937           1.000858            1       True          6
# 11          CatBoost_BAG_L2       0.786408   0.902913    accuracy        2.378966       0.901303  81.554030                 0.041741                0.009687          26.062840            2       True         20
# 12  RandomForestEntr_BAG_L2       0.786408   0.888350    accuracy        2.415290       0.984654  56.182398                 0.078064                0.093038           0.691207            2       True         19
# 13    NeuralNetTorch_BAG_L2       0.786408   0.883495    accuracy        2.539632       1.094922  78.978791                 0.202406                0.203306          23.487600            2       True         24
# 14   NeuralNetFastAI_BAG_L2       0.786408   0.907767    accuracy        2.567276       1.006767  66.257944                 0.230051                0.115152          10.766753            2       True         15
# 15     LightGBMLarge_BAG_L2       0.776699   0.912621    accuracy        2.348386       0.904719  60.941327                 0.011161                0.013104           5.450136            2       True         25
# 16          LightGBM_BAG_L2       0.776699   0.912621    accuracy        2.360366       0.895616  58.129534                 0.023141                0.004001           2.638343            2       True         17
# 17      WeightedEnsemble_L3       0.776699   0.917476    accuracy        2.402107       0.905303  84.568831                 0.000000                0.000000           0.376457            3       True         26
# 18    ExtraTreesGini_BAG_L2       0.776699   0.888350    accuracy        2.404708       1.001324  56.215379                 0.067482                0.109709           0.724188            2       True         21
# 19    ExtraTreesEntr_BAG_L2       0.776699   0.883495    accuracy        2.424132       0.984170  56.292663                 0.086906                0.092555           0.801472            2       True         22
# 20           XGBoost_BAG_L2       0.776699   0.912621    accuracy        2.507362       0.934270  58.991238                 0.170137                0.042655           3.500047            2       True         23
# 21    ExtraTreesEntr_BAG_L1       0.766990   0.864078    accuracy        0.089152       0.088517   0.842559                 0.089152                0.088517           0.842559            1       True         10
# 22    NeuralNetTorch_BAG_L1       0.757282   0.825243    accuracy        0.136247       0.178883  14.469705                 0.136247                0.178883          14.469705            1       True         12
# 23        LightGBMXT_BAG_L2       0.747573   0.902913    accuracy        2.357596       0.914999  57.630558                 0.020371                0.023383           2.139368            2       True         16
# 24    KNeighborsDist_BAG_L1       0.699029   0.747573    accuracy        0.019029       0.003059   0.003515                 0.019029                0.003059           0.003515            1       True          2
# 25    KNeighborsUnif_BAG_L1       0.563107   0.635922    accuracy        0.010084       0.118485   0.005998                 0.010084                0.118485           0.005998            1       True          1
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	658s	 = DyStack   runtime |	2942s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2942s
# AutoGluon will save models to "models\Teacher\medium_quality-20241031-214904"
# Train Data Rows:    309
# Train Data Columns: 36
# Label Column:       label
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6269.87 MB
# 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# 	0.1s = Fit runtime
# 	36 features in original data used to generate 36 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.28s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2941.75s of the 2941.75s of remaining time.
# 	0.6861	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2938.4s of the 2938.39s of remaining time.
# 	0.7994	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2938.36s of the 2938.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.9029	 = Validation score   (accuracy)
# 	9.54s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2923.41s of the 2923.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	0.8932	 = Validation score   (accuracy)
# 	4.02s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2913.37s of the 2913.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	0.8964	 = Validation score   (accuracy)
# 	2.64s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2905.02s of the 2905.01s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2903.91s of the 2903.91s of remaining time.
# 	0.8641	 = Validation score   (accuracy)
# 	0.8s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2902.97s of the 2902.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.8738	 = Validation score   (accuracy)
# 	25.26s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2872.29s of the 2872.28s of remaining time.
# 	0.89	 = Validation score   (accuracy)
# 	0.75s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2871.42s of the 2871.41s of remaining time.
# 	0.8964	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2870.52s of the 2870.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.8835	 = Validation score   (accuracy)
# 	3.47s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2861.71s of the 2861.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.01%)
# 	0.8835	 = Validation score   (accuracy)
# 	25.18s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2830.94s of the 2830.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8997	 = Validation score   (accuracy)
# 	5.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2819.95s of remaining time.
# 	Ensemble Weights: {'ExtraTreesGini_BAG_L1': 0.667, 'NeuralNetFastAI_BAG_L1': 0.333}
# 	0.9159	 = Validation score   (accuracy)
# 	0.18s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 122.29s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 253.8 rows/s (39 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models\Teacher\medium_quality-20241031-214904")

# %% [markdown]
# #### 将基础信息写入文件保存

# %%
# 在模型目录中写入程序运行信息和数据预处理的基础信息
with open(save_path + '/model_info.txt', 'w') as f:
    f.writelines('--- Program Setup Info ---')
    f.writelines(f'\nmin_cells_per_type:{min_cells_per_type}')
    f.writelines(f'\ncell_subset:  {cell_subset}')
    f.writelines(f'\nmodality:     {modality}')
    f.writelines(f'\ntaxonomy:     {taxonomy}')
    f.writelines(f'\ndataset:      {labeled_data.shape}')
    f.writelines(f'\ntrain_data:   {X_train.shape}')
    f.writelines(f'\ntrain_label:  {np.unique(y_train)}')
    f.writelines(f'\ntest_data:    {X_test.shape}')
    f.writelines(f'\ntest_label:   {np.unique(y_test)}')
    f.writelines(f'\npresets:      {presets}')
    f.writelines('\n--- End of Program Setup Info ---')

# %% [markdown]
# #### 加载保存的模型的方法

# %%
# 加载以前训练结果，可用于查看以前的参数和使用以前训练的模型进行预测
#predictor_path = "models\Teacher\medium_quality-20241008-171554"
#predictor = TabularPredictor.load(predictor_path)

# %% [markdown]
# #### 显示训练结果信息

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
print("Best Model:", predictor.model_best)
result = predictor.fit_summary(show_plot=True)
# Out:
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# Best Model: WeightedEnsemble_L2
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L2   0.915858    accuracy       0.230767  10.462600                0.000000           0.175867            2       True         14
# 1    NeuralNetFastAI_BAG_L1   0.902913    accuracy       0.142537   9.539016                0.142537           9.539016            1       True          3
# 2      LightGBMLarge_BAG_L1   0.899676    accuracy       0.027272   5.324706                0.027272           5.324706            1       True         13
# 3           LightGBM_BAG_L1   0.896440    accuracy       0.028132   2.637169                0.028132           2.637169            1       True          5
# 4     ExtraTreesEntr_BAG_L1   0.896440    accuracy       0.094240   0.757924                0.094240           0.757924            1       True         10
# 5         LightGBMXT_BAG_L1   0.893204    accuracy       0.035384   4.021726                0.035384           4.021726            1       True          4
# 6     ExtraTreesGini_BAG_L1   0.889968    accuracy       0.088229   0.747717                0.088229           0.747717            1       True          9
# 7            XGBoost_BAG_L1   0.883495    accuracy       0.041190   3.473365                0.041190           3.473365            1       True         11
# 8     NeuralNetTorch_BAG_L1   0.883495    accuracy       0.156438  25.178305                0.156438          25.178305            1       True         12
# 9           CatBoost_BAG_L1   0.873786    accuracy       0.017014  25.264824                0.017014          25.264824            1       True          8
# 10  RandomForestGini_BAG_L1   0.864078    accuracy       0.092353   0.960024                0.092353           0.960024            1       True          6
# 11  RandomForestEntr_BAG_L1   0.864078    accuracy       0.092600   0.802094                0.092600           0.802094            1       True          7
# 12    KNeighborsDist_BAG_L1   0.799353    accuracy       0.000000   0.016657                0.000000           0.016657            1       True          2
# 13    KNeighborsUnif_BAG_L1   0.686084    accuracy       0.313280   0.007509                0.313280           0.007509            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 36 | ['input_resistance', 'sag', 'VmatSag', 'vmbaseM', 'tau', ...]
# *** End of fit() summary ***
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %% [markdown]
# ### 5.2 利用教师模型对测试集预测

# %% [markdown]
# #### Best model 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel)#,model=predictor.model_best)
print(predictor.model_best)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
# WeightedEnsemble_L2
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.64      0.60      0.62        15
# Exc L2-3 LINC00507 FREM3 superficial       0.79      0.88      0.84        26
#             Exc L2-4 LINC00507 GLP2R       1.00      0.60      0.75         5
#
#                             accuracy                           0.76        46
#                            macro avg       0.81      0.69      0.74        46
#                         weighted avg       0.77      0.76      0.76        46

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'], labels=t_types_updated)
print(cfm)
#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()
# Out:
# [[ 9  6  0]
#  [ 3 23  0]
#  [ 2  0  3]]

# %% [markdown]
# #### 显示各个类别预测概率

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba
# Out:
#     Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0           0.526007                              0.433888
# 1           0.173638                              0.791389
# 2           0.439676                              0.255070
# 3           0.340058                              0.548448
# 4           0.078229                              0.907460
# 5           0.240538                              0.681828
# 6           0.360500                              0.601447
# 7           0.067686                              0.841708
# 8           0.180622                              0.579435
# 9           0.542363                              0.341549
# 10          0.713275                              0.267348
# 11          0.208923                              0.326138
# 12          0.539123                              0.384879
# 13          0.206488                              0.623383
# 14          0.088261                              0.660233
# 15          0.312736                              0.461630
# 16          0.315247                              0.624114
# 17          0.219767                              0.568650
# 18          0.219985                              0.521284
# 19          0.524242                              0.404209
# 20          0.168132                              0.234369
# 21          0.504771                              0.440228
# 22          0.170248                              0.763053
# 23          0.145251                              0.826098
# 24          0.566470                              0.299341
# 25          0.434723                              0.431488
# 26          0.724436                              0.209353
# 27          0.262177                              0.707387
# 28          0.125922                              0.678697
# 29          0.474297                              0.452918
# 30          0.670186                              0.213177
# 31          0.096913                              0.877459
# 32          0.033169                              0.938873
# 33          0.239111                              0.679154
# 34          0.097100                              0.782864
# 35          0.424719                              0.401367
# 36          0.368087                              0.358581
# 37          0.128013                              0.757171
# 38          0.145930                              0.739630
# 39          0.035510                              0.921398
# 40          0.359268                              0.248342
# 41          0.205144                              0.661415
# 42          0.202410                              0.653539
# 43          0.378689                              0.427743
# 44          0.245445                              0.646073
# 45          0.163761                              0.655780
#
#     Exc L2-4 LINC00507 GLP2R
# 0                   0.040105
# 1                   0.034973
# 2                   0.305254
# 3                   0.111493
# 4                   0.014311
# 5                   0.077634
# 6                   0.038053
# 7                   0.090606
# 8                   0.239942
# 9                   0.116088
# 10                  0.019377
# 11                  0.464939
# 12                  0.075998
# 13                  0.170129
# 14                  0.251506
# 15                  0.225634
# 16                  0.060639
# 17                  0.211583
# 18                  0.258731
# 19                  0.071548
# 20                  0.597499
# 21                  0.055002
# 22                  0.066699
# 23                  0.028651
# 24                  0.134189
# 25                  0.133790
# 26                  0.066211
# 27                  0.030436
# 28                  0.195381
# 29                  0.072785
# 30                  0.116637
# 31                  0.025628
# 32                  0.027958
# 33                  0.081735
# 34                  0.120036
# 35                  0.173914
# 36                  0.273332
# 37                  0.114816
# 38                  0.114440
# 39                  0.043092
# 40                  0.392390
# 41                  0.133441
# 42                  0.144051
# 43                  0.193568
# 44                  0.108483
# 45                  0.180458

# %% [markdown]
# #### 模型解释：特征重要性

# %%
print(predictor.feature_importance(test_data))
# Out:
# Computing feature importance via permutation shuffling for 36 features using 46 rows with 5 shuffle sets...
# 	38.86s	= Expected runtime (7.77s per shuffle set)
# 	2.35s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                         importance    stddev   p_value  n  p99_high   p99_low
# L23_depth_normalized  1.043478e-01  0.038888  0.001941  5  0.184419  0.024277
# FAP_rheobase          1.000000e-01  0.045079  0.003852  5  0.192819  0.007181
# tau                   6.086957e-02  0.009722  0.000076  5  0.080887  0.040852
# TS2_avg_upstroke      5.652174e-02  0.019444  0.001445  5  0.096557  0.016486
# FAP_maxdownstroke     5.217391e-02  0.011907  0.000304  5  0.076691  0.027657
# input_resistance      5.217391e-02  0.024786  0.004631  5  0.103209  0.001138
# VmatSag               5.217391e-02  0.011907  0.000304  5  0.076691  0.027657
# TS2_rheobase          4.782609e-02  0.023814  0.005450  5  0.096859 -0.001207
# TS2_up_down_ratio     4.782609e-02  0.028344  0.009777  5  0.106188 -0.010535
# FAP_threshold         4.347826e-02  0.015372  0.001599  5  0.075129  0.011827
# TS2_maxupstroke       3.913043e-02  0.023814  0.010656  5  0.088164 -0.009903
# FAP_avg_downstroke    3.913043e-02  0.028344  0.018341  5  0.097492 -0.019231
# FAP_num_APs           3.478261e-02  0.019444  0.008065  5  0.074818 -0.005253
# FAP_peak              3.478261e-02  0.011907  0.001419  5  0.059299  0.010266
# TS2_adp_index         3.478261e-02  0.032969  0.038871  5  0.102666 -0.033101
# TS1_avg_downstroke    3.043478e-02  0.024786  0.025803  5  0.081470 -0.020601
# TS1_threshold         3.043478e-02  0.024786  0.025803  5  0.081470 -0.020601
# FAP_halfwidth         2.608696e-02  0.018188  0.016339  5  0.063537 -0.011363
# sag                   2.608696e-02  0.018188  0.016339  5  0.063537 -0.011363
# TS1_halfwidth         2.173913e-02  0.000000  0.500000  5  0.021739  0.021739
# vmbaseM               2.173913e-02  0.021739  0.044505  5  0.066500 -0.023022
# TS1_num_APs           1.739130e-02  0.028344  0.120991  5  0.075753 -0.040970
# TS1_rheobase          1.739130e-02  0.018188  0.049650  5  0.054841 -0.020059
# TS2_avg_downstroke    1.739130e-02  0.018188  0.049650  5  0.054841 -0.020059
# TS1_maxupstroke       8.695652e-03  0.019444  0.186950  5  0.048731 -0.031340
# TS1_adp_index         8.695652e-03  0.011907  0.088904  5  0.033212 -0.015821
# TS1_up_down_ratio     8.695652e-03  0.011907  0.088904  5  0.033212 -0.015821
# TS1_maxdownstroke     4.347826e-03  0.028344  0.374434  5  0.062709 -0.054014
# FAP_maxupstroke       4.347826e-03  0.009722  0.186950  5  0.024366 -0.015670
# TS2_threshold         4.440892e-17  0.021739  0.500000  5  0.044761 -0.044761
# TS1_avg_upstroke      2.220446e-17  0.015372  0.500000  5  0.031651 -0.031651
# TS2_maxdownstroke     0.000000e+00  0.000000  0.500000  5  0.000000  0.000000
# TS2_num_APs          -4.347826e-03  0.009722  0.813050  5  0.015670 -0.024366
# FAP_up_down_ratio    -4.347826e-03  0.009722  0.813050  5  0.015670 -0.024366
# TS2_peak             -8.695652e-03  0.011907  0.911096  5  0.015821 -0.033212
# FAP_avg_upstroke     -8.695652e-03  0.011907  0.911096  5  0.015821 -0.033212

# %% [markdown]
# #### 评估教师模型性能
# <font color='Red'>这里也可以查看混淆矩阵</font>

# %%
# Evaluate the predictor (optional)
eval_result = predictor.evaluate(test_data, display=False, detailed_report=True)
print(predictor.model_best)
eval_result
# Out:
# WeightedEnsemble_L2
# {'accuracy': 0.7608695652173914,
#  'balanced_accuracy': 0.694871794871795,
#  'mcc': 0.5591959144007389,
#  'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
#  Exc L2 LAMP5 LTK                                     9
#  Exc L2-3 LINC00507 FREM3 superficial                 3
#  Exc L2-4 LINC00507 GLP2R                             2
#
#                                        Exc L2-3 LINC00507 FREM3 superficial  \
#  Exc L2 LAMP5 LTK                                                         6
#  Exc L2-3 LINC00507 FREM3 superficial                                    23
#  Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                        Exc L2-4 LINC00507 GLP2R
#  Exc L2 LAMP5 LTK                                             0
#  Exc L2-3 LINC00507 FREM3 superficial                         0
#  Exc L2-4 LINC00507 GLP2R                                     3  ,
#  'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6428571428571429,
#    'recall': 0.6,
#    'f1-score': 0.6206896551724138,
#    'support': 15.0},
#   'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7931034482758621,
#    'recall': 0.8846153846153846,
#    'f1-score': 0.8363636363636363,
#    'support': 26.0},
#   'Exc L2-4 LINC00507 GLP2R': {'precision': 1.0,
#    'recall': 0.6,
#    'f1-score': 0.75,
#    'support': 5.0},
#   'accuracy': 0.7608695652173914,
#   'macro avg': {'precision': 0.8119868637110016,
#    'recall': 0.694871794871795,
#    'f1-score': 0.7356844305120167,
#    'support': 46.0},
#   'weighted avg': {'precision': 0.7665988434354252,
#    'recall': 0.7608695652173914,
#    'f1-score': 0.7566478124574075,
#    'support': 46.0}}}

# %% [markdown]
# #### 查看不同模型的评估指标
# **注:**
# **‘f1’, ‘recall’, ‘precision’, ‘roc_auc’ 是针对二分类问题的，多分类使用‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’**
#
# options for classification:
# [‘accuracy’, ‘balanced_accuracy’, ‘f1’, ‘f1_macro’, ‘f1_micro’, ‘f1_weighted’, ‘roc_auc’, ‘roc_auc_ovo_macro’, ‘average_precision’, ‘precision’, ‘precision_macro’, ‘precision_micro’, ‘precision_weighted’, ‘recall’, ‘recall_macro’, ‘recall_micro’, ‘recall_weighted’, ‘log_loss’, ‘pac_score’]
#
# Options for regression:
# [‘root_mean_squared_error’, ‘mean_squared_error’, ‘mean_absolute_error’, ‘median_absolute_error’, ‘mean_absolute_percentage_error’, ‘r2’, ‘symmetric_mean_absolute_percentage_error’]

# %%
# Get leaderboard of models (optional)
leaderboard = predictor.leaderboard(test_data,extra_info=False, silent=True)

# Access predictions and evaluation results as needed
print(leaderboard)
#leaderboard.to_csv('leaderboard_medium.csv')
# Out:
#                       model  score_test  score_val eval_metric  \
# 0       WeightedEnsemble_L2    0.760870   0.915858    accuracy
# 1    NeuralNetFastAI_BAG_L1    0.739130   0.902913    accuracy
# 2     ExtraTreesGini_BAG_L1    0.717391   0.889968    accuracy
# 3   RandomForestGini_BAG_L1    0.717391   0.864078    accuracy
# 4           LightGBM_BAG_L1    0.695652   0.896440    accuracy
# 5   RandomForestEntr_BAG_L1    0.695652   0.864078    accuracy
# 6     ExtraTreesEntr_BAG_L1    0.695652   0.896440    accuracy
# 7           CatBoost_BAG_L1    0.673913   0.873786    accuracy
# 8      LightGBMLarge_BAG_L1    0.673913   0.899676    accuracy
# 9         LightGBMXT_BAG_L1    0.673913   0.893204    accuracy
# 10    NeuralNetTorch_BAG_L1    0.673913   0.883495    accuracy
# 11           XGBoost_BAG_L1    0.652174   0.883495    accuracy
# 12    KNeighborsUnif_BAG_L1    0.391304   0.686084    accuracy
# 13    KNeighborsDist_BAG_L1    0.391304   0.799353    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.232414       0.230767  10.462600                 0.000000
# 1         0.153701       0.142537   9.539016                 0.153701
# 2         0.078713       0.088229   0.747717                 0.078713
# 3         0.089575       0.092353   0.960024                 0.089575
# 4         0.066361       0.028132   2.637169                 0.066361
# 5         0.066457       0.092600   0.802094                 0.066457
# 6         0.072799       0.094240   0.757924                 0.072799
# 7         0.069630       0.017014  25.264824                 0.069630
# 8         0.094116       0.027272   5.324706                 0.094116
# 9         0.123088       0.035384   4.021726                 0.123088
# 10        0.147077       0.156438  25.178305                 0.147077
# 11        0.187714       0.041190   3.473365                 0.187714
# 12        0.005015       0.313280   0.007509                 0.005015
# 13        0.005594       0.000000   0.016657                 0.005594
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000000           0.175867            2       True
# 1                 0.142537           9.539016            1       True
# 2                 0.088229           0.747717            1       True
# 3                 0.092353           0.960024            1       True
# 4                 0.028132           2.637169            1       True
# 5                 0.092600           0.802094            1       True
# 6                 0.094240           0.757924            1       True
# 7                 0.017014          25.264824            1       True
# 8                 0.027272           5.324706            1       True
# 9                 0.035384           4.021726            1       True
# 10                0.156438          25.178305            1       True
# 11                0.041190           3.473365            1       True
# 12                0.313280           0.007509            1       True
# 13                0.000000           0.016657            1       True
#
#     fit_order
# 0          14
# 1           3
# 2           9
# 3           6
# 4           5
# 5           7
# 6          10
# 7           8
# 8          13
# 9           4
# 10         12
# 11         11
# 12          1
# 13          2

# %% [markdown]
# ## 6. 利用教师模型预测未标记数据集

# %%
y_pred = predictor.predict(unlabeled_data.iloc[:,0:-1])
unlabeled_data.iloc[:,-1] = y_pred
y_pred
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_36672\2002465791.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207                        Exc L2 LAMP5 LTK
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   unlabeled_data.iloc[:,-1] = y_pred
# 0      Exc L2-3 LINC00507 FREM3 superficial
# 1      Exc L2-3 LINC00507 FREM3 superficial
# 2      Exc L2-3 LINC00507 FREM3 superficial
# 3      Exc L2-3 LINC00507 FREM3 superficial
# 4      Exc L2-3 LINC00507 FREM3 superficial
#                        ...
# 204                        Exc L2 LAMP5 LTK
# 205    Exc L2-3 LINC00507 FREM3 superficial
# 206    Exc L2-3 LINC00507 FREM3 superficial
# 207                        Exc L2 LAMP5 LTK
# 208    Exc L2-3 LINC00507 FREM3 superficial
# Name: label, Length: 209, dtype: object

# %% [markdown]
# ### 查看预测概率

# %%
y_pred_proba = predictor.predict_proba(unlabeled_data.iloc[:,0:-1])
y_pred_proba
# Out:
#      Exc L2 LAMP5 LTK  Exc L2-3 LINC00507 FREM3 superficial  \
# 0            0.092898                              0.884836
# 1            0.042696                              0.934666
# 2            0.107360                              0.784830
# 3            0.152046                              0.748788
# 4            0.181433                              0.773402
# ..                ...                                   ...
# 204          0.479653                              0.279363
# 205          0.122044                              0.824025
# 206          0.296404                              0.605250
# 207          0.518437                              0.430615
# 208          0.165819                              0.709758
#
#      Exc L2-4 LINC00507 GLP2R
# 0                    0.022266
# 1                    0.022638
# 2                    0.107810
# 3                    0.099165
# 4                    0.045165
# ..                        ...
# 204                  0.240985
# 205                  0.053931
# 206                  0.098346
# 207                  0.050948
# 208                  0.124423
#
# [209 rows x 3 columns]

# %% [markdown]
# #### 观察unlabel数据预测概率的分布情况

# %%
y_pred_proba.max(axis=1).sort_values().to_frame().boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### 过滤unlabeled数据, 用于知识蒸馏

# %%
# 如果使用descibe的方式过滤可取以下值
proba_threshold = '25%' # '25%', '50%', '75%', 'mean'
idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).describe()[proba_threshold]].index
# 如果使用median函数计算的方式过滤使用以下方法
# idx_filted = y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>=y_pred_proba.max(axis=1).median()].index
#proba_list_75=y_pred_proba.max(axis=1)[y_pred_proba.max(axis=1)>y_pred_proba.max(axis=1).describe()['75%']]
#proba_list_50_25=y_pred_proba.max(axis=1)[proba_list.between(y_pred_proba.max(axis=1).describe()['25%'],y_pred_proba.max(axis=1)<y_pred_proba.max(axis=1).describe()['50%'])]
#idx_filted =pd.concat([proba_list_75,proba_list_50_25]).index


new_unlabeled_data=pd.concat([unlabeled_data.loc[idx_filted,:],unlabeled_data[unlabeled_data.iloc[:,-1]!='Exc L2-3 LINC00507 FREM3 superficial']])

new_unlabeled_data.shape
# Out:
# (159, 37)

# %%
plt.figure(figsize=(10,4))
new_unlabeled_data[LABEL_COLUMN].value_counts().plot(kind='bar')
# 为条形图添加数值标签
plt.bar_label(plt.gca().containers[0])
plt.title('Number of samples per classification', fontsize=14)
plt.xticks(rotation=30,fontsize=8)
plt.show()

# %% [markdown]
# ## 8.利用训练的教师模型和未标注的数据集蒸馏学生模型
# **待确认的问题：**
# **1.teacher_preds参数的含义有待确认**
# **2.augment_method参数对于训练结果的影响，需要实验去确认,关于munge参数的内容，可阅读https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf**
# **3.Knowledge Distillation in AutoMM这篇文章（见参考信息2）的调用方法与此不同，有待测试**
# PARAMETERS:
# 1. train_data (str or or , default = None) – Same as train_data argument of fit(). If None, the same training data will be loaded from fit() call used to produce this Predictor.TabularDatasetpd.DataFrame
# 2. tuning_data (str or or , default = None) – Same as tuning_data argument of fit(). If tuning_data = None and train_data = None: the same training/validation splits will be loaded from fit() call used to produce this Predictor, unless bagging/stacking was previously used in which case a new training/validation split is performed.TabularDatasetpd.DataFrame
# 3. augmentation_data ( or , default = None) – An optional extra dataset of unlabeled rows that can be used for augmenting the dataset used to fit student models during distillation (ignored if None).TabularDatasetpd.DataFrame
# 4. holdout_frac (float) – Same as holdout_frac argument of TabularPredictor.fit().
# 5. teacher_preds (str, default = 'soft') – What form of teacher predictions to distill from (teacher refers to the most accurate AutoGluon ensemble-predictor). If None, we only train with original labels (no data augmentation). If ‘hard’, labels are hard teacher predictions given by: teacher.predict() If ‘soft’, labels are soft teacher predictions given by: teacher.predict_proba() Note: ‘hard’ and ‘soft’ are equivalent for regression problems. If augment_method is not None, teacher predictions are only used to label augmented data (training data keeps original labels). To apply label-smoothing: teacher_preds=’onehot’ will use original training data labels converted to one-hot vectors for multiclass problems (no data augmentation).
# 6. augment_method (str, default='spunge') –Specifies method to use for generating augmented data for distilling student models. Options include:None : no data augmentation performed.
# ‘munge’ : The MUNGE algorithm (https://www.cs.cornell.edu/~caruana/compression.kdd06.pdf).
# ‘spunge’ : A simpler, more efficient variant of the MUNGE algorithm.
# 7. verbosity (int, default = None) – Controls amount of printed output during distillation (4 = highest, 0 = lowest). Same as verbosity parameter of TabularPredictor. If None, the same verbosity used in previous fit is employed again.
# #### 参考信息：
# 1. https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.distill.html
# 2. https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/model_distillation.html

# %% [markdown]
# ### <font color=Red>第一次蒸馏</font>

# %%
augmentation_data = unlabeled_data.iloc[:,0:-1]

teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_DSTL ...
# [50]	valid_set's soft_log_loss: -0.526016
# [100]	valid_set's soft_log_loss: -0.433132
# [150]	valid_set's soft_log_loss: -0.431963
# [200]	valid_set's soft_log_loss: -0.438023
# [250]	valid_set's soft_log_loss: -0.465177
# [300]	valid_set's soft_log_loss: -0.50105
# [350]	valid_set's soft_log_loss: -0.512735
# [400]	valid_set's soft_log_loss: -0.514036
# 	Note: model has different eval_metric than default.
# 	-0.4299	 = Validation score   (-soft_log_loss)
# 	1.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE_DSTL ...
# 	Note: model has different eval_metric than default.
# 	-0.4716	 = Validation score   (-soft_log_loss)
# 	0.85s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0691675	test: -1.0838388	best: -1.0838388 (0)	total: 1.05s	remaining: 2h 55m 4s
# 20:	learn: -0.7547554	test: -0.8144060	best: -0.8144060 (20)	total: 1.41s	remaining: 11m 10s
# 40:	learn: -0.6396762	test: -0.7048046	best: -0.7048046 (40)	total: 1.78s	remaining: 7m 12s
# 60:	learn: -0.5729793	test: -0.6295757	best: -0.6295757 (60)	total: 2.16s	remaining: 5m 51s
# 80:	learn: -0.5363737	test: -0.5925245	best: -0.5925245 (80)	total: 2.53s	remaining: 5m 10s
# 100:	learn: -0.5044590	test: -0.5580505	best: -0.5580505 (100)	total: 2.9s	remaining: 4m 44s
# 120:	learn: -0.4799798	test: -0.5324237	best: -0.5324237 (120)	total: 3.23s	remaining: 4m 23s
# 140:	learn: -0.4635352	test: -0.5113601	best: -0.5113601 (140)	total: 3.6s	remaining: 4m 11s
# 160:	learn: -0.4481031	test: -0.4957254	best: -0.4957254 (160)	total: 3.96s	remaining: 4m 1s
# 180:	learn: -0.4337035	test: -0.4821311	best: -0.4821311 (180)	total: 4.31s	remaining: 3m 53s
# 200:	learn: -0.4226586	test: -0.4682249	best: -0.4682249 (200)	total: 4.69s	remaining: 3m 48s
# 220:	learn: -0.4137214	test: -0.4622533	best: -0.4622533 (220)	total: 5.06s	remaining: 3m 43s
# 240:	learn: -0.4055766	test: -0.4558579	best: -0.4557357 (238)	total: 5.39s	remaining: 3m 38s
# 260:	learn: -0.3992736	test: -0.4474385	best: -0.4473559 (258)	total: 5.72s	remaining: 3m 33s
# 280:	learn: -0.3933289	test: -0.4416247	best: -0.4416104 (279)	total: 6.05s	remaining: 3m 29s
# 300:	learn: -0.3876744	test: -0.4365248	best: -0.4365248 (300)	total: 6.42s	remaining: 3m 26s
# 320:	learn: -0.3826200	test: -0.4342330	best: -0.4338320 (317)	total: 6.79s	remaining: 3m 24s
# 340:	learn: -0.3781252	test: -0.4310953	best: -0.4302004 (334)	total: 7.14s	remaining: 3m 22s
# 360:	learn: -0.3741908	test: -0.4284793	best: -0.4284793 (360)	total: 7.5s	remaining: 3m 20s
# 380:	learn: -0.3705230	test: -0.4273326	best: -0.4262183 (376)	total: 7.84s	remaining: 3m 18s
# 400:	learn: -0.3673710	test: -0.4255888	best: -0.4255888 (400)	total: 8.18s	remaining: 3m 15s
# 420:	learn: -0.3640536	test: -0.4235902	best: -0.4228174 (417)	total: 8.51s	remaining: 3m 13s
# 440:	learn: -0.3611741	test: -0.4218679	best: -0.4218211 (432)	total: 8.82s	remaining: 3m 11s
# 460:	learn: -0.3586545	test: -0.4190479	best: -0.4190479 (460)	total: 9.13s	remaining: 3m 9s
# 480:	learn: -0.3559547	test: -0.4186787	best: -0.4185050 (478)	total: 9.46s	remaining: 3m 7s
# 500:	learn: -0.3540439	test: -0.4172483	best: -0.4172483 (500)	total: 9.82s	remaining: 3m 6s
# 520:	learn: -0.3520364	test: -0.4173245	best: -0.4162475 (506)	total: 10.2s	remaining: 3m 4s
# 540:	learn: -0.3502469	test: -0.4156129	best: -0.4153366 (538)	total: 10.5s	remaining: 3m 3s
# 560:	learn: -0.3483110	test: -0.4157178	best: -0.4148389 (542)	total: 10.8s	remaining: 3m 2s
# 580:	learn: -0.3466915	test: -0.4156151	best: -0.4144642 (570)	total: 11.2s	remaining: 3m 1s
# 600:	learn: -0.3454182	test: -0.4147414	best: -0.4144642 (570)	total: 11.5s	remaining: 2m 59s
# 620:	learn: -0.3438619	test: -0.4143197	best: -0.4130776 (613)	total: 11.8s	remaining: 2m 58s
# 640:	learn: -0.3425813	test: -0.4122406	best: -0.4117657 (635)	total: 12.2s	remaining: 2m 57s
# 660:	learn: -0.3412838	test: -0.4124545	best: -0.4116843 (650)	total: 12.5s	remaining: 2m 56s
# 680:	learn: -0.3403030	test: -0.4112249	best: -0.4109461 (678)	total: 12.9s	remaining: 2m 55s
# 700:	learn: -0.3390514	test: -0.4129404	best: -0.4106793 (683)	total: 13.2s	remaining: 2m 54s
# 720:	learn: -0.3380505	test: -0.4130591	best: -0.4106793 (683)	total: 13.5s	remaining: 2m 53s
# 740:	learn: -0.3369458	test: -0.4139738	best: -0.4106793 (683)	total: 13.9s	remaining: 2m 53s
# 760:	learn: -0.3360345	test: -0.4137181	best: -0.4106793 (683)	total: 14.2s	remaining: 2m 52s
# 780:	learn: -0.3352763	test: -0.4143716	best: -0.4106793 (683)	total: 14.5s	remaining: 2m 51s
# 800:	learn: -0.3344597	test: -0.4130176	best: -0.4106793 (683)	total: 14.9s	remaining: 2m 51s
# 820:	learn: -0.3335681	test: -0.4139140	best: -0.4106793 (683)	total: 15.3s	remaining: 2m 50s
# 840:	learn: -0.3329088	test: -0.4149172	best: -0.4106793 (683)	total: 15.6s	remaining: 2m 49s
# 860:	learn: -0.3322093	test: -0.4147796	best: -0.4106793 (683)	total: 15.9s	remaining: 2m 49s
# 880:	learn: -0.3315273	test: -0.4148691	best: -0.4106793 (683)	total: 16.3s	remaining: 2m 48s
# 900:	learn: -0.3307837	test: -0.4170246	best: -0.4106793 (683)	total: 16.6s	remaining: 2m 48s
# 920:	learn: -0.3302575	test: -0.4172960	best: -0.4106793 (683)	total: 17s	remaining: 2m 47s
# 940:	learn: -0.3297385	test: -0.4182786	best: -0.4106793 (683)	total: 17.4s	remaining: 2m 47s
# 960:	learn: -0.3292301	test: -0.4167158	best: -0.4106793 (683)	total: 17.7s	remaining: 2m 46s
# 	Note: model has different eval_metric than default.
# 	-0.4107	 = Validation score   (-soft_log_loss)
# 	19.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ...
# 980:	learn: -0.3286678	test: -0.4168428	best: -0.4106793 (683)	total: 18s	remaining: 2m 45s
#
# bestTest = -0.410679281
# bestIteration = 683
#
# Shrink model to first 684 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.549	 = Validation score   (-soft_log_loss)
# 	26.38s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_DSTL': 0.619, 'LightGBM_DSTL': 0.381}
# 	Note: model has different eval_metric than default.
# 	-0.4014	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM_DSTL   0.854839  soft_log_loss       0.000000   1.232379                0.000000           1.232379            1       True         15
# 1  WeightedEnsemble_L2_DSTL   0.838710  soft_log_loss       0.003028  20.736611                0.000000           0.033284            2       True         19
# 2             CatBoost_DSTL   0.822581  soft_log_loss       0.003028  19.470948                0.003028          19.470948            1       True         17
# 3      RandomForestMSE_DSTL   0.822581  soft_log_loss       0.065165   0.849490                0.065165           0.849490            1       True         16
# 4       NeuralNetTorch_DSTL   0.806452  soft_log_loss       0.031252  26.381263                0.031252          26.381263            1       True         18
# ['LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']

# %% [markdown]
# ### 8.1 蒸馏后的学生模型的评估效果

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_val','score_test'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
# Out:
# 按测试集分数对所有模型排序：
#                        model  score_test  score_val    eval_metric  \
# 0        WeightedEnsemble_L2    0.760870   0.915858       accuracy
# 2     NeuralNetFastAI_BAG_L1    0.739130   0.902913       accuracy
# 13      LightGBMLarge_BAG_L1    0.673913   0.899676       accuracy
# 7            LightGBM_BAG_L1    0.695652   0.896440       accuracy
# 10     ExtraTreesEntr_BAG_L1    0.695652   0.896440       accuracy
# 12         LightGBMXT_BAG_L1    0.673913   0.893204       accuracy
# 6      ExtraTreesGini_BAG_L1    0.717391   0.889968       accuracy
# 14     NeuralNetTorch_BAG_L1    0.673913   0.883495       accuracy
# 16            XGBoost_BAG_L1    0.652174   0.883495       accuracy
# 11           CatBoost_BAG_L1    0.673913   0.873786       accuracy
# 5    RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 8    RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 3              LightGBM_DSTL    0.717391   0.854839  soft_log_loss
# 4   WeightedEnsemble_L2_DSTL    0.717391   0.838710  soft_log_loss
# 1              CatBoost_DSTL    0.739130   0.822581  soft_log_loss
# 9       RandomForestMSE_DSTL    0.695652   0.822581  soft_log_loss
# 15       NeuralNetTorch_DSTL    0.652174   0.806452  soft_log_loss
# 18     KNeighborsDist_BAG_L1    0.391304   0.799353       accuracy
# 17     KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.210649       0.230767  10.462600                 0.000000
# 2         0.116225       0.142537   9.539016                 0.116225
# 13        0.133158       0.027272   5.324706                 0.133158
# 7         0.066733       0.028132   2.637169                 0.066733
# 10        0.111568       0.094240   0.757924                 0.111568
# 12        0.102651       0.035384   4.021726                 0.102651
# 6         0.094424       0.088229   0.747717                 0.094424
# 14        0.182197       0.156438  25.178305                 0.182197
# 16        0.236560       0.041190   3.473365                 0.236560
# 11        0.025891       0.017014  25.264824                 0.025891
# 5         0.087710       0.092353   0.960024                 0.087710
# 8         0.067438       0.092600   0.802094                 0.067438
# 3         0.010072       0.000000   1.232379                 0.010072
# 4         0.033613       0.003028  20.736611                 0.015903
# 1         0.007639       0.003028  19.470948                 0.007639
# 9         0.104653       0.065165   0.849490                 0.104653
# 15        0.004006       0.031252  26.381263                 0.004006
# 18        0.015971       0.000000   0.016657                 0.015971
# 17        0.014819       0.313280   0.007509                 0.014819
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000000           0.175867            2       True
# 2                 0.142537           9.539016            1       True
# 13                0.027272           5.324706            1       True
# 7                 0.028132           2.637169            1       True
# 10                0.094240           0.757924            1       True
# 12                0.035384           4.021726            1       True
# 6                 0.088229           0.747717            1       True
# 14                0.156438          25.178305            1       True
# 16                0.041190           3.473365            1       True
# 11                0.017014          25.264824            1       True
# 5                 0.092353           0.960024            1       True
# 8                 0.092600           0.802094            1       True
# 3                 0.000000           1.232379            1       True
# 4                 0.000000           0.033284            2       True
# 1                 0.003028          19.470948            1       True
# 9                 0.065165           0.849490            1       True
# 15                0.031252          26.381263            1       True
# 18                0.000000           0.016657            1       True
# 17                0.313280           0.007509            1       True
#
#     fit_order
# 0          14
# 2           3
# 13         13
# 7           5
# 10         10
# 12          4
# 6           9
# 14         12
# 16         11
# 11          8
# 5           6
# 8           7
# 3          15
# 4          19
# 1          17
# 9          16
# 15         18
# 18          2
# 17          1
# 测试集上的最佳蒸馏模型：
# LightGBM_DSTL

# %% [markdown]
# <font color="Red">评估test_data</font>

# %%
eval_result = predictor.evaluate(test_data, display=True, model=best_student_model, detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7136752136752138,
#     "mcc": 0.5137023471769848
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6666666666666666,
#         "recall": 0.5333333333333333,
#         "f1-score": 0.5925925925925926,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8076923076923077,
#         "recall": 0.8076923076923077,
#         "f1-score": 0.8076923076923077,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5,
#         "recall": 0.8,
#         "f1-score": 0.6153846153846154,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6581196581196581,
#         "recall": 0.7136752136752138,
#         "f1-score": 0.6718898385565053,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7282608695652174,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7166480862133036,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7136752136752138, 'mcc': 0.5137023471769848, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     8
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    21
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             2
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6666666666666666, 'recall': 0.5333333333333333, 'f1-score': 0.5925925925925926, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8076923076923077, 'recall': 0.8076923076923077, 'f1-score': 0.8076923076923077, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5, 'recall': 0.8, 'f1-score': 0.6153846153846154, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6581196581196581, 'recall': 0.7136752136752138, 'f1-score': 0.6718898385565053, 'support': 46.0}, 'weighted avg': {'precision': 0.7282608695652174, 'recall': 0.717391304347826, 'f1-score': 0.7166480862133036, 'support': 46.0}}}

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.717391304347826
# Evaluations on test data:
# {
#     "accuracy": 0.717391304347826,
#     "balanced_accuracy": 0.7042735042735043,
#     "mcc": 0.5017362354034579
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.6363636363636364,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5384615384615384,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.7857142857142857,
#         "recall": 0.8461538461538461,
#         "f1-score": 0.8148148148148148,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.5714285714285714,
#         "recall": 0.8,
#         "f1-score": 0.6666666666666666,
#         "support": 5.0
#     },
#     "accuracy": 0.717391304347826,
#     "macro avg": {
#         "precision": 0.6645021645021645,
#         "recall": 0.7042735042735043,
#         "f1-score": 0.6733143399810065,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.7137210615471483,
#         "recall": 0.717391304347826,
#         "f1-score": 0.7085965564226433,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.717391304347826, 'balanced_accuracy': 0.7042735042735043, 'mcc': 0.5017362354034579, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 3
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         6
# Exc L2-3 LINC00507 FREM3 superficial                                    22
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             2
# Exc L2-3 LINC00507 FREM3 superficial                         1
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.6363636363636364, 'recall': 0.4666666666666667, 'f1-score': 0.5384615384615384, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.7857142857142857, 'recall': 0.8461538461538461, 'f1-score': 0.8148148148148148, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.5714285714285714, 'recall': 0.8, 'f1-score': 0.6666666666666666, 'support': 5.0}, 'accuracy': 0.717391304347826, 'macro avg': {'precision': 0.6645021645021645, 'recall': 0.7042735042735043, 'f1-score': 0.6733143399810065, 'support': 46.0}, 'weighted avg': {'precision': 0.7137210615471483, 'recall': 0.717391304347826, 'f1-score': 0.7085965564226433, 'support': 46.0}}}

# %% [markdown]
# #### 预测与实际对比

# %%
from sklearn.metrics import classification_report
y_pred = predictor.predict(test_data_nolabel, model=best_student_model)
results = pd.concat([y_pred, pd.DataFrame(y_test, columns = [LABEL_COLUMN])], axis=1)
results.columns=['predicted', 'actual']
# 打印每个类的精确度，召回率，F1值, 由于样本量较少,会出现被0除, 计算结果为0，但会出现警告错误：
# UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. 
# Use `zero_division` parameter to control this behavior._warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
print(classification_report(results['actual'], results['predicted'], target_names=t_types_updated))
# 输出预测值与实际值对比
#results
# Out:
#                                       precision    recall  f1-score   support
#
#                     Exc L2 LAMP5 LTK       0.67      0.53      0.59        15
# Exc L2-3 LINC00507 FREM3 superficial       0.81      0.81      0.81        26
#             Exc L2-4 LINC00507 GLP2R       0.50      0.80      0.62         5
#
#                             accuracy                           0.72        46
#                            macro avg       0.66      0.71      0.67        46
#                         weighted avg       0.73      0.72      0.72        46

# %% [markdown]
# ### <font color=Red>第二次蒸馏</font>
# 这里使用了过滤后的数据，但不知道是在原来的dstl基础上蒸馏，还是又再原来的基础模型上又做了一遍蒸馏，但。

# %%
augmentation_data = new_unlabeled_data.iloc[:,0:-1]
predictor.set_model_best('WeightedEnsemble_L2_DSTL')#best_student_model)
teacher_preds = 'soft'
# augment_method 可选'munge'和'spunge',缺省为spunge，可以选择测试模型的效果
augment_method = 'munge'
# 训练中输出的信息详细程度
verbosity = 3
# 蒸馏student模型
student_models = predictor.distill(augmentation_data = augmentation_data, teacher_preds = teacher_preds, augment_method = augment_method, verbosity = verbosity) 
print(student_models)
# Out:
# Distilling with teacher='WeightedEnsemble_L2_DSTL', teacher_preds=soft, augment_method=munge ...
# Model configs that will be trained (in order):
# 	LightGBM_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 100}}
# 	RandomForestMSE_2_DSTL: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 60}}
# 	NeuralNetTorch_2_DSTL: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 0}}
# Distilling with each of these student models: ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL']
# Fitting 4 L1 models ...
# Fitting model: LightGBM_2_DSTL ...
# [50]	valid_set's soft_log_loss: -0.504662
# [100]	valid_set's soft_log_loss: -0.422904
# [150]	valid_set's soft_log_loss: -0.448053
# [200]	valid_set's soft_log_loss: -0.477393
# [250]	valid_set's soft_log_loss: -0.529354
# [300]	valid_set's soft_log_loss: -0.566494
# 	Note: model has different eval_metric than default.
# 	-0.4223	 = Validation score   (-soft_log_loss)
# 	1.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE_2_DSTL ...
# [350]	valid_set's soft_log_loss: -0.591131
# [400]	valid_set's soft_log_loss: -0.603331
# 	Note: model has different eval_metric than default.
# 	-0.4784	 = Validation score   (-soft_log_loss)
# 	0.79s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_DSTL ...
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\catboost\core.py:2321: UserWarning: Can't optimze method "evaluate" because self argument is used
#   _check_train_params(params)
# 0:	learn: -1.0694448	test: -1.0850461	best: -1.0850461 (0)	total: 559ms	remaining: 1h 33m 5s
# 20:	learn: -0.7303510	test: -0.8078041	best: -0.8078041 (20)	total: 890ms	remaining: 7m 3s
# 40:	learn: -0.5938023	test: -0.6916414	best: -0.6916414 (40)	total: 1.21s	remaining: 4m 55s
# 60:	learn: -0.5260619	test: -0.6227362	best: -0.6227362 (60)	total: 1.54s	remaining: 4m 11s
# 80:	learn: -0.4852039	test: -0.5894112	best: -0.5894112 (80)	total: 1.89s	remaining: 3m 51s
# 100:	learn: -0.4481672	test: -0.5498395	best: -0.5498395 (100)	total: 2.23s	remaining: 3m 38s
# 120:	learn: -0.4199348	test: -0.5209286	best: -0.5209286 (120)	total: 2.62s	remaining: 3m 33s
# 140:	learn: -0.3996628	test: -0.5018582	best: -0.5017940 (139)	total: 2.96s	remaining: 3m 26s
# 160:	learn: -0.3829185	test: -0.4831218	best: -0.4831218 (160)	total: 3.29s	remaining: 3m 20s
# 180:	learn: -0.3678082	test: -0.4733966	best: -0.4733966 (180)	total: 3.62s	remaining: 3m 16s
# 200:	learn: -0.3549285	test: -0.4598653	best: -0.4598653 (200)	total: 3.96s	remaining: 3m 13s
# 220:	learn: -0.3445807	test: -0.4533472	best: -0.4533472 (220)	total: 4.28s	remaining: 3m 9s
# 240:	learn: -0.3366717	test: -0.4495759	best: -0.4492477 (236)	total: 4.62s	remaining: 3m 7s
# 260:	learn: -0.3298847	test: -0.4444649	best: -0.4444649 (260)	total: 4.95s	remaining: 3m 4s
# 280:	learn: -0.3231888	test: -0.4370183	best: -0.4370183 (280)	total: 5.28s	remaining: 3m 2s
# 300:	learn: -0.3163952	test: -0.4351013	best: -0.4351013 (300)	total: 5.6s	remaining: 3m
# 320:	learn: -0.3108272	test: -0.4334586	best: -0.4333134 (317)	total: 5.92s	remaining: 2m 58s
# 340:	learn: -0.3056344	test: -0.4277552	best: -0.4277552 (340)	total: 6.28s	remaining: 2m 58s
# 360:	learn: -0.3013292	test: -0.4269883	best: -0.4264583 (354)	total: 6.64s	remaining: 2m 57s
# 380:	learn: -0.2977108	test: -0.4251667	best: -0.4248282 (379)	total: 6.98s	remaining: 2m 56s
# 400:	learn: -0.2937005	test: -0.4219285	best: -0.4219285 (400)	total: 7.39s	remaining: 2m 56s
# 420:	learn: -0.2905475	test: -0.4217201	best: -0.4208865 (418)	total: 7.7s	remaining: 2m 55s
# 440:	learn: -0.2876410	test: -0.4201557	best: -0.4197861 (435)	total: 8.03s	remaining: 2m 54s
# 460:	learn: -0.2844972	test: -0.4169042	best: -0.4169042 (460)	total: 8.37s	remaining: 2m 53s
# 480:	learn: -0.2814781	test: -0.4154594	best: -0.4146863 (476)	total: 8.71s	remaining: 2m 52s
# 500:	learn: -0.2794261	test: -0.4156002	best: -0.4146863 (476)	total: 9.07s	remaining: 2m 51s
# 520:	learn: -0.2771439	test: -0.4129909	best: -0.4129909 (520)	total: 9.4s	remaining: 2m 51s
# 540:	learn: -0.2752631	test: -0.4123143	best: -0.4113905 (534)	total: 9.72s	remaining: 2m 49s
# 560:	learn: -0.2734375	test: -0.4114932	best: -0.4110427 (555)	total: 10s	remaining: 2m 49s
# 580:	learn: -0.2718124	test: -0.4128089	best: -0.4110427 (555)	total: 10.4s	remaining: 2m 48s
# 600:	learn: -0.2701957	test: -0.4121055	best: -0.4110427 (555)	total: 10.7s	remaining: 2m 47s
# 620:	learn: -0.2688110	test: -0.4105637	best: -0.4105637 (620)	total: 11s	remaining: 2m 46s
# 640:	learn: -0.2674668	test: -0.4109097	best: -0.4105637 (620)	total: 11.4s	remaining: 2m 46s
# 660:	learn: -0.2663008	test: -0.4102104	best: -0.4102104 (660)	total: 11.7s	remaining: 2m 45s
# 680:	learn: -0.2650979	test: -0.4101109	best: -0.4099744 (671)	total: 12s	remaining: 2m 44s
# 700:	learn: -0.2640327	test: -0.4113733	best: -0.4093604 (685)	total: 12.3s	remaining: 2m 43s
# 720:	learn: -0.2630547	test: -0.4117308	best: -0.4093604 (685)	total: 12.6s	remaining: 2m 42s
# 740:	learn: -0.2621271	test: -0.4113896	best: -0.4093604 (685)	total: 13s	remaining: 2m 42s
# 760:	learn: -0.2612018	test: -0.4110082	best: -0.4093604 (685)	total: 13.3s	remaining: 2m 41s
# 780:	learn: -0.2603087	test: -0.4114484	best: -0.4093604 (685)	total: 13.7s	remaining: 2m 41s
# 800:	learn: -0.2594679	test: -0.4120771	best: -0.4093604 (685)	total: 14s	remaining: 2m 40s
# 820:	learn: -0.2586505	test: -0.4136647	best: -0.4093604 (685)	total: 14.3s	remaining: 2m 39s
# 840:	learn: -0.2579376	test: -0.4121208	best: -0.4093604 (685)	total: 14.6s	remaining: 2m 39s
# 860:	learn: -0.2573600	test: -0.4127881	best: -0.4093604 (685)	total: 15s	remaining: 2m 38s
# 880:	learn: -0.2567086	test: -0.4137144	best: -0.4093604 (685)	total: 15.3s	remaining: 2m 38s
# 900:	learn: -0.2559726	test: -0.4146161	best: -0.4093604 (685)	total: 15.6s	remaining: 2m 37s
# 920:	learn: -0.2553838	test: -0.4139962	best: -0.4093604 (685)	total: 15.9s	remaining: 2m 36s
# 940:	learn: -0.2548131	test: -0.4146669	best: -0.4093604 (685)	total: 16.2s	remaining: 2m 36s
# 960:	learn: -0.2542930	test: -0.4143019	best: -0.4093604 (685)	total: 16.6s	remaining: 2m 35s
# 	Note: model has different eval_metric than default.
# 	-0.4094	 = Validation score   (-soft_log_loss)
# 	18.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_2_DSTL ...
# 980:	learn: -0.2537350	test: -0.4139862	best: -0.4093604 (685)	total: 16.9s	remaining: 2m 35s
#
# bestTest = -0.4093603776
# bestIteration = 685
#
# Shrink model to first 686 iterations.
# d:\pythonprj\env\tcell-QkBhXdaq-py3.11\Lib\site-packages\torch\nn\functional.py:2976: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 	Note: model has different eval_metric than default.
# 	-0.5897	 = Validation score   (-soft_log_loss)
# 	3.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Model configs that will be trained (in order):
# 	WeightedEnsemble_2_L2_DSTL: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Distilling with each of these student models: ['WeightedEnsemble_2_L2_DSTL']
# Fitting model: WeightedEnsemble_2_L2_DSTL ...
# 	Ensemble Weights: {'CatBoost_2_DSTL': 0.6, 'LightGBM_2_DSTL': 0.4}
# 	Note: model has different eval_metric than default.
# 	-0.3971	 = Validation score   (-soft_log_loss)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                         model  score_val    eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             CatBoost_2_DSTL   0.854839  soft_log_loss       0.000000  18.145262                0.000000          18.145262            1       True         22
# 1  WeightedEnsemble_2_L2_DSTL   0.854839  soft_log_loss       0.009081  19.394580                0.000000           0.034317            2       True         24
# 2             LightGBM_2_DSTL   0.838710  soft_log_loss       0.009081   1.215001                0.009081           1.215001            1       True         20
# 3       NeuralNetTorch_2_DSTL   0.790323  soft_log_loss       0.010288   3.656328                0.010288           3.656328            1       True         23
# 4      RandomForestMSE_2_DSTL   0.790323  soft_log_loss       0.050037   0.793256                0.050037           0.793256            1       True         21
# ['LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
models=predictor.leaderboard(test_data)
print('按测试集分数对所有模型排序：')
models.sort_values(by=['score_test','score_val'], ascending=False, inplace=True)
print(models)
print('测试集上的最佳蒸馏模型：')
best_student_model = models[models['model'].str.contains('DSTL')].iloc[0]['model']
print(best_student_model)
pst = presets.split('_')[0]
cv = ''
if auto_stack and dynamic_stacking:
    validation_procedure=ds_args['validation_procedure']
    folds=ds_args['n_folds']
    repeats=ds_args['n_repeats']
    cv =f"-{validation_procedure}{folds}{repeats}"
models.to_csv(f'{modality}-{cell_subset}-{pst}{cv}.csv')
# Out:
# 按测试集分数对所有模型排序：
#                          model  score_test  score_val    eval_metric  \
# 0          WeightedEnsemble_L2    0.760870   0.915858       accuracy
# 2       NeuralNetFastAI_BAG_L1    0.739130   0.902913       accuracy
# 1                CatBoost_DSTL    0.739130   0.822581  soft_log_loss
# 7        ExtraTreesGini_BAG_L1    0.717391   0.889968       accuracy
# 6      RandomForestGini_BAG_L1    0.717391   0.864078       accuracy
# 3                LightGBM_DSTL    0.717391   0.854839  soft_log_loss
# 4     WeightedEnsemble_L2_DSTL    0.717391   0.838710  soft_log_loss
# 5              LightGBM_2_DSTL    0.717391   0.838710  soft_log_loss
# 8              LightGBM_BAG_L1    0.695652   0.896440       accuracy
# 9        ExtraTreesEntr_BAG_L1    0.695652   0.896440       accuracy
# 10     RandomForestEntr_BAG_L1    0.695652   0.864078       accuracy
# 11        RandomForestMSE_DSTL    0.695652   0.822581  soft_log_loss
# 16        LightGBMLarge_BAG_L1    0.673913   0.899676       accuracy
# 15           LightGBMXT_BAG_L1    0.673913   0.893204       accuracy
# 17       NeuralNetTorch_BAG_L1    0.673913   0.883495       accuracy
# 14             CatBoost_BAG_L1    0.673913   0.873786       accuracy
# 12             CatBoost_2_DSTL    0.673913   0.854839  soft_log_loss
# 13  WeightedEnsemble_2_L2_DSTL    0.673913   0.854839  soft_log_loss
# 19              XGBoost_BAG_L1    0.652174   0.883495       accuracy
# 18         NeuralNetTorch_DSTL    0.652174   0.806452  soft_log_loss
# 20       NeuralNetTorch_2_DSTL    0.630435   0.790323  soft_log_loss
# 21      RandomForestMSE_2_DSTL    0.586957   0.790323  soft_log_loss
# 23       KNeighborsDist_BAG_L1    0.391304   0.799353       accuracy
# 22       KNeighborsUnif_BAG_L1    0.391304   0.686084       accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.218208       0.230767  10.462600                 0.000000
# 2         0.112958       0.142537   9.539016                 0.112958
# 1         0.006082       0.003028  19.470948                 0.006082
# 7         0.105250       0.088229   0.747717                 0.105250
# 6         0.104421       0.092353   0.960024                 0.104421
# 3         0.000000       0.000000   1.232379                 0.000000
# 4         0.006082       0.003028  20.736611                 0.000000
# 5         0.020662       0.009081   1.215001                 0.020662
# 8         0.062915       0.028132   2.637169                 0.062915
# 9         0.072000       0.094240   0.757924                 0.072000
# 10        0.096044       0.092600   0.802094                 0.096044
# 11        0.113129       0.065165   0.849490                 0.113129
# 16        0.105042       0.027272   5.324706                 0.105042
# 15        0.096007       0.035384   4.021726                 0.096007
# 17        0.127290       0.156438  25.178305                 0.127290
# 14        0.047186       0.017014  25.264824                 0.047186
# 12        0.010113       0.000000  18.145262                 0.010113
# 13        0.030775       0.009081  19.394580                 0.000000
# 19        0.195718       0.041190   3.473365                 0.195718
# 18        0.020203       0.031252  26.381263                 0.020203
# 20        0.020667       0.010288   3.656328                 0.020667
# 21        0.090750       0.050037   0.793256                 0.090750
# 23        0.018538       0.000000   0.016657                 0.018538
# 22        0.007001       0.313280   0.007509                 0.007001
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000000           0.175867            2       True
# 2                 0.142537           9.539016            1       True
# 1                 0.003028          19.470948            1       True
# 7                 0.088229           0.747717            1       True
# 6                 0.092353           0.960024            1       True
# 3                 0.000000           1.232379            1       True
# 4                 0.000000           0.033284            2       True
# 5                 0.009081           1.215001            1       True
# 8                 0.028132           2.637169            1       True
# 9                 0.094240           0.757924            1       True
# 10                0.092600           0.802094            1       True
# 11                0.065165           0.849490            1       True
# 16                0.027272           5.324706            1       True
# 15                0.035384           4.021726            1       True
# 17                0.156438          25.178305            1       True
# 14                0.017014          25.264824            1       True
# 12                0.000000          18.145262            1       True
# 13                0.000000           0.034317            2       True
# 19                0.041190           3.473365            1       True
# 18                0.031252          26.381263            1       True
# 20                0.010288           3.656328            1       True
# 21                0.050037           0.793256            1       True
# 23                0.000000           0.016657            1       True
# 22                0.313280           0.007509            1       True
#
#     fit_order
# 0          14
# 2           3
# 1          17
# 7           9
# 6           6
# 3          15
# 4          19
# 5          20
# 8           5
# 9          10
# 10          7
# 11         16
# 16         13
# 15          4
# 17         12
# 14          8
# 12         22
# 13         24
# 19         11
# 18         18
# 20         23
# 21         21
# 23          2
# 22          1
# 测试集上的最佳蒸馏模型：
# CatBoost_DSTL

# %%
eval_result = predictor.evaluate(test_data, display=True, model='WeightedEnsemble_2_L2_DSTL', detailed_report=True)
print(eval_result)
# Out:
# Evaluation: accuracy on test data: 0.6739130434782609
# Evaluations on test data:
# {
#     "accuracy": 0.6739130434782609,
#     "balanced_accuracy": 0.6786324786324786,
#     "mcc": 0.44891205220309377
# }
# Detailed (per-class) classification report:
# {
#     "Exc L2 LAMP5 LTK": {
#         "precision": 0.5833333333333334,
#         "recall": 0.4666666666666667,
#         "f1-score": 0.5185185185185185,
#         "support": 15.0
#     },
#     "Exc L2-3 LINC00507 FREM3 superficial": {
#         "precision": 0.8,
#         "recall": 0.7692307692307693,
#         "f1-score": 0.7843137254901961,
#         "support": 26.0
#     },
#     "Exc L2-4 LINC00507 GLP2R": {
#         "precision": 0.4444444444444444,
#         "recall": 0.8,
#         "f1-score": 0.5714285714285714,
#         "support": 5.0
#     },
#     "accuracy": 0.6739130434782609,
#     "macro avg": {
#         "precision": 0.6092592592592593,
#         "recall": 0.6786324786324786,
#         "f1-score": 0.624753605145762,
#         "support": 46.0
#     },
#     "weighted avg": {
#         "precision": 0.6907004830917874,
#         "recall": 0.6739130434782609,
#         "f1-score": 0.6745016847318638,
#         "support": 46.0
#     }
# }
# {'accuracy': 0.6739130434782609, 'balanced_accuracy': 0.6786324786324786, 'mcc': 0.44891205220309377, 'confusion_matrix':                                       Exc L2 LAMP5 LTK  \
# Exc L2 LAMP5 LTK                                     7
# Exc L2-3 LINC00507 FREM3 superficial                 4
# Exc L2-4 LINC00507 GLP2R                             1
#
#                                       Exc L2-3 LINC00507 FREM3 superficial  \
# Exc L2 LAMP5 LTK                                                         5
# Exc L2-3 LINC00507 FREM3 superficial                                    20
# Exc L2-4 LINC00507 GLP2R                                                 0
#
#                                       Exc L2-4 LINC00507 GLP2R
# Exc L2 LAMP5 LTK                                             3
# Exc L2-3 LINC00507 FREM3 superficial                         2
# Exc L2-4 LINC00507 GLP2R                                     4  , 'classification_report': {'Exc L2 LAMP5 LTK': {'precision': 0.5833333333333334, 'recall': 0.4666666666666667, 'f1-score': 0.5185185185185185, 'support': 15.0}, 'Exc L2-3 LINC00507 FREM3 superficial': {'precision': 0.8, 'recall': 0.7692307692307693, 'f1-score': 0.7843137254901961, 'support': 26.0}, 'Exc L2-4 LINC00507 GLP2R': {'precision': 0.4444444444444444, 'recall': 0.8, 'f1-score': 0.5714285714285714, 'support': 5.0}, 'accuracy': 0.6739130434782609, 'macro avg': {'precision': 0.6092592592592593, 'recall': 0.6786324786324786, 'f1-score': 0.624753605145762, 'support': 46.0}, 'weighted avg': {'precision': 0.6907004830917874, 'recall': 0.6739130434782609, 'f1-score': 0.6745016847318638, 'support': 46.0}}}

# %% [markdown]
# ### 利用SNS和Matplotlib绘制混淆矩阵

# %% [markdown]
# #### 利用matplotlib的matshow函数绘制混淆矩阵

# %%
from sklearn.metrics import confusion_matrix
cfm = confusion_matrix(results['actual'], results['predicted'])

#imshow和matshow二者不同在于横轴一个在上方一个在下方，还有就是plt.matshow()显示图片可以连续使用，
# 但是plt.imshow()想要显示多张图片必须每次都新建一个图plt.figure()或者使用plt.subplots()
ax = plt.imshow(cfm, origin ='lower') 

plt.title("Confusion Matrix",fontsize=25)
plt.colorbar(ax.colorbar, fraction=0.025)
plt.xlabel('actual')
plt.ylabel('predicted')
# 设置刻度字体大小
plt.xticks(np.arange(len(t_types_updated)),labels=t_types_updated, rotation=25,  ha="right",fontsize=10)
plt.yticks(np.arange(len(t_types_updated)),labels=t_types_updated, fontsize=10)
#plt.set_xticklabels(t_types_updated)
for i in range(cfm.shape[0]):
    for j in range(cfm.shape[1]):
        plt.text(j, i, f'{cfm[i, j]:.0f}', ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# ## 9. 其它

# %% [markdown]
# ### 9.1 选择特定模型预测的方法

# %%
# 打印模型索引和模型名
all_models = predictor.model_names()
print(all_models)
# Out:
# ['KNeighborsUnif_BAG_L1', 'KNeighborsDist_BAG_L1', 'NeuralNetFastAI_BAG_L1', 'LightGBMXT_BAG_L1', 'LightGBM_BAG_L1', 'RandomForestGini_BAG_L1', 'RandomForestEntr_BAG_L1', 'CatBoost_BAG_L1', 'ExtraTreesGini_BAG_L1', 'ExtraTreesEntr_BAG_L1', 'XGBoost_BAG_L1', 'NeuralNetTorch_BAG_L1', 'LightGBMLarge_BAG_L1', 'WeightedEnsemble_L2', 'LightGBM_DSTL', 'RandomForestMSE_DSTL', 'CatBoost_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL', 'LightGBM_2_DSTL', 'RandomForestMSE_2_DSTL', 'CatBoost_2_DSTL', 'NeuralNetTorch_2_DSTL', 'WeightedEnsemble_2_L2_DSTL']

# %%
# 选择特定模型预测,i为选择的模型索引
i = 0  # index of model to use
model_to_use = all_models[i]
model_pred = predictor.predict(test_data, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from KNeighborsUnif_BAG_L1 model: Exc L2-3 LINC00507 FREM3 superficial

# %% [markdown]
# ### 9.2 删除其余模型的方法

# %%
# 删除其余模型（减少内存开销）,只保留最佳模型
#predictor.delete_models(models_to_keep='best')

# %%
'''
from sklearn.preprocessing import LabelEncoder
# 转换标签列
label_encoder = LabelEncoder()
labeled_y = labeled_data[LABEL_COLUMN]
labeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)
class_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))
print(class_dict)
'''
# Out:
# '\nfrom sklearn.preprocessing import LabelEncoder\n# 转换标签列\nlabel_encoder = LabelEncoder()\nlabeled_y = labeled_data[LABEL_COLUMN]\nlabeled_data[LABEL_COLUMN] = label_encoder.fit_transform(labeled_data[LABEL_COLUMN]).astype(np.int8)\nclass_dict = dict(zip(label_encoder.transform(label_encoder.classes_), label_encoder.classes_))\nprint(class_dict)\n'
